# %% [markdown]
# # Visibility Metrics for Typescript
# <br>
#
# ### References
# - [Visibility Metrics and the Importance of Hiding Things](https://dzone.com/articles/visibility-metrics-and-the-importance-of-hiding-th)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Controlling Access to Members of a Class](https://docs.oracle.com/javase/tutorial/java/javaOO/accesscontrol.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())
    

def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Relative Visibility Of Elements
#
# A Typescript element (variable, function, class, ...) may be exported in which case it is visible and can be imported everywhere (if there are no other rules defined). If there is no "export" keyword and the element (variable, function, class, ...) is only declared, then it is only visible within the file or module.
#
# The relative visibility is the number of inner components that are visible outside (exported) divided by the number of all components:
#
# $$ relative visibility = \frac{exported\:elements}{all\:declared\:elements} $$
#
# Using directories with an index file as a module and exporting only the elements (variables, function, classes, ...) that the caller of the module should use is a good way to improve encapsulation and implementation detail hiding.
#
# ### How to apply the results
#
# The relative visibility is between zero (no element is exported) and one (all elements are exported). A value lower than one means that there are elements that are not exported. The lower the value is, the better the encapsulation and the better the implementation details are hidden.
#
# Non exported elements can't be accessed from another modules so they can be changed without affecting code in other modules. They clearly indicate functionality that only belongs to one modules. This also motivates to split up code into smaller pieces with a dedicated reason to change (single responsibility).

# %% [markdown]
# ### Table 1a - Top 40 projects with lowest median of module encapsulation
#
# This table shows the relative visibility statistics aggregated for all modules per project and focusses on projects with many modules and hardly any non-exported elements (lowest median, high visibility). Module directories with an index file and intentional exporting helps to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_elements_for_Typescript`

# %%
# Query the visibility statistics per project (all modules aggregated)
# The results will be used in multiple tables below.
relative_visibility_per_project_aggregated=query_cypher_to_data_frame("../cypher/Visibility/Global_relative_visibility_statistics_for_elements_for_Typescript.cypher")

# %%
# Sort by the "percentile50" (median) and "all" (number of modules in the project) descending
relative_visibility_statistics_highest_median=relative_visibility_per_project_aggregated.sort_values(by=['percentile50', 'all'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_highest_median=relative_visibility_statistics_highest_median.reset_index(drop=True)

relative_visibility_statistics_highest_median.head(40)
# Out:
#                                          projectPath  all  exported  min  \
# 0  /home/runner/work/code-graph-analysis-examples...   26        18  0.0
# 1  /home/runner/work/code-graph-analysis-examples...   13         8  0.0
# 2  /home/runner/work/code-graph-analysis-examples...  389       132  0.0
# 3  /home/runner/work/code-graph-analysis-examples...   12         8  0.0
# 4  /home/runner/work/code-graph-analysis-examples...  726       559  0.0
# 5  /home/runner/work/code-graph-analysis-examples...   14         8  0.0
# 6  /home/runner/work/code-graph-analysis-examples...   10         6  0.0
# 7  /home/runner/work/code-graph-analysis-examples...  124        46  0.0
# 8  /home/runner/work/code-graph-analysis-examples...    8         6  0.0
# 9  /home/runner/work/code-graph-analysis-examples...    6         0  0.0
#
#          max   average  percentile25  percentile50  percentile75  \
# 0   1.000000  0.730000      0.650000      1.000000      1.000000
# 1   1.000000  0.685714      0.428571      1.000000      1.000000
# 2   1.000000  0.672601      0.357143      0.750000      1.000000
# 3   0.800000  0.533333      0.500000      0.666667      0.700000
# 4  85.000000  2.081895      0.402941      0.554945      0.975000
# 5   0.857143  0.371429      0.000000      0.500000      0.500000
# 6   0.714286  0.404762      0.250000      0.500000      0.607143
# 7   1.000000  0.513557      0.068391      0.471861      1.000000
# 8   0.857143  0.428571      0.214286      0.428571      0.642857
# 9   0.000000  0.000000      0.000000      0.000000      0.000000
#
#    percentile90  percentile95  percentile99
# 0      1.000000      1.000000      1.000000
# 1      1.000000      1.000000      1.000000
# 2      1.000000      1.000000      1.000000
# 3      0.760000      0.780000      0.796000
# 4      1.000000      1.000000     37.690000
# 5      0.714286      0.785714      0.842857
# 6      0.671429      0.692857      0.710000
# 7      1.000000      1.000000      1.000000
# 8      0.771429      0.814286      0.848571
# 9      0.000000      0.000000      0.000000

# %% [markdown]
# ### Table 1b - Top 40 projects with highest median of module encapsulation
#
# This table shows the relative visibility statistics aggregated for all modules per project and focusses on project with many modules and the highest median of non-exported elements (variables, functions, classes, ...) (low visibility). Module directories with an index file and intentional exporting helps to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_elements_for_Typescript`

# %%
# Sort by the "percentile50" (median) ascending and "all" (number of packages in the artifact) descending
relative_visibility_statistics_lowest_median=relative_visibility_per_project_aggregated.sort_values(by=['percentile50', 'all'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_lowest_median=relative_visibility_statistics_lowest_median.reset_index(drop=True)

relative_visibility_statistics_lowest_median.head(40)
# Out:
#                                          projectPath  all  exported  min  \
# 0  /home/runner/work/code-graph-analysis-examples...    6         0  0.0
# 1  /home/runner/work/code-graph-analysis-examples...    8         6  0.0
# 2  /home/runner/work/code-graph-analysis-examples...  124        46  0.0
# 3  /home/runner/work/code-graph-analysis-examples...   14         8  0.0
# 4  /home/runner/work/code-graph-analysis-examples...   10         6  0.0
# 5  /home/runner/work/code-graph-analysis-examples...  726       559  0.0
# 6  /home/runner/work/code-graph-analysis-examples...   12         8  0.0
# 7  /home/runner/work/code-graph-analysis-examples...  389       132  0.0
# 8  /home/runner/work/code-graph-analysis-examples...   26        18  0.0
# 9  /home/runner/work/code-graph-analysis-examples...   13         8  0.0
#
#          max   average  percentile25  percentile50  percentile75  \
# 0   0.000000  0.000000      0.000000      0.000000      0.000000
# 1   0.857143  0.428571      0.214286      0.428571      0.642857
# 2   1.000000  0.513557      0.068391      0.471861      1.000000
# 3   0.857143  0.371429      0.000000      0.500000      0.500000
# 4   0.714286  0.404762      0.250000      0.500000      0.607143
# 5  85.000000  2.081895      0.402941      0.554945      0.975000
# 6   0.800000  0.533333      0.500000      0.666667      0.700000
# 7   1.000000  0.672601      0.357143      0.750000      1.000000
# 8   1.000000  0.730000      0.650000      1.000000      1.000000
# 9   1.000000  0.685714      0.428571      1.000000      1.000000
#
#    percentile90  percentile95  percentile99
# 0      0.000000      0.000000      0.000000
# 1      0.771429      0.814286      0.848571
# 2      1.000000      1.000000      1.000000
# 3      0.714286      0.785714      0.842857
# 4      0.671429      0.692857      0.710000
# 5      1.000000      1.000000     37.690000
# 6      0.760000      0.780000      0.796000
# 7      1.000000      1.000000      1.000000
# 8      1.000000      1.000000      1.000000
# 9      1.000000      1.000000      1.000000

# %% [markdown]
# ### Table 1 Chart 1 - Relative visibility in projects

# %%
plot.figure();
fig, axes = plot.subplots(nrows=3, ncols=1, sharex=True)

number_of_modules_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_project_aggregated.plot(
    ax=axes[0],
    kind='scatter',
    title='Relative visibility in projects (75% percentile)', 
    x='percentile75',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_modules_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of modules',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_project_aggregated.plot(
    ax=axes[1],
    kind='scatter',
    title='Relative visibility in projects (50% percentile)', 
    x='percentile50',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_modules_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of modules',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_project_aggregated.plot(
    ax=axes[2],
    kind='scatter',
    title='Relative visibility in artifacts (25% percentile)', 
    x='percentile25',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_modules_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,10),
)
axes[0].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[1].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[2].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
plot.show()
# Out:
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### Table 2a - Top 40 modules with the highest visibility and lowest encapsulation
#
# This table shows the relative visibility statistics per module and project and focusses on modules with many elements (variables, functions, classes, ...), hardly any non-exported ones and therefore the highest relative visibility (lowest encapsulation). Module directories with an index file and intentional exporting helps to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_exported_elements_to_all_elements_per_module_for_Typescript`

# %%
# Query the visibility statistics per module and project (all elements aggregated)
# The results will be used in multiple tables below.
relative_visibility_per_module=query_cypher_to_data_frame("../cypher/Visibility/Relative_visibility_exported_elements_to_all_elements_per_module_for_Typescript.cypher")

# %%
# Sort by the "relativeVisibility" and "allElements" (number of elements in the module) descending
highest_relative_visibility_module=relative_visibility_per_module.sort_values(by=['relativeVisibility', 'allElements'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
highest_relative_visibility_module=highest_relative_visibility_module.reset_index(drop=True)

highest_relative_visibility_module.head(40)
# Out:
#                                           projectPath  \
# 0   /home/runner/work/code-graph-analysis-examples...
# 1   /home/runner/work/code-graph-analysis-examples...
# 2   /home/runner/work/code-graph-analysis-examples...
# 3   /home/runner/work/code-graph-analysis-examples...
# 4   /home/runner/work/code-graph-analysis-examples...
# 5   /home/runner/work/code-graph-analysis-examples...
# 6   /home/runner/work/code-graph-analysis-examples...
# 7   /home/runner/work/code-graph-analysis-examples...
# 8   /home/runner/work/code-graph-analysis-examples...
# 9   /home/runner/work/code-graph-analysis-examples...
# 10  /home/runner/work/code-graph-analysis-examples...
# 11  /home/runner/work/code-graph-analysis-examples...
# 12  /home/runner/work/code-graph-analysis-examples...
# 13  /home/runner/work/code-graph-analysis-examples...
# 14  /home/runner/work/code-graph-analysis-examples...
# 15  /home/runner/work/code-graph-analysis-examples...
# 16  /home/runner/work/code-graph-analysis-examples...
# 17  /home/runner/work/code-graph-analysis-examples...
# 18  /home/runner/work/code-graph-analysis-examples...
# 19  /home/runner/work/code-graph-analysis-examples...
# 20  /home/runner/work/code-graph-analysis-examples...
# 21  /home/runner/work/code-graph-analysis-examples...
# 22  /home/runner/work/code-graph-analysis-examples...
# 23  /home/runner/work/code-graph-analysis-examples...
# 24  /home/runner/work/code-graph-analysis-examples...
# 25  /home/runner/work/code-graph-analysis-examples...
# 26  /home/runner/work/code-graph-analysis-examples...
# 27  /home/runner/work/code-graph-analysis-examples...
# 28  /home/runner/work/code-graph-analysis-examples...
# 29  /home/runner/work/code-graph-analysis-examples...
# 30  /home/runner/work/code-graph-analysis-examples...
# 31  /home/runner/work/code-graph-analysis-examples...
# 32  /home/runner/work/code-graph-analysis-examples...
# 33  /home/runner/work/code-graph-analysis-examples...
# 34  /home/runner/work/code-graph-analysis-examples...
# 35  /home/runner/work/code-graph-analysis-examples...
# 36  /home/runner/work/code-graph-analysis-examples...
# 37  /home/runner/work/code-graph-analysis-examples...
# 38  /home/runner/work/code-graph-analysis-examples...
# 39  /home/runner/work/code-graph-analysis-examples...
#
#                              modulePath             moduleName  \
# 0       vendor/turbo-stream-v2/utils.ts                  utils
# 1          lib/server-runtime/errors.ts                 errors
# 2                    prompts-confirm.ts        prompts-confirm
# 3                     prompts-select.ts         prompts-select
# 4              lib/dom/ssr/invariant.ts              invariant
# 5       lib/server-runtime/invariant.ts              invariant
# 6                          invariant.ts              invariant
# 7                           manifest.ts               manifest
# 8                           manifest.ts               manifest
# 9               prompts-multi-select.ts   prompts-multi-select
# 10               prompts-prompt-base.ts    prompts-prompt-base
# 11                      prompts-text.ts           prompts-text
# 12                  lib/types/future.ts                 future
# 13                    lib/dom/global.ts                 global
# 14           lib/server-runtime/mode.ts                   mode
# 15                             index.ts           react-router
# 16  lib/server-runtime/routeMatching.ts          routeMatching
# 17  lib/server-runtime/serverHandoff.ts          serverHandoff
# 18                        vite/babel.ts                  babel
# 19                   typegen/context.ts                context
# 20                          vite/dev.ts                    dev
# 21                          manifest.ts               manifest
# 22                 vite/node-adapter.ts           node-adapter
# 23                     typegen/route.ts                  route
# 24                    vite/vite-node.ts              vite-node
# 25       lib/rsc/html-stream/browser.ts                browser
# 26                  lib/dom/ssr/data.ts                   data
# 27          lib/server-runtime/entry.ts                  entry
# 28                lib/dom/ssr/errors.ts                 errors
# 29                lib/types/internal.ts               internal
# 30                  lib/types/params.ts                 params
# 31            lib/types/route-module.ts           route-module
# 32                 vite/combine-urls.ts           combine-urls
# 33               vite/has-dependency.ts         has-dependency
# 34               vite/has-rsc-plugin.ts         has-rsc-plugin
# 35       config/is-react-router-repo.ts   is-react-router-repo
# 36                  vite/load-dotenv.ts            load-dotenv
# 37        vite/optimize-deps-entries.ts  optimize-deps-entries
# 38                    typegen/params.ts                 params
# 39             vite/resolve-file-url.ts       resolve-file-url
#
#     exportedElements  allElements  relativeVisibility
# 0                 24           24                 1.0
# 1                  5            5                 1.0
# 2                  3            3                 1.0
# 3                  3            3                 1.0
# 4                  3            3                 1.0
# 5                  3            3                 1.0
# 6                  3            3                 1.0
# 7                  3            3                 1.0
# 8                  3            3                 1.0
# 9                  2            2                 1.0
# 10                 2            2                 1.0
# 11                 2            2                 1.0
# 12                 2            2                 1.0
# 13                 2            2                 1.0
# 14                 2            2                 1.0
# 15                 2            2                 1.0
# 16                 2            2                 1.0
# 17                 2            2                 1.0
# 18                 2            2                 1.0
# 19                 2            2                 1.0
# 20                 2            2                 1.0
# 21                 2            2                 1.0
# 22                 2            2                 1.0
# 23                 2            2                 1.0
# 24                 2            2                 1.0
# 25                 1            1                 1.0
# 26                 1            1                 1.0
# 27                 1            1                 1.0
# 28                 1            1                 1.0
# 29                 1            1                 1.0
# 30                 1            1                 1.0
# 31                 1            1                 1.0
# 32                 1            1                 1.0
# 33                 1            1                 1.0
# 34                 1            1                 1.0
# 35                 1            1                 1.0
# 36                 1            1                 1.0
# 37                 1            1                 1.0
# 38                 1            1                 1.0
# 39                 1            1                 1.0

# %% [markdown]
# ### Table 2b - Top 40 modules with the lowest visibility and highest encapsulation
#
# This table shows the relative visibility statistics per modules and project and focusses on modules with many elements (variables, functions, classes, ...), many non-exported ones and therefore the lowest relative visibility (highest encapsulation). Non-exported elements help to improve encapsulation. Zero percent visibility and therefore modules with no exported elements are suspicious to contain dead code.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Sort by the "relativeVisibility" ascending and "allTypes" (number of types in the package) descending
lowest_relative_visibility_modules=relative_visibility_per_module.sort_values(by=['relativeVisibility', 'allElements'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
lowest_relative_visibility_modules=lowest_relative_visibility_modules.reset_index(drop=True)

lowest_relative_visibility_modules.head(40)
# Out:
#                                           projectPath  \
# 0   /home/runner/work/code-graph-analysis-examples...
# 1   /home/runner/work/code-graph-analysis-examples...
# 2   /home/runner/work/code-graph-analysis-examples...
# 3   /home/runner/work/code-graph-analysis-examples...
# 4   /home/runner/work/code-graph-analysis-examples...
# 5   /home/runner/work/code-graph-analysis-examples...
# 6   /home/runner/work/code-graph-analysis-examples...
# 7   /home/runner/work/code-graph-analysis-examples...
# 8   /home/runner/work/code-graph-analysis-examples...
# 9   /home/runner/work/code-graph-analysis-examples...
# 10  /home/runner/work/code-graph-analysis-examples...
# 11  /home/runner/work/code-graph-analysis-examples...
# 12  /home/runner/work/code-graph-analysis-examples...
# 13  /home/runner/work/code-graph-analysis-examples...
# 14  /home/runner/work/code-graph-analysis-examples...
# 15  /home/runner/work/code-graph-analysis-examples...
# 16  /home/runner/work/code-graph-analysis-examples...
# 17  /home/runner/work/code-graph-analysis-examples...
# 18  /home/runner/work/code-graph-analysis-examples...
# 19  /home/runner/work/code-graph-analysis-examples...
# 20  /home/runner/work/code-graph-analysis-examples...
# 21  /home/runner/work/code-graph-analysis-examples...
# 22  /home/runner/work/code-graph-analysis-examples...
# 23  /home/runner/work/code-graph-analysis-examples...
# 24  /home/runner/work/code-graph-analysis-examples...
# 25  /home/runner/work/code-graph-analysis-examples...
# 26  /home/runner/work/code-graph-analysis-examples...
# 27  /home/runner/work/code-graph-analysis-examples...
# 28  /home/runner/work/code-graph-analysis-examples...
# 29  /home/runner/work/code-graph-analysis-examples...
# 30  /home/runner/work/code-graph-analysis-examples...
# 31  /home/runner/work/code-graph-analysis-examples...
# 32  /home/runner/work/code-graph-analysis-examples...
# 33  /home/runner/work/code-graph-analysis-examples...
# 34  /home/runner/work/code-graph-analysis-examples...
# 35  /home/runner/work/code-graph-analysis-examples...
# 36  /home/runner/work/code-graph-analysis-examples...
# 37  /home/runner/work/code-graph-analysis-examples...
# 38  /home/runner/work/code-graph-analysis-examples...
# 39  /home/runner/work/code-graph-analysis-examples...
#
#                                modulePath                moduleName  \
# 0                                  cli.ts                       cli
# 1                      tsup.config.rsc.ts                      tsup
# 2                          tsup.config.ts                      tsup
# 3                __tests__/server-test.ts               server-test
# 4                          tsup.config.ts                      tsup
# 5                                  cli.ts                       cli
# 6                          tsup.config.ts                      tsup
# 7                          tsup.config.ts                      tsup
# 8                          tsup.config.ts                      tsup
# 9                          tsup.config.ts                      tsup
# 10                         tsup.config.ts                      tsup
# 11                         tsup.config.ts                      tsup
# 12                         tsup.config.ts                      tsup
# 13                         tsup.config.ts                      tsup
# 14  lib/types/route-module-annotations.ts  route-module-annotations
# 15                              prompt.ts                    prompt
# 16                       copy-template.ts             copy-template
# 17                   loading-indicator.ts         loading-indicator
# 18                               index.ts       create-react-router
# 19      vite/rsc/virtual-route-modules.ts     virtual-route-modules
# 20           vite/cloudflare-dev-proxy.ts      cloudflare-dev-proxy
# 21                     vite/rsc/plugin.ts                    plugin
# 22                         vite/plugin.ts                    plugin
# 23          lib/rsc/html-stream/server.ts                    server
# 24                     vite/with-props.ts                with-props
# 25                         lib/actions.ts                   actions
# 26      vendor/turbo-stream-v2/flatten.ts                   flatten
# 27                            lib/href.ts                      href
# 28          lib/router/instrumentation.ts           instrumentation
# 29                   lib/router/router.ts                    router
# 30           lib/server-runtime/server.ts                    server
# 31                         vite/styles.ts                    styles
# 32                       config/config.ts                    config
# 33                   vite/route-chunks.ts              route-chunks
# 34                  lib/dom/ssr/markup.ts                    markup
# 35    vendor/turbo-stream-v2/unflatten.ts                 unflatten
# 36                 vite/remove-exports.ts            remove-exports
# 37                    typegen/generate.ts                  generate
# 38                        cli/commands.ts                  commands
# 39           lib/server-runtime/crypto.ts                    crypto
#
#     exportedElements  allElements  relativeVisibility
# 0                  0            5            0.000000
# 1                  0            3            0.000000
# 2                  0            2            0.000000
# 3                  0            2            0.000000
# 4                  0            2            0.000000
# 5                  0            1            0.000000
# 6                  0            1            0.000000
# 7                  0            1            0.000000
# 8                  0            1            0.000000
# 9                  0            1            0.000000
# 10                 0            1            0.000000
# 11                 0            1            0.000000
# 12                 0            1            0.000000
# 13                 0            1            0.000000
# 14                 1           24            0.041667
# 15                 1           15            0.066667
# 16                 2           29            0.068966
# 17                 1           12            0.083333
# 18                 2           21            0.095238
# 19                 4           37            0.108108
# 20                 1            8            0.125000
# 21                 1            8            0.125000
# 22                17          106            0.160377
# 23                 1            6            0.166667
# 24                 1            6            0.166667
# 25                 1            4            0.250000
# 26                 1            4            0.250000
# 27                 1            4            0.250000
# 28                 9           34            0.264706
# 29                33          123            0.268293
# 30                 3           11            0.272727
# 31                 4           13            0.307692
# 32                12           38            0.315789
# 33                12           36            0.333333
# 34                 1            3            0.333333
# 35                 1            3            0.333333
# 36                 1            3            0.333333
# 37                 5           14            0.357143
# 38                 5           13            0.384615
# 39                 2            5            0.400000

# %% [markdown]
# ### Table 2 Chart 1 - Relative visibility of modules

# %%
plot.figure();

number_of_types_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_module.plot(
    kind='scatter',
    title='Relative visibility of modules', 
    x='relativeVisibility',
    y='allElements',
    grid=True,
    logy=True,
    yticks=number_of_types_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of elements',
    cmap=main_color_map,
    figsize=(10,4),
)

plot.show()
# Out:
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
