# %% [markdown]
# # Overview for Typescript
#
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Overview

# %% [markdown]
# ### Table 1 - Size

# %%
overview_size = query_cypher_to_data_frame("../cypher/Overview/Overview_size_for_Typescript.cypher")
overview_size
# Out:
#    nodeCount  relationshipCount  projectCount  moduleCount  functionCount  \
# 0     203005             431601            11          156           1039
#
#    objectCount  typeAliasCount  interfaceCount  classCount  methodCount
# 0         1544             332             142          12          121

# %% [markdown]
# ## Modules

# %% [markdown]
# ### Table 2a - Largest 30 elements per module
#
# This table shows the largest (number of elements) modules and their kind of elements (Interface, TypeAlias, Variable).
# The whole table can be found in the CSV report `Number_of_elements_per_module_for_Typescript`.

# %%
elements_per_module = query_cypher_to_data_frame("../cypher/Overview/Number_of_elements_per_module_for_Typescript.cypher")
elements_per_module.drop(columns='fullQualifiedModuleName').head(30)
# Out:
#       moduleName             modulePath  numberOfModuleElements  \
# 0   react-router               index.ts                     167
# 1   react-router               index.ts                     167
# 2   react-router               index.ts                     167
# 3   react-router               index.ts                     167
# 4   react-router               index.ts                     167
# 5   react-router               index.ts                     167
# 6          utils    lib/router/utils.ts                      85
# 7          utils    lib/router/utils.ts                      85
# 8          utils    lib/router/utils.ts                      85
# 9          utils    lib/router/utils.ts                      85
# 10         utils    lib/router/utils.ts                      85
# 11         utils    lib/router/utils.ts                      85
# 12  react-router  index-react-server.ts                      39
# 13  react-router  index-react-server.ts                      39
# 14  react-router  index-react-server.ts                      39
# 15  react-router  index-react-server.ts                      39
# 16  react-router  index-react-server.ts                      39
# 17        router   lib/router/router.ts                      33
# 18        router   lib/router/router.ts                      33
# 19        router   lib/router/router.ts                      33
# 20        router   lib/router/router.ts                      33
# 21         utils               utils.ts                      28
# 22         utils               utils.ts                      28
# 23       context         lib/context.ts                      27
# 24       context         lib/context.ts                      27
# 25       context         lib/context.ts                      27
# 26       context         lib/context.ts                      27
# 27       history  lib/router/history.ts                      25
# 28       history  lib/router/history.ts                      25
# 29       history  lib/router/history.ts                      25
#
#    languageElement  numberOfElements
# 0         Function                20
# 1        TypeAlias                61
# 2        Interface                50
# 3             Enum                 2
# 4         Variable                18
# 5            Class                 3
# 6        Interface                23
# 7        TypeAlias                28
# 8            Class                 3
# 9         Function                21
# 10        Variable                 9
# 11            Enum                 1
# 12        Function                 9
# 13       TypeAlias                15
# 14        Variable                 6
# 15       Interface                 4
# 16           Class                 1
# 17       TypeAlias                11
# 18       Interface                10
# 19        Variable                 4
# 20        Function                 8
# 21        Function                24
# 22        Variable                 4
# 23       Interface                 8
# 24        Variable                12
# 25       TypeAlias                 6
# 26        Function                 1
# 27       Interface                 9
# 28        Function                 9
# 29            Enum                 1

# %% [markdown]
# ### Table 2b - Largest 30 elements per module grouped
#
# This table shows the largest (number of elements) modules each in one row, their kind of elements in columns and the count of them as values.
#
# The source data for this aggregated table can be found in the CSV report `Number_of_elements_per_module_for_Typescript`.

# %%
# Pivot the DataFrame to 
# - group by the first column (moduleName) as new index
# - convert the values in the second column (typeLabel) 
# - into columns with the value of the third column (numberOfTypes).
elements_per_module_grouped = elements_per_module.pivot(index=['fullQualifiedModuleName', 'modulePath', 'moduleName'], columns='languageElement', values='numberOfElements')

# Fill missing values with zero
elements_per_module_grouped.fillna(0, inplace=True)

# Calculate the sum of values for each row
elements_per_module_grouped['Total'] = elements_per_module_grouped.sum(axis=1)

# Sort the DataFrame by the sum of values
elements_per_module_grouped.sort_values(by='Total', ascending=False, inplace=True)

# Remove the 'Total' column
elements_per_module_grouped.drop('Total', axis=1, inplace=True)

# Sort the order of the columns by their sum
column_sum = elements_per_module_grouped.sum()
elements_per_module_grouped = elements_per_module_grouped[column_sum.sort_values(ascending=False).index[:]]

# Convert all numeric columns to integers instead of decimal numbers with .0
elements_per_module_grouped = elements_per_module_grouped.astype(int)

# Reset the index to be able to select the module name representation (name, path, full)
# elements_per_module_grouped.reset_index(inplace=True)

# Convert to integer
elements_per_module_grouped.reset_index().drop(columns='fullQualifiedModuleName').head(30)
# Out:
# languageElement                          modulePath               moduleName  \
# 0                                          index.ts             react-router
# 1                               lib/router/utils.ts                    utils
# 2                             index-react-server.ts             react-router
# 3                              lib/router/router.ts                   router
# 4                                          utils.ts                    utils
# 5                                    lib/context.ts                  context
# 6                             lib/router/history.ts                  history
# 7                   vendor/turbo-stream-v2/utils.ts                    utils
# 8                             lib/rsc/server.rsc.ts                   server
# 9                       lib/dom/ssr/routeModules.ts             routeModules
# 10                                   vite/plugin.ts                   plugin
# 11                                 config/routes.ts                   routes
# 12                                   lib/dom/dom.ts                      dom
# 13                                    flatRoutes.ts               flatRoutes
# 14                             vite/route-chunks.ts             route-chunks
# 15                                 config/config.ts                   config
# 16                   lib/server-runtime/sessions.ts                 sessions
# 17                    lib/router/instrumentation.ts          instrumentation
# 18               lib/server-runtime/single-fetch.ts             single-fetch
# 19                             lib/dom/ssr/links.ts                    links
# 20                                        routes.ts                   routes
# 21                                    dom-export.ts               dom-export
# 22                                         index.ts        react-router-node
# 23                          lib/types/route-data.ts               route-data
# 24                               lib/types/utils.ts                    utils
# 25                                        server.ts                   server
# 26                    lib/server-runtime/cookies.ts                  cookies
# 27                                        server.ts                   server
# 28                                         index.ts  react-router-cloudflare
# 29                        lib/dom/ssr/fog-of-war.ts               fog-of-war
#
# languageElement  Function  TypeAlias  Interface  Variable  Class  Enum
# 0                      20         61         50        18      3     2
# 1                      21         28         23         9      3     1
# 2                       9         15          4         6      1     0
# 3                       8         11         10         4      0     0
# 4                      24          0          0         4      0     0
# 5                       1          6          8        12      0     0
# 6                       9          6          9         0      0     1
# 7                       1          2          2        18      1     0
# 8                       3         14          0         4      0     0
# 9                       1         12          8         0      0     0
# 10                     10          4          1         2      0     0
# 11                      9          1          3         2      0     0
# 12                      8          3          2         1      0     0
# 13                      7          0          0         6      0     0
# 14                      8          2          0         2      0     0
# 15                      4          7          0         1      0     0
# 16                      2          3          4         2      0     0
# 17                      3          6          0         0      0     0
# 18                      6          1          0         1      0     0
# 19                      7          1          0         0      0     0
# 20                      6          1          1         0      0     0
# 21                      1          6          0         0      0     0
# 22                      5          0          1         1      0     0
# 23                      0          7          0         0      0     0
# 24                      0          6          0         0      0     0
# 25                      4          2          0         0      0     0
# 26                      0          2          2         2      0     0
# 27                      4          2          0         0      0     0
# 28                      3          2          1         0      0     0
# 29                      6          0          0         0      0     0

# %% [markdown]
# ### Table 2b Chart 1 - 30 largest modules and their elements stacked

# %%
if elements_per_module_grouped.empty:
    print("No data to plot")
else:
    plot.figure();
    elements_per_module_grouped.reset_index().head(30).plot(
        kind='bar', 
        title='Top 30 elements per module',
        xlabel='Module',
        ylabel='Elements',
        x='modulePath',
        stacked=True, 
        cmap=main_color_map,
        figsize=(9, 6)
    )
    plot.show()

# %% [markdown]
# ### Table 2c - 30 highest element count per module (grouped and normalized in %)

# %%
# Divide every value by the sum of the row to get horizontal normalized values.
# This makes it easier to compare the "language element" usage without taking the size of the module into account
elements_per_module_grouped_normalized = elements_per_module_grouped.div(elements_per_module_grouped.sum(axis=1), axis=0).multiply(100)
elements_per_module_grouped_normalized.reset_index().drop(columns='fullQualifiedModuleName').head(30)
# Out:
# languageElement                          modulePath               moduleName  \
# 0                                          index.ts             react-router
# 1                               lib/router/utils.ts                    utils
# 2                             index-react-server.ts             react-router
# 3                              lib/router/router.ts                   router
# 4                                          utils.ts                    utils
# 5                                    lib/context.ts                  context
# 6                             lib/router/history.ts                  history
# 7                   vendor/turbo-stream-v2/utils.ts                    utils
# 8                             lib/rsc/server.rsc.ts                   server
# 9                       lib/dom/ssr/routeModules.ts             routeModules
# 10                                   vite/plugin.ts                   plugin
# 11                                 config/routes.ts                   routes
# 12                                   lib/dom/dom.ts                      dom
# 13                                    flatRoutes.ts               flatRoutes
# 14                             vite/route-chunks.ts             route-chunks
# 15                                 config/config.ts                   config
# 16                   lib/server-runtime/sessions.ts                 sessions
# 17                    lib/router/instrumentation.ts          instrumentation
# 18               lib/server-runtime/single-fetch.ts             single-fetch
# 19                             lib/dom/ssr/links.ts                    links
# 20                                        routes.ts                   routes
# 21                                    dom-export.ts               dom-export
# 22                                         index.ts        react-router-node
# 23                          lib/types/route-data.ts               route-data
# 24                               lib/types/utils.ts                    utils
# 25                                        server.ts                   server
# 26                    lib/server-runtime/cookies.ts                  cookies
# 27                                        server.ts                   server
# 28                                         index.ts  react-router-cloudflare
# 29                        lib/dom/ssr/fog-of-war.ts               fog-of-war
#
# languageElement    Function   TypeAlias  Interface   Variable     Class  \
# 0                 12.987013   39.610390  32.467532  11.688312  1.948052
# 1                 24.705882   32.941176  27.058824  10.588235  3.529412
# 2                 25.714286   42.857143  11.428571  17.142857  2.857143
# 3                 24.242424   33.333333  30.303030  12.121212  0.000000
# 4                 85.714286    0.000000   0.000000  14.285714  0.000000
# 5                  3.703704   22.222222  29.629630  44.444444  0.000000
# 6                 36.000000   24.000000  36.000000   0.000000  0.000000
# 7                  4.166667    8.333333   8.333333  75.000000  4.166667
# 8                 14.285714   66.666667   0.000000  19.047619  0.000000
# 9                  4.761905   57.142857  38.095238   0.000000  0.000000
# 10                58.823529   23.529412   5.882353  11.764706  0.000000
# 11                60.000000    6.666667  20.000000  13.333333  0.000000
# 12                57.142857   21.428571  14.285714   7.142857  0.000000
# 13                53.846154    0.000000   0.000000  46.153846  0.000000
# 14                66.666667   16.666667   0.000000  16.666667  0.000000
# 15                33.333333   58.333333   0.000000   8.333333  0.000000
# 16                18.181818   27.272727  36.363636  18.181818  0.000000
# 17                33.333333   66.666667   0.000000   0.000000  0.000000
# 18                75.000000   12.500000   0.000000  12.500000  0.000000
# 19                87.500000   12.500000   0.000000   0.000000  0.000000
# 20                75.000000   12.500000  12.500000   0.000000  0.000000
# 21                14.285714   85.714286   0.000000   0.000000  0.000000
# 22                71.428571    0.000000  14.285714  14.285714  0.000000
# 23                 0.000000  100.000000   0.000000   0.000000  0.000000
# 24                 0.000000  100.000000   0.000000   0.000000  0.000000
# 25                66.666667   33.333333   0.000000   0.000000  0.000000
# 26                 0.000000   33.333333  33.333333  33.333333  0.000000
# 27                66.666667   33.333333   0.000000   0.000000  0.000000
# 28                50.000000   33.333333  16.666667   0.000000  0.000000
# 29               100.000000    0.000000   0.000000   0.000000  0.000000
#
# languageElement      Enum
# 0                1.298701
# 1                1.176471
# 2                0.000000
# 3                0.000000
# 4                0.000000
# 5                0.000000
# 6                4.000000
# 7                0.000000
# 8                0.000000
# 9                0.000000
# 10               0.000000
# 11               0.000000
# 12               0.000000
# 13               0.000000
# 14               0.000000
# 15               0.000000
# 16               0.000000
# 17               0.000000
# 18               0.000000
# 19               0.000000
# 20               0.000000
# 21               0.000000
# 22               0.000000
# 23               0.000000
# 24               0.000000
# 25               0.000000
# 26               0.000000
# 27               0.000000
# 28               0.000000
# 29               0.000000

# %% [markdown]
# ### Table 2c Chart 1 - Top 30 modules with the highest relative amount of type aliases in %

# %%
if elements_per_module_grouped_normalized.empty:
    print("No data to plot")
else:
    elements_per_module_sorted_by_type_alias=elements_per_module_grouped_normalized.sort_values(by='TypeAlias', ascending=False)
    
    plot.figure();
    elements_per_module_sorted_by_type_alias.reset_index().head(30).plot(
        x='moduleName',
        kind='bar', 
        stacked=True, 
        cmap=main_color_map, 
        figsize=(9, 5)
    )
    plot.xlabel('Module')
    plot.ylabel('Elements %')
    plot.title('Exported type aliases [%] per module')
    plot.show()

# %% [markdown]
# ### Table 2c Chart 2 - Top 30 module with the highest relative amount of interfaces in %

# %%
if elements_per_module_grouped_normalized.empty:
    print("No data to plot")
else:
    elements_per_module_sorted_by_interfaces=elements_per_module_grouped_normalized.sort_values(by='Interface', ascending=False)
    
    plot.figure();
    elements_per_module_sorted_by_interfaces.reset_index().head(30).plot(
        x='moduleName',
        kind='bar', 
        stacked=True, 
        cmap=main_color_map, 
        figsize=(8, 5)
    )
    plot.xlabel('Module')
    plot.ylabel('Elements %')
    plot.title('Exported interfaces [%] per module')
    plot.show()

# %% [markdown]
# ### Table 2c Chart 3 - Top 30 modules with the highest relative amount of variables in %

# %%
if elements_per_module_grouped_normalized.empty:
    print("No data to plot")
else:
    elements_per_module_sorted_by_variables=elements_per_module_grouped_normalized.sort_values(by='Variable', ascending=False)
    plot.figure();
    elements_per_module_sorted_by_variables.reset_index().head(30).plot(
        x='moduleName',
        kind='bar', 
        stacked=True, 
        cmap=main_color_map, 
        figsize=(8, 5)
    )
    plot.xlabel('Module')
    plot.ylabel('Elements %')
    plot.title('Exported variables [%] per module')
    plot.show()

# %% [markdown]
# ### Table 2c Chart 4 - Top 30 modules with the highest relative amount of functions in %

# %%
if elements_per_module_grouped_normalized.empty:
    print("No data to plot")
else:
    elements_per_module_sorted_by_functions=elements_per_module_grouped_normalized.sort_values(by='Function', ascending=False)
    plot.figure();
    elements_per_module_sorted_by_functions.reset_index().head(30).plot(
        x='moduleName',
        kind='bar', 
        stacked=True, 
        cmap=main_color_map, 
        figsize=(8, 5)
    )
    plot.xlabel('Module')
    plot.ylabel('Elements %')
    plot.title('Exported functions [%] per module')
    plot.show()
