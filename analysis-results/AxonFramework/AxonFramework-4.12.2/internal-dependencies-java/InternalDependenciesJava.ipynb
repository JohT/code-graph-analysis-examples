# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.12.2.jar        70    830
# 1           axon-server-connector-4.12.2.jar        11    147
# 2                  axon-modelling-4.12.2.jar        10    158
# 3  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 4              axon-eventsourcing-4.12.2.jar         9    133
# 5                       axon-test-4.12.2.jar         8     87
# 6              axon-configuration-4.12.2.jar         1     43
# 7                  axon-disruptor-4.12.2.jar         1     22
# 8      axon-tracing-opentelemetry-4.12.2.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     1                     4
# 2                     6                     1
# 3                     0                     7
# 4                     5                     2
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.12.2.jar        70    830
# 1                  axon-modelling-4.12.2.jar        10    158
# 2           axon-server-connector-4.12.2.jar        11    147
# 3              axon-eventsourcing-4.12.2.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 5                       axon-test-4.12.2.jar         8     87
# 6              axon-configuration-4.12.2.jar         1     43
# 7                  axon-disruptor-4.12.2.jar         1     22
# 8      axon-tracing-opentelemetry-4.12.2.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     4
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.12.2.jar        70    830
# 1                  axon-modelling-4.12.2.jar        10    158
# 2              axon-eventsourcing-4.12.2.jar         9    133
# 3              axon-configuration-4.12.2.jar         1     43
# 4                  axon-disruptor-4.12.2.jar         1     22
# 5           axon-server-connector-4.12.2.jar        11    147
# 6                       axon-test-4.12.2.jar         8     87
# 7      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 8  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     2                     4
# 4                     1                     3
# 5                     1                     4
# 6                     1                     3
# 7                     1                     1
# 8                     0                     7

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 1              axon-configuration-4.12.2.jar         1     43
# 2           axon-server-connector-4.12.2.jar        11    147
# 3                  axon-disruptor-4.12.2.jar         1     22
# 4                       axon-test-4.12.2.jar         8     87
# 5              axon-eventsourcing-4.12.2.jar         9    133
# 6                  axon-modelling-4.12.2.jar        10    158
# 7      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 8                  axon-messaging-4.12.2.jar        70    830
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     2                     4
# 2                     1                     4
# 3                     1                     3
# 4                     1                     3
# 5                     5                     2
# 6                     6                     1
# 7                     1                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0              axon-configuration-4.12.2.jar         1     43
# 1                  axon-disruptor-4.12.2.jar         1     22
# 2      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 3                       axon-test-4.12.2.jar         8     87
# 4              axon-eventsourcing-4.12.2.jar         9    133
# 5                  axon-modelling-4.12.2.jar        10    158
# 6  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 7           axon-server-connector-4.12.2.jar        11    147
# 8                  axon-messaging-4.12.2.jar        70    830
#
#    incomingDependencies  outgoingDependencies
# 0                     2                     4
# 1                     1                     3
# 2                     1                     1
# 3                     1                     3
# 4                     5                     2
# 5                     6                     1
# 6                     0                     7
# 7                     1                     4
# 8                     8                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 1                  axon-disruptor-4.12.2.jar         1     22
# 2              axon-configuration-4.12.2.jar         1     43
# 3                       axon-test-4.12.2.jar         8     87
# 4  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 5              axon-eventsourcing-4.12.2.jar         9    133
# 6           axon-server-connector-4.12.2.jar        11    147
# 7                  axon-modelling-4.12.2.jar        10    158
# 8                  axon-messaging-4.12.2.jar        70    830
#
#    incomingDependencies  outgoingDependencies
# 0                     1                     1
# 1                     1                     3
# 2                     2                     4
# 3                     1                     3
# 4                     0                     7
# 5                     5                     2
# 6                     1                     4
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
# 1                  axon-disruptor-4.12.2.jar         1     22
# 2           axon-server-connector-4.12.2.jar        11    147
# 3                       axon-test-4.12.2.jar         8     87
# 4      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 5              axon-configuration-4.12.2.jar         1     43
# 6              axon-eventsourcing-4.12.2.jar         9    133
# 7                  axon-modelling-4.12.2.jar        10    158
# 8                  axon-messaging-4.12.2.jar        70    830
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     1                     3
# 2                     1                     4
# 3                     1                     3
# 4                     1                     1
# 5                     2                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.12.2.jar        70    830
# 1                  axon-modelling-4.12.2.jar        10    158
# 2      axon-tracing-opentelemetry-4.12.2.jar         1      5
# 3              axon-eventsourcing-4.12.2.jar         9    133
# 4                  axon-disruptor-4.12.2.jar         1     22
# 5                       axon-test-4.12.2.jar         8     87
# 6              axon-configuration-4.12.2.jar         1     43
# 7           axon-server-connector-4.12.2.jar        11    147
# 8  axon-spring-boot-autoconfigure-4.12.2.jar        10     91
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     1
# 3                     5                     2
# 4                     1                     3
# 5                     1                     3
# 6                     2                     4
# 7                     1                     4
# 8                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                     artifactName  \
# 0          axon-messaging-4.12.2
# 1          axon-messaging-4.12.2
# 2          axon-messaging-4.12.2
# 3          axon-messaging-4.12.2
# 4          axon-messaging-4.12.2
# 5          axon-messaging-4.12.2
# 6          axon-messaging-4.12.2
# 7      axon-eventsourcing-4.12.2
# 8          axon-messaging-4.12.2
# 9          axon-messaging-4.12.2
# 10         axon-messaging-4.12.2
# 11  axon-server-connector-4.12.2
# 12         axon-messaging-4.12.2
# 13  axon-server-connector-4.12.2
# 14         axon-messaging-4.12.2
# 15  axon-server-connector-4.12.2
# 16  axon-server-connector-4.12.2
# 17  axon-server-connector-4.12.2
# 18         axon-messaging-4.12.2
# 19     axon-eventsourcing-4.12.2
# 20         axon-messaging-4.12.2
# 21         axon-modelling-4.12.2
# 22         axon-messaging-4.12.2
# 23         axon-messaging-4.12.2
# 24  axon-server-connector-4.12.2
# 25         axon-messaging-4.12.2
# 26         axon-modelling-4.12.2
# 27         axon-messaging-4.12.2
#
#                                                     packageName  \
# 0                               org.axonframework.eventhandling
# 1                               org.axonframework.queryhandling
# 2                               org.axonframework.queryhandling
# 3                               org.axonframework.eventhandling
# 4                               org.axonframework.eventhandling
# 5                                    org.axonframework.deadline
# 6                             org.axonframework.commandhandling
# 7                               org.axonframework.eventsourcing
# 8                   org.axonframework.commandhandling.callbacks
# 9                               org.axonframework.eventhandling
# 10                       org.axonframework.messaging.unitofwork
# 11            org.axonframework.axonserver.connector.event.axon
# 12                        org.axonframework.eventhandling.async
# 13                 org.axonframework.axonserver.connector.query
# 14                       org.axonframework.eventhandling.replay
# 15                  org.axonframework.axonserver.connector.util
# 16                       org.axonframework.axonserver.connector
# 17                 org.axonframework.axonserver.connector.query
# 18              org.axonframework.serialization.upcasting.event
# 19              org.axonframework.eventsourcing.eventstore.jdbc
# 20                              org.axonframework.eventhandling
# 21               org.axonframework.modelling.command.inspection
# 22                 org.axonframework.queryhandling.registration
# 23                                  org.axonframework.messaging
# 24               org.axonframework.axonserver.connector.command
# 25                       org.axonframework.messaging.annotation
# 26                             org.axonframework.modelling.saga
# 27  org.axonframework.commandhandling.distributed.commandfilter
#
#            dependentArtifactName  \
# 0          axon-messaging-4.12.2
# 1          axon-messaging-4.12.2
# 2          axon-messaging-4.12.2
# 3          axon-messaging-4.12.2
# 4          axon-messaging-4.12.2
# 5          axon-messaging-4.12.2
# 6          axon-messaging-4.12.2
# 7      axon-eventsourcing-4.12.2
# 8          axon-messaging-4.12.2
# 9          axon-messaging-4.12.2
# 10         axon-messaging-4.12.2
# 11  axon-server-connector-4.12.2
# 12         axon-messaging-4.12.2
# 13  axon-server-connector-4.12.2
# 14         axon-messaging-4.12.2
# 15  axon-server-connector-4.12.2
# 16  axon-server-connector-4.12.2
# 17  axon-server-connector-4.12.2
# 18         axon-messaging-4.12.2
# 19     axon-eventsourcing-4.12.2
# 20         axon-messaging-4.12.2
# 21         axon-modelling-4.12.2
# 22         axon-messaging-4.12.2
# 23         axon-messaging-4.12.2
# 24  axon-server-connector-4.12.2
# 25         axon-messaging-4.12.2
# 26         axon-modelling-4.12.2
# 27         axon-messaging-4.12.2
#
#                                           dependentPackageName  \
# 0                                    org.axonframework.tracing
# 1                    org.axonframework.messaging.responsetypes
# 2                                    org.axonframework.tracing
# 3                                  org.axonframework.messaging
# 4                       org.axonframework.messaging.annotation
# 5                                    org.axonframework.tracing
# 6                                    org.axonframework.tracing
# 7                   org.axonframework.eventsourcing.eventstore
# 8                            org.axonframework.commandhandling
# 9                              org.axonframework.serialization
# 10                                 org.axonframework.messaging
# 11                      org.axonframework.axonserver.connector
# 12                             org.axonframework.eventhandling
# 13                      org.axonframework.axonserver.connector
# 14                             org.axonframework.eventhandling
# 15                      org.axonframework.axonserver.connector
# 16           org.axonframework.axonserver.connector.event.util
# 17   org.axonframework.axonserver.connector.query.subscription
# 18                             org.axonframework.eventhandling
# 19  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 20                  org.axonframework.eventhandling.tokenstore
# 21                         org.axonframework.modelling.command
# 22                             org.axonframework.queryhandling
# 23                             org.axonframework.serialization
# 24                      org.axonframework.axonserver.connector
# 25                    org.axonframework.messaging.interceptors
# 26                  org.axonframework.modelling.saga.metamodel
# 27               org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.615385             21               5
# 12                  0.571429             11               3
# 13                  0.555556             21               6
# 14                  0.454545              8               3
# 15                  0.428571              5               2
# 16                  0.333333              2               1
# 17                  0.333333              4               2
# 18                  0.333333              6               3
# 19                  0.317073             27              14
# 20                  0.285714              9               5
# 21                  0.250000             20              12
# 22                  0.250000              5               3
# 23                  0.238095             13               8
# 24                  0.222222             11               7
# 25                  0.200000              3               2
# 26                  0.142857              4               3
# 27                  0.076923              7               6
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [AbstractEventBus->SpanScope, AbstractEventBus->Span, SimpleEventBus$Builder->SpanFactory, EventBusSpanFactory->Span, DefaultEventProcessorSpanFactory->Span, DefaultEventProcessorSpanFactory->SpanFactory, DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan, DefaultEventProcessorSpanFactor...
# 1   [QuerySubscription->ResponseType, QueryGateway->ResponseType, QueryGateway->ResponseTypes, GenericQueryMessage->ResponseType, SubscriptionQueryMessage->ResponseType, StreamingQueryMessage->ResponseType, GenericStreamingQueryMessage->PublisherResponseType, GenericStreamingQueryMessage->ResponseTy...
# 2   [QueryUpdateEmitterSpanFactory->Span, SimpleQueryUpdateEmitter$Builder->SpanFactory, SimpleQueryUpdateEmitter$Builder->NoOpSpanFactory, DefaultQueryBusSpanFactory->SpanFactory, DefaultQueryBusSpanFactory->Span, QueryBusSpanFactory->Span, SimpleQueryBus$Builder->NoOpSpanFactory, SimpleQueryBus$Bu...
# 3   [TrackingEventProcessorConfiguration->StreamableMessageSource, TimestampParameterResolverFactory$TimestampParameterResolver->Message, EventMessage->Message, GenericDomainEventMessage->MetaData, GenericDomainEventMessage->GenericMessage, GenericDomainEventMessage->Message, AbstractEventBus->Messa...
# 4   [SimpleEventHandlerInvoker$Builder->HandlerDefinition, SimpleEventHandlerInvoker$Builder->ParameterResolverFactory, TimestampParameterResolverFactory$TimestampParameterResolver->ParameterResolver, TrackingTokenParameterResolverFactory->ParameterResolver, TrackingTokenParameterResolverFactory->Pa...
# 5   [SimpleDeadlineManager->Span, SimpleDeadlineManager$DeadlineTask->Span, SimpleDeadlineManager$DeadlineTask->SpanScope, DefaultDeadlineManagerSpanFactory->Span, DefaultDeadlineManagerSpanFactory->SpanFactory, DefaultDeadlineManagerSpanFactory$Builder->SpanFactory, DeadlineManagerSpanFactory->Span...
# 6   [AsynchronousCommandBus$Builder->SpanFactory, SimpleCommandBus$Builder->NoOpSpanFactory, SimpleCommandBus$Builder->SpanFactory, DefaultCommandBusSpanFactory->SpanFactory, DefaultCommandBusSpanFactory->Span, CommandBusSpanFactory->Span, DefaultCommandBusSpanFactory$Builder->SpanFactory, SimpleCom...
# 7   [EventSourcingRepository$Builder->EventStore, FilteringEventStorageEngine->EventStorageEngine, FilteringEventStorageEngine->DomainEventStream, AbstractSnapshotter->EventStore, AbstractSnapshotter->DomainEventStream, AbstractSnapshotter$CreateSnapshotTask->DomainEventStream, AbstractSnapshotter$C...
# 8   [FailureLoggingCallback->CommandResultMessage, FailureLoggingCallback->CommandMessage, FailureLoggingCallback->CommandCallback, LoggingCallback->CommandResultMessage, LoggingCallback->CommandCallback, LoggingCallback->CommandMessage, NoOpCallback->CommandResultMessage, NoOpCallback->CommandCallb...
# 9   [EventUtils->Serializer, EventUtils->LazyDeserializingObject, EventUtils->SerializedMessage, AbstractDomainEventEntry->Serializer, AbstractSequencedDomainEventEntry->Serializer, AbstractEventEntry->SimpleSerializedType, AbstractEventEntry->SerializedObject, AbstractEventEntry->Serializer, Abstra...
# 10                             [MessageProcessingContext->Message, BatchingUnitOfWork->ResultMessage, BatchingUnitOfWork->Message, BatchingUnitOfWork->GenericResultMessage, ExecutionResult->ResultMessage, CurrentUnitOfWork->MetaData, UnitOfWork->MetaData, UnitOfWork->ResultMessage, UnitOfWork->Message]
# 11  [AxonServerEventStore$Builder->AxonServerConfiguration, AxonServerEventStore$Builder->AxonServerConnectionManager, AxonServerEventScheduler$Builder->AxonServerConnectionManager, AxonServerEventStoreFactory$Builder->AxonServerConnectionManager, AxonServerEventStoreFactory$Builder->AxonServerConfi...
# 12  [PropertySequencingPolicy->EventMessage, SequentialPerAggregatePolicy->DomainEventMessage, SequentialPerAggregatePolicy->EventMessage, FullConcurrencyPolicy->EventMessage, PropertySequencingPolicy$Builder->EventMessage, EventProcessorTask$ProcessingTask->EventMessage, PropertySequencingPolicy$Bu...
# 13  [QueryProcessingTask->ErrorCode, GrpcBackedResponseMessage->ErrorCode, AxonServerQueryDispatchException->ErrorCode, AxonServerQueryBus$ResponseProcessingTask->ErrorCode, AxonServerQueryBus$LocalSegmentAdapter->PriorityRunnable, AxonServerQueryBus$LocalSegmentAdapter->AxonServerConfiguration, Axo...
# 14  [ReplayAwareMessageHandlerWrapper$ReplayBlockingMessageHandlingMember->ReplayToken, ReplayAwareMessageHandlerWrapper->AllowReplay, ReplayParameterResolverFactory$ReplayParameterResolver->ReplayStatus, ReplayParameterResolverFactory$ReplayParameterResolver->ReplayToken, ReplayParameterResolverFac...
# 15                             [PriorityExecutorService->PriorityRunnable, PriorityExecutorService->PriorityCallable, ExecutorServiceBuilder->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration$FlowControlConfiguration]
# 16                                                                                                                                                                                                                         [AxonServerConfiguration->EventCipher, AxonServerConfiguration$Builder->EventCipher]
# 17                                                                 [AxonServerQueryBus$LocalSegmentAdapter->SubscriptionMessageSerializer, AxonServerQueryBus->AxonServerSubscriptionQueryResult, AxonServerQueryBus->SubscriptionMessageSerializer, AxonServerQueryBus$Builder->SubscriptionMessageSerializer]
# 18                                    [InitialEventRepresentation->TrackingToken, InitialEventRepresentation->EventData, InitialEventRepresentation->TrackedEventData, InitialEventRepresentation->DomainEventData, UpcastedEventRepresentation->TrackingToken, IntermediateEventRepresentation->TrackingToken]
# 19  [JdbcEventStorageEngine$Builder->LastSequenceNumberForStatementBuilder, JdbcEventStorageEngine$Builder->CreateHeadTokenStatementBuilder, JdbcEventStorageEngine$Builder->ReadSnapshotDataStatementBuilder, JdbcEventStorageEngine$Builder->CreateTokenAtStatementBuilder, JdbcEventStorageEngine$Builder...
# 20  [TrackingEventProcessor$Instruction->UnableToClaimTokenException, TrackingEventProcessor$MergeSegmentInstruction->TokenStore, TrackingEventProcessor->TokenStore, TrackingEventProcessor->UnableToClaimTokenException, TrackingEventProcessor$WorkerLauncher->UnableToClaimTokenException, TrackingEvent...
# 21  [MethodCommandHandlerInterceptorDefinition->CommandHandlerInterceptor, MethodCreationPolicyDefinition$MethodCreationPolicyHandlingMember->AggregateCreationPolicy, AbstractChildEntityDefinition->AggregateMember, AbstractChildEntityDefinition->ForwardingMode, MethodCreationPolicyDefinition->Creati...
# 22                      [FailingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolver->QuerySubscription, LoggingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolution->QuerySubscription, DuplicateQueryHandlerSubscriptionException->QuerySubscription]
# 23                 [GenericResultMessage->Serializer, GenericResultMessage->SerializedObject, Message->SerializedObject, Message->Serializer, ResultMessage->SerializedObject, ResultMessage->Serializer, GenericMessage->Serializer, GenericMessage->SerializedObject, GenericMessage->SerializedObjectHolder]
# 24  [CommandSerializer->AxonServerConfiguration, CommandSerializer->ErrorCode, AxonServerCommandBus$Builder->AxonServerConnectionManager, AxonServerCommandBus$Builder->AxonServerConfiguration, AxonServerCommandBus$Builder->TargetContextResolver, AxonServerCommandBus->ErrorCode, AxonServerCommandBus-...
# 25                                                                                                                                          [MessageHandlerInterceptorDefinition->MessageHandlerInterceptor, MessageHandlerInterceptorDefinition->ResultHandler, ResultParameterResolverFactory->ResultHandler]
# 26                                                                                                                                           [AnnotatedSagaManager->SagaModel, AnnotatedSagaManager$Builder->SagaModel, AnnotatedSagaManager$Builder->AnnotationSagaMetaModelFactory, AnnotatedSaga->SagaModel]
# 27        [CommandNameFilter->CommandMessageFilter, AcceptAll->CommandMessageFilter, DenyCommandNameFilter->CommandMessageFilter, NegateCommandMessageFilter->CommandMessageFilter, OrCommandMessageFilter->CommandMessageFilter, DenyAll->CommandMessageFilter, AndCommandMessageFilter->CommandMessageFilter]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                            [NestingSpanFactory->EventMessage]
# 1                                                                                                                                                                                                                                                             [ConvertingResponseMessage->QueryResponseMessage]
# 2                                                                                                                                                                                                                                                                                     [SpanUtils->QueryMessage]
# 3                                                                                                                                                                                                                  [StreamableMessageSource->TrackingToken, Headers->EventMessage, Headers->DomainEventMessage]
# 4                                                                                                                                    [AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->DomainEventMessage, SourceIdParameterResolverFactory$SourceIdParameterResolver->DomainEventMessage]
# 5                                                                                                                                                                                                                                                                                  [SpanUtils->DeadlineMessage]
# 6                                                                                                                                                                                                                                                                                   [SpanUtils->CommandMessage]
# 7                                                                                                                                                                                                                           [AbstractEventStorageEngine->EventStreamUtils, DomainEventStream->EventStreamUtils]
# 8                                                                                                                                                                                                                           [SimpleCommandBus$Builder->LoggingCallback, SimpleCommandBus$Builder->NoOpCallback]
# 9                                                                                                                                                 [GapAwareTrackingTokenConverter->GapAwareTrackingToken, AbstractXStreamSerializer->GenericEventMessage, AbstractXStreamSerializer->GenericDomainEventMessage]
# 10                                                                                                                                                                                              [MessageHandlerInterceptor->UnitOfWork, DefaultInterceptorChain->UnitOfWork, GenericMessage->CurrentUnitOfWork]
# 11  [ServerConnectorConfigurerModule->AxonServerEventStoreFactory, ServerConnectorConfigurerModule->AxonServerEventStore, ServerConnectorConfigurerModule->EventProcessorInfoConfiguration, ServerConnectorConfigurerModule->AxonServerEventStore$Builder, ServerConnectorConfigurerModule->AxonServerEventS...
# 12                                                                                                                                          [SimpleEventHandlerInvoker$Builder->SequentialPerAggregatePolicy, SimpleEventHandlerInvoker$Builder->SequencingPolicy, SimpleEventHandlerInvoker->SequencingPolicy]
# 13  [ServerConnectorConfigurerModule->AxonServerQueryBus, ServerConnectorConfigurerModule->QueryPriorityCalculator, ServerConnectorConfigurerModule->AxonServerQueryBus$Builder, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->AxonServerRemoteQueryHandlingException, ErrorCode...
# 14                                                                                                                                                                                [ResetHandler->ResetContext, AnnotationEventHandlerAdapter->GenericResetContext, AnnotationEventHandlerAdapter->ResetContext]
# 15                                                                                                                                                                                                            [ErrorCode->ExceptionSerializer, AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor]
# 16                                                                                                                                                                                                                                                                             [GrpcExceptionParser->ErrorCode]
# 17                                                                                                                                                                                       [SubscriptionMessageSerializer->GrpcBackedResponseMessage, GrpcBackedSubscriptionQueryMessage->GrpcBackedQueryMessage]
# 18                                                                                                                                                                                             [EventUtils->EventUpcaster, EventUtils->InitialEventRepresentation, EventUtils->IntermediateEventRepresentation]
# 19  [ReadEventDataWithGapsStatementBuilder->EventSchema, LastSequenceNumberForStatementBuilder->EventSchema, AppendEventsStatementBuilder->EventSchema, ReadSnapshotDataStatementBuilder->EventSchema, ReadEventDataWithoutGapsStatementBuilder->EventSchema, CreateTokenAtStatementBuilder->EventSchema, Jd...
# 20                                                                                                                                                            [TokenStore->TrackingToken, TokenStore->Segment, GenericTokenEntry->TrackingToken, ConfigToken->TrackingToken, AbstractTokenEntry->TrackingToken]
# 21  [AbstractRepository$Builder->AggregateModel, AbstractRepository$Builder->AnnotatedAggregateMetaModelFactory, GenericJpaRepository$Builder->AggregateModel, AbstractRepository->AggregateModel, GenericJpaRepository->AnnotatedAggregate, LockingRepository$Builder->AggregateModel, ForwardingMode->Enti...
# 22                                                                                                                                              [SimpleQueryBus$Builder->DuplicateQueryHandlerResolution, SimpleQueryBus$Builder->DuplicateQueryHandlerResolver, SimpleQueryBus->DuplicateQueryHandlerResolver]
# 23                  [SerializedMetaData->MetaData, SerializedObjectHolder->Message, AbstractXStreamSerializer->MetaData, AbstractXStreamSerializer$MetaDataConverter->MetaData, SerializedMessage->MetaData, SerializedMessage->AbstractMessage, SerializedMessage->Message, SerializedMessage->GenericMessage]
# 24  [ServerConnectorConfigurerModule->CommandPriorityCalculator, ServerConnectorConfigurerModule->AxonServerCommandBus$Builder, ServerConnectorConfigurerModule->AxonServerCommandBus, ServerConnectorConfigurerModule->CommandLoadFactorProvider, ErrorCode->AxonServerRemoteCommandHandlingException, Erro...
# 25                                                                                                                                                                                                                             [ResultHandler->HasHandlerAttributes, MessageHandlerInterceptor->MessageHandler]
# 26                                                                                                                       [SagaModel->AssociationValue, AnnotationSagaMetaModelFactory$InspectedSagaModel->AssociationValue, AnnotationSagaMetaModelFactory$InspectedSagaModel->SagaMethodMessageHandlingMember]
# 27                                      [CommandMessageFilter->OrCommandMessageFilter, CommandMessageFilter->AndCommandMessageFilter, CommandMessageFilter->NegateCommandMessageFilter, DistributedCommandBus->DenyCommandNameFilter, DistributedCommandBus->CommandNameFilter, DistributedCommandBus->DenyAll]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#              artifactName                      packageName  \
# 0   axon-messaging-4.12.2  org.axonframework.eventhandling
# 1   axon-messaging-4.12.2  org.axonframework.eventhandling
# 2   axon-messaging-4.12.2  org.axonframework.eventhandling
# 3   axon-messaging-4.12.2  org.axonframework.eventhandling
# 4   axon-messaging-4.12.2  org.axonframework.eventhandling
# 5   axon-messaging-4.12.2  org.axonframework.eventhandling
# 6   axon-messaging-4.12.2  org.axonframework.eventhandling
# 7   axon-messaging-4.12.2  org.axonframework.eventhandling
# 8   axon-messaging-4.12.2  org.axonframework.eventhandling
# 9   axon-messaging-4.12.2  org.axonframework.eventhandling
# 10  axon-messaging-4.12.2  org.axonframework.eventhandling
# 11  axon-messaging-4.12.2  org.axonframework.eventhandling
# 12  axon-messaging-4.12.2  org.axonframework.eventhandling
# 13  axon-messaging-4.12.2  org.axonframework.eventhandling
# 14  axon-messaging-4.12.2  org.axonframework.eventhandling
# 15  axon-messaging-4.12.2  org.axonframework.eventhandling
# 16  axon-messaging-4.12.2  org.axonframework.eventhandling
# 17  axon-messaging-4.12.2  org.axonframework.eventhandling
# 18  axon-messaging-4.12.2  org.axonframework.eventhandling
# 19  axon-messaging-4.12.2  org.axonframework.eventhandling
# 20  axon-messaging-4.12.2  org.axonframework.queryhandling
# 21  axon-messaging-4.12.2  org.axonframework.queryhandling
# 22  axon-messaging-4.12.2  org.axonframework.queryhandling
# 23  axon-messaging-4.12.2  org.axonframework.queryhandling
# 24  axon-messaging-4.12.2  org.axonframework.queryhandling
# 25  axon-messaging-4.12.2  org.axonframework.queryhandling
# 26  axon-messaging-4.12.2  org.axonframework.queryhandling
# 27  axon-messaging-4.12.2  org.axonframework.queryhandling
# 28  axon-messaging-4.12.2  org.axonframework.queryhandling
# 29  axon-messaging-4.12.2  org.axonframework.queryhandling
# 30  axon-messaging-4.12.2  org.axonframework.queryhandling
# 31  axon-messaging-4.12.2  org.axonframework.queryhandling
# 32  axon-messaging-4.12.2  org.axonframework.queryhandling
# 33  axon-messaging-4.12.2  org.axonframework.queryhandling
# 34  axon-messaging-4.12.2  org.axonframework.queryhandling
# 35  axon-messaging-4.12.2  org.axonframework.queryhandling
# 36  axon-messaging-4.12.2  org.axonframework.queryhandling
# 37  axon-messaging-4.12.2  org.axonframework.queryhandling
# 38  axon-messaging-4.12.2  org.axonframework.queryhandling
# 39  axon-messaging-4.12.2  org.axonframework.queryhandling
#
#     dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.12.2                  org.axonframework.tracing
# 1   axon-messaging-4.12.2                  org.axonframework.tracing
# 2   axon-messaging-4.12.2                  org.axonframework.tracing
# 3   axon-messaging-4.12.2                  org.axonframework.tracing
# 4   axon-messaging-4.12.2                  org.axonframework.tracing
# 5   axon-messaging-4.12.2                  org.axonframework.tracing
# 6   axon-messaging-4.12.2                  org.axonframework.tracing
# 7   axon-messaging-4.12.2                  org.axonframework.tracing
# 8   axon-messaging-4.12.2                  org.axonframework.tracing
# 9   axon-messaging-4.12.2                  org.axonframework.tracing
# 10  axon-messaging-4.12.2                  org.axonframework.tracing
# 11  axon-messaging-4.12.2                  org.axonframework.tracing
# 12  axon-messaging-4.12.2                  org.axonframework.tracing
# 13  axon-messaging-4.12.2                  org.axonframework.tracing
# 14  axon-messaging-4.12.2                  org.axonframework.tracing
# 15  axon-messaging-4.12.2                  org.axonframework.tracing
# 16  axon-messaging-4.12.2                  org.axonframework.tracing
# 17  axon-messaging-4.12.2                  org.axonframework.tracing
# 18  axon-messaging-4.12.2                  org.axonframework.tracing
# 19  axon-messaging-4.12.2                  org.axonframework.tracing
# 20  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.12.2  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.12.2                  org.axonframework.tracing
# 38  axon-messaging-4.12.2                  org.axonframework.tracing
# 39  axon-messaging-4.12.2                  org.axonframework.tracing
#
#                                                     dependency  \
# 0                                    EventBusSpanFactory->Span
# 1                              EventProcessorSpanFactory->Span
# 2                             DefaultEventBusSpanFactory->Span
# 3   DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan
# 4                             EventMessage<-NestingSpanFactory
# 5                  AbstractEventProcessor$Builder->SpanFactory
# 6                DefaultEventProcessorSpanFactory->SpanFactory
# 7              DefaultEventBusSpanFactory$Builder->SpanFactory
# 8               SubscribingEventProcessor$Builder->SpanFactory
# 9        DefaultEventProcessorSpanFactory$Builder->SpanFactory
# 10                                 AbstractEventBus->SpanScope
# 11                     DefaultEventBusSpanFactory->SpanFactory
# 12                         SimpleEventBus$Builder->SpanFactory
# 13                 TrackingEventProcessor$Builder->SpanFactory
# 14                                      AbstractEventBus->Span
# 15                      DefaultEventProcessorSpanFactory->Span
# 16             AbstractEventProcessor$Builder->NoOpSpanFactory
# 17                                AbstractEventProcessor->Span
# 18                   AbstractEventBus$Builder->NoOpSpanFactory
# 19                       AbstractEventBus$Builder->SpanFactory
# 20               GenericSubscriptionQueryMessage->ResponseType
# 21                             QuerySubscription->ResponseType
# 22             SimpleQueryUpdateEmitter->PublisherResponseType
# 23                                SimpleQueryBus->ResponseType
# 24                                  QueryMessage->ResponseType
# 25     SimpleQueryUpdateEmitter->MultipleInstancesResponseType
# 26         GenericStreamingQueryMessage->PublisherResponseType
# 27                      SimpleQueryUpdateEmitter->ResponseType
# 28             QueryResponseMessage<-ConvertingResponseMessage
# 29                           DefaultQueryGateway->ResponseType
# 30                                  QueryGateway->ResponseType
# 31                  GenericStreamingQueryMessage->ResponseType
# 32              SimpleQueryUpdateEmitter->OptionalResponseType
# 33                                 QueryGateway->ResponseTypes
# 34                           GenericQueryMessage->ResponseType
# 35                      SubscriptionQueryMessage->ResponseType
# 36                         StreamingQueryMessage->ResponseType
# 37             DefaultQueryBusSpanFactory$Builder->SpanFactory
# 38                  DefaultQueryUpdateEmitterSpanFactory->Span
# 39   DefaultQueryUpdateEmitterSpanFactory$Builder->SpanFactory
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                     artifactName  \
# 0          axon-messaging-4.12.2
# 1          axon-messaging-4.12.2
# 2          axon-messaging-4.12.2
# 3          axon-messaging-4.12.2
# 4          axon-messaging-4.12.2
# 5          axon-messaging-4.12.2
# 6          axon-messaging-4.12.2
# 7          axon-messaging-4.12.2
# 8          axon-messaging-4.12.2
# 9          axon-messaging-4.12.2
# 10     axon-eventsourcing-4.12.2
# 11     axon-eventsourcing-4.12.2
# 12         axon-messaging-4.12.2
# 13         axon-messaging-4.12.2
# 14         axon-messaging-4.12.2
# 15         axon-messaging-4.12.2
# 16         axon-messaging-4.12.2
# 17         axon-messaging-4.12.2
# 18         axon-messaging-4.12.2
# 19         axon-messaging-4.12.2
# 20  axon-server-connector-4.12.2
# 21  axon-server-connector-4.12.2
# 22  axon-server-connector-4.12.2
# 23  axon-server-connector-4.12.2
# 24  axon-server-connector-4.12.2
# 25         axon-messaging-4.12.2
# 26         axon-messaging-4.12.2
# 27         axon-messaging-4.12.2
# 28  axon-server-connector-4.12.2
# 29  axon-server-connector-4.12.2
# 30  axon-server-connector-4.12.2
# 31  axon-server-connector-4.12.2
# 32  axon-server-connector-4.12.2
# 33  axon-server-connector-4.12.2
# 34         axon-messaging-4.12.2
# 35         axon-messaging-4.12.2
# 36         axon-messaging-4.12.2
# 37  axon-server-connector-4.12.2
# 38  axon-server-connector-4.12.2
# 39  axon-server-connector-4.12.2
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.eventhandling
# 6                     org.axonframework.eventhandling
# 7                     org.axonframework.eventhandling
# 8                          org.axonframework.deadline
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventsourcing
# 11                    org.axonframework.eventsourcing
# 12        org.axonframework.commandhandling.callbacks
# 13        org.axonframework.commandhandling.callbacks
# 14                    org.axonframework.eventhandling
# 15                    org.axonframework.eventhandling
# 16                    org.axonframework.eventhandling
# 17             org.axonframework.messaging.unitofwork
# 18             org.axonframework.messaging.unitofwork
# 19             org.axonframework.messaging.unitofwork
# 20  org.axonframework.axonserver.connector.event.axon
# 21  org.axonframework.axonserver.connector.event.axon
# 22  org.axonframework.axonserver.connector.event.axon
# 23  org.axonframework.axonserver.connector.event.axon
# 24  org.axonframework.axonserver.connector.event.axon
# 25              org.axonframework.eventhandling.async
# 26              org.axonframework.eventhandling.async
# 27              org.axonframework.eventhandling.async
# 28       org.axonframework.axonserver.connector.query
# 29       org.axonframework.axonserver.connector.query
# 30       org.axonframework.axonserver.connector.query
# 31       org.axonframework.axonserver.connector.query
# 32       org.axonframework.axonserver.connector.query
# 33       org.axonframework.axonserver.connector.query
# 34             org.axonframework.eventhandling.replay
# 35             org.axonframework.eventhandling.replay
# 36             org.axonframework.eventhandling.replay
# 37        org.axonframework.axonserver.connector.util
# 38        org.axonframework.axonserver.connector.util
# 39             org.axonframework.axonserver.connector
#
#            dependentArtifactName  \
# 0          axon-messaging-4.12.2
# 1          axon-messaging-4.12.2
# 2          axon-messaging-4.12.2
# 3          axon-messaging-4.12.2
# 4          axon-messaging-4.12.2
# 5          axon-messaging-4.12.2
# 6          axon-messaging-4.12.2
# 7          axon-messaging-4.12.2
# 8          axon-messaging-4.12.2
# 9          axon-messaging-4.12.2
# 10     axon-eventsourcing-4.12.2
# 11     axon-eventsourcing-4.12.2
# 12         axon-messaging-4.12.2
# 13         axon-messaging-4.12.2
# 14         axon-messaging-4.12.2
# 15         axon-messaging-4.12.2
# 16         axon-messaging-4.12.2
# 17         axon-messaging-4.12.2
# 18         axon-messaging-4.12.2
# 19         axon-messaging-4.12.2
# 20  axon-server-connector-4.12.2
# 21  axon-server-connector-4.12.2
# 22  axon-server-connector-4.12.2
# 23  axon-server-connector-4.12.2
# 24  axon-server-connector-4.12.2
# 25         axon-messaging-4.12.2
# 26         axon-messaging-4.12.2
# 27         axon-messaging-4.12.2
# 28  axon-server-connector-4.12.2
# 29  axon-server-connector-4.12.2
# 30  axon-server-connector-4.12.2
# 31  axon-server-connector-4.12.2
# 32  axon-server-connector-4.12.2
# 33  axon-server-connector-4.12.2
# 34         axon-messaging-4.12.2
# 35         axon-messaging-4.12.2
# 36         axon-messaging-4.12.2
# 37  axon-server-connector-4.12.2
# 38  axon-server-connector-4.12.2
# 39  axon-server-connector-4.12.2
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1           org.axonframework.messaging.responsetypes
# 2                           org.axonframework.tracing
# 3                         org.axonframework.messaging
# 4                         org.axonframework.messaging
# 5                         org.axonframework.messaging
# 6              org.axonframework.messaging.annotation
# 7              org.axonframework.messaging.annotation
# 8                           org.axonframework.tracing
# 9                           org.axonframework.tracing
# 10         org.axonframework.eventsourcing.eventstore
# 11         org.axonframework.eventsourcing.eventstore
# 12                  org.axonframework.commandhandling
# 13                  org.axonframework.commandhandling
# 14                    org.axonframework.serialization
# 15                    org.axonframework.serialization
# 16                    org.axonframework.serialization
# 17                        org.axonframework.messaging
# 18                        org.axonframework.messaging
# 19                        org.axonframework.messaging
# 20             org.axonframework.axonserver.connector
# 21             org.axonframework.axonserver.connector
# 22             org.axonframework.axonserver.connector
# 23             org.axonframework.axonserver.connector
# 24             org.axonframework.axonserver.connector
# 25                    org.axonframework.eventhandling
# 26                    org.axonframework.eventhandling
# 27                    org.axonframework.eventhandling
# 28             org.axonframework.axonserver.connector
# 29             org.axonframework.axonserver.connector
# 30             org.axonframework.axonserver.connector
# 31             org.axonframework.axonserver.connector
# 32             org.axonframework.axonserver.connector
# 33             org.axonframework.axonserver.connector
# 34                    org.axonframework.eventhandling
# 35                    org.axonframework.eventhandling
# 36                    org.axonframework.eventhandling
# 37             org.axonframework.axonserver.connector
# 38             org.axonframework.axonserver.connector
# 39  org.axonframework.axonserver.connector.event.util
#
#                                                                                   dependency  \
# 0                                                           EventMessage<-NestingSpanFactory
# 1                                            QueryResponseMessage<-ConvertingResponseMessage
# 2                                                                    QueryMessage<-SpanUtils
# 3                                                                DomainEventMessage<-Headers
# 4                                                     TrackingToken<-StreamableMessageSource
# 5                                                                      EventMessage<-Headers
# 6   DomainEventMessage<-AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver
# 7             DomainEventMessage<-SourceIdParameterResolverFactory$SourceIdParameterResolver
# 8                                                                 DeadlineMessage<-SpanUtils
# 9                                                                  CommandMessage<-SpanUtils
# 10                                                       EventStreamUtils<-DomainEventStream
# 11                                              EventStreamUtils<-AbstractEventStorageEngine
# 12                                                 LoggingCallback<-SimpleCommandBus$Builder
# 13                                                    NoOpCallback<-SimpleCommandBus$Builder
# 14                                     GapAwareTrackingToken<-GapAwareTrackingTokenConverter
# 15                                            GenericEventMessage<-AbstractXStreamSerializer
# 16                                      GenericDomainEventMessage<-AbstractXStreamSerializer
# 17                                                       UnitOfWork<-DefaultInterceptorChain
# 18                                                     UnitOfWork<-MessageHandlerInterceptor
# 19                                                         CurrentUnitOfWork<-GenericMessage
# 20                      AxonServerEventStoreFactory$Builder<-ServerConnectorConfigurerModule
# 21                             AxonServerEventStore$Builder<-ServerConnectorConfigurerModule
# 22                          EventProcessorInfoConfiguration<-ServerConnectorConfigurerModule
# 23                                     AxonServerEventStore<-ServerConnectorConfigurerModule
# 24                              AxonServerEventStoreFactory<-ServerConnectorConfigurerModule
# 25                                               SequencingPolicy<-SimpleEventHandlerInvoker
# 26                           SequentialPerAggregatePolicy<-SimpleEventHandlerInvoker$Builder
# 27                                       SequencingPolicy<-SimpleEventHandlerInvoker$Builder
# 28                                  QueryPriorityCalculator<-ServerConnectorConfigurerModule
# 29                                       AxonServerQueryBus<-ServerConnectorConfigurerModule
# 30                                               AxonServerQueryDispatchException<-ErrorCode
# 31                                         AxonServerRemoteQueryHandlingException<-ErrorCode
# 32                             AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 33                               AxonServerQueryBus$Builder<-ServerConnectorConfigurerModule
# 34                                        GenericResetContext<-AnnotationEventHandlerAdapter
# 35                                                                ResetContext<-ResetHandler
# 36                                               ResetContext<-AnnotationEventHandlerAdapter
# 37                           GrpcMessageSizeInterceptor<-AxonServerConnectionManager$Builder
# 38                                                            ExceptionSerializer<-ErrorCode
# 39                                                            ErrorCode<-GrpcExceptionParser
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.647059             14               3
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.615385             21               5
# 21                  0.615385             21               5
# 22                  0.615385             21               5
# 23                  0.615385             21               5
# 24                  0.615385             21               5
# 25                  0.571429             11               3
# 26                  0.571429             11               3
# 27                  0.571429             11               3
# 28                  0.555556             21               6
# 29                  0.555556             21               6
# 30                  0.555556             21               6
# 31                  0.555556             21               6
# 32                  0.555556             21               6
# 33                  0.555556             21               6
# 34                  0.454545              8               3
# 35                  0.454545              8               3
# 36                  0.454545              8               3
# 37                  0.428571              5               2
# 38                  0.428571              5               2
# 39                  0.333333              2               1

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                    fullDependentTypeName  \
# 0                       org.axonframework.commandhandling.CommandMessage
# 1                           org.axonframework.eventhandling.EventMessage
# 2                           org.axonframework.eventhandling.EventMessage
# 3                     org.axonframework.eventhandling.DomainEventMessage
# 4                    org.axonframework.eventhandling.TrackedEventMessage
# 5          org.axonframework.commandhandling.GenericCommandResultMessage
# 6                     org.axonframework.eventhandling.DomainEventMessage
# 7                              org.axonframework.messaging.ResultMessage
# 8                            org.axonframework.eventhandling.ReplayToken
# 9                      org.axonframework.deadline.GenericDeadlineMessage
# 10                    org.axonframework.eventhandling.DomainEventMessage
# 11                   org.axonframework.eventhandling.TrackedEventMessage
# 12                   org.axonframework.eventhandling.GenericEventMessage
# 13                            org.axonframework.deadline.DeadlineMessage
# 14                    org.axonframework.eventhandling.DomainEventMessage
# 15          org.axonframework.deadline.DefaultDeadlineManagerSpanFactory
# 16             org.axonframework.common.transaction.NoTransactionManager
# 17              org.axonframework.queryhandling.SimpleQueryUpdateEmitter
# 18         org.axonframework.commandhandling.GenericCommandResultMessage
# 19   org.axonframework.messaging.annotation.WrappedMessageHandlingMember
# 20                           org.axonframework.eventhandling.ReplayToken
# 21         org.axonframework.modelling.command.inspection.AggregateModel
# 22              org.axonframework.queryhandling.SubscriptionQueryMessage
# 23                    org.axonframework.eventhandling.DomainEventMessage
# 24                        org.axonframework.queryhandling.SimpleQueryBus
# 25                    org.axonframework.eventhandling.DomainEventMessage
# 26                 org.axonframework.eventhandling.GapAwareTrackingToken
# 27                   org.axonframework.eventhandling.GenericEventMessage
# 28            org.axonframework.queryhandling.DefaultQueryBusSpanFactory
# 29       org.axonframework.commandhandling.gateway.DefaultCommandGateway
# 30                                org.axonframework.config.Configuration
# 31                                org.axonframework.config.Configuration
# 32                          org.axonframework.eventhandling.EventMessage
# 33                          org.axonframework.messaging.MessageDecorator
# 34                          org.axonframework.queryhandling.QueryMessage
# 35        org.axonframework.commandhandling.DefaultCommandBusSpanFactory
# 36                      org.axonframework.eventhandling.TrackedEventData
# 37                org.axonframework.eventhandling.tokenstore.ConfigToken
# 38            org.axonframework.eventhandling.DefaultEventBusSpanFactory
# 39  org.axonframework.queryhandling.DefaultQueryUpdateEmitterSpanFactory
#
#     declaredMethods  \
# 0                 9
# 1                 9
# 2                 9
# 3                10
# 4                10
# 5                14
# 6                10
# 7                 9
# 8                13
# 9                11
# 10               10
# 11               12
# 12               11
# 13               10
# 14               10
# 15                8
# 16                4
# 17               17
# 18               15
# 19               14
# 20               13
# 21               13
# 22               12
# 23               11
# 24               11
# 25               10
# 26               10
# 27               10
# 28               10
# 29                9
# 30                9
# 31                9
# 32                9
# 33                9
# 34                9
# 35                5
# 36                5
# 37                5
# 38                4
# 39                4
#
#                                                    calledMethodNames  \
# 0                                                   [getCommandName]
# 1                                      [getTimestamp, getIdentifier]
# 2                                                    [getIdentifier]
# 3                                                [getSequenceNumber]
# 4                                                    [trackingToken]
# 5                                           [asCommandResultMessage]
# 6               [getSequenceNumber, getAggregateIdentifier, getType]
# 7                                   [exceptionResult, isExceptional]
# 8                                                [createReplayToken]
# 9                                                [asDeadlineMessage]
# 10                                          [getAggregateIdentifier]
# 11                                                   [trackingToken]
# 12                                                  [asEventMessage]
# 13                                                 [getDeadlineName]
# 14                                                         [getType]
# 15                                                         [builder]
# 16                                                        [instance]
# 17                                                         [builder]
# 18                                          [asCommandResultMessage]
# 19                                                          [handle]
# 20                                                        [isReplay]
# 21                                                            [type]
# 22                                           [getUpdateResponseType]
# 23              [getSequenceNumber, getAggregateIdentifier, getType]
# 24                                                         [builder]
# 25                       [getSequenceNumber, getAggregateIdentifier]
# 26  [advanceTo, newInstance, getIndex, withGapsTruncatedAt, getGaps]
# 27                                                  [asEventMessage]
# 28                                                         [builder]
# 29                                                         [builder]
# 30                                                    [getComponent]
# 31                                   [upcasterChain, snapshotFilter]
# 32                                                    [getTimestamp]
# 33                                                      [describeTo]
# 34                                   [getResponseType, getQueryName]
# 35                                                         [builder]
# 36                                                   [trackingToken]
# 37                                                             [get]
# 38                                                         [builder]
# 39                                                         [builder]
#
#     calledMethods  callerTypes
# 0               1           20
# 1               2           10
# 2               1           10
# 3               1            9
# 4               1            8
# 5               1            6
# 6               3            6
# 7               2            6
# 8               1            5
# 9               1            5
# 10              1            5
# 11              1            4
# 12              1            4
# 13              1            4
# 14              1            4
# 15              1            4
# 16              1            4
# 17              1            3
# 18              1            3
# 19              1            3
# 20              1            3
# 21              1            3
# 22              1            3
# 23              3            3
# 24              1            3
# 25              2            3
# 26              5            3
# 27              1            3
# 28              1            3
# 29              1            3
# 30              1            3
# 31              2            3
# 32              1            3
# 33              1            3
# 34              2            3
# 35              1            3
# 36              1            3
# 37              1            3
# 38              1            3
# 39              1            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                      fullQualifiedDependentTypeName  \
# 0                             org.axonframework.common.BuilderUtils
# 1               org.axonframework.common.AxonConfigurationException
# 2                               org.axonframework.messaging.Message
# 3                              org.axonframework.messaging.MetaData
# 4                        org.axonframework.serialization.Serializer
# 5                      org.axonframework.eventhandling.EventMessage
# 6                 org.axonframework.messaging.unitofwork.UnitOfWork
# 7           org.axonframework.common.transaction.TransactionManager
# 8                                   org.axonframework.common.Assert
# 9                  org.axonframework.serialization.SerializedObject
# 10                   org.axonframework.serialization.SerializedType
# 11         org.axonframework.messaging.unitofwork.CurrentUnitOfWork
# 12                            org.axonframework.common.Registration
# 13                            org.axonframework.tracing.SpanFactory
# 14                            org.axonframework.lifecycle.Lifecycle
# 15          org.axonframework.lifecycle.Lifecycle$LifecycleRegistry
# 16            org.axonframework.messaging.MessageHandlerInterceptor
# 17                             org.axonframework.common.ObjectUtils
# 18                    org.axonframework.eventhandling.TrackingToken
# 19               org.axonframework.eventhandling.DomainEventMessage
# 20           org.axonframework.messaging.MessageDispatchInterceptor
# 21  org.axonframework.messaging.annotation.ParameterResolverFactory
# 22           org.axonframework.serialization.SimpleSerializedObject
# 23               org.axonframework.common.AxonNonTransientException
# 24              org.axonframework.eventhandling.GenericEventMessage
# 25                 org.axonframework.commandhandling.CommandMessage
# 26                        org.axonframework.tracing.NoOpSpanFactory
# 27                         org.axonframework.eventhandling.EventBus
# 28         org.axonframework.messaging.annotation.HandlerDefinition
# 29        org.axonframework.common.transaction.NoTransactionManager
# 30                        org.axonframework.messaging.ResultMessage
# 31                                   org.axonframework.tracing.Span
# 32         org.axonframework.messaging.unitofwork.DefaultUnitOfWork
# 33                         org.axonframework.common.ReflectionUtils
# 34                     org.axonframework.messaging.InterceptorChain
# 35              org.axonframework.eventhandling.TrackedEventMessage
# 36                           org.axonframework.common.AxonException
# 37                           org.axonframework.common.DateTimeUtils
# 38              org.axonframework.messaging.DefaultInterceptorChain
# 39        org.axonframework.eventhandling.GenericDomainEventMessage
#
#               dependentTypeName  \
# 0                  BuilderUtils
# 1    AxonConfigurationException
# 2                       Message
# 3                      MetaData
# 4                    Serializer
# 5                  EventMessage
# 6                    UnitOfWork
# 7            TransactionManager
# 8                        Assert
# 9              SerializedObject
# 10               SerializedType
# 11            CurrentUnitOfWork
# 12                 Registration
# 13                  SpanFactory
# 14                    Lifecycle
# 15  Lifecycle$LifecycleRegistry
# 16    MessageHandlerInterceptor
# 17                  ObjectUtils
# 18                TrackingToken
# 19           DomainEventMessage
# 20   MessageDispatchInterceptor
# 21     ParameterResolverFactory
# 22       SimpleSerializedObject
# 23    AxonNonTransientException
# 24          GenericEventMessage
# 25               CommandMessage
# 26              NoOpSpanFactory
# 27                     EventBus
# 28            HandlerDefinition
# 29         NoTransactionManager
# 30                ResultMessage
# 31                         Span
# 32            DefaultUnitOfWork
# 33              ReflectionUtils
# 34             InterceptorChain
# 35          TrackedEventMessage
# 36                AxonException
# 37                DateTimeUtils
# 38      DefaultInterceptorChain
# 39    GenericDomainEventMessage
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 1   [Type, File, Java, Class, ByteCode, Throwable, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedCom...
# 2   [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 3   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4Ty...
# 4   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 5   [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 6   [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWe...
# 7   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1...
# 8   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 9   [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 10  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 11  [Type, File, Java, Class, ByteCode, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut36...
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity6, M...
# 13  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity4, ...
# 14                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut98, Mark4TypeHDBSCAN-1]
# 15                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut74, Mark4TypeHDBSCAN-1]
# 16  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4Ty...
# 17                                                                        [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut2, Mark4TypeHDBSCAN149]
# 18  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 19  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4Ty...
# 20  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity6, Mark4TypeKC...
# 21  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, ...
# 22  [Type, File, Java, Class, GenericDeclaration, ByteCode, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut74, Mark4Type...
# 23  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecompositi...
# 24  [Type, File, Java, Class, GenericDeclaration, ByteCode, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity5, Mark4TypeKCoreD...
# 25  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 26                                                                       [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut96, Mark4TypeHDBSCAN109]
# 27  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10, ...
# 28  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, ...
# 29                [Type, File, Java, ByteCode, Enum, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut85, Mark4TypeLocalClusteringCoefficient0.14285714285714285, Mark4TypeHDBSCAN205]
# 30  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation17, Mark4TypeLouvainCommunit...
# 31  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5,...
# 32                                                   [Type, File, Java, Class, GenericDeclaration, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut47, Mark4TypeHDBSCAN139]
# 33                                                     [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition7, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN111, Mark4TopAnomalyHub]
# 34             [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut54, Mark4TypeLocalClusteringCoefficient0.1038961038961039, Mark4TypeHDBSCAN-1]
# 35  [Type, File, Java, GenericDeclaration, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity10, Mark4...
# 36  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation43, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity11, Mark4TypeKCoreDecompos...
# 37                                                                       [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation18, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut54, Mark4TypeHDBSCAN151]
# 38           [Type, File, Java, Class, GenericDeclaration, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut13, Mark4TypeLocalClusteringCoefficient0.25, Mark4TypeHDBSCAN-1]
# 39  [Type, File, Java, Class, GenericDeclaration, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut80, Mark4TypeLocalClusteringCoefficient0.2727272727272727, Mark4TypeHD...
#
#     numberOfUsingPackages
# 0                      52
# 1                      43
# 2                      42
# 3                      40
# 4                      37
# 5                      36
# 6                      33
# 7                      31
# 8                      29
# 9                      28
# 10                     28
# 11                     22
# 12                     22
# 13                     22
# 14                     21
# 15                     21
# 16                     20
# 17                     20
# 18                     20
# 19                     19
# 20                     19
# 21                     19
# 22                     19
# 23                     18
# 24                     18
# 25                     17
# 26                     17
# 27                     15
# 28                     15
# 29                     15
# 30                     15
# 31                     15
# 32                     14
# 33                     14
# 34                     13
# 35                     13
# 36                     12
# 37                     12
# 38                     12
# 39                     12

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                              artifactName  \
# 0       axon-tracing-opentelemetry-4.12.2
# 1            axon-server-connector-4.12.2
# 2   axon-spring-boot-autoconfigure-4.12.2
# 3                   axon-disruptor-4.12.2
# 4                        axon-test-4.12.2
# 5                   axon-disruptor-4.12.2
# 6               axon-eventsourcing-4.12.2
# 7                        axon-test-4.12.2
# 8                   axon-disruptor-4.12.2
# 9                   axon-modelling-4.12.2
# 10              axon-eventsourcing-4.12.2
# 11           axon-server-connector-4.12.2
# 12           axon-server-connector-4.12.2
# 13  axon-spring-boot-autoconfigure-4.12.2
# 14              axon-configuration-4.12.2
# 15                       axon-test-4.12.2
# 16              axon-configuration-4.12.2
# 17  axon-spring-boot-autoconfigure-4.12.2
# 18                  axon-modelling-4.12.2
# 19  axon-spring-boot-autoconfigure-4.12.2
# 20              axon-configuration-4.12.2
# 21                       axon-test-4.12.2
# 22  axon-spring-boot-autoconfigure-4.12.2
# 23                  axon-messaging-4.12.2
# 24              axon-eventsourcing-4.12.2
# 25           axon-server-connector-4.12.2
# 26  axon-spring-boot-autoconfigure-4.12.2
# 27           axon-server-connector-4.12.2
# 28              axon-configuration-4.12.2
# 29  axon-spring-boot-autoconfigure-4.12.2
#
#                     dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-4.12.2                  3
# 1                   axon-modelling-4.12.2                  1
# 2                        axon-test-4.12.2                  1
# 3                   axon-messaging-4.12.2                  9
# 4                   axon-messaging-4.12.2                 10
# 5                   axon-modelling-4.12.2                  2
# 6                   axon-modelling-4.12.2                  2
# 7               axon-eventsourcing-4.12.2                  2
# 8               axon-eventsourcing-4.12.2                  2
# 9                   axon-messaging-4.12.2                 18
# 10                  axon-messaging-4.12.2                 20
# 11              axon-eventsourcing-4.12.2                  3
# 12                  axon-messaging-4.12.2                 25
# 13           axon-server-connector-4.12.2                  4
# 14              axon-eventsourcing-4.12.2                  4
# 15                  axon-modelling-4.12.2                  5
# 16                  axon-messaging-4.12.2                 37
# 17              axon-eventsourcing-4.12.2                  5
# 18                  axon-modelling-4.12.2                  6
# 19                  axon-modelling-4.12.2                  6
# 20                  axon-modelling-4.12.2                  6
# 21                       axon-test-4.12.2                  5
# 22                  axon-messaging-4.12.2                 44
# 23                  axon-messaging-4.12.2                 44
# 24              axon-eventsourcing-4.12.2                  7
# 25           axon-server-connector-4.12.2                  9
# 26  axon-spring-boot-autoconfigure-4.12.2                  9
# 27              axon-configuration-4.12.2                  1
# 28                  axon-disruptor-4.12.2                  1
# 29              axon-configuration-4.12.2                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          70                0.042857
# 1                          10                0.100000
# 2                           8                0.125000
# 3                          70                0.128571
# 4                          70                0.142857
# 5                          10                0.200000
# 6                          10                0.200000
# 7                           9                0.222222
# 8                           9                0.222222
# 9                          70                0.257143
# 10                         70                0.285714
# 11                          9                0.333333
# 12                         70                0.357143
# 13                         11                0.363636
# 14                          9                0.444444
# 15                         10                0.500000
# 16                         70                0.528571
# 17                          9                0.555556
# 18                         10                0.600000
# 19                         10                0.600000
# 20                         10                0.600000
# 21                          8                0.625000
# 22                         70                0.628571
# 23                         70                0.628571
# 24                          9                0.777778
# 25                         11                0.818182
# 26                         10                0.900000
# 27                          1                1.000000
# 28                          1                1.000000
# 29                          1                1.000000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                            [org.axonframework.common, org.axonframework.messaging, org.axonframework.tracing]
# 1                                                                                                                                                                                                                                                                         [org.axonframework.modelling.command]
# 2                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 3   [org.axonframework.common.transaction, org.axonframework.common.caching, org.axonframework.commandhandling.callbacks, org.axonframework.messaging.annotation, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.commandhandling, org.axonframework.monitoring, org.axo...
# 4   [org.axonframework.eventhandling, org.axonframework.eventhandling.scheduling, org.axonframework.common, org.axonframework.messaging, org.axonframework.commandhandling, org.axonframework.messaging.annotation, org.axonframework.deadline, org.axonframework.commandhandling.gateway, org.axonframework...
# 5                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 6                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 7                                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing]
# 8                                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing]
# 9   [org.axonframework.eventhandling, org.axonframework.commandhandling, org.axonframework.messaging.annotation, org.axonframework.messaging, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.common.annotation, org.axonframework.common.property, org.axonframework.co...
# 10  [org.axonframework.eventhandling, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.serialization, org.axonframework.serialization.upcasting.event, org.axonframework.common.jdbc, org.axonframework.common.transaction, org.axonframework.commandhandling, org.axonfr...
# 11                                                                                                                                                                                  [org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore]
# 12  [org.axonframework.lifecycle, org.axonframework.common, org.axonframework.serialization, org.axonframework.messaging, org.axonframework.common.jdbc, org.axonframework.eventhandling, org.axonframework.eventhandling.scheduling, org.axonframework.monitoring, org.axonframework.eventhandling.scheduli...
# 13                                                                                                                    [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.event.axon, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.query]
# 14                                                                                                                                  [org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore.jpa]
# 15                                                                                   [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga, org.axonframework.modelling.command.inspection, org.axonframework.modelling.command]
# 16  [org.axonframework.common.caching, org.axonframework.common.lock, org.axonframework.serialization.xml, org.axonframework.lifecycle, org.axonframework.eventhandling.tokenstore.jpa, org.axonframework.commandhandling.gateway, org.axonframework.eventhandling, org.axonframework.common.transaction, or...
# 17                                                                         [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.eventstore.legacyjpa]
# 18                                            [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.metamodel, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jpa]
# 19                               [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jdbc, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.command, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.legacyjpa]
# 20                                  [org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.command.inspection, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga]
# 21                                                                                                                                              [org.axonframework.test, org.axonframework.test.deadline, org.axonframework.test.matchers, org.axonframework.test.utils, org.axonframework.test.eventscheduler]
# 22  [org.axonframework.common.jpa, org.axonframework.messaging.timeout, org.axonframework.common.legacyjpa, org.axonframework.eventhandling.deadletter.jpa, org.axonframework.common, org.axonframework.tracing.attributes, org.axonframework.deadline.jobrunr, org.axonframework.serialization.xml, org.axo...
# 23  [org.axonframework.messaging, org.axonframework.common, org.axonframework.serialization, org.axonframework.util, org.axonframework.queryhandling, org.axonframework.commandhandling, org.axonframework.common.transaction, org.axonframework.eventhandling, org.axonframework.messaging.annotation, org....
# 24  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jdbc.statements, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing, org.axonframework.eventsourcing.conflictresolution, org.axonfra...
# 25  [org.axonframework.axonserver.connector.util, org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.event.util, org.axonframework.axonserver.connector.processor, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector.heartbeat, org.axonframe...
# 26  [org.axonframework.actuator, org.axonframework.springboot.updates, org.axonframework.springboot.util.jpa, org.axonframework.actuator.axonserver, org.axonframework.springboot.util, org.axonframework.springboot, org.axonframework.springboot.service.connection, org.axonframework.springboot.autoconf...
# 27                                                                                                                                                                                                                                                                                   [org.axonframework.config]
# 28                                                                                                                                                                                                                                                                [org.axonframework.disruptor.commandhandling]
# 29                                                                                                                                                                                                                                                                                   [org.axonframework.config]
#
#                                                                                                                                                                                                                                                                                           dependentPackageNames
# 0                                                                                                                                                                                                                                                                                  [common, messaging, tracing]
# 1                                                                                                                                                                                                                                                                                                     [command]
# 2                                                                                                                                                                                                                                                                                                      [server]
# 3                                                                                                                                                                                                     [transaction, caching, callbacks, annotation, unitofwork, common, commandhandling, monitoring, messaging]
# 4                                                                                                                                                                                            [eventhandling, scheduling, common, messaging, commandhandling, annotation, deadline, gateway, unitofwork, stream]
# 5                                                                                                                                                                                                                                                                                         [command, inspection]
# 6                                                                                                                                                                                                                                                                                         [command, inspection]
# 7                                                                                                                                                                                                                                                                                   [eventstore, eventsourcing]
# 8                                                                                                                                                                                                                                                                                   [eventstore, eventsourcing]
# 9                                                                                                                               [eventhandling, commandhandling, annotation, messaging, unitofwork, common, property, jpa, deadline, lock, tracing, interceptors, serialization, jdbc, xml, legacyjpa, caching]
# 10                                                                                                         [eventhandling, unitofwork, common, serialization, event, jdbc, transaction, commandhandling, annotation, messaging, jpa, io, tracing, lifecycle, stream, xml, monitoring, caching, lock, legacyjpa]
# 11                                                                                                                                                                                                                                                                    [eventsourcing, snapshotting, eventstore]
# 12                                     [lifecycle, common, serialization, messaging, jdbc, eventhandling, scheduling, monitoring, java, tracing, unitofwork, xml, async, stream, event, responsetypes, queryhandling, util, tokenstore, transaction, commandhandling, distributed, inmemory, pooled, callbacks]
# 13                                                                                                                                                                                                                                                                            [connector, axon, command, query]
# 14                                                                                                                                                                                                                                                               [snapshotting, eventstore, eventsourcing, jpa]
# 15                                                                                                                                                                                                                                                            [repository, inmemory, saga, inspection, command]
# 16  [caching, lock, xml, lifecycle, jpa, gateway, eventhandling, transaction, deadletter, unitofwork, event, util, serialization, interceptors, async, tokenstore, inmemory, monitoring, detection, annotation, messaging, configuration, updates, scheduling, deadline, correlation, pooled, commandhandlin...
# 17                                                                                                                                                                                                                                                            [eventsourcing, eventstore, jpa, jdbc, legacyjpa]
# 18                                                                                                                                                                                                                                                      [command, inspection, metamodel, saga, repository, jpa]
# 19                                                                                                                                                                                                                                                            [repository, jdbc, jpa, command, saga, legacyjpa]
# 20                                                                                                                                                                                                                                                       [jpa, inspection, command, repository, inmemory, saga]
# 21                                                                                                                                                                                                                                                            [test, deadline, matchers, utils, eventscheduler]
# 22  [jpa, timeout, legacyjpa, common, attributes, jobrunr, xml, distributed, scheduling, pooled, deadletter, tokenstore, json, detection, jdbc, annotation, eventhandling, correlation, avro, deadline, configuration, commandhandling, lifecycle, tracing, event, transaction, updates, interceptors, dbsch...
# 23  [messaging, common, serialization, util, queryhandling, commandhandling, transaction, eventhandling, annotation, distributed, unitofwork, tokenstore, jdbc, deadletter, api, async, event, tracing, stream, lifecycle, monitoring, io, replay, jobrunr, scheduling, deadline, jpa, correlation, digest, ...
# 24                                                                                                                                                                                                                         [eventstore, statements, snapshotting, jdbc, eventsourcing, conflictresolution, jpa]
# 25                                                                                                                                                                                                                                  [util, connector, processor, query, heartbeat, subscription, command, axon]
# 26                                                                                                                                                                                                                    [actuator, updates, jpa, axonserver, util, springboot, connection, autoconfig, legacyjpa]
# 27                                                                                                                                                                                                                                                                                                     [config]
# 28                                                                                                                                                                                                                                                                                            [commandhandling]
# 29                                                                                                                                                                                                                                                                                                     [config]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                              artifactName         dependentArtifactName  \
# 0                        axon-test-4.12.2         axon-messaging-4.12.2
# 1                   axon-modelling-4.12.2         axon-messaging-4.12.2
# 2               axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 3            axon-server-connector-4.12.2         axon-messaging-4.12.2
# 4   axon-spring-boot-autoconfigure-4.12.2         axon-messaging-4.12.2
# 5   axon-spring-boot-autoconfigure-4.12.2         axon-messaging-4.12.2
# 6               axon-eventsourcing-4.12.2         axon-modelling-4.12.2
# 7               axon-eventsourcing-4.12.2         axon-modelling-4.12.2
# 8            axon-server-connector-4.12.2         axon-modelling-4.12.2
# 9               axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 10                  axon-modelling-4.12.2         axon-messaging-4.12.2
# 11                       axon-test-4.12.2         axon-messaging-4.12.2
# 12                  axon-modelling-4.12.2         axon-messaging-4.12.2
# 13  axon-spring-boot-autoconfigure-4.12.2     axon-configuration-4.12.2
# 14  axon-spring-boot-autoconfigure-4.12.2     axon-configuration-4.12.2
# 15           axon-server-connector-4.12.2     axon-configuration-4.12.2
# 16           axon-server-connector-4.12.2     axon-eventsourcing-4.12.2
# 17                       axon-test-4.12.2         axon-messaging-4.12.2
# 18              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 19              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 20                       axon-test-4.12.2         axon-messaging-4.12.2
# 21              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 22              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 23  axon-spring-boot-autoconfigure-4.12.2         axon-messaging-4.12.2
# 24              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 25              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 26                       axon-test-4.12.2         axon-modelling-4.12.2
# 27              axon-eventsourcing-4.12.2         axon-messaging-4.12.2
# 28                       axon-test-4.12.2         axon-messaging-4.12.2
# 29  axon-spring-boot-autoconfigure-4.12.2  axon-server-connector-4.12.2
#
#                                                    packageName  \
# 0                              org.axonframework.test.matchers
# 1                   org.axonframework.modelling.saga.metamodel
# 2                 org.axonframework.eventsourcing.snapshotting
# 3                       org.axonframework.axonserver.connector
# 4                            org.axonframework.springboot.util
# 5            org.axonframework.springboot.autoconfig.legacyjpa
# 6              org.axonframework.eventsourcing.eventstore.jdbc
# 7           org.axonframework.eventsourcing.conflictresolution
# 8                       org.axonframework.axonserver.connector
# 9           org.axonframework.eventsourcing.conflictresolution
# 10               org.axonframework.modelling.command.legacyjpa
# 11                       org.axonframework.test.eventscheduler
# 12                         org.axonframework.modelling.command
# 13                                org.axonframework.springboot
# 14           org.axonframework.springboot.autoconfig.legacyjpa
# 15            org.axonframework.axonserver.connector.processor
# 16           org.axonframework.axonserver.connector.event.axon
# 17                                      org.axonframework.test
# 18                  org.axonframework.eventsourcing.eventstore
# 19          org.axonframework.eventsourcing.conflictresolution
# 20                             org.axonframework.test.matchers
# 21             org.axonframework.eventsourcing.eventstore.jdbc
# 22        org.axonframework.eventsourcing.eventstore.legacyjpa
# 23           org.axonframework.springboot.autoconfig.legacyjpa
# 24              org.axonframework.eventsourcing.eventstore.jpa
# 25  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 26                                org.axonframework.test.utils
# 27          org.axonframework.eventsourcing.conflictresolution
# 28                             org.axonframework.test.matchers
# 29                       org.axonframework.actuator.axonserver
#
#                       dependentPackage.fqn  dependentTypes  \
# 0          org.axonframework.eventhandling               1
# 1          org.axonframework.eventhandling               1
# 2          org.axonframework.eventhandling               1
# 3          org.axonframework.eventhandling               1
# 4          org.axonframework.eventhandling               1
# 5          org.axonframework.eventhandling               1
# 6      org.axonframework.modelling.command               1
# 7      org.axonframework.modelling.command               1
# 8      org.axonframework.modelling.command               1
# 9          org.axonframework.eventhandling               2
# 10         org.axonframework.eventhandling               2
# 11         org.axonframework.eventhandling               2
# 12         org.axonframework.eventhandling               2
# 13                org.axonframework.config               1
# 14                org.axonframework.config               1
# 15                org.axonframework.config               1
# 16         org.axonframework.eventsourcing               1
# 17             org.axonframework.messaging               1
# 18             org.axonframework.messaging               1
# 19             org.axonframework.messaging               1
# 20             org.axonframework.messaging               1
# 21         org.axonframework.serialization               1
# 22         org.axonframework.serialization               1
# 23         org.axonframework.serialization               1
# 24         org.axonframework.serialization               1
# 25         org.axonframework.eventhandling               3
# 26        org.axonframework.modelling.saga               1
# 27       org.axonframework.commandhandling               1
# 28       org.axonframework.commandhandling               1
# 29  org.axonframework.axonserver.connector               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                     100             0.010000
# 4                     100             0.010000
# 5                     100             0.010000
# 6                      56             0.017857
# 7                      56             0.017857
# 8                      56             0.017857
# 9                     100             0.020000
# 10                    100             0.020000
# 11                    100             0.020000
# 12                    100             0.020000
# 13                     43             0.023256
# 14                     43             0.023256
# 15                     43             0.023256
# 16                     42             0.023810
# 17                     35             0.028571
# 18                     35             0.028571
# 19                     35             0.028571
# 20                     35             0.028571
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                    100             0.030000
# 26                     33             0.030303
# 27                     32             0.031250
# 28                     32             0.031250
# 29                     32             0.031250
#
#                                                                                                                                                dependentTypeNames
# 0                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 1                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 2                                                                                                               [org.axonframework.eventhandling.DomainEventData]
# 3                                                                                                           [org.axonframework.eventhandling.EventBusSpanFactory]
# 4                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 5                                                                                                                      [org.axonframework.eventhandling.EventBus]
# 6                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 7                                                                                      [org.axonframework.modelling.command.ConflictingAggregateVersionException]
# 8                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 9                                                              [org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.DomainEventMessage]
# 10                                                           [org.axonframework.eventhandling.DomainEventSequenceAware, org.axonframework.eventhandling.EventBus]
# 11                                                            [org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.GenericEventMessage]
# 12                                                           [org.axonframework.eventhandling.DomainEventSequenceAware, org.axonframework.eventhandling.EventBus]
# 13                                                                                                                   [org.axonframework.config.TagsConfiguration]
# 14                                                                                                                       [org.axonframework.config.Configuration]
# 15                                                                                                        [org.axonframework.config.EventProcessingConfiguration]
# 16                                                                                                             [org.axonframework.eventsourcing.EventStreamUtils]
# 17                                                                                                                          [org.axonframework.messaging.Message]
# 18                                                                                                          [org.axonframework.messaging.StreamableMessageSource]
# 19                                                                                                                          [org.axonframework.messaging.Message]
# 20                                                                                                                          [org.axonframework.messaging.Message]
# 21                                                                                                                   [org.axonframework.serialization.Serializer]
# 22                                                                                                                   [org.axonframework.serialization.Serializer]
# 23                                                                                                                   [org.axonframework.serialization.Serializer]
# 24                                                                                                                   [org.axonframework.serialization.Serializer]
# 25  [org.axonframework.eventhandling.EventMessage, org.axonframework.eventhandling.GenericDomainEventMessage, org.axonframework.eventhandling.DomainEventMessage]
# 26                                                                                                      [org.axonframework.modelling.saga.SimpleResourceInjector]
# 27                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 28                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 29                                                                                           [org.axonframework.axonserver.connector.AxonServerConnectionManager]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                    javax.annotation.Nonnull
# 1                                                        java.lang.Deprecated
# 2                                 org.springframework.context.annotation.Bean
# 3   org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 4                                               java.lang.FunctionalInterface
# 5                                                   javax.annotation.Nullable
# 6                                                    javax.annotation.Nonnull
# 7                                              java.lang.annotation.Retention
# 8                                                 java.lang.annotation.Target
# 9                                                        java.lang.Deprecated
# 10                                                    javax.persistence.Basic
# 11                                                  jakarta.persistence.Basic
# 12                              com.fasterxml.jackson.annotation.JsonProperty
# 13                   org.springframework.boot.autoconfigure.AutoConfiguration
# 14                                            java.lang.annotation.Documented
# 15                                           java.beans.ConstructorProperties
# 16                                                       java.lang.Deprecated
# 17                     org.springframework.beans.factory.annotation.Qualifier
# 18                  org.springframework.boot.autoconfigure.AutoConfigureAfter
# 19     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 20         org.springframework.boot.autoconfigure.condition.ConditionalOnBean
# 21                               com.fasterxml.jackson.annotation.JsonCreator
# 22                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 23        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 24  org.springframework.boot.context.properties.EnableConfigurationProperties
# 25                                                   javax.persistence.Column
# 26                                                 jakarta.persistence.Column
# 27                                          org.axonframework.common.Priority
# 28                                                      javax.persistence.Lob
# 29        org.springframework.boot.context.properties.ConfigurationProperties
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       1670
# 1           Method                        133
# 2           Method                        129
# 3           Method                         82
# 4        Interface                         68
# 5        Parameter                         62
# 6           Method                         60
# 7       Annotation                         44
# 8       Annotation                         44
# 9            Class                         43
# 10           Field                         39
# 11           Field                         33
# 12       Parameter                         32
# 13           Class                         27
# 14      Annotation                         24
# 15     Constructor                         21
# 16     Constructor                         20
# 17       Parameter                         20
# 18           Class                         17
# 19          Method                         16
# 20          Method                         16
# 21     Constructor                         16
# 22           Class                         15
# 23           Class                         15
# 24           Class                         13
# 25           Field                         12
# 26           Field                         11
# 27           Class                         11
# 28           Field                         10
# 29           Class                         10
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.test.aggregate.AggregateTestFixture$CreationalRepository.load(0), org.axonframework.test.aggregate.AggregateTestFixture$CreationalRepository.newInstance(0), org.axonframework.test.aggregate.AggregateTestFixture$InMemoryRepository.newInstance(0), org.axonframework.test.aggregat...
# 1   [org.axonframework.test.matchers.Matchers.equalTo, org.axonframework.test.aggregate.AggregateTestFixture.whenThenTimeElapses, org.axonframework.test.aggregate.AggregateTestFixture.whenThenTimeAdvancesTo, org.axonframework.test.aggregate.TestExecutor.andThenTimeElapses, org.axonframework.test.agg...
# 2   [org.axonframework.springboot.autoconfig.AxonAutoConfiguration.serializer, org.axonframework.springboot.autoconfig.AxonAutoConfiguration.messageSerializer, org.axonframework.springboot.autoconfig.AxonAutoConfiguration.eventSerializer, org.axonframework.springboot.autoconfig.AxonAutoConfiguration...
# 3   [org.axonframework.springboot.autoconfig.AxonAutoConfiguration.messageOriginProvider, org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration$ConnectionDetailsConnectionManagerConfiguration.axonServerConnectionDetails, org.axonframework.springboot.autoconfig.AxonServerActuatorAutoCon...
# 4   [org.axonframework.test.matchers.FieldFilter, org.axonframework.test.deadline.DeadlineConsumer, org.axonframework.test.eventscheduler.EventConsumer, org.axonframework.eventsourcing.conflictresolution.ConflictExceptionSupplier, org.axonframework.eventsourcing.conflictresolution.ContextAwareConfli...
# 5   [org.axonframework.eventsourcing.eventstore.EventStorageEngine.readEvents(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(1), org.axonframework.commandhandling.MonitorAwareCallback.<init>(0), org.ax...
# 6   [org.axonframework.test.aggregate.AggregateTestFixture$RecordingEventStore.subscribe, org.axonframework.test.aggregate.AggregateTestFixture$RecordingEventStore.registerDispatchInterceptor, org.axonframework.test.deadline.StubDeadlineManager.schedule, org.axonframework.test.deadline.StubDeadlineM...
# 7   [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework...
# 8   [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonframework.commandhandling.gateway.Timeout, org.axonframework.common.Priority, org.axonframework...
# 9   [org.axonframework.test.aggregate.StubAggregateLifecycleRule, org.axonframework.test.utils.AutowiredResourceInjector, org.axonframework.test.server.AxonServerSEContainer, org.axonframework.test.server.AxonServerEEContainer, org.axonframework.eventsourcing.MultiStreamableMessageSource$Builder, or...
# 10  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 11  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 12  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(0), org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(1), org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>(0), org.axonframewor...
# 13  [org.axonframework.springboot.autoconfig.AxonServerActuatorAutoConfiguration, org.axonframework.springboot.autoconfig.OpenTelemetryAutoConfiguration, org.axonframework.springboot.autoconfig.AxonAutoConfiguration, org.axonframework.springboot.autoconfig.UpdateCheckerAutoConfiguration, org.axonfra...
# 14  [org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonframework.commandhandling.CommandHandler, org.axonframework.eventhandling.AllowReplay, org.axonframework.eventhandling.DisallowReplay, org.axonframework.eventhandling.EventHandler, org.axonfr...
# 15  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.DenyCommandNameFilter.<init>, org.axonframework.commandha...
# 16  [org.axonframework.eventsourcing.MultiStreamableMessageSource.<init>, org.axonframework.eventsourcing.snapshotting.RevisionSnapshotFilter.<init>, org.axonframework.commandhandling.callbacks.FailureLoggingCallback.<init>, org.axonframework.commandhandling.distributed.AbstractRoutingStrategy.<init...
# 17  [org.axonframework.springboot.autoconfig.AxonAutoConfiguration.eventSerializer(0), org.axonframework.springboot.autoconfig.AxonAutoConfiguration.serializerConfigurer(0), org.axonframework.springboot.autoconfig.AxonAutoConfiguration.serializerConfigurer(1), org.axonframework.springboot.autoconfig...
# 18  [org.axonframework.springboot.autoconfig.AxonServerActuatorAutoConfiguration, org.axonframework.springboot.autoconfig.AxonAutoConfiguration, org.axonframework.springboot.autoconfig.NoOpTransactionAutoConfiguration, org.axonframework.springboot.autoconfig.AxonDbSchedulerAutoConfiguration, org.axo...
# 19  [org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.eventStore, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration.axonServerEventStoreFactory, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.metricsConfigurerModule, org.axonframework.spri...
# 20  [org.axonframework.springboot.autoconfig.JdbcAutoConfiguration.sagaStoreWithSchema, org.axonframework.springboot.autoconfig.AxonAutoConfiguration.eventStore, org.axonframework.springboot.autoconfig.AxonAutoConfiguration.aggregateSnapshotter, org.axonframework.springboot.autoconfig.InterceptorAut...
# 21  [org.axonframework.eventhandling.GapAwareTrackingToken.<init>, org.axonframework.eventhandling.ReplayToken.<init>, org.axonframework.eventhandling.GlobalSequenceTrackingToken.<init>, org.axonframework.eventhandling.MergedTrackingToken.<init>, org.axonframework.eventhandling.MultiSourceTrackingTo...
# 22  [org.axonframework.springboot.autoconfig.OpenTelemetryAutoConfiguration, org.axonframework.springboot.autoconfig.NoOpTransactionAutoConfiguration, org.axonframework.springboot.autoconfig.JdbcAutoConfiguration, org.axonframework.springboot.autoconfig.AxonServerBusAutoConfiguration, org.axonframew...
# 23  [org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration$ConnectionDetailsConnectionManagerConfiguration, org.axonframework.springboot.autoconfig.AxonServerActuatorAutoConfiguration, org.axonframework.springboot.autoconfig.OpenTelemetryAutoConfiguration, org.axonframework.springboot....
# 24  [org.axonframework.springboot.autoconfig.AxonAutoConfiguration, org.axonframework.springboot.autoconfig.UpdateCheckerAutoConfiguration, org.axonframework.springboot.autoconfig.JdbcAutoConfiguration, org.axonframework.springboot.autoconfig.CBORMapperAutoConfiguration, org.axonframework.springboot...
# 25  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 26  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 27  [org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.config.ConfigurationParameterResolverFactory, org.axonframework.commandhandling.CurrentUnitOfWorkParameterResolverFactory, org.axonframework.eventhandling.SequenceNumberParameterResolverFactory, org.axonframework....
# 28  [org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.diagnostics, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEventEntry.payload, org.axonframework.eve...
# 29  [org.axonframework.springboot.TracingProperties, org.axonframework.springboot.EventProcessorProperties, org.axonframework.springboot.SerializerProperties, org.axonframework.springboot.TokenStoreProperties, org.axonframework.springboot.TimeoutProperties, org.axonframework.springboot.MetricsProper...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2720                     1080                         1217
# 1                    95                       85                           41
# 2                  2584                      787                          488
# 3                  2657                      462                          562
#
#                                                                                                                                                                                                                                                                                                       examples
# 0                 [/axon-spring-boot-autoconfigure-4.12.2.jar uses /axon-test-4.12.2.jar, /org/axonframework/test/deadline uses /org/axonframework/test/matchers, /org/axonframework/test/aggregate uses /org/axonframework/test/matchers, /org/axonframework/test/saga uses /org/axonframework/test/matchers]
# 1                                          [/org/axonframework/test/aggregate uses /org/axonframework/test, /org/axonframework/test/deadline uses /org/axonframework/test, /org/axonframework/test/eventscheduler uses /org/axonframework/test, /org/axonframework/test/matchers uses /org/axonframework/test]
# 2  [/org/axonframework/test/aggregate/ResultValidatorImpl.class uses /org/axonframework/test/matchers/PayloadMatcher.class, /org/axonframework/test/aggregate/ResultValidatorImpl.class uses /org/axonframework/test/deadline/StubDeadlineManager.class, /org/axonframework/test/saga/FixtureExecutionResul...
# 3  [/org/axonframework/springboot/service/connection uses /org/axonframework/test/server, /org/axonframework/springboot/service/connection/AxonServerTestContainerConnectionDetailsFactory$AxonServerContainerConnectionDetails.class uses /org/axonframework/test/server/AxonServerContainer.class, /org/a...
