# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.2.jar        66    808
# 1           axon-server-connector-4.11.2.jar        11    142
# 2                  axon-modelling-4.11.2.jar        10    158
# 3              axon-eventsourcing-4.11.2.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 5                       axon-test-4.11.2.jar         8     87
# 6              axon-configuration-4.11.2.jar         1     42
# 7                  axon-disruptor-4.11.2.jar         1     22
# 8      axon-tracing-opentelemetry-4.11.2.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     1                     4
# 2                     6                     1
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.2.jar        66    808
# 1                  axon-modelling-4.11.2.jar        10    158
# 2           axon-server-connector-4.11.2.jar        11    142
# 3              axon-eventsourcing-4.11.2.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 5                       axon-test-4.11.2.jar         8     87
# 6              axon-configuration-4.11.2.jar         1     42
# 7                  axon-disruptor-4.11.2.jar         1     22
# 8      axon-tracing-opentelemetry-4.11.2.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     4
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.2.jar        66    808
# 1                  axon-modelling-4.11.2.jar        10    158
# 2              axon-eventsourcing-4.11.2.jar         9    133
# 3              axon-configuration-4.11.2.jar         1     42
# 4                  axon-disruptor-4.11.2.jar         1     22
# 5           axon-server-connector-4.11.2.jar        11    142
# 6                       axon-test-4.11.2.jar         8     87
# 7      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 8  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     2                     4
# 4                     1                     3
# 5                     1                     4
# 6                     1                     3
# 7                     1                     1
# 8                     0                     7

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 1              axon-configuration-4.11.2.jar         1     42
# 2           axon-server-connector-4.11.2.jar        11    142
# 3                  axon-disruptor-4.11.2.jar         1     22
# 4                       axon-test-4.11.2.jar         8     87
# 5              axon-eventsourcing-4.11.2.jar         9    133
# 6                  axon-modelling-4.11.2.jar        10    158
# 7      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 8                  axon-messaging-4.11.2.jar        66    808
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     2                     4
# 2                     1                     4
# 3                     1                     3
# 4                     1                     3
# 5                     5                     2
# 6                     6                     1
# 7                     1                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0              axon-configuration-4.11.2.jar         1     42
# 1                  axon-disruptor-4.11.2.jar         1     22
# 2      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 3                       axon-test-4.11.2.jar         8     87
# 4              axon-eventsourcing-4.11.2.jar         9    133
# 5  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 6                  axon-modelling-4.11.2.jar        10    158
# 7           axon-server-connector-4.11.2.jar        11    142
# 8                  axon-messaging-4.11.2.jar        66    808
#
#    incomingDependencies  outgoingDependencies
# 0                     2                     4
# 1                     1                     3
# 2                     1                     1
# 3                     1                     3
# 4                     5                     2
# 5                     0                     7
# 6                     6                     1
# 7                     1                     4
# 8                     8                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 1                  axon-disruptor-4.11.2.jar         1     22
# 2              axon-configuration-4.11.2.jar         1     42
# 3                       axon-test-4.11.2.jar         8     87
# 4  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 5              axon-eventsourcing-4.11.2.jar         9    133
# 6           axon-server-connector-4.11.2.jar        11    142
# 7                  axon-modelling-4.11.2.jar        10    158
# 8                  axon-messaging-4.11.2.jar        66    808
#
#    incomingDependencies  outgoingDependencies
# 0                     1                     1
# 1                     1                     3
# 2                     2                     4
# 3                     1                     3
# 4                     0                     7
# 5                     5                     2
# 6                     1                     4
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
# 1                  axon-disruptor-4.11.2.jar         1     22
# 2           axon-server-connector-4.11.2.jar        11    142
# 3                       axon-test-4.11.2.jar         8     87
# 4      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 5              axon-configuration-4.11.2.jar         1     42
# 6              axon-eventsourcing-4.11.2.jar         9    133
# 7                  axon-modelling-4.11.2.jar        10    158
# 8                  axon-messaging-4.11.2.jar        66    808
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     1                     3
# 2                     1                     4
# 3                     1                     3
# 4                     1                     1
# 5                     2                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.2.jar        66    808
# 1                  axon-modelling-4.11.2.jar        10    158
# 2      axon-tracing-opentelemetry-4.11.2.jar         1      5
# 3              axon-eventsourcing-4.11.2.jar         9    133
# 4                  axon-disruptor-4.11.2.jar         1     22
# 5                       axon-test-4.11.2.jar         8     87
# 6              axon-configuration-4.11.2.jar         1     42
# 7           axon-server-connector-4.11.2.jar        11    142
# 8  axon-spring-boot-autoconfigure-4.11.2.jar         9     88
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     1
# 3                     5                     2
# 4                     1                     3
# 5                     1                     3
# 6                     2                     4
# 7                     1                     4
# 8                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                     artifactName  \
# 0          axon-messaging-4.11.2
# 1          axon-messaging-4.11.2
# 2          axon-messaging-4.11.2
# 3          axon-messaging-4.11.2
# 4          axon-messaging-4.11.2
# 5          axon-messaging-4.11.2
# 6          axon-messaging-4.11.2
# 7      axon-eventsourcing-4.11.2
# 8          axon-messaging-4.11.2
# 9          axon-messaging-4.11.2
# 10         axon-messaging-4.11.2
# 11  axon-server-connector-4.11.2
# 12         axon-messaging-4.11.2
# 13  axon-server-connector-4.11.2
# 14         axon-messaging-4.11.2
# 15  axon-server-connector-4.11.2
# 16  axon-server-connector-4.11.2
# 17  axon-server-connector-4.11.2
# 18         axon-messaging-4.11.2
# 19     axon-eventsourcing-4.11.2
# 20         axon-messaging-4.11.2
# 21         axon-modelling-4.11.2
# 22         axon-messaging-4.11.2
# 23         axon-messaging-4.11.2
# 24  axon-server-connector-4.11.2
# 25         axon-messaging-4.11.2
# 26         axon-modelling-4.11.2
# 27         axon-messaging-4.11.2
#
#                                                     packageName  \
# 0                               org.axonframework.eventhandling
# 1                               org.axonframework.queryhandling
# 2                               org.axonframework.queryhandling
# 3                               org.axonframework.eventhandling
# 4                               org.axonframework.eventhandling
# 5                                    org.axonframework.deadline
# 6                             org.axonframework.commandhandling
# 7                               org.axonframework.eventsourcing
# 8                   org.axonframework.commandhandling.callbacks
# 9                               org.axonframework.eventhandling
# 10                       org.axonframework.messaging.unitofwork
# 11            org.axonframework.axonserver.connector.event.axon
# 12                        org.axonframework.eventhandling.async
# 13                 org.axonframework.axonserver.connector.query
# 14                       org.axonframework.eventhandling.replay
# 15                  org.axonframework.axonserver.connector.util
# 16                       org.axonframework.axonserver.connector
# 17                 org.axonframework.axonserver.connector.query
# 18              org.axonframework.serialization.upcasting.event
# 19              org.axonframework.eventsourcing.eventstore.jdbc
# 20                              org.axonframework.eventhandling
# 21               org.axonframework.modelling.command.inspection
# 22                 org.axonframework.queryhandling.registration
# 23                                  org.axonframework.messaging
# 24               org.axonframework.axonserver.connector.command
# 25                       org.axonframework.messaging.annotation
# 26                             org.axonframework.modelling.saga
# 27  org.axonframework.commandhandling.distributed.commandfilter
#
#            dependentArtifactName  \
# 0          axon-messaging-4.11.2
# 1          axon-messaging-4.11.2
# 2          axon-messaging-4.11.2
# 3          axon-messaging-4.11.2
# 4          axon-messaging-4.11.2
# 5          axon-messaging-4.11.2
# 6          axon-messaging-4.11.2
# 7      axon-eventsourcing-4.11.2
# 8          axon-messaging-4.11.2
# 9          axon-messaging-4.11.2
# 10         axon-messaging-4.11.2
# 11  axon-server-connector-4.11.2
# 12         axon-messaging-4.11.2
# 13  axon-server-connector-4.11.2
# 14         axon-messaging-4.11.2
# 15  axon-server-connector-4.11.2
# 16  axon-server-connector-4.11.2
# 17  axon-server-connector-4.11.2
# 18         axon-messaging-4.11.2
# 19     axon-eventsourcing-4.11.2
# 20         axon-messaging-4.11.2
# 21         axon-modelling-4.11.2
# 22         axon-messaging-4.11.2
# 23         axon-messaging-4.11.2
# 24  axon-server-connector-4.11.2
# 25         axon-messaging-4.11.2
# 26         axon-modelling-4.11.2
# 27         axon-messaging-4.11.2
#
#                                           dependentPackageName  \
# 0                                    org.axonframework.tracing
# 1                    org.axonframework.messaging.responsetypes
# 2                                    org.axonframework.tracing
# 3                                  org.axonframework.messaging
# 4                       org.axonframework.messaging.annotation
# 5                                    org.axonframework.tracing
# 6                                    org.axonframework.tracing
# 7                   org.axonframework.eventsourcing.eventstore
# 8                            org.axonframework.commandhandling
# 9                              org.axonframework.serialization
# 10                                 org.axonframework.messaging
# 11                      org.axonframework.axonserver.connector
# 12                             org.axonframework.eventhandling
# 13                      org.axonframework.axonserver.connector
# 14                             org.axonframework.eventhandling
# 15                      org.axonframework.axonserver.connector
# 16           org.axonframework.axonserver.connector.event.util
# 17   org.axonframework.axonserver.connector.query.subscription
# 18                             org.axonframework.eventhandling
# 19  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 20                  org.axonframework.eventhandling.tokenstore
# 21                         org.axonframework.modelling.command
# 22                             org.axonframework.queryhandling
# 23                             org.axonframework.serialization
# 24                      org.axonframework.axonserver.connector
# 25                    org.axonframework.messaging.interceptors
# 26                  org.axonframework.modelling.saga.metamodel
# 27               org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.615385             21               5
# 12                  0.571429             11               3
# 13                  0.555556             21               6
# 14                  0.454545              8               3
# 15                  0.428571              5               2
# 16                  0.333333              2               1
# 17                  0.333333              4               2
# 18                  0.333333              6               3
# 19                  0.317073             27              14
# 20                  0.285714              9               5
# 21                  0.250000             20              12
# 22                  0.250000              5               3
# 23                  0.238095             13               8
# 24                  0.222222             11               7
# 25                  0.200000              3               2
# 26                  0.142857              4               3
# 27                  0.076923              7               6
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [SimpleEventBus$Builder->SpanFactory, DefaultEventProcessorSpanFactory->Span, DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan, DefaultEventProcessorSpanFactory->SpanFactory, EventProcessorSpanFactory->Span, AbstractEventProcessor->Span, AbstractEventBus->Span, AbstractEventBus->SpanSc...
# 1   [StreamingQueryMessage->ResponseType, QueryMessage->ResponseType, QueryGateway->ResponseType, QueryGateway->ResponseTypes, QuerySubscription->ResponseType, SimpleQueryUpdateEmitter->OptionalResponseType, SimpleQueryUpdateEmitter->MultipleInstancesResponseType, SimpleQueryUpdateEmitter->ResponseT...
# 2   [QueryBusSpanFactory->Span, DefaultQueryUpdateEmitterSpanFactory->Span, DefaultQueryUpdateEmitterSpanFactory->SpanFactory, SimpleQueryUpdateEmitter->Span, SimpleQueryUpdateEmitter$Builder->SpanFactory, SimpleQueryUpdateEmitter$Builder->NoOpSpanFactory, DefaultQueryUpdateEmitterSpanFactory$Builde...
# 3   [EventProcessor->MessageHandlerInterceptor, EventProcessor->MessageHandlerInterceptorSupport, TrackingTokenParameterResolverFactory$TrackingTokenParameterResolver->Message, MultiStreamableMessageSource$Builder->StreamableMessageSource, ConcludesBatchParameterResolverFactory->Message, StreamingEv...
# 4   [TrackingTokenParameterResolverFactory$TrackingTokenParameterResolver->ParameterResolver, ConcludesBatchParameterResolverFactory->AbstractAnnotatedParameterResolverFactory, ConcludesBatchParameterResolverFactory->ParameterResolver, AnnotationEventHandlerAdapter->HandlerDefinition, AnnotationEven...
# 5   [DefaultDeadlineManagerSpanFactory->SpanFactory, DefaultDeadlineManagerSpanFactory->Span, DeadlineManagerSpanFactory->Span, SimpleDeadlineManager$Builder->NoOpSpanFactory, SimpleDeadlineManager$Builder->SpanFactory, SimpleDeadlineManager->Span, SimpleDeadlineManager$DeadlineTask->Span, SimpleDea...
# 6   [AsynchronousCommandBus$Builder->SpanFactory, CommandBusSpanFactory->Span, SimpleCommandBus->Span, DefaultCommandBusSpanFactory->SpanFactory, DefaultCommandBusSpanFactory->Span, DefaultCommandBusSpanFactory$Builder->SpanFactory, SimpleCommandBus$Builder->NoOpSpanFactory, SimpleCommandBus$Builder...
# 7   [EventSourcingRepository->DomainEventStream, EventSourcingRepository->EventStore, AbstractSnapshotter->EventStore, AbstractSnapshotter->DomainEventStream, EventSourcingRepository$Builder->EventStore, AbstractSnapshotter$Builder->EventStore, AggregateSnapshotter$Builder->EventStore, AggregateCach...
# 8   [LoggingCallback->CommandCallback, LoggingCallback->CommandMessage, LoggingCallback->CommandResultMessage, FutureCallback->GenericCommandResultMessage, FutureCallback->CommandResultMessage, FutureCallback->CommandMessage, FutureCallback->CommandCallback, FailureLoggingCallback->CommandCallback, ...
# 9   [GenericEventMessage->CachingSupplier, AbstractDomainEventEntry->Serializer, AbstractEventEntry->SerializedObject, AbstractEventEntry->SimpleSerializedObject, AbstractEventEntry->Serializer, AbstractEventEntry->SerializedType, AbstractEventEntry->SerializedMetaData, AbstractEventEntry->SimpleSer...
# 10                   [BatchingUnitOfWork->GenericResultMessage, BatchingUnitOfWork->Message, BatchingUnitOfWork->ResultMessage, CurrentUnitOfWork->MetaData, AbstractUnitOfWork->MetaData, AbstractUnitOfWork->Message, MessageProcessingContext->Message, ExecutionResult->ResultMessage, UnitOfWork->Message]
# 11  [AxonServerEventStoreFactory$Builder->AxonServerConfiguration, AxonServerEventStoreFactory$Builder->AxonServerConnectionManager, AxonServerEventScheduler->AxonServerConnectionManager, AxonServerEventScheduler->ErrorCode, AxonServerEventStore$AxonIQEventStorageEngine$Builder->AxonServerConnection...
# 12  [PropertySequencingPolicy->EventMessage, FullConcurrencyPolicy->EventMessage, EventProcessorTask$ProcessingTask->EventMessage, EventProcessorTask->EventMessage, SequentialPerAggregatePolicy->EventMessage, SequentialPerAggregatePolicy->DomainEventMessage, MetaDataSequencingPolicy->EventMessage, A...
# 13  [GrpcBackedResponseMessage->ErrorCode, QueryProcessingTask->ErrorCode, StreamableFluxResponse$SendingSubscriber->ErrorCode, QuerySerializer->AxonServerConfiguration, QuerySerializer->ErrorCode, AxonServerQueryBus->ErrorCode, AxonServerQueryBus->PriorityRunnable, AxonServerQueryBus->AxonServerCon...
# 14  [ReplayParameterResolverFactory$ReplayParameterResolver->ReplayToken, ReplayParameterResolverFactory$ReplayParameterResolver->ReplayStatus, ReplayParameterResolverFactory->ReplayStatus, ReplayAwareMessageHandlerWrapper->AllowReplay, ReplayAwareMessageHandlerWrapper$ReplayBlockingMessageHandlingM...
# 15                             [PriorityExecutorService->PriorityRunnable, PriorityExecutorService->PriorityCallable, ExecutorServiceBuilder->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration$FlowControlConfiguration]
# 16                                                                                                                                                                                                                         [AxonServerConfiguration$Builder->EventCipher, AxonServerConfiguration->EventCipher]
# 17                                                                 [AxonServerQueryBus->AxonServerSubscriptionQueryResult, AxonServerQueryBus->SubscriptionMessageSerializer, AxonServerQueryBus$Builder->SubscriptionMessageSerializer, AxonServerQueryBus$LocalSegmentAdapter->SubscriptionMessageSerializer]
# 18                                    [IntermediateEventRepresentation->TrackingToken, InitialEventRepresentation->DomainEventData, InitialEventRepresentation->EventData, InitialEventRepresentation->TrackingToken, InitialEventRepresentation->TrackedEventData, UpcastedEventRepresentation->TrackingToken]
# 19  [JdbcEventStorageEngine$Builder->LastSequenceNumberForStatementBuilder, JdbcEventStorageEngine$Builder->ReadEventDataWithoutGapsStatementBuilder, JdbcEventStorageEngine$Builder->CreateTokenAtStatementBuilder, JdbcEventStorageEngine$Builder->AppendSnapshotStatementBuilder, JdbcEventStorageEngine$...
# 20  [TrackingEventProcessor$WorkerLauncher->UnableToClaimTokenException, TrackingEventProcessor$WorkerLauncher->TokenStore, TrackingEventProcessor$MergeSegmentInstruction->TokenStore, TrackingEventProcessor$ClaimSegmentInstruction->TokenStore, TrackingEventProcessor->TokenStore, TrackingEventProcess...
# 21  [ChildForwardingCommandMessageHandlingMember->AggregateEntityNotFoundException, AggregateMemberAnnotatedChildEntityDefinition->ForwardingMode, AbstractChildEntityDefinition->ForwardingMode, AbstractChildEntityDefinition->AggregateMember, AnnotatedAggregateMetaModelFactory$AnnotatedAggregateModel...
# 22                      [FailingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolver->QuerySubscription, LoggingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolution->QuerySubscription, DuplicateQueryHandlerSubscriptionException->QuerySubscription]
# 23             [ResultMessage->SerializedObject, ResultMessage->Serializer, GenericResultMessage->Serializer, GenericResultMessage->SerializedObject, GenericMessage->SerializedObjectHolder, GenericMessage->Serializer, GenericMessage->SerializedObject, Headers->SerializedType, Headers->SerializedObject]
# 24  [CommandSerializer->ErrorCode, CommandSerializer->AxonServerConfiguration, AxonServerCommandBus$Builder->TargetContextResolver, AxonServerCommandBus$Builder->AxonServerConfiguration, AxonServerCommandBus$Builder->AxonServerConnectionManager, AxonServerCommandBus->ErrorCode, AxonServerCommandBus-...
# 25                                                                                                                                          [MessageHandlerInterceptorDefinition->ResultHandler, MessageHandlerInterceptorDefinition->MessageHandlerInterceptor, ResultParameterResolverFactory->ResultHandler]
# 26                                                                                                                                           [AnnotatedSaga->SagaModel, AnnotatedSagaManager$Builder->AnnotationSagaMetaModelFactory, AnnotatedSagaManager$Builder->SagaModel, AnnotatedSagaManager->SagaModel]
# 27        [DenyCommandNameFilter->CommandMessageFilter, CommandNameFilter->CommandMessageFilter, AndCommandMessageFilter->CommandMessageFilter, NegateCommandMessageFilter->CommandMessageFilter, DenyAll->CommandMessageFilter, OrCommandMessageFilter->CommandMessageFilter, AcceptAll->CommandMessageFilter]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                            [NestingSpanFactory->EventMessage]
# 1                                                                                                                                                                                                                                                             [ConvertingResponseMessage->QueryResponseMessage]
# 2                                                                                                                                                                                                                                                                                     [SpanUtils->QueryMessage]
# 3                                                                                                                                                                                                                  [Headers->EventMessage, Headers->DomainEventMessage, StreamableMessageSource->TrackingToken]
# 4                                                                                                                                    [SourceIdParameterResolverFactory$SourceIdParameterResolver->DomainEventMessage, AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->DomainEventMessage]
# 5                                                                                                                                                                                                                                                                                  [SpanUtils->DeadlineMessage]
# 6                                                                                                                                                                                                                                                                                   [SpanUtils->CommandMessage]
# 7                                                                                                                                                                                                                           [AbstractEventStorageEngine->EventStreamUtils, DomainEventStream->EventStreamUtils]
# 8                                                                                                                                                                                                                           [SimpleCommandBus$Builder->LoggingCallback, SimpleCommandBus$Builder->NoOpCallback]
# 9                                                                                                                                                 [GapAwareTrackingTokenConverter->GapAwareTrackingToken, AbstractXStreamSerializer->GenericDomainEventMessage, AbstractXStreamSerializer->GenericEventMessage]
# 10                                                                                                                                                                                              [DefaultInterceptorChain->UnitOfWork, GenericMessage->CurrentUnitOfWork, MessageHandlerInterceptor->UnitOfWork]
# 11  [ServerConnectorConfigurerModule->AxonServerEventStore, ServerConnectorConfigurerModule->AxonServerEventStoreFactory$Builder, ServerConnectorConfigurerModule->EventProcessorInfoConfiguration, ServerConnectorConfigurerModule->AxonServerEventStore$Builder, ServerConnectorConfigurerModule->AxonServ...
# 12                                                                                                                                          [SimpleEventHandlerInvoker$Builder->SequencingPolicy, SimpleEventHandlerInvoker$Builder->SequentialPerAggregatePolicy, SimpleEventHandlerInvoker->SequencingPolicy]
# 13  [ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->AxonServerRemoteQueryHandlingException, ServerConnectorConfigurerModule->AxonServerQueryBus$Builder, ServerConnectorConfigurerModule->QueryPriorityCalculator, ServerConnectorCo...
# 14                                                                                                                                                                                [AnnotationEventHandlerAdapter->GenericResetContext, AnnotationEventHandlerAdapter->ResetContext, ResetHandler->ResetContext]
# 15                                                                                                                                                                                                            [ErrorCode->ExceptionSerializer, AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor]
# 16                                                                                                                                                                                                                                                                             [GrpcExceptionParser->ErrorCode]
# 17                                                                                                                                                                                       [SubscriptionMessageSerializer->GrpcBackedResponseMessage, GrpcBackedSubscriptionQueryMessage->GrpcBackedQueryMessage]
# 18                                                                                                                                                                                             [EventUtils->IntermediateEventRepresentation, EventUtils->EventUpcaster, EventUtils->InitialEventRepresentation]
# 19  [JdbcEventStorageEngineStatements->EventSchema, CleanGapsStatementBuilder->EventSchema, ReadEventDataWithoutGapsStatementBuilder->EventSchema, AppendEventsStatementBuilder->EventSchema, ReadSnapshotDataStatementBuilder->EventSchema, ReadEventDataForAggregateStatementBuilder->EventSchema, ReadEve...
# 20                                                                                                                                                            [TokenStore->Segment, TokenStore->TrackingToken, GenericTokenEntry->TrackingToken, AbstractTokenEntry->TrackingToken, ConfigToken->TrackingToken]
# 21  [LockingRepository$Builder->AggregateModel, AbstractRepository$Builder->AnnotatedAggregateMetaModelFactory, AbstractRepository$Builder->AggregateModel, ForwardingMode->EntityModel, ForwardMatchingInstances->EntityModel, GenericJpaRepository->AnnotatedAggregate, AggregateAnnotationCommandHandler$...
# 22                                                                                                                                              [SimpleQueryBus->DuplicateQueryHandlerResolver, SimpleQueryBus$Builder->DuplicateQueryHandlerResolver, SimpleQueryBus$Builder->DuplicateQueryHandlerResolution]
# 23                  [SerializedObjectHolder->Message, AbstractXStreamSerializer$MetaDataConverter->MetaData, SerializedMessage->Message, SerializedMessage->MetaData, SerializedMessage->AbstractMessage, SerializedMessage->GenericMessage, SerializedMetaData->MetaData, AbstractXStreamSerializer->MetaData]
# 24  [ErrorCode->AxonServerCommandDispatchException, ErrorCode->AxonServerNonTransientRemoteCommandHandlingException, ErrorCode->AxonServerRemoteCommandHandlingException, ServerConnectorConfigurerModule->CommandPriorityCalculator, ServerConnectorConfigurerModule->CommandLoadFactorProvider, ServerConn...
# 25                                                                                                                                                                                                                             [ResultHandler->HasHandlerAttributes, MessageHandlerInterceptor->MessageHandler]
# 26                                                                                                                       [AnnotationSagaMetaModelFactory$InspectedSagaModel->AssociationValue, AnnotationSagaMetaModelFactory$InspectedSagaModel->SagaMethodMessageHandlingMember, SagaModel->AssociationValue]
# 27                                      [CommandMessageFilter->OrCommandMessageFilter, CommandMessageFilter->NegateCommandMessageFilter, CommandMessageFilter->AndCommandMessageFilter, DistributedCommandBus->DenyAll, DistributedCommandBus->DenyCommandNameFilter, DistributedCommandBus->CommandNameFilter]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#              artifactName                      packageName  \
# 0   axon-messaging-4.11.2  org.axonframework.eventhandling
# 1   axon-messaging-4.11.2  org.axonframework.eventhandling
# 2   axon-messaging-4.11.2  org.axonframework.eventhandling
# 3   axon-messaging-4.11.2  org.axonframework.eventhandling
# 4   axon-messaging-4.11.2  org.axonframework.eventhandling
# 5   axon-messaging-4.11.2  org.axonframework.eventhandling
# 6   axon-messaging-4.11.2  org.axonframework.eventhandling
# 7   axon-messaging-4.11.2  org.axonframework.eventhandling
# 8   axon-messaging-4.11.2  org.axonframework.eventhandling
# 9   axon-messaging-4.11.2  org.axonframework.eventhandling
# 10  axon-messaging-4.11.2  org.axonframework.eventhandling
# 11  axon-messaging-4.11.2  org.axonframework.eventhandling
# 12  axon-messaging-4.11.2  org.axonframework.eventhandling
# 13  axon-messaging-4.11.2  org.axonframework.eventhandling
# 14  axon-messaging-4.11.2  org.axonframework.eventhandling
# 15  axon-messaging-4.11.2  org.axonframework.eventhandling
# 16  axon-messaging-4.11.2  org.axonframework.eventhandling
# 17  axon-messaging-4.11.2  org.axonframework.eventhandling
# 18  axon-messaging-4.11.2  org.axonframework.eventhandling
# 19  axon-messaging-4.11.2  org.axonframework.eventhandling
# 20  axon-messaging-4.11.2  org.axonframework.queryhandling
# 21  axon-messaging-4.11.2  org.axonframework.queryhandling
# 22  axon-messaging-4.11.2  org.axonframework.queryhandling
# 23  axon-messaging-4.11.2  org.axonframework.queryhandling
# 24  axon-messaging-4.11.2  org.axonframework.queryhandling
# 25  axon-messaging-4.11.2  org.axonframework.queryhandling
# 26  axon-messaging-4.11.2  org.axonframework.queryhandling
# 27  axon-messaging-4.11.2  org.axonframework.queryhandling
# 28  axon-messaging-4.11.2  org.axonframework.queryhandling
# 29  axon-messaging-4.11.2  org.axonframework.queryhandling
# 30  axon-messaging-4.11.2  org.axonframework.queryhandling
# 31  axon-messaging-4.11.2  org.axonframework.queryhandling
# 32  axon-messaging-4.11.2  org.axonframework.queryhandling
# 33  axon-messaging-4.11.2  org.axonframework.queryhandling
# 34  axon-messaging-4.11.2  org.axonframework.queryhandling
# 35  axon-messaging-4.11.2  org.axonframework.queryhandling
# 36  axon-messaging-4.11.2  org.axonframework.queryhandling
# 37  axon-messaging-4.11.2  org.axonframework.queryhandling
# 38  axon-messaging-4.11.2  org.axonframework.queryhandling
# 39  axon-messaging-4.11.2  org.axonframework.queryhandling
#
#     dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.11.2                  org.axonframework.tracing
# 1   axon-messaging-4.11.2                  org.axonframework.tracing
# 2   axon-messaging-4.11.2                  org.axonframework.tracing
# 3   axon-messaging-4.11.2                  org.axonframework.tracing
# 4   axon-messaging-4.11.2                  org.axonframework.tracing
# 5   axon-messaging-4.11.2                  org.axonframework.tracing
# 6   axon-messaging-4.11.2                  org.axonframework.tracing
# 7   axon-messaging-4.11.2                  org.axonframework.tracing
# 8   axon-messaging-4.11.2                  org.axonframework.tracing
# 9   axon-messaging-4.11.2                  org.axonframework.tracing
# 10  axon-messaging-4.11.2                  org.axonframework.tracing
# 11  axon-messaging-4.11.2                  org.axonframework.tracing
# 12  axon-messaging-4.11.2                  org.axonframework.tracing
# 13  axon-messaging-4.11.2                  org.axonframework.tracing
# 14  axon-messaging-4.11.2                  org.axonframework.tracing
# 15  axon-messaging-4.11.2                  org.axonframework.tracing
# 16  axon-messaging-4.11.2                  org.axonframework.tracing
# 17  axon-messaging-4.11.2                  org.axonframework.tracing
# 18  axon-messaging-4.11.2                  org.axonframework.tracing
# 19  axon-messaging-4.11.2                  org.axonframework.tracing
# 20  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.11.2  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.11.2                  org.axonframework.tracing
# 38  axon-messaging-4.11.2                  org.axonframework.tracing
# 39  axon-messaging-4.11.2                  org.axonframework.tracing
#
#                                                     dependency  \
# 0                DefaultEventProcessorSpanFactory->SpanFactory
# 1              DefaultEventBusSpanFactory$Builder->SpanFactory
# 2                             DefaultEventBusSpanFactory->Span
# 3                                       AbstractEventBus->Span
# 4                             EventMessage<-NestingSpanFactory
# 5              AbstractEventProcessor$Builder->NoOpSpanFactory
# 6                                 AbstractEventProcessor->Span
# 7                    AbstractEventBus$Builder->NoOpSpanFactory
# 8                                    EventBusSpanFactory->Span
# 9                                  AbstractEventBus->SpanScope
# 10                         SimpleEventBus$Builder->SpanFactory
# 11                     DefaultEventBusSpanFactory->SpanFactory
# 12  DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan
# 13                 AbstractEventProcessor$Builder->SpanFactory
# 14                      DefaultEventProcessorSpanFactory->Span
# 15                             EventProcessorSpanFactory->Span
# 16       DefaultEventProcessorSpanFactory$Builder->SpanFactory
# 17                       AbstractEventBus$Builder->SpanFactory
# 18                 TrackingEventProcessor$Builder->SpanFactory
# 19              SubscribingEventProcessor$Builder->SpanFactory
# 20         GenericStreamingQueryMessage->PublisherResponseType
# 21                      SubscriptionQueryMessage->ResponseType
# 22                           DefaultQueryGateway->ResponseType
# 23                      SimpleQueryUpdateEmitter->ResponseType
# 24     SimpleQueryUpdateEmitter->MultipleInstancesResponseType
# 25             SimpleQueryUpdateEmitter->PublisherResponseType
# 26                             QuerySubscription->ResponseType
# 27                           GenericQueryMessage->ResponseType
# 28                                SimpleQueryBus->ResponseType
# 29                  GenericStreamingQueryMessage->ResponseType
# 30                                 QueryGateway->ResponseTypes
# 31              SimpleQueryUpdateEmitter->OptionalResponseType
# 32               GenericSubscriptionQueryMessage->ResponseType
# 33             QueryResponseMessage<-ConvertingResponseMessage
# 34                         StreamingQueryMessage->ResponseType
# 35                                  QueryMessage->ResponseType
# 36                                  QueryGateway->ResponseType
# 37                                     QueryMessage<-SpanUtils
# 38                                   QueryBusSpanFactory->Span
# 39                  DefaultQueryUpdateEmitterSpanFactory->Span
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                     artifactName  \
# 0          axon-messaging-4.11.2
# 1          axon-messaging-4.11.2
# 2          axon-messaging-4.11.2
# 3          axon-messaging-4.11.2
# 4          axon-messaging-4.11.2
# 5          axon-messaging-4.11.2
# 6          axon-messaging-4.11.2
# 7          axon-messaging-4.11.2
# 8          axon-messaging-4.11.2
# 9          axon-messaging-4.11.2
# 10     axon-eventsourcing-4.11.2
# 11     axon-eventsourcing-4.11.2
# 12         axon-messaging-4.11.2
# 13         axon-messaging-4.11.2
# 14         axon-messaging-4.11.2
# 15         axon-messaging-4.11.2
# 16         axon-messaging-4.11.2
# 17         axon-messaging-4.11.2
# 18         axon-messaging-4.11.2
# 19         axon-messaging-4.11.2
# 20  axon-server-connector-4.11.2
# 21  axon-server-connector-4.11.2
# 22  axon-server-connector-4.11.2
# 23  axon-server-connector-4.11.2
# 24  axon-server-connector-4.11.2
# 25         axon-messaging-4.11.2
# 26         axon-messaging-4.11.2
# 27         axon-messaging-4.11.2
# 28  axon-server-connector-4.11.2
# 29  axon-server-connector-4.11.2
# 30  axon-server-connector-4.11.2
# 31  axon-server-connector-4.11.2
# 32  axon-server-connector-4.11.2
# 33  axon-server-connector-4.11.2
# 34         axon-messaging-4.11.2
# 35         axon-messaging-4.11.2
# 36         axon-messaging-4.11.2
# 37  axon-server-connector-4.11.2
# 38  axon-server-connector-4.11.2
# 39  axon-server-connector-4.11.2
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.eventhandling
# 6                     org.axonframework.eventhandling
# 7                     org.axonframework.eventhandling
# 8                          org.axonframework.deadline
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventsourcing
# 11                    org.axonframework.eventsourcing
# 12        org.axonframework.commandhandling.callbacks
# 13        org.axonframework.commandhandling.callbacks
# 14                    org.axonframework.eventhandling
# 15                    org.axonframework.eventhandling
# 16                    org.axonframework.eventhandling
# 17             org.axonframework.messaging.unitofwork
# 18             org.axonframework.messaging.unitofwork
# 19             org.axonframework.messaging.unitofwork
# 20  org.axonframework.axonserver.connector.event.axon
# 21  org.axonframework.axonserver.connector.event.axon
# 22  org.axonframework.axonserver.connector.event.axon
# 23  org.axonframework.axonserver.connector.event.axon
# 24  org.axonframework.axonserver.connector.event.axon
# 25              org.axonframework.eventhandling.async
# 26              org.axonframework.eventhandling.async
# 27              org.axonframework.eventhandling.async
# 28       org.axonframework.axonserver.connector.query
# 29       org.axonframework.axonserver.connector.query
# 30       org.axonframework.axonserver.connector.query
# 31       org.axonframework.axonserver.connector.query
# 32       org.axonframework.axonserver.connector.query
# 33       org.axonframework.axonserver.connector.query
# 34             org.axonframework.eventhandling.replay
# 35             org.axonframework.eventhandling.replay
# 36             org.axonframework.eventhandling.replay
# 37        org.axonframework.axonserver.connector.util
# 38        org.axonframework.axonserver.connector.util
# 39             org.axonframework.axonserver.connector
#
#            dependentArtifactName  \
# 0          axon-messaging-4.11.2
# 1          axon-messaging-4.11.2
# 2          axon-messaging-4.11.2
# 3          axon-messaging-4.11.2
# 4          axon-messaging-4.11.2
# 5          axon-messaging-4.11.2
# 6          axon-messaging-4.11.2
# 7          axon-messaging-4.11.2
# 8          axon-messaging-4.11.2
# 9          axon-messaging-4.11.2
# 10     axon-eventsourcing-4.11.2
# 11     axon-eventsourcing-4.11.2
# 12         axon-messaging-4.11.2
# 13         axon-messaging-4.11.2
# 14         axon-messaging-4.11.2
# 15         axon-messaging-4.11.2
# 16         axon-messaging-4.11.2
# 17         axon-messaging-4.11.2
# 18         axon-messaging-4.11.2
# 19         axon-messaging-4.11.2
# 20  axon-server-connector-4.11.2
# 21  axon-server-connector-4.11.2
# 22  axon-server-connector-4.11.2
# 23  axon-server-connector-4.11.2
# 24  axon-server-connector-4.11.2
# 25         axon-messaging-4.11.2
# 26         axon-messaging-4.11.2
# 27         axon-messaging-4.11.2
# 28  axon-server-connector-4.11.2
# 29  axon-server-connector-4.11.2
# 30  axon-server-connector-4.11.2
# 31  axon-server-connector-4.11.2
# 32  axon-server-connector-4.11.2
# 33  axon-server-connector-4.11.2
# 34         axon-messaging-4.11.2
# 35         axon-messaging-4.11.2
# 36         axon-messaging-4.11.2
# 37  axon-server-connector-4.11.2
# 38  axon-server-connector-4.11.2
# 39  axon-server-connector-4.11.2
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1           org.axonframework.messaging.responsetypes
# 2                           org.axonframework.tracing
# 3                         org.axonframework.messaging
# 4                         org.axonframework.messaging
# 5                         org.axonframework.messaging
# 6              org.axonframework.messaging.annotation
# 7              org.axonframework.messaging.annotation
# 8                           org.axonframework.tracing
# 9                           org.axonframework.tracing
# 10         org.axonframework.eventsourcing.eventstore
# 11         org.axonframework.eventsourcing.eventstore
# 12                  org.axonframework.commandhandling
# 13                  org.axonframework.commandhandling
# 14                    org.axonframework.serialization
# 15                    org.axonframework.serialization
# 16                    org.axonframework.serialization
# 17                        org.axonframework.messaging
# 18                        org.axonframework.messaging
# 19                        org.axonframework.messaging
# 20             org.axonframework.axonserver.connector
# 21             org.axonframework.axonserver.connector
# 22             org.axonframework.axonserver.connector
# 23             org.axonframework.axonserver.connector
# 24             org.axonframework.axonserver.connector
# 25                    org.axonframework.eventhandling
# 26                    org.axonframework.eventhandling
# 27                    org.axonframework.eventhandling
# 28             org.axonframework.axonserver.connector
# 29             org.axonframework.axonserver.connector
# 30             org.axonframework.axonserver.connector
# 31             org.axonframework.axonserver.connector
# 32             org.axonframework.axonserver.connector
# 33             org.axonframework.axonserver.connector
# 34                    org.axonframework.eventhandling
# 35                    org.axonframework.eventhandling
# 36                    org.axonframework.eventhandling
# 37             org.axonframework.axonserver.connector
# 38             org.axonframework.axonserver.connector
# 39  org.axonframework.axonserver.connector.event.util
#
#                                                                                   dependency  \
# 0                                                           EventMessage<-NestingSpanFactory
# 1                                            QueryResponseMessage<-ConvertingResponseMessage
# 2                                                                    QueryMessage<-SpanUtils
# 3                                                                DomainEventMessage<-Headers
# 4                                                                      EventMessage<-Headers
# 5                                                     TrackingToken<-StreamableMessageSource
# 6   DomainEventMessage<-AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver
# 7             DomainEventMessage<-SourceIdParameterResolverFactory$SourceIdParameterResolver
# 8                                                                 DeadlineMessage<-SpanUtils
# 9                                                                  CommandMessage<-SpanUtils
# 10                                                       EventStreamUtils<-DomainEventStream
# 11                                              EventStreamUtils<-AbstractEventStorageEngine
# 12                                                    NoOpCallback<-SimpleCommandBus$Builder
# 13                                                 LoggingCallback<-SimpleCommandBus$Builder
# 14                                     GapAwareTrackingToken<-GapAwareTrackingTokenConverter
# 15                                      GenericDomainEventMessage<-AbstractXStreamSerializer
# 16                                            GenericEventMessage<-AbstractXStreamSerializer
# 17                                                     UnitOfWork<-MessageHandlerInterceptor
# 18                                                         CurrentUnitOfWork<-GenericMessage
# 19                                                       UnitOfWork<-DefaultInterceptorChain
# 20                              AxonServerEventStoreFactory<-ServerConnectorConfigurerModule
# 21                             AxonServerEventStore$Builder<-ServerConnectorConfigurerModule
# 22                          EventProcessorInfoConfiguration<-ServerConnectorConfigurerModule
# 23                      AxonServerEventStoreFactory$Builder<-ServerConnectorConfigurerModule
# 24                                     AxonServerEventStore<-ServerConnectorConfigurerModule
# 25                                               SequencingPolicy<-SimpleEventHandlerInvoker
# 26                                       SequencingPolicy<-SimpleEventHandlerInvoker$Builder
# 27                           SequentialPerAggregatePolicy<-SimpleEventHandlerInvoker$Builder
# 28                             AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 29                                               AxonServerQueryDispatchException<-ErrorCode
# 30                                       AxonServerQueryBus<-ServerConnectorConfigurerModule
# 31                                  QueryPriorityCalculator<-ServerConnectorConfigurerModule
# 32                               AxonServerQueryBus$Builder<-ServerConnectorConfigurerModule
# 33                                         AxonServerRemoteQueryHandlingException<-ErrorCode
# 34                                        GenericResetContext<-AnnotationEventHandlerAdapter
# 35                                               ResetContext<-AnnotationEventHandlerAdapter
# 36                                                                ResetContext<-ResetHandler
# 37                           GrpcMessageSizeInterceptor<-AxonServerConnectionManager$Builder
# 38                                                            ExceptionSerializer<-ErrorCode
# 39                                                            ErrorCode<-GrpcExceptionParser
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.647059             14               3
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.615385             21               5
# 21                  0.615385             21               5
# 22                  0.615385             21               5
# 23                  0.615385             21               5
# 24                  0.615385             21               5
# 25                  0.571429             11               3
# 26                  0.571429             11               3
# 27                  0.571429             11               3
# 28                  0.555556             21               6
# 29                  0.555556             21               6
# 30                  0.555556             21               6
# 31                  0.555556             21               6
# 32                  0.555556             21               6
# 33                  0.555556             21               6
# 34                  0.454545              8               3
# 35                  0.454545              8               3
# 36                  0.454545              8               3
# 37                  0.428571              5               2
# 38                  0.428571              5               2
# 39                  0.333333              2               1

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                    fullDependentTypeName  \
# 0                       org.axonframework.commandhandling.CommandMessage
# 1                           org.axonframework.eventhandling.EventMessage
# 2                           org.axonframework.eventhandling.EventMessage
# 3                     org.axonframework.eventhandling.DomainEventMessage
# 4                    org.axonframework.eventhandling.TrackedEventMessage
# 5          org.axonframework.commandhandling.GenericCommandResultMessage
# 6                     org.axonframework.eventhandling.DomainEventMessage
# 7                              org.axonframework.messaging.ResultMessage
# 8                            org.axonframework.eventhandling.ReplayToken
# 9                      org.axonframework.deadline.GenericDeadlineMessage
# 10                    org.axonframework.eventhandling.DomainEventMessage
# 11                   org.axonframework.eventhandling.TrackedEventMessage
# 12                   org.axonframework.eventhandling.GenericEventMessage
# 13                            org.axonframework.deadline.DeadlineMessage
# 14                    org.axonframework.eventhandling.DomainEventMessage
# 15                          org.axonframework.eventhandling.EventMessage
# 16          org.axonframework.deadline.DefaultDeadlineManagerSpanFactory
# 17             org.axonframework.common.transaction.NoTransactionManager
# 18              org.axonframework.queryhandling.SimpleQueryUpdateEmitter
# 19         org.axonframework.commandhandling.GenericCommandResultMessage
# 20   org.axonframework.messaging.annotation.WrappedMessageHandlingMember
# 21         org.axonframework.modelling.command.inspection.AggregateModel
# 22              org.axonframework.queryhandling.SubscriptionQueryMessage
# 23                    org.axonframework.eventhandling.DomainEventMessage
# 24                        org.axonframework.queryhandling.SimpleQueryBus
# 25                    org.axonframework.eventhandling.DomainEventMessage
# 26                 org.axonframework.eventhandling.GapAwareTrackingToken
# 27                   org.axonframework.eventhandling.GenericEventMessage
# 28            org.axonframework.queryhandling.DefaultQueryBusSpanFactory
# 29       org.axonframework.commandhandling.gateway.DefaultCommandGateway
# 30                                org.axonframework.config.Configuration
# 31                                org.axonframework.config.Configuration
# 32                          org.axonframework.queryhandling.QueryMessage
# 33        org.axonframework.commandhandling.DefaultCommandBusSpanFactory
# 34                      org.axonframework.eventhandling.TrackedEventData
# 35                org.axonframework.eventhandling.tokenstore.ConfigToken
# 36            org.axonframework.eventhandling.DefaultEventBusSpanFactory
# 37  org.axonframework.queryhandling.DefaultQueryUpdateEmitterSpanFactory
# 38     org.axonframework.modelling.command.inspection.AnnotatedAggregate
# 39                   org.axonframework.queryhandling.DefaultQueryGateway
#
#     declaredMethods  \
# 0                 9
# 1                 9
# 2                 9
# 3                10
# 4                10
# 5                14
# 6                10
# 7                 9
# 8                13
# 9                11
# 10               10
# 11               12
# 12               11
# 13               10
# 14               10
# 15                9
# 16                8
# 17                4
# 18               17
# 19               15
# 20               14
# 21               13
# 22               12
# 23               11
# 24               11
# 25               10
# 26               10
# 27               10
# 28               10
# 29                9
# 30                9
# 31                9
# 32                9
# 33                5
# 34                5
# 35                5
# 36                4
# 37                4
# 38               17
# 39               17
#
#                                                    calledMethodNames  \
# 0                                                   [getCommandName]
# 1                                      [getTimestamp, getIdentifier]
# 2                                                    [getIdentifier]
# 3                                                [getSequenceNumber]
# 4                                                    [trackingToken]
# 5                                           [asCommandResultMessage]
# 6               [getSequenceNumber, getAggregateIdentifier, getType]
# 7                                   [isExceptional, exceptionResult]
# 8                                                [createReplayToken]
# 9                                                [asDeadlineMessage]
# 10                                          [getAggregateIdentifier]
# 11                                                   [trackingToken]
# 12                                                  [asEventMessage]
# 13                                                 [getDeadlineName]
# 14                                                         [getType]
# 15                                                    [getTimestamp]
# 16                                                         [builder]
# 17                                                        [instance]
# 18                                                         [builder]
# 19                                          [asCommandResultMessage]
# 20                                                          [handle]
# 21                                                            [type]
# 22                                           [getUpdateResponseType]
# 23              [getSequenceNumber, getAggregateIdentifier, getType]
# 24                                                         [builder]
# 25                       [getSequenceNumber, getAggregateIdentifier]
# 26  [getIndex, getGaps, withGapsTruncatedAt, newInstance, advanceTo]
# 27                                                  [asEventMessage]
# 28                                                         [builder]
# 29                                                         [builder]
# 30                                                    [getComponent]
# 31                                   [upcasterChain, snapshotFilter]
# 32                                   [getResponseType, getQueryName]
# 33                                                         [builder]
# 34                                                   [trackingToken]
# 35                                                             [get]
# 36                                                         [builder]
# 37                                                         [builder]
# 38                      [initialize, initSequence, getAggregateRoot]
# 39                                                         [builder]
#
#     calledMethods  callerTypes
# 0               1           20
# 1               2           11
# 2               1           10
# 3               1            9
# 4               1            8
# 5               1            6
# 6               3            6
# 7               2            6
# 8               1            5
# 9               1            5
# 10              1            5
# 11              1            4
# 12              1            4
# 13              1            4
# 14              1            4
# 15              1            4
# 16              1            4
# 17              1            4
# 18              1            3
# 19              1            3
# 20              1            3
# 21              1            3
# 22              1            3
# 23              3            3
# 24              1            3
# 25              2            3
# 26              5            3
# 27              1            3
# 28              1            3
# 29              1            3
# 30              1            3
# 31              2            3
# 32              2            3
# 33              1            3
# 34              1            3
# 35              1            3
# 36              1            3
# 37              1            3
# 38              4            2
# 39              1            2

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                      fullQualifiedDependentTypeName  \
# 0                             org.axonframework.common.BuilderUtils
# 1               org.axonframework.common.AxonConfigurationException
# 2                               org.axonframework.messaging.Message
# 3                              org.axonframework.messaging.MetaData
# 4                        org.axonframework.serialization.Serializer
# 5                      org.axonframework.eventhandling.EventMessage
# 6                 org.axonframework.messaging.unitofwork.UnitOfWork
# 7           org.axonframework.common.transaction.TransactionManager
# 8                                   org.axonframework.common.Assert
# 9                  org.axonframework.serialization.SerializedObject
# 10                   org.axonframework.serialization.SerializedType
# 11         org.axonframework.messaging.unitofwork.CurrentUnitOfWork
# 12                            org.axonframework.common.Registration
# 13                            org.axonframework.tracing.SpanFactory
# 14                            org.axonframework.lifecycle.Lifecycle
# 15          org.axonframework.lifecycle.Lifecycle$LifecycleRegistry
# 16            org.axonframework.messaging.MessageHandlerInterceptor
# 17                             org.axonframework.common.ObjectUtils
# 18                    org.axonframework.eventhandling.TrackingToken
# 19               org.axonframework.eventhandling.DomainEventMessage
# 20           org.axonframework.messaging.MessageDispatchInterceptor
# 21  org.axonframework.messaging.annotation.ParameterResolverFactory
# 22           org.axonframework.serialization.SimpleSerializedObject
# 23               org.axonframework.common.AxonNonTransientException
# 24              org.axonframework.eventhandling.GenericEventMessage
# 25                 org.axonframework.commandhandling.CommandMessage
# 26                        org.axonframework.tracing.NoOpSpanFactory
# 27                         org.axonframework.eventhandling.EventBus
# 28         org.axonframework.messaging.annotation.HandlerDefinition
# 29        org.axonframework.common.transaction.NoTransactionManager
# 30                        org.axonframework.messaging.ResultMessage
# 31                                   org.axonframework.tracing.Span
# 32         org.axonframework.messaging.unitofwork.DefaultUnitOfWork
# 33                         org.axonframework.common.ReflectionUtils
# 34                     org.axonframework.messaging.InterceptorChain
# 35              org.axonframework.eventhandling.TrackedEventMessage
# 36                           org.axonframework.common.AxonException
# 37                           org.axonframework.common.DateTimeUtils
# 38              org.axonframework.messaging.DefaultInterceptorChain
# 39        org.axonframework.eventhandling.GenericDomainEventMessage
#
#               dependentTypeName  \
# 0                  BuilderUtils
# 1    AxonConfigurationException
# 2                       Message
# 3                      MetaData
# 4                    Serializer
# 5                  EventMessage
# 6                    UnitOfWork
# 7            TransactionManager
# 8                        Assert
# 9              SerializedObject
# 10               SerializedType
# 11            CurrentUnitOfWork
# 12                 Registration
# 13                  SpanFactory
# 14                    Lifecycle
# 15  Lifecycle$LifecycleRegistry
# 16    MessageHandlerInterceptor
# 17                  ObjectUtils
# 18                TrackingToken
# 19           DomainEventMessage
# 20   MessageDispatchInterceptor
# 21     ParameterResolverFactory
# 22       SimpleSerializedObject
# 23    AxonNonTransientException
# 24          GenericEventMessage
# 25               CommandMessage
# 26              NoOpSpanFactory
# 27                     EventBus
# 28            HandlerDefinition
# 29         NoTransactionManager
# 30                ResultMessage
# 31                         Span
# 32            DefaultUnitOfWork
# 33              ReflectionUtils
# 34             InterceptorChain
# 35          TrackedEventMessage
# 36                AxonException
# 37                DateTimeUtils
# 38      DefaultInterceptorChain
# 39    GenericDomainEventMessage
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 1   [Type, File, Java, Class, ByteCode, Throwable, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedCom...
# 2   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 3   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4Ty...
# 4   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 5   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 6   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWe...
# 7   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1...
# 8   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 9   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 10  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 11                          [Type, File, Java, Class, ByteCode, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation31, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity18, Mark4TypeKCoreDecomposition10]
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation25, Mark4TypeLouvainCommunity15,...
# 13  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2,...
# 14                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10]
# 15                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10]
# 16  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation23, Mark4TypeLouvainCommunity5, Mark4T...
# 17                                                                                                                   [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation32, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10]
# 18  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 19  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation28, Mark4T...
# 20  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation25, Mark4TypeLouvainCommunity16, Mark4TypeLeidenCommunity16, Mark4Typ...
# 21   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation39, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity11, Mark4TypeKCoreDecomposition10]
# 22           [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.125]
# 23  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation58, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposi...
# 24  [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation66, Mark4TypeLouvainCommunity13, Mark4TypeLeidenCommunity18, Mark4TypeKCo...
# 25  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 26                                                                                                                   [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10]
# 27    [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation15, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposition10]
# 28   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation38, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity11, Mark4TypeKCoreDecomposition10]
# 29                                                                            [Type, File, Java, ByteCode, Enum, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.14285714285714285]
# 30  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunit...
# 31  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity2...
# 32                                                                                              [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation56, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity18, Mark4TypeKCoreDecomposition10]
# 33                                                                                                                  [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation68, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity11, Mark4TypeKCoreDecomposition7]
# 34                                                                      [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation57, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity18, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.1038961038961039]
# 35  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation34, Mark4TypeLouvainCommunity11, Mark4...
# 36  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation89, Mark4TypeLouvainCommunity18, Mark4TypeLeidenCommunity19, Mark4TypeKCoreDecompos...
# 37                                                                                                                    [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation32, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition8]
# 38                                                                   [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity15, Mark4TypeLeidenCommunity14, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.25]
# 39                                                      [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation66, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity18, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.2727272727272727]
#
#     numberOfUsingPackages
# 0                      50
# 1                      43
# 2                      42
# 3                      40
# 4                      37
# 5                      36
# 6                      33
# 7                      31
# 8                      29
# 9                      28
# 10                     28
# 11                     22
# 12                     22
# 13                     22
# 14                     20
# 15                     20
# 16                     20
# 17                     20
# 18                     20
# 19                     19
# 20                     19
# 21                     19
# 22                     19
# 23                     18
# 24                     18
# 25                     17
# 26                     17
# 27                     15
# 28                     15
# 29                     15
# 30                     15
# 31                     15
# 32                     14
# 33                     14
# 34                     13
# 35                     13
# 36                     12
# 37                     12
# 38                     12
# 39                     12

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                              artifactName  \
# 0       axon-tracing-opentelemetry-4.11.2
# 1            axon-server-connector-4.11.2
# 2   axon-spring-boot-autoconfigure-4.11.2
# 3                   axon-disruptor-4.11.2
# 4                        axon-test-4.11.2
# 5               axon-eventsourcing-4.11.2
# 6                   axon-disruptor-4.11.2
# 7                   axon-disruptor-4.11.2
# 8                        axon-test-4.11.2
# 9                   axon-modelling-4.11.2
# 10              axon-eventsourcing-4.11.2
# 11           axon-server-connector-4.11.2
# 12  axon-spring-boot-autoconfigure-4.11.2
# 13           axon-server-connector-4.11.2
# 14              axon-configuration-4.11.2
# 15                       axon-test-4.11.2
# 16              axon-configuration-4.11.2
# 17  axon-spring-boot-autoconfigure-4.11.2
# 18                  axon-modelling-4.11.2
# 19  axon-spring-boot-autoconfigure-4.11.2
# 20              axon-configuration-4.11.2
# 21                  axon-messaging-4.11.2
# 22  axon-spring-boot-autoconfigure-4.11.2
# 23                       axon-test-4.11.2
# 24              axon-eventsourcing-4.11.2
# 25           axon-server-connector-4.11.2
# 26  axon-spring-boot-autoconfigure-4.11.2
# 27           axon-server-connector-4.11.2
# 28  axon-spring-boot-autoconfigure-4.11.2
# 29  axon-spring-boot-autoconfigure-4.11.2
#
#                     dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-4.11.2                  3
# 1                   axon-modelling-4.11.2                  1
# 2                        axon-test-4.11.2                  1
# 3                   axon-messaging-4.11.2                  9
# 4                   axon-messaging-4.11.2                 10
# 5                   axon-modelling-4.11.2                  2
# 6                   axon-modelling-4.11.2                  2
# 7               axon-eventsourcing-4.11.2                  2
# 8               axon-eventsourcing-4.11.2                  2
# 9                   axon-messaging-4.11.2                 18
# 10                  axon-messaging-4.11.2                 20
# 11              axon-eventsourcing-4.11.2                  3
# 12           axon-server-connector-4.11.2                  4
# 13                  axon-messaging-4.11.2                 25
# 14              axon-eventsourcing-4.11.2                  4
# 15                  axon-modelling-4.11.2                  5
# 16                  axon-messaging-4.11.2                 34
# 17              axon-eventsourcing-4.11.2                  5
# 18                  axon-modelling-4.11.2                  6
# 19                  axon-modelling-4.11.2                  6
# 20                  axon-modelling-4.11.2                  6
# 21                  axon-messaging-4.11.2                 41
# 22                  axon-messaging-4.11.2                 41
# 23                       axon-test-4.11.2                  5
# 24              axon-eventsourcing-4.11.2                  7
# 25           axon-server-connector-4.11.2                  9
# 26  axon-spring-boot-autoconfigure-4.11.2                  8
# 27              axon-configuration-4.11.2                  1
# 28              axon-configuration-4.11.2                  1
# 29      axon-tracing-opentelemetry-4.11.2                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          66                0.045455
# 1                          10                0.100000
# 2                           8                0.125000
# 3                          66                0.136364
# 4                          66                0.151515
# 5                          10                0.200000
# 6                          10                0.200000
# 7                           9                0.222222
# 8                           9                0.222222
# 9                          66                0.272727
# 10                         66                0.303030
# 11                          9                0.333333
# 12                         11                0.363636
# 13                         66                0.378788
# 14                          9                0.444444
# 15                         10                0.500000
# 16                         66                0.515152
# 17                          9                0.555556
# 18                         10                0.600000
# 19                         10                0.600000
# 20                         10                0.600000
# 21                         66                0.621212
# 22                         66                0.621212
# 23                          8                0.625000
# 24                          9                0.777778
# 25                         11                0.818182
# 26                          9                0.888889
# 27                          1                1.000000
# 28                          1                1.000000
# 29                          1                1.000000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                            [org.axonframework.tracing, org.axonframework.common, org.axonframework.messaging]
# 1                                                                                                                                                                                                                                                                         [org.axonframework.modelling.command]
# 2                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 3   [org.axonframework.monitoring, org.axonframework.messaging.unitofwork, org.axonframework.commandhandling, org.axonframework.messaging.annotation, org.axonframework.common, org.axonframework.common.transaction, org.axonframework.messaging, org.axonframework.commandhandling.callbacks, org.axonfram...
# 4   [org.axonframework.messaging, org.axonframework.commandhandling, org.axonframework.common, org.axonframework.eventhandling, org.axonframework.messaging.annotation, org.axonframework.commandhandling.gateway, org.axonframework.deadline, org.axonframework.messaging.unitofwork, org.axonframework.com...
# 5                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 6                                                                                                                                                                                                                         [org.axonframework.modelling.command.inspection, org.axonframework.modelling.command]
# 7                                                                                                                                                                                                                                 [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore]
# 8                                                                                                                                                                                                                                 [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore]
# 9   [org.axonframework.common, org.axonframework.serialization, org.axonframework.common.legacyjpa, org.axonframework.serialization.xml, org.axonframework.common.lock, org.axonframework.messaging.unitofwork, org.axonframework.commandhandling, org.axonframework.common.annotation, org.axonframework.co...
# 10  [org.axonframework.eventhandling, org.axonframework.serialization, org.axonframework.common, org.axonframework.serialization.upcasting.event, org.axonframework.messaging.annotation, org.axonframework.common.lock, org.axonframework.common.caching, org.axonframework.messaging.unitofwork, org.axonf...
# 11                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting]
# 12                                                                                                                    [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.event.axon]
# 13  [org.axonframework.commandhandling.distributed, org.axonframework.commandhandling, org.axonframework.eventhandling, org.axonframework.common.transaction, org.axonframework.lifecycle, org.axonframework.common, org.axonframework.eventhandling.tokenstore, org.axonframework.eventhandling.tokenstore....
# 14                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore.jpa]
# 15                                                                                   [org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga.repository, org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 16  [org.axonframework.eventhandling.gateway, org.axonframework.common.transaction, org.axonframework.lifecycle, org.axonframework.deadline, org.axonframework.serialization.upcasting.event, org.axonframework.eventhandling.async, org.axonframework.common, org.axonframework.queryhandling.annotation, o...
# 17                                                                         [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.legacyjpa, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore.jpa]
# 18                                            [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.metamodel, org.axonframework.modelling.command]
# 19                               [org.axonframework.modelling.saga.repository.legacyjpa, org.axonframework.modelling.saga.repository, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.jdbc, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.jpa]
# 20                                  [org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga]
# 21  [org.axonframework.common.transaction, org.axonframework.tracing, org.axonframework.commandhandling.callbacks, org.axonframework.messaging.annotation, org.axonframework.messaging, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.monitoring, org.axonframework.ev...
# 22  [org.axonframework.messaging.timeout, org.axonframework.common.jpa, org.axonframework.eventhandling.tokenstore, org.axonframework.common.legacyjpa, org.axonframework.serialization, org.axonframework.messaging.deadletter, org.axonframework.common.jdbc, org.axonframework.eventhandling.tokenstore.l...
# 23                                                                                                                                              [org.axonframework.test, org.axonframework.test.matchers, org.axonframework.test.eventscheduler, org.axonframework.test.deadline, org.axonframework.test.utils]
# 24  [org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.conflictresolution, org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore.jdbc.statemen...
# 25  [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.heartbeat, org.axonframework.axonserver.connector.event.util, org.axonframework.axonserver.connector.util, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector.event.axon, org.axonfram...
# 26  [org.axonframework.actuator, org.axonframework.springboot.util, org.axonframework.springboot.util.legacyjpa, org.axonframework.springboot, org.axonframework.springboot.autoconfig, org.axonframework.springboot.service.connection, org.axonframework.springboot.util.jpa, org.axonframework.actuator.a...
# 27                                                                                                                                                                                                                                                                                   [org.axonframework.config]
# 28                                                                                                                                                                                                                                                                                   [org.axonframework.config]
# 29                                                                                                                                                                                                                                                                    [org.axonframework.tracing.opentelemetry]
#
#                                                                                                                                                                                                                                                                                           dependentPackageNames
# 0                                                                                                                                                                                                                                                                                  [tracing, common, messaging]
# 1                                                                                                                                                                                                                                                                                                     [command]
# 2                                                                                                                                                                                                                                                                                                      [server]
# 3                                                                                                                                                                                                     [monitoring, unitofwork, commandhandling, annotation, common, transaction, messaging, callbacks, caching]
# 4                                                                                                                                                                                            [messaging, commandhandling, common, eventhandling, annotation, gateway, deadline, unitofwork, stream, scheduling]
# 5                                                                                                                                                                                                                                                                                         [command, inspection]
# 6                                                                                                                                                                                                                                                                                         [inspection, command]
# 7                                                                                                                                                                                                                                                                                   [eventsourcing, eventstore]
# 8                                                                                                                                                                                                                                                                                   [eventsourcing, eventstore]
# 9                                                                                                                               [common, serialization, legacyjpa, xml, lock, unitofwork, commandhandling, annotation, jpa, deadline, interceptors, eventhandling, messaging, tracing, property, jdbc, caching]
# 10                                                                                                         [eventhandling, serialization, common, event, annotation, lock, caching, unitofwork, tracing, transaction, messaging, commandhandling, legacyjpa, monitoring, jdbc, io, stream, xml, lifecycle, jpa]
# 11                                                                                                                                                                                                                                                                    [eventstore, eventsourcing, snapshotting]
# 12                                                                                                                                                                                                                                                                            [connector, query, command, axon]
# 13                                     [distributed, commandhandling, eventhandling, transaction, lifecycle, common, tokenstore, inmemory, queryhandling, messaging, pooled, serialization, util, responsetypes, tracing, callbacks, async, jdbc, monitoring, java, xml, scheduling, stream, event, unitofwork]
# 14                                                                                                                                                                                                                                                               [eventstore, eventsourcing, snapshotting, jpa]
# 15                                                                                                                                                                                                                                                            [saga, inmemory, repository, command, inspection]
# 16  [gateway, transaction, lifecycle, deadline, event, async, common, annotation, xml, deadletter, eventhandling, messaging, caching, util, scheduling, pooled, jdbc, tokenstore, jpa, interceptors, correlation, commandhandling, inmemory, tracing, monitoring, queryhandling, serialization, lock, unitof...
# 17                                                                                                                                                                                                                                                            [eventstore, legacyjpa, jdbc, eventsourcing, jpa]
# 18                                                                                                                                                                                                                                                      [repository, saga, jpa, inspection, metamodel, command]
# 19                                                                                                                                                                                                                                                            [legacyjpa, repository, command, jdbc, saga, jpa]
# 20                                                                                                                                                                                                                                                       [inspection, repository, inmemory, command, jpa, saga]
# 21  [transaction, tracing, callbacks, annotation, messaging, unitofwork, common, monitoring, eventhandling, jpa, deadletter, serialization, deadline, digest, lifecycle, registration, interceptors, responsetypes, correlation, legacyjpa, stream, xml, property, commandhandling, queryhandling, lock, jdb...
# 22  [timeout, jpa, tokenstore, legacyjpa, serialization, deadletter, jdbc, transaction, eventhandling, deadline, pooled, gateway, jobrunr, event, avro, dbscheduler, json, correlation, lifecycle, distributed, common, async, tracing, attributes, xml, scheduling, messaging, interceptors, commandhandlin...
# 23                                                                                                                                                                                                                                                            [test, matchers, eventscheduler, deadline, utils]
# 24                                                                                                                                                                                                                         [jdbc, eventstore, conflictresolution, jpa, snapshotting, statements, eventsourcing]
# 25                                                                                                                                                                                                                                  [connector, heartbeat, util, query, axon, command, subscription, processor]
# 26                                                                                                                                                                                                                             [actuator, util, legacyjpa, springboot, autoconfig, connection, jpa, axonserver]
# 27                                                                                                                                                                                                                                                                                                     [config]
# 28                                                                                                                                                                                                                                                                                                     [config]
# 29                                                                                                                                                                                                                                                                                              [opentelemetry]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                              artifactName      dependentArtifactName  \
# 0   axon-spring-boot-autoconfigure-4.11.2      axon-messaging-4.11.2
# 1                   axon-modelling-4.11.2      axon-messaging-4.11.2
# 2               axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 3                        axon-test-4.11.2      axon-messaging-4.11.2
# 4   axon-spring-boot-autoconfigure-4.11.2      axon-messaging-4.11.2
# 5            axon-server-connector-4.11.2      axon-messaging-4.11.2
# 6               axon-eventsourcing-4.11.2      axon-modelling-4.11.2
# 7            axon-server-connector-4.11.2      axon-modelling-4.11.2
# 8               axon-eventsourcing-4.11.2      axon-modelling-4.11.2
# 9                   axon-modelling-4.11.2      axon-messaging-4.11.2
# 10                  axon-modelling-4.11.2      axon-messaging-4.11.2
# 11                       axon-test-4.11.2      axon-messaging-4.11.2
# 12              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 13           axon-server-connector-4.11.2  axon-eventsourcing-4.11.2
# 14  axon-spring-boot-autoconfigure-4.11.2  axon-configuration-4.11.2
# 15  axon-spring-boot-autoconfigure-4.11.2  axon-configuration-4.11.2
# 16           axon-server-connector-4.11.2  axon-configuration-4.11.2
# 17                       axon-test-4.11.2      axon-messaging-4.11.2
# 18                       axon-test-4.11.2      axon-messaging-4.11.2
# 19              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 20              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 21              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 22              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 23              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 24  axon-spring-boot-autoconfigure-4.11.2      axon-messaging-4.11.2
# 25              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 26                       axon-test-4.11.2      axon-modelling-4.11.2
# 27                       axon-test-4.11.2      axon-messaging-4.11.2
# 28              axon-eventsourcing-4.11.2      axon-messaging-4.11.2
# 29           axon-server-connector-4.11.2  axon-eventsourcing-4.11.2
#
#                                                    packageName  \
# 0                            org.axonframework.springboot.util
# 1                   org.axonframework.modelling.saga.metamodel
# 2                 org.axonframework.eventsourcing.snapshotting
# 3                              org.axonframework.test.matchers
# 4            org.axonframework.springboot.autoconfig.legacyjpa
# 5                       org.axonframework.axonserver.connector
# 6              org.axonframework.eventsourcing.eventstore.jdbc
# 7                       org.axonframework.axonserver.connector
# 8           org.axonframework.eventsourcing.conflictresolution
# 9                          org.axonframework.modelling.command
# 10               org.axonframework.modelling.command.legacyjpa
# 11                       org.axonframework.test.eventscheduler
# 12          org.axonframework.eventsourcing.conflictresolution
# 13           org.axonframework.axonserver.connector.event.axon
# 14           org.axonframework.springboot.autoconfig.legacyjpa
# 15                                org.axonframework.springboot
# 16            org.axonframework.axonserver.connector.processor
# 17                                      org.axonframework.test
# 18                             org.axonframework.test.matchers
# 19                  org.axonframework.eventsourcing.eventstore
# 20          org.axonframework.eventsourcing.conflictresolution
# 21              org.axonframework.eventsourcing.eventstore.jpa
# 22        org.axonframework.eventsourcing.eventstore.legacyjpa
# 23             org.axonframework.eventsourcing.eventstore.jdbc
# 24           org.axonframework.springboot.autoconfig.legacyjpa
# 25  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 26                                org.axonframework.test.utils
# 27                             org.axonframework.test.matchers
# 28          org.axonframework.eventsourcing.conflictresolution
# 29                      org.axonframework.axonserver.connector
#
#                           dependentPackage.fqn  dependentTypes  \
# 0              org.axonframework.eventhandling               1
# 1              org.axonframework.eventhandling               1
# 2              org.axonframework.eventhandling               1
# 3              org.axonframework.eventhandling               1
# 4              org.axonframework.eventhandling               1
# 5              org.axonframework.eventhandling               1
# 6          org.axonframework.modelling.command               1
# 7          org.axonframework.modelling.command               1
# 8          org.axonframework.modelling.command               1
# 9              org.axonframework.eventhandling               2
# 10             org.axonframework.eventhandling               2
# 11             org.axonframework.eventhandling               2
# 12             org.axonframework.eventhandling               2
# 13             org.axonframework.eventsourcing               1
# 14                    org.axonframework.config               1
# 15                    org.axonframework.config               1
# 16                    org.axonframework.config               1
# 17                 org.axonframework.messaging               1
# 18                 org.axonframework.messaging               1
# 19                 org.axonframework.messaging               1
# 20                 org.axonframework.messaging               1
# 21             org.axonframework.serialization               1
# 22             org.axonframework.serialization               1
# 23             org.axonframework.serialization               1
# 24             org.axonframework.serialization               1
# 25             org.axonframework.eventhandling               3
# 26            org.axonframework.modelling.saga               1
# 27           org.axonframework.commandhandling               1
# 28           org.axonframework.commandhandling               1
# 29  org.axonframework.eventsourcing.eventstore               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                     100             0.010000
# 4                     100             0.010000
# 5                     100             0.010000
# 6                      56             0.017857
# 7                      56             0.017857
# 8                      56             0.017857
# 9                     100             0.020000
# 10                    100             0.020000
# 11                    100             0.020000
# 12                    100             0.020000
# 13                     42             0.023810
# 14                     42             0.023810
# 15                     42             0.023810
# 16                     42             0.023810
# 17                     35             0.028571
# 18                     35             0.028571
# 19                     35             0.028571
# 20                     35             0.028571
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                    100             0.030000
# 26                     33             0.030303
# 27                     32             0.031250
# 28                     32             0.031250
# 29                     31             0.032258
#
#                                                                                                                                                dependentTypeNames
# 0                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 1                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 2                                                                                                               [org.axonframework.eventhandling.DomainEventData]
# 3                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 4                                                                                                                      [org.axonframework.eventhandling.EventBus]
# 5                                                                                                           [org.axonframework.eventhandling.EventBusSpanFactory]
# 6                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 7                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 8                                                                                      [org.axonframework.modelling.command.ConflictingAggregateVersionException]
# 9                                                            [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 10                                                           [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 11                                                            [org.axonframework.eventhandling.GenericEventMessage, org.axonframework.eventhandling.EventMessage]
# 12                                                             [org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 13                                                                                                             [org.axonframework.eventsourcing.EventStreamUtils]
# 14                                                                                                                       [org.axonframework.config.Configuration]
# 15                                                                                                                   [org.axonframework.config.TagsConfiguration]
# 16                                                                                                        [org.axonframework.config.EventProcessingConfiguration]
# 17                                                                                                                          [org.axonframework.messaging.Message]
# 18                                                                                                                          [org.axonframework.messaging.Message]
# 19                                                                                                          [org.axonframework.messaging.StreamableMessageSource]
# 20                                                                                                                          [org.axonframework.messaging.Message]
# 21                                                                                                                   [org.axonframework.serialization.Serializer]
# 22                                                                                                                   [org.axonframework.serialization.Serializer]
# 23                                                                                                                   [org.axonframework.serialization.Serializer]
# 24                                                                                                                   [org.axonframework.serialization.Serializer]
# 25  [org.axonframework.eventhandling.GenericDomainEventMessage, org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 26                                                                                                      [org.axonframework.modelling.saga.SimpleResourceInjector]
# 27                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 28                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 29                                                                                               [org.axonframework.eventsourcing.eventstore.EventStoreException]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                    javax.annotation.Nonnull
# 1                                                        java.lang.Deprecated
# 2                                 org.springframework.context.annotation.Bean
# 3   org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 4                                               java.lang.FunctionalInterface
# 5                                                   javax.annotation.Nullable
# 6                                                    javax.annotation.Nonnull
# 7                                                 java.lang.annotation.Target
# 8                                              java.lang.annotation.Retention
# 9                                                        java.lang.Deprecated
# 10                                                    javax.persistence.Basic
# 11                                                  jakarta.persistence.Basic
# 12                              com.fasterxml.jackson.annotation.JsonProperty
# 13                   org.springframework.boot.autoconfigure.AutoConfiguration
# 14                                            java.lang.annotation.Documented
# 15                                           java.beans.ConstructorProperties
# 16                                                       java.lang.Deprecated
# 17                     org.springframework.beans.factory.annotation.Qualifier
# 18                  org.springframework.boot.autoconfigure.AutoConfigureAfter
# 19     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 20                               com.fasterxml.jackson.annotation.JsonCreator
# 21         org.springframework.boot.autoconfigure.condition.ConditionalOnBean
# 22        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 23                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 24  org.springframework.boot.context.properties.EnableConfigurationProperties
# 25                                                   javax.persistence.Column
# 26                                          org.axonframework.common.Priority
# 27                                                 jakarta.persistence.Column
# 28     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 29                                                      javax.persistence.Lob
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       1668
# 1           Method                        133
# 2           Method                        124
# 3           Method                         78
# 4        Interface                         66
# 5        Parameter                         62
# 6           Method                         60
# 7       Annotation                         44
# 8       Annotation                         44
# 9            Class                         43
# 10           Field                         39
# 11           Field                         33
# 12       Parameter                         32
# 13           Class                         26
# 14      Annotation                         24
# 15     Constructor                         21
# 16     Constructor                         20
# 17       Parameter                         20
# 18           Class                         17
# 19          Method                         16
# 20     Constructor                         16
# 21          Method                         15
# 22           Class                         15
# 23           Class                         15
# 24           Class                         12
# 25           Field                         12
# 26           Class                         11
# 27           Field                         11
# 28           Class                         10
# 29           Field                         10
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.springboot.autoconfig.AxonAutoConfiguration.setBeanClassLoader(0), org.axonframework.springboot.autoconfig.PersistentStreamMessageSourceRegistrar.postProcessBeanDefinitionRegistry(0), org.axonframework.springboot.autoconfig.PersistentStreamMessageSourceRegistrar.postProcessBea...
# 1   [org.axonframework.springboot.TracingProperties.isNestedHandlers, org.axonframework.springboot.TracingProperties.setNestedHandlers, org.axonframework.springboot.TracingProperties.getNestedTimeLimit, org.axonframework.springboot.TracingProperties.setNestedTimeLimit, org.axonframework.test.deadlin...
# 2   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration.eventStorageEngine, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.entityManagerProvider, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.tokenStore, or...
# 3   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.entityManagerProvider, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.tokenStore, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.sagaStore, org.axonframework.spr...
# 4   [org.axonframework.test.deadline.DeadlineConsumer, org.axonframework.test.eventscheduler.EventConsumer, org.axonframework.test.matchers.FieldFilter, org.axonframework.commandhandling.CommandCallback, org.axonframework.commandhandling.DuplicateCommandHandlerResolver, org.axonframework.commandhand...
# 5   [org.axonframework.commandhandling.GenericCommandResultMessage.<init>(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(1), org.axonframework.commandhandling.MonitorAwareCallback.<init>(0), org.axonframework.deadline.DeadlineManager.schedule(2), org.axonframework.deadline....
# 6   [org.axonframework.springboot.util.legacyjpa.ContainerManagedEntityManagerProvider.getEntityManager, org.axonframework.springboot.util.AbstractQualifiedBeanCondition.getConfigurationPhase, org.axonframework.springboot.util.jpa.ContainerManagedEntityManagerProvider.getEntityManager, org.axonframe...
# 7   [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.springboot.util.RegisterDefaultEntities, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonf...
# 8   [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.springboot.util.RegisterDefaultEntities, org.axonframework.commandhandling.CommandHandler, org.axonframework.commandhandling.RoutingKey, org.axonf...
# 9   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.util.legacyjpa.ContainerManagedEntityManagerProvider, org.axonframework.test.server.AxonServerEEContai...
# 10  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 11  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 12  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(0), org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(1), org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>(0), org.axonframewor...
# 13  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration,...
# 14  [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.commandhandling.CommandHandler, org.axonframework.eventhandling.AllowReplay, org.axonframework.eventhandling.DisallowReplay, org.axonframework.eve...
# 15  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.NegateCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.OrCommandMessageFilter.<init>, org.axonframework...
# 16  [org.axonframework.commandhandling.distributed.AbstractRoutingStrategy.<init>, org.axonframework.commandhandling.distributed.AnnotationRoutingStrategy.<init>, org.axonframework.commandhandling.callbacks.FailureLoggingCallback.<init>, org.axonframework.commandhandling.distributed.MetaDataRoutingS...
# 17  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration.eventStorageEngine(2), org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.deadLetterQueueProviderConfigurerModule(4), org.axonframework.springboot.autoconfig.AxonDbSchedulerAutoConfigu...
# 18  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonDbSchedulerAutoConfigurat...
# 19  [org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration.eventScheduler, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.metricsConfigurerModule, org.axonframework.springboot.autoconfig.AxonTracingAutoConfiguration.aggregateIdentifierSpanAttributesProvider, org.axonf...
# 20  [org.axonframework.eventhandling.MergedTrackingToken.<init>, org.axonframework.eventhandling.MultiSourceTrackingToken.<init>, org.axonframework.eventhandling.GapAwareTrackingToken.<init>, org.axonframework.eventhandling.GlobalSequenceTrackingToken.<init>, org.axonframework.eventhandling.ReplayTo...
# 21  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.persistenceExceptionResolver, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration.commandDispatchInterceptorConfigurer, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration.eventDispatch...
# 22  [org.axonframework.springboot.autoconfig.AvroSerializerAutoConfiguration, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration, org.axonframework...
# 23  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.AvroSerializerAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfigu...
# 24  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframework.sp...
# 25  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 26  [org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.commandhandling.CurrentUnitOfWorkParameterResolverFactory, org.axonframework.eventhandling.SequenceNumberParameterResolverFactory, org.axonframework.eventhandling.TimestampParameterResolverFactory, org.axonframewo...
# 27  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 28  [org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.springboot.autoconfig.XStreamAutoConfiguration$XStreamConfiguredCondition$EventsXStreamCondition, org.axonframework.springboot.autoconfig.XStreamAutoConfiguration$XStreamConfiguredCondition$GeneralDefaultCon...
# 29  [org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.diagnostics, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEventEntry.payload, org.axonframework.eve...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2685                     1062                         1195
# 1                    92                       84                           38
# 2                  2558                      778                          477
# 3                  2636                      457                          552
#
#                                                                                                                                                                                                                                                                                                       examples
# 0  [/org/axonframework/springboot/autoconfig uses /org/axonframework/springboot/util, /org/axonframework/springboot/DistributedCommandBusProperties$JGroupsProperties$Gossip.class uses /org/axonframework/springboot/DistributedCommandBusProperties$JGroupsProperties.class, /org/axonframework/springboo...
# 1  [/org/axonframework/actuator/axonserver uses /org/axonframework/actuator, /org/axonframework/springboot/util uses /org/axonframework/springboot, /org/axonframework/springboot/autoconfig uses /org/axonframework/springboot, /org/axonframework/springboot/autoconfig/legacyjpa uses /org/axonframework...
# 2  [/org/axonframework/springboot/autoconfig uses /org/axonframework/actuator/axonserver, /org/axonframework/springboot/autoconfig/legacyjpa uses /org/axonframework/springboot, /org/axonframework/springboot/autoconfig uses /org/axonframework/springboot/service/connection, /org/axonframework/springb...
# 3  [/org/axonframework/springboot/service/connection uses /org/axonframework/test/server, /org/axonframework/springboot/service/connection/AxonServerTestContainerConnectionDetailsFactory.class uses /org/axonframework/test/server/AxonServerContainer.class, /org/axonframework/springboot/service/conne...
