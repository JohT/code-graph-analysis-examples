# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.3.jar        59    579
# 1                      axon-common-5.0.3.jar        15    156
# 2               axon-eventsourcing-5.0.3.jar         7    100
# 3                   axon-modelling-5.0.3.jar         7     92
# 4   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 5                        axon-test-5.0.3.jar         6     78
# 6                  axon-conversion-5.0.3.jar         5     35
# 7            axon-server-connector-5.0.3.jar         5     72
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      1                     7
# 5                      1                     3
# 6                      4                     1
# 7                      1                     4
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.3.jar        59    579
# 1                      axon-common-5.0.3.jar        15    156
# 2               axon-eventsourcing-5.0.3.jar         7    100
# 3                   axon-modelling-5.0.3.jar         7     92
# 4                        axon-test-5.0.3.jar         6     78
# 5   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 6            axon-server-connector-5.0.3.jar         5     72
# 7                  axon-conversion-5.0.3.jar         5     35
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      1                     3
# 5                      1                     7
# 6                      1                     4
# 7                      4                     1
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.3.jar        15    156
# 1                   axon-messaging-5.0.3.jar        59    579
# 2                  axon-conversion-5.0.3.jar         5     35
# 3               axon-eventsourcing-5.0.3.jar         7    100
# 4                   axon-modelling-5.0.3.jar         7     92
# 5            axon-server-connector-5.0.3.jar         5     72
# 6   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 7                        axon-test-5.0.3.jar         6     78
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      7                     2
# 2                      4                     1
# 3                      3                     4
# 4                      2                     3
# 5                      1                     4
# 6                      1                     7
# 7                      1                     3
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 1               axon-eventsourcing-5.0.3.jar         7    100
# 2            axon-server-connector-5.0.3.jar         5     72
# 3          axon-metrics-micrometer-5.0.3.jar         3     16
# 4                   axon-modelling-5.0.3.jar         7     92
# 5                        axon-test-5.0.3.jar         6     78
# 6                   axon-messaging-5.0.3.jar        59    579
# 7       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 8                  axon-conversion-5.0.3.jar         5     35
# 9                      axon-update-5.0.3.jar         5     23
# 10                     axon-common-5.0.3.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      1                     7
# 1                      3                     4
# 2                      1                     4
# 3                      0                     3
# 4                      2                     3
# 5                      1                     3
# 6                      7                     2
# 7                      0                     2
# 8                      4                     1
# 9                      1                     1
# 10                    10                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 1          axon-metrics-micrometer-5.0.3.jar         3     16
# 2                  axon-conversion-5.0.3.jar         5     35
# 3            axon-server-connector-5.0.3.jar         5     72
# 4                      axon-update-5.0.3.jar         5     23
# 5                        axon-test-5.0.3.jar         6     78
# 6               axon-eventsourcing-5.0.3.jar         7    100
# 7                   axon-modelling-5.0.3.jar         7     92
# 8   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 9                      axon-common-5.0.3.jar        15    156
# 10                  axon-messaging-5.0.3.jar        59    579
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     3
# 2                      4                     1
# 3                      1                     4
# 4                      1                     1
# 5                      1                     3
# 6                      3                     4
# 7                      2                     3
# 8                      1                     7
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 1          axon-metrics-micrometer-5.0.3.jar         3     16
# 2                      axon-update-5.0.3.jar         5     23
# 3                  axon-conversion-5.0.3.jar         5     35
# 4            axon-server-connector-5.0.3.jar         5     72
# 5   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 6                        axon-test-5.0.3.jar         6     78
# 7                   axon-modelling-5.0.3.jar         7     92
# 8               axon-eventsourcing-5.0.3.jar         7    100
# 9                      axon-common-5.0.3.jar        15    156
# 10                  axon-messaging-5.0.3.jar        59    579
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     3
# 2                      1                     1
# 3                      4                     1
# 4                      1                     4
# 5                      1                     7
# 6                      1                     3
# 7                      2                     3
# 8                      3                     4
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0          axon-metrics-micrometer-5.0.3.jar         3     16
# 1       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 2            axon-server-connector-5.0.3.jar         5     72
# 3   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 4                        axon-test-5.0.3.jar         6     78
# 5                      axon-update-5.0.3.jar         5     23
# 6                   axon-modelling-5.0.3.jar         7     92
# 7               axon-eventsourcing-5.0.3.jar         7    100
# 8                  axon-conversion-5.0.3.jar         5     35
# 9                   axon-messaging-5.0.3.jar        59    579
# 10                     axon-common-5.0.3.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     3
# 1                      0                     2
# 2                      1                     4
# 3                      1                     7
# 4                      1                     3
# 5                      1                     1
# 6                      2                     3
# 7                      3                     4
# 8                      4                     1
# 9                      7                     2
# 10                    10                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.3.jar        15    156
# 1                  axon-conversion-5.0.3.jar         5     35
# 2                      axon-update-5.0.3.jar         5     23
# 3                   axon-messaging-5.0.3.jar        59    579
# 4       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 5          axon-metrics-micrometer-5.0.3.jar         3     16
# 6                   axon-modelling-5.0.3.jar         7     92
# 7                        axon-test-5.0.3.jar         6     78
# 8               axon-eventsourcing-5.0.3.jar         7    100
# 9            axon-server-connector-5.0.3.jar         5     72
# 10  axon-spring-boot-autoconfigure-5.0.3.jar         7     75
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      4                     1
# 2                      1                     1
# 3                      7                     2
# 4                      0                     2
# 5                      0                     3
# 6                      2                     3
# 7                      1                     3
# 8                      3                     4
# 9                      1                     4
# 10                     1                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9             axon-common-5.0.3
# 10         axon-messaging-5.0.3
# 11  axon-server-connector-5.0.3
# 12  axon-server-connector-5.0.3
# 13         axon-messaging-5.0.3
# 14         axon-messaging-5.0.3
# 15  axon-server-connector-5.0.3
# 16         axon-modelling-5.0.3
# 17         axon-modelling-5.0.3
# 18         axon-messaging-5.0.3
# 19  axon-server-connector-5.0.3
# 20     axon-eventsourcing-5.0.3
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8        org.axonframework.messaging.eventhandling.processing.subscribing
# 9                                  org.axonframework.common.configuration
# 10               org.axonframework.messaging.core.interception.annotation
# 11                           org.axonframework.axonserver.connector.event
# 12                                 org.axonframework.axonserver.connector
# 13                         org.axonframework.messaging.core.configuration
# 14                              org.axonframework.messaging.eventhandling
# 15                           org.axonframework.axonserver.connector.query
# 16                          org.axonframework.modelling.entity.annotation
# 17                               org.axonframework.modelling.entity.child
# 18                            org.axonframework.messaging.core.unitofwork
# 19                            org.axonframework.axonserver.connector.util
# 20                  org.axonframework.eventsourcing.annotation.reflection
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9             axon-common-5.0.3
# 10         axon-messaging-5.0.3
# 11  axon-server-connector-5.0.3
# 12  axon-server-connector-5.0.3
# 13         axon-messaging-5.0.3
# 14         axon-messaging-5.0.3
# 15  axon-server-connector-5.0.3
# 16         axon-modelling-5.0.3
# 17         axon-modelling-5.0.3
# 18         axon-messaging-5.0.3
# 19  axon-server-connector-5.0.3
# 20     axon-eventsourcing-5.0.3
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9                            org.axonframework.common.infra
# 10              org.axonframework.messaging.core.annotation
# 11                   org.axonframework.axonserver.connector
# 12           org.axonframework.axonserver.connector.command
# 13  org.axonframework.messaging.eventhandling.configuration
# 14              org.axonframework.messaging.core.sequencing
# 15                   org.axonframework.axonserver.connector
# 16                   org.axonframework.modelling.annotation
# 17                       org.axonframework.modelling.entity
# 18                         org.axonframework.messaging.core
# 19                   org.axonframework.axonserver.connector
# 20               org.axonframework.eventsourcing.annotation
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.931034             28               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.529412             13               4
# 10                  0.500000             15               5
# 11                  0.428571              5               2
# 12                  0.333333              4               2
# 13                  0.333333              2               1
# 14                  0.333333              4               2
# 15                  0.200000              6               4
# 16                  0.200000              3               2
# 17                  0.142857              8               6
# 18                  0.111111             10               8
# 19                  0.000000              2               2
# 20                  0.000000              1               1
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Message, DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Metadata, MessageHandler->Message, MultiHandlerDefinition->MessageStream, MessageStreamResolverUtils->MessageStream$Empty, MessageStreamResolverUtils-...
# 1   [SimpleEventHandlingComponent->Message, SimpleEventHandlingComponent->MessageType, SimpleEventHandlingComponent->MessageStream, SimpleEventHandlingComponent->QualifiedName, SimpleEventHandlingComponent->MessageStream$Empty, TerminalEventMessage->MessageType, EventMessage->Message, SimpleEventBus...
# 2   [EventAppenderParameterResolverFactoryConfigurationEnhancer->ParameterResolverFactory, TimestampParameterResolverFactory->ParameterResolver, TimestampParameterResolverFactory->AbstractAnnotatedParameterResolverFactory, MethodSequencingPolicyEventHandlerDefinition->HandlerEnhancerDefinition, Meth...
# 3   [CommandDispatcherParameterResolverFactory->ParameterResolverFactory, CommandDispatcherParameterResolverFactory->ParameterResolver, CommandDispatcherParameterResolverFactoryConfigurationEnhancer->ParameterResolverFactory, AnnotatedCommandHandlingComponent->MessageHandlingMember, AnnotatedCommand...
# 4   [MethodQueryHandlerDefinition$MethodQueryHandlingMember->WrappedMessageHandlingMember, MethodQueryHandlerDefinition$MethodQueryHandlingMember->UnsupportedHandlerException, MethodQueryHandlerDefinition$MethodQueryHandlingMember->MessageHandlingMember, AnnotatedQueryHandlingComponent->HandlerDefin...
# 5   [AnnotationBasedEntityIdResolver->EntityIdResolutionException, AnnotationBasedEntityIdResolver->EntityIdResolver, InjectEntityParameterResolverFactory->EntityIdResolver, InjectEntityParameterResolverFactory->PropertyBasedEntityIdResolver, InjectEntityParameterResolver->EntityIdResolutionExceptio...
# 6                                                                       [TransactionalExecutorProvider->ProcessingContext, TransactionManager->ProcessingContext, TransactionManager->ProcessingLifecycle$Phase, TransactionManager->ProcessingLifecycle$ErrorHandler, TransactionManager->ProcessingLifecycle]
# 7   [PooledStreamingEventProcessorModule->EventHandlingComponentsConfigurer$CompletePhase, PooledStreamingEventProcessorModule->EventHandlingComponentsConfigurer$RequiredComponentPhase, PooledStreamingEventProcessorModule->DefaultEventHandlingComponentsConfigurer, PooledStreamingEventProcessorModule...
# 8   [SubscribingEventProcessorsConfigurer->EventProcessorModule$EventHandlingPhase, SubscribingEventProcessorsConfigurer->EventHandlingComponentsConfigurer$RequiredComponentPhase, SubscribingEventProcessorsConfigurer->EventHandlingComponentsConfigurer$CompletePhase, SubscribingEventProcessorsConfigu...
# 9   [Component->DescribableComponent, DefaultComponentRegistry$LocalConfiguration->ComponentDescriptor, LazyInitializedComponentDefinition->ComponentDescriptor, Configuration->DescribableComponent, DefaultAxonApplication$AxonConfigurationImpl->ComponentDescriptor, DecoratedComponent->ComponentDescri...
# 10  [NoMoreInterceptors->MessageHandlingMember, MessageHandlerInterceptorDefinition$InterceptedMessageHandlingMember->MessageHandlingMember, MessageHandlerInterceptorDefinition$InterceptedMessageHandlingMember->WrappedMessageHandlingMember, MessageHandlerInterceptorMemberChain->MessageHandlingMember...
# 11  [EventProcessorControlService->AxonServerConfiguration$Eventhandling$ProcessorSettings, EventProcessorControlService->AxonServerConnectionManager, EventProcessorControlService->AxonServerConfiguration$Eventhandling, AggregateBasedAxonServerEventStorageEngine->MetadataConverter, AxonServerEventSt...
# 12                                                                        [ErrorCode->AxonServerRemoteCommandHandlingException, ErrorCode->AxonServerNonTransientRemoteCommandHandlingException, ErrorCode->AxonServerCommandDispatchException, AxonServerConfigurationEnhancer->AxonServerCommandBusConnector]
# 13                                                                                                                                                                                                         [MessagingConfigurer->EventBusConfigurationDefaults, MessagingConfigurer->EventProcessingConfigurer]
# 14                                                                                     [SimpleEventHandlingComponent->SequentialPolicy, SimpleEventHandlingComponent->SequentialPerAggregatePolicy, SimpleEventHandlingComponent->HierarchicalSequencingPolicy, SimpleEventHandlingComponent->SequencingPolicy]
# 15                                  [QueryConverter->ErrorCode, QueryConverter->MetadataConverter, FlowControlledResponseSender->ErrorCode, AxonServerQueryDispatchException->ErrorCode, AxonServerQueryBusConnector->AxonServerConfiguration, AxonServerQueryBusConnector$AxonServerUpdateCallback->ErrorCode]
# 16                                                                                                    [AnnotatedEntityMetamodel->AnnotationBasedEntityEvolvingComponent, AnnotatedEntityIdResolverDefinition->AnnotationBasedEntityIdResolver, AnnotatedEntityIdResolverDefinition->EntityIdResolverDefinition]
# 17  [SingleEntityChildMetamodel->EntityMetamodel, AbstractEntityChildMetamodel->ChildEntityNotFoundException, AbstractEntityChildMetamodel->EntityMetamodel, ListEntityChildMetamodel->EntityMetamodel, SingleEntityChildMetamodel$Builder->EntityMetamodel, EntityChildMetamodel->EntityMetamodel, Abstract...
# 18  [UnitOfWork->ApplicationContext, LegacyMessageSupportingContext->Context$ResourceKey, LegacyMessageSupportingContext->Message, ResourceOverridingProcessingContext->Context$ResourceKey, ProcessingContext->Context, ProcessingContext->ApplicationContext, ProcessingContext->Context$ResourceKey, Unit...
# 19                                                                                                                                                                                                                                              [ExceptionConverter->ErrorCode, GrpcExceptionParser->ErrorCode]
# 20                                                                                                                                                                                                                    [AnnotationBasedEventSourcedEntityFactoryDefinition->EventSourcedEntityFactoryDefinition]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                  [SimpleHandlerAttributes->HandlerAttributes]
# 1                                                                                                                                                                                                                                                                       [SubscribableEventSource->EventMessage]
# 2                                                                                                                                                                                                                                                                           [HandlerTypeResolver->EventHandler]
# 3                                                                                                                                                                                                                                                                         [HandlerTypeResolver->CommandHandler]
# 4                                                                                                                                                                                                                                                                           [HandlerTypeResolver->QueryHandler]
# 5                                                                                                                                                                                                                                        [PropertyBasedEntityIdResolver->TargetEntityIdMemberMismatchException]
# 6                                                                                                                                                                                                                                                          [TransactionalUnitOfWorkFactory->TransactionManager]
# 7                                                                                                            [EventProcessorModule->PooledStreamingEventProcessorModule, EventProcessorModule->PooledStreamingEventProcessorConfiguration, EventProcessingConfigurer->PooledStreamingEventProcessorsConfigurer]
# 8                                                                                                                        [EventProcessorModule->SubscribingEventProcessorConfiguration, EventProcessorModule->SubscribingEventProcessorModule, EventProcessingConfigurer->SubscribingEventProcessorsConfigurer]
# 9                                                                                                            [FilesystemStyleComponentDescriptor->Component$Identifier, FilesystemStyleComponentDescriptor->Component, JacksonComponentDescriptor->Component, JacksonComponentDescriptor->Component$Identifier]
# 10  [AnnotatedHandlerInspector->MessageInterceptingMember, AnnotatedHandlerInspector->MessageHandlerInterceptorMemberChain, AnnotatedHandlerInspector->NoMoreInterceptors, ChainedMessageHandlerInterceptorMember->NoMoreInterceptors, ChainedMessageHandlerInterceptorMember->MessageHandlerInterceptorMemb...
# 11                                                                                                                                                                        [AxonServerConfigurationEnhancer->EventProcessorControlService, AxonServerConfigurationEnhancer->AxonServerEventStorageEngineFactory]
# 12                                                                                                                                                                                                                [CommandConverter->MetadataConverter, AxonServerCommandBusConnector->AxonServerConfiguration]
# 13                                                                                                                                                                                                                                                             [EventProcessingConfigurer->MessagingConfigurer]
# 14                                                                                                                                                                                                                       [SequentialPerAggregatePolicy->EventMessage, ExtractionSequencingPolicy->EventMessage]
# 15                                                                                [ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerRemoteQueryHandlingException, AxonServerConfigurationEnhancer->AxonServerQueryBusConnector]
# 16                                                                                                                                                                                  [AnnotationBasedEntityIdResolverDefinition->AnnotatedEntityMetamodel, EntityIdResolverDefinition->AnnotatedEntityMetamodel]
# 17  [PolymorphicEntityMetamodel$Builder->EntityChildMetamodel, EntityMetamodelBuilder->EntityChildMetamodel, PolymorphicEntityMetamodelBuilder->EntityChildMetamodel, ConcreteEntityMetamodel->EntityChildMetamodel, ConcreteEntityMetamodel->ChildAmbiguityException, ConcreteEntityMetamodel$Builder->Enti...
# 18  [DefaultMessageDispatchInterceptorChain->ProcessingContext, MessageHandlerInterceptor->ProcessingContext, DefaultMessageDispatchInterceptorChain$InterceptingDispatcher->ProcessingContext, MessageDispatchInterceptorChain->ProcessingContext, Message->ProcessingContext, MessageDispatchInterceptor->...
# 19                                                                                                                                                                                                             [AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor, ErrorCode->ExceptionConverter]
# 20                                                                                                                                                                                                                                     [EventSourcedEntity->AnnotationBasedEventSourcedEntityFactoryDefinition]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#             artifactName                                  packageName  \
# 0   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 1   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 2   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 3   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 4   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 5   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 6   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 7   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 8   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 9   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 10  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 11  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 12  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 13  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 14  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 15  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 16  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 17  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 18  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 19  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 20  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 21  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 22  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 23  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 24  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 25  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 26  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 27  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 28  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 29  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 30  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 31  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 32  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 33  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 34  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 35  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 36  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 37  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 38  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 39  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
#
#    dependentArtifactName              dependentPackageName  \
# 0   axon-messaging-5.0.3  org.axonframework.messaging.core
# 1   axon-messaging-5.0.3  org.axonframework.messaging.core
# 2   axon-messaging-5.0.3  org.axonframework.messaging.core
# 3   axon-messaging-5.0.3  org.axonframework.messaging.core
# 4   axon-messaging-5.0.3  org.axonframework.messaging.core
# 5   axon-messaging-5.0.3  org.axonframework.messaging.core
# 6   axon-messaging-5.0.3  org.axonframework.messaging.core
# 7   axon-messaging-5.0.3  org.axonframework.messaging.core
# 8   axon-messaging-5.0.3  org.axonframework.messaging.core
# 9   axon-messaging-5.0.3  org.axonframework.messaging.core
# 10  axon-messaging-5.0.3  org.axonframework.messaging.core
# 11  axon-messaging-5.0.3  org.axonframework.messaging.core
# 12  axon-messaging-5.0.3  org.axonframework.messaging.core
# 13  axon-messaging-5.0.3  org.axonframework.messaging.core
# 14  axon-messaging-5.0.3  org.axonframework.messaging.core
# 15  axon-messaging-5.0.3  org.axonframework.messaging.core
# 16  axon-messaging-5.0.3  org.axonframework.messaging.core
# 17  axon-messaging-5.0.3  org.axonframework.messaging.core
# 18  axon-messaging-5.0.3  org.axonframework.messaging.core
# 19  axon-messaging-5.0.3  org.axonframework.messaging.core
# 20  axon-messaging-5.0.3  org.axonframework.messaging.core
# 21  axon-messaging-5.0.3  org.axonframework.messaging.core
# 22  axon-messaging-5.0.3  org.axonframework.messaging.core
# 23  axon-messaging-5.0.3  org.axonframework.messaging.core
# 24  axon-messaging-5.0.3  org.axonframework.messaging.core
# 25  axon-messaging-5.0.3  org.axonframework.messaging.core
# 26  axon-messaging-5.0.3  org.axonframework.messaging.core
# 27  axon-messaging-5.0.3  org.axonframework.messaging.core
# 28  axon-messaging-5.0.3  org.axonframework.messaging.core
# 29  axon-messaging-5.0.3  org.axonframework.messaging.core
# 30  axon-messaging-5.0.3  org.axonframework.messaging.core
# 31  axon-messaging-5.0.3  org.axonframework.messaging.core
# 32  axon-messaging-5.0.3  org.axonframework.messaging.core
# 33  axon-messaging-5.0.3  org.axonframework.messaging.core
# 34  axon-messaging-5.0.3  org.axonframework.messaging.core
# 35  axon-messaging-5.0.3  org.axonframework.messaging.core
# 36  axon-messaging-5.0.3  org.axonframework.messaging.core
# 37  axon-messaging-5.0.3  org.axonframework.messaging.core
# 38  axon-messaging-5.0.3  org.axonframework.messaging.core
# 39  axon-messaging-5.0.3  org.axonframework.messaging.core
#
#                                                                                    dependency  \
# 0                                             ChainedMessageHandlerInterceptorMember->Message
# 1                                   MethodInvokingMessageHandlingMember->MessageStream$Single
# 2                                                        MessageHandlingMember->MessageStream
# 3                                       ChainedMessageHandlerInterceptorMember->MessageStream
# 4                                           AnnotatedMessageHandlingMemberDefinition->Message
# 5                                     AnnotatedMessageHandlingMemberDefinition->MessageStream
# 6                                          AnnotationMessageTypeResolver->MessageTypeResolver
# 7                                                           PayloadParameterResolver->Message
# 8                                                   DefaultParameterResolverFactory->Metadata
# 9                           DefaultParameterResolverFactory$MessageParameterResolver->Message
# 10                                          InterceptorChainParameterResolverFactory->Message
# 11  AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->Context$ResourceKey
# 12                                    InterceptorChainParameterResolverFactory->MessageStream
# 13                              InterceptorChainParameterResolverFactory->Context$ResourceKey
# 14                                                WrappedMessageHandlingMember->MessageStream
# 15                                                 AnnotationMessageTypeResolver->MessageType
# 16                               AnnotationMessageTypeResolver->ClassBasedMessageTypeResolver
# 17                                                 MessageStreamResolverUtils->GenericMessage
# 18                                                      WrappedMessageHandlingMember->Message
# 19                                                             MessageHandlingMember->Message
# 20                                                 HandlerAttributes<-SimpleHandlerAttributes
# 21                                                   DefaultParameterResolverFactory->Message
# 22                                                                    MessageHandler->Message
# 23      MessageIdentifierParameterResolverFactory$MessageIdentifierParameterResolver->Message
# 24                                            MessageStreamResolverUtils->MessageStream$Empty
# 25      AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->LegacyResources
# 26                                                         AnnotatedHandlerInspector->Message
# 27                                                      MultiHandlerDefinition->MessageStream
# 28                                                   AnnotatedHandlerInspector->MessageStream
# 29                   InterceptorChainParameterResolverFactory->MessageHandlerInterceptorChain
# 30                                           MessageStreamResolverUtils->MessageStream$Single
# 31                SourceIdParameterResolverFactory$SourceIdParameterResolver->LegacyResources
# 32                                            MessageStreamResolverUtils->MessageTypeResolver
# 33               DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Metadata
# 34                                                      MessageStreamResolverUtils->FluxUtils
# 35            SourceIdParameterResolverFactory$SourceIdParameterResolver->Context$ResourceKey
# 36                                                      MessageStreamResolverUtils->MonoUtils
# 37                                                  MessageStreamResolverUtils->MessageStream
# 38                DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Message
# 39                                   MethodInvokingMessageHandlingMember->MessageStream$Entry
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.959184             48               1
# 2                   0.959184             48               1
# 3                   0.959184             48               1
# 4                   0.959184             48               1
# 5                   0.959184             48               1
# 6                   0.959184             48               1
# 7                   0.959184             48               1
# 8                   0.959184             48               1
# 9                   0.959184             48               1
# 10                  0.959184             48               1
# 11                  0.959184             48               1
# 12                  0.959184             48               1
# 13                  0.959184             48               1
# 14                  0.959184             48               1
# 15                  0.959184             48               1
# 16                  0.959184             48               1
# 17                  0.959184             48               1
# 18                  0.959184             48               1
# 19                  0.959184             48               1
# 20                  0.959184             48               1
# 21                  0.959184             48               1
# 22                  0.959184             48               1
# 23                  0.959184             48               1
# 24                  0.959184             48               1
# 25                  0.959184             48               1
# 26                  0.959184             48               1
# 27                  0.959184             48               1
# 28                  0.959184             48               1
# 29                  0.959184             48               1
# 30                  0.959184             48               1
# 31                  0.959184             48               1
# 32                  0.959184             48               1
# 33                  0.959184             48               1
# 34                  0.959184             48               1
# 35                  0.959184             48               1
# 36                  0.959184             48               1
# 37                  0.959184             48               1
# 38                  0.959184             48               1
# 39                  0.959184             48               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9          axon-messaging-5.0.3
# 10         axon-messaging-5.0.3
# 11         axon-messaging-5.0.3
# 12         axon-messaging-5.0.3
# 13            axon-common-5.0.3
# 14            axon-common-5.0.3
# 15            axon-common-5.0.3
# 16            axon-common-5.0.3
# 17         axon-messaging-5.0.3
# 18         axon-messaging-5.0.3
# 19         axon-messaging-5.0.3
# 20         axon-messaging-5.0.3
# 21         axon-messaging-5.0.3
# 22  axon-server-connector-5.0.3
# 23  axon-server-connector-5.0.3
# 24  axon-server-connector-5.0.3
# 25  axon-server-connector-5.0.3
# 26         axon-messaging-5.0.3
# 27         axon-messaging-5.0.3
# 28         axon-messaging-5.0.3
# 29  axon-server-connector-5.0.3
# 30  axon-server-connector-5.0.3
# 31  axon-server-connector-5.0.3
# 32  axon-server-connector-5.0.3
# 33         axon-modelling-5.0.3
# 34         axon-modelling-5.0.3
# 35         axon-modelling-5.0.3
# 36         axon-modelling-5.0.3
# 37         axon-modelling-5.0.3
# 38         axon-modelling-5.0.3
# 39         axon-modelling-5.0.3
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 9   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 10       org.axonframework.messaging.eventhandling.processing.subscribing
# 11       org.axonframework.messaging.eventhandling.processing.subscribing
# 12       org.axonframework.messaging.eventhandling.processing.subscribing
# 13                                 org.axonframework.common.configuration
# 14                                 org.axonframework.common.configuration
# 15                                 org.axonframework.common.configuration
# 16                                 org.axonframework.common.configuration
# 17               org.axonframework.messaging.core.interception.annotation
# 18               org.axonframework.messaging.core.interception.annotation
# 19               org.axonframework.messaging.core.interception.annotation
# 20               org.axonframework.messaging.core.interception.annotation
# 21               org.axonframework.messaging.core.interception.annotation
# 22                           org.axonframework.axonserver.connector.event
# 23                           org.axonframework.axonserver.connector.event
# 24                                 org.axonframework.axonserver.connector
# 25                                 org.axonframework.axonserver.connector
# 26                         org.axonframework.messaging.core.configuration
# 27                              org.axonframework.messaging.eventhandling
# 28                              org.axonframework.messaging.eventhandling
# 29                           org.axonframework.axonserver.connector.query
# 30                           org.axonframework.axonserver.connector.query
# 31                           org.axonframework.axonserver.connector.query
# 32                           org.axonframework.axonserver.connector.query
# 33                          org.axonframework.modelling.entity.annotation
# 34                          org.axonframework.modelling.entity.annotation
# 35                               org.axonframework.modelling.entity.child
# 36                               org.axonframework.modelling.entity.child
# 37                               org.axonframework.modelling.entity.child
# 38                               org.axonframework.modelling.entity.child
# 39                               org.axonframework.modelling.entity.child
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9          axon-messaging-5.0.3
# 10         axon-messaging-5.0.3
# 11         axon-messaging-5.0.3
# 12         axon-messaging-5.0.3
# 13            axon-common-5.0.3
# 14            axon-common-5.0.3
# 15            axon-common-5.0.3
# 16            axon-common-5.0.3
# 17         axon-messaging-5.0.3
# 18         axon-messaging-5.0.3
# 19         axon-messaging-5.0.3
# 20         axon-messaging-5.0.3
# 21         axon-messaging-5.0.3
# 22  axon-server-connector-5.0.3
# 23  axon-server-connector-5.0.3
# 24  axon-server-connector-5.0.3
# 25  axon-server-connector-5.0.3
# 26         axon-messaging-5.0.3
# 27         axon-messaging-5.0.3
# 28         axon-messaging-5.0.3
# 29  axon-server-connector-5.0.3
# 30  axon-server-connector-5.0.3
# 31  axon-server-connector-5.0.3
# 32  axon-server-connector-5.0.3
# 33         axon-modelling-5.0.3
# 34         axon-modelling-5.0.3
# 35         axon-modelling-5.0.3
# 36         axon-modelling-5.0.3
# 37         axon-modelling-5.0.3
# 38         axon-modelling-5.0.3
# 39         axon-modelling-5.0.3
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9   org.axonframework.messaging.eventhandling.configuration
# 10  org.axonframework.messaging.eventhandling.configuration
# 11  org.axonframework.messaging.eventhandling.configuration
# 12  org.axonframework.messaging.eventhandling.configuration
# 13                           org.axonframework.common.infra
# 14                           org.axonframework.common.infra
# 15                           org.axonframework.common.infra
# 16                           org.axonframework.common.infra
# 17              org.axonframework.messaging.core.annotation
# 18              org.axonframework.messaging.core.annotation
# 19              org.axonframework.messaging.core.annotation
# 20              org.axonframework.messaging.core.annotation
# 21              org.axonframework.messaging.core.annotation
# 22                   org.axonframework.axonserver.connector
# 23                   org.axonframework.axonserver.connector
# 24           org.axonframework.axonserver.connector.command
# 25           org.axonframework.axonserver.connector.command
# 26  org.axonframework.messaging.eventhandling.configuration
# 27              org.axonframework.messaging.core.sequencing
# 28              org.axonframework.messaging.core.sequencing
# 29                   org.axonframework.axonserver.connector
# 30                   org.axonframework.axonserver.connector
# 31                   org.axonframework.axonserver.connector
# 32                   org.axonframework.axonserver.connector
# 33                   org.axonframework.modelling.annotation
# 34                   org.axonframework.modelling.annotation
# 35                       org.axonframework.modelling.entity
# 36                       org.axonframework.modelling.entity
# 37                       org.axonframework.modelling.entity
# 38                       org.axonframework.modelling.entity
# 39                       org.axonframework.modelling.entity
#
#                                                                       dependency  \
# 0                                     HandlerAttributes<-SimpleHandlerAttributes
# 1                                          EventMessage<-SubscribableEventSource
# 2                                              EventHandler<-HandlerTypeResolver
# 3                                            CommandHandler<-HandlerTypeResolver
# 4                                              QueryHandler<-HandlerTypeResolver
# 5           TargetEntityIdMemberMismatchException<-PropertyBasedEntityIdResolver
# 6                             TransactionManager<-TransactionalUnitOfWorkFactory
# 7            PooledStreamingEventProcessorsConfigurer<-EventProcessingConfigurer
# 8               PooledStreamingEventProcessorConfiguration<-EventProcessorModule
# 9                      PooledStreamingEventProcessorModule<-EventProcessorModule
# 10                  SubscribingEventProcessorConfiguration<-EventProcessorModule
# 11               SubscribingEventProcessorsConfigurer<-EventProcessingConfigurer
# 12                         SubscribingEventProcessorModule<-EventProcessorModule
# 13                              Component$Identifier<-JacksonComponentDescriptor
# 14                                         Component<-JacksonComponentDescriptor
# 15                                 Component<-FilesystemStyleComponentDescriptor
# 16                      Component$Identifier<-FilesystemStyleComponentDescriptor
# 17                    NoMoreInterceptors<-ChainedMessageHandlerInterceptorMember
# 18                                 NoMoreInterceptors<-AnnotatedHandlerInspector
# 19               MessageHandlerInterceptorMemberChain<-AnnotatedHandlerInspector
# 20                          MessageInterceptingMember<-AnnotatedHandlerInspector
# 21  MessageHandlerInterceptorMemberChain<-ChainedMessageHandlerInterceptorMember
# 22                 EventProcessorControlService<-AxonServerConfigurationEnhancer
# 23          AxonServerEventStorageEngineFactory<-AxonServerConfigurationEnhancer
# 24                                           MetadataConverter<-CommandConverter
# 25                        AxonServerConfiguration<-AxonServerCommandBusConnector
# 26                                MessagingConfigurer<-EventProcessingConfigurer
# 27                                      EventMessage<-ExtractionSequencingPolicy
# 28                                    EventMessage<-SequentialPerAggregatePolicy
# 29                             AxonServerRemoteQueryHandlingException<-ErrorCode
# 30                                   AxonServerQueryDispatchException<-ErrorCode
# 31                 AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 32                  AxonServerQueryBusConnector<-AxonServerConfigurationEnhancer
# 33                          AnnotatedEntityMetamodel<-EntityIdResolverDefinition
# 34           AnnotatedEntityMetamodel<-AnnotationBasedEntityIdResolverDefinition
# 35                      EntityChildMetamodel<-PolymorphicEntityMetamodel$Builder
# 36                                  EntityChildMetamodel<-EntityMetamodelBuilder
# 37                       EntityChildMetamodel<-PolymorphicEntityMetamodelBuilder
# 38                                 EntityChildMetamodel<-ConcreteEntityMetamodel
# 39                              ChildAmbiguityException<-ConcreteEntityMetamodel
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.931034             28               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.666667             15               3
# 10                  0.666667             15               3
# 11                  0.666667             15               3
# 12                  0.666667             15               3
# 13                  0.529412             13               4
# 14                  0.529412             13               4
# 15                  0.529412             13               4
# 16                  0.529412             13               4
# 17                  0.500000             15               5
# 18                  0.500000             15               5
# 19                  0.500000             15               5
# 20                  0.500000             15               5
# 21                  0.500000             15               5
# 22                  0.428571              5               2
# 23                  0.428571              5               2
# 24                  0.333333              4               2
# 25                  0.333333              4               2
# 26                  0.333333              2               1
# 27                  0.333333              4               2
# 28                  0.333333              4               2
# 29                  0.200000              6               4
# 30                  0.200000              6               4
# 31                  0.200000              6               4
# 32                  0.200000              6               4
# 33                  0.200000              3               2
# 34                  0.200000              3               2
# 35                  0.142857              8               6
# 36                  0.142857              8               6
# 37                  0.142857              8               6
# 38                  0.142857              8               6
# 39                  0.142857              8               6

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                                                     fullDependentTypeName  \
# 0                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                                  org.axonframework.messaging.commandhandling.CommandBus
# 2                             org.axonframework.common.configuration.ComponentDefinition$ComponentCreator
# 3                                                    org.axonframework.messaging.core.MessageStream$Entry
# 4                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 5                                                  org.axonframework.messaging.eventhandling.EventMessage
# 6                                                  org.axonframework.messaging.eventhandling.EventMessage
# 7                                                    org.axonframework.messaging.core.MessageStream$Empty
# 8                                                   org.axonframework.messaging.core.DelayedMessageStream
# 9                                                  org.axonframework.messaging.eventhandling.EventMessage
# 10                               org.axonframework.messaging.core.annotation.WrappedMessageHandlingMember
# 11                                               org.axonframework.common.configuration.AbstractComponent
# 12                                                 org.axonframework.messaging.core.unitofwork.UnitOfWork
# 13                                                     org.axonframework.test.fixture.AxonTestThenMessage
# 14                                             org.axonframework.messaging.commandhandling.CommandMessage
# 15                                             org.axonframework.messaging.commandhandling.CommandMessage
# 16                                             org.axonframework.messaging.commandhandling.CommandMessage
# 17                                                 org.axonframework.messaging.eventhandling.EventMessage
# 18                                                 org.axonframework.messaging.eventhandling.EventMessage
# 19                                              org.axonframework.messaging.eventstreaming.EventCriterion
# 20                                             org.axonframework.messaging.eventstreaming.OrEventCriteria
# 21                                             org.axonframework.modelling.entity.ConcreteEntityMetamodel
# 22                                          org.axonframework.modelling.entity.PolymorphicEntityMetamodel
# 23                                                  org.axonframework.eventsourcing.eventstore.EventStore
# 24                 org.axonframework.messaging.eventhandling.processing.streaming.token.store.ConfigToken
# 25                                                   org.axonframework.messaging.core.MessageStream$Entry
# 26                                              org.axonframework.conversion.ChainingContentTypeConverter
# 27                     org.axonframework.messaging.core.unitofwork.UnitOfWork$UnitOfWorkProcessingContext
# 28                                                    org.axonframework.messaging.core.EmptyMessageStream
# 29  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 30  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 31                                                  org.axonframework.messaging.core.DelayedMessageStream
# 32                                                  org.axonframework.messaging.core.MessageStream$Single
# 33                                                  org.axonframework.messaging.core.MessageStream$Single
# 34                                                  org.axonframework.messaging.core.MessageStream$Single
# 35                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 36                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 37                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 38                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 39                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
#
#     declaredMethods  \
# 0                32
# 1                 6
# 2                17
# 3                 7
# 4                32
# 5                19
# 6                19
# 7                44
# 8                42
# 9                19
# 10               13
# 11               24
# 12               24
# 13               22
# 14               20
# 15               19
# 16               19
# 17               19
# 18               19
# 19               12
# 20               12
# 21               11
# 22               11
# 23                9
# 24                9
# 25                7
# 26                5
# 27               45
# 28               44
# 29               43
# 30               42
# 31               42
# 32               42
# 33               42
# 34               42
# 35               37
# 36               36
# 37               35
# 38               34
# 39               33
#
#                                                                               calledMethodNames  \
# 0                                                                     [computeResourceIfAbsent]
# 1                                                                                    [dispatch]
# 2                                                                             [createComponent]
# 3                                                                                     [message]
# 4                                                                                [withResource]
# 5                                                                       [identifier, timestamp]
# 6                                                                                   [timestamp]
# 7                                                                                        [cast]
# 8                                                                                      [create]
# 9                                                                                 [andMetadata]
# 10                                                                                 [handleSync]
# 11                                                                                 [describeTo]
# 12                                                                                    [execute]
# 13                                                              [exception, exceptionSatisfies]
# 14                                                                       [priority, routingKey]
# 15                                                                       [withConvertedPayload]
# 16                                                                                [andMetadata]
# 17                                                                       [withConvertedPayload]
# 18                                                                                 [identifier]
# 19                                                                                       [tags]
# 20                                                                                         [or]
# 21                                                                             [forEntityClass]
# 22                                                                               [forSuperType]
# 23                                                                                [transaction]
# 24                                                                                        [get]
# 25                                                                                        [map]
# 26                                                              [registerConverter, canConvert]
# 27            [on, commit, whenComplete, isCommitted, isCompleted, isStarted, isError, onError]
# 28                                                                                   [instance]
# 29                                                              [hasNextAvailable, isCompleted]
# 30                                                                                   [callback]
# 31                                                                               [createSingle]
# 32                                                                        [asCompletableFuture]
# 33                                                                                       [cast]
# 34                                                                                      [first]
# 35  [updateResource, removeResource, putResourceIfAbsent, putResource, computeResourceIfAbsent]
# 36                                                    [updateResource, computeResourceIfAbsent]
# 37                                                                    [computeResourceIfAbsent]
# 38                                                                    [computeResourceIfAbsent]
# 39                                               [putResourceIfAbsent, computeResourceIfAbsent]
#
#     calledMethods  callerTypes
# 0               1            7
# 1               1            7
# 2               1            5
# 3               1            5
# 4               1            4
# 5               2            4
# 6               1            4
# 7               1            3
# 8               1            3
# 9               1            3
# 10              1            3
# 11              1            2
# 12              1            2
# 13              3            2
# 14              2            2
# 15              1            2
# 16              1            2
# 17              1            2
# 18              1            2
# 19              1            2
# 20              1            2
# 21              1            2
# 22              1            2
# 23              1            2
# 24              1            2
# 25              1            2
# 26              2            2
# 27              8            1
# 28              1            1
# 29              2            1
# 30              1            1
# 31              1            1
# 32              1            1
# 33              1            1
# 34              1            1
# 35              6            1
# 36              2            1
# 37              1            1
# 38              1            1
# 39              2            1

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                                               fullQualifiedDependentTypeName  \
# 0                              org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                               org.axonframework.common.annotation.Internal
# 2                                                   org.axonframework.messaging.core.Message
# 3                                         org.axonframework.common.infra.ComponentDescriptor
# 4                                             org.axonframework.messaging.core.MessageStream
# 5                                     org.axonframework.messaging.eventhandling.EventMessage
# 6                                               org.axonframework.messaging.core.MessageType
# 7                                             org.axonframework.messaging.core.QualifiedName
# 8                                       org.axonframework.common.configuration.Configuration
# 9                                                       org.axonframework.common.FutureUtils
# 10                                      org.axonframework.messaging.core.Context$ResourceKey
# 11                                      org.axonframework.messaging.core.MessageStream$Empty
# 12                                       org.axonframework.common.infra.DescribableComponent
# 13                                                           org.axonframework.common.Assert
# 14                                  org.axonframework.common.configuration.ComponentRegistry
# 15                                                     org.axonframework.common.BuilderUtils
# 16                                org.axonframework.messaging.commandhandling.CommandMessage
# 17                      org.axonframework.messaging.core.annotation.ParameterResolverFactory
# 18                                      org.axonframework.messaging.core.MessageStream$Entry
# 19                              org.axonframework.common.configuration.ConfigurationEnhancer
# 20                                                    org.axonframework.conversion.Converter
# 21                                     org.axonframework.messaging.core.MessageStream$Single
# 22                                      org.axonframework.messaging.core.MessageTypeResolver
# 23                              org.axonframework.messaging.core.conversion.MessageConverter
# 24                                                 org.axonframework.messaging.core.Metadata
# 25                                                      org.axonframework.common.ObjectUtils
# 26        org.axonframework.messaging.eventhandling.processing.streaming.token.TrackingToken
# 27                                       org.axonframework.common.AxonConfigurationException
# 28                                    org.axonframework.messaging.commandhandling.CommandBus
# 29                                                  org.axonframework.common.ReflectionUtils
# 30                          org.axonframework.messaging.commandhandling.CommandResultMessage
# 31                                org.axonframework.common.configuration.ComponentDefinition
# 32  org.axonframework.common.configuration.ComponentDefinition$IncompleteComponentDefinition
# 33                                                  org.axonframework.messaging.core.Context
# 34                                    org.axonframework.messaging.queryhandling.QueryMessage
# 35                                        org.axonframework.common.AxonNonTransientException
# 36                                   org.axonframework.common.configuration.ComponentBuilder
# 37                       org.axonframework.messaging.eventhandling.conversion.EventConverter
# 38                                org.axonframework.messaging.core.MessageHandlerInterceptor
# 39                             org.axonframework.messaging.core.annotation.ParameterResolver
#
#                                     dependentTypeName  \
# 0                                   ProcessingContext
# 1                                            Internal
# 2                                             Message
# 3                                 ComponentDescriptor
# 4                                       MessageStream
# 5                                        EventMessage
# 6                                         MessageType
# 7                                       QualifiedName
# 8                                       Configuration
# 9                                         FutureUtils
# 10                                Context$ResourceKey
# 11                                MessageStream$Empty
# 12                               DescribableComponent
# 13                                             Assert
# 14                                  ComponentRegistry
# 15                                       BuilderUtils
# 16                                     CommandMessage
# 17                           ParameterResolverFactory
# 18                                MessageStream$Entry
# 19                              ConfigurationEnhancer
# 20                                          Converter
# 21                               MessageStream$Single
# 22                                MessageTypeResolver
# 23                                   MessageConverter
# 24                                           Metadata
# 25                                        ObjectUtils
# 26                                      TrackingToken
# 27                         AxonConfigurationException
# 28                                         CommandBus
# 29                                    ReflectionUtils
# 30                               CommandResultMessage
# 31                                ComponentDefinition
# 32  ComponentDefinition$IncompleteComponentDefinition
# 33                                            Context
# 34                                       QueryMessage
# 35                          AxonNonTransientException
# 36                                   ComponentBuilder
# 37                                     EventConverter
# 38                          MessageHandlerInterceptor
# 39                                  ParameterResolver
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 1   [Type, File, Java, ByteCode, Annotation, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent...
# 2   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 3   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 4   [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWea...
# 5   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponen...
# 6   [Type, File, Java, ByteCode, Record, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 7   [Type, File, Java, ByteCode, Record, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4T...
# 8   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity6...
# 9   [Type, File, Java, Class, ByteCode, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity12, Mark...
# 10  [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyCon...
# 11  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity9, Mark4TypeKC...
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 13  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecompositi...
# 14                                    [Type, File, Java, ByteCode, Interface, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation13, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut17, Mark4TypeHDBSCAN-1]
# 15                                                     [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut81, Mark4TypeHDBSCAN51, Mark4TopAnomalyHub]
# 16  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity3, ...
# 17                                                                  [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation22, Mark4TypeLouvainCommunity13, Mark4TypeLeidenCommunity13, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut12, Mark4TypeHDBSCAN-1]
# 18  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity8, Mark4Ty...
# 19                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation17, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut88, Mark4TypeHDBSCAN-1]
# 20  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecompo...
# 21  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark...
# 22  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10, ...
# 23             [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut64, Mark4TypeLocalClusteringCoefficient0.11333333333333333, Mark4TypeHDBSCAN-1]
# 24  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut0, Mar...
# 25                                                                          [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN63]
# 26  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation39, Mark4TypeLouvainCommunity1...
# 27                             [Type, File, Java, Class, ByteCode, Throwable, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation27, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity13, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut76, Mark4TypeHDBSCAN-1]
# 28                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut30, Mark4TypeHDBSCAN-1]
# 29  [Type, File, Java, Class, ByteCode, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation19, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity13, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut34, Mark4TypeHDBSCAN53, Mark4TopAnomalyBottleneck, Mark4To...
# 30  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10, ...
# 31                                              [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut83, Mark4TypeHDBSCAN-1]
# 32                                              [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut42, Mark4TypeHDBSCAN17]
# 33  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCo...
# 34  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10, ...
# 35  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation2, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition4, Mark4TypeMaximumKCut91, Mark4TypeLocalClusteringCoef...
# 36                                               [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation13, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut75, Mark4TypeHDBSCAN81]
# 37                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut86, Mark4TypeHDBSCAN-1]
# 38  [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation8, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKC...
# 39                                                [Type, File, Java, ByteCode, GenericDeclaration, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity13, Mark4TypeKCoreDecomposition7, Mark4TypeMaximumKCut46, Mark4TypeHDBSCAN27]
#
#     numberOfUsingPackages
# 0                      59
# 1                      55
# 2                      47
# 3                      46
# 4                      36
# 5                      35
# 6                      31
# 7                      30
# 8                      29
# 9                      28
# 10                     25
# 11                     25
# 12                     24
# 13                     22
# 14                     22
# 15                     21
# 16                     20
# 17                     20
# 18                     19
# 19                     18
# 20                     18
# 21                     18
# 22                     18
# 23                     17
# 24                     16
# 25                     16
# 26                     15
# 27                     14
# 28                     13
# 29                     13
# 30                     12
# 31                     12
# 32                     12
# 33                     12
# 34                     12
# 35                     11
# 36                     11
# 37                     11
# 38                     11
# 39                     11

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                             artifactName  \
# 0       axon-tracing-opentelemetry-5.0.3
# 1       axon-tracing-opentelemetry-5.0.3
# 2          axon-metrics-micrometer-5.0.3
# 3          axon-metrics-micrometer-5.0.3
# 4                        axon-test-5.0.3
# 5            axon-server-connector-5.0.3
# 6            axon-server-connector-5.0.3
# 7          axon-metrics-micrometer-5.0.3
# 8                        axon-test-5.0.3
# 9   axon-spring-boot-autoconfigure-5.0.3
# 10              axon-eventsourcing-5.0.3
# 11                 axon-conversion-5.0.3
# 12                  axon-modelling-5.0.3
# 13                 axon-conversion-5.0.3
# 14  axon-spring-boot-autoconfigure-5.0.3
# 15                     axon-update-5.0.3
# 16                  axon-modelling-5.0.3
# 17                       axon-test-5.0.3
# 18           axon-server-connector-5.0.3
# 19              axon-eventsourcing-5.0.3
# 20  axon-spring-boot-autoconfigure-5.0.3
# 21  axon-spring-boot-autoconfigure-5.0.3
# 22  axon-spring-boot-autoconfigure-5.0.3
# 23                  axon-modelling-5.0.3
# 24           axon-server-connector-5.0.3
# 25                  axon-messaging-5.0.3
# 26              axon-eventsourcing-5.0.3
# 27                     axon-common-5.0.3
# 28  axon-spring-boot-autoconfigure-5.0.3
# 29         axon-metrics-micrometer-5.0.3
#
#                    dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-5.0.3                  2
# 1                      axon-common-5.0.3                  1
# 2                   axon-messaging-5.0.3                  7
# 3                      axon-common-5.0.3                  2
# 4               axon-eventsourcing-5.0.3                  1
# 5                   axon-modelling-5.0.3                  1
# 6               axon-eventsourcing-5.0.3                  1
# 7   axon-spring-boot-autoconfigure-5.0.3                  1
# 8                   axon-messaging-5.0.3                  9
# 9                        axon-test-5.0.3                  1
# 10                 axon-conversion-5.0.3                  1
# 11                 axon-conversion-5.0.3                  1
# 12                 axon-conversion-5.0.3                  1
# 13                     axon-common-5.0.3                  3
# 14           axon-server-connector-5.0.3                  1
# 15                     axon-common-5.0.3                  3
# 16                  axon-messaging-5.0.3                 13
# 17                     axon-common-5.0.3                  4
# 18                  axon-messaging-5.0.3                 16
# 19                  axon-messaging-5.0.3                 16
# 20                  axon-messaging-5.0.3                 16
# 21              axon-eventsourcing-5.0.3                  2
# 22                     axon-common-5.0.3                  5
# 23                     axon-common-5.0.3                  5
# 24                     axon-common-5.0.3                  6
# 25                 axon-conversion-5.0.3                  2
# 26                     axon-common-5.0.3                  8
# 27                     axon-common-5.0.3                  8
# 28                     axon-update-5.0.3                  3
# 29         axon-metrics-micrometer-5.0.3                  2
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          59                0.033898
# 1                          15                0.066667
# 2                          59                0.118644
# 3                          15                0.133333
# 4                           7                0.142857
# 5                           7                0.142857
# 6                           7                0.142857
# 7                           7                0.142857
# 8                          59                0.152542
# 9                           6                0.166667
# 10                          5                0.200000
# 11                          5                0.200000
# 12                          5                0.200000
# 13                         15                0.200000
# 14                          5                0.200000
# 15                         15                0.200000
# 16                         59                0.220339
# 17                         15                0.266667
# 18                         59                0.271186
# 19                         59                0.271186
# 20                         59                0.271186
# 21                          7                0.285714
# 22                         15                0.333333
# 23                         15                0.333333
# 24                         15                0.400000
# 25                          5                0.400000
# 26                         15                0.533333
# 27                         15                0.533333
# 28                          5                0.600000
# 29                          3                0.666667
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                                       [org.axonframework.messaging.core, org.axonframework.messaging.tracing]
# 1                                                                                                                                                                                                                                                                                    [org.axonframework.common]
# 2   [org.axonframework.messaging.commandhandling, org.axonframework.messaging.core, org.axonframework.messaging.eventhandling, org.axonframework.messaging.queryhandling, org.axonframework.messaging.monitoring, org.axonframework.messaging.eventhandling.processing, org.axonframework.messaging.monitori...
# 3                                                                                                                                                                                                                                            [org.axonframework.common.configuration, org.axonframework.common]
# 4                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 5                                                                                                                                                                                                                                                                                 [org.axonframework.modelling]
# 6                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 7                                                                                                                                                                                                                                                           [org.axonframework.extension.springboot.autoconfig]
# 8   [org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.core, org.axonframework.messaging.monitoring, org.axonframework.messaging.commandhandling, org.axonframework.messaging.core.annotation, org.axonframework.messaging.eventhandling, org.axonframework.messaging.eventhandling.p...
# 9                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 10                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 11                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 12                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 13                                                                                                                                                                                                              [org.axonframework.common, org.axonframework.common.infra, org.axonframework.common.annotation]
# 14                                                                                                                                                                                                                                                                     [org.axonframework.axonserver.connector]
# 15                                                                                                                                                                                                      [org.axonframework.common.annotation, org.axonframework.common, org.axonframework.common.configuration]
# 16  [org.axonframework.messaging.queryhandling.configuration, org.axonframework.messaging.core.configuration, org.axonframework.messaging.commandhandling.configuration, org.axonframework.messaging.commandhandling, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core, org.axonf...
# 17                                                                                                                                                                      [org.axonframework.common, org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common.configuration]
# 18  [org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.eventhandling.processing.streaming.token, org.axonframework.messaging.eventhandling.processing, org.axonframework.messaging.eventhandling.conversion, org.axonframework.messaging.eventstreaming, org.axonframework.messaging....
# 19  [org.axonframework.messaging.core.configuration, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core.interception, org.axonframework.messaging.commandhandling, org.axonframework.messaging.core.annotation, org.axonframework.messaging.eventhandling.conversion, org.axonframe...
# 20  [org.axonframework.messaging.core.annotation, org.axonframework.messaging.commandhandling.distributed, org.axonframework.messaging.core.interception, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa, org.axonframework.messaging.queryhandling.distributed, org.axonfra...
# 21                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.eventstore]
# 22                                                                                                                                         [org.axonframework.common, org.axonframework.common.jdbc, org.axonframework.common.jpa, org.axonframework.common.configuration, org.axonframework.common.annotation]
# 23                                                                                                                                   [org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common.property]
# 24                                                                                                   [org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common, org.axonframework.common.lifecycle, org.axonframework.common.util]
# 25                                                                                                                                                                                                                                         [org.axonframework.conversion, org.axonframework.conversion.jackson]
# 26                                               [org.axonframework.common, org.axonframework.common.annotation, org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.tx, org.axonframework.common.jpa, org.axonframework.common.jdbc, org.axonframework.common.io]
# 27                                     [org.axonframework.common.infra, org.axonframework.common.lifecycle, org.axonframework.common.annotation, org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.tx, org.axonframework.common.function, org.axonframework.common.io]
# 28                                                                                                                                                                                                       [org.axonframework.update.detection, org.axonframework.update.configuration, org.axonframework.update]
# 29                                                                                                                                                                                                   [org.axonframework.extension.metrics.micrometer, org.axonframework.extension.metrics.micrometer.reservoir]
#
#                                                                                                                                                        dependentPackageNames
# 0                                                                                                                                                            [core, tracing]
# 1                                                                                                                                                                   [common]
# 2                                                                               [commandhandling, core, eventhandling, queryhandling, monitoring, processing, configuration]
# 3                                                                                                                                                    [configuration, common]
# 4                                                                                                                                                               [eventstore]
# 5                                                                                                                                                                [modelling]
# 6                                                                                                                                                               [eventstore]
# 7                                                                                                                                                               [autoconfig]
# 8                                                              [unitofwork, core, monitoring, commandhandling, annotation, eventhandling, token, conversion, eventstreaming]
# 9                                                                                                                                                                   [server]
# 10                                                                                                                                                              [conversion]
# 11                                                                                                                                                              [conversion]
# 12                                                                                                                                                              [conversion]
# 13                                                                                                                                               [common, infra, annotation]
# 14                                                                                                                                                               [connector]
# 15                                                                                                                                       [annotation, common, configuration]
# 16                                                                     [configuration, commandhandling, eventhandling, core, unitofwork, annotation, conversion, reflection]
# 17                                                                                                                                [common, infra, annotation, configuration]
# 18  [unitofwork, token, processing, conversion, eventstreaming, streaming, subscribing, store, segmenting, core, eventhandling, distributed, queryhandling, commandhandling]
# 19                               [configuration, eventhandling, interception, commandhandling, annotation, conversion, core, token, eventstreaming, unitofwork, transaction]
# 20                   [annotation, distributed, interception, jpa, conversion, timeout, store, core, eventhandling, transaction, correlation, queryhandling, commandhandling]
# 21                                                                                                                                                         [jpa, eventstore]
# 22                                                                                                                            [common, jdbc, jpa, configuration, annotation]
# 23                                                                                                                      [common, configuration, infra, annotation, property]
# 24                                                                                                               [configuration, infra, annotation, common, lifecycle, util]
# 25                                                                                                                                                     [conversion, jackson]
# 26                                                                                                             [common, annotation, configuration, infra, tx, jpa, jdbc, io]
# 27                                                                                                   [infra, lifecycle, annotation, common, configuration, tx, function, io]
# 28                                                                                                                                        [detection, configuration, update]
# 29                                                                                                                                                   [micrometer, reservoir]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                             artifactName  \
# 0               axon-eventsourcing-5.0.3
# 1                        axon-test-5.0.3
# 2                   axon-modelling-5.0.3
# 3               axon-eventsourcing-5.0.3
# 4               axon-eventsourcing-5.0.3
# 5                   axon-messaging-5.0.3
# 6                   axon-messaging-5.0.3
# 7                   axon-modelling-5.0.3
# 8               axon-eventsourcing-5.0.3
# 9          axon-metrics-micrometer-5.0.3
# 10      axon-tracing-opentelemetry-5.0.3
# 11  axon-spring-boot-autoconfigure-5.0.3
# 12                     axon-update-5.0.3
# 13                  axon-messaging-5.0.3
# 14                  axon-messaging-5.0.3
# 15                 axon-conversion-5.0.3
# 16                  axon-messaging-5.0.3
# 17                       axon-test-5.0.3
# 18                  axon-messaging-5.0.3
# 19                  axon-messaging-5.0.3
# 20                  axon-messaging-5.0.3
# 21                  axon-messaging-5.0.3
# 22                       axon-test-5.0.3
# 23                  axon-messaging-5.0.3
# 24                  axon-messaging-5.0.3
# 25                  axon-messaging-5.0.3
# 26                  axon-messaging-5.0.3
# 27                       axon-test-5.0.3
# 28                  axon-messaging-5.0.3
# 29      axon-tracing-opentelemetry-5.0.3
#
#                    dependentArtifactName  \
# 0                   axon-messaging-5.0.3
# 1                   axon-messaging-5.0.3
# 2                   axon-messaging-5.0.3
# 3                   axon-messaging-5.0.3
# 4                      axon-common-5.0.3
# 5                      axon-common-5.0.3
# 6                      axon-common-5.0.3
# 7                      axon-common-5.0.3
# 8                      axon-common-5.0.3
# 9   axon-spring-boot-autoconfigure-5.0.3
# 10                  axon-messaging-5.0.3
# 11                     axon-common-5.0.3
# 12                     axon-common-5.0.3
# 13                     axon-common-5.0.3
# 14                     axon-common-5.0.3
# 15                     axon-common-5.0.3
# 16                     axon-common-5.0.3
# 17                     axon-common-5.0.3
# 18                     axon-common-5.0.3
# 19                     axon-common-5.0.3
# 20                     axon-common-5.0.3
# 21                     axon-common-5.0.3
# 22                     axon-common-5.0.3
# 23                     axon-common-5.0.3
# 24                     axon-common-5.0.3
# 25                     axon-common-5.0.3
# 26                     axon-common-5.0.3
# 27                     axon-common-5.0.3
# 28                     axon-common-5.0.3
# 29                     axon-common-5.0.3
#
#                                                   packageName  \
# 0               org.axonframework.eventsourcing.configuration
# 1                             org.axonframework.test.matchers
# 2                      org.axonframework.modelling.repository
# 3               org.axonframework.eventsourcing.configuration
# 4                  org.axonframework.eventsourcing.annotation
# 5                            org.axonframework.messaging.core
# 6                 org.axonframework.messaging.core.unitofwork
# 7               org.axonframework.modelling.entity.annotation
# 8       org.axonframework.eventsourcing.annotation.reflection
# 9   org.axonframework.extension.metrics.micrometer.springboot
# 10          org.axonframework.extension.tracing.opentelemetry
# 11          org.axonframework.extension.springboot.autoconfig
# 12                                   org.axonframework.update
# 13                     org.axonframework.messaging.monitoring
# 14   org.axonframework.messaging.core.interception.annotation
# 15                          org.axonframework.conversion.avro
# 16     org.axonframework.messaging.core.unitofwork.annotation
# 17                                org.axonframework.test.util
# 18          org.axonframework.messaging.queryhandling.tracing
# 19  org.axonframework.messaging.core.configuration.reflection
# 20                 org.axonframework.messaging.eventstreaming
# 21       org.axonframework.messaging.eventhandling.processing
# 22                           org.axonframework.test.extension
# 23          org.axonframework.messaging.eventhandling.tracing
# 24        org.axonframework.messaging.commandhandling.tracing
# 25                org.axonframework.messaging.core.sequencing
# 26                   org.axonframework.messaging.core.timeout
# 27                              org.axonframework.test.server
# 28       org.axonframework.messaging.monitoring.configuration
# 29          org.axonframework.extension.tracing.opentelemetry
#
#                                  dependentPackage.fqn  dependentTypes  \
# 0                    org.axonframework.messaging.core               1
# 1                    org.axonframework.messaging.core               1
# 2                    org.axonframework.messaging.core               1
# 3         org.axonframework.messaging.core.annotation               1
# 4              org.axonframework.common.configuration               1
# 5              org.axonframework.common.configuration               1
# 6              org.axonframework.common.configuration               1
# 7              org.axonframework.common.configuration               1
# 8              org.axonframework.common.configuration               1
# 9   org.axonframework.extension.springboot.autoconfig               1
# 10                   org.axonframework.messaging.core               2
# 11                           org.axonframework.common               1
# 12                           org.axonframework.common               1
# 13                           org.axonframework.common               1
# 14                           org.axonframework.common               1
# 15                           org.axonframework.common               1
# 16                           org.axonframework.common               1
# 17                           org.axonframework.common               1
# 18                           org.axonframework.common               1
# 19                           org.axonframework.common               1
# 20                           org.axonframework.common               1
# 21                           org.axonframework.common               1
# 22                           org.axonframework.common               1
# 23                           org.axonframework.common               1
# 24                           org.axonframework.common               1
# 25                           org.axonframework.common               1
# 26                           org.axonframework.common               1
# 27                           org.axonframework.common               1
# 28                           org.axonframework.common               1
# 29                           org.axonframework.common               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      80             0.012500
# 1                      80             0.012500
# 2                      80             0.012500
# 3                      51             0.019608
# 4                      46             0.021739
# 5                      46             0.021739
# 6                      46             0.021739
# 7                      46             0.021739
# 8                      46             0.021739
# 9                      41             0.024390
# 10                     80             0.025000
# 11                     34             0.029412
# 12                     34             0.029412
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     34             0.029412
# 17                     34             0.029412
# 18                     34             0.029412
# 19                     34             0.029412
# 20                     34             0.029412
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                     34             0.029412
# 26                     34             0.029412
# 27                     34             0.029412
# 28                     34             0.029412
# 29                     34             0.029412
#
#                                                                        dependentTypeNames
# 0                                  [org.axonframework.messaging.core.MessageTypeResolver]
# 1                                              [org.axonframework.messaging.core.Message]
# 2                                  [org.axonframework.messaging.core.Context$ResourceKey]
# 3                  [org.axonframework.messaging.core.annotation.ParameterResolverFactory]
# 4                                  [org.axonframework.common.configuration.Configuration]
# 5                                  [org.axonframework.common.configuration.Configuration]
# 6                     [org.axonframework.common.configuration.ComponentNotFoundException]
# 7                                  [org.axonframework.common.configuration.Configuration]
# 8                                  [org.axonframework.common.configuration.Configuration]
# 9               [org.axonframework.extension.springboot.autoconfig.AxonAutoConfiguration]
# 10  [org.axonframework.messaging.core.Metadata, org.axonframework.messaging.core.Message]
# 11                                  [org.axonframework.common.AxonConfigurationException]
# 12                                                 [org.axonframework.common.ObjectUtils]
# 13                                                      [org.axonframework.common.Assert]
# 14                                  [org.axonframework.common.AxonConfigurationException]
# 15                                                [org.axonframework.common.BuilderUtils]
# 16                                                    [org.axonframework.common.Priority]
# 17                                                 [org.axonframework.common.ObjectUtils]
# 18                                                [org.axonframework.common.BuilderUtils]
# 19                                                    [org.axonframework.common.Priority]
# 20                                                      [org.axonframework.common.Assert]
# 21                                               [org.axonframework.common.AxonException]
# 22                                             [org.axonframework.common.ReflectionUtils]
# 23                                                [org.axonframework.common.BuilderUtils]
# 24                                                [org.axonframework.common.BuilderUtils]
# 25                                                [org.axonframework.common.BuilderUtils]
# 26                                           [org.axonframework.common.AxonThreadFactory]
# 27                                                      [org.axonframework.common.Assert]
# 28                                               [org.axonframework.common.TypeReference]
# 29                                                [org.axonframework.common.BuilderUtils]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                  jakarta.annotation.Nonnull
# 1                                                  jakarta.annotation.Nonnull
# 2                                                 jakarta.annotation.Nullable
# 3                                                 jakarta.annotation.Nullable
# 4                                org.axonframework.common.annotation.Internal
# 5                                                  jakarta.annotation.Nonnull
# 6                                               java.lang.FunctionalInterface
# 7                                 org.springframework.context.annotation.Bean
# 8                                              java.lang.annotation.Retention
# 9                                                 java.lang.annotation.Target
# 10  org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 11                   org.springframework.boot.autoconfigure.AutoConfiguration
# 12                               org.axonframework.common.annotation.Internal
# 13                               org.axonframework.common.annotation.Internal
# 14                                            java.lang.annotation.Documented
# 15                              com.fasterxml.jackson.annotation.JsonProperty
# 16     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 17                                          org.axonframework.common.Priority
# 18  org.springframework.boot.context.properties.EnableConfigurationProperties
# 19                               org.axonframework.common.annotation.Internal
# 20        org.springframework.boot.context.properties.ConfigurationProperties
# 21        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 22     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 23                                                  jakarta.persistence.Basic
# 24                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 25    org.springframework.boot.context.properties.NestedConfigurationProperty
# 26                                                      java.lang.SafeVarargs
# 27                         org.springframework.context.annotation.Conditional
# 28                                                       java.lang.Deprecated
# 29                                           java.beans.ConstructorProperties
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       3497
# 1           Method                        865
# 2        Parameter                        395
# 3           Method                        112
# 4            Class                         83
# 5            Field                         72
# 6        Interface                         59
# 7           Method                         45
# 8       Annotation                         42
# 9       Annotation                         42
# 10          Method                         23
# 11           Class                         21
# 12       Interface                         18
# 13     Constructor                         17
# 14      Annotation                         15
# 15       Parameter                         12
# 16           Class                         12
# 17           Class                         12
# 18           Class                         11
# 19          Method                         11
# 20           Class                         10
# 21           Class                          9
# 22          Method                          8
# 23           Field                          8
# 24           Class                          8
# 25           Field                          8
# 26     Constructor                          7
# 27          Method                          7
# 28          Method                          7
# 29     Constructor                          6
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.conversion.ChainedConverter.calculateChain(0), org.axonframework.conversion.ChainedConverter.calculateChain(1), org.axonframework.conversion.ChainedConverter.calculateChain(2), org.axonframework.conversion.ChainedConverter.canConvert(0), org.axonframework.conversion.ChainedCon...
# 1   [org.axonframework.conversion.ContentTypeConverter.expectedSourceType, org.axonframework.conversion.ContentTypeConverter.targetType, org.axonframework.conversion.ChainedConverter.expectedSourceType, org.axonframework.conversion.ChainedConverter.targetType, org.axonframework.conversion.jackson.Js...
# 2   [org.axonframework.conversion.ChainedConverter.convert(0), org.axonframework.conversion.Converter.convert(0), org.axonframework.conversion.jackson.JsonNodeToByteArrayConverter.convert(0), org.axonframework.conversion.jackson.ObjectNodeToJsonNodeConverter.convert(0), org.axonframework.conversion....
# 3   [org.axonframework.conversion.ChainedConverter.convert, org.axonframework.conversion.ContentTypeConverter.convert, org.axonframework.conversion.Converter.convert, org.axonframework.conversion.jackson.JsonNodeToByteArrayConverter.convert, org.axonframework.conversion.jackson.ObjectNodeToJsonNodeC...
# 4   [org.axonframework.messaging.monitoring.configuration.DefaultMessageMonitorRegistry, org.axonframework.messaging.commandhandling.distributed.DistributedCommandBusConfigurationEnhancer, org.axonframework.messaging.commandhandling.annotation.CommandDispatcherParameterResolverFactory, org.axonframe...
# 5   [org.axonframework.conversion.avro.AvroConverterConfiguration.strategies, org.axonframework.conversion.avro.AvroConverterConfiguration.schemaStore, org.axonframework.conversion.avro.AvroConverterConfiguration.schemaIncompatibilityChecker, org.axonframework.conversion.avro.AvroConverterConfigurat...
# 6   [org.axonframework.messaging.monitoring.configuration.MessageMonitorFactory, org.axonframework.messaging.commandhandling.distributed.CommandBusConnector$Handler, org.axonframework.messaging.commandhandling.CommandHandler, org.axonframework.messaging.commandhandling.CommandPriorityCalculator, org...
# 7   [org.axonframework.extension.springboot.autoconfig.UpdateCheckerAutoConfiguration.springUpdateCheckerConfigEnhancer, org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration.axonTransactionManager, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfigu...
# 8   [org.axonframework.messaging.commandhandling.annotation.CommandHandler, org.axonframework.messaging.commandhandling.annotation.Command, org.axonframework.messaging.eventhandling.annotation.EventHandler, org.axonframework.messaging.eventhandling.annotation.SequenceNumber, org.axonframework.messag...
# 9   [org.axonframework.messaging.commandhandling.annotation.CommandHandler, org.axonframework.messaging.commandhandling.annotation.Command, org.axonframework.messaging.eventhandling.annotation.EventHandler, org.axonframework.messaging.eventhandling.annotation.SequenceNumber, org.axonframework.messag...
# 10  [org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration.axonTransactionManager, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration.defaultAxonJackson2Mapper, org.axonframework.extension.springboot.autoconfig.JpaAutoConfiguration.entityMa...
# 11  [org.axonframework.extension.springboot.autoconfig.UpdateCheckerAutoConfiguration, org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig...
# 12  [org.axonframework.messaging.monitoring.configuration.MessageMonitorRegistry, org.axonframework.messaging.commandhandling.annotation.CommandHandlingMember, org.axonframework.messaging.eventhandling.annotation.EventHandlingMember, org.axonframework.messaging.queryhandling.annotation.QueryHandling...
# 13  [org.axonframework.conversion.jackson.JacksonConverter.<init>, org.axonframework.conversion.jackson2.Jackson2Converter.<init>, org.axonframework.conversion.avro.AvroConverter.<init>, org.axonframework.messaging.eventhandling.processing.streaming.pooled.PooledStreamingEventProcessorConfiguration....
# 14  [org.axonframework.messaging.commandhandling.annotation.CommandHandler, org.axonframework.messaging.eventhandling.annotation.EventHandler, org.axonframework.messaging.eventhandling.replay.annotation.AllowReplay, org.axonframework.messaging.eventhandling.replay.annotation.DisallowReplay, org.axon...
# 15  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(0), org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(1), org.axonframework.messaging.eventhandling.processing.streaming.token.ReplayToken.<init>(0),...
# 16  [org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration$JacksonConfiguredCondition$EventsJacksonCondition, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration$JacksonConfiguredCondition$GeneralDefaultCondition, org.axonframework.extension....
# 17  [org.axonframework.messaging.eventhandling.annotation.SequenceNumberParameterResolverFactory, org.axonframework.messaging.eventhandling.annotation.TimestampParameterResolverFactory, org.axonframework.messaging.core.annotation.SimpleResourceParameterResolverFactory, org.axonframework.messaging.co...
# 18  [org.axonframework.extension.springboot.autoconfig.UpdateCheckerAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extension.springboot.autoconfig....
# 19  [org.axonframework.messaging.eventhandling.conversion.DelegatingEventConverter.delegate, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa.JpaTokenStore.converter, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jdbc.JdbcTokenStore.converte...
# 20  [org.axonframework.extension.springboot.DistributedCommandBusProperties, org.axonframework.extension.springboot.TokenStoreProperties, org.axonframework.extension.springboot.TagsConfigurationProperties, org.axonframework.extension.springboot.TimeoutProperties, org.axonframework.extension.springbo...
# 21  [org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extension.springboot.autoconfig.CBORMapperAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration, org.axonframework.extension.springboot.autoconfig...
# 22  [org.axonframework.extension.springboot.autoconfig.AxonServerAutoConfiguration.disableAxonServerConfigurationEnhancer, org.axonframework.extension.springboot.autoconfig.AxonServerAutoConfiguration.axonServerConfigurationEnhancer, org.axonframework.extension.springboot.autoconfig.AxonServerAutoCo...
# 23  [org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa.TokenEntry.tokenType, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa.TokenEntry.timestamp, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa.TokenEntry.own...
# 24  [org.axonframework.extension.springboot.autoconfig.CorrelationDataProviderAutoConfiguration, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extension.springboot.autoconfig.CBORMapperAutoConfiguration, org.axonframework.extension.springboot.au...
# 25  [org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.events, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.commands, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.queries, o...
# 26  [org.axonframework.messaging.monitoring.MultiMessageMonitor.<init>, org.axonframework.messaging.core.retry.NonTransientExceptionClassesPredicate.<init>, org.axonframework.test.matchers.SequenceMatcher.<init>, org.axonframework.test.matchers.ListMatcher.<init>, org.axonframework.test.matchers.Exa...
# 27  [org.axonframework.extension.springboot.autoconfig.UpdateCheckerAutoConfiguration.springUpdateCheckerConfigEnhancer, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration.defaultAxonJackson2Mapper, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoC...
# 28  [org.axonframework.messaging.core.GenericResultMessage.asResultMessage, org.axonframework.messaging.core.annotation.MessageHandlingMember.handleSync, org.axonframework.messaging.core.interception.annotation.MessageHandlerInterceptorMemberChain.handleSync, org.axonframework.messaging.core.interce...
# 29  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.ReplayToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.store.ConfigToken.<init>, org.axonfram...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2125                      881                          921
# 1                   100                       86                           41
# 2                  2138                      631                          420
# 3                  2104                      679                          322
#
#                                                                                                                                                                                                                                                                                                       examples
# 0                                             [/axon-eventsourcing-5.0.3.jar uses /axon-conversion-5.0.3.jar, /axon-spring-boot-autoconfigure-5.0.3.jar uses /axon-conversion-5.0.3.jar, /axon-messaging-5.0.3.jar uses /axon-conversion-5.0.3.jar, /axon-modelling-5.0.3.jar uses /axon-conversion-5.0.3.jar]
# 1     [/org/axonframework/conversion/jackson2 uses /org/axonframework/conversion, /org/axonframework/conversion/avro uses /org/axonframework/conversion, /org/axonframework/conversion/jackson uses /org/axonframework/conversion, /org/axonframework/conversion/converter uses /org/axonframework/conversion]
# 2  [/org/axonframework/conversion/avro/AvroConverter.class uses /org/axonframework/conversion/ChainingContentTypeConverter.class, /org/axonframework/conversion/jackson/JacksonConverter.class uses /org/axonframework/conversion/ChainingContentTypeConverter.class, /org/axonframework/conversion/jackson...
# 3  [/org/axonframework/messaging/eventhandling/conversion uses /org/axonframework/conversion, /org/axonframework/messaging/core/configuration uses /org/axonframework/conversion, /org/axonframework/messaging/commandhandling/gateway uses /org/axonframework/conversion, /org/axonframework/messaging/eve...
