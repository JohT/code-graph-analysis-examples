# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.3.jar        59    579
# 1                      axon-common-5.0.3.jar        15    156
# 2               axon-eventsourcing-5.0.3.jar         7    100
# 3                   axon-modelling-5.0.3.jar         7     92
# 4   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 5                        axon-test-5.0.3.jar         6     78
# 6                  axon-conversion-5.0.3.jar         5     35
# 7            axon-server-connector-5.0.3.jar         5     72
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      1                     7
# 5                      1                     3
# 6                      4                     1
# 7                      1                     4
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.3.jar        59    579
# 1                      axon-common-5.0.3.jar        15    156
# 2               axon-eventsourcing-5.0.3.jar         7    100
# 3                   axon-modelling-5.0.3.jar         7     92
# 4                        axon-test-5.0.3.jar         6     78
# 5   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 6            axon-server-connector-5.0.3.jar         5     72
# 7                  axon-conversion-5.0.3.jar         5     35
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      1                     3
# 5                      1                     7
# 6                      1                     4
# 7                      4                     1
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.3.jar        15    156
# 1                   axon-messaging-5.0.3.jar        59    579
# 2                  axon-conversion-5.0.3.jar         5     35
# 3               axon-eventsourcing-5.0.3.jar         7    100
# 4                   axon-modelling-5.0.3.jar         7     92
# 5            axon-server-connector-5.0.3.jar         5     72
# 6   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 7                        axon-test-5.0.3.jar         6     78
# 8                      axon-update-5.0.3.jar         5     23
# 9          axon-metrics-micrometer-5.0.3.jar         3     16
# 10      axon-tracing-opentelemetry-5.0.3.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      7                     2
# 2                      4                     1
# 3                      3                     4
# 4                      2                     3
# 5                      1                     4
# 6                      1                     7
# 7                      1                     3
# 8                      1                     1
# 9                      0                     3
# 10                     0                     2

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 1               axon-eventsourcing-5.0.3.jar         7    100
# 2            axon-server-connector-5.0.3.jar         5     72
# 3          axon-metrics-micrometer-5.0.3.jar         3     16
# 4                   axon-modelling-5.0.3.jar         7     92
# 5                        axon-test-5.0.3.jar         6     78
# 6                   axon-messaging-5.0.3.jar        59    579
# 7       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 8                  axon-conversion-5.0.3.jar         5     35
# 9                      axon-update-5.0.3.jar         5     23
# 10                     axon-common-5.0.3.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      1                     7
# 1                      3                     4
# 2                      1                     4
# 3                      0                     3
# 4                      2                     3
# 5                      1                     3
# 6                      7                     2
# 7                      0                     2
# 8                      4                     1
# 9                      1                     1
# 10                    10                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 1          axon-metrics-micrometer-5.0.3.jar         3     16
# 2                  axon-conversion-5.0.3.jar         5     35
# 3            axon-server-connector-5.0.3.jar         5     72
# 4                      axon-update-5.0.3.jar         5     23
# 5                        axon-test-5.0.3.jar         6     78
# 6               axon-eventsourcing-5.0.3.jar         7    100
# 7                   axon-modelling-5.0.3.jar         7     92
# 8   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 9                      axon-common-5.0.3.jar        15    156
# 10                  axon-messaging-5.0.3.jar        59    579
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     3
# 2                      4                     1
# 3                      1                     4
# 4                      1                     1
# 5                      1                     3
# 6                      3                     4
# 7                      2                     3
# 8                      1                     7
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 1          axon-metrics-micrometer-5.0.3.jar         3     16
# 2                      axon-update-5.0.3.jar         5     23
# 3                  axon-conversion-5.0.3.jar         5     35
# 4            axon-server-connector-5.0.3.jar         5     72
# 5   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 6                        axon-test-5.0.3.jar         6     78
# 7                   axon-modelling-5.0.3.jar         7     92
# 8               axon-eventsourcing-5.0.3.jar         7    100
# 9                      axon-common-5.0.3.jar        15    156
# 10                  axon-messaging-5.0.3.jar        59    579
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     3
# 2                      1                     1
# 3                      4                     1
# 4                      1                     4
# 5                      1                     7
# 6                      1                     3
# 7                      2                     3
# 8                      3                     4
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0          axon-metrics-micrometer-5.0.3.jar         3     16
# 1       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 2            axon-server-connector-5.0.3.jar         5     72
# 3   axon-spring-boot-autoconfigure-5.0.3.jar         7     75
# 4                        axon-test-5.0.3.jar         6     78
# 5                      axon-update-5.0.3.jar         5     23
# 6                   axon-modelling-5.0.3.jar         7     92
# 7               axon-eventsourcing-5.0.3.jar         7    100
# 8                  axon-conversion-5.0.3.jar         5     35
# 9                   axon-messaging-5.0.3.jar        59    579
# 10                     axon-common-5.0.3.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     3
# 1                      0                     2
# 2                      1                     4
# 3                      1                     7
# 4                      1                     3
# 5                      1                     1
# 6                      2                     3
# 7                      3                     4
# 8                      4                     1
# 9                      7                     2
# 10                    10                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.3.jar        15    156
# 1                  axon-conversion-5.0.3.jar         5     35
# 2                      axon-update-5.0.3.jar         5     23
# 3                   axon-messaging-5.0.3.jar        59    579
# 4       axon-tracing-opentelemetry-5.0.3.jar         1      5
# 5          axon-metrics-micrometer-5.0.3.jar         3     16
# 6                   axon-modelling-5.0.3.jar         7     92
# 7                        axon-test-5.0.3.jar         6     78
# 8               axon-eventsourcing-5.0.3.jar         7    100
# 9            axon-server-connector-5.0.3.jar         5     72
# 10  axon-spring-boot-autoconfigure-5.0.3.jar         7     75
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      4                     1
# 2                      1                     1
# 3                      7                     2
# 4                      0                     2
# 5                      0                     3
# 6                      2                     3
# 7                      1                     3
# 8                      3                     4
# 9                      1                     4
# 10                     1                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9             axon-common-5.0.3
# 10         axon-messaging-5.0.3
# 11  axon-server-connector-5.0.3
# 12  axon-server-connector-5.0.3
# 13         axon-messaging-5.0.3
# 14         axon-messaging-5.0.3
# 15  axon-server-connector-5.0.3
# 16         axon-modelling-5.0.3
# 17         axon-modelling-5.0.3
# 18         axon-messaging-5.0.3
# 19  axon-server-connector-5.0.3
# 20     axon-eventsourcing-5.0.3
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8        org.axonframework.messaging.eventhandling.processing.subscribing
# 9                                  org.axonframework.common.configuration
# 10               org.axonframework.messaging.core.interception.annotation
# 11                           org.axonframework.axonserver.connector.event
# 12                                 org.axonframework.axonserver.connector
# 13                         org.axonframework.messaging.core.configuration
# 14                              org.axonframework.messaging.eventhandling
# 15                           org.axonframework.axonserver.connector.query
# 16                          org.axonframework.modelling.entity.annotation
# 17                               org.axonframework.modelling.entity.child
# 18                            org.axonframework.messaging.core.unitofwork
# 19                            org.axonframework.axonserver.connector.util
# 20                  org.axonframework.eventsourcing.annotation.reflection
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9             axon-common-5.0.3
# 10         axon-messaging-5.0.3
# 11  axon-server-connector-5.0.3
# 12  axon-server-connector-5.0.3
# 13         axon-messaging-5.0.3
# 14         axon-messaging-5.0.3
# 15  axon-server-connector-5.0.3
# 16         axon-modelling-5.0.3
# 17         axon-modelling-5.0.3
# 18         axon-messaging-5.0.3
# 19  axon-server-connector-5.0.3
# 20     axon-eventsourcing-5.0.3
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9                            org.axonframework.common.infra
# 10              org.axonframework.messaging.core.annotation
# 11                   org.axonframework.axonserver.connector
# 12           org.axonframework.axonserver.connector.command
# 13  org.axonframework.messaging.eventhandling.configuration
# 14              org.axonframework.messaging.core.sequencing
# 15                   org.axonframework.axonserver.connector
# 16                   org.axonframework.modelling.annotation
# 17                       org.axonframework.modelling.entity
# 18                         org.axonframework.messaging.core
# 19                   org.axonframework.axonserver.connector
# 20               org.axonframework.eventsourcing.annotation
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.931034             28               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.529412             13               4
# 10                  0.500000             15               5
# 11                  0.428571              5               2
# 12                  0.333333              4               2
# 13                  0.333333              2               1
# 14                  0.333333              4               2
# 15                  0.200000              6               4
# 16                  0.200000              3               2
# 17                  0.142857              8               6
# 18                  0.111111             10               8
# 19                  0.000000              2               2
# 20                  0.000000              1               1
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [SourceIdParameterResolverFactory$SourceIdParameterResolver->Context$ResourceKey, SourceIdParameterResolverFactory$SourceIdParameterResolver->LegacyResources, MessageIdentifierParameterResolverFactory$MessageIdentifierParameterResolver->Message, InterceptorChainParameterResolverFactory->Context$...
# 1   [EventHandlerRegistry->QualifiedName, DelegatingEventHandlingComponent->QualifiedName, DelegatingEventHandlingComponent->Message, DelegatingEventHandlingComponent->MessageStream$Empty, EventHandlingComponent->QualifiedName, TerminalEventMessage->MessageType, EventBus->SubscribableEventSource, Si...
# 2   [Event->Message, AnnotatedEventHandlingComponent->MessageHandlingMember, AnnotatedEventHandlingComponent->AnnotatedHandlerInspector, AnnotatedEventHandlingComponent->ParameterResolverFactory, AnnotatedEventHandlingComponent->HandlerDefinition, TimestampParameterResolverFactory$TimestampParameter...
# 3   [MethodCommandHandlerDefinition$MethodCommandHandlingMember->WrappedMessageHandlingMember, MethodCommandHandlerDefinition$MethodCommandHandlingMember->MessageHandlingMember, CommandHandler->MessageHandler, Command->Message, CommandDispatcherParameterResolverFactoryConfigurationEnhancer->Paramete...
# 4   [QueryHandler->MessageHandler, MethodQueryHandlerDefinition->HandlerEnhancerDefinition, MethodQueryHandlerDefinition->MessageHandlingMember, QueryResponse->Message, QueryHandlingMember->MessageHandlingMember, MethodQueryHandlerDefinition$MethodQueryHandlingMember->MessageHandlingMember, MethodQu...
# 5   [AnnotationBasedEntityIdResolverDefinition->EntityIdResolver, InjectEntity->EntityIdResolver, EntityIdResolverDefinition->EntityIdResolver, AnnotationBasedEntityIdResolver->EntityIdResolver, AnnotationBasedEntityIdResolver->EntityIdResolutionException, InjectEntityParameterResolverFactory->Prope...
# 6                                                                       [TransactionalExecutorProvider->ProcessingContext, TransactionManager->ProcessingLifecycle$Phase, TransactionManager->ProcessingLifecycle$ErrorHandler, TransactionManager->ProcessingLifecycle, TransactionManager->ProcessingContext]
# 7   [PooledStreamingEventProcessorModule->DefaultEventHandlingComponentsConfigurer, PooledStreamingEventProcessorModule->EventProcessorModule$CustomizationPhase, PooledStreamingEventProcessorModule->EventProcessorConfiguration, PooledStreamingEventProcessorModule->EventProcessorModule$EventHandlingP...
# 8   [SubscribingEventProcessorsConfigurer->EventProcessingConfigurer, SubscribingEventProcessorsConfigurer->EventHandlingComponentsConfigurer$RequiredComponentPhase, SubscribingEventProcessorsConfigurer->EventProcessorModule$CustomizationPhase, SubscribingEventProcessorsConfigurer->EventProcessorMod...
# 9   [DefaultAxonApplication$AxonConfigurationImpl->ComponentDescriptor, AbstractComponent->ComponentDescriptor, DecoratedComponent->ComponentDescriptor, Components->DescribableComponent, Components->ComponentDescriptor, InstantiatedComponentDefinition->ComponentDescriptor, DefaultComponentRegistry->...
# 10  [MessageInterceptingMember->MessageHandlingMember, MessageHandlerInterceptorDefinition$ResultHandlingInterceptorMember->InterceptorChainParameterResolverFactory, MessageHandlerInterceptorDefinition$ResultHandlingInterceptorMember->MessageHandlingMember, MessageHandlerInterceptorDefinition$Result...
# 11  [EventProcessorControlService->AxonServerConfiguration$Eventhandling$ProcessorSettings, EventProcessorControlService->AxonServerConnectionManager, EventProcessorControlService->AxonServerConfiguration$Eventhandling, AggregateBasedAxonServerEventStorageEngine->MetadataConverter, AxonServerEventSt...
# 12                                                                        [ErrorCode->AxonServerCommandDispatchException, ErrorCode->AxonServerNonTransientRemoteCommandHandlingException, ErrorCode->AxonServerRemoteCommandHandlingException, AxonServerConfigurationEnhancer->AxonServerCommandBusConnector]
# 13                                                                                                                                                                                                         [MessagingConfigurer->EventBusConfigurationDefaults, MessagingConfigurer->EventProcessingConfigurer]
# 14                                                                                     [SimpleEventHandlingComponent->SequencingPolicy, SimpleEventHandlingComponent->SequentialPolicy, SimpleEventHandlingComponent->SequentialPerAggregatePolicy, SimpleEventHandlingComponent->HierarchicalSequencingPolicy]
# 15                                  [AxonServerQueryDispatchException->ErrorCode, AxonServerQueryBusConnector$AxonServerUpdateCallback->ErrorCode, QueryConverter->ErrorCode, QueryConverter->MetadataConverter, AxonServerQueryBusConnector->AxonServerConfiguration, FlowControlledResponseSender->ErrorCode]
# 16                                                                                                    [AnnotatedEntityIdResolverDefinition->EntityIdResolverDefinition, AnnotatedEntityIdResolverDefinition->AnnotationBasedEntityIdResolver, AnnotatedEntityMetamodel->AnnotationBasedEntityEvolvingComponent]
# 17  [AbstractEntityChildMetamodel->ChildEntityNotFoundException, AbstractEntityChildMetamodel->EntityMetamodel, SingleEntityChildMetamodel->EntityMetamodel, ListEntityChildMetamodel$Builder->EntityMetamodel, SingleEntityChildMetamodel$Builder->EntityMetamodel, ListEntityChildMetamodel->EntityMetamod...
# 18  [LegacyMessageSupportingContext->Message, LegacyMessageSupportingContext->Context$ResourceKey, SimpleUnitOfWorkFactory->ApplicationContext, ResourceOverridingProcessingContext->Context$ResourceKey, ProcessingContext->Context, ProcessingContext->ApplicationContext, ProcessingContext->Context$Reso...
# 19                                                                                                                                                                                                                                              [GrpcExceptionParser->ErrorCode, ExceptionConverter->ErrorCode]
# 20                                                                                                                                                                                                                    [AnnotationBasedEventSourcedEntityFactoryDefinition->EventSourcedEntityFactoryDefinition]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                  [SimpleHandlerAttributes->HandlerAttributes]
# 1                                                                                                                                                                                                                                                                       [SubscribableEventSource->EventMessage]
# 2                                                                                                                                                                                                                                                                           [HandlerTypeResolver->EventHandler]
# 3                                                                                                                                                                                                                                                                         [HandlerTypeResolver->CommandHandler]
# 4                                                                                                                                                                                                                                                                           [HandlerTypeResolver->QueryHandler]
# 5                                                                                                                                                                                                                                        [PropertyBasedEntityIdResolver->TargetEntityIdMemberMismatchException]
# 6                                                                                                                                                                                                                                                          [TransactionalUnitOfWorkFactory->TransactionManager]
# 7                                                                                                            [EventProcessorModule->PooledStreamingEventProcessorModule, EventProcessorModule->PooledStreamingEventProcessorConfiguration, EventProcessingConfigurer->PooledStreamingEventProcessorsConfigurer]
# 8                                                                                                                        [EventProcessorModule->SubscribingEventProcessorModule, EventProcessorModule->SubscribingEventProcessorConfiguration, EventProcessingConfigurer->SubscribingEventProcessorsConfigurer]
# 9                                                                                                            [FilesystemStyleComponentDescriptor->Component$Identifier, FilesystemStyleComponentDescriptor->Component, JacksonComponentDescriptor->Component$Identifier, JacksonComponentDescriptor->Component]
# 10  [AnnotatedHandlerInspector->MessageInterceptingMember, AnnotatedHandlerInspector->NoMoreInterceptors, AnnotatedHandlerInspector->MessageHandlerInterceptorMemberChain, ChainedMessageHandlerInterceptorMember->NoMoreInterceptors, ChainedMessageHandlerInterceptorMember->MessageHandlerInterceptorMemb...
# 11                                                                                                                                                                        [AxonServerConfigurationEnhancer->EventProcessorControlService, AxonServerConfigurationEnhancer->AxonServerEventStorageEngineFactory]
# 12                                                                                                                                                                                                                [CommandConverter->MetadataConverter, AxonServerCommandBusConnector->AxonServerConfiguration]
# 13                                                                                                                                                                                                                                                             [EventProcessingConfigurer->MessagingConfigurer]
# 14                                                                                                                                                                                                                       [SequentialPerAggregatePolicy->EventMessage, ExtractionSequencingPolicy->EventMessage]
# 15                                                                                [ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, ErrorCode->AxonServerRemoteQueryHandlingException, AxonServerConfigurationEnhancer->AxonServerQueryBusConnector]
# 16                                                                                                                                                                                  [AnnotationBasedEntityIdResolverDefinition->AnnotatedEntityMetamodel, EntityIdResolverDefinition->AnnotatedEntityMetamodel]
# 17  [ConcreteEntityMetamodel->EntityChildMetamodel, ConcreteEntityMetamodel->ChildAmbiguityException, PolymorphicEntityMetamodel$Builder->EntityChildMetamodel, PolymorphicEntityMetamodelBuilder->EntityChildMetamodel, ConcreteEntityMetamodel$Builder->EntityChildMetamodel, EntityMetamodelBuilder->Enti...
# 18  [DefaultMessageDispatchInterceptorChain$InterceptingDispatcher->ProcessingContext, MessageDispatchInterceptor->ProcessingContext, SubscribableEventSource->ProcessingContext, MessageHandlerInterceptor->ProcessingContext, MessageHandlerInterceptorChain->ProcessingContext, MessageDispatchIntercepto...
# 19                                                                                                                                                                                                             [ErrorCode->ExceptionConverter, AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor]
# 20                                                                                                                                                                                                                                     [EventSourcedEntity->AnnotationBasedEventSourcedEntityFactoryDefinition]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#             artifactName                                  packageName  \
# 0   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 1   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 2   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 3   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 4   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 5   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 6   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 7   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 8   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 9   axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 10  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 11  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 12  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 13  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 14  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 15  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 16  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 17  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 18  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 19  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 20  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 21  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 22  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 23  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 24  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 25  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 26  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 27  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 28  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 29  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 30  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 31  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 32  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 33  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 34  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 35  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 36  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 37  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 38  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
# 39  axon-messaging-5.0.3  org.axonframework.messaging.core.annotation
#
#    dependentArtifactName              dependentPackageName  \
# 0   axon-messaging-5.0.3  org.axonframework.messaging.core
# 1   axon-messaging-5.0.3  org.axonframework.messaging.core
# 2   axon-messaging-5.0.3  org.axonframework.messaging.core
# 3   axon-messaging-5.0.3  org.axonframework.messaging.core
# 4   axon-messaging-5.0.3  org.axonframework.messaging.core
# 5   axon-messaging-5.0.3  org.axonframework.messaging.core
# 6   axon-messaging-5.0.3  org.axonframework.messaging.core
# 7   axon-messaging-5.0.3  org.axonframework.messaging.core
# 8   axon-messaging-5.0.3  org.axonframework.messaging.core
# 9   axon-messaging-5.0.3  org.axonframework.messaging.core
# 10  axon-messaging-5.0.3  org.axonframework.messaging.core
# 11  axon-messaging-5.0.3  org.axonframework.messaging.core
# 12  axon-messaging-5.0.3  org.axonframework.messaging.core
# 13  axon-messaging-5.0.3  org.axonframework.messaging.core
# 14  axon-messaging-5.0.3  org.axonframework.messaging.core
# 15  axon-messaging-5.0.3  org.axonframework.messaging.core
# 16  axon-messaging-5.0.3  org.axonframework.messaging.core
# 17  axon-messaging-5.0.3  org.axonframework.messaging.core
# 18  axon-messaging-5.0.3  org.axonframework.messaging.core
# 19  axon-messaging-5.0.3  org.axonframework.messaging.core
# 20  axon-messaging-5.0.3  org.axonframework.messaging.core
# 21  axon-messaging-5.0.3  org.axonframework.messaging.core
# 22  axon-messaging-5.0.3  org.axonframework.messaging.core
# 23  axon-messaging-5.0.3  org.axonframework.messaging.core
# 24  axon-messaging-5.0.3  org.axonframework.messaging.core
# 25  axon-messaging-5.0.3  org.axonframework.messaging.core
# 26  axon-messaging-5.0.3  org.axonframework.messaging.core
# 27  axon-messaging-5.0.3  org.axonframework.messaging.core
# 28  axon-messaging-5.0.3  org.axonframework.messaging.core
# 29  axon-messaging-5.0.3  org.axonframework.messaging.core
# 30  axon-messaging-5.0.3  org.axonframework.messaging.core
# 31  axon-messaging-5.0.3  org.axonframework.messaging.core
# 32  axon-messaging-5.0.3  org.axonframework.messaging.core
# 33  axon-messaging-5.0.3  org.axonframework.messaging.core
# 34  axon-messaging-5.0.3  org.axonframework.messaging.core
# 35  axon-messaging-5.0.3  org.axonframework.messaging.core
# 36  axon-messaging-5.0.3  org.axonframework.messaging.core
# 37  axon-messaging-5.0.3  org.axonframework.messaging.core
# 38  axon-messaging-5.0.3  org.axonframework.messaging.core
# 39  axon-messaging-5.0.3  org.axonframework.messaging.core
#
#                                                                                    dependency  \
# 0                                    MethodInvokingMessageHandlingMember->MessageStream$Entry
# 1                                                           PayloadParameterResolver->Message
# 2                                                                            Message->Message
# 3                                    MethodInvokingMessageHandlingMember->MessageStream$Empty
# 4                         DefaultParameterResolverFactory$MetadataParameterResolver->Metadata
# 5                           DefaultParameterResolverFactory$MessageParameterResolver->Message
# 6   AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->Context$ResourceKey
# 7                                                 WrappedMessageHandlingMember->MessageStream
# 8                                   MethodInvokingMessageHandlingMember->MessageStream$Single
# 9                                          MethodInvokingMessageHandlingMember->MessageStream
# 10                                          AnnotatedMessageHandlingMemberDefinition->Message
# 11                         DefaultParameterResolverFactory$MetadataParameterResolver->Message
# 12                                    AnnotatedMessageHandlingMemberDefinition->MessageStream
# 13                                      ChainedMessageHandlerInterceptorMember->MessageStream
# 14                                                             MessageHandlingMember->Message
# 15      AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->LegacyResources
# 16                                                      WrappedMessageHandlingMember->Message
# 17                                                   DefaultParameterResolverFactory->Message
# 18                                                       MessageHandlingMember->MessageStream
# 19                                  MethodInvokingMessageHandlingMember->DelayedMessageStream
# 20                                                 HandlerAttributes<-SimpleHandlerAttributes
# 21                                               MethodInvokingMessageHandlingMember->Message
# 22      MessageIdentifierParameterResolverFactory$MessageIdentifierParameterResolver->Message
# 23                DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Message
# 24                                    InterceptorChainParameterResolverFactory->MessageStream
# 25                                                      MultiHandlerDefinition->MessageStream
# 26               DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Metadata
# 27                              InterceptorChainParameterResolverFactory->Context$ResourceKey
# 28                                                           HandlerDefinition->MessageStream
# 29                                            ChainedMessageHandlerInterceptorMember->Message
# 30                   InterceptorChainParameterResolverFactory->MessageHandlerInterceptorChain
# 31                                                                    MessageHandler->Message
# 32                                          InterceptorChainParameterResolverFactory->Message
# 33                SourceIdParameterResolverFactory$SourceIdParameterResolver->LegacyResources
# 34                                                         AnnotatedHandlerInspector->Message
# 35                                                  DefaultParameterResolverFactory->Metadata
# 36                                                   AnnotatedHandlerInspector->MessageStream
# 37                                        AnnotatedHandlerAttributes->SimpleHandlerAttributes
# 38            SourceIdParameterResolverFactory$SourceIdParameterResolver->Context$ResourceKey
# 39                                                 AnnotationMessageTypeResolver->MessageType
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.959184             48               1
# 2                   0.959184             48               1
# 3                   0.959184             48               1
# 4                   0.959184             48               1
# 5                   0.959184             48               1
# 6                   0.959184             48               1
# 7                   0.959184             48               1
# 8                   0.959184             48               1
# 9                   0.959184             48               1
# 10                  0.959184             48               1
# 11                  0.959184             48               1
# 12                  0.959184             48               1
# 13                  0.959184             48               1
# 14                  0.959184             48               1
# 15                  0.959184             48               1
# 16                  0.959184             48               1
# 17                  0.959184             48               1
# 18                  0.959184             48               1
# 19                  0.959184             48               1
# 20                  0.959184             48               1
# 21                  0.959184             48               1
# 22                  0.959184             48               1
# 23                  0.959184             48               1
# 24                  0.959184             48               1
# 25                  0.959184             48               1
# 26                  0.959184             48               1
# 27                  0.959184             48               1
# 28                  0.959184             48               1
# 29                  0.959184             48               1
# 30                  0.959184             48               1
# 31                  0.959184             48               1
# 32                  0.959184             48               1
# 33                  0.959184             48               1
# 34                  0.959184             48               1
# 35                  0.959184             48               1
# 36                  0.959184             48               1
# 37                  0.959184             48               1
# 38                  0.959184             48               1
# 39                  0.959184             48               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9          axon-messaging-5.0.3
# 10         axon-messaging-5.0.3
# 11         axon-messaging-5.0.3
# 12         axon-messaging-5.0.3
# 13            axon-common-5.0.3
# 14            axon-common-5.0.3
# 15            axon-common-5.0.3
# 16            axon-common-5.0.3
# 17         axon-messaging-5.0.3
# 18         axon-messaging-5.0.3
# 19         axon-messaging-5.0.3
# 20         axon-messaging-5.0.3
# 21         axon-messaging-5.0.3
# 22  axon-server-connector-5.0.3
# 23  axon-server-connector-5.0.3
# 24  axon-server-connector-5.0.3
# 25  axon-server-connector-5.0.3
# 26         axon-messaging-5.0.3
# 27         axon-messaging-5.0.3
# 28         axon-messaging-5.0.3
# 29  axon-server-connector-5.0.3
# 30  axon-server-connector-5.0.3
# 31  axon-server-connector-5.0.3
# 32  axon-server-connector-5.0.3
# 33         axon-modelling-5.0.3
# 34         axon-modelling-5.0.3
# 35         axon-modelling-5.0.3
# 36         axon-modelling-5.0.3
# 37         axon-modelling-5.0.3
# 38         axon-modelling-5.0.3
# 39         axon-modelling-5.0.3
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 9   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 10       org.axonframework.messaging.eventhandling.processing.subscribing
# 11       org.axonframework.messaging.eventhandling.processing.subscribing
# 12       org.axonframework.messaging.eventhandling.processing.subscribing
# 13                                 org.axonframework.common.configuration
# 14                                 org.axonframework.common.configuration
# 15                                 org.axonframework.common.configuration
# 16                                 org.axonframework.common.configuration
# 17               org.axonframework.messaging.core.interception.annotation
# 18               org.axonframework.messaging.core.interception.annotation
# 19               org.axonframework.messaging.core.interception.annotation
# 20               org.axonframework.messaging.core.interception.annotation
# 21               org.axonframework.messaging.core.interception.annotation
# 22                           org.axonframework.axonserver.connector.event
# 23                           org.axonframework.axonserver.connector.event
# 24                                 org.axonframework.axonserver.connector
# 25                                 org.axonframework.axonserver.connector
# 26                         org.axonframework.messaging.core.configuration
# 27                              org.axonframework.messaging.eventhandling
# 28                              org.axonframework.messaging.eventhandling
# 29                           org.axonframework.axonserver.connector.query
# 30                           org.axonframework.axonserver.connector.query
# 31                           org.axonframework.axonserver.connector.query
# 32                           org.axonframework.axonserver.connector.query
# 33                          org.axonframework.modelling.entity.annotation
# 34                          org.axonframework.modelling.entity.annotation
# 35                               org.axonframework.modelling.entity.child
# 36                               org.axonframework.modelling.entity.child
# 37                               org.axonframework.modelling.entity.child
# 38                               org.axonframework.modelling.entity.child
# 39                               org.axonframework.modelling.entity.child
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.3
# 1          axon-messaging-5.0.3
# 2          axon-messaging-5.0.3
# 3          axon-messaging-5.0.3
# 4          axon-messaging-5.0.3
# 5          axon-modelling-5.0.3
# 6          axon-messaging-5.0.3
# 7          axon-messaging-5.0.3
# 8          axon-messaging-5.0.3
# 9          axon-messaging-5.0.3
# 10         axon-messaging-5.0.3
# 11         axon-messaging-5.0.3
# 12         axon-messaging-5.0.3
# 13            axon-common-5.0.3
# 14            axon-common-5.0.3
# 15            axon-common-5.0.3
# 16            axon-common-5.0.3
# 17         axon-messaging-5.0.3
# 18         axon-messaging-5.0.3
# 19         axon-messaging-5.0.3
# 20         axon-messaging-5.0.3
# 21         axon-messaging-5.0.3
# 22  axon-server-connector-5.0.3
# 23  axon-server-connector-5.0.3
# 24  axon-server-connector-5.0.3
# 25  axon-server-connector-5.0.3
# 26         axon-messaging-5.0.3
# 27         axon-messaging-5.0.3
# 28         axon-messaging-5.0.3
# 29  axon-server-connector-5.0.3
# 30  axon-server-connector-5.0.3
# 31  axon-server-connector-5.0.3
# 32  axon-server-connector-5.0.3
# 33         axon-modelling-5.0.3
# 34         axon-modelling-5.0.3
# 35         axon-modelling-5.0.3
# 36         axon-modelling-5.0.3
# 37         axon-modelling-5.0.3
# 38         axon-modelling-5.0.3
# 39         axon-modelling-5.0.3
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9   org.axonframework.messaging.eventhandling.configuration
# 10  org.axonframework.messaging.eventhandling.configuration
# 11  org.axonframework.messaging.eventhandling.configuration
# 12  org.axonframework.messaging.eventhandling.configuration
# 13                           org.axonframework.common.infra
# 14                           org.axonframework.common.infra
# 15                           org.axonframework.common.infra
# 16                           org.axonframework.common.infra
# 17              org.axonframework.messaging.core.annotation
# 18              org.axonframework.messaging.core.annotation
# 19              org.axonframework.messaging.core.annotation
# 20              org.axonframework.messaging.core.annotation
# 21              org.axonframework.messaging.core.annotation
# 22                   org.axonframework.axonserver.connector
# 23                   org.axonframework.axonserver.connector
# 24           org.axonframework.axonserver.connector.command
# 25           org.axonframework.axonserver.connector.command
# 26  org.axonframework.messaging.eventhandling.configuration
# 27              org.axonframework.messaging.core.sequencing
# 28              org.axonframework.messaging.core.sequencing
# 29                   org.axonframework.axonserver.connector
# 30                   org.axonframework.axonserver.connector
# 31                   org.axonframework.axonserver.connector
# 32                   org.axonframework.axonserver.connector
# 33                   org.axonframework.modelling.annotation
# 34                   org.axonframework.modelling.annotation
# 35                       org.axonframework.modelling.entity
# 36                       org.axonframework.modelling.entity
# 37                       org.axonframework.modelling.entity
# 38                       org.axonframework.modelling.entity
# 39                       org.axonframework.modelling.entity
#
#                                                                       dependency  \
# 0                                     HandlerAttributes<-SimpleHandlerAttributes
# 1                                          EventMessage<-SubscribableEventSource
# 2                                              EventHandler<-HandlerTypeResolver
# 3                                            CommandHandler<-HandlerTypeResolver
# 4                                              QueryHandler<-HandlerTypeResolver
# 5           TargetEntityIdMemberMismatchException<-PropertyBasedEntityIdResolver
# 6                             TransactionManager<-TransactionalUnitOfWorkFactory
# 7            PooledStreamingEventProcessorsConfigurer<-EventProcessingConfigurer
# 8               PooledStreamingEventProcessorConfiguration<-EventProcessorModule
# 9                      PooledStreamingEventProcessorModule<-EventProcessorModule
# 10                         SubscribingEventProcessorModule<-EventProcessorModule
# 11               SubscribingEventProcessorsConfigurer<-EventProcessingConfigurer
# 12                  SubscribingEventProcessorConfiguration<-EventProcessorModule
# 13                                         Component<-JacksonComponentDescriptor
# 14                              Component$Identifier<-JacksonComponentDescriptor
# 15                                 Component<-FilesystemStyleComponentDescriptor
# 16                      Component$Identifier<-FilesystemStyleComponentDescriptor
# 17                    NoMoreInterceptors<-ChainedMessageHandlerInterceptorMember
# 18               MessageHandlerInterceptorMemberChain<-AnnotatedHandlerInspector
# 19                                 NoMoreInterceptors<-AnnotatedHandlerInspector
# 20                          MessageInterceptingMember<-AnnotatedHandlerInspector
# 21  MessageHandlerInterceptorMemberChain<-ChainedMessageHandlerInterceptorMember
# 22                 EventProcessorControlService<-AxonServerConfigurationEnhancer
# 23          AxonServerEventStorageEngineFactory<-AxonServerConfigurationEnhancer
# 24                                           MetadataConverter<-CommandConverter
# 25                        AxonServerConfiguration<-AxonServerCommandBusConnector
# 26                                MessagingConfigurer<-EventProcessingConfigurer
# 27                                      EventMessage<-ExtractionSequencingPolicy
# 28                                    EventMessage<-SequentialPerAggregatePolicy
# 29                             AxonServerRemoteQueryHandlingException<-ErrorCode
# 30                 AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 31                                   AxonServerQueryDispatchException<-ErrorCode
# 32                  AxonServerQueryBusConnector<-AxonServerConfigurationEnhancer
# 33                          AnnotatedEntityMetamodel<-EntityIdResolverDefinition
# 34           AnnotatedEntityMetamodel<-AnnotationBasedEntityIdResolverDefinition
# 35                                 EntityChildMetamodel<-ConcreteEntityMetamodel
# 36                              ChildAmbiguityException<-ConcreteEntityMetamodel
# 37                      EntityChildMetamodel<-PolymorphicEntityMetamodel$Builder
# 38                       EntityChildMetamodel<-PolymorphicEntityMetamodelBuilder
# 39                         EntityChildMetamodel<-ConcreteEntityMetamodel$Builder
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.931034             28               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.666667             15               3
# 10                  0.666667             15               3
# 11                  0.666667             15               3
# 12                  0.666667             15               3
# 13                  0.529412             13               4
# 14                  0.529412             13               4
# 15                  0.529412             13               4
# 16                  0.529412             13               4
# 17                  0.500000             15               5
# 18                  0.500000             15               5
# 19                  0.500000             15               5
# 20                  0.500000             15               5
# 21                  0.500000             15               5
# 22                  0.428571              5               2
# 23                  0.428571              5               2
# 24                  0.333333              4               2
# 25                  0.333333              4               2
# 26                  0.333333              2               1
# 27                  0.333333              4               2
# 28                  0.333333              4               2
# 29                  0.200000              6               4
# 30                  0.200000              6               4
# 31                  0.200000              6               4
# 32                  0.200000              6               4
# 33                  0.200000              3               2
# 34                  0.200000              3               2
# 35                  0.142857              8               6
# 36                  0.142857              8               6
# 37                  0.142857              8               6
# 38                  0.142857              8               6
# 39                  0.142857              8               6

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                                                     fullDependentTypeName  \
# 0                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                                  org.axonframework.messaging.commandhandling.CommandBus
# 2                             org.axonframework.common.configuration.ComponentDefinition$ComponentCreator
# 3                                                    org.axonframework.messaging.core.MessageStream$Entry
# 4                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 5                                                  org.axonframework.messaging.eventhandling.EventMessage
# 6                                                  org.axonframework.messaging.eventhandling.EventMessage
# 7                                                    org.axonframework.messaging.core.MessageStream$Empty
# 8                                                   org.axonframework.messaging.core.DelayedMessageStream
# 9                                                  org.axonframework.messaging.eventhandling.EventMessage
# 10                               org.axonframework.messaging.core.annotation.WrappedMessageHandlingMember
# 11                                                 org.axonframework.messaging.core.unitofwork.UnitOfWork
# 12                                                     org.axonframework.test.fixture.AxonTestThenMessage
# 13                                             org.axonframework.messaging.commandhandling.CommandMessage
# 14                                             org.axonframework.messaging.commandhandling.CommandMessage
# 15                                             org.axonframework.messaging.commandhandling.CommandMessage
# 16                                                 org.axonframework.messaging.eventhandling.EventMessage
# 17                                                 org.axonframework.messaging.eventhandling.EventMessage
# 18                                              org.axonframework.messaging.eventstreaming.EventCriterion
# 19                                             org.axonframework.messaging.eventstreaming.OrEventCriteria
# 20                                             org.axonframework.modelling.entity.ConcreteEntityMetamodel
# 21                                          org.axonframework.modelling.entity.PolymorphicEntityMetamodel
# 22                                                  org.axonframework.eventsourcing.eventstore.EventStore
# 23                      org.axonframework.messaging.eventhandling.processing.streaming.token.WrappedToken
# 24                 org.axonframework.messaging.eventhandling.processing.streaming.token.store.ConfigToken
# 25                                                   org.axonframework.messaging.core.MessageStream$Entry
# 26                                              org.axonframework.conversion.ChainingContentTypeConverter
# 27                                                    org.axonframework.messaging.core.EmptyMessageStream
# 28  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 29  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 30                                                  org.axonframework.messaging.core.DelayedMessageStream
# 31                                                  org.axonframework.messaging.core.MessageStream$Single
# 32                                                  org.axonframework.messaging.core.MessageStream$Single
# 33                                                  org.axonframework.messaging.core.MessageStream$Single
# 34                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 35                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 36                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 37                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 38                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 39                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
#
#     declaredMethods  \
# 0                32
# 1                 6
# 2                17
# 3                 7
# 4                32
# 5                19
# 6                19
# 7                44
# 8                42
# 9                19
# 10               13
# 11               24
# 12               22
# 13               20
# 14               19
# 15               19
# 16               19
# 17               19
# 18               12
# 19               12
# 20               11
# 21               11
# 22                9
# 23                9
# 24                9
# 25                7
# 26                5
# 27               44
# 28               43
# 29               42
# 30               42
# 31               42
# 32               42
# 33               42
# 34               37
# 35               36
# 36               35
# 37               34
# 38               33
# 39               33
#
#                                                                               calledMethodNames  \
# 0                                                                     [computeResourceIfAbsent]
# 1                                                                                    [dispatch]
# 2                                                                             [createComponent]
# 3                                                                                     [message]
# 4                                                                                [withResource]
# 5                                                                       [identifier, timestamp]
# 6                                                                                   [timestamp]
# 7                                                                                        [cast]
# 8                                                                                      [create]
# 9                                                                                 [andMetadata]
# 10                                                                                 [handleSync]
# 11                                                                                    [execute]
# 12                                                              [exceptionSatisfies, exception]
# 13                                                                       [routingKey, priority]
# 14                                                                       [withConvertedPayload]
# 15                                                                                [andMetadata]
# 16                                                                       [withConvertedPayload]
# 17                                                                                 [identifier]
# 18                                                                                       [tags]
# 19                                                                                         [or]
# 20                                                                             [forEntityClass]
# 21                                                                               [forSuperType]
# 22                                                                                [transaction]
# 23                                                                           [unwrapLowerBound]
# 24                                                                                        [get]
# 25                                                                                        [map]
# 26                                                              [canConvert, registerConverter]
# 27                                                                                   [instance]
# 28                                                              [isCompleted, hasNextAvailable]
# 29                                                                                   [callback]
# 30                                                                               [createSingle]
# 31                                                                        [asCompletableFuture]
# 32                                                                                      [first]
# 33                                                                                       [cast]
# 34  [removeResource, putResourceIfAbsent, updateResource, putResource, computeResourceIfAbsent]
# 35                                                    [updateResource, computeResourceIfAbsent]
# 36                                                                    [computeResourceIfAbsent]
# 37                                                                    [computeResourceIfAbsent]
# 38                                                                                [putResource]
# 39                                                    [removeResource, computeResourceIfAbsent]
#
#     calledMethods  callerTypes
# 0               1            7
# 1               1            7
# 2               1            5
# 3               1            5
# 4               1            4
# 5               2            4
# 6               1            4
# 7               1            3
# 8               1            3
# 9               1            3
# 10              1            3
# 11              1            2
# 12              3            2
# 13              2            2
# 14              1            2
# 15              1            2
# 16              1            2
# 17              1            2
# 18              1            2
# 19              1            2
# 20              1            2
# 21              1            2
# 22              1            2
# 23              1            2
# 24              1            2
# 25              1            2
# 26              2            2
# 27              1            1
# 28              2            1
# 29              1            1
# 30              1            1
# 31              1            1
# 32              1            1
# 33              1            1
# 34              6            1
# 35              2            1
# 36              1            1
# 37              1            1
# 38              1            1
# 39              2            1

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                                               fullQualifiedDependentTypeName  \
# 0                              org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                               org.axonframework.common.annotation.Internal
# 2                                                   org.axonframework.messaging.core.Message
# 3                                         org.axonframework.common.infra.ComponentDescriptor
# 4                                             org.axonframework.messaging.core.MessageStream
# 5                                     org.axonframework.messaging.eventhandling.EventMessage
# 6                                               org.axonframework.messaging.core.MessageType
# 7                                             org.axonframework.messaging.core.QualifiedName
# 8                                       org.axonframework.common.configuration.Configuration
# 9                                                       org.axonframework.common.FutureUtils
# 10                                      org.axonframework.messaging.core.Context$ResourceKey
# 11                                      org.axonframework.messaging.core.MessageStream$Empty
# 12                                       org.axonframework.common.infra.DescribableComponent
# 13                                                           org.axonframework.common.Assert
# 14                                  org.axonframework.common.configuration.ComponentRegistry
# 15                                                     org.axonframework.common.BuilderUtils
# 16                                org.axonframework.messaging.commandhandling.CommandMessage
# 17                      org.axonframework.messaging.core.annotation.ParameterResolverFactory
# 18                                      org.axonframework.messaging.core.MessageStream$Entry
# 19                              org.axonframework.common.configuration.ConfigurationEnhancer
# 20                                                    org.axonframework.conversion.Converter
# 21                                     org.axonframework.messaging.core.MessageStream$Single
# 22                                      org.axonframework.messaging.core.MessageTypeResolver
# 23                              org.axonframework.messaging.core.conversion.MessageConverter
# 24                                                 org.axonframework.messaging.core.Metadata
# 25                                                      org.axonframework.common.ObjectUtils
# 26        org.axonframework.messaging.eventhandling.processing.streaming.token.TrackingToken
# 27                                       org.axonframework.common.AxonConfigurationException
# 28                                    org.axonframework.messaging.commandhandling.CommandBus
# 29                                                  org.axonframework.common.ReflectionUtils
# 30                          org.axonframework.messaging.commandhandling.CommandResultMessage
# 31                                org.axonframework.common.configuration.ComponentDefinition
# 32  org.axonframework.common.configuration.ComponentDefinition$IncompleteComponentDefinition
# 33                                                  org.axonframework.messaging.core.Context
# 34                                    org.axonframework.messaging.queryhandling.QueryMessage
# 35                                        org.axonframework.common.AxonNonTransientException
# 36                                   org.axonframework.common.configuration.ComponentBuilder
# 37                       org.axonframework.messaging.eventhandling.conversion.EventConverter
# 38                                org.axonframework.messaging.core.MessageHandlerInterceptor
# 39                             org.axonframework.messaging.core.annotation.ParameterResolver
#
#                                     dependentTypeName  \
# 0                                   ProcessingContext
# 1                                            Internal
# 2                                             Message
# 3                                 ComponentDescriptor
# 4                                       MessageStream
# 5                                        EventMessage
# 6                                         MessageType
# 7                                       QualifiedName
# 8                                       Configuration
# 9                                         FutureUtils
# 10                                Context$ResourceKey
# 11                                MessageStream$Empty
# 12                               DescribableComponent
# 13                                             Assert
# 14                                  ComponentRegistry
# 15                                       BuilderUtils
# 16                                     CommandMessage
# 17                           ParameterResolverFactory
# 18                                MessageStream$Entry
# 19                              ConfigurationEnhancer
# 20                                          Converter
# 21                               MessageStream$Single
# 22                                MessageTypeResolver
# 23                                   MessageConverter
# 24                                           Metadata
# 25                                        ObjectUtils
# 26                                      TrackingToken
# 27                         AxonConfigurationException
# 28                                         CommandBus
# 29                                    ReflectionUtils
# 30                               CommandResultMessage
# 31                                ComponentDefinition
# 32  ComponentDefinition$IncompleteComponentDefinition
# 33                                            Context
# 34                                       QueryMessage
# 35                          AxonNonTransientException
# 36                                   ComponentBuilder
# 37                                     EventConverter
# 38                          MessageHandlerInterceptor
# 39                                  ParameterResolver
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 1   [Type, File, Java, ByteCode, Annotation, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent...
# 2   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 3   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 4   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWea...
# 5   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponen...
# 6   [Type, File, Java, ByteCode, Record, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 7   [Type, File, Java, ByteCode, Record, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4T...
# 8   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity5,...
# 9   [Type, File, Java, ByteCode, Class, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation8, Mark4TypeLouvainCommunity4, Mark4...
# 10  [Type, File, Java, ByteCode, GenericDeclaration, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyCon...
# 11  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity9, Mark4TypeK...
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 13  [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposit...
# 14                                     [Type, File, Java, ByteCode, Interface, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut18, Mark4TypeHDBSCAN63]
# 15                                                   [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation22, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCommunity13, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN41, Mark4TopAnomalyHub]
# 16  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation2, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, ...
# 17                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut89, Mark4TypeHDBSCAN97]
# 18  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity8, Mark4T...
# 19                                                                     [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN133]
# 20  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecompo...
# 21  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mar...
# 22  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition10, ...
# 23            [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut38, Mark4TypeLocalClusteringCoefficient0.11333333333333333, Mark4TypeHDBSCAN111]
# 24  [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation0, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut0, Mar...
# 25                                                                          [Type, File, Java, ByteCode, Class, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN-1]
# 26  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation15, Mark4TypeLouvainCommunity4...
# 27                               [Type, File, Java, ByteCode, Class, Throwable, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation30, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut1, Mark4TypeHDBSCAN54]
# 28                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation2, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut24, Mark4TypeHDBSCAN71]
# 29  [Type, File, Java, ByteCode, Class, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity0, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut27, Mark4TypeHDBSCAN49, Mark4TopAnomalyBottleneck, Mark4TopA...
# 30  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation2, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10, ...
# 31                                               [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut19, Mark4TypeHDBSCAN-1]
# 32                                               [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut20, Mark4TypeHDBSCAN-1]
# 33  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation12, Mark4TypeLouvainCommunity8, Mark4TypeLeidenC...
# 34  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation62, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10,...
# 35  [Type, File, Java, ByteCode, Class, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition4, Mark4TypeMaximumKCut24, Mark4TypeLocalClusteringCoef...
# 36                                               [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut45, Mark4TypeHDBSCAN125]
# 37                                                                   [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut28, Mark4TypeHDBSCAN147]
# 38  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation9, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity6, Mark4TypeKC...
# 39                                                [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation7, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition7, Mark4TypeMaximumKCut90, Mark4TypeHDBSCAN128]
#
#     numberOfUsingPackages
# 0                      59
# 1                      55
# 2                      47
# 3                      46
# 4                      36
# 5                      35
# 6                      31
# 7                      30
# 8                      29
# 9                      28
# 10                     25
# 11                     25
# 12                     24
# 13                     22
# 14                     22
# 15                     21
# 16                     20
# 17                     20
# 18                     19
# 19                     18
# 20                     18
# 21                     18
# 22                     18
# 23                     17
# 24                     16
# 25                     16
# 26                     15
# 27                     14
# 28                     13
# 29                     13
# 30                     12
# 31                     12
# 32                     12
# 33                     12
# 34                     12
# 35                     11
# 36                     11
# 37                     11
# 38                     11
# 39                     11

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                             artifactName  \
# 0       axon-tracing-opentelemetry-5.0.3
# 1       axon-tracing-opentelemetry-5.0.3
# 2          axon-metrics-micrometer-5.0.3
# 3          axon-metrics-micrometer-5.0.3
# 4                        axon-test-5.0.3
# 5            axon-server-connector-5.0.3
# 6            axon-server-connector-5.0.3
# 7          axon-metrics-micrometer-5.0.3
# 8                        axon-test-5.0.3
# 9   axon-spring-boot-autoconfigure-5.0.3
# 10                  axon-modelling-5.0.3
# 11                 axon-conversion-5.0.3
# 12              axon-eventsourcing-5.0.3
# 13                 axon-conversion-5.0.3
# 14                     axon-update-5.0.3
# 15  axon-spring-boot-autoconfigure-5.0.3
# 16                  axon-modelling-5.0.3
# 17                       axon-test-5.0.3
# 18           axon-server-connector-5.0.3
# 19              axon-eventsourcing-5.0.3
# 20  axon-spring-boot-autoconfigure-5.0.3
# 21  axon-spring-boot-autoconfigure-5.0.3
# 22  axon-spring-boot-autoconfigure-5.0.3
# 23                  axon-modelling-5.0.3
# 24           axon-server-connector-5.0.3
# 25                  axon-messaging-5.0.3
# 26                     axon-common-5.0.3
# 27              axon-eventsourcing-5.0.3
# 28  axon-spring-boot-autoconfigure-5.0.3
# 29                       axon-test-5.0.3
#
#                    dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-5.0.3                  2
# 1                      axon-common-5.0.3                  1
# 2                   axon-messaging-5.0.3                  7
# 3                      axon-common-5.0.3                  2
# 4               axon-eventsourcing-5.0.3                  1
# 5               axon-eventsourcing-5.0.3                  1
# 6                   axon-modelling-5.0.3                  1
# 7   axon-spring-boot-autoconfigure-5.0.3                  1
# 8                   axon-messaging-5.0.3                  9
# 9                        axon-test-5.0.3                  1
# 10                 axon-conversion-5.0.3                  1
# 11                     axon-common-5.0.3                  3
# 12                 axon-conversion-5.0.3                  1
# 13                 axon-conversion-5.0.3                  1
# 14                     axon-common-5.0.3                  3
# 15           axon-server-connector-5.0.3                  1
# 16                  axon-messaging-5.0.3                 13
# 17                     axon-common-5.0.3                  4
# 18                  axon-messaging-5.0.3                 16
# 19                  axon-messaging-5.0.3                 16
# 20                  axon-messaging-5.0.3                 16
# 21              axon-eventsourcing-5.0.3                  2
# 22                     axon-common-5.0.3                  5
# 23                     axon-common-5.0.3                  5
# 24                     axon-common-5.0.3                  6
# 25                 axon-conversion-5.0.3                  2
# 26                     axon-common-5.0.3                  8
# 27                     axon-common-5.0.3                  8
# 28                     axon-update-5.0.3                  3
# 29                       axon-test-5.0.3                  4
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          59                0.033898
# 1                          15                0.066667
# 2                          59                0.118644
# 3                          15                0.133333
# 4                           7                0.142857
# 5                           7                0.142857
# 6                           7                0.142857
# 7                           7                0.142857
# 8                          59                0.152542
# 9                           6                0.166667
# 10                          5                0.200000
# 11                         15                0.200000
# 12                          5                0.200000
# 13                          5                0.200000
# 14                         15                0.200000
# 15                          5                0.200000
# 16                         59                0.220339
# 17                         15                0.266667
# 18                         59                0.271186
# 19                         59                0.271186
# 20                         59                0.271186
# 21                          7                0.285714
# 22                         15                0.333333
# 23                         15                0.333333
# 24                         15                0.400000
# 25                          5                0.400000
# 26                         15                0.533333
# 27                         15                0.533333
# 28                          5                0.600000
# 29                          6                0.666667
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                                       [org.axonframework.messaging.core, org.axonframework.messaging.tracing]
# 1                                                                                                                                                                                                                                                                                    [org.axonframework.common]
# 2   [org.axonframework.messaging.core, org.axonframework.messaging.eventhandling.processing, org.axonframework.messaging.monitoring, org.axonframework.messaging.commandhandling, org.axonframework.messaging.queryhandling, org.axonframework.messaging.eventhandling, org.axonframework.messaging.monitori...
# 3                                                                                                                                                                                                                                            [org.axonframework.common.configuration, org.axonframework.common]
# 4                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 5                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 6                                                                                                                                                                                                                                                                                 [org.axonframework.modelling]
# 7                                                                                                                                                                                                                                                           [org.axonframework.extension.springboot.autoconfig]
# 8   [org.axonframework.messaging.commandhandling, org.axonframework.messaging.core, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core.conversion, org.axonframework.messaging.eventstreaming, org.axonframework.messaging.eventhandling.processing.streaming.token, org.axonframew...
# 9                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 10                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 11                                                                                                                                                                                                              [org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common]
# 12                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 13                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 14                                                                                                                                                                                                      [org.axonframework.common.annotation, org.axonframework.common, org.axonframework.common.configuration]
# 15                                                                                                                                                                                                                                                                     [org.axonframework.axonserver.connector]
# 16  [org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core, org.axonframework.messaging.commandhandling, org.axonframework.messaging.queryhandling.configuration, org.axonframework.messaging.commandhandling.configuration, org.axonfram...
# 17                                                                                                                                                                      [org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.annotation]
# 18  [org.axonframework.messaging.eventhandling.processing.subscribing, org.axonframework.messaging.eventstreaming, org.axonframework.messaging.eventhandling.processing.streaming, org.axonframework.messaging.core, org.axonframework.messaging.eventhandling.processing, org.axonframework.messaging.event...
# 19  [org.axonframework.messaging.eventhandling.annotation, org.axonframework.messaging.eventstreaming, org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core, org.axonframework.messaging.eventhandling.processing.streaming.token, org.a...
# 20  [org.axonframework.messaging.core.timeout, org.axonframework.messaging.core.conversion, org.axonframework.messaging.core.unitofwork.transaction.jpa, org.axonframework.messaging.core.annotation, org.axonframework.messaging.core, org.axonframework.messaging.eventhandling, org.axonframework.messagi...
# 21                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.eventstore]
# 22                                                                                                                                         [org.axonframework.common.annotation, org.axonframework.common.jpa, org.axonframework.common.jdbc, org.axonframework.common.configuration, org.axonframework.common]
# 23                                                                                                                                   [org.axonframework.common.infra, org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.property, org.axonframework.common.annotation]
# 24                                                                                                   [org.axonframework.common, org.axonframework.common.annotation, org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.lifecycle, org.axonframework.common.util]
# 25                                                                                                                                                                                                                                         [org.axonframework.conversion, org.axonframework.conversion.jackson]
# 26                                     [org.axonframework.common, org.axonframework.common.tx, org.axonframework.common.function, org.axonframework.common.annotation, org.axonframework.common.configuration, org.axonframework.common.infra, org.axonframework.common.lifecycle, org.axonframework.common.io]
# 27                                               [org.axonframework.common.infra, org.axonframework.common.configuration, org.axonframework.common, org.axonframework.common.annotation, org.axonframework.common.jpa, org.axonframework.common.tx, org.axonframework.common.jdbc, org.axonframework.common.io]
# 28                                                                                                                                                                                                       [org.axonframework.update.configuration, org.axonframework.update.detection, org.axonframework.update]
# 29                                                                                                                                                                                       [org.axonframework.test, org.axonframework.test.util, org.axonframework.test.matchers, org.axonframework.test.fixture]
#
#                                                                                                                                                        dependentPackageNames
# 0                                                                                                                                                            [core, tracing]
# 1                                                                                                                                                                   [common]
# 2                                                                               [core, processing, monitoring, commandhandling, queryhandling, eventhandling, configuration]
# 3                                                                                                                                                    [configuration, common]
# 4                                                                                                                                                               [eventstore]
# 5                                                                                                                                                               [eventstore]
# 6                                                                                                                                                                [modelling]
# 7                                                                                                                                                               [autoconfig]
# 8                                                              [commandhandling, core, eventhandling, conversion, eventstreaming, token, unitofwork, annotation, monitoring]
# 9                                                                                                                                                                   [server]
# 10                                                                                                                                                              [conversion]
# 11                                                                                                                                               [infra, annotation, common]
# 12                                                                                                                                                              [conversion]
# 13                                                                                                                                                              [conversion]
# 14                                                                                                                                       [annotation, common, configuration]
# 15                                                                                                                                                               [connector]
# 16                                                                     [unitofwork, eventhandling, core, commandhandling, configuration, conversion, annotation, reflection]
# 17                                                                                                                                [common, configuration, infra, annotation]
# 18  [subscribing, eventstreaming, streaming, core, processing, token, conversion, unitofwork, segmenting, store, eventhandling, distributed, commandhandling, queryhandling]
# 19                               [annotation, eventstreaming, unitofwork, eventhandling, core, token, conversion, commandhandling, configuration, interception, transaction]
# 20                   [timeout, conversion, jpa, annotation, core, eventhandling, correlation, interception, commandhandling, distributed, queryhandling, store, transaction]
# 21                                                                                                                                                         [jpa, eventstore]
# 22                                                                                                                            [annotation, jpa, jdbc, configuration, common]
# 23                                                                                                                      [infra, common, configuration, property, annotation]
# 24                                                                                                               [common, annotation, configuration, infra, lifecycle, util]
# 25                                                                                                                                                     [conversion, jackson]
# 26                                                                                                   [common, tx, function, annotation, configuration, infra, lifecycle, io]
# 27                                                                                                             [infra, configuration, common, annotation, jpa, tx, jdbc, io]
# 28                                                                                                                                        [configuration, detection, update]
# 29                                                                                                                                           [test, util, matchers, fixture]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                         artifactName                 dependentArtifactName  \
# 0               axon-modelling-5.0.3                  axon-messaging-5.0.3
# 1                    axon-test-5.0.3                  axon-messaging-5.0.3
# 2           axon-eventsourcing-5.0.3                  axon-messaging-5.0.3
# 3           axon-eventsourcing-5.0.3                  axon-messaging-5.0.3
# 4           axon-eventsourcing-5.0.3                     axon-common-5.0.3
# 5               axon-messaging-5.0.3                     axon-common-5.0.3
# 6               axon-messaging-5.0.3                     axon-common-5.0.3
# 7               axon-modelling-5.0.3                     axon-common-5.0.3
# 8           axon-eventsourcing-5.0.3                     axon-common-5.0.3
# 9      axon-metrics-micrometer-5.0.3  axon-spring-boot-autoconfigure-5.0.3
# 10  axon-tracing-opentelemetry-5.0.3                  axon-messaging-5.0.3
# 11             axon-conversion-5.0.3                     axon-common-5.0.3
# 12              axon-messaging-5.0.3                     axon-common-5.0.3
# 13              axon-messaging-5.0.3                     axon-common-5.0.3
# 14                   axon-test-5.0.3                     axon-common-5.0.3
# 15              axon-messaging-5.0.3                     axon-common-5.0.3
# 16              axon-messaging-5.0.3                     axon-common-5.0.3
# 17              axon-modelling-5.0.3                     axon-common-5.0.3
# 18              axon-messaging-5.0.3                     axon-common-5.0.3
# 19  axon-tracing-opentelemetry-5.0.3                     axon-common-5.0.3
# 20              axon-messaging-5.0.3                     axon-common-5.0.3
# 21              axon-messaging-5.0.3                     axon-common-5.0.3
# 22                   axon-test-5.0.3                     axon-common-5.0.3
# 23                   axon-test-5.0.3                     axon-common-5.0.3
# 24                 axon-update-5.0.3                     axon-common-5.0.3
# 25          axon-eventsourcing-5.0.3                     axon-common-5.0.3
# 26              axon-messaging-5.0.3                     axon-common-5.0.3
# 27              axon-messaging-5.0.3                     axon-common-5.0.3
# 28              axon-messaging-5.0.3                     axon-common-5.0.3
# 29              axon-messaging-5.0.3                     axon-common-5.0.3
#
#                                                                    packageName  \
# 0                                       org.axonframework.modelling.repository
# 1                                              org.axonframework.test.matchers
# 2                                org.axonframework.eventsourcing.configuration
# 3                                org.axonframework.eventsourcing.configuration
# 4                                   org.axonframework.eventsourcing.annotation
# 5                                  org.axonframework.messaging.core.unitofwork
# 6                                             org.axonframework.messaging.core
# 7                                org.axonframework.modelling.entity.annotation
# 8                        org.axonframework.eventsourcing.annotation.reflection
# 9                    org.axonframework.extension.metrics.micrometer.springboot
# 10                           org.axonframework.extension.tracing.opentelemetry
# 11                                           org.axonframework.conversion.avro
# 12                         org.axonframework.messaging.commandhandling.tracing
# 13  org.axonframework.messaging.eventhandling.processing.streaming.token.store
# 14                                                 org.axonframework.test.util
# 15                    org.axonframework.messaging.core.interception.annotation
# 16                      org.axonframework.messaging.core.unitofwork.annotation
# 17                                      org.axonframework.modelling.repository
# 18                    org.axonframework.messaging.commandhandling.interception
# 19                           org.axonframework.extension.tracing.opentelemetry
# 20                        org.axonframework.messaging.monitoring.configuration
# 21                                  org.axonframework.messaging.eventstreaming
# 22                                               org.axonframework.test.server
# 23                                            org.axonframework.test.extension
# 24                                                    org.axonframework.update
# 25                                  org.axonframework.eventsourcing.annotation
# 26                        org.axonframework.messaging.eventhandling.processing
# 27                           org.axonframework.messaging.eventhandling.tracing
# 28                                      org.axonframework.messaging.monitoring
# 29                     org.axonframework.messaging.queryhandling.configuration
#
#                                  dependentPackage.fqn  dependentTypes  \
# 0                    org.axonframework.messaging.core               1
# 1                    org.axonframework.messaging.core               1
# 2                    org.axonframework.messaging.core               1
# 3         org.axonframework.messaging.core.annotation               1
# 4              org.axonframework.common.configuration               1
# 5              org.axonframework.common.configuration               1
# 6              org.axonframework.common.configuration               1
# 7              org.axonframework.common.configuration               1
# 8              org.axonframework.common.configuration               1
# 9   org.axonframework.extension.springboot.autoconfig               1
# 10                   org.axonframework.messaging.core               2
# 11                           org.axonframework.common               1
# 12                           org.axonframework.common               1
# 13                           org.axonframework.common               1
# 14                           org.axonframework.common               1
# 15                           org.axonframework.common               1
# 16                           org.axonframework.common               1
# 17                           org.axonframework.common               1
# 18                           org.axonframework.common               1
# 19                           org.axonframework.common               1
# 20                           org.axonframework.common               1
# 21                           org.axonframework.common               1
# 22                           org.axonframework.common               1
# 23                           org.axonframework.common               1
# 24                           org.axonframework.common               1
# 25                           org.axonframework.common               1
# 26                           org.axonframework.common               1
# 27                           org.axonframework.common               1
# 28                           org.axonframework.common               1
# 29                           org.axonframework.common               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      80             0.012500
# 1                      80             0.012500
# 2                      80             0.012500
# 3                      51             0.019608
# 4                      46             0.021739
# 5                      46             0.021739
# 6                      46             0.021739
# 7                      46             0.021739
# 8                      46             0.021739
# 9                      41             0.024390
# 10                     80             0.025000
# 11                     34             0.029412
# 12                     34             0.029412
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     34             0.029412
# 17                     34             0.029412
# 18                     34             0.029412
# 19                     34             0.029412
# 20                     34             0.029412
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                     34             0.029412
# 26                     34             0.029412
# 27                     34             0.029412
# 28                     34             0.029412
# 29                     34             0.029412
#
#                                                                        dependentTypeNames
# 0                                  [org.axonframework.messaging.core.Context$ResourceKey]
# 1                                              [org.axonframework.messaging.core.Message]
# 2                                  [org.axonframework.messaging.core.MessageTypeResolver]
# 3                  [org.axonframework.messaging.core.annotation.ParameterResolverFactory]
# 4                                  [org.axonframework.common.configuration.Configuration]
# 5                     [org.axonframework.common.configuration.ComponentNotFoundException]
# 6                                  [org.axonframework.common.configuration.Configuration]
# 7                                  [org.axonframework.common.configuration.Configuration]
# 8                                  [org.axonframework.common.configuration.Configuration]
# 9               [org.axonframework.extension.springboot.autoconfig.AxonAutoConfiguration]
# 10  [org.axonframework.messaging.core.Metadata, org.axonframework.messaging.core.Message]
# 11                                                [org.axonframework.common.BuilderUtils]
# 12                                                [org.axonframework.common.BuilderUtils]
# 13                                      [org.axonframework.common.AxonTransientException]
# 14                                                 [org.axonframework.common.ObjectUtils]
# 15                                  [org.axonframework.common.AxonConfigurationException]
# 16                                                    [org.axonframework.common.Priority]
# 17                                                 [org.axonframework.common.FutureUtils]
# 18                                                 [org.axonframework.common.FutureUtils]
# 19                                                [org.axonframework.common.BuilderUtils]
# 20                                               [org.axonframework.common.TypeReference]
# 21                                                      [org.axonframework.common.Assert]
# 22                                                      [org.axonframework.common.Assert]
# 23                                             [org.axonframework.common.ReflectionUtils]
# 24                                                 [org.axonframework.common.ObjectUtils]
# 25                                             [org.axonframework.common.ReflectionUtils]
# 26                                               [org.axonframework.common.AxonException]
# 27                                                [org.axonframework.common.BuilderUtils]
# 28                                                      [org.axonframework.common.Assert]
# 29                                                 [org.axonframework.common.FutureUtils]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                  jakarta.annotation.Nonnull
# 1                                                  jakarta.annotation.Nonnull
# 2                                                 jakarta.annotation.Nullable
# 3                                                 jakarta.annotation.Nullable
# 4                                org.axonframework.common.annotation.Internal
# 5                                                  jakarta.annotation.Nonnull
# 6                                               java.lang.FunctionalInterface
# 7                                 org.springframework.context.annotation.Bean
# 8                                                 java.lang.annotation.Target
# 9                                              java.lang.annotation.Retention
# 10  org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 11                   org.springframework.boot.autoconfigure.AutoConfiguration
# 12                               org.axonframework.common.annotation.Internal
# 13                               org.axonframework.common.annotation.Internal
# 14                                            java.lang.annotation.Documented
# 15                              com.fasterxml.jackson.annotation.JsonProperty
# 16                                          org.axonframework.common.Priority
# 17     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 18                               org.axonframework.common.annotation.Internal
# 19  org.springframework.boot.context.properties.EnableConfigurationProperties
# 20        org.springframework.boot.context.properties.ConfigurationProperties
# 21        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 22                                                  jakarta.persistence.Basic
# 23                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 24     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 25    org.springframework.boot.context.properties.NestedConfigurationProperty
# 26                                                      java.lang.SafeVarargs
# 27                                                       java.lang.Deprecated
# 28                         org.springframework.context.annotation.Conditional
# 29                               com.fasterxml.jackson.annotation.JsonCreator
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       3497
# 1           Method                        865
# 2        Parameter                        395
# 3           Method                        112
# 4            Class                         83
# 5            Field                         72
# 6        Interface                         59
# 7           Method                         45
# 8       Annotation                         42
# 9       Annotation                         42
# 10          Method                         23
# 11           Class                         21
# 12       Interface                         18
# 13     Constructor                         17
# 14      Annotation                         15
# 15       Parameter                         12
# 16           Class                         12
# 17           Class                         12
# 18          Method                         11
# 19           Class                         11
# 20           Class                         10
# 21           Class                          9
# 22           Field                          8
# 23           Class                          8
# 24          Method                          8
# 25           Field                          8
# 26     Constructor                          7
# 27          Method                          7
# 28          Method                          7
# 29     Constructor                          6
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.test.fixture.RecordingCommandBus.<init>(0), org.axonframework.test.fixture.RecordingCommandBus.dispatch(0), org.axonframework.test.fixture.RecordingCommandBus.subscribe(0), org.axonframework.test.fixture.RecordingCommandBus.subscribe(1), org.axonframework.test.fixture.Recordin...
# 1   [org.axonframework.test.extension.ProvidedAxonTestFixtureUtils.getAxonTestFixtureProvider, org.axonframework.test.FixtureResourceParameterResolverFactory$FailingParameterResolver.resolveParameterValue, org.axonframework.common.util.ExecutorServiceFactory.createExecutorService, org.axonframework....
# 2   [org.axonframework.test.fixture.RecordingCommandBus.dispatch(1), org.axonframework.test.fixture.AxonTestThenCommand.<init>(4), org.axonframework.test.fixture.AxonTestThenNothing.<init>(3), org.axonframework.test.fixture.RecordingEventSink.publish(0), org.axonframework.test.fixture.AxonTestThenMe...
# 3   [org.axonframework.test.fixture.RecordingCommandBus.resultOf, org.axonframework.test.extension.AxonFrameworkExtension.resolveParameter, org.axonframework.common.ReflectionUtils.declaringClass, org.axonframework.common.FutureUtils.joinAndUnwrap, org.axonframework.common.configuration.AbstractComp...
# 4   [org.axonframework.test.fixture.RecordingComponentsRegistry, org.axonframework.test.fixture.RecordingCommandBus, org.axonframework.test.fixture.RecordingEventSink, org.axonframework.test.fixture.MessagesRecordingConfigurationEnhancer, org.axonframework.test.util.RecordingCommandBus, org.axonfram...
# 5   [org.axonframework.test.fixture.AxonTestFixture$Customization.fieldFilters, org.axonframework.common.configuration.AbstractComponent$HandlerRegistration.handler, org.axonframework.common.configuration.Component$Identifier.type, org.axonframework.eventsourcing.eventstore.DefaultAppendCondition.co...
# 6   [org.axonframework.test.extension.AxonTestFixtureProvider, org.axonframework.test.matchers.FieldFilter, org.axonframework.common.jdbc.JdbcUtils$SqlResultConverter, org.axonframework.common.jdbc.ConnectionProvider, org.axonframework.common.jdbc.JdbcUtils$SqlFunction, org.axonframework.common.util...
# 7   [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.disableMetricsConfigurationEnhancer, org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.meterRegistry, org.axonframework.extension.metrics.micrometer.springboot...
# 8   [org.axonframework.test.extension.ProvidedAxonTestFixture, org.axonframework.common.annotation.Internal, org.axonframework.common.Priority, org.axonframework.eventsourcing.annotation.EventSourcedEntity, org.axonframework.eventsourcing.annotation.EventTag, org.axonframework.eventsourcing.annotati...
# 9   [org.axonframework.test.extension.ProvidedAxonTestFixture, org.axonframework.common.annotation.Internal, org.axonframework.common.Priority, org.axonframework.eventsourcing.annotation.EventSourcedEntity, org.axonframework.eventsourcing.annotation.EventTag, org.axonframework.eventsourcing.annotati...
# 10  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.meterRegistry, org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.metricsConfigurationEnhancer, org.axonframework.extension.springboot.autoconfig.JdbcTransactio...
# 11  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration, org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboo...
# 12  [org.axonframework.common.jdbc.ConnectionProvider, org.axonframework.common.tx.TransactionalExecutor, org.axonframework.common.jpa.EntityManagerProvider, org.axonframework.common.configuration.Component, org.axonframework.eventsourcing.eventstore.EventCoordinator, org.axonframework.eventsourcing...
# 13  [org.axonframework.eventsourcing.eventstore.InterceptingEventStore.<init>, org.axonframework.conversion.jackson2.Jackson2Converter.<init>, org.axonframework.conversion.jackson.JacksonConverter.<init>, org.axonframework.conversion.avro.AvroConverter.<init>, org.axonframework.messaging.eventhandli...
# 14  [org.axonframework.common.annotation.Internal, org.axonframework.eventsourcing.annotation.EventSourcingHandler, org.axonframework.messaging.commandhandling.annotation.CommandHandler, org.axonframework.messaging.eventhandling.annotation.EventHandler, org.axonframework.messaging.eventhandling.repl...
# 15  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(0), org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(1), org.axonframework.messaging.eventhandling.processing.streaming.token.store.ConfigToken.<ini...
# 16  [org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.messaging.eventhandling.annotation.SequenceNumberParameterResolverFactory, org.axonframework.messaging.eventhandling.annotation.TimestampParameterResolverFactory, org.axonframework.messaging.core.annotation.Hierar...
# 17  [org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration$AvroConfiguredCondition$MessagesAvroCondition, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration$Av...
# 18  [org.axonframework.messaging.eventhandling.conversion.DelegatingEventConverter.delegate, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jdbc.JdbcTokenStore.converter, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jpa.JpaTokenStore.converte...
# 19  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extension.springboot...
# 20  [org.axonframework.extension.metrics.micrometer.springboot.MetricsProperties, org.axonframework.axonserver.connector.AxonServerConfiguration, org.axonframework.extension.springboot.DistributedCommandBusProperties, org.axonframework.extension.springboot.TokenStoreProperties, org.axonframework.ext...
# 21  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration, org.axonframework.extension.spring...
# 22  [org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.type, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.version, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.timestamp, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.p...
# 23  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration, org.axonframework.extension.springboot.autoconfig.CorrelationDataProviderAutoConfiguration, org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration, org.axonframework.extensio...
# 24  [org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.disableMetricsConfigurationEnhancer, org.axonframework.extension.metrics.micrometer.springboot.MicrometerMetricsAutoConfiguration.meterRegistry, org.axonframework.extension.metrics.micrometer.springboot...
# 25  [org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.events, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.commands, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.queries, o...
# 26  [org.axonframework.test.matchers.SequenceMatcher.<init>, org.axonframework.test.matchers.ListMatcher.<init>, org.axonframework.test.matchers.ExactSequenceMatcher.<init>, org.axonframework.test.matchers.ListWithAllOfMatcher.<init>, org.axonframework.test.matchers.ListWithAnyOfMatcher.<init>, org....
# 27  [org.axonframework.test.fixture.AxonTestThenCommand.resultMessagePayloadSatisfies, org.axonframework.test.fixture.AxonTestPhase$Then$Command.resultMessagePayloadSatisfies, org.axonframework.messaging.core.GenericResultMessage.asResultMessage, org.axonframework.messaging.core.annotation.MessageHa...
# 28  [org.axonframework.extension.springboot.autoconfig.Jackson2MapperAutoConfiguration.defaultAxonJackson2Mapper, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration.defaultAxonSchemaStore, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfigurat...
# 29  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.store.ConfigToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.ReplayToken.<init>, org.axonfram...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2125                      881                          921
# 1                   100                       86                           41
# 2                  2138                      631                          420
# 3                  2104                      679                          322
#
#                                                                                                                                                                                                                                                                                                       examples
# 0                      [/axon-spring-boot-autoconfigure-5.0.3.jar uses /axon-test-5.0.3.jar, /org/axonframework/test/extension uses /org/axonframework/test/fixture, /org/axonframework/test/fixture uses /org/axonframework/test/util, /org/axonframework/test/fixture uses /org/axonframework/test/matchers]
# 1                                                  [/org/axonframework/test/matchers uses /org/axonframework/test, /org/axonframework/test/extension uses /org/axonframework/test, /org/axonframework/test/fixture uses /org/axonframework/test, /org/axonframework/common/jpa uses /org/axonframework/common]
# 2  [/org/axonframework/test/fixture/AxonTestFixture$Customization.class uses /org/axonframework/test/matchers/FieldFilter.class, /org/axonframework/test/fixture/CommandValidator.class uses /org/axonframework/test/matchers/FieldFilter.class, /org/axonframework/test/fixture/AxonTestFixture$Customizat...
# 3  [/org/axonframework/extension/springboot/service/connection uses /org/axonframework/test/server, /org/axonframework/extension/springboot/service/connection/AxonServerTestContainerConnectionDetailsFactory.class uses /org/axonframework/test/server/AxonServerContainer.class, /org/axonframework/exte...
