# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())
    

def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-5.0.3.jar  axon-common-5.0.3.jar  \
# effectiveLineCount
# 1                                       1933                    369
# 2                                        524                    145
# 3                                        424                     97
# 4                                        191                     38
# 5                                        159                     36
# 6                                         93                     36
# 7                                         76                     15
# 8                                         68                     18
# 9                                         39                     11
# 10                                        26                      7
# 11                                        20                      6
# 12                                         6                      7
# 13                                        10                      5
# 14                                         6                      5
# 15                                         6                      1
# 16                                         6                      2
# 17                                         4                      3
# 18                                         1                      1
# 19                                         3                      0
# 20                                         3                      0
# 21                                         1                      0
# 22                                         2                      0
# 23                                         1                      0
# 24                                         0                      1
# 25                                         2                      0
# 26                                         0                      1
# 27                                         1                      0
# 28                                         0                      0
# 29                                         0                      0
# 30                                         0                      0
# 31                                         2                      0
# 36                                         1                      0
# 38                                         0                      0
# 40                                         0                      0
# 41                                         0                      0
# 42                                         0                      0
# 45                                         0                      0
# 111                                        1                      0
#
# artifactName        axon-server-connector-5.0.3.jar  \
# effectiveLineCount
# 1                                               266
# 2                                               143
# 3                                                77
# 4                                                44
# 5                                                33
# 6                                                15
# 7                                                 9
# 8                                                15
# 9                                                11
# 10                                                7
# 11                                                2
# 12                                                3
# 13                                                2
# 14                                                2
# 15                                                1
# 16                                                1
# 17                                                2
# 18                                                1
# 19                                                0
# 20                                                1
# 21                                                2
# 22                                                0
# 23                                                0
# 24                                                0
# 25                                                0
# 26                                                0
# 27                                                0
# 28                                                1
# 29                                                0
# 30                                                1
# 31                                                0
# 36                                                0
# 38                                                0
# 40                                                0
# 41                                                0
# 42                                                1
# 45                                                0
# 111                                               0
#
# artifactName        axon-eventsourcing-5.0.3.jar  axon-test-5.0.3.jar  \
# effectiveLineCount
# 1                                            301                  212
# 2                                             75                   73
# 3                                             58                   36
# 4                                             53                   40
# 5                                             31                    6
# 6                                             16                   15
# 7                                             14                    9
# 8                                              6                    8
# 9                                             10                    8
# 10                                             7                    5
# 11                                             5                    4
# 12                                             3                    9
# 13                                             4                    2
# 14                                             3                    1
# 15                                             1                    3
# 16                                             1                    3
# 17                                             1                    0
# 18                                             0                    2
# 19                                             1                    0
# 20                                             1                    2
# 21                                             1                    1
# 22                                             0                    0
# 23                                             0                    1
# 24                                             0                    0
# 25                                             0                    0
# 26                                             0                    1
# 27                                             1                    0
# 28                                             0                    0
# 29                                             0                    0
# 30                                             1                    0
# 31                                             0                    1
# 36                                             0                    0
# 38                                             0                    0
# 40                                             1                    0
# 41                                             0                    0
# 42                                             0                    0
# 45                                             0                    1
# 111                                            0                    0
#
# artifactName        axon-modelling-5.0.3.jar  \
# effectiveLineCount
# 1                                        162
# 2                                         54
# 3                                         28
# 4                                         35
# 5                                         22
# 6                                         17
# 7                                          9
# 8                                         11
# 9                                         12
# 10                                         2
# 11                                         1
# 12                                         4
# 13                                         4
# 14                                         1
# 15                                         1
# 16                                         1
# 17                                         1
# 18                                         2
# 19                                         0
# 20                                         0
# 21                                         1
# 22                                         0
# 23                                         0
# 24                                         0
# 25                                         0
# 26                                         0
# 27                                         0
# 28                                         0
# 29                                         0
# 30                                         0
# 31                                         0
# 36                                         0
# 38                                         0
# 40                                         0
# 41                                         0
# 42                                         0
# 45                                         0
# 111                                        0
#
# artifactName        axon-spring-boot-autoconfigure-5.0.3.jar  \
# effectiveLineCount
# 1                                                        186
# 2                                                         74
# 3                                                         16
# 4                                                          6
# 5                                                          8
# 6                                                          8
# 7                                                          5
# 8                                                          2
# 9                                                          1
# 10                                                         1
# 11                                                         0
# 12                                                         1
# 13                                                         1
# 14                                                         0
# 15                                                         0
# 16                                                         0
# 17                                                         1
# 18                                                         0
# 19                                                         0
# 20                                                         0
# 21                                                         0
# 22                                                         0
# 23                                                         1
# 24                                                         0
# 25                                                         0
# 26                                                         0
# 27                                                         0
# 28                                                         0
# 29                                                         0
# 30                                                         0
# 31                                                         0
# 36                                                         0
# 38                                                         1
# 40                                                         0
# 41                                                         0
# 42                                                         0
# 45                                                         0
# 111                                                        0
#
# artifactName        axon-conversion-5.0.3.jar  axon-update-5.0.3.jar  \
# effectiveLineCount
# 1                                         116                     88
# 2                                          22                     10
# 3                                          16                      6
# 4                                           8                     10
# 5                                          10                      8
# 6                                           7                      8
# 7                                           4                      2
# 8                                           6                      2
# 9                                           4                      4
# 10                                          1                      2
# 11                                          2                      0
# 12                                          0                      1
# 13                                          1                      3
# 14                                          0                      2
# 15                                          1                      0
# 16                                          2                      1
# 17                                          1                      2
# 18                                          0                      1
# 19                                          1                      0
# 20                                          0                      0
# 21                                          0                      2
# 22                                          0                      0
# 23                                          0                      0
# 24                                          0                      1
# 25                                          0                      0
# 26                                          0                      0
# 27                                          0                      0
# 28                                          0                      0
# 29                                          2                      0
# 30                                          1                      0
# 31                                          0                      0
# 36                                          0                      0
# 38                                          0                      0
# 40                                          0                      0
# 41                                          0                      1
# 42                                          0                      0
# 45                                          0                      0
# 111                                         0                      0
#
# artifactName        axon-metrics-micrometer-5.0.3.jar  \
# effectiveLineCount
# 1                                                  46
# 2                                                  18
# 3                                                  20
# 4                                                   8
# 5                                                   2
# 6                                                   4
# 7                                                   3
# 8                                                   4
# 9                                                   1
# 10                                                  1
# 11                                                  0
# 12                                                  0
# 13                                                  0
# 14                                                  0
# 15                                                  1
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 36                                                  0
# 38                                                  0
# 40                                                  0
# 41                                                  0
# 42                                                  0
# 45                                                  0
# 111                                                 0
#
# artifactName        axon-tracing-opentelemetry-5.0.3.jar
# effectiveLineCount
# 1                                                     11
# 2                                                      4
# 3                                                     10
# 4                                                      7
# 5                                                      2
# 6                                                      3
# 7                                                      2
# 8                                                      0
# 9                                                      1
# 10                                                     0
# 11                                                     0
# 12                                                     1
# 13                                                     0
# 14                                                     0
# 15                                                     0
# 16                                                     0
# 17                                                     0
# 18                                                     0
# 19                                                     0
# 20                                                     0
# 21                                                     0
# 22                                                     0
# 23                                                     0
# 24                                                     0
# 25                                                     0
# 26                                                     0
# 27                                                     0
# 28                                                     0
# 29                                                     0
# 30                                                     0
# 31                                                     0
# 36                                                     0
# 38                                                     0
# 40                                                     0
# 41                                                     0
# 42                                                     0
# 45                                                     0
# 111                                                    0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-5.0.3.jar  axon-common-5.0.3.jar  \
# effectiveLineCount
# 1                                  53.560543              45.895522
# 2                                  14.519257              18.034826
# 3                                  11.748407              12.064677
# 4                                   5.292325               4.726368
# 5                                   4.405653               4.477612
# 6                                   2.576891               4.477612
# 7                                   2.105846               1.865672
# 8                                   1.884178               2.238806
# 9                                   1.080632               1.368159
# 10                                  0.720421               0.870647
# 11                                  0.554170               0.746269
# 12                                  0.166251               0.870647
# 13                                  0.277085               0.621891
# 14                                  0.166251               0.621891
# 15                                  0.166251               0.124378
# 16                                  0.166251               0.248756
# 17                                  0.110834               0.373134
# 18                                  0.027709               0.124378
# 19                                  0.083126               0.000000
# 20                                  0.083126               0.000000
# 21                                  0.027709               0.000000
# 22                                  0.055417               0.000000
# 23                                  0.027709               0.000000
# 24                                  0.000000               0.124378
# 25                                  0.055417               0.000000
# 26                                  0.000000               0.124378
# 27                                  0.027709               0.000000
# 28                                  0.000000               0.000000
# 29                                  0.000000               0.000000
# 30                                  0.000000               0.000000
# 31                                  0.055417               0.000000
# 36                                  0.027709               0.000000
# 38                                  0.000000               0.000000
# 40                                  0.000000               0.000000
# 41                                  0.000000               0.000000
# 42                                  0.000000               0.000000
# 45                                  0.000000               0.000000
# 111                                 0.027709               0.000000
#
# artifactName        axon-server-connector-5.0.3.jar  \
# effectiveLineCount
# 1                                          41.56250
# 2                                          22.34375
# 3                                          12.03125
# 4                                           6.87500
# 5                                           5.15625
# 6                                           2.34375
# 7                                           1.40625
# 8                                           2.34375
# 9                                           1.71875
# 10                                          1.09375
# 11                                          0.31250
# 12                                          0.46875
# 13                                          0.31250
# 14                                          0.31250
# 15                                          0.15625
# 16                                          0.15625
# 17                                          0.31250
# 18                                          0.15625
# 19                                          0.00000
# 20                                          0.15625
# 21                                          0.31250
# 22                                          0.00000
# 23                                          0.00000
# 24                                          0.00000
# 25                                          0.00000
# 26                                          0.00000
# 27                                          0.00000
# 28                                          0.15625
# 29                                          0.00000
# 30                                          0.15625
# 31                                          0.00000
# 36                                          0.00000
# 38                                          0.00000
# 40                                          0.00000
# 41                                          0.00000
# 42                                          0.15625
# 45                                          0.00000
# 111                                         0.00000
#
# artifactName        axon-eventsourcing-5.0.3.jar  axon-test-5.0.3.jar  \
# effectiveLineCount
# 1                                      50.588235            47.855530
# 2                                      12.605042            16.478555
# 3                                       9.747899             8.126411
# 4                                       8.907563             9.029345
# 5                                       5.210084             1.354402
# 6                                       2.689076             3.386005
# 7                                       2.352941             2.031603
# 8                                       1.008403             1.805869
# 9                                       1.680672             1.805869
# 10                                      1.176471             1.128668
# 11                                      0.840336             0.902935
# 12                                      0.504202             2.031603
# 13                                      0.672269             0.451467
# 14                                      0.504202             0.225734
# 15                                      0.168067             0.677201
# 16                                      0.168067             0.677201
# 17                                      0.168067             0.000000
# 18                                      0.000000             0.451467
# 19                                      0.168067             0.000000
# 20                                      0.168067             0.451467
# 21                                      0.168067             0.225734
# 22                                      0.000000             0.000000
# 23                                      0.000000             0.225734
# 24                                      0.000000             0.000000
# 25                                      0.000000             0.000000
# 26                                      0.000000             0.225734
# 27                                      0.168067             0.000000
# 28                                      0.000000             0.000000
# 29                                      0.000000             0.000000
# 30                                      0.168067             0.000000
# 31                                      0.000000             0.225734
# 36                                      0.000000             0.000000
# 38                                      0.000000             0.000000
# 40                                      0.168067             0.000000
# 41                                      0.000000             0.000000
# 42                                      0.000000             0.000000
# 45                                      0.000000             0.225734
# 111                                     0.000000             0.000000
#
# artifactName        axon-modelling-5.0.3.jar  \
# effectiveLineCount
# 1                                  44.021739
# 2                                  14.673913
# 3                                   7.608696
# 4                                   9.510870
# 5                                   5.978261
# 6                                   4.619565
# 7                                   2.445652
# 8                                   2.989130
# 9                                   3.260870
# 10                                  0.543478
# 11                                  0.271739
# 12                                  1.086957
# 13                                  1.086957
# 14                                  0.271739
# 15                                  0.271739
# 16                                  0.271739
# 17                                  0.271739
# 18                                  0.543478
# 19                                  0.000000
# 20                                  0.000000
# 21                                  0.271739
# 22                                  0.000000
# 23                                  0.000000
# 24                                  0.000000
# 25                                  0.000000
# 26                                  0.000000
# 27                                  0.000000
# 28                                  0.000000
# 29                                  0.000000
# 30                                  0.000000
# 31                                  0.000000
# 36                                  0.000000
# 38                                  0.000000
# 40                                  0.000000
# 41                                  0.000000
# 42                                  0.000000
# 45                                  0.000000
# 111                                 0.000000
#
# artifactName        axon-spring-boot-autoconfigure-5.0.3.jar  \
# effectiveLineCount
# 1                                                  59.615385
# 2                                                  23.717949
# 3                                                   5.128205
# 4                                                   1.923077
# 5                                                   2.564103
# 6                                                   2.564103
# 7                                                   1.602564
# 8                                                   0.641026
# 9                                                   0.320513
# 10                                                  0.320513
# 11                                                  0.000000
# 12                                                  0.320513
# 13                                                  0.320513
# 14                                                  0.000000
# 15                                                  0.000000
# 16                                                  0.000000
# 17                                                  0.320513
# 18                                                  0.000000
# 19                                                  0.000000
# 20                                                  0.000000
# 21                                                  0.000000
# 22                                                  0.000000
# 23                                                  0.320513
# 24                                                  0.000000
# 25                                                  0.000000
# 26                                                  0.000000
# 27                                                  0.000000
# 28                                                  0.000000
# 29                                                  0.000000
# 30                                                  0.000000
# 31                                                  0.000000
# 36                                                  0.000000
# 38                                                  0.320513
# 40                                                  0.000000
# 41                                                  0.000000
# 42                                                  0.000000
# 45                                                  0.000000
# 111                                                 0.000000
#
# artifactName        axon-conversion-5.0.3.jar  axon-update-5.0.3.jar  \
# effectiveLineCount
# 1                                   56.585366              57.142857
# 2                                   10.731707               6.493506
# 3                                    7.804878               3.896104
# 4                                    3.902439               6.493506
# 5                                    4.878049               5.194805
# 6                                    3.414634               5.194805
# 7                                    1.951220               1.298701
# 8                                    2.926829               1.298701
# 9                                    1.951220               2.597403
# 10                                   0.487805               1.298701
# 11                                   0.975610               0.000000
# 12                                   0.000000               0.649351
# 13                                   0.487805               1.948052
# 14                                   0.000000               1.298701
# 15                                   0.487805               0.000000
# 16                                   0.975610               0.649351
# 17                                   0.487805               1.298701
# 18                                   0.000000               0.649351
# 19                                   0.487805               0.000000
# 20                                   0.000000               0.000000
# 21                                   0.000000               1.298701
# 22                                   0.000000               0.000000
# 23                                   0.000000               0.000000
# 24                                   0.000000               0.649351
# 25                                   0.000000               0.000000
# 26                                   0.000000               0.000000
# 27                                   0.000000               0.000000
# 28                                   0.000000               0.000000
# 29                                   0.975610               0.000000
# 30                                   0.487805               0.000000
# 31                                   0.000000               0.000000
# 36                                   0.000000               0.000000
# 38                                   0.000000               0.000000
# 40                                   0.000000               0.000000
# 41                                   0.000000               0.649351
# 42                                   0.000000               0.000000
# 45                                   0.000000               0.000000
# 111                                  0.000000               0.000000
#
# artifactName        axon-metrics-micrometer-5.0.3.jar  \
# effectiveLineCount
# 1                                           42.592593
# 2                                           16.666667
# 3                                           18.518519
# 4                                            7.407407
# 5                                            1.851852
# 6                                            3.703704
# 7                                            2.777778
# 8                                            3.703704
# 9                                            0.925926
# 10                                           0.925926
# 11                                           0.000000
# 12                                           0.000000
# 13                                           0.000000
# 14                                           0.000000
# 15                                           0.925926
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 36                                           0.000000
# 38                                           0.000000
# 40                                           0.000000
# 41                                           0.000000
# 42                                           0.000000
# 45                                           0.000000
# 111                                          0.000000
#
# artifactName        axon-tracing-opentelemetry-5.0.3.jar
# effectiveLineCount
# 1                                              26.829268
# 2                                               9.756098
# 3                                              24.390244
# 4                                              17.073171
# 5                                               4.878049
# 6                                               7.317073
# 7                                               4.878049
# 8                                               0.000000
# 9                                               2.439024
# 10                                              0.000000
# 11                                              0.000000
# 12                                              2.439024
# 13                                              0.000000
# 14                                              0.000000
# 15                                              0.000000
# 16                                              0.000000
# 17                                              0.000000
# 18                                              0.000000
# 19                                              0.000000
# 20                                              0.000000
# 21                                              0.000000
# 22                                              0.000000
# 23                                              0.000000
# 24                                              0.000000
# 25                                              0.000000
# 26                                              0.000000
# 27                                              0.000000
# 28                                              0.000000
# 29                                              0.000000
# 30                                              0.000000
# 31                                              0.000000
# 36                                              0.000000
# 38                                              0.000000
# 40                                              0.000000
# 41                                              0.000000
# 42                                              0.000000
# 45                                              0.000000
# 111                                             0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
if effective_method_line_count_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,20)
    axes = effective_method_line_count_distribution_normalized.head(20).plot(
        kind='line',
        logx=True,
        grid=True,
        xlim=[2, 20],
        ylim=[0, 20],
        xticks=method_line_count_x_ticks,
        title='Effective Method Line Count Distribution', 
        xlabel='effective line count',
        ylabel='percent of methods',
        cmap=main_color_map,
        figsize=(10, 6),
        lw=2,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.3
# 1                   axon-messaging-5.0.3
# 2                        axon-test-5.0.3
# 3                      axon-common-5.0.3
# 4                   axon-messaging-5.0.3
# 5            axon-server-connector-5.0.3
# 6                      axon-common-5.0.3
# 7               axon-eventsourcing-5.0.3
# 8            axon-server-connector-5.0.3
# 9                   axon-messaging-5.0.3
# 10              axon-eventsourcing-5.0.3
# 11                  axon-messaging-5.0.3
# 12                  axon-messaging-5.0.3
# 13  axon-spring-boot-autoconfigure-5.0.3
# 14           axon-server-connector-5.0.3
# 15                  axon-messaging-5.0.3
# 16                       axon-test-5.0.3
# 17                  axon-modelling-5.0.3
# 18                 axon-conversion-5.0.3
# 19                  axon-modelling-5.0.3
# 20                  axon-messaging-5.0.3
# 21                  axon-messaging-5.0.3
# 22         axon-metrics-micrometer-5.0.3
# 23  axon-spring-boot-autoconfigure-5.0.3
# 24                     axon-common-5.0.3
# 25                     axon-common-5.0.3
# 26                  axon-messaging-5.0.3
# 27                  axon-messaging-5.0.3
# 28                  axon-messaging-5.0.3
# 29                  axon-messaging-5.0.3
#
#                                       fullPackageName  linesInPackage  \
# 0   org.axonframework.messaging.eventhandling.proc...            1409
# 1                    org.axonframework.messaging.core            1119
# 2                      org.axonframework.test.fixture             752
# 3              org.axonframework.common.configuration             710
# 4         org.axonframework.messaging.core.annotation             702
# 5              org.axonframework.axonserver.connector             698
# 6                            org.axonframework.common             614
# 7          org.axonframework.eventsourcing.eventstore             605
# 8        org.axonframework.axonserver.connector.event             540
# 9   org.axonframework.messaging.eventhandling.proc...             436
# 10     org.axonframework.eventsourcing.eventstore.jpa             434
# 11          org.axonframework.messaging.queryhandling             381
# 12        org.axonframework.messaging.core.unitofwork             375
# 13  org.axonframework.extension.springboot.autoconfig             327
# 14       org.axonframework.axonserver.connector.query             325
# 15  org.axonframework.messaging.eventhandling.proc...             319
# 16                    org.axonframework.test.matchers             318
# 17      org.axonframework.modelling.entity.annotation             307
# 18                  org.axonframework.conversion.avro             285
# 19                 org.axonframework.modelling.entity             268
# 20     org.axonframework.messaging.core.configuration             256
# 21  org.axonframework.messaging.eventhandling.proc...             253
# 22     org.axonframework.extension.metrics.micrometer             252
# 23             org.axonframework.extension.springboot             248
# 24                   org.axonframework.common.caching             234
# 25                     org.axonframework.common.infra             233
# 26      org.axonframework.messaging.core.interception             217
# 27           org.axonframework.messaging.core.timeout             217
# 28        org.axonframework.messaging.commandhandling             216
# 29  org.axonframework.messaging.eventhandling.proc...             215
#
#     methodCount  maxLinesMethod  \
# 0           397             111
# 1           531              16
# 2           211              45
# 3           288              26
# 4           235              23
# 5           278              42
# 6           183              24
# 7           234              19
# 8           162              21
# 9           109              25
# 10          136              20
# 11          172              14
# 12          186              21
# 13          145              38
# 14           90              21
# 15          121              11
# 16          101              21
# 17           73              18
# 18           80              30
# 19           76              18
# 20          116              20
# 21           94              19
# 22           88              15
# 23          136               9
# 24           85              13
# 25           56              14
# 26           93              14
# 27           56              16
# 28          100              18
# 29           64              19
#
#                                    maxLinesMethodName
# 0                                                 run
# 1                                             process
# 2                                 appendEventOverview
# 3                             invokeLifecycleHandlers
# 4                                              <init>
# 5                                               build
# 6   getExactDirectSuperTypesOfParameterizedTypeOrC...
# 7                                  createTagsForValue
# 8                               lambda$appendEvents$0
# 9                                         updateToken
# 10                                    withGapsCleaned
# 11                                             handle
# 12                                       runNextPhase
# 13                                     buildConverter
# 14                                convertQueryMessage
# 15                                          advanceTo
# 16                                     matchingFields
# 17                       createOptionalChildForMember
# 18                                            convert
# 19                                             <init>
# 20                                 registerComponents
# 21                                              split
# 22                    constructEventProcessorMonitors
# 23                                             <init>
# 24                          lambda$computeIfPresent$4
# 25                                   describeProperty
# 26                                            convert
# 27                                             <init>
# 28                                             handle
# 29                                lambda$storeToken$1

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index                          artifactName  \
# 0       0                  axon-messaging-5.0.3
# 1       2                       axon-test-5.0.3
# 2       5           axon-server-connector-5.0.3
# 3      42                     axon-update-5.0.3
# 4      33              axon-eventsourcing-5.0.3
# 5      13  axon-spring-boot-autoconfigure-5.0.3
# 6      61              axon-eventsourcing-5.0.3
# 7      18                 axon-conversion-5.0.3
# 8      67                 axon-conversion-5.0.3
# 9      68                 axon-conversion-5.0.3
# 10      3                     axon-common-5.0.3
# 11      9                  axon-messaging-5.0.3
# 12      6                     axon-common-5.0.3
# 13     86  axon-spring-boot-autoconfigure-5.0.3
# 14      4                  axon-messaging-5.0.3
# 15     40                     axon-update-5.0.3
# 16     53                  axon-modelling-5.0.3
# 17     14           axon-server-connector-5.0.3
# 18     16                       axon-test-5.0.3
# 19     12                  axon-messaging-5.0.3
# 20      8           axon-server-connector-5.0.3
# 21     46                     axon-update-5.0.3
# 22     35           axon-server-connector-5.0.3
# 23     20                  axon-messaging-5.0.3
# 24     10              axon-eventsourcing-5.0.3
# 25     32                       axon-test-5.0.3
# 26     21                  axon-messaging-5.0.3
# 27     29                  axon-messaging-5.0.3
# 28      7              axon-eventsourcing-5.0.3
# 29     19                  axon-modelling-5.0.3
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.proc...
# 1                      org.axonframework.test.fixture
# 2              org.axonframework.axonserver.connector
# 3                  org.axonframework.update.detection
# 4   org.axonframework.eventsourcing.annotation.ref...
# 5   org.axonframework.extension.springboot.autoconfig
# 6          org.axonframework.eventsourcing.annotation
# 7                   org.axonframework.conversion.avro
# 8                org.axonframework.conversion.jackson
# 9               org.axonframework.conversion.jackson2
# 10             org.axonframework.common.configuration
# 11  org.axonframework.messaging.eventhandling.proc...
# 12                           org.axonframework.common
# 13        org.axonframework.extension.springboot.util
# 14        org.axonframework.messaging.core.annotation
# 15                           org.axonframework.update
# 16             org.axonframework.modelling.annotation
# 17       org.axonframework.axonserver.connector.query
# 18                    org.axonframework.test.matchers
# 19        org.axonframework.messaging.core.unitofwork
# 20       org.axonframework.axonserver.connector.event
# 21                       org.axonframework.update.api
# 22     org.axonframework.axonserver.connector.command
# 23     org.axonframework.messaging.core.configuration
# 24     org.axonframework.eventsourcing.eventstore.jpa
# 25                      org.axonframework.test.server
# 26  org.axonframework.messaging.eventhandling.proc...
# 27  org.axonframework.messaging.eventhandling.proc...
# 28         org.axonframework.eventsourcing.eventstore
# 29                 org.axonframework.modelling.entity
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                                            Reporter
# 2                 AxonServerConnectionManager$Builder
# 3                             TestEnvironmentDetector
# 4            AnnotationBasedEventSourcedEntityFactory
# 5                          ConverterAutoConfiguration
# 6   AnnotationBasedEventCriteriaResolver$WrappedEv...
# 7                                       AvroConverter
# 8                                    JacksonConverter
# 9                                   Jackson2Converter
# 10       DefaultAxonApplication$AxonConfigurationImpl
# 11                                     JdbcTokenStore
# 12                                TypeReflectionUtils
# 13                     AbstractQualifiedBeanCondition
# 14                MethodInvokingMessageHandlingMember
# 15                            UpdateCheckerHttpClient
# 16             AnnotationBasedEntityEvolvingComponent
# 17                                     QueryConverter
# 18                                  DeepEqualsMatcher
# 19             UnitOfWork$UnitOfWorkProcessingContext
# 20         AggregateBasedAxonServerEventStorageEngine
# 21                                UpdateCheckResponse
# 22                                   CommandConverter
# 23                     MessagingConfigurationDefaults
# 24                    GapAwareTrackingTokenOperations
# 25                           AxonServerContainerUtils
# 26                                      TrackerStatus
# 27                                      JpaTokenStore
# 28                         AnnotationBasedTagResolver
# 29                            ConcreteEntityMetamodel
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run             111
# 1                                 appendEventOverview              45
# 2                                               build              42
# 3                                         isTestClass              41
# 4                          addEntityCreatorExecutable              40
# 5                                      buildConverter              38
# 6                                              <init>              30
# 7                                             convert              30
# 8                                             convert              29
# 9                                             convert              29
# 10                            invokeLifecycleHandlers              26
# 11                                        updateToken              25
# 12  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 13                                    getMatchOutcome              23
# 14                                             <init>              23
# 15                                        sendRequest              21
# 16                                             evolve              21
# 17                                convertQueryMessage              21
# 18                                     matchingFields              21
# 19                                       runNextPhase              21
# 20                              lambda$appendEvents$0              21
# 21                                        fromRequest              21
# 22                               convertResultMessage              20
# 23                                 registerComponents              20
# 24                                    withGapsCleaned              20
# 25                                      createContext              20
# 26                                              split              19
# 27                                lambda$storeToken$1              19
# 28                                 createTagsForValue              19
# 29                                             <init>              18
#
#     linesInPackage
# 0             1409
# 1              752
# 2              698
# 3              163
# 4              197
# 5              327
# 6               97
# 7              285
# 8               80
# 9               80
# 10             710
# 11             436
# 12             614
# 13              46
# 14             702
# 15             169
# 16             120
# 17             325
# 18             318
# 19             375
# 20             540
# 21             143
# 22             186
# 23             256
# 24             434
# 25             199
# 26             253
# 27             215
# 28             605
# 29             268

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-5.0.3.jar  axon-common-5.0.3.jar  \
# cyclomaticComplexity
# 1                                         2968                    566
# 2                                          312                     95
# 3                                          160                     75
# 4                                           85                     30
# 5                                           33                     10
# 6                                           34                      8
# 7                                            9                      6
# 8                                            3                      8
# 9                                            1                      3
# 10                                           0                      1
# 11                                           1                      1
# 12                                           0                      1
# 13                                           1                      0
# 17                                           0                      0
# 21                                           0                      0
# 25                                           1                      0
# 41                                           0                      0
# 58                                           1                      0
#
# artifactName          axon-server-connector-5.0.3.jar  \
# cyclomaticComplexity
# 1                                                 536
# 2                                                  57
# 3                                                  26
# 4                                                   7
# 5                                                   5
# 6                                                   5
# 7                                                   1
# 8                                                   0
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  0
# 17                                                  0
# 21                                                  0
# 25                                                  0
# 41                                                  0
# 58                                                  0
#
# artifactName          axon-eventsourcing-5.0.3.jar  axon-test-5.0.3.jar  \
# cyclomaticComplexity
# 1                                              457                  331
# 2                                               59                   41
# 3                                               37                   36
# 4                                               18                   11
# 5                                                8                    8
# 6                                                6                    6
# 7                                                4                    3
# 8                                                4                    4
# 9                                                0                    1
# 10                                               0                    0
# 11                                               1                    1
# 12                                               0                    0
# 13                                               1                    1
# 17                                               0                    0
# 21                                               0                    0
# 25                                               0                    0
# 41                                               0                    0
# 58                                               0                    0
#
# artifactName          axon-modelling-5.0.3.jar  \
# cyclomaticComplexity
# 1                                          291
# 2                                           26
# 3                                           21
# 4                                           18
# 5                                            7
# 6                                            3
# 7                                            1
# 8                                            1
# 9                                            0
# 10                                           0
# 11                                           0
# 12                                           0
# 13                                           0
# 17                                           0
# 21                                           0
# 25                                           0
# 41                                           0
# 58                                           0
#
# artifactName          axon-spring-boot-autoconfigure-5.0.3.jar  \
# cyclomaticComplexity
# 1                                                          288
# 2                                                           11
# 3                                                            7
# 4                                                            2
# 5                                                            0
# 6                                                            1
# 7                                                            1
# 8                                                            0
# 9                                                            1
# 10                                                           0
# 11                                                           1
# 12                                                           0
# 13                                                           0
# 17                                                           0
# 21                                                           0
# 25                                                           0
# 41                                                           0
# 58                                                           0
#
# artifactName          axon-conversion-5.0.3.jar  axon-update-5.0.3.jar  \
# cyclomaticComplexity
# 1                                           158                    119
# 2                                            14                     16
# 3                                             9                      5
# 4                                            13                      1
# 5                                             2                      3
# 6                                             2                      4
# 7                                             2                      2
# 8                                             1                      0
# 9                                             1                      1
# 10                                            0                      0
# 11                                            0                      1
# 12                                            0                      0
# 13                                            0                      0
# 17                                            2                      1
# 21                                            1                      0
# 25                                            0                      0
# 41                                            0                      1
# 58                                            0                      0
#
# artifactName          axon-metrics-micrometer-5.0.3.jar  \
# cyclomaticComplexity
# 1                                                    96
# 2                                                    10
# 3                                                     2
# 4                                                     0
# 5                                                     0
# 6                                                     0
# 7                                                     0
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 12                                                    0
# 13                                                    0
# 17                                                    0
# 21                                                    0
# 25                                                    0
# 41                                                    0
# 58                                                    0
#
# artifactName          axon-tracing-opentelemetry-5.0.3.jar
# cyclomaticComplexity
# 1                                                       30
# 2                                                        8
# 3                                                        2
# 4                                                        1
# 5                                                        0
# 6                                                        0
# 7                                                        0
# 8                                                        0
# 9                                                        0
# 10                                                       0
# 11                                                       0
# 12                                                       0
# 13                                                       0
# 17                                                       0
# 21                                                       0
# 25                                                       0
# 41                                                       0
# 58                                                       0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-5.0.3.jar  axon-common-5.0.3.jar  \
# cyclomaticComplexity
# 1                                    82.238847              70.398010
# 2                                     8.645054              11.815920
# 3                                     4.433361               9.328358
# 4                                     2.355223               3.731343
# 5                                     0.914381               1.243781
# 6                                     0.942089               0.995025
# 7                                     0.249377               0.746269
# 8                                     0.083126               0.995025
# 9                                     0.027709               0.373134
# 10                                    0.000000               0.124378
# 11                                    0.027709               0.124378
# 12                                    0.000000               0.124378
# 13                                    0.027709               0.000000
# 17                                    0.000000               0.000000
# 21                                    0.000000               0.000000
# 25                                    0.027709               0.000000
# 41                                    0.000000               0.000000
# 58                                    0.027709               0.000000
#
# artifactName          axon-server-connector-5.0.3.jar  \
# cyclomaticComplexity
# 1                                            83.75000
# 2                                             8.90625
# 3                                             4.06250
# 4                                             1.09375
# 5                                             0.78125
# 6                                             0.78125
# 7                                             0.15625
# 8                                             0.00000
# 9                                             0.31250
# 10                                            0.00000
# 11                                            0.00000
# 12                                            0.15625
# 13                                            0.00000
# 17                                            0.00000
# 21                                            0.00000
# 25                                            0.00000
# 41                                            0.00000
# 58                                            0.00000
#
# artifactName          axon-eventsourcing-5.0.3.jar  axon-test-5.0.3.jar  \
# cyclomaticComplexity
# 1                                        76.806723            74.717833
# 2                                         9.915966             9.255079
# 3                                         6.218487             8.126411
# 4                                         3.025210             2.483070
# 5                                         1.344538             1.805869
# 6                                         1.008403             1.354402
# 7                                         0.672269             0.677201
# 8                                         0.672269             0.902935
# 9                                         0.000000             0.225734
# 10                                        0.000000             0.000000
# 11                                        0.168067             0.225734
# 12                                        0.000000             0.000000
# 13                                        0.168067             0.225734
# 17                                        0.000000             0.000000
# 21                                        0.000000             0.000000
# 25                                        0.000000             0.000000
# 41                                        0.000000             0.000000
# 58                                        0.000000             0.000000
#
# artifactName          axon-modelling-5.0.3.jar  \
# cyclomaticComplexity
# 1                                    79.076087
# 2                                     7.065217
# 3                                     5.706522
# 4                                     4.891304
# 5                                     1.902174
# 6                                     0.815217
# 7                                     0.271739
# 8                                     0.271739
# 9                                     0.000000
# 10                                    0.000000
# 11                                    0.000000
# 12                                    0.000000
# 13                                    0.000000
# 17                                    0.000000
# 21                                    0.000000
# 25                                    0.000000
# 41                                    0.000000
# 58                                    0.000000
#
# artifactName          axon-spring-boot-autoconfigure-5.0.3.jar  \
# cyclomaticComplexity
# 1                                                    92.307692
# 2                                                     3.525641
# 3                                                     2.243590
# 4                                                     0.641026
# 5                                                     0.000000
# 6                                                     0.320513
# 7                                                     0.320513
# 8                                                     0.000000
# 9                                                     0.320513
# 10                                                    0.000000
# 11                                                    0.320513
# 12                                                    0.000000
# 13                                                    0.000000
# 17                                                    0.000000
# 21                                                    0.000000
# 25                                                    0.000000
# 41                                                    0.000000
# 58                                                    0.000000
#
# artifactName          axon-conversion-5.0.3.jar  axon-update-5.0.3.jar  \
# cyclomaticComplexity
# 1                                     77.073171              77.272727
# 2                                      6.829268              10.389610
# 3                                      4.390244               3.246753
# 4                                      6.341463               0.649351
# 5                                      0.975610               1.948052
# 6                                      0.975610               2.597403
# 7                                      0.975610               1.298701
# 8                                      0.487805               0.000000
# 9                                      0.487805               0.649351
# 10                                     0.000000               0.000000
# 11                                     0.000000               0.649351
# 12                                     0.000000               0.000000
# 13                                     0.000000               0.000000
# 17                                     0.975610               0.649351
# 21                                     0.487805               0.000000
# 25                                     0.000000               0.000000
# 41                                     0.000000               0.649351
# 58                                     0.000000               0.000000
#
# artifactName          axon-metrics-micrometer-5.0.3.jar  \
# cyclomaticComplexity
# 1                                             88.888889
# 2                                              9.259259
# 3                                              1.851852
# 4                                              0.000000
# 5                                              0.000000
# 6                                              0.000000
# 7                                              0.000000
# 8                                              0.000000
# 9                                              0.000000
# 10                                             0.000000
# 11                                             0.000000
# 12                                             0.000000
# 13                                             0.000000
# 17                                             0.000000
# 21                                             0.000000
# 25                                             0.000000
# 41                                             0.000000
# 58                                             0.000000
#
# artifactName          axon-tracing-opentelemetry-5.0.3.jar
# cyclomaticComplexity
# 1                                                73.170732
# 2                                                19.512195
# 3                                                 4.878049
# 4                                                 2.439024
# 5                                                 0.000000
# 6                                                 0.000000
# 7                                                 0.000000
# 8                                                 0.000000
# 9                                                 0.000000
# 10                                                0.000000
# 11                                                0.000000
# 12                                                0.000000
# 13                                                0.000000
# 17                                                0.000000
# 21                                                0.000000
# 25                                                0.000000
# 41                                                0.000000
# 58                                                0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
if cyclomatic_method_complexity_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,11)
    cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
    axes = cyclomatic_method_complexity_distribution_normalized.plot(
        kind='line', 
        logx=True,
        logy=True,
        grid=True,
        xlim=[1,11],
        ylim=[1,100],
        xticks=method_line_count_x_ticks,
        yticks=cyclomatic_complexity_y_ticks,
        title='Cyclomatic complexity distribution of methods', 
        xlabel='cyclomatic complexity',
        ylabel='percentage of methods',
        cmap=main_color_map,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.set_yticklabels(cyclomatic_complexity_y_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                             artifactName  \
# 1                   axon-messaging-5.0.3
# 0                   axon-messaging-5.0.3
# 6                      axon-common-5.0.3
# 3                      axon-common-5.0.3
# 7               axon-eventsourcing-5.0.3
# 4                   axon-messaging-5.0.3
# 5            axon-server-connector-5.0.3
# 2                        axon-test-5.0.3
# 15                  axon-messaging-5.0.3
# 12                  axon-messaging-5.0.3
# 8            axon-server-connector-5.0.3
# 11                  axon-messaging-5.0.3
# 10              axon-eventsourcing-5.0.3
# 9                   axon-messaging-5.0.3
# 13  axon-spring-boot-autoconfigure-5.0.3
# 16                       axon-test-5.0.3
# 18                 axon-conversion-5.0.3
# 21                  axon-messaging-5.0.3
# 24                     axon-common-5.0.3
# 34                  axon-messaging-5.0.3
# 23  axon-spring-boot-autoconfigure-5.0.3
# 20                  axon-messaging-5.0.3
# 14           axon-server-connector-5.0.3
# 17                  axon-modelling-5.0.3
# 19                  axon-modelling-5.0.3
# 43                  axon-messaging-5.0.3
# 28                  axon-messaging-5.0.3
# 26                  axon-messaging-5.0.3
# 29                  axon-messaging-5.0.3
# 30                  axon-messaging-5.0.3
#
#                                       fullPackageName  complexityInPackage  \
# 1                    org.axonframework.messaging.core                  731
# 0   org.axonframework.messaging.eventhandling.proc...                  548
# 6                            org.axonframework.common                  388
# 3              org.axonframework.common.configuration                  388
# 7          org.axonframework.eventsourcing.eventstore                  377
# 4         org.axonframework.messaging.core.annotation                  371
# 5              org.axonframework.axonserver.connector                  357
# 2                      org.axonframework.test.fixture                  325
# 15  org.axonframework.messaging.eventhandling.proc...                  248
# 12        org.axonframework.messaging.core.unitofwork                  242
# 8        org.axonframework.axonserver.connector.event                  218
# 11          org.axonframework.messaging.queryhandling                  216
# 10     org.axonframework.eventsourcing.eventstore.jpa                  207
# 9   org.axonframework.messaging.eventhandling.proc...                  194
# 13  org.axonframework.extension.springboot.autoconfig                  191
# 16                    org.axonframework.test.matchers                  173
# 18                  org.axonframework.conversion.avro                  149
# 21  org.axonframework.messaging.eventhandling.proc...                  147
# 24                   org.axonframework.common.caching                  147
# 34  org.axonframework.messaging.eventhandling.anno...                  144
# 23             org.axonframework.extension.springboot                  139
# 20     org.axonframework.messaging.core.configuration                  129
# 14       org.axonframework.axonserver.connector.query                  127
# 17      org.axonframework.modelling.entity.annotation                  124
# 19                 org.axonframework.modelling.entity                  119
# 43         org.axonframework.messaging.eventstreaming                  119
# 28        org.axonframework.messaging.commandhandling                  117
# 26      org.axonframework.messaging.core.interception                  107
# 29  org.axonframework.messaging.eventhandling.proc...                  106
# 30          org.axonframework.messaging.eventhandling                  106
#
#     methodCount  maxComplexity           maxComplexityMethod
# 1           531              9                       process
# 0           397             25                           run
# 6           183              9           fieldNameFromMember
# 3           288              8                  hasComponent
# 7           234              8                          from
# 4           235             13               resolveToStream
# 5           278             12                         build
# 2           211             11           appendEventOverview
# 15          121              7                        covers
# 12          186              6                        commit
# 8           162              4                  appendEvents
# 11          172              4                     subscribe
# 10          136              8               withGapsCleaned
# 9           109              8                   updateToken
# 13          145             11                buildConverter
# 16          101              8                matchingFields
# 18           80             21                       convert
# 21           94              8                        equals
# 24           85              8                       onEvent
# 34           56             58                parseParameter
# 23          136              2                     batchSize
# 20          116              4  lambda$registerDecorators$15
# 14           90              6                 sendResponses
# 17           73              6     getExpectedRepresentation
# 19           76              7                handleInstance
# 43           92              4                    havingTags
# 28          100              4                     subscribe
# 26           93              4                       convert
# 29           64              6                        equals
# 30           86              4                        handle

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index                          artifactName  \
# 0      34                  axon-messaging-5.0.3
# 1      42                     axon-update-5.0.3
# 2       0                  axon-messaging-5.0.3
# 3      18                 axon-conversion-5.0.3
# 4      67                 axon-conversion-5.0.3
# 5      46                     axon-update-5.0.3
# 6      68                 axon-conversion-5.0.3
# 7       4                  axon-messaging-5.0.3
# 8      33              axon-eventsourcing-5.0.3
# 9      32                       axon-test-5.0.3
# 10     48                     axon-common-5.0.3
# 11      5           axon-server-connector-5.0.3
# 12     13  axon-spring-boot-autoconfigure-5.0.3
# 13      2                       axon-test-5.0.3
# 14     61              axon-eventsourcing-5.0.3
# 15     52                     axon-common-5.0.3
# 16      6                     axon-common-5.0.3
# 17      1                  axon-messaging-5.0.3
# 18     24                     axon-common-5.0.3
# 19     70                     axon-common-5.0.3
# 20     37                  axon-modelling-5.0.3
# 21     60                       axon-test-5.0.3
# 22      9                  axon-messaging-5.0.3
# 23     21                  axon-messaging-5.0.3
# 24      3                     axon-common-5.0.3
# 25      7              axon-eventsourcing-5.0.3
# 26     10              axon-eventsourcing-5.0.3
# 27     16                       axon-test-5.0.3
# 28     77                     axon-common-5.0.3
# 29     25                     axon-common-5.0.3
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.anno...
# 1                  org.axonframework.update.detection
# 2   org.axonframework.messaging.eventhandling.proc...
# 3                   org.axonframework.conversion.avro
# 4                org.axonframework.conversion.jackson
# 5                        org.axonframework.update.api
# 6               org.axonframework.conversion.jackson2
# 7         org.axonframework.messaging.core.annotation
# 8   org.axonframework.eventsourcing.annotation.ref...
# 9                       org.axonframework.test.server
# 10                      org.axonframework.common.jdbc
# 11             org.axonframework.axonserver.connector
# 12  org.axonframework.extension.springboot.autoconfig
# 13                     org.axonframework.test.fixture
# 14         org.axonframework.eventsourcing.annotation
# 15                      org.axonframework.common.lock
# 16                           org.axonframework.common
# 17                   org.axonframework.messaging.core
# 18                   org.axonframework.common.caching
# 19                org.axonframework.common.annotation
# 20           org.axonframework.modelling.entity.child
# 21                   org.axonframework.test.extension
# 22  org.axonframework.messaging.eventhandling.proc...
# 23  org.axonframework.messaging.eventhandling.proc...
# 24             org.axonframework.common.configuration
# 25         org.axonframework.eventsourcing.eventstore
# 26     org.axonframework.eventsourcing.eventstore.jpa
# 27                    org.axonframework.test.matchers
# 28                      org.axonframework.common.util
# 29                     org.axonframework.common.infra
#
#                                     maxComplexityType  \
# 0   MethodSequencingPolicyEventHandlerDefinition$S...
# 1                             TestEnvironmentDetector
# 2                        Coordinator$CoordinationTask
# 3                                       AvroConverter
# 4                                    JacksonConverter
# 5                                 UpdateCheckResponse
# 6                                   Jackson2Converter
# 7                          MessageStreamResolverUtils
# 8            AnnotationBasedEventSourcedEntityFactory
# 9                                 AxonServerContainer
# 10                           ConnectionWrapperFactory
# 11                AxonServerConnectionManager$Builder
# 12                         ConverterAutoConfiguration
# 13                                           Reporter
# 14  AnnotationBasedEventCriteriaResolver$WrappedEv...
# 15              PessimisticLockFactory$DisposableLock
# 16                                    ReflectionUtils
# 17                         MessageStreamUtils$Reducer
# 18           EhCacheAdapter$CacheEventListenerAdapter
# 19                                    AnnotationUtils
# 20                    FieldChildEntityFieldDefinition
# 21                       ProvidedAxonTestFixtureUtils
# 22                                     JdbcTokenStore
# 23                                      TrackerStatus
# 24                           DefaultComponentRegistry
# 25                    AggregateBasedConsistencyMarker
# 26                    GapAwareTrackingTokenOperations
# 27                                  DeepEqualsMatcher
# 28                                   PriorityRunnable
# 29    FilesystemStyleComponentDescriptor$TreeRenderer
#
#               maxComplexityMethod  maxComplexity
# 0                  parseParameter             58
# 1                     isTestClass             41
# 2                             run             25
# 3                         convert             21
# 4                         convert             17
# 5                     fromRequest             17
# 6                         convert             17
# 7                 resolveToStream             13
# 8      addEntityCreatorExecutable             13
# 9                          equals             13
# 10                  lambda$wrap$0             12
# 11                          build             12
# 12                 buildConverter             11
# 13            appendEventOverview             11
# 14                         <init>             11
# 15                           lock             10
# 16            fieldNameFromMember              9
# 17                        process              9
# 18                        onEvent              8
# 19              collectAttributes              8
# 20  evolveParentBasedOnChildInput              8
# 21             validateValueUsage              8
# 22                    updateToken              8
# 23                         equals              8
# 24                   hasComponent              8
# 25                           from              8
# 26                withGapsCleaned              8
# 27                 matchingFields              8
# 28                         equals              7
# 29                 renderProperty              7
