# %% [markdown]
# # Visibility Metrics for Java
# <br>
#
# ### References
# - [Visibility Metrics and the Importance of Hiding Things](https://dzone.com/articles/visibility-metrics-and-the-importance-of-hiding-th)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Controlling Access to Members of a Class](https://docs.oracle.com/javase/tutorial/java/javaOO/accesscontrol.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Relative Visibility Of Types
#
# A Java class or interface may be declared with the modifier public, in which case it is visible to all classes everywhere. If a class or interface has no modifier (the default, also known as package-private), it is visible only within its own package.
#
# The relative visibility is the number of inner components that are visible outside (public) divided by the number of all types:
#
# $$ relative visibility = \frac{public\:types}{all\:types} $$
#
# Using package protected types is one of many ways to improve encapsulation and implementation detail hiding.
#
# ### How to apply the results
#
# The relative visibility is between zero (all types are package protected) and one (all types are public). A value lower than one means that there are types that are declared package protected. The lower the value is, the better implementation details are hidden.
#
# Non public classes can't be accessed from another package so they can be changed without affecting code in other packages. They clearly indicate functionality that only belongs to one package. This also motivates to use more classes and to split up code into smaller pieces with a single responsibility and reason to change.

# %% [markdown]
# ### Table 1a - Top 40 artifacts with lowest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and hardly any package protected types (lowest median, high visibility). Package protected types would help to  improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Query the visibility statistics per artifact (all packages aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_artifact_aggregated=query_cypher_to_data_frame("../cypher/Visibility/Global_relative_visibility_statistics_for_types.cypher")

# %%
# Sort by the "percentile50" (median) and "all" (number of packages in the artifact) descending
relative_visibility_statistics_highest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_highest_median=relative_visibility_statistics_highest_median.reset_index(drop=True)

relative_visibility_statistics_highest_median.head(40)
# Out:
#                                 artifact  all  public       min       max  \
# 0                      axon-common-5.0.3  156     129  0.615385  1.000000
# 1   axon-spring-boot-autoconfigure-5.0.3   75      53  0.512195  1.000000
# 2                  axon-conversion-5.0.3   35      32  0.700000  1.000000
# 3                      axon-update-5.0.3   23      23  1.000000  1.000000
# 4       axon-tracing-opentelemetry-5.0.3    5       5  1.000000  1.000000
# 5                   axon-modelling-5.0.3   92      84  0.692308  1.000000
# 6                   axon-messaging-5.0.3  579     439  0.250000  1.000000
# 7            axon-server-connector-5.0.3   72      58  0.642857  0.892857
# 8                        axon-test-5.0.3   78      63  0.600000  1.000000
# 9          axon-metrics-micrometer-5.0.3   16      12  0.727273  1.000000
# 10              axon-eventsourcing-5.0.3  100      66  0.200000  0.900000
#
#      average  percentile25  percentile50  percentile75  percentile90
# 0   0.893102      0.791304      1.000000      1.000000      1.000000
# 1   0.887081      0.848684      1.000000      1.000000      1.000000
# 2   0.940000      1.000000      1.000000      1.000000      1.000000
# 3   1.000000      1.000000      1.000000      1.000000      1.000000
# 4   1.000000      1.000000      1.000000      1.000000      1.000000
# 5   0.901923      0.860577      0.900000      1.000000      1.000000
# 6   0.802085      0.727273      0.842105      1.000000      1.000000
# 7   0.788495      0.727273      0.833333      0.846154      0.874176
# 8   0.809768      0.726562      0.791667      0.925725      0.978261
# 9   0.825758      0.738636      0.750000      0.875000      0.950000
# 10  0.599721      0.480769      0.666667      0.734921      0.813333

# %% [markdown]
# ### Table 1b - Top 40 artifacts with highest median of package protection encapsulation
#
# This table shows the relative visibility statistics aggregated for all packages per artifact and focusses on artifacts with many packages and the highest median of package protected types (low visibility). Package protected types help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Global_relative_visibility_statistics_for_types`

# %%
# Sort by the "percentile50" (median) ascending and "all" (number of packages in the artifact) descending
relative_visibility_statistics_lowest_median=relative_visibility_per_artifact_aggregated.sort_values(by=['percentile50', 'all'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
relative_visibility_statistics_lowest_median=relative_visibility_statistics_lowest_median.reset_index(drop=True)

relative_visibility_statistics_lowest_median.head(40)
# Out:
#                                 artifact  all  public       min       max  \
# 0               axon-eventsourcing-5.0.3  100      66  0.200000  0.900000
# 1          axon-metrics-micrometer-5.0.3   16      12  0.727273  1.000000
# 2                        axon-test-5.0.3   78      63  0.600000  1.000000
# 3            axon-server-connector-5.0.3   72      58  0.642857  0.892857
# 4                   axon-messaging-5.0.3  579     439  0.250000  1.000000
# 5                   axon-modelling-5.0.3   92      84  0.692308  1.000000
# 6                      axon-common-5.0.3  156     129  0.615385  1.000000
# 7   axon-spring-boot-autoconfigure-5.0.3   75      53  0.512195  1.000000
# 8                  axon-conversion-5.0.3   35      32  0.700000  1.000000
# 9                      axon-update-5.0.3   23      23  1.000000  1.000000
# 10      axon-tracing-opentelemetry-5.0.3    5       5  1.000000  1.000000
#
#      average  percentile25  percentile50  percentile75  percentile90
# 0   0.599721      0.480769      0.666667      0.734921      0.813333
# 1   0.825758      0.738636      0.750000      0.875000      0.950000
# 2   0.809768      0.726562      0.791667      0.925725      0.978261
# 3   0.788495      0.727273      0.833333      0.846154      0.874176
# 4   0.802085      0.727273      0.842105      1.000000      1.000000
# 5   0.901923      0.860577      0.900000      1.000000      1.000000
# 6   0.893102      0.791304      1.000000      1.000000      1.000000
# 7   0.887081      0.848684      1.000000      1.000000      1.000000
# 8   0.940000      1.000000      1.000000      1.000000      1.000000
# 9   1.000000      1.000000      1.000000      1.000000      1.000000
# 10  1.000000      1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# ### Table 1 Chart 1 - Relative visibility in artifacts

# %%
plot.figure();
fig, axes = plot.subplots(nrows=3, ncols=1, sharex=True)

number_of_packages_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_artifact_aggregated.plot(
    ax=axes[0],
    kind='scatter',
    title='Relative visibility in artifacts (75% percentile)', 
    x='percentile75',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[1],
    kind='scatter',
    title='Relative visibility in artifacts (50% percentile)', 
    x='percentile50',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,4),
)
relative_visibility_per_artifact_aggregated.plot(
    ax=axes[2],
    kind='scatter',
    title='Relative visibility in artifacts (25% percentile)', 
    x='percentile25',
    y='all',
    grid=True,
    logy=True,
    yticks=number_of_packages_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of packages',
    cmap=main_color_map,
    figsize=(10,10),
)
axes[0].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[1].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
axes[2].grid(color = 'grey', linestyle = '-', linewidth = 0.2)
plot.show()
# Out:
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ### Table 2a - Top 40 packages with the highest visibility and lowest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, hardly any package protected ones and therefore the highest relative visibility (lowest encapsulation). Package protected types would help to improve encapsulation.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Query the visibility statistics per package and artifact (all types aggregated)
# The results Will be used in multiple tables below.
relative_visibility_per_package=query_cypher_to_data_frame("../cypher/Visibility/Relative_visibility_public_types_to_all_types_per_package.cypher")

# %%
# Sort by the "relativeVisibility" and "allTypes" (number of types in the package) descending
highest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[False, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
highest_relative_visibility_packages=highest_relative_visibility_packages.reset_index(drop=True)

highest_relative_visibility_packages.head(40)
# Out:
#                             artifactName  \
# 0                   axon-modelling-5.0.3
# 1                   axon-modelling-5.0.3
# 2                   axon-messaging-5.0.3
# 3                   axon-modelling-5.0.3
# 4                      axon-common-5.0.3
# 5                   axon-messaging-5.0.3
# 6                  axon-conversion-5.0.3
# 7                      axon-common-5.0.3
# 8                   axon-messaging-5.0.3
# 9                   axon-messaging-5.0.3
# 10                  axon-messaging-5.0.3
# 11  axon-spring-boot-autoconfigure-5.0.3
# 12                     axon-update-5.0.3
# 13                     axon-common-5.0.3
# 14                  axon-messaging-5.0.3
# 15                  axon-messaging-5.0.3
# 16                     axon-update-5.0.3
# 17                     axon-common-5.0.3
# 18                 axon-conversion-5.0.3
# 19                 axon-conversion-5.0.3
# 20                 axon-conversion-5.0.3
# 21                  axon-messaging-5.0.3
# 22                  axon-messaging-5.0.3
# 23                  axon-messaging-5.0.3
# 24      axon-tracing-opentelemetry-5.0.3
# 25                     axon-update-5.0.3
# 26                     axon-common-5.0.3
# 27                  axon-messaging-5.0.3
# 28                  axon-messaging-5.0.3
# 29                     axon-update-5.0.3
# 30                  axon-messaging-5.0.3
# 31                  axon-messaging-5.0.3
# 32                  axon-messaging-5.0.3
# 33                     axon-common-5.0.3
# 34                  axon-messaging-5.0.3
# 35                  axon-messaging-5.0.3
# 36                  axon-messaging-5.0.3
# 37                  axon-messaging-5.0.3
# 38                  axon-messaging-5.0.3
# 39  axon-spring-boot-autoconfigure-5.0.3
#
#                              fullQualifiedPackageName    packageName  \
# 0       org.axonframework.modelling.entity.annotation     annotation
# 1                         org.axonframework.modelling      modelling
# 2   org.axonframework.messaging.eventhandling.conf...  configuration
# 3            org.axonframework.modelling.entity.child          child
# 4                       org.axonframework.common.jdbc           jdbc
# 5         org.axonframework.messaging.core.sequencing     sequencing
# 6                   org.axonframework.conversion.avro           avro
# 7                   org.axonframework.common.property       property
# 8   org.axonframework.messaging.eventhandling.proc...           jdbc
# 9   org.axonframework.messaging.eventhandling.tracing        tracing
# 10  org.axonframework.messaging.queryhandling.tracing        tracing
# 11        org.axonframework.extension.springboot.util           util
# 12             org.axonframework.update.configuration  configuration
# 13                      org.axonframework.common.util           util
# 14     org.axonframework.messaging.tracing.attributes     attributes
# 15       org.axonframework.messaging.core.correlation    correlation
# 16                       org.axonframework.update.api            api
# 17                 org.axonframework.common.lifecycle      lifecycle
# 18             org.axonframework.conversion.converter      converter
# 19               org.axonframework.conversion.jackson        jackson
# 20              org.axonframework.conversion.jackson2       jackson2
# 21  org.axonframework.messaging.monitoring.interce...   interception
# 22  org.axonframework.messaging.eventhandling.proc...          store
# 23  org.axonframework.messaging.eventhandling.proc...    subscribing
# 24  org.axonframework.extension.tracing.opentelemetry  opentelemetry
# 25                           org.axonframework.update         update
# 26                       org.axonframework.common.jpa            jpa
# 27  org.axonframework.messaging.eventhandling.proc...            jpa
# 28   org.axonframework.messaging.eventhandling.replay         replay
# 29                 org.axonframework.update.detection      detection
# 30  org.axonframework.messaging.eventhandling.proc...  errorhandling
# 31  org.axonframework.messaging.eventhandling.proc...     processing
# 32  org.axonframework.messaging.core.configuration...     reflection
# 33                  org.axonframework.common.function       function
# 34     org.axonframework.messaging.core.configuration  configuration
# 35  org.axonframework.messaging.eventhandling.conv...     conversion
# 36        org.axonframework.messaging.core.conversion     conversion
# 37  org.axonframework.messaging.queryhandling.gateway        gateway
# 38        org.axonframework.messaging.core.reflection     reflection
# 39  org.axonframework.extension.springboot.actuato...     axonserver
#
#     publicTypes  allTypes  relativeVisibility
# 0            18        18                 1.0
# 1            16        16                 1.0
# 2            14        14                 1.0
# 3            14        14                 1.0
# 4            12        12                 1.0
# 5            11        11                 1.0
# 6            10        10                 1.0
# 7             9         9                 1.0
# 8             9         9                 1.0
# 9             7         7                 1.0
# 10            7         7                 1.0
# 11            7         7                 1.0
# 12            7         7                 1.0
# 13            6         6                 1.0
# 14            6         6                 1.0
# 15            6         6                 1.0
# 16            6         6                 1.0
# 17            5         5                 1.0
# 18            5         5                 1.0
# 19            5         5                 1.0
# 20            5         5                 1.0
# 21            5         5                 1.0
# 22            5         5                 1.0
# 23            5         5                 1.0
# 24            5         5                 1.0
# 25            5         5                 1.0
# 26            4         4                 1.0
# 27            4         4                 1.0
# 28            4         4                 1.0
# 29            4         4                 1.0
# 30            3         3                 1.0
# 31            3         3                 1.0
# 32            3         3                 1.0
# 33            2         2                 1.0
# 34            2         2                 1.0
# 35            2         2                 1.0
# 36            2         2                 1.0
# 37            2         2                 1.0
# 38            2         2                 1.0
# 39            2         2                 1.0

# %% [markdown]
# ### Table 2b - Top 40 packages with the lowest visibility and highest encapsulation
#
# This table shows the relative visibility statistics per packages and artifact and focusses on packages with many types, many package protected ones and therefore the lowest relative visibility (highest encapsulation). Package protected types help to improve encapsulation. Zero percent visibility and therefore packages with no public visible type are suspicious to be dead code.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Relative_visibility_public_types_to_all_types_per_package`

# %%
# Sort by the "relativeVisibility" ascending and "allTypes" (number of types in the package) descending
lowest_relative_visibility_packages=relative_visibility_per_package.sort_values(by=['relativeVisibility', 'allTypes'], ascending=[True, False])

# Reset the index (row numbering starting at 0 and increasing by 1)
lowest_relative_visibility_packages=lowest_relative_visibility_packages.reset_index(drop=True)

lowest_relative_visibility_packages.head(40)
# Out:
#                             artifactName  \
# 0               axon-eventsourcing-5.0.3
# 1                   axon-messaging-5.0.3
# 2                   axon-messaging-5.0.3
# 3                   axon-messaging-5.0.3
# 4                   axon-messaging-5.0.3
# 5               axon-eventsourcing-5.0.3
# 6                   axon-messaging-5.0.3
# 7               axon-eventsourcing-5.0.3
# 8                   axon-messaging-5.0.3
# 9                   axon-messaging-5.0.3
# 10                  axon-messaging-5.0.3
# 11                  axon-messaging-5.0.3
# 12                  axon-messaging-5.0.3
# 13  axon-spring-boot-autoconfigure-5.0.3
# 14                  axon-messaging-5.0.3
# 15                       axon-test-5.0.3
# 16                     axon-common-5.0.3
# 17                  axon-messaging-5.0.3
# 18                     axon-common-5.0.3
# 19           axon-server-connector-5.0.3
# 20              axon-eventsourcing-5.0.3
# 21                  axon-messaging-5.0.3
# 22                  axon-modelling-5.0.3
# 23                 axon-conversion-5.0.3
# 24                  axon-messaging-5.0.3
# 25              axon-eventsourcing-5.0.3
# 26                       axon-test-5.0.3
# 27                  axon-messaging-5.0.3
# 28                  axon-messaging-5.0.3
# 29                  axon-messaging-5.0.3
# 30         axon-metrics-micrometer-5.0.3
# 31           axon-server-connector-5.0.3
# 32                  axon-messaging-5.0.3
# 33                  axon-messaging-5.0.3
# 34                     axon-common-5.0.3
# 35                  axon-messaging-5.0.3
# 36                  axon-messaging-5.0.3
# 37         axon-metrics-micrometer-5.0.3
# 38  axon-spring-boot-autoconfigure-5.0.3
# 39                       axon-test-5.0.3
#
#                              fullQualifiedPackageName     packageName  \
# 0   org.axonframework.eventsourcing.eventstore.inm...        inmemory
# 1   org.axonframework.messaging.eventhandling.proc...          pooled
# 2   org.axonframework.messaging.queryhandling.inte...    interception
# 3   org.axonframework.messaging.monitoring.configu...   configuration
# 4   org.axonframework.messaging.eventhandling.proc...        inmemory
# 5      org.axonframework.eventsourcing.eventstore.jpa             jpa
# 6       org.axonframework.messaging.core.interception    interception
# 7       org.axonframework.eventsourcing.configuration   configuration
# 8   org.axonframework.messaging.commandhandling.in...    interception
# 9   org.axonframework.messaging.eventhandling.proc...      annotation
# 10  org.axonframework.messaging.core.unitofwork.an...      annotation
# 11  org.axonframework.messaging.core.unitofwork.tr...            jdbc
# 12  org.axonframework.messaging.core.unitofwork.tr...             jpa
# 13  org.axonframework.extension.springboot.autoconfig      autoconfig
# 14         org.axonframework.messaging.eventstreaming  eventstreaming
# 15                             org.axonframework.test            test
# 16                   org.axonframework.common.caching         caching
# 17                   org.axonframework.messaging.core            core
# 18                     org.axonframework.common.infra           infra
# 19       org.axonframework.axonserver.connector.event           event
# 20  org.axonframework.eventsourcing.annotation.ref...      reflection
# 21  org.axonframework.messaging.eventhandling.inte...    interception
# 22          org.axonframework.modelling.configuration   configuration
# 23                       org.axonframework.conversion      conversion
# 24  org.axonframework.messaging.eventhandling.repl...      annotation
# 25                    org.axonframework.eventsourcing   eventsourcing
# 26                     org.axonframework.test.fixture         fixture
# 27  org.axonframework.messaging.commandhandling.an...      annotation
# 28  org.axonframework.messaging.core.interception....      annotation
# 29  org.axonframework.messaging.queryhandling.dist...     distributed
# 30     org.axonframework.extension.metrics.micrometer      micrometer
# 31       org.axonframework.axonserver.connector.query           query
# 32           org.axonframework.messaging.core.timeout         timeout
# 33  org.axonframework.messaging.eventhandling.proc...           token
# 34                org.axonframework.common.annotation      annotation
# 35  org.axonframework.messaging.commandhandling.co...   configuration
# 36  org.axonframework.messaging.queryhandling.conf...   configuration
# 37  org.axonframework.extension.metrics.micrometer...      springboot
# 38  org.axonframework.extension.springboot.service...      connection
# 39                   org.axonframework.test.extension       extension
#
#     publicTypes  allTypes  relativeVisibility
# 0             1         5            0.200000
# 1             6        24            0.250000
# 2             2         8            0.250000
# 3             3         9            0.333333
# 4             1         3            0.333333
# 5             6        13            0.461538
# 6            10        21            0.476190
# 7             7        14            0.500000
# 8             3         6            0.500000
# 9             1         2            0.500000
# 10            1         2            0.500000
# 11            1         2            0.500000
# 12            1         2            0.500000
# 13           21        41            0.512195
# 14            9        16            0.562500
# 15            3         5            0.600000
# 16            8        13            0.615385
# 17           50        80            0.625000
# 18            5         8            0.625000
# 19            9        14            0.642857
# 20            4         6            0.666667
# 21            2         3            0.666667
# 22            9        13            0.692308
# 23            7        10            0.700000
# 24            7        10            0.700000
# 25            5         7            0.714286
# 26           23        32            0.718750
# 27            8        11            0.727273
# 28            8        11            0.727273
# 29            8        11            0.727273
# 30            8        11            0.727273
# 31            8        11            0.727273
# 32            6         8            0.750000
# 33            6         8            0.750000
# 34            3         4            0.750000
# 35            3         4            0.750000
# 36            3         4            0.750000
# 37            3         4            0.750000
# 38            3         4            0.750000
# 39            3         4            0.750000

# %% [markdown]
# ### Table 2 Chart 1 - Relative visibility of packages

# %%
plot.figure();

number_of_types_grid_ticks=[1, 2, 5, 10, 20, 50, 100, 200, 500, 1_000, 2_000, 5_000, 10_000]

relative_visibility_per_package.plot(
    kind='scatter',
    title='Relative visibility of packages', 
    x='relativeVisibility',
    y='allTypes',
    grid=True,
    logy=True,
    yticks=number_of_types_grid_ticks,
    xlabel='relative visibility',
    ylabel='number of types',
    cmap=main_color_map,
    figsize=(10,4),
)

plot.show()
# Out:
# /home/runner/miniconda3/envs/codegraph/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1351: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
