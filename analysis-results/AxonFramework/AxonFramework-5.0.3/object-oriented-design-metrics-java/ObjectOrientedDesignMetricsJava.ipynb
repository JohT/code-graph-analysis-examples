# %% [markdown]
# # Object Oriented Design Quality Metrics
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [jqassistant](https://jqassistant.org)
# - [notebook walks through examples for integrating various packages with Neo4j](https://nicolewhite.github.io/neo4j-jupyter/hello-world.html)
# - [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616)
# - [A Validation of Martin's Metric](https://www.researchgate.net/publication/31598248_A_Validation_of_Martin's_Metric)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Incoming Dependencies
#
# Incoming dependencies are also denoted as "Fan-in", "Afferent Coupling" or "in-degree".
# These are the ones that use the listed package.
#
# If these packages get changed, the incoming dependencies might be affected by the change. The more incoming dependencies, the harder it gets to change the code without the need to adapt the dependent code (“rigid code”). Even worse, it might affect the behavior of the dependent code in an unwanted way (“fragile code”).
#
# Since Java Packages are organized hierarchically, incoming dependencies can be count for every package in isolation or by including all of its sub-packages. The latter one is done without top level packages like for example "org" or "org.company" by assuring that only packages are considered that have other packages or types in the same hierarchy level ("siblings").

# %% [markdown]
# #### Table 1a
# - Show the top 20 Java Packages with the most incoming dependencies
# - Set the "incomingDependencies" properties on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Incoming_Java_Package_Dependencies.cypher",
                                           "../cypher/Metrics/Set_Incoming_Java_Package_Dependencies.cypher", limit=20)
# Out:
#                 artifactName  \
# 0       axon-messaging-5.0.3
# 1       axon-messaging-5.0.3
# 2          axon-common-5.0.3
# 3       axon-messaging-5.0.3
# 4          axon-common-5.0.3
# 5       axon-messaging-5.0.3
# 6          axon-common-5.0.3
# 7          axon-common-5.0.3
# 8       axon-messaging-5.0.3
# 9       axon-messaging-5.0.3
# 10     axon-conversion-5.0.3
# 11      axon-messaging-5.0.3
# 12      axon-messaging-5.0.3
# 13  axon-eventsourcing-5.0.3
# 14      axon-messaging-5.0.3
# 15           axon-test-5.0.3
# 16      axon-modelling-5.0.3
# 17      axon-modelling-5.0.3
# 18      axon-modelling-5.0.3
# 19      axon-messaging-5.0.3
#
#                              fullQualifiedPackageName      packageName  \
# 0                    org.axonframework.messaging.core             core
# 1         org.axonframework.messaging.core.unitofwork       unitofwork
# 2              org.axonframework.common.configuration    configuration
# 3           org.axonframework.messaging.eventhandling    eventhandling
# 4                 org.axonframework.common.annotation       annotation
# 5         org.axonframework.messaging.commandhandling  commandhandling
# 6                      org.axonframework.common.infra            infra
# 7                            org.axonframework.common           common
# 8           org.axonframework.messaging.queryhandling    queryhandling
# 9         org.axonframework.messaging.core.annotation       annotation
# 10                       org.axonframework.conversion       conversion
# 11  org.axonframework.messaging.eventhandling.proc...            token
# 12         org.axonframework.messaging.eventstreaming   eventstreaming
# 13         org.axonframework.eventsourcing.eventstore       eventstore
# 14                org.axonframework.messaging.tracing          tracing
# 15                     org.axonframework.test.fixture          fixture
# 16                        org.axonframework.modelling        modelling
# 17                 org.axonframework.modelling.entity           entity
# 18           org.axonframework.modelling.entity.child            child
# 19  org.axonframework.messaging.eventhandling.proc...       segmenting
#
#     incomingDependencies  incomingDependenciesWeight  incomingDependentTypes  \
# 0                  12499                       39679                     419
# 1                  11625                       38453                     242
# 2                   3727                       19786                     151
# 3                   3012                       10890                     149
# 4                   2579                        2787                     144
# 5                   1497                        5379                     100
# 6                   1378                        1669                     122
# 7                    977                        2407                     288
# 8                    688                        2544                      76
# 9                    512                        1632                     119
# 10                   468                        1807                      62
# 11                   425                        2147                      58
# 12                   293                         833                      53
# 13                   224                         724                      65
# 14                   136                         478                      36
# 15                   134                         376                      29
# 16                   125                         282                      36
# 17                   115                         394                      25
# 18                    89                         230                      28
# 19                    86                         662                      31
#
#     incomingDependentInterfaces  incomingDependentPackages  \
# 0                            83                         71
# 1                            54                         62
# 2                            53                         33
# 3                            30                         37
# 4                            20                         60
# 5                            25                         27
# 6                            30                         47
# 7                            22                         80
# 8                            17                         16
# 9                            11                         24
# 10                           12                         22
# 11                            8                         16
# 12                           14                         10
# 13                            7                          9
# 14                            7                          6
# 15                            1                          2
# 16                            9                          9
# 17                            5                          5
# 18                            7                          3
# 19                            5                         10
#
#     incomingDependentArtifacts
# 0                            7
# 1                            4
# 2                            8
# 3                            6
# 4                            8
# 5                            6
# 6                            6
# 7                           10
# 8                            3
# 9                            4
# 10                           4
# 11                           3
# 12                           3
# 13                           3
# 14                           1
# 15                           0
# 16                           2
# 17                           1
# 18                           0
# 19                           1

# %% [markdown]
# #### Table 1b
# - Show the top 20 Java Packages including their sub-packages with the most incoming dependencies
# - Set the property "incomingDependenciesIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Incoming_Java_Package_Dependencies_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Set_Incoming_Java_Package_Dependencies_Including_Subpackages.cypher", limit=20)
# Out:
#                 artifactName  \
# 0       axon-messaging-5.0.3
# 1       axon-messaging-5.0.3
# 2          axon-common-5.0.3
# 3          axon-common-5.0.3
# 4          axon-common-5.0.3
# 5       axon-messaging-5.0.3
# 6          axon-common-5.0.3
# 7       axon-messaging-5.0.3
# 8       axon-messaging-5.0.3
# 9      axon-conversion-5.0.3
# 10      axon-messaging-5.0.3
# 11      axon-messaging-5.0.3
# 12      axon-messaging-5.0.3
# 13      axon-messaging-5.0.3
# 14      axon-messaging-5.0.3
# 15      axon-messaging-5.0.3
# 16  axon-eventsourcing-5.0.3
# 17      axon-messaging-5.0.3
# 18      axon-modelling-5.0.3
# 19      axon-messaging-5.0.3
#
#                              fullQualifiedPackageName      packageName  \
# 0                    org.axonframework.messaging.core             core
# 1         org.axonframework.messaging.core.unitofwork       unitofwork
# 2                            org.axonframework.common           common
# 3              org.axonframework.common.configuration    configuration
# 4                 org.axonframework.common.annotation       annotation
# 5           org.axonframework.messaging.eventhandling    eventhandling
# 6                      org.axonframework.common.infra            infra
# 7         org.axonframework.messaging.commandhandling  commandhandling
# 8         org.axonframework.messaging.core.annotation       annotation
# 9                        org.axonframework.conversion       conversion
# 10  org.axonframework.messaging.eventhandling.proc...            token
# 11          org.axonframework.messaging.queryhandling    queryhandling
# 12         org.axonframework.messaging.eventstreaming   eventstreaming
# 13  org.axonframework.messaging.eventhandling.proc...       processing
# 14  org.axonframework.messaging.eventhandling.proc...        streaming
# 15                org.axonframework.messaging.tracing          tracing
# 16         org.axonframework.eventsourcing.eventstore       eventstore
# 17  org.axonframework.messaging.eventhandling.proc...       segmenting
# 18                        org.axonframework.modelling        modelling
# 19        org.axonframework.messaging.core.conversion       conversion
#
#     incomingDependencies  incomingDependenciesWeight  incomingDependentTypes  \
# 0                  18180                       59941                     367
# 1                  11275                       37337                     228
# 2                   8038                       25190                     470
# 3                   3566                       19095                     111
# 4                   2578                        2786                     143
# 5                   2061                        7468                      99
# 6                   1364                        1595                     117
# 7                    900                        3463                      62
# 8                    423                        1325                      82
# 9                    397                        1597                      38
# 10                   350                        1416                      45
# 11                   269                         973                      34
# 12                   241                         688                      39
# 13                   218                         685                      30
# 14                   207                         655                      30
# 15                   107                         356                      21
# 16                    76                         207                      19
# 17                    74                         623                      23
# 18                    74                         226                      13
# 19                    69                         225                      22
#
#     incomingDependentInterfaces  incomingDependentPackages  \
# 0                           115                         67
# 1                            54                         58
# 2                           107                         94
# 3                            53                         32
# 4                            20                         59
# 5                            35                         26
# 6                            30                         46
# 7                            26                         20
# 8                            11                         23
# 9                            12                         17
# 10                            8                         11
# 11                           15                         12
# 12                           14                          9
# 13                           13                         10
# 14                           12                         11
# 15                            7                          4
# 16                            6                          6
# 17                            5                          9
# 18                           20                          4
# 19                            3                         17
#
#     incomingDependentArtifacts
# 0                            7
# 1                            5
# 2                            9
# 3                            8
# 4                            8
# 5                            6
# 6                            6
# 7                            6
# 8                            4
# 9                            3
# 10                           4
# 11                           5
# 12                           3
# 13                           5
# 14                           4
# 15                           1
# 16                           3
# 17                           1
# 18                           1
# 19                           5

# %% [markdown]
# ## Outgoing Dependencies
#
# Outgoing dependencies are also denoted as "Fan-out", "Efferent Coupling" or "out-degree".
# These are the ones that are used by the listed package.
#
# Code from other packages and libraries you’re depending on (outgoing) might change over time. The more outgoing changes, the more likely and frequently code changes are needed. This involves time and effort which can be reduced by automation of tests and version updates. Automated tests are crucial to reveal updates, that change the behavior of the code unexpectedly (“fragile code”). As soon as more effort is required, keeping up becomes difficult (“rigid code”). Not being able to use a newer version might not only restrict features, it can get problematic if there are security issues. This might force you to take “fast but ugly” solutions into account which further increases technical dept.
#
# Since Java Packages are organized hierarchically, outgoing dependencies can be count for every package in isolation or by including all of its sub-packages. The latter one is done without top level packages like for example "org" or "org.company" by assuring that only packages are considered that have other packages or types in the same hierarchy level ("siblings").

# %% [markdown]
# #### Table 2a
#
# - Show the top 20 Java Packages with the most outgoing dependencies
# - Set the "outgoingDependencies" properties on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Outgoing_Java_Package_Dependencies.cypher",
                                           "../cypher/Metrics/Set_Outgoing_Java_Package_Dependencies.cypher", limit=20)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.3
# 1                   axon-messaging-5.0.3
# 2            axon-server-connector-5.0.3
# 3               axon-eventsourcing-5.0.3
# 4               axon-eventsourcing-5.0.3
# 5                   axon-messaging-5.0.3
# 6                        axon-test-5.0.3
# 7                   axon-modelling-5.0.3
# 8                   axon-modelling-5.0.3
# 9                   axon-messaging-5.0.3
# 10              axon-eventsourcing-5.0.3
# 11  axon-spring-boot-autoconfigure-5.0.3
# 12                  axon-modelling-5.0.3
# 13                  axon-messaging-5.0.3
# 14                  axon-messaging-5.0.3
# 15                  axon-messaging-5.0.3
# 16                  axon-messaging-5.0.3
# 17                  axon-messaging-5.0.3
# 18                  axon-messaging-5.0.3
# 19                  axon-messaging-5.0.3
#
#                              fullQualifiedPackageName    packageName  \
# 0      org.axonframework.messaging.core.configuration  configuration
# 1   org.axonframework.messaging.eventhandling.proc...         pooled
# 2        org.axonframework.axonserver.connector.event          event
# 3      org.axonframework.eventsourcing.eventstore.jpa            jpa
# 4       org.axonframework.eventsourcing.configuration  configuration
# 5       org.axonframework.messaging.core.interception   interception
# 6                      org.axonframework.test.fixture        fixture
# 7       org.axonframework.modelling.entity.annotation     annotation
# 8                  org.axonframework.modelling.entity         entity
# 9   org.axonframework.messaging.eventhandling.proc...    subscribing
# 10         org.axonframework.eventsourcing.eventstore     eventstore
# 11  org.axonframework.extension.springboot.autoconfig     autoconfig
# 12          org.axonframework.modelling.configuration  configuration
# 13          org.axonframework.messaging.queryhandling  queryhandling
# 14  org.axonframework.messaging.queryhandling.dist...    distributed
# 15  org.axonframework.messaging.monitoring.interce...   interception
# 16  org.axonframework.messaging.commandhandling.in...   interception
# 17  org.axonframework.messaging.queryhandling.inte...   interception
# 18  org.axonframework.messaging.eventhandling.anno...     annotation
# 19          org.axonframework.messaging.eventhandling  eventhandling
#
#     outgoingDependencies  outgoingDependenciesWeight  outgoingDependentTypes  \
# 0                   2694                       16653                      79
# 1                   2322                        9835                      96
# 2                   1282                        4029                      72
# 3                   1239                        4839                      61
# 4                   1237                        4808                      66
# 5                   1160                        6002                      48
# 6                   1079                        3869                      74
# 7                    857                        3255                      63
# 8                    800                        2887                      35
# 9                    750                        2762                      47
# 10                   716                        2684                      64
# 11                   714                        2921                     112
# 12                   585                        2279                      41
# 13                   533                        2104                      48
# 14                   513                        1412                      38
# 15                   500                        1550                      15
# 16                   499                        1240                      25
# 17                   491                        1561                      26
# 18                   480                        1539                      48
# 19                   471                        1201                      42
#
#     outgoingDependentInterfaces  outgoingDependentPackages  \
# 0                            41                         29
# 1                            46                         20
# 2                            29                         18
# 3                            27                         17
# 4                            41                         25
# 5                            27                         11
# 6                            39                         16
# 7                            30                         19
# 8                            21                          9
# 9                            29                         14
# 10                           29                         10
# 11                           39                         36
# 12                           29                         10
# 13                           23                          9
# 14                           23                         10
# 15                           15                          6
# 16                           16                          8
# 17                           16                          6
# 18                           22                         14
# 19                           20                          8
#
#     outgoingDependentArtifacts
# 0                            2
# 1                            1
# 2                            3
# 3                            3
# 4                            3
# 5                            1
# 6                            3
# 7                            3
# 8                            2
# 9                            1
# 10                           2
# 11                           6
# 12                           2
# 13                           2
# 14                           1
# 15                           0
# 16                           1
# 17                           1
# 18                           1
# 19                           2

# %% [markdown]
# #### Table 2b
#
# - Show the top 20 Java Packages including their sub-packages with the most outgoing dependencies
# - Set the property "outgoingDependenciesIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Outgoing_Java_Package_Dependencies_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Set_Outgoing_Java_Package_Dependencies_Including_Subpackages.cypher", limit=20)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.3
# 1                   axon-messaging-5.0.3
# 2                   axon-modelling-5.0.3
# 3                   axon-messaging-5.0.3
# 4                   axon-messaging-5.0.3
# 5                   axon-messaging-5.0.3
# 6               axon-eventsourcing-5.0.3
# 7                   axon-messaging-5.0.3
# 8                   axon-modelling-5.0.3
# 9            axon-server-connector-5.0.3
# 10                  axon-messaging-5.0.3
# 11                  axon-messaging-5.0.3
# 12              axon-eventsourcing-5.0.3
# 13                  axon-modelling-5.0.3
# 14                  axon-messaging-5.0.3
# 15                       axon-test-5.0.3
# 16           axon-server-connector-5.0.3
# 17                       axon-test-5.0.3
# 18  axon-spring-boot-autoconfigure-5.0.3
# 19                  axon-messaging-5.0.3
#
#                              fullQualifiedPackageName      packageName  \
# 0           org.axonframework.messaging.eventhandling    eventhandling
# 1                    org.axonframework.messaging.core             core
# 2                         org.axonframework.modelling        modelling
# 3   org.axonframework.messaging.eventhandling.proc...       processing
# 4         org.axonframework.messaging.commandhandling  commandhandling
# 5           org.axonframework.messaging.queryhandling    queryhandling
# 6                     org.axonframework.eventsourcing    eventsourcing
# 7   org.axonframework.messaging.eventhandling.proc...        streaming
# 8                  org.axonframework.modelling.entity           entity
# 9              org.axonframework.axonserver.connector        connector
# 10  org.axonframework.messaging.eventhandling.proc...           pooled
# 11        org.axonframework.messaging.core.unitofwork       unitofwork
# 12         org.axonframework.eventsourcing.eventstore       eventstore
# 13      org.axonframework.modelling.entity.annotation       annotation
# 14      org.axonframework.messaging.core.interception     interception
# 15                             org.axonframework.test             test
# 16       org.axonframework.axonserver.connector.event            event
# 17                     org.axonframework.test.fixture          fixture
# 18  org.axonframework.extension.springboot.autoconfig       autoconfig
# 19        org.axonframework.messaging.core.annotation       annotation
#
#     outgoingDependencies  outgoingDependenciesWeight  outgoingDependentTypes  \
# 0                    675                        2160                     105
# 1                    434                        1531                      92
# 2                    372                        1088                      63
# 3                    348                        1280                      75
# 4                    325                        1035                      74
# 5                    316                        1128                      73
# 6                    313                        1037                      96
# 7                    275                        1008                      76
# 8                    269                         854                      46
# 9                    253                         866                     107
# 10                   231                         927                      73
# 11                   188                         716                      15
# 12                   178                         572                      54
# 13                   178                         679                      48
# 14                   172                         588                      43
# 15                   169                         510                      46
# 16                   142                         416                      59
# 17                   138                         490                      43
# 18                   129                         452                      84
# 19                   128                         341                      38
#
#     outgoingDependentInterfaces  outgoingDependentPackages  \
# 0                            46                         21
# 1                            76                         30
# 2                            23                         19
# 3                            13                         18
# 4                            29                         15
# 5                            19                         12
# 6                            14                         31
# 7                            11                         20
# 8                            11                         17
# 9                             2                         24
# 10                            2                         19
# 11                           54                          9
# 12                            7                         16
# 13                            5                         18
# 14                            2                         11
# 15                           10                         14
# 16                            0                         17
# 17                            9                         15
# 18                            0                         35
# 19                           11                         10
#
#     outgoingDependentArtifacts
# 0                            2
# 1                            2
# 2                            2
# 3                            2
# 4                            2
# 5                            2
# 6                            3
# 7                            2
# 8                            3
# 9                            3
# 10                           1
# 11                           1
# 12                           3
# 13                           3
# 14                           1
# 15                           2
# 16                           3
# 17                           3
# 18                           6
# 19                           1

# %% [markdown]
# ## Instability
#
# $$ Instability = \frac{Outgoing\:Dependencies}{Outgoing\:Dependencies + Incoming\:Dependencies} $$
#
# *Instability* is expressed as the ratio of the number of outgoing dependencies of a module (i.e., the number of packages that depend on it) to the total number of dependencies (i.e., the sum of incoming and outgoing dependencies).
#
# Small values near zero indicate low *Instability*. With no outgoing but some incoming dependencies the Instability is zero which is denoted as maximally stable. Such code units are more rigid and difficult to change without impacting other parts of the system. If they are changed less because of that, they are considered stable.
#
# Conversely, high values approaching one indicate high *Instability*. With some outgoing dependencies but no incoming ones the *Instability* is denoted as maximally unstable. Such code units are easier to change without affecting other modules, making them more flexible and less prone to cascading changes throughout the system. If they are changed more often because of that, they are considered unstable.
#
# Since Java Packages are organized hierarchically, *Instability* can be calculated for every package in isolation or by including all of its sub-packages.

# %% [markdown]
# #### Table 3a
#
# - Show the top 20 Java Packages with the lowest *Instability*
# - Set the property "instability" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Instability_for_Java.cypher",
                                           "../cypher/Metrics/Calculate_and_set_Instability_for_Java.cypher", limit=20)
# Out:
#              artifactName                           fullQualifiedPackageName  \
# 0       axon-common-5.0.3                org.axonframework.common.annotation
# 1    axon-messaging-5.0.3        org.axonframework.messaging.core.unitofwork
# 2       axon-common-5.0.3                     org.axonframework.common.infra
# 3    axon-messaging-5.0.3                   org.axonframework.messaging.core
# 4       axon-common-5.0.3                           org.axonframework.common
# 5    axon-messaging-5.0.3  org.axonframework.messaging.eventhandling.proc...
# 6   axon-conversion-5.0.3                       org.axonframework.conversion
# 7       axon-common-5.0.3             org.axonframework.common.configuration
# 8    axon-messaging-5.0.3          org.axonframework.messaging.eventhandling
# 9    axon-messaging-5.0.3        org.axonframework.messaging.commandhandling
# 10      axon-common-5.0.3                      org.axonframework.common.util
# 11   axon-messaging-5.0.3             org.axonframework.messaging.monitoring
# 12   axon-messaging-5.0.3        org.axonframework.messaging.core.conversion
# 13   axon-messaging-5.0.3  org.axonframework.messaging.eventhandling.proc...
# 14   axon-messaging-5.0.3         org.axonframework.messaging.eventstreaming
# 15      axon-common-5.0.3                 org.axonframework.common.lifecycle
# 16   axon-messaging-5.0.3                org.axonframework.messaging.tracing
# 17      axon-common-5.0.3                        org.axonframework.common.tx
# 18      axon-update-5.0.3                       org.axonframework.update.api
# 19   axon-messaging-5.0.3  org.axonframework.messaging.eventhandling.proc...
#
#         packageName  instability  instabilityTypes  instabilityInterfaces  \
# 0        annotation     0.001162          0.020408               0.000000
# 1        unitofwork     0.009205          0.079848               0.142857
# 2             infra     0.019217          0.075758               0.090909
# 3              core     0.026558          0.160321               0.170000
# 4            common     0.030754          0.055738               0.000000
# 5             token     0.042793          0.134328               0.333333
# 6        conversion     0.042945          0.138889               0.250000
# 7     configuration     0.070574          0.256158               0.283784
# 8     eventhandling     0.135228          0.219895               0.400000
# 9   commandhandling     0.165552          0.259259               0.431818
# 10             util     0.200000          0.153846               0.000000
# 11       monitoring     0.213592          0.190476               0.571429
# 12       conversion     0.230769          0.178571               0.571429
# 13            store     0.263158          0.190476               1.000000
# 14   eventstreaming     0.263819          0.320513               0.461538
# 15        lifecycle     0.333333          0.444444               0.000000
# 16          tracing     0.333333          0.320755               0.533333
# 17               tx     0.375000          0.230769               0.666667
# 18              api     0.379310          0.384615               0.000000
# 19    errorhandling     0.380952          0.384615               0.750000
#
#     instabilityPackages  instabilityArtifacts  p.outgoingDependencies  \
# 0              0.032258              0.000000                       3
# 1              0.088235              0.200000                     108
# 2              0.060000              0.000000                      27
# 3              0.101266              0.222222                     341
# 4              0.012346              0.000000                      31
# 5              0.200000              0.400000                      19
# 6              0.120000              0.200000                      21
# 7              0.131579              0.000000                     283
# 8              0.177778              0.250000                     471
# 9              0.181818              0.250000                     297
# 10             0.250000              0.000000                       3
# 11             0.307692              0.333333                      22
# 12             0.217391              0.285714                      21
# 13             0.400000              0.333333                      10
# 14             0.375000              0.250000                     105
# 15             0.333333              0.000000                       4
# 16             0.454545              0.500000                      68
# 17             0.200000              0.000000                       6
# 18             0.400000              1.000000                      11
# 19             0.500000              0.000000                       8
#
#     p.incomingDependencies  p.outgoingDependentTypes  \
# 0                     2579                         3
# 1                    11625                        21
# 2                     1378                        10
# 3                    12499                        80
# 4                      977                        17
# 5                      425                         9
# 6                      468                        10
# 7                     3727                        52
# 8                     3012                        42
# 9                     1497                        35
# 10                      12                         2
# 11                      81                         8
# 12                      70                         5
# 13                      28                         4
# 14                     293                        25
# 15                       8                         4
# 16                     136                        17
# 17                      10                         3
# 18                      18                         5
# 19                      13                         5
#
#     p.incomingDependentTypes  p.outgoingDependentInterfaces  \
# 0                        144                              0
# 1                        242                              9
# 2                        122                              3
# 3                        419                             17
# 4                        288                              0
# 5                         58                              4
# 6                         62                              4
# 7                        151                             21
# 8                        149                             20
# 9                        100                             19
# 10                        11                              0
# 11                        34                              4
# 12                        23                              4
# 13                        17                              2
# 14                        53                             12
# 15                         5                              0
# 16                        36                              8
# 17                        10                              2
# 18                         8                              0
# 19                         8                              3
#
#     p.incomingDependentInterfaces  p.outgoingDependentPackages  \
# 0                              20                            2
# 1                              54                            6
# 2                              30                            3
# 3                              83                            8
# 4                              22                            1
# 5                               8                            4
# 6                              12                            3
# 7                              53                            5
# 8                              30                            8
# 9                              25                            6
# 10                              0                            2
# 11                              3                            4
# 12                              3                            5
# 13                              0                            4
# 14                             14                            6
# 15                              0                            2
# 16                              7                            5
# 17                              1                            2
# 18                              1                            2
# 19                              1                            4
#
#     p.incomingDependentPackages  p.outgoingDependentArtifacts  \
# 0                            60                             0
# 1                            62                             1
# 2                            47                             0
# 3                            71                             2
# 4                            80                             0
# 5                            16                             2
# 6                            22                             1
# 7                            33                             0
# 8                            37                             2
# 9                            27                             2
# 10                            6                             0
# 11                            9                             1
# 12                           18                             2
# 13                            6                             1
# 14                           10                             1
# 15                            4                             0
# 16                            6                             1
# 17                            8                             0
# 18                            3                             1
# 19                            4                             0
#
#     p.incomingDependentArtifacts
# 0                              8
# 1                              4
# 2                              6
# 3                              7
# 4                             10
# 5                              3
# 6                              4
# 7                              8
# 8                              6
# 9                              6
# 10                             2
# 11                             2
# 12                             5
# 13                             2
# 14                             3
# 15                             1
# 16                             1
# 17                             2
# 18                             0
# 19                             0

# %% [markdown]
# #### Table 3b
#
# - Show the top 20 Java Packages including their sub-packages with the lowest *Instability*
# - Set the property "instabilityIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Instability_for_Java_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Calculate_and_set_Instability_for_Java_Including_Subpackages.cypher", limit=20)
# Out:
#                             artifactName  \
# 0                      axon-common-5.0.3
# 1                      axon-common-5.0.3
# 2                   axon-messaging-5.0.3
# 3                   axon-messaging-5.0.3
# 4                      axon-common-5.0.3
# 5                  axon-conversion-5.0.3
# 6                      axon-common-5.0.3
# 7                   axon-messaging-5.0.3
# 8                   axon-messaging-5.0.3
# 9                   axon-messaging-5.0.3
# 10                     axon-common-5.0.3
# 11                  axon-modelling-5.0.3
# 12                  axon-messaging-5.0.3
# 13                     axon-common-5.0.3
# 14                  axon-messaging-5.0.3
# 15                  axon-messaging-5.0.3
# 16                  axon-messaging-5.0.3
# 17                     axon-common-5.0.3
# 18  axon-spring-boot-autoconfigure-5.0.3
# 19                  axon-messaging-5.0.3
#
#                              fullQualifiedPackageName      packageName  \
# 0                 org.axonframework.common.annotation       annotation
# 1                      org.axonframework.common.infra            infra
# 2         org.axonframework.messaging.core.unitofwork       unitofwork
# 3                    org.axonframework.messaging.core             core
# 4              org.axonframework.common.configuration    configuration
# 5                        org.axonframework.conversion       conversion
# 6                       org.axonframework.common.util             util
# 7         org.axonframework.messaging.core.conversion       conversion
# 8   org.axonframework.messaging.eventhandling.proc...            token
# 9          org.axonframework.messaging.eventstreaming   eventstreaming
# 10                 org.axonframework.common.lifecycle        lifecycle
# 11             org.axonframework.modelling.repository       repository
# 12                org.axonframework.messaging.tracing          tracing
# 13                        org.axonframework.common.tx               tx
# 14  org.axonframework.messaging.eventhandling.proc...    errorhandling
# 15        org.axonframework.messaging.core.annotation       annotation
# 16          org.axonframework.messaging.eventhandling    eventhandling
# 17                  org.axonframework.common.property         property
# 18        org.axonframework.extension.springboot.util             util
# 19        org.axonframework.messaging.commandhandling  commandhandling
#
#     instability  instabilityTypes  instabilityInterfaces  instabilityPackages  \
# 0      0.000775          0.013793               0.000000             0.016667
# 1      0.003652          0.025000               0.000000             0.041667
# 2      0.016401          0.061728               0.500000             0.134328
# 3      0.023316          0.200436               0.397906             0.309278
# 4      0.030188          0.067227               0.436170             0.111111
# 5      0.059242          0.136364               0.500000             0.150000
# 6      0.090909          0.100000               0.000000             0.166667
# 7      0.126582          0.153846               0.500000             0.190476
# 8      0.154589          0.318182               0.500000             0.476190
# 9      0.157343          0.204082               0.500000             0.357143
# 10     0.166667          0.250000               0.000000             0.250000
# 11     0.204819          0.263158               0.500000             0.400000
# 12     0.207407          0.300000               0.461538             0.500000
# 13     0.230769          0.230769               0.500000             0.200000
# 14     0.230769          0.333333               0.500000             0.500000
# 15     0.232305          0.316667               0.500000             0.303030
# 16     0.246711          0.514706               0.567901             0.446809
# 17     0.250000          0.400000               0.000000             0.250000
# 18     0.250000          0.333333               0.000000             0.500000
# 19     0.265306          0.544118               0.527273             0.428571
#
#     instabilityArtifacts  p.outgoingDependenciesIncludingSubpackages  \
# 0               0.000000                                           2
# 1               0.000000                                           5
# 2               0.166667                                         188
# 3               0.222222                                         434
# 4               0.000000                                         111
# 5               0.000000                                          25
# 6               0.000000                                           1
# 7               0.285714                                          10
# 8               0.333333                                          64
# 9               0.250000                                          45
# 10              0.000000                                           1
# 11              0.500000                                          17
# 12              0.500000                                          28
# 13              0.000000                                           3
# 14              0.000000                                           3
# 15              0.200000                                         128
# 16              0.250000                                         675
# 17              0.000000                                           2
# 18              0.000000                                           1
# 19              0.250000                                         325
#
#     p.incomingDependenciesIncludingSubpackages  \
# 0                                         2578
# 1                                         1364
# 2                                        11275
# 3                                        18180
# 4                                         3566
# 5                                          397
# 6                                           10
# 7                                           69
# 8                                          350
# 9                                          241
# 10                                           5
# 11                                          66
# 12                                         107
# 13                                          10
# 14                                          10
# 15                                         423
# 16                                        2061
# 17                                           6
# 18                                           3
# 19                                         900
#
#     p.outgoingDependentTypesIncludingSubpackages  \
# 0                                              2
# 1                                              3
# 2                                             15
# 3                                             92
# 4                                              8
# 5                                              6
# 6                                              1
# 7                                              4
# 8                                             21
# 9                                             10
# 10                                             1
# 11                                             5
# 12                                             9
# 13                                             3
# 14                                             3
# 15                                            38
# 16                                           105
# 17                                             2
# 18                                             1
# 19                                            74
#
#     p.incomingDependentTypesIncludingSubpackages  \
# 0                                            143
# 1                                            117
# 2                                            228
# 3                                            367
# 4                                            111
# 5                                             38
# 6                                              9
# 7                                             22
# 8                                             45
# 9                                             39
# 10                                             3
# 11                                            14
# 12                                            21
# 13                                            10
# 14                                             6
# 15                                            82
# 16                                            99
# 17                                             3
# 18                                             2
# 19                                            62
#
#     p.outgoingDependentInterfacesIncludingSubpackages  \
# 0                                                   0
# 1                                                   0
# 2                                                  54
# 3                                                  76
# 4                                                  41
# 5                                                  12
# 6                                                   0
# 7                                                   3
# 8                                                   8
# 9                                                  14
# 10                                                  0
# 11                                                  5
# 12                                                  6
# 13                                                  1
# 14                                                  1
# 15                                                 11
# 16                                                 46
# 17                                                  0
# 18                                                  0
# 19                                                 29
#
#     p.incomingDependentInterfacesIncludingSubpackages  \
# 0                                                  20
# 1                                                  30
# 2                                                  54
# 3                                                 115
# 4                                                  53
# 5                                                  12
# 6                                                   0
# 7                                                   3
# 8                                                   8
# 9                                                  14
# 10                                                  0
# 11                                                  5
# 12                                                  7
# 13                                                  1
# 14                                                  1
# 15                                                 11
# 16                                                 35
# 17                                                  0
# 18                                                  0
# 19                                                 26
#
#     p.outgoingDependentPackagesIncludingSubpackages  \
# 0                                                 1
# 1                                                 2
# 2                                                 9
# 3                                                30
# 4                                                 4
# 5                                                 3
# 6                                                 1
# 7                                                 4
# 8                                                10
# 9                                                 5
# 10                                                1
# 11                                                4
# 12                                                4
# 13                                                2
# 14                                                3
# 15                                               10
# 16                                               21
# 17                                                1
# 18                                                1
# 19                                               15
#
#     p.incomingDependentPackagesIncludingSubpackages  \
# 0                                                59
# 1                                                46
# 2                                                58
# 3                                                67
# 4                                                32
# 5                                                17
# 6                                                 5
# 7                                                17
# 8                                                11
# 9                                                 9
# 10                                                3
# 11                                                6
# 12                                                4
# 13                                                8
# 14                                                3
# 15                                               23
# 16                                               26
# 17                                                3
# 18                                                1
# 19                                               20
#
#     p.outgoingDependentArtifactsIncludingSubpackages  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  2
# 4                                                  0
# 5                                                  0
# 6                                                  0
# 7                                                  2
# 8                                                  2
# 9                                                  1
# 10                                                 0
# 11                                                 1
# 12                                                 1
# 13                                                 0
# 14                                                 0
# 15                                                 1
# 16                                                 2
# 17                                                 0
# 18                                                 0
# 19                                                 2
#
#     p.incomingDependentArtifactsIncludingSubpackages
# 0                                                  8
# 1                                                  6
# 2                                                  5
# 3                                                  7
# 4                                                  8
# 5                                                  3
# 6                                                  1
# 7                                                  5
# 8                                                  4
# 9                                                  3
# 10                                                 1
# 11                                                 1
# 12                                                 1
# 13                                                 2
# 14                                                 0
# 15                                                 4
# 16                                                 6
# 17                                                 1
# 18                                                 0
# 19                                                 6

# %% [markdown]
# ## Abstractness
#
# $$ Abstractness = \frac{abstract\:classes\:in\:category}{total\:number\:of\:classes\:in\:category} $$
#
# Package *Abstractness* is expressed as the ratio of the number of abstract classes and interfaces to the total number of classes of a package.
#
# Zero *Abstractness* means that there are no abstract types or interfaces in the package. On the other hand, a value of one means that there are only abstract types.
#
# Since Java Packages are organized hierarchically, *Abstractness* can be calculated for every package in isolation or by including all of its sub-packages.

# %% [markdown]
# #### Table 4a
#
# - Show the top 30 packages with the lowest *Abstractness*
# - Set the property "abstractness" on Package nodes.

# %%
abstractness = query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Abstractness_for_Java.cypher",
                                                          "../cypher/Metrics/Calculate_and_set_Abstractness_for_Java.cypher")
abstractness.head(30)
# Out:
#                             artifactName  \
# 0   axon-spring-boot-autoconfigure-5.0.3
# 1   axon-spring-boot-autoconfigure-5.0.3
# 2            axon-server-connector-5.0.3
# 3          axon-metrics-micrometer-5.0.3
# 4                   axon-messaging-5.0.3
# 5                   axon-messaging-5.0.3
# 6                   axon-messaging-5.0.3
# 7                   axon-messaging-5.0.3
# 8            axon-server-connector-5.0.3
# 9                      axon-update-5.0.3
# 10                 axon-conversion-5.0.3
# 11                 axon-conversion-5.0.3
# 12                 axon-conversion-5.0.3
# 13                  axon-messaging-5.0.3
# 14      axon-tracing-opentelemetry-5.0.3
# 15                     axon-common-5.0.3
# 16                  axon-messaging-5.0.3
# 17         axon-metrics-micrometer-5.0.3
# 18                     axon-update-5.0.3
# 19                  axon-messaging-5.0.3
# 20                  axon-messaging-5.0.3
# 21                  axon-messaging-5.0.3
# 22                  axon-messaging-5.0.3
# 23                  axon-messaging-5.0.3
# 24                  axon-messaging-5.0.3
# 25                  axon-messaging-5.0.3
# 26                  axon-messaging-5.0.3
# 27                  axon-messaging-5.0.3
# 28  axon-spring-boot-autoconfigure-5.0.3
# 29                       axon-test-5.0.3
#
#                              fullQualifiedPackageName    packageName  \
# 0   org.axonframework.extension.springboot.autoconfig     autoconfig
# 1              org.axonframework.extension.springboot     springboot
# 2        org.axonframework.axonserver.connector.event          event
# 3      org.axonframework.extension.metrics.micrometer     micrometer
# 4   org.axonframework.messaging.queryhandling.inte...   interception
# 5            org.axonframework.messaging.core.timeout        timeout
# 6   org.axonframework.messaging.commandhandling.in...   interception
# 7      org.axonframework.messaging.tracing.attributes     attributes
# 8      org.axonframework.axonserver.connector.command        command
# 9                        org.axonframework.update.api            api
# 10               org.axonframework.conversion.jackson        jackson
# 11             org.axonframework.conversion.converter      converter
# 12              org.axonframework.conversion.jackson2       jackson2
# 13  org.axonframework.messaging.monitoring.interce...   interception
# 14  org.axonframework.extension.tracing.opentelemetry  opentelemetry
# 15                 org.axonframework.common.lifecycle      lifecycle
# 16  org.axonframework.messaging.eventhandling.proc...            jpa
# 17  org.axonframework.extension.metrics.micrometer...     springboot
# 18                 org.axonframework.update.detection      detection
# 19  org.axonframework.messaging.eventhandling.inte...   interception
# 20  org.axonframework.messaging.eventhandling.proc...       inmemory
# 21  org.axonframework.messaging.core.configuration...     reflection
# 22  org.axonframework.messaging.eventhandling.proc...     annotation
# 23        org.axonframework.messaging.core.reflection     reflection
# 24  org.axonframework.messaging.core.unitofwork.an...     annotation
# 25  org.axonframework.messaging.core.unitofwork.tr...           jdbc
# 26  org.axonframework.messaging.core.unitofwork.tr...            jpa
# 27     org.axonframework.messaging.core.configuration  configuration
# 28  org.axonframework.extension.springboot.actuato...     axonserver
# 29                      org.axonframework.test.server         server
#
#     abstractness  numberAbstractTypes  numberTypes
# 0            0.0                    0           41
# 1            0.0                    0           19
# 2            0.0                    0           14
# 3            0.0                    0           11
# 4            0.0                    0            8
# 5            0.0                    0            8
# 6            0.0                    0            6
# 7            0.0                    0            6
# 8            0.0                    0            6
# 9            0.0                    0            6
# 10           0.0                    0            5
# 11           0.0                    0            5
# 12           0.0                    0            5
# 13           0.0                    0            5
# 14           0.0                    0            5
# 15           0.0                    0            5
# 16           0.0                    0            4
# 17           0.0                    0            4
# 18           0.0                    0            4
# 19           0.0                    0            3
# 20           0.0                    0            3
# 21           0.0                    0            3
# 22           0.0                    0            2
# 23           0.0                    0            2
# 24           0.0                    0            2
# 25           0.0                    0            2
# 26           0.0                    0            2
# 27           0.0                    0            2
# 28           0.0                    0            2
# 29           0.0                    0            2

# %% [markdown]
# #### Table 4b
#
# - Show the top 30 packages with the highest *Abstractness* and number of Java Types

# %%
abstractness.sort_values(by=['abstractness', 'numberTypes'], ascending=[False, False]).head(30)
# Out:
#                              artifactName  \
# 146                     axon-common-5.0.3
# 147                  axon-messaging-5.0.3
# 148  axon-spring-boot-autoconfigure-5.0.3
# 149                     axon-common-5.0.3
# 144                  axon-messaging-5.0.3
# 145                  axon-messaging-5.0.3
# 143                  axon-messaging-5.0.3
# 142              axon-eventsourcing-5.0.3
# 141                  axon-modelling-5.0.3
# 140                  axon-messaging-5.0.3
# 138                  axon-messaging-5.0.3
# 139  axon-spring-boot-autoconfigure-5.0.3
# 137                  axon-modelling-5.0.3
# 131                     axon-common-5.0.3
# 132                       axon-test-5.0.3
# 133                     axon-common-5.0.3
# 134                  axon-messaging-5.0.3
# 135                  axon-messaging-5.0.3
# 136                  axon-messaging-5.0.3
# 130                     axon-common-5.0.3
# 128                  axon-messaging-5.0.3
# 129                  axon-messaging-5.0.3
# 127                  axon-messaging-5.0.3
# 125                       axon-test-5.0.3
# 126                  axon-messaging-5.0.3
# 123                  axon-modelling-5.0.3
# 124              axon-eventsourcing-5.0.3
# 122                  axon-messaging-5.0.3
# 119                  axon-messaging-5.0.3
# 120                  axon-messaging-5.0.3
#
#                               fullQualifiedPackageName      packageName  \
# 146                  org.axonframework.common.function         function
# 147  org.axonframework.messaging.eventhandling.proc...        streaming
# 148    org.axonframework.extension.springboot.actuator         actuator
# 149                        org.axonframework.common.tx               tx
# 144  org.axonframework.messaging.commandhandling.co...    configuration
# 145  org.axonframework.messaging.queryhandling.conf...    configuration
# 143  org.axonframework.messaging.eventhandling.conf...    configuration
# 142         org.axonframework.eventsourcing.annotation       annotation
# 141             org.axonframework.modelling.repository       repository
# 140  org.axonframework.messaging.core.unitofwork.tr...      transaction
# 138  org.axonframework.messaging.queryhandling.anno...       annotation
# 139        org.axonframework.extension.springboot.util             util
# 137          org.axonframework.modelling.configuration    configuration
# 131                      org.axonframework.common.jdbc             jdbc
# 132                   org.axonframework.test.extension        extension
# 133                org.axonframework.common.annotation       annotation
# 134  org.axonframework.messaging.eventhandling.conv...       conversion
# 135  org.axonframework.messaging.queryhandling.gateway          gateway
# 136        org.axonframework.messaging.core.conversion       conversion
# 130             org.axonframework.common.configuration    configuration
# 128        org.axonframework.messaging.commandhandling  commandhandling
# 129          org.axonframework.messaging.eventhandling    eventhandling
# 127  org.axonframework.messaging.core.interception....       annotation
# 125                     org.axonframework.test.fixture          fixture
# 126         org.axonframework.messaging.eventstreaming   eventstreaming
# 123           org.axonframework.modelling.entity.child            child
# 124                    org.axonframework.eventsourcing    eventsourcing
# 122          org.axonframework.messaging.queryhandling    queryhandling
# 119  org.axonframework.messaging.commandhandling.di...      distributed
# 120  org.axonframework.messaging.eventhandling.repl...       annotation
#
#      abstractness  numberAbstractTypes  numberTypes
# 146      1.000000                    2            2
# 147      1.000000                    1            1
# 148      1.000000                    1            1
# 149      1.000000                    1            1
# 144      0.750000                    3            4
# 145      0.750000                    3            4
# 143      0.714286                   10           14
# 142      0.700000                    7           10
# 141      0.625000                    5            8
# 140      0.600000                    3            5
# 138      0.571429                    4            7
# 139      0.571429                    4            7
# 137      0.538462                    7           13
# 131      0.500000                    6           12
# 132      0.500000                    2            4
# 133      0.500000                    2            4
# 134      0.500000                    1            2
# 135      0.500000                    1            2
# 136      0.500000                    1            2
# 130      0.478261                   22           46
# 128      0.473684                    9           19
# 129      0.473684                    9           19
# 127      0.454545                    5           11
# 125      0.437500                   14           32
# 126      0.437500                    7           16
# 123      0.428571                    6           14
# 124      0.428571                    3            7
# 122      0.416667                   10           24
# 119      0.400000                    4           10
# 120      0.400000                    4           10

# %% [markdown]
# #### Table 4c
#
# - Show the top 30 packages including their sub-packages with the highest package depth and lowest *Abstractness*
# - Set the property "abstractnessIncludingSubpackages" on Package nodes.

# %%
abstractnessIncludingSubpackages = query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Abstractness_for_Java_including_Subpackages.cypher",
                                                                              "../cypher/Metrics/Calculate_and_set_Abstractness_for_Java_including_Subpackages.cypher")
abstractnessIncludingSubpackages.head(30)
# Out:
#                             artifactName  \
# 0          axon-metrics-micrometer-5.0.3
# 1                   axon-messaging-5.0.3
# 2   axon-spring-boot-autoconfigure-5.0.3
# 3            axon-server-connector-5.0.3
# 4                   axon-messaging-5.0.3
# 5                   axon-messaging-5.0.3
# 6                   axon-messaging-5.0.3
# 7                   axon-messaging-5.0.3
# 8            axon-server-connector-5.0.3
# 9                      axon-update-5.0.3
# 10                 axon-conversion-5.0.3
# 11                 axon-conversion-5.0.3
# 12                 axon-conversion-5.0.3
# 13                  axon-messaging-5.0.3
# 14      axon-tracing-opentelemetry-5.0.3
# 15                     axon-common-5.0.3
# 16                  axon-messaging-5.0.3
# 17         axon-metrics-micrometer-5.0.3
# 18                     axon-update-5.0.3
# 19                  axon-messaging-5.0.3
# 20                  axon-messaging-5.0.3
# 21                  axon-messaging-5.0.3
# 22                  axon-messaging-5.0.3
# 23                  axon-messaging-5.0.3
# 24                  axon-messaging-5.0.3
# 25                  axon-messaging-5.0.3
# 26                  axon-messaging-5.0.3
# 27  axon-spring-boot-autoconfigure-5.0.3
# 28                       axon-test-5.0.3
# 29                  axon-messaging-5.0.3
#
#                              fullQualifiedPackageName    packageName  \
# 0      org.axonframework.extension.metrics.micrometer     micrometer
# 1      org.axonframework.messaging.core.configuration  configuration
# 2   org.axonframework.extension.springboot.autoconfig     autoconfig
# 3        org.axonframework.axonserver.connector.event          event
# 4   org.axonframework.messaging.queryhandling.inte...   interception
# 5            org.axonframework.messaging.core.timeout        timeout
# 6   org.axonframework.messaging.commandhandling.in...   interception
# 7      org.axonframework.messaging.tracing.attributes     attributes
# 8      org.axonframework.axonserver.connector.command        command
# 9                        org.axonframework.update.api            api
# 10               org.axonframework.conversion.jackson        jackson
# 11             org.axonframework.conversion.converter      converter
# 12              org.axonframework.conversion.jackson2       jackson2
# 13  org.axonframework.messaging.monitoring.interce...   interception
# 14  org.axonframework.extension.tracing.opentelemetry  opentelemetry
# 15                 org.axonframework.common.lifecycle      lifecycle
# 16  org.axonframework.messaging.eventhandling.proc...            jpa
# 17  org.axonframework.extension.metrics.micrometer...     springboot
# 18                 org.axonframework.update.detection      detection
# 19  org.axonframework.messaging.eventhandling.inte...   interception
# 20  org.axonframework.messaging.eventhandling.proc...       inmemory
# 21  org.axonframework.messaging.core.configuration...     reflection
# 22  org.axonframework.messaging.eventhandling.proc...     annotation
# 23        org.axonframework.messaging.core.reflection     reflection
# 24  org.axonframework.messaging.core.unitofwork.an...     annotation
# 25  org.axonframework.messaging.core.unitofwork.tr...           jdbc
# 26  org.axonframework.messaging.core.unitofwork.tr...            jpa
# 27  org.axonframework.extension.springboot.actuato...     axonserver
# 28                      org.axonframework.test.server         server
# 29  org.axonframework.messaging.commandhandling.retry          retry
#
#     abstractness  numberAbstractTypes  numberTypes  maxSubpackageDepth
# 0            0.0                    0           16                   1
# 1            0.0                    0            5                   1
# 2            0.0                    0           41                   0
# 3            0.0                    0           14                   0
# 4            0.0                    0            8                   0
# 5            0.0                    0            8                   0
# 6            0.0                    0            6                   0
# 7            0.0                    0            6                   0
# 8            0.0                    0            6                   0
# 9            0.0                    0            6                   0
# 10           0.0                    0            5                   0
# 11           0.0                    0            5                   0
# 12           0.0                    0            5                   0
# 13           0.0                    0            5                   0
# 14           0.0                    0            5                   0
# 15           0.0                    0            5                   0
# 16           0.0                    0            4                   0
# 17           0.0                    0            4                   0
# 18           0.0                    0            4                   0
# 19           0.0                    0            3                   0
# 20           0.0                    0            3                   0
# 21           0.0                    0            3                   0
# 22           0.0                    0            2                   0
# 23           0.0                    0            2                   0
# 24           0.0                    0            2                   0
# 25           0.0                    0            2                   0
# 26           0.0                    0            2                   0
# 27           0.0                    0            2                   0
# 28           0.0                    0            2                   0
# 29           0.0                    0            1                   0

# %% [markdown]
# #### Table 4d
#
# - Show the top 30 packages including their sub-packages with the highest package depth and highest *Abstractness*

# %%
abstractnessIncludingSubpackages.sort_values(by=['abstractness', 'maxSubpackageDepth', 'numberTypes'], ascending=[False, False, False]).head(30)
# Out:
#                              artifactName  \
# 119                     axon-common-5.0.3
# 120                     axon-common-5.0.3
# 117                  axon-messaging-5.0.3
# 118                  axon-messaging-5.0.3
# 116                  axon-messaging-5.0.3
# 115                  axon-modelling-5.0.3
# 114                  axon-messaging-5.0.3
# 113              axon-eventsourcing-5.0.3
# 112                  axon-modelling-5.0.3
# 105  axon-spring-boot-autoconfigure-5.0.3
# 106                     axon-common-5.0.3
# 107                       axon-test-5.0.3
# 108                     axon-common-5.0.3
# 109                  axon-messaging-5.0.3
# 110                  axon-messaging-5.0.3
# 111                  axon-messaging-5.0.3
# 104                     axon-common-5.0.3
# 103                  axon-messaging-5.0.3
# 101                       axon-test-5.0.3
# 102                  axon-messaging-5.0.3
# 100                  axon-modelling-5.0.3
# 97                   axon-messaging-5.0.3
# 98                   axon-messaging-5.0.3
# 99                   axon-messaging-5.0.3
# 96                   axon-messaging-5.0.3
# 95                   axon-modelling-5.0.3
# 94                   axon-messaging-5.0.3
# 93                   axon-messaging-5.0.3
# 92                   axon-messaging-5.0.3
# 90                   axon-messaging-5.0.3
#
#                               fullQualifiedPackageName      packageName  \
# 119                  org.axonframework.common.function         function
# 120                        org.axonframework.common.tx               tx
# 117  org.axonframework.messaging.commandhandling.co...    configuration
# 118  org.axonframework.messaging.queryhandling.conf...    configuration
# 116  org.axonframework.messaging.eventhandling.conf...    configuration
# 115             org.axonframework.modelling.repository       repository
# 114  org.axonframework.messaging.queryhandling.anno...       annotation
# 113         org.axonframework.eventsourcing.annotation       annotation
# 112          org.axonframework.modelling.configuration    configuration
# 105        org.axonframework.extension.springboot.util             util
# 106                      org.axonframework.common.jdbc             jdbc
# 107                   org.axonframework.test.extension        extension
# 108                org.axonframework.common.annotation       annotation
# 109  org.axonframework.messaging.eventhandling.conv...       conversion
# 110  org.axonframework.messaging.queryhandling.gateway          gateway
# 111        org.axonframework.messaging.core.conversion       conversion
# 104             org.axonframework.common.configuration    configuration
# 103  org.axonframework.messaging.core.interception....       annotation
# 101                     org.axonframework.test.fixture          fixture
# 102         org.axonframework.messaging.eventstreaming   eventstreaming
# 100           org.axonframework.modelling.entity.child            child
# 97   org.axonframework.messaging.commandhandling.di...      distributed
# 98   org.axonframework.messaging.eventhandling.repl...       annotation
# 99   org.axonframework.messaging.eventhandling.gateway          gateway
# 96           org.axonframework.messaging.queryhandling    queryhandling
# 95                         org.axonframework.modelling        modelling
# 94   org.axonframework.messaging.commandhandling.ga...          gateway
# 93   org.axonframework.messaging.queryhandling.dist...      distributed
# 92         org.axonframework.messaging.commandhandling  commandhandling
# 90    org.axonframework.messaging.eventhandling.replay           replay
#
#      abstractness  numberAbstractTypes  numberTypes  maxSubpackageDepth
# 119      1.000000                    2            2                   0
# 120      1.000000                    1            1                   0
# 117      0.750000                    3            4                   0
# 118      0.750000                    3            4                   0
# 116      0.714286                   10           14                   0
# 115      0.625000                    5            8                   0
# 114      0.571429                    4            7                   0
# 113      0.562500                    9           16                   1
# 112      0.538462                    7           13                   0
# 105      0.500000                    4            8                   1
# 106      0.500000                    6           12                   0
# 107      0.500000                    2            4                   0
# 108      0.500000                    2            4                   0
# 109      0.500000                    1            2                   0
# 110      0.500000                    1            2                   0
# 111      0.500000                    1            2                   0
# 104      0.478261                   22           46                   0
# 103      0.454545                    5           11                   0
# 101      0.437500                   14           32                   0
# 102      0.437500                    7           16                   0
# 100      0.428571                    6           14                   0
# 97       0.400000                    4           10                   0
# 98       0.400000                    4           10                   0
# 99       0.400000                    2            5                   0
# 96       0.380952                   24           63                   1
# 95       0.380435                   35           92                   2
# 94       0.375000                    3            8                   0
# 93       0.363636                    4           11                   0
# 92       0.359375                   23           64                   1
# 90       0.357143                    5           14                   1

# %% [markdown]
# ## Distance from the main sequence
#
# The *main sequence* is a imaginary line that represents a good compromise between *Abstractness* and *Instability*. A high distance to this line may indicate problems. For example is very *stable* (rigid) code with low abstractness hard to change.
#
# Read more details on that in [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616) and [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html).
#
# #### Table 5a
#
# - Show the top 30 packages with the highest distance from the "main sequence"

# %%
instabilityPerAbstractness = query_cypher_to_data_frame("../cypher/Metrics/Calculate_distance_between_abstractness_and_instability_for_Java.cypher")
instabilityPerAbstractness.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.3
# 1                  axon-conversion-5.0.3
# 2                   axon-messaging-5.0.3
# 3                      axon-common-5.0.3
# 4                   axon-messaging-5.0.3
# 5   axon-spring-boot-autoconfigure-5.0.3
# 6          axon-metrics-micrometer-5.0.3
# 7                      axon-common-5.0.3
# 8                      axon-common-5.0.3
# 9                  axon-conversion-5.0.3
# 10                 axon-conversion-5.0.3
# 11                  axon-messaging-5.0.3
# 12                  axon-messaging-5.0.3
# 13                  axon-messaging-5.0.3
# 14  axon-spring-boot-autoconfigure-5.0.3
# 15  axon-spring-boot-autoconfigure-5.0.3
# 16  axon-spring-boot-autoconfigure-5.0.3
# 17  axon-spring-boot-autoconfigure-5.0.3
# 18         axon-metrics-micrometer-5.0.3
# 19         axon-metrics-micrometer-5.0.3
# 20         axon-metrics-micrometer-5.0.3
# 21         axon-metrics-micrometer-5.0.3
# 22                       axon-test-5.0.3
# 23                       axon-test-5.0.3
# 24              axon-eventsourcing-5.0.3
# 25              axon-eventsourcing-5.0.3
# 26           axon-server-connector-5.0.3
# 27           axon-server-connector-5.0.3
# 28           axon-server-connector-5.0.3
# 29      axon-tracing-opentelemetry-5.0.3
#
#                                     fullQualifiedName           name  \
# 0      org.axonframework.messaging.tracing.attributes     attributes
# 1              org.axonframework.conversion.converter      converter
# 2         org.axonframework.messaging.core.reflection     reflection
# 3                   org.axonframework.common.function       function
# 4   org.axonframework.messaging.commandhandling.retry          retry
# 5     org.axonframework.extension.springboot.actuator       actuator
# 6   org.axonframework.extension.metrics.micrometer...      reservoir
# 7                         org.axonframework.common.io             io
# 8                     org.axonframework.common.digest         digest
# 9                                                 org            org
# 10                                  org.axonframework  axonframework
# 11                                                org            org
# 12                                  org.axonframework  axonframework
# 13                        org.axonframework.messaging      messaging
# 14                                                org            org
# 15                                  org.axonframework  axonframework
# 16                        org.axonframework.extension      extension
# 17     org.axonframework.extension.springboot.service        service
# 18                                                org            org
# 19                                  org.axonframework  axonframework
# 20                        org.axonframework.extension      extension
# 21                org.axonframework.extension.metrics        metrics
# 22                                                org            org
# 23                                  org.axonframework  axonframework
# 24                                                org            org
# 25                                  org.axonframework  axonframework
# 26                                                org            org
# 27                                  org.axonframework  axonframework
# 28                       org.axonframework.axonserver     axonserver
# 29                                                org            org
#
#     distance  abstractness  instability  elementsCount
# 0        NaN           0.0          NaN              6
# 1        NaN           0.0          NaN              5
# 2        NaN           0.0          NaN              2
# 3        NaN           1.0          NaN              2
# 4        NaN           0.0          NaN              1
# 5        NaN           1.0          NaN              1
# 6        NaN           0.0          NaN              1
# 7        NaN           0.0          NaN              1
# 8        NaN           0.0          NaN              1
# 9        NaN           0.0          NaN              0
# 10       NaN           0.0          NaN              0
# 11       NaN           0.0          NaN              0
# 12       NaN           0.0          NaN              0
# 13       NaN           0.0          NaN              0
# 14       NaN           0.0          NaN              0
# 15       NaN           0.0          NaN              0
# 16       NaN           0.0          NaN              0
# 17       NaN           0.0          NaN              0
# 18       NaN           0.0          NaN              0
# 19       NaN           0.0          NaN              0
# 20       NaN           0.0          NaN              0
# 21       NaN           0.0          NaN              0
# 22       NaN           0.0          NaN              0
# 23       NaN           0.0          NaN              0
# 24       NaN           0.0          NaN              0
# 25       NaN           0.0          NaN              0
# 26       NaN           0.0          NaN              0
# 27       NaN           0.0          NaN              0
# 28       NaN           0.0          NaN              0
# 29       NaN           0.0          NaN              0

# %% [markdown]
# #### Table 5b
#
# - Show the top 30 packages including their sub-packages with the highest distance from the "main sequence"

# %%
instabilityPerAbstractnessIncludingSubpackages = query_cypher_to_data_frame("../cypher/Metrics/Calculate_distance_between_abstractness_and_instability_for_Java_including_subpackages.cypher")
instabilityPerAbstractnessIncludingSubpackages.head(30)
# Out:
#                             artifactName  \
# 0                      axon-common-5.0.3
# 1                  axon-conversion-5.0.3
# 2                      axon-common-5.0.3
# 3                   axon-messaging-5.0.3
# 4                   axon-messaging-5.0.3
# 5                      axon-update-5.0.3
# 6                   axon-messaging-5.0.3
# 7                   axon-messaging-5.0.3
# 8                   axon-messaging-5.0.3
# 9                        axon-test-5.0.3
# 10                     axon-common-5.0.3
# 11                  axon-messaging-5.0.3
# 12                  axon-messaging-5.0.3
# 13                     axon-update-5.0.3
# 14  axon-spring-boot-autoconfigure-5.0.3
# 15                     axon-update-5.0.3
# 16                     axon-common-5.0.3
# 17                     axon-common-5.0.3
# 18              axon-eventsourcing-5.0.3
# 19                  axon-messaging-5.0.3
# 20                  axon-messaging-5.0.3
# 21                  axon-messaging-5.0.3
# 22                       axon-test-5.0.3
# 23                     axon-common-5.0.3
# 24                  axon-modelling-5.0.3
# 25                  axon-messaging-5.0.3
# 26  axon-spring-boot-autoconfigure-5.0.3
# 27                  axon-messaging-5.0.3
# 28                  axon-messaging-5.0.3
# 29                  axon-messaging-5.0.3
#
#                                     fullQualifiedName             name  \
# 0                  org.axonframework.common.lifecycle        lifecycle
# 1                        org.axonframework.conversion       conversion
# 2                      org.axonframework.common.infra            infra
# 3   org.axonframework.messaging.eventhandling.proc...            token
# 4                    org.axonframework.messaging.core             core
# 5                        org.axonframework.update.api              api
# 6   org.axonframework.messaging.commandhandling.co...    configuration
# 7   org.axonframework.messaging.queryhandling.conf...    configuration
# 8         org.axonframework.messaging.core.unitofwork       unitofwork
# 9                       org.axonframework.test.server           server
# 10                      org.axonframework.common.util             util
# 11                org.axonframework.messaging.tracing          tracing
# 12  org.axonframework.messaging.queryhandling.anno...       annotation
# 13                 org.axonframework.update.detection        detection
# 14    org.axonframework.extension.springboot.util.jpa              jpa
# 15                    org.axonframework.update.common           common
# 16                org.axonframework.common.annotation       annotation
# 17             org.axonframework.common.configuration    configuration
# 18         org.axonframework.eventsourcing.annotation       annotation
# 19  org.axonframework.messaging.eventhandling.proc...    errorhandling
# 20        org.axonframework.messaging.core.annotation       annotation
# 21          org.axonframework.messaging.eventhandling    eventhandling
# 22                     org.axonframework.test.fixture          fixture
# 23                  org.axonframework.common.property         property
# 24          org.axonframework.modelling.configuration    configuration
# 25         org.axonframework.messaging.eventstreaming   eventstreaming
# 26  org.axonframework.extension.springboot.actuato...       axonserver
# 27  org.axonframework.messaging.queryhandling.gateway          gateway
# 28  org.axonframework.messaging.eventhandling.conf...    configuration
# 29        org.axonframework.messaging.commandhandling  commandhandling
#
#     distance  abstractness  instability  elementsCount
# 0   0.833333      0.000000     0.166667              5
# 1   0.797901      0.142857     0.059242             35
# 2   0.746348      0.250000     0.003652              8
# 3   0.716378      0.129032     0.154589             31
# 4   0.697023      0.279661     0.023316            236
# 5   0.684211      0.000000     0.315789              6
# 6   0.678571      0.750000     0.928571              4
# 7   0.678571      0.750000     0.928571              4
# 8   0.675907      0.307692     0.016401             26
# 9   0.666667      0.000000     0.333333              2
# 10  0.575758      0.333333     0.090909              6
# 11  0.529435      0.263158     0.207407             19
# 12  0.523810      0.571429     0.952381              7
# 13  0.500000      0.000000     0.500000              4
# 14  0.500000      0.000000     0.500000              1
# 15  0.500000      0.000000     0.500000              1
# 16  0.499225      0.500000     0.000775              4
# 17  0.491551      0.478261     0.030188             46
# 18  0.474781      0.562500     0.912281             16
# 19  0.435897      0.333333     0.230769              3
# 20  0.434362      0.333333     0.232305             51
# 21  0.430308      0.322981     0.246711            161
# 22  0.423214      0.437500     0.985714             32
# 23  0.416667      0.333333     0.250000              9
# 24  0.415174      0.538462     0.876712             13
# 25  0.405157      0.437500     0.157343             16
# 26  0.400000      0.000000     0.600000              2
# 27  0.400000      0.500000     0.900000              2
# 28  0.388083      0.714286     0.673797             14
# 29  0.375319      0.359375     0.265306             64

# %% [markdown]
# ### *Abstractness* vs. *Instability* Plot with "Main Sequence" line as reference
#
# - Plot *Abstractness* vs. *Instability* of all packages
# - Draw the "main sequence" as dashed green diagonal line
# - Scale the packages by the number of types they contain
# - Color the packages by their distance to the "main sequence" (blue=near, red=far)

# %%
# Function that returns the number of past (index smaller than given index) rows 
# with the same value in columnName1 and columnName2
# If there was a row with the same columnName1 and columnName2 values
# def countPastEntriesWithSameValues(dataFrame, index, columnName1, columnName2):
#     columnValue1 = dataFrame[columnName1][index]
#     columnValue2 = dataFrame[columnName2][index]
#     return len(dataFrame[
#         (dataFrame.index.isin(range(0, index + 1))) & 
#         (dataFrame[columnName1]==columnValue1) & 
#         (dataFrame[columnName2]==columnValue2)
#     ]) - 1

# %%
def annotate_plot(data_frame: pd.DataFrame, index: int):
    """
    Annotates the data points identified by the "index" in the plot of the "data_frame" 
    """
    x_position = data_frame.abstractness[index].item()
    y_position = data_frame.instability[index].item()
    artifact_name = data_frame.artifactName[index].item()
    package_name = data_frame.name[index].item()

    label_box=dict(boxstyle="round4,pad=0.5", fc="w", alpha=0.8)
    plot.annotate(artifact_name + '\n' + package_name
        ,xy=(x_position, y_position)
        ,xycoords='data'
        ,xytext=(20, 0)
        ,textcoords='offset points'
        ,size=6
        ,bbox=label_box
        ,arrowprops=dict(arrowstyle="-|>", mutation_scale=10, color="black")
    )

def index_of_sorted(data_frame: pd.DataFrame, highest: list[str] = []):
    """
    Sorts the "data_frame" by columns 'abstractness','instability','elementsCount', 'artifactName'
    and returns the index of the first row.
    Columns that are contained in the list of strings parameter "highest" will be sorted descending.
    """
    by = ['abstractness','instability','elementsCount','artifactName']
    ascending = [('abstractness' not in highest), ('instability' not in highest), False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

def index_of_highest_property(data_frame: pd.DataFrame, highest: str):
    """
    Sorts the "data_frame" by the property given in input parameter "highest" descending
    and returns the index of the first row.
    """
    by = [highest,'artifactName']
    ascending = [False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

# %%
from  matplotlib.colors import LinearSegmentedColormap

def plot_instability_per_abstractness_with_main_sequence(data_frame: pd.DataFrame, subtitle: str = ''):
    """
    Prints the so called "Main Sequence" as green dotted diagonal line as a reference.
    On top of that every Java Package is plotted as a data point:
     - The X-axis is the "Abstractness" where 0 = all classes to 1 = all interfaces and abstract classes
     - The Y-axis is the "Instability" where 0 = stable (many incoming dependencies) and 1 instable (no incoming dependencies)
     - The size reflects the number of contained Java Types
     - The color reflects the distance to the "Main Sequence"
    """
        
    colormap=LinearSegmentedColormap.from_list('rg',["green", "gold", "orangered", "red"], N=256) 
    marker_scales_bounded=data_frame.elementsCount.clip(lower=2, upper=300) * 0.7

    plot.scatter(
        data_frame.abstractness, # x axis shows abstractness
        data_frame.instability, # y axis shows instability
        s=marker_scales_bounded, # scale depends on number of contained types
        c=data_frame.distance, # color depends on distance to the main sequence
        cmap=colormap, #'bwr' # colormap that prints high values in red and lower values in blue
        alpha=0.5,
    )
    # green "main sequence" line
    plot.plot([0,1], [1,0], c='lightgreen', linestyle='dashed') 

    # Annotate largest package
    annotate_plot(data_frame, index_of_highest_property(data_frame, highest='elementsCount'))
    # Annotate largest package with the highest abstractness and instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['abstractness','instability']))
    # Annotate largest package with the lowest abstractness and highest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['instability']))
    # Annotate largest package with the lowest abstractness and lowest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=[]))
    # Annotate largest package with the highest abstractness and lowest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['abstractness']))
    # Annotate largest packages with the highest abstractness and instability near 0.5% 
    annotation_index = index_of_sorted(highest=['abstractness', 'instability'], data_frame=data_frame.query('abstractness <= 0.4 & instability <= 0.4'))
    annotate_plot(data_frame, annotation_index)

    plot.title('Abstractness vs. Instability ("Main Sequence")\n' + subtitle)
    plot.xlabel('Abstractness')
    plot.ylabel('Instability')
    plot.show()

# %% [markdown]
# #### Figure 5a - Packages without their sub-packages

# %%
if not instabilityPerAbstractness.empty:
   plot_instability_per_abstractness_with_main_sequence(instabilityPerAbstractness, 'Packages without their sub-packages')

# %% [markdown]
# #### Figure 5b - Packages including their sub-packages

# %%
if not instabilityPerAbstractnessIncludingSubpackages.empty:
   plot_instability_per_abstractness_with_main_sequence(instabilityPerAbstractnessIncludingSubpackages, 'Packages including their sub-packages')
