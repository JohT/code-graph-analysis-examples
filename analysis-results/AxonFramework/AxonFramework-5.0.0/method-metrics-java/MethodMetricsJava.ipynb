# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())
    

def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-5.0.0.jar  axon-common-5.0.0.jar  \
# effectiveLineCount
# 1                                       1936                    349
# 2                                        500                    139
# 3                                        424                     87
# 4                                        189                     39
# 5                                        148                     36
# 6                                         85                     36
# 7                                         67                     14
# 8                                         66                     17
# 9                                         41                     11
# 10                                        24                      6
# 11                                        22                      7
# 12                                         8                      7
# 13                                         9                      5
# 14                                         6                      5
# 15                                         5                      1
# 16                                         7                      2
# 17                                         3                      3
# 18                                         1                      1
# 19                                         3                      0
# 20                                         2                      0
# 21                                         1                      0
# 22                                         3                      0
# 23                                         1                      0
# 24                                         0                      1
# 25                                         2                      0
# 26                                         1                      1
# 27                                         1                      0
# 28                                         0                      0
# 29                                         0                      0
# 30                                         1                      0
# 31                                         0                      0
# 36                                         1                      0
# 40                                         0                      0
# 41                                         0                      0
# 42                                         0                      0
# 45                                         0                      0
# 77                                         1                      0
#
# artifactName        axon-server-connector-5.0.0.jar  \
# effectiveLineCount
# 1                                               266
# 2                                               143
# 3                                                77
# 4                                                43
# 5                                                34
# 6                                                14
# 7                                                 9
# 8                                                15
# 9                                                11
# 10                                                7
# 11                                                2
# 12                                                3
# 13                                                2
# 14                                                2
# 15                                                1
# 16                                                1
# 17                                                2
# 18                                                1
# 19                                                0
# 20                                                1
# 21                                                2
# 22                                                0
# 23                                                0
# 24                                                0
# 25                                                0
# 26                                                0
# 27                                                0
# 28                                                1
# 29                                                0
# 30                                                1
# 31                                                0
# 36                                                0
# 40                                                0
# 41                                                0
# 42                                                1
# 45                                                0
# 77                                                0
#
# artifactName        axon-eventsourcing-5.0.0.jar  axon-test-5.0.0.jar  \
# effectiveLineCount
# 1                                            302                  201
# 2                                             74                   72
# 3                                             57                   32
# 4                                             54                   35
# 5                                             28                    4
# 6                                             19                   13
# 7                                             15                    8
# 8                                              4                    7
# 9                                             11                    7
# 10                                             6                    2
# 11                                             5                    3
# 12                                             4                    7
# 13                                             4                    3
# 14                                             2                    3
# 15                                             2                    1
# 16                                             1                    3
# 17                                             1                    0
# 18                                             0                    2
# 19                                             1                    0
# 20                                             1                    2
# 21                                             1                    1
# 22                                             0                    0
# 23                                             0                    1
# 24                                             0                    0
# 25                                             0                    0
# 26                                             0                    1
# 27                                             1                    0
# 28                                             0                    0
# 29                                             0                    0
# 30                                             1                    0
# 31                                             0                    1
# 36                                             0                    0
# 40                                             1                    0
# 41                                             0                    0
# 42                                             0                    0
# 45                                             0                    1
# 77                                             0                    0
#
# artifactName        axon-modelling-5.0.0.jar  \
# effectiveLineCount
# 1                                        175
# 2                                         56
# 3                                         30
# 4                                         36
# 5                                         23
# 6                                         18
# 7                                          9
# 8                                          9
# 9                                         13
# 10                                         3
# 11                                         2
# 12                                         4
# 13                                         5
# 14                                         1
# 15                                         1
# 16                                         1
# 17                                         2
# 18                                         2
# 19                                         0
# 20                                         0
# 21                                         1
# 22                                         0
# 23                                         0
# 24                                         0
# 25                                         0
# 26                                         0
# 27                                         0
# 28                                         0
# 29                                         0
# 30                                         0
# 31                                         0
# 36                                         0
# 40                                         0
# 41                                         0
# 42                                         0
# 45                                         0
# 77                                         0
#
# artifactName        axon-spring-boot-autoconfigure-5.0.0.jar  \
# effectiveLineCount
# 1                                                        161
# 2                                                         75
# 3                                                         15
# 4                                                          6
# 5                                                          9
# 6                                                          5
# 7                                                          5
# 8                                                          2
# 9                                                          2
# 10                                                         1
# 11                                                         0
# 12                                                         1
# 13                                                         1
# 14                                                         0
# 15                                                         0
# 16                                                         0
# 17                                                         1
# 18                                                         0
# 19                                                         0
# 20                                                         0
# 21                                                         0
# 22                                                         0
# 23                                                         1
# 24                                                         0
# 25                                                         0
# 26                                                         0
# 27                                                         0
# 28                                                         0
# 29                                                         1
# 30                                                         0
# 31                                                         0
# 36                                                         0
# 40                                                         0
# 41                                                         0
# 42                                                         0
# 45                                                         0
# 77                                                         0
#
# artifactName        axon-conversion-5.0.0.jar  axon-update-5.0.0.jar  \
# effectiveLineCount
# 1                                         101                     88
# 2                                          20                     11
# 3                                          12                      6
# 4                                           8                      9
# 5                                           9                      8
# 6                                           7                      8
# 7                                           5                      2
# 8                                           5                      3
# 9                                           4                      3
# 10                                          1                      2
# 11                                          2                      0
# 12                                          0                      0
# 13                                          1                      4
# 14                                          0                      2
# 15                                          1                      1
# 16                                          2                      0
# 17                                          1                      2
# 18                                          0                      1
# 19                                          1                      0
# 20                                          0                      0
# 21                                          0                      2
# 22                                          0                      0
# 23                                          0                      0
# 24                                          0                      1
# 25                                          0                      0
# 26                                          0                      0
# 27                                          0                      0
# 28                                          0                      0
# 29                                          1                      0
# 30                                          1                      0
# 31                                          0                      0
# 36                                          0                      0
# 40                                          0                      0
# 41                                          0                      1
# 42                                          0                      0
# 45                                          0                      0
# 77                                          0                      0
#
# artifactName        axon-metrics-micrometer-5.0.0.jar  \
# effectiveLineCount
# 1                                                  34
# 2                                                  17
# 3                                                  15
# 4                                                   6
# 5                                                   2
# 6                                                   4
# 7                                                   4
# 8                                                   5
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                                  3
# 14                                                  0
# 15                                                  1
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 36                                                  0
# 40                                                  0
# 41                                                  0
# 42                                                  0
# 45                                                  0
# 77                                                  0
#
# artifactName        axon-tracing-opentelemetry-5.0.0.jar
# effectiveLineCount
# 1                                                     11
# 2                                                      4
# 3                                                     10
# 4                                                      7
# 5                                                      2
# 6                                                      3
# 7                                                      2
# 8                                                      0
# 9                                                      1
# 10                                                     0
# 11                                                     0
# 12                                                     1
# 13                                                     0
# 14                                                     0
# 15                                                     0
# 16                                                     0
# 17                                                     0
# 18                                                     0
# 19                                                     0
# 20                                                     0
# 21                                                     0
# 22                                                     0
# 23                                                     0
# 24                                                     0
# 25                                                     0
# 26                                                     0
# 27                                                     0
# 28                                                     0
# 29                                                     0
# 30                                                     0
# 31                                                     0
# 36                                                     0
# 40                                                     0
# 41                                                     0
# 42                                                     0
# 45                                                     0
# 77                                                     0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-5.0.0.jar  axon-common-5.0.0.jar  \
# effectiveLineCount
# 1                                  54.412591              45.501956
# 2                                  14.052839              18.122555
# 3                                  11.916807              11.342894
# 4                                   5.311973               5.084746
# 5                                   4.159640               4.693611
# 6                                   2.388983               4.693611
# 7                                   1.883080               1.825293
# 8                                   1.854975               2.216428
# 9                                   1.152333               1.434159
# 10                                  0.674536               0.782269
# 11                                  0.618325               0.912647
# 12                                  0.224845               0.912647
# 13                                  0.252951               0.651890
# 14                                  0.168634               0.651890
# 15                                  0.140528               0.130378
# 16                                  0.196740               0.260756
# 17                                  0.084317               0.391134
# 18                                  0.028106               0.130378
# 19                                  0.084317               0.000000
# 20                                  0.056211               0.000000
# 21                                  0.028106               0.000000
# 22                                  0.084317               0.000000
# 23                                  0.028106               0.000000
# 24                                  0.000000               0.130378
# 25                                  0.056211               0.000000
# 26                                  0.028106               0.130378
# 27                                  0.028106               0.000000
# 28                                  0.000000               0.000000
# 29                                  0.000000               0.000000
# 30                                  0.028106               0.000000
# 31                                  0.000000               0.000000
# 36                                  0.028106               0.000000
# 40                                  0.000000               0.000000
# 41                                  0.000000               0.000000
# 42                                  0.000000               0.000000
# 45                                  0.000000               0.000000
# 77                                  0.028106               0.000000
#
# artifactName        axon-server-connector-5.0.0.jar  \
# effectiveLineCount
# 1                                         41.627543
# 2                                         22.378717
# 3                                         12.050078
# 4                                          6.729264
# 5                                          5.320814
# 6                                          2.190923
# 7                                          1.408451
# 8                                          2.347418
# 9                                          1.721440
# 10                                         1.095462
# 11                                         0.312989
# 12                                         0.469484
# 13                                         0.312989
# 14                                         0.312989
# 15                                         0.156495
# 16                                         0.156495
# 17                                         0.312989
# 18                                         0.156495
# 19                                         0.000000
# 20                                         0.156495
# 21                                         0.312989
# 22                                         0.000000
# 23                                         0.000000
# 24                                         0.000000
# 25                                         0.000000
# 26                                         0.000000
# 27                                         0.000000
# 28                                         0.156495
# 29                                         0.000000
# 30                                         0.156495
# 31                                         0.000000
# 36                                         0.000000
# 40                                         0.000000
# 41                                         0.000000
# 42                                         0.156495
# 45                                         0.000000
# 77                                         0.000000
#
# artifactName        axon-eventsourcing-5.0.0.jar  axon-test-5.0.0.jar  \
# effectiveLineCount
# 1                                      50.756303            49.024390
# 2                                      12.436975            17.560976
# 3                                       9.579832             7.804878
# 4                                       9.075630             8.536585
# 5                                       4.705882             0.975610
# 6                                       3.193277             3.170732
# 7                                       2.521008             1.951220
# 8                                       0.672269             1.707317
# 9                                       1.848739             1.707317
# 10                                      1.008403             0.487805
# 11                                      0.840336             0.731707
# 12                                      0.672269             1.707317
# 13                                      0.672269             0.731707
# 14                                      0.336134             0.731707
# 15                                      0.336134             0.243902
# 16                                      0.168067             0.731707
# 17                                      0.168067             0.000000
# 18                                      0.000000             0.487805
# 19                                      0.168067             0.000000
# 20                                      0.168067             0.487805
# 21                                      0.168067             0.243902
# 22                                      0.000000             0.000000
# 23                                      0.000000             0.243902
# 24                                      0.000000             0.000000
# 25                                      0.000000             0.000000
# 26                                      0.000000             0.243902
# 27                                      0.168067             0.000000
# 28                                      0.000000             0.000000
# 29                                      0.000000             0.000000
# 30                                      0.168067             0.000000
# 31                                      0.000000             0.243902
# 36                                      0.000000             0.000000
# 40                                      0.168067             0.000000
# 41                                      0.000000             0.000000
# 42                                      0.000000             0.000000
# 45                                      0.000000             0.243902
# 77                                      0.000000             0.000000
#
# artifactName        axon-modelling-5.0.0.jar  \
# effectiveLineCount
# 1                                  44.757033
# 2                                  14.322251
# 3                                   7.672634
# 4                                   9.207161
# 5                                   5.882353
# 6                                   4.603581
# 7                                   2.301790
# 8                                   2.301790
# 9                                   3.324808
# 10                                  0.767263
# 11                                  0.511509
# 12                                  1.023018
# 13                                  1.278772
# 14                                  0.255754
# 15                                  0.255754
# 16                                  0.255754
# 17                                  0.511509
# 18                                  0.511509
# 19                                  0.000000
# 20                                  0.000000
# 21                                  0.255754
# 22                                  0.000000
# 23                                  0.000000
# 24                                  0.000000
# 25                                  0.000000
# 26                                  0.000000
# 27                                  0.000000
# 28                                  0.000000
# 29                                  0.000000
# 30                                  0.000000
# 31                                  0.000000
# 36                                  0.000000
# 40                                  0.000000
# 41                                  0.000000
# 42                                  0.000000
# 45                                  0.000000
# 77                                  0.000000
#
# artifactName        axon-spring-boot-autoconfigure-5.0.0.jar  \
# effectiveLineCount
# 1                                                  56.293706
# 2                                                  26.223776
# 3                                                   5.244755
# 4                                                   2.097902
# 5                                                   3.146853
# 6                                                   1.748252
# 7                                                   1.748252
# 8                                                   0.699301
# 9                                                   0.699301
# 10                                                  0.349650
# 11                                                  0.000000
# 12                                                  0.349650
# 13                                                  0.349650
# 14                                                  0.000000
# 15                                                  0.000000
# 16                                                  0.000000
# 17                                                  0.349650
# 18                                                  0.000000
# 19                                                  0.000000
# 20                                                  0.000000
# 21                                                  0.000000
# 22                                                  0.000000
# 23                                                  0.349650
# 24                                                  0.000000
# 25                                                  0.000000
# 26                                                  0.000000
# 27                                                  0.000000
# 28                                                  0.000000
# 29                                                  0.349650
# 30                                                  0.000000
# 31                                                  0.000000
# 36                                                  0.000000
# 40                                                  0.000000
# 41                                                  0.000000
# 42                                                  0.000000
# 45                                                  0.000000
# 77                                                  0.000000
#
# artifactName        axon-conversion-5.0.0.jar  axon-update-5.0.0.jar  \
# effectiveLineCount
# 1                                   55.494505              57.142857
# 2                                   10.989011               7.142857
# 3                                    6.593407               3.896104
# 4                                    4.395604               5.844156
# 5                                    4.945055               5.194805
# 6                                    3.846154               5.194805
# 7                                    2.747253               1.298701
# 8                                    2.747253               1.948052
# 9                                    2.197802               1.948052
# 10                                   0.549451               1.298701
# 11                                   1.098901               0.000000
# 12                                   0.000000               0.000000
# 13                                   0.549451               2.597403
# 14                                   0.000000               1.298701
# 15                                   0.549451               0.649351
# 16                                   1.098901               0.000000
# 17                                   0.549451               1.298701
# 18                                   0.000000               0.649351
# 19                                   0.549451               0.000000
# 20                                   0.000000               0.000000
# 21                                   0.000000               1.298701
# 22                                   0.000000               0.000000
# 23                                   0.000000               0.000000
# 24                                   0.000000               0.649351
# 25                                   0.000000               0.000000
# 26                                   0.000000               0.000000
# 27                                   0.000000               0.000000
# 28                                   0.000000               0.000000
# 29                                   0.549451               0.000000
# 30                                   0.549451               0.000000
# 31                                   0.000000               0.000000
# 36                                   0.000000               0.000000
# 40                                   0.000000               0.000000
# 41                                   0.000000               0.649351
# 42                                   0.000000               0.000000
# 45                                   0.000000               0.000000
# 77                                   0.000000               0.000000
#
# artifactName        axon-metrics-micrometer-5.0.0.jar  \
# effectiveLineCount
# 1                                           36.956522
# 2                                           18.478261
# 3                                           16.304348
# 4                                            6.521739
# 5                                            2.173913
# 6                                            4.347826
# 7                                            4.347826
# 8                                            5.434783
# 9                                            1.086957
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           3.260870
# 14                                           0.000000
# 15                                           1.086957
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 36                                           0.000000
# 40                                           0.000000
# 41                                           0.000000
# 42                                           0.000000
# 45                                           0.000000
# 77                                           0.000000
#
# artifactName        axon-tracing-opentelemetry-5.0.0.jar
# effectiveLineCount
# 1                                              26.829268
# 2                                               9.756098
# 3                                              24.390244
# 4                                              17.073171
# 5                                               4.878049
# 6                                               7.317073
# 7                                               4.878049
# 8                                               0.000000
# 9                                               2.439024
# 10                                              0.000000
# 11                                              0.000000
# 12                                              2.439024
# 13                                              0.000000
# 14                                              0.000000
# 15                                              0.000000
# 16                                              0.000000
# 17                                              0.000000
# 18                                              0.000000
# 19                                              0.000000
# 20                                              0.000000
# 21                                              0.000000
# 22                                              0.000000
# 23                                              0.000000
# 24                                              0.000000
# 25                                              0.000000
# 26                                              0.000000
# 27                                              0.000000
# 28                                              0.000000
# 29                                              0.000000
# 30                                              0.000000
# 31                                              0.000000
# 36                                              0.000000
# 40                                              0.000000
# 41                                              0.000000
# 42                                              0.000000
# 45                                              0.000000
# 77                                              0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
if effective_method_line_count_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,20)
    axes = effective_method_line_count_distribution_normalized.head(20).plot(
        kind='line',
        logx=True,
        grid=True,
        xlim=[2, 20],
        ylim=[0, 20],
        xticks=method_line_count_x_ticks,
        title='Effective Method Line Count Distribution', 
        xlabel='effective line count',
        ylabel='percent of methods',
        cmap=main_color_map,
        figsize=(10, 6),
        lw=2,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.0
# 1                   axon-messaging-5.0.0
# 2                        axon-test-5.0.0
# 3            axon-server-connector-5.0.0
# 4                   axon-messaging-5.0.0
# 5                      axon-common-5.0.0
# 6                      axon-common-5.0.0
# 7               axon-eventsourcing-5.0.0
# 8            axon-server-connector-5.0.0
# 9               axon-eventsourcing-5.0.0
# 10                  axon-messaging-5.0.0
# 11                  axon-messaging-5.0.0
# 12                  axon-messaging-5.0.0
# 13           axon-server-connector-5.0.0
# 14                  axon-modelling-5.0.0
# 15                       axon-test-5.0.0
# 16                  axon-messaging-5.0.0
# 17                 axon-conversion-5.0.0
# 18  axon-spring-boot-autoconfigure-5.0.0
# 19         axon-metrics-micrometer-5.0.0
# 20                  axon-modelling-5.0.0
# 21                  axon-messaging-5.0.0
# 22                  axon-messaging-5.0.0
# 23  axon-spring-boot-autoconfigure-5.0.0
# 24                     axon-common-5.0.0
# 25                     axon-common-5.0.0
# 26                  axon-messaging-5.0.0
# 27                  axon-messaging-5.0.0
# 28                  axon-messaging-5.0.0
# 29                  axon-messaging-5.0.0
#
#                                       fullPackageName  linesInPackage  \
# 0   org.axonframework.messaging.eventhandling.proc...            1319
# 1                    org.axonframework.messaging.core            1119
# 2                      org.axonframework.test.fixture             709
# 3              org.axonframework.axonserver.connector             698
# 4         org.axonframework.messaging.core.annotation             687
# 5              org.axonframework.common.configuration             667
# 6                            org.axonframework.common             605
# 7          org.axonframework.eventsourcing.eventstore             591
# 8        org.axonframework.axonserver.connector.event             535
# 9      org.axonframework.eventsourcing.eventstore.jpa             455
# 10  org.axonframework.messaging.eventhandling.proc...             455
# 11          org.axonframework.messaging.queryhandling             378
# 12        org.axonframework.messaging.core.unitofwork             352
# 13       org.axonframework.axonserver.connector.query             325
# 14      org.axonframework.modelling.entity.annotation             321
# 15                    org.axonframework.test.matchers             318
# 16  org.axonframework.messaging.eventhandling.proc...             297
# 17                  org.axonframework.conversion.avro             292
# 18  org.axonframework.extension.springboot.autoconfig             290
# 19     org.axonframework.extension.metrics.micrometer             281
# 20                 org.axonframework.modelling.entity             268
# 21     org.axonframework.messaging.core.configuration             259
# 22  org.axonframework.messaging.eventhandling.proc...             253
# 23             org.axonframework.extension.springboot             246
# 24                   org.axonframework.common.caching             234
# 25                     org.axonframework.common.infra             233
# 26        org.axonframework.messaging.commandhandling             228
# 27  org.axonframework.messaging.eventhandling.proc...             224
# 28           org.axonframework.messaging.core.timeout             217
# 29          org.axonframework.messaging.eventhandling             207
#
#     methodCount  maxLinesMethod  \
# 0           390              77
# 1           531              16
# 2           200              45
# 3           278              42
# 4           225              23
# 5           261              26
# 6           181              24
# 7           232              19
# 8           161              21
# 9           138              20
# 10          130              25
# 11          171              14
# 12          172              21
# 13           90              21
# 14           75              18
# 15          101              21
# 16          115              12
# 17           81              30
# 18          121              29
# 19           87              15
# 20           76              18
# 21          120              19
# 22           96              19
# 23          134               9
# 24           85              13
# 25           56              14
# 26          101              18
# 27           50              22
# 28           56              16
# 29           84              11
#
#                                    maxLinesMethodName
# 0                                                 run
# 1                                             process
# 2                                 appendEventOverview
# 3                                               build
# 4                                              <init>
# 5                             invokeLifecycleHandlers
# 6   getExactDirectSuperTypesOfParameterizedTypeOrC...
# 7                                  createTagsForValue
# 8                               lambda$appendEvents$0
# 9                                     withGapsCleaned
# 10                                        updateToken
# 11                                             handle
# 12                                       runNextPhase
# 13                                convertQueryMessage
# 14                       createOptionalChildForMember
# 15                                     matchingFields
# 16                                         advancedTo
# 17                                            convert
# 18                                     buildConverter
# 19                             registerEventProcessor
# 20                                             <init>
# 21                                 registerComponents
# 22                                              split
# 23                                             <init>
# 24                          lambda$computeIfPresent$4
# 25                                   describeProperty
# 26                                             handle
# 27                                         storeToken
# 28                                             <init>
# 29                                             handle

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index                          artifactName  \
# 0       0                  axon-messaging-5.0.0
# 1       2                       axon-test-5.0.0
# 2       3           axon-server-connector-5.0.0
# 3      42                     axon-update-5.0.0
# 4      30              axon-eventsourcing-5.0.0
# 5      17                 axon-conversion-5.0.0
# 6      61              axon-eventsourcing-5.0.0
# 7      18  axon-spring-boot-autoconfigure-5.0.0
# 8      65                 axon-conversion-5.0.0
# 9       5                     axon-common-5.0.0
# 10     10                  axon-messaging-5.0.0
# 11      6                     axon-common-5.0.0
# 12     82  axon-spring-boot-autoconfigure-5.0.0
# 13      4                  axon-messaging-5.0.0
# 14     27                  axon-messaging-5.0.0
# 15     40                     axon-update-5.0.0
# 16     54                  axon-modelling-5.0.0
# 17     47                     axon-update-5.0.0
# 18     15                       axon-test-5.0.0
# 19     13           axon-server-connector-5.0.0
# 20      8           axon-server-connector-5.0.0
# 21     12                  axon-messaging-5.0.0
# 22      9              axon-eventsourcing-5.0.0
# 23     34           axon-server-connector-5.0.0
# 24     33                       axon-test-5.0.0
# 25     21                  axon-messaging-5.0.0
# 26      7              axon-eventsourcing-5.0.0
# 27     22                  axon-messaging-5.0.0
# 28     14                  axon-modelling-5.0.0
# 29     20                  axon-modelling-5.0.0
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.proc...
# 1                      org.axonframework.test.fixture
# 2              org.axonframework.axonserver.connector
# 3                  org.axonframework.update.detection
# 4   org.axonframework.eventsourcing.annotation.ref...
# 5                   org.axonframework.conversion.avro
# 6          org.axonframework.eventsourcing.annotation
# 7   org.axonframework.extension.springboot.autoconfig
# 8                   org.axonframework.conversion.json
# 9              org.axonframework.common.configuration
# 10  org.axonframework.messaging.eventhandling.proc...
# 11                           org.axonframework.common
# 12        org.axonframework.extension.springboot.util
# 13        org.axonframework.messaging.core.annotation
# 14  org.axonframework.messaging.eventhandling.proc...
# 15                           org.axonframework.update
# 16             org.axonframework.modelling.annotation
# 17                       org.axonframework.update.api
# 18                    org.axonframework.test.matchers
# 19       org.axonframework.axonserver.connector.query
# 20       org.axonframework.axonserver.connector.event
# 21        org.axonframework.messaging.core.unitofwork
# 22     org.axonframework.eventsourcing.eventstore.jpa
# 23     org.axonframework.axonserver.connector.command
# 24                      org.axonframework.test.server
# 25     org.axonframework.messaging.core.configuration
# 26         org.axonframework.eventsourcing.eventstore
# 27  org.axonframework.messaging.eventhandling.proc...
# 28      org.axonframework.modelling.entity.annotation
# 29                 org.axonframework.modelling.entity
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                                            Reporter
# 2                 AxonServerConnectionManager$Builder
# 3                             TestEnvironmentDetector
# 4            AnnotationBasedEventSourcedEntityFactory
# 5                                       AvroConverter
# 6   AnnotationBasedEventCriteriaResolver$WrappedEv...
# 7                          ConverterAutoConfiguration
# 8                                    JacksonConverter
# 9        DefaultAxonApplication$AxonConfigurationImpl
# 10                                     JdbcTokenStore
# 11                                TypeReflectionUtils
# 12                     AbstractQualifiedBeanCondition
# 13                MethodInvokingMessageHandlingMember
# 14                                      JpaTokenStore
# 15                            UpdateCheckerHttpClient
# 16             AnnotationBasedEntityEvolvingComponent
# 17                                UpdateCheckResponse
# 18                                  DeepEqualsMatcher
# 19                                     QueryConverter
# 20         AggregateBasedAxonServerEventStorageEngine
# 21             UnitOfWork$UnitOfWorkProcessingContext
# 22                    GapAwareTrackingTokenOperations
# 23                                   CommandConverter
# 24                           AxonServerContainerUtils
# 25                     MessagingConfigurationDefaults
# 26                         AnnotationBasedTagResolver
# 27                                      TrackerStatus
# 28                           AnnotatedEntityMetamodel
# 29                            ConcreteEntityMetamodel
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              77
# 1                                 appendEventOverview              45
# 2                                               build              42
# 3                                         isTestClass              41
# 4                          addEntityCreatorExecutable              40
# 5                                             convert              30
# 6                                              <init>              30
# 7                                      buildConverter              29
# 8                                             convert              29
# 9                             invokeLifecycleHandlers              26
# 10                                        updateToken              25
# 11  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 12                                    getMatchOutcome              23
# 13                                             <init>              23
# 14                                         storeToken              22
# 15                                        sendRequest              21
# 16                                             evolve              21
# 17                                        fromRequest              21
# 18                                     matchingFields              21
# 19                                convertQueryMessage              21
# 20                              lambda$appendEvents$0              21
# 21                                       runNextPhase              21
# 22                                    withGapsCleaned              20
# 23                               convertResultMessage              20
# 24                                      createContext              20
# 25                                 registerComponents              19
# 26                                 createTagsForValue              19
# 27                                              split              19
# 28                       createOptionalChildForMember              18
# 29                                             <init>              18
#
#     linesInPackage
# 0             1319
# 1              709
# 2              698
# 3              163
# 4              197
# 5              292
# 6               97
# 7              290
# 8               86
# 9              667
# 10             455
# 11             605
# 12              46
# 13             687
# 14             224
# 15             168
# 16             120
# 17             143
# 18             318
# 19             325
# 20             535
# 21             352
# 22             455
# 23             186
# 24             195
# 25             259
# 26             591
# 27             253
# 28             321
# 29             268

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-5.0.0.jar  axon-common-5.0.0.jar  \
# cyclomaticComplexity
# 1                                         2935                    537
# 2                                          316                     88
# 3                                          148                     74
# 4                                           86                     31
# 5                                           29                     10
# 6                                           27                      7
# 7                                            9                      6
# 8                                            3                      8
# 9                                            1                      3
# 10                                           0                      1
# 11                                           1                      1
# 12                                           0                      1
# 13                                           1                      0
# 17                                           0                      0
# 21                                           0                      0
# 23                                           1                      0
# 41                                           0                      0
# 58                                           1                      0
#
# artifactName          axon-server-connector-5.0.0.jar  \
# cyclomaticComplexity
# 1                                                 536
# 2                                                  57
# 3                                                  25
# 4                                                   7
# 5                                                   5
# 6                                                   5
# 7                                                   1
# 8                                                   0
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  0
# 17                                                  0
# 21                                                  0
# 23                                                  0
# 41                                                  0
# 58                                                  0
#
# artifactName          axon-eventsourcing-5.0.0.jar  axon-test-5.0.0.jar  \
# cyclomaticComplexity
# 1                                              455                  314
# 2                                               63                   36
# 3                                               36                   32
# 4                                               17                    7
# 5                                                8                    9
# 6                                                6                    5
# 7                                                4                    2
# 8                                                4                    2
# 9                                                0                    1
# 10                                               0                    0
# 11                                               1                    1
# 12                                               0                    1
# 13                                               1                    0
# 17                                               0                    0
# 21                                               0                    0
# 23                                               0                    0
# 41                                               0                    0
# 58                                               0                    0
#
# artifactName          axon-modelling-5.0.0.jar  \
# cyclomaticComplexity
# 1                                          311
# 2                                           27
# 3                                           23
# 4                                           16
# 5                                            7
# 6                                            5
# 7                                            1
# 8                                            1
# 9                                            0
# 10                                           0
# 11                                           0
# 12                                           0
# 13                                           0
# 17                                           0
# 21                                           0
# 23                                           0
# 41                                           0
# 58                                           0
#
# artifactName          axon-spring-boot-autoconfigure-5.0.0.jar  \
# cyclomaticComplexity
# 1                                                          262
# 2                                                           11
# 3                                                            7
# 4                                                            2
# 5                                                            1
# 6                                                            0
# 7                                                            1
# 8                                                            0
# 9                                                            2
# 10                                                           0
# 11                                                           0
# 12                                                           0
# 13                                                           0
# 17                                                           0
# 21                                                           0
# 23                                                           0
# 41                                                           0
# 58                                                           0
#
# artifactName          axon-conversion-5.0.0.jar  axon-update-5.0.0.jar  \
# cyclomaticComplexity
# 1                                           137                    119
# 2                                            14                     16
# 3                                             8                      5
# 4                                            11                      1
# 5                                             2                      3
# 6                                             3                      5
# 7                                             2                      1
# 8                                             1                      0
# 9                                             1                      1
# 10                                            1                      0
# 11                                            0                      1
# 12                                            0                      0
# 13                                            0                      0
# 17                                            1                      1
# 21                                            1                      0
# 23                                            0                      0
# 41                                            0                      1
# 58                                            0                      0
#
# artifactName          axon-metrics-micrometer-5.0.0.jar  \
# cyclomaticComplexity
# 1                                                    86
# 2                                                     3
# 3                                                     1
# 4                                                     0
# 5                                                     0
# 6                                                     2
# 7                                                     0
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 12                                                    0
# 13                                                    0
# 17                                                    0
# 21                                                    0
# 23                                                    0
# 41                                                    0
# 58                                                    0
#
# artifactName          axon-tracing-opentelemetry-5.0.0.jar
# cyclomaticComplexity
# 1                                                       30
# 2                                                        8
# 3                                                        2
# 4                                                        1
# 5                                                        0
# 6                                                        0
# 7                                                        0
# 8                                                        0
# 9                                                        0
# 10                                                       0
# 11                                                       0
# 12                                                       0
# 13                                                       0
# 17                                                       0
# 21                                                       0
# 23                                                       0
# 41                                                       0
# 58                                                       0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-5.0.0.jar  axon-common-5.0.0.jar  \
# cyclomaticComplexity
# 1                                    82.490163              70.013038
# 2                                     8.881394              11.473272
# 3                                     4.159640               9.647979
# 4                                     2.417088               4.041721
# 5                                     0.815065               1.303781
# 6                                     0.758853               0.912647
# 7                                     0.252951               0.782269
# 8                                     0.084317               1.043025
# 9                                     0.028106               0.391134
# 10                                    0.000000               0.130378
# 11                                    0.028106               0.130378
# 12                                    0.000000               0.130378
# 13                                    0.028106               0.000000
# 17                                    0.000000               0.000000
# 21                                    0.000000               0.000000
# 23                                    0.028106               0.000000
# 41                                    0.000000               0.000000
# 58                                    0.028106               0.000000
#
# artifactName          axon-server-connector-5.0.0.jar  \
# cyclomaticComplexity
# 1                                           83.881064
# 2                                            8.920188
# 3                                            3.912363
# 4                                            1.095462
# 5                                            0.782473
# 6                                            0.782473
# 7                                            0.156495
# 8                                            0.000000
# 9                                            0.312989
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.156495
# 13                                           0.000000
# 17                                           0.000000
# 21                                           0.000000
# 23                                           0.000000
# 41                                           0.000000
# 58                                           0.000000
#
# artifactName          axon-eventsourcing-5.0.0.jar  axon-test-5.0.0.jar  \
# cyclomaticComplexity
# 1                                        76.470588            76.585366
# 2                                        10.588235             8.780488
# 3                                         6.050420             7.804878
# 4                                         2.857143             1.707317
# 5                                         1.344538             2.195122
# 6                                         1.008403             1.219512
# 7                                         0.672269             0.487805
# 8                                         0.672269             0.487805
# 9                                         0.000000             0.243902
# 10                                        0.000000             0.000000
# 11                                        0.168067             0.243902
# 12                                        0.000000             0.243902
# 13                                        0.168067             0.000000
# 17                                        0.000000             0.000000
# 21                                        0.000000             0.000000
# 23                                        0.000000             0.000000
# 41                                        0.000000             0.000000
# 58                                        0.000000             0.000000
#
# artifactName          axon-modelling-5.0.0.jar  \
# cyclomaticComplexity
# 1                                    79.539642
# 2                                     6.905371
# 3                                     5.882353
# 4                                     4.092072
# 5                                     1.790281
# 6                                     1.278772
# 7                                     0.255754
# 8                                     0.255754
# 9                                     0.000000
# 10                                    0.000000
# 11                                    0.000000
# 12                                    0.000000
# 13                                    0.000000
# 17                                    0.000000
# 21                                    0.000000
# 23                                    0.000000
# 41                                    0.000000
# 58                                    0.000000
#
# artifactName          axon-spring-boot-autoconfigure-5.0.0.jar  \
# cyclomaticComplexity
# 1                                                    91.608392
# 2                                                     3.846154
# 3                                                     2.447552
# 4                                                     0.699301
# 5                                                     0.349650
# 6                                                     0.000000
# 7                                                     0.349650
# 8                                                     0.000000
# 9                                                     0.699301
# 10                                                    0.000000
# 11                                                    0.000000
# 12                                                    0.000000
# 13                                                    0.000000
# 17                                                    0.000000
# 21                                                    0.000000
# 23                                                    0.000000
# 41                                                    0.000000
# 58                                                    0.000000
#
# artifactName          axon-conversion-5.0.0.jar  axon-update-5.0.0.jar  \
# cyclomaticComplexity
# 1                                     75.274725              77.272727
# 2                                      7.692308              10.389610
# 3                                      4.395604               3.246753
# 4                                      6.043956               0.649351
# 5                                      1.098901               1.948052
# 6                                      1.648352               3.246753
# 7                                      1.098901               0.649351
# 8                                      0.549451               0.000000
# 9                                      0.549451               0.649351
# 10                                     0.549451               0.000000
# 11                                     0.000000               0.649351
# 12                                     0.000000               0.000000
# 13                                     0.000000               0.000000
# 17                                     0.549451               0.649351
# 21                                     0.549451               0.000000
# 23                                     0.000000               0.000000
# 41                                     0.000000               0.649351
# 58                                     0.000000               0.000000
#
# artifactName          axon-metrics-micrometer-5.0.0.jar  \
# cyclomaticComplexity
# 1                                             93.478261
# 2                                              3.260870
# 3                                              1.086957
# 4                                              0.000000
# 5                                              0.000000
# 6                                              2.173913
# 7                                              0.000000
# 8                                              0.000000
# 9                                              0.000000
# 10                                             0.000000
# 11                                             0.000000
# 12                                             0.000000
# 13                                             0.000000
# 17                                             0.000000
# 21                                             0.000000
# 23                                             0.000000
# 41                                             0.000000
# 58                                             0.000000
#
# artifactName          axon-tracing-opentelemetry-5.0.0.jar
# cyclomaticComplexity
# 1                                                73.170732
# 2                                                19.512195
# 3                                                 4.878049
# 4                                                 2.439024
# 5                                                 0.000000
# 6                                                 0.000000
# 7                                                 0.000000
# 8                                                 0.000000
# 9                                                 0.000000
# 10                                                0.000000
# 11                                                0.000000
# 12                                                0.000000
# 13                                                0.000000
# 17                                                0.000000
# 21                                                0.000000
# 23                                                0.000000
# 41                                                0.000000
# 58                                                0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
if cyclomatic_method_complexity_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,11)
    cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
    axes = cyclomatic_method_complexity_distribution_normalized.plot(
        kind='line', 
        logx=True,
        logy=True,
        grid=True,
        xlim=[1,11],
        ylim=[1,100],
        xticks=method_line_count_x_ticks,
        yticks=cyclomatic_complexity_y_ticks,
        title='Cyclomatic complexity distribution of methods', 
        xlabel='cyclomatic complexity',
        ylabel='percentage of methods',
        cmap=main_color_map,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.set_yticklabels(cyclomatic_complexity_y_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                             artifactName  \
# 1                   axon-messaging-5.0.0
# 0                   axon-messaging-5.0.0
# 6                      axon-common-5.0.0
# 7               axon-eventsourcing-5.0.0
# 4                   axon-messaging-5.0.0
# 3            axon-server-connector-5.0.0
# 5                      axon-common-5.0.0
# 2                        axon-test-5.0.0
# 12                  axon-messaging-5.0.0
# 16                  axon-messaging-5.0.0
# 8            axon-server-connector-5.0.0
# 11                  axon-messaging-5.0.0
# 9               axon-eventsourcing-5.0.0
# 10                  axon-messaging-5.0.0
# 15                       axon-test-5.0.0
# 18  axon-spring-boot-autoconfigure-5.0.0
# 17                 axon-conversion-5.0.0
# 36                  axon-messaging-5.0.0
# 22                  axon-messaging-5.0.0
# 24                     axon-common-5.0.0
# 23  axon-spring-boot-autoconfigure-5.0.0
# 21                  axon-messaging-5.0.0
# 14                  axon-modelling-5.0.0
# 13           axon-server-connector-5.0.0
# 26                  axon-messaging-5.0.0
# 43                  axon-messaging-5.0.0
# 20                  axon-modelling-5.0.0
# 29                  axon-messaging-5.0.0
# 19         axon-metrics-micrometer-5.0.0
# 27                  axon-messaging-5.0.0
#
#                                       fullPackageName  complexityInPackage  \
# 1                    org.axonframework.messaging.core                  731
# 0   org.axonframework.messaging.eventhandling.proc...                  537
# 6                            org.axonframework.common                  381
# 7          org.axonframework.eventsourcing.eventstore                  371
# 4         org.axonframework.messaging.core.annotation                  361
# 3              org.axonframework.axonserver.connector                  357
# 5              org.axonframework.common.configuration                  357
# 2                      org.axonframework.test.fixture                  312
# 12        org.axonframework.messaging.core.unitofwork                  228
# 16  org.axonframework.messaging.eventhandling.proc...                  217
# 8        org.axonframework.axonserver.connector.event                  215
# 11          org.axonframework.messaging.queryhandling                  213
# 9      org.axonframework.eventsourcing.eventstore.jpa                  212
# 10  org.axonframework.messaging.eventhandling.proc...                  196
# 15                    org.axonframework.test.matchers                  173
# 18  org.axonframework.extension.springboot.autoconfig                  164
# 17                  org.axonframework.conversion.avro                  159
# 36  org.axonframework.messaging.eventhandling.anno...                  153
# 22  org.axonframework.messaging.eventhandling.proc...                  149
# 24                   org.axonframework.common.caching                  147
# 23             org.axonframework.extension.springboot                  137
# 21     org.axonframework.messaging.core.configuration                  132
# 14      org.axonframework.modelling.entity.annotation                  130
# 13       org.axonframework.axonserver.connector.query                  127
# 26        org.axonframework.messaging.commandhandling                  120
# 43         org.axonframework.messaging.eventstreaming                  119
# 20                 org.axonframework.modelling.entity                  119
# 29          org.axonframework.messaging.eventhandling                  104
# 19     org.axonframework.extension.metrics.micrometer                   99
# 27  org.axonframework.messaging.eventhandling.proc...                   98
#
#     methodCount  maxComplexity                 maxComplexityMethod
# 1           531              9                             process
# 0           390             23                                 run
# 6           181              9  doConstructionWithOptionalArgument
# 7           232              8                                from
# 4           225             13                     resolveToStream
# 3           278             12                               build
# 5           261              8                   registerComponent
# 2           200             11                 appendEventOverview
# 12          172              6                              commit
# 16          115              7                              covers
# 8           161              4                      releaseSegment
# 11          171              4                  subscribeToUpdates
# 9           138              8               loadKeyViolationCodes
# 10          130              8                         updateToken
# 15          101              8                         matchesList
# 18          121              9         registerHandlerInterceptors
# 17           81             21                             convert
# 36           66             58                      parseParameter
# 22           96              8                         isDifferent
# 24           85              8                             onEvent
# 23          134              2                           batchSize
# 21          120              4        lambda$registerDecorators$10
# 14           75              6         createCommandTargetResolver
# 13           90              6                 responseSendingLoop
# 26          101              4                           subscribe
# 43           92              4                          havingTags
# 20           76              7                      handleInstance
# 29           84              4                         andMetadata
# 19           87              6    registerComponentWithDefaultTags
# 27           50              6                              equals

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index                          artifactName  \
# 0      36                  axon-messaging-5.0.0
# 1      42                     axon-update-5.0.0
# 2       0                  axon-messaging-5.0.0
# 3      17                 axon-conversion-5.0.0
# 4      47                     axon-update-5.0.0
# 5      65                 axon-conversion-5.0.0
# 6       4                  axon-messaging-5.0.0
# 7      30              axon-eventsourcing-5.0.0
# 8       3           axon-server-connector-5.0.0
# 9      33                       axon-test-5.0.0
# 10     52                     axon-common-5.0.0
# 11      2                       axon-test-5.0.0
# 12     61              axon-eventsourcing-5.0.0
# 13     53                     axon-common-5.0.0
# 14      1                  axon-messaging-5.0.0
# 15     18  axon-spring-boot-autoconfigure-5.0.0
# 16      6                     axon-common-5.0.0
# 17      9              axon-eventsourcing-5.0.0
# 18     10                  axon-messaging-5.0.0
# 19      5                     axon-common-5.0.0
# 20      7              axon-eventsourcing-5.0.0
# 21     15                       axon-test-5.0.0
# 22     24                     axon-common-5.0.0
# 23     37                  axon-modelling-5.0.0
# 24     22                  axon-messaging-5.0.0
# 25     68                     axon-common-5.0.0
# 26     25                     axon-common-5.0.0
# 27     72                     axon-common-5.0.0
# 28     50                  axon-messaging-5.0.0
# 29     20                  axon-modelling-5.0.0
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.anno...
# 1                  org.axonframework.update.detection
# 2   org.axonframework.messaging.eventhandling.proc...
# 3                   org.axonframework.conversion.avro
# 4                        org.axonframework.update.api
# 5                   org.axonframework.conversion.json
# 6         org.axonframework.messaging.core.annotation
# 7   org.axonframework.eventsourcing.annotation.ref...
# 8              org.axonframework.axonserver.connector
# 9                       org.axonframework.test.server
# 10                      org.axonframework.common.jdbc
# 11                     org.axonframework.test.fixture
# 12         org.axonframework.eventsourcing.annotation
# 13                      org.axonframework.common.lock
# 14                   org.axonframework.messaging.core
# 15  org.axonframework.extension.springboot.autoconfig
# 16                           org.axonframework.common
# 17     org.axonframework.eventsourcing.eventstore.jpa
# 18  org.axonframework.messaging.eventhandling.proc...
# 19             org.axonframework.common.configuration
# 20         org.axonframework.eventsourcing.eventstore
# 21                    org.axonframework.test.matchers
# 22                   org.axonframework.common.caching
# 23           org.axonframework.modelling.entity.child
# 24  org.axonframework.messaging.eventhandling.proc...
# 25                org.axonframework.common.annotation
# 26                     org.axonframework.common.infra
# 27                      org.axonframework.common.util
# 28  org.axonframework.messaging.commandhandling.an...
# 29                 org.axonframework.modelling.entity
#
#                                     maxComplexityType  \
# 0   MethodSequencingPolicyEventHandlerDefinition$S...
# 1                             TestEnvironmentDetector
# 2                        Coordinator$CoordinationTask
# 3                                       AvroConverter
# 4                                 UpdateCheckResponse
# 5                                    JacksonConverter
# 6                          MessageStreamResolverUtils
# 7            AnnotationBasedEventSourcedEntityFactory
# 8                 AxonServerConnectionManager$Builder
# 9                                 AxonServerContainer
# 10                           ConnectionWrapperFactory
# 11                                           Reporter
# 12  AnnotationBasedEventCriteriaResolver$WrappedEv...
# 13              PessimisticLockFactory$DisposableLock
# 14                         MessageStreamUtils$Reducer
# 15                       InterceptorAutoConfiguration
# 16                                   ConstructorUtils
# 17                              SQLErrorCodesResolver
# 18                                     JdbcTokenStore
# 19                           DefaultComponentRegistry
# 20                    AggregateBasedConsistencyMarker
# 21                                    SequenceMatcher
# 22           EhCacheAdapter$CacheEventListenerAdapter
# 23                    FieldChildEntityFieldDefinition
# 24                                 EventTrackerStatus
# 25                                    AnnotationUtils
# 26    FilesystemStyleComponentDescriptor$TreeRenderer
# 27                                   PriorityCallable
# 28  MethodCommandHandlerDefinition$MethodCommandHa...
# 29                            ConcreteEntityMetamodel
#
#                    maxComplexityMethod  maxComplexity
# 0                       parseParameter             58
# 1                          isTestClass             41
# 2                                  run             23
# 3                              convert             21
# 4                          fromRequest             17
# 5                              convert             17
# 6                      resolveToStream             13
# 7           addEntityCreatorExecutable             13
# 8                                build             12
# 9                               equals             12
# 10                       lambda$wrap$0             12
# 11                 appendEventOverview             11
# 12                              <init>             11
# 13                                lock             10
# 14                             process              9
# 15         registerHandlerInterceptors              9
# 16  doConstructionWithOptionalArgument              9
# 17               loadKeyViolationCodes              8
# 18                         updateToken              8
# 19                   registerComponent              8
# 20                                from              8
# 21                         matchesList              8
# 22                             onEvent              8
# 23       evolveParentBasedOnChildInput              8
# 24                         isDifferent              8
# 25                   collectAttributes              8
# 26                      renderProperty              7
# 27                              equals              7
# 28                              <init>              7
# 29                      handleInstance              7
