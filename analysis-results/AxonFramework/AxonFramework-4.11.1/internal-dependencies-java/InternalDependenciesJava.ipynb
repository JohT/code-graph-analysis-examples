# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypherFileName):
    with open(cypherFileName) as file:
        return ' '.join(file.readlines())

# %%
def query_cypher_to_data_frame(filename : str, limit: int = 10_000):
    cypher_query_template = "{query}\nLIMIT {row_limit}"
    cypher_query = get_cypher_query_from_file(filename)
    cypher_query = cypher_query_template.format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = 10_000):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.1.jar        66    809
# 1           axon-server-connector-4.11.1.jar        11    142
# 2                  axon-modelling-4.11.1.jar        10    158
# 3              axon-eventsourcing-4.11.1.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 5                       axon-test-4.11.1.jar         8     87
# 6              axon-configuration-4.11.1.jar         1     41
# 7                  axon-disruptor-4.11.1.jar         1     22
# 8      axon-tracing-opentelemetry-4.11.1.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     1                     4
# 2                     6                     1
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.1.jar        66    809
# 1                  axon-modelling-4.11.1.jar        10    158
# 2           axon-server-connector-4.11.1.jar        11    142
# 3              axon-eventsourcing-4.11.1.jar         9    133
# 4  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 5                       axon-test-4.11.1.jar         8     87
# 6              axon-configuration-4.11.1.jar         1     41
# 7                  axon-disruptor-4.11.1.jar         1     22
# 8      axon-tracing-opentelemetry-4.11.1.jar         1      5
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     4
# 3                     5                     2
# 4                     0                     7
# 5                     1                     3
# 6                     2                     4
# 7                     1                     3
# 8                     1                     1

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.1.jar        66    809
# 1                  axon-modelling-4.11.1.jar        10    158
# 2              axon-eventsourcing-4.11.1.jar         9    133
# 3              axon-configuration-4.11.1.jar         1     41
# 4                  axon-disruptor-4.11.1.jar         1     22
# 5           axon-server-connector-4.11.1.jar        11    142
# 6                       axon-test-4.11.1.jar         8     87
# 7      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 8  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     5                     2
# 3                     2                     4
# 4                     1                     3
# 5                     1                     4
# 6                     1                     3
# 7                     1                     1
# 8                     0                     7

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 1              axon-configuration-4.11.1.jar         1     41
# 2           axon-server-connector-4.11.1.jar        11    142
# 3                  axon-disruptor-4.11.1.jar         1     22
# 4                       axon-test-4.11.1.jar         8     87
# 5              axon-eventsourcing-4.11.1.jar         9    133
# 6                  axon-modelling-4.11.1.jar        10    158
# 7      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 8                  axon-messaging-4.11.1.jar        66    809
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     2                     4
# 2                     1                     4
# 3                     1                     3
# 4                     1                     3
# 5                     5                     2
# 6                     6                     1
# 7                     1                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0              axon-configuration-4.11.1.jar         1     41
# 1                  axon-disruptor-4.11.1.jar         1     22
# 2      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 3                       axon-test-4.11.1.jar         8     87
# 4              axon-eventsourcing-4.11.1.jar         9    133
# 5  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 6                  axon-modelling-4.11.1.jar        10    158
# 7           axon-server-connector-4.11.1.jar        11    142
# 8                  axon-messaging-4.11.1.jar        66    809
#
#    incomingDependencies  outgoingDependencies
# 0                     2                     4
# 1                     1                     3
# 2                     1                     1
# 3                     1                     3
# 4                     5                     2
# 5                     0                     7
# 6                     6                     1
# 7                     1                     4
# 8                     8                     0

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 1                  axon-disruptor-4.11.1.jar         1     22
# 2              axon-configuration-4.11.1.jar         1     41
# 3                       axon-test-4.11.1.jar         8     87
# 4  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 5              axon-eventsourcing-4.11.1.jar         9    133
# 6           axon-server-connector-4.11.1.jar        11    142
# 7                  axon-modelling-4.11.1.jar        10    158
# 8                  axon-messaging-4.11.1.jar        66    809
#
#    incomingDependencies  outgoingDependencies
# 0                     1                     1
# 1                     1                     3
# 2                     2                     4
# 3                     1                     3
# 4                     0                     7
# 5                     5                     2
# 6                     1                     4
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
# 1                  axon-disruptor-4.11.1.jar         1     22
# 2           axon-server-connector-4.11.1.jar        11    142
# 3                       axon-test-4.11.1.jar         8     87
# 4      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 5              axon-configuration-4.11.1.jar         1     41
# 6              axon-eventsourcing-4.11.1.jar         9    133
# 7                  axon-modelling-4.11.1.jar        10    158
# 8                  axon-messaging-4.11.1.jar        66    809
#
#    incomingDependencies  outgoingDependencies
# 0                     0                     7
# 1                     1                     3
# 2                     1                     4
# 3                     1                     3
# 4                     1                     1
# 5                     2                     4
# 6                     5                     2
# 7                     6                     1
# 8                     8                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                  axon-messaging-4.11.1.jar        66    809
# 1                  axon-modelling-4.11.1.jar        10    158
# 2      axon-tracing-opentelemetry-4.11.1.jar         1      5
# 3              axon-eventsourcing-4.11.1.jar         9    133
# 4                  axon-disruptor-4.11.1.jar         1     22
# 5                       axon-test-4.11.1.jar         8     87
# 6              axon-configuration-4.11.1.jar         1     41
# 7           axon-server-connector-4.11.1.jar        11    142
# 8  axon-spring-boot-autoconfigure-4.11.1.jar         9     88
#
#    incomingDependencies  outgoingDependencies
# 0                     8                     0
# 1                     6                     1
# 2                     1                     1
# 3                     5                     2
# 4                     1                     3
# 5                     1                     3
# 6                     2                     4
# 7                     1                     4
# 8                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                     artifactName  \
# 0          axon-messaging-4.11.1
# 1          axon-messaging-4.11.1
# 2          axon-messaging-4.11.1
# 3          axon-messaging-4.11.1
# 4          axon-messaging-4.11.1
# 5          axon-messaging-4.11.1
# 6          axon-messaging-4.11.1
# 7      axon-eventsourcing-4.11.1
# 8          axon-messaging-4.11.1
# 9          axon-messaging-4.11.1
# 10         axon-messaging-4.11.1
# 11  axon-server-connector-4.11.1
# 12  axon-server-connector-4.11.1
# 13         axon-messaging-4.11.1
# 14         axon-messaging-4.11.1
# 15  axon-server-connector-4.11.1
# 16  axon-server-connector-4.11.1
# 17  axon-server-connector-4.11.1
# 18         axon-messaging-4.11.1
# 19     axon-eventsourcing-4.11.1
# 20         axon-messaging-4.11.1
# 21         axon-modelling-4.11.1
# 22         axon-messaging-4.11.1
# 23         axon-messaging-4.11.1
# 24  axon-server-connector-4.11.1
# 25         axon-messaging-4.11.1
# 26         axon-modelling-4.11.1
# 27         axon-messaging-4.11.1
#
#                                                     packageName  \
# 0                               org.axonframework.eventhandling
# 1                               org.axonframework.queryhandling
# 2                               org.axonframework.queryhandling
# 3                               org.axonframework.eventhandling
# 4                               org.axonframework.eventhandling
# 5                                    org.axonframework.deadline
# 6                             org.axonframework.commandhandling
# 7                               org.axonframework.eventsourcing
# 8                   org.axonframework.commandhandling.callbacks
# 9                               org.axonframework.eventhandling
# 10                       org.axonframework.messaging.unitofwork
# 11            org.axonframework.axonserver.connector.event.axon
# 12                 org.axonframework.axonserver.connector.query
# 13                        org.axonframework.eventhandling.async
# 14                       org.axonframework.eventhandling.replay
# 15                  org.axonframework.axonserver.connector.util
# 16                       org.axonframework.axonserver.connector
# 17                 org.axonframework.axonserver.connector.query
# 18              org.axonframework.serialization.upcasting.event
# 19              org.axonframework.eventsourcing.eventstore.jdbc
# 20                              org.axonframework.eventhandling
# 21               org.axonframework.modelling.command.inspection
# 22                 org.axonframework.queryhandling.registration
# 23                                  org.axonframework.messaging
# 24               org.axonframework.axonserver.connector.command
# 25                       org.axonframework.messaging.annotation
# 26                             org.axonframework.modelling.saga
# 27  org.axonframework.commandhandling.distributed.commandfilter
#
#            dependentArtifactName  \
# 0          axon-messaging-4.11.1
# 1          axon-messaging-4.11.1
# 2          axon-messaging-4.11.1
# 3          axon-messaging-4.11.1
# 4          axon-messaging-4.11.1
# 5          axon-messaging-4.11.1
# 6          axon-messaging-4.11.1
# 7      axon-eventsourcing-4.11.1
# 8          axon-messaging-4.11.1
# 9          axon-messaging-4.11.1
# 10         axon-messaging-4.11.1
# 11  axon-server-connector-4.11.1
# 12  axon-server-connector-4.11.1
# 13         axon-messaging-4.11.1
# 14         axon-messaging-4.11.1
# 15  axon-server-connector-4.11.1
# 16  axon-server-connector-4.11.1
# 17  axon-server-connector-4.11.1
# 18         axon-messaging-4.11.1
# 19     axon-eventsourcing-4.11.1
# 20         axon-messaging-4.11.1
# 21         axon-modelling-4.11.1
# 22         axon-messaging-4.11.1
# 23         axon-messaging-4.11.1
# 24  axon-server-connector-4.11.1
# 25         axon-messaging-4.11.1
# 26         axon-modelling-4.11.1
# 27         axon-messaging-4.11.1
#
#                                           dependentPackageName  \
# 0                                    org.axonframework.tracing
# 1                    org.axonframework.messaging.responsetypes
# 2                                    org.axonframework.tracing
# 3                                  org.axonframework.messaging
# 4                       org.axonframework.messaging.annotation
# 5                                    org.axonframework.tracing
# 6                                    org.axonframework.tracing
# 7                   org.axonframework.eventsourcing.eventstore
# 8                            org.axonframework.commandhandling
# 9                              org.axonframework.serialization
# 10                                 org.axonframework.messaging
# 11                      org.axonframework.axonserver.connector
# 12                      org.axonframework.axonserver.connector
# 13                             org.axonframework.eventhandling
# 14                             org.axonframework.eventhandling
# 15                      org.axonframework.axonserver.connector
# 16           org.axonframework.axonserver.connector.event.util
# 17   org.axonframework.axonserver.connector.query.subscription
# 18                             org.axonframework.eventhandling
# 19  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 20                  org.axonframework.eventhandling.tokenstore
# 21                         org.axonframework.modelling.command
# 22                             org.axonframework.queryhandling
# 23                             org.axonframework.serialization
# 24                      org.axonframework.axonserver.connector
# 25                    org.axonframework.messaging.interceptors
# 26                  org.axonframework.modelling.saga.metamodel
# 27               org.axonframework.commandhandling.distributed
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.840000             23               2
# 5                   0.800000              9               1
# 6                   0.777778              8               1
# 7                   0.777778             16               2
# 8                   0.733333             13               2
# 9                   0.647059             14               3
# 10                  0.647059             14               3
# 11                  0.615385             21               5
# 12                  0.571429             22               6
# 13                  0.571429             11               3
# 14                  0.454545              8               3
# 15                  0.428571              5               2
# 16                  0.333333              2               1
# 17                  0.333333              4               2
# 18                  0.333333              6               3
# 19                  0.317073             27              14
# 20                  0.285714              9               5
# 21                  0.250000             20              12
# 22                  0.250000              5               3
# 23                  0.238095             13               8
# 24                  0.222222             11               7
# 25                  0.200000              3               2
# 26                  0.142857              4               3
# 27                  0.076923              7               6
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [AbstractEventProcessor$Builder->NoOpSpanFactory, AbstractEventProcessor$Builder->SpanFactory, DefaultEventBusSpanFactory->SpanFactory, DefaultEventBusSpanFactory->Span, AbstractEventBus$Builder->SpanFactory, AbstractEventBus$Builder->NoOpSpanFactory, DefaultEventProcessorSpanFactory$Builder->Sp...
# 1   [GenericQueryMessage->ResponseType, QuerySubscription->ResponseType, StreamingQueryMessage->ResponseType, GenericStreamingQueryMessage->PublisherResponseType, GenericStreamingQueryMessage->ResponseType, DefaultQueryGateway->ResponseType, QueryMessage->ResponseType, GenericSubscriptionQueryMessag...
# 2   [DefaultQueryBusSpanFactory$Builder->SpanFactory, SimpleQueryBus$Builder->NoOpSpanFactory, SimpleQueryBus$Builder->SpanFactory, DefaultQueryUpdateEmitterSpanFactory->Span, DefaultQueryUpdateEmitterSpanFactory->SpanFactory, SimpleQueryUpdateEmitter$Builder->NoOpSpanFactory, SimpleQueryUpdateEmitt...
# 3   [EventBus->SubscribableMessageSource, EventBus->MessageDispatchInterceptorSupport, GenericDomainEventMessage->GenericMessage, GenericDomainEventMessage->MetaData, GenericDomainEventMessage->Message, GenericTrackedDomainEventMessage->Message, DefaultEventBusSpanFactory->Message, TrackingEventProc...
# 4   [AnnotationEventHandlerAdapter->ClasspathHandlerDefinition, AnnotationEventHandlerAdapter->ClasspathParameterResolverFactory, AnnotationEventHandlerAdapter->ParameterResolverFactory, AnnotationEventHandlerAdapter->MessageHandlingMember, AnnotationEventHandlerAdapter->HandlerDefinition, Annotatio...
# 5   [SimpleDeadlineManager$Builder->SpanFactory, SimpleDeadlineManager$Builder->NoOpSpanFactory, SimpleDeadlineManager->Span, DefaultDeadlineManagerSpanFactory->Span, DefaultDeadlineManagerSpanFactory->SpanFactory, DeadlineManagerSpanFactory->Span, SimpleDeadlineManager$DeadlineTask->SpanScope, Simp...
# 6   [CommandBusSpanFactory->Span, DefaultCommandBusSpanFactory$Builder->SpanFactory, SimpleCommandBus->Span, AsynchronousCommandBus$Builder->SpanFactory, SimpleCommandBus$Builder->SpanFactory, SimpleCommandBus$Builder->NoOpSpanFactory, DefaultCommandBusSpanFactory->Span, DefaultCommandBusSpanFactory...
# 7   [EventSourcingRepository->EventStore, EventSourcingRepository->DomainEventStream, AbstractSnapshotter->EventStore, AbstractSnapshotter->DomainEventStream, AggregateSnapshotter->DomainEventStream, AggregateSnapshotter$Builder->EventStore, EventSourcingRepository$Builder->EventStore, AbstractSnaps...
# 8   [FutureCallback->CommandCallback, FutureCallback->CommandMessage, FutureCallback->GenericCommandResultMessage, FutureCallback->CommandResultMessage, FailureLoggingCallback->CommandMessage, FailureLoggingCallback->CommandCallback, FailureLoggingCallback->CommandResultMessage, LoggingCallback->Com...
# 9   [EventData->SerializedObject, EventUtils->Serializer, EventUtils->LazyDeserializingObject, EventUtils->SerializedMessage, GenericEventMessage->CachingSupplier, TrackedDomainEventData->SerializedObject, AbstractSequencedDomainEventEntry->Serializer, AbstractDomainEventEntry->Serializer, AbstractE...
# 10                             [UnitOfWork->ResultMessage, UnitOfWork->MetaData, UnitOfWork->Message, MessageProcessingContext->Message, ExecutionResult->ResultMessage, CurrentUnitOfWork->MetaData, BatchingUnitOfWork->GenericResultMessage, BatchingUnitOfWork->Message, BatchingUnitOfWork->ResultMessage]
# 11  [EventBuffer->AxonServerException, EventBuffer->ErrorCode, PersistentStreamConnection->AxonServerConfiguration, PersistentStreamConnection->AxonServerConnectionManager, PersistentStreamConnection->AxonServerConfiguration$FlowControlConfiguration, AxonServerEventStore$AxonIQEventStorageEngine$Bui...
# 12  [StreamableFluxResponse$SendingSubscriber->ErrorCode, QueryProcessingTask->ErrorCode, AxonServerQueryBus$LocalSegmentAdapter$1->PriorityRunnable, AxonServerQueryBus$Builder->AxonServerConfiguration, AxonServerQueryBus$Builder->AxonServerConnectionManager, AxonServerQueryBus$Builder->TargetContex...
# 13  [EventProcessorTask$ProcessingTask->EventMessage, FullConcurrencyPolicy->EventMessage, MetaDataSequencingPolicy->EventMessage, AsynchronousEventProcessingStrategy->EventProcessingStrategy, AsynchronousEventProcessingStrategy->EventMessage, PropertySequencingPolicy$Builder$ExceptionRaisingSequenc...
# 14  [ReplayParameterResolverFactory->ReplayStatus, ReplayParameterResolverFactory$ReplayParameterResolver->ReplayToken, ReplayParameterResolverFactory$ReplayParameterResolver->ReplayStatus, ReplayAwareMessageHandlerWrapper$ReplayBlockingMessageHandlingMember->ReplayToken, ReplayContextParameterResol...
# 15                             [ExecutorServiceBuilder->AxonServerConfiguration, PriorityExecutorService->PriorityRunnable, PriorityExecutorService->PriorityCallable, FlowControllingStreamObserver->AxonServerConfiguration, FlowControllingStreamObserver->AxonServerConfiguration$FlowControlConfiguration]
# 16                                                                                                                                                                                                                         [AxonServerConfiguration$Builder->EventCipher, AxonServerConfiguration->EventCipher]
# 17                                                                 [AxonServerQueryBus$Builder->SubscriptionMessageSerializer, AxonServerQueryBus->AxonServerSubscriptionQueryResult, AxonServerQueryBus->SubscriptionMessageSerializer, AxonServerQueryBus$LocalSegmentAdapter->SubscriptionMessageSerializer]
# 18                                    [InitialEventRepresentation->DomainEventData, InitialEventRepresentation->TrackedEventData, InitialEventRepresentation->TrackingToken, InitialEventRepresentation->EventData, IntermediateEventRepresentation->TrackingToken, UpcastedEventRepresentation->TrackingToken]
# 19  [JdbcEventStorageEngine$Builder->LastSequenceNumberForStatementBuilder, JdbcEventStorageEngine$Builder->DeleteSnapshotsStatementBuilder, JdbcEventStorageEngine$Builder->CreateHeadTokenStatementBuilder, JdbcEventStorageEngine$Builder->CleanGapsStatementBuilder, JdbcEventStorageEngine$Builder->Rea...
# 20  [TrackingEventProcessor$ClaimSegmentInstruction->TokenStore, TrackingEventProcessor$WorkerLauncher->UnableToClaimTokenException, TrackingEventProcessor$WorkerLauncher->TokenStore, TrackingEventProcessor$SplitSegmentInstruction->TokenStore, TrackingEventProcessor$Instruction->UnableToClaimTokenEx...
# 21  [AbstractChildEntityDefinition->ForwardingMode, AbstractChildEntityDefinition->AggregateMember, AggregateMemberAnnotatedChildEntityDefinition->ForwardingMode, MethodCreationPolicyDefinition->CreationPolicy, AnnotatedAggregate->ApplyMore, AnnotatedAggregate->Repository, AnnotatedAggregate->Aggreg...
# 22                      [DuplicateQueryHandlerSubscriptionException->QuerySubscription, FailingDuplicateQueryHandlerResolver->QuerySubscription, DuplicateQueryHandlerResolution->QuerySubscription, DuplicateQueryHandlerResolver->QuerySubscription, LoggingDuplicateQueryHandlerResolver->QuerySubscription]
# 23                            [MessageDecorator->Serializer, MessageDecorator->SerializedObject, GenericResultMessage->SerializedObject, GenericResultMessage->Serializer, Message->Serializer, Message->SerializedObject, Headers->SerializedObject, Headers->SerializedType, ResultMessage->SerializedObject]
# 24  [CommandSerializer->ErrorCode, CommandSerializer->AxonServerConfiguration, AxonServerCommandBus->TargetContextResolver, AxonServerCommandBus->DispatchInterceptors, AxonServerCommandBus->AxonServerConnectionManager, AxonServerCommandBus->AxonServerConfiguration, AxonServerCommandBus->PriorityRunn...
# 25                                                                                                                                          [ResultParameterResolverFactory->ResultHandler, MessageHandlerInterceptorDefinition->ResultHandler, MessageHandlerInterceptorDefinition->MessageHandlerInterceptor]
# 26                                                                                                                                           [AnnotatedSagaManager->SagaModel, AnnotatedSagaManager$Builder->AnnotationSagaMetaModelFactory, AnnotatedSagaManager$Builder->SagaModel, AnnotatedSaga->SagaModel]
# 27        [AndCommandMessageFilter->CommandMessageFilter, DenyCommandNameFilter->CommandMessageFilter, NegateCommandMessageFilter->CommandMessageFilter, DenyAll->CommandMessageFilter, OrCommandMessageFilter->CommandMessageFilter, AcceptAll->CommandMessageFilter, CommandNameFilter->CommandMessageFilter]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                            [NestingSpanFactory->EventMessage]
# 1                                                                                                                                                                                                                                                             [ConvertingResponseMessage->QueryResponseMessage]
# 2                                                                                                                                                                                                                                                                                     [SpanUtils->QueryMessage]
# 3                                                                                                                                                                                                                  [Headers->DomainEventMessage, StreamableMessageSource->TrackingToken, Headers->EventMessage]
# 4                                                                                                                                    [SourceIdParameterResolverFactory$SourceIdParameterResolver->DomainEventMessage, AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->DomainEventMessage]
# 5                                                                                                                                                                                                                                                                                  [SpanUtils->DeadlineMessage]
# 6                                                                                                                                                                                                                                                                                   [SpanUtils->CommandMessage]
# 7                                                                                                                                                                                                                           [AbstractEventStorageEngine->EventStreamUtils, DomainEventStream->EventStreamUtils]
# 8                                                                                                                                                                                                                           [SimpleCommandBus$Builder->LoggingCallback, SimpleCommandBus$Builder->NoOpCallback]
# 9                                                                                                                                                 [AbstractXStreamSerializer->GenericDomainEventMessage, AbstractXStreamSerializer->GenericEventMessage, GapAwareTrackingTokenConverter->GapAwareTrackingToken]
# 10                                                                                                                                                                                              [MessageHandlerInterceptor->UnitOfWork, DefaultInterceptorChain->UnitOfWork, GenericMessage->CurrentUnitOfWork]
# 11  [ServerConnectorConfigurerModule->AxonServerEventStoreFactory, ServerConnectorConfigurerModule->AxonServerEventStore$Builder, ServerConnectorConfigurerModule->EventProcessorInfoConfiguration, ServerConnectorConfigurerModule->AxonServerEventStore, ServerConnectorConfigurerModule->AxonServerEventS...
# 12  [ServerConnectorConfigurerModule->QueryPriorityCalculator, ServerConnectorConfigurerModule->AxonServerQueryBus$Builder, ServerConnectorConfigurerModule->AxonServerQueryBus, ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerRemoteQueryHandlingException, ErrorCode->AxonServerNonTra...
# 13                                                                                                                                          [SimpleEventHandlerInvoker$Builder->SequencingPolicy, SimpleEventHandlerInvoker->SequencingPolicy, SimpleEventHandlerInvoker$Builder->SequentialPerAggregatePolicy]
# 14                                                                                                                                                                                [AnnotationEventHandlerAdapter->GenericResetContext, ResetHandler->ResetContext, AnnotationEventHandlerAdapter->ResetContext]
# 15                                                                                                                                                                                                            [ErrorCode->ExceptionSerializer, AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor]
# 16                                                                                                                                                                                                                                                                             [GrpcExceptionParser->ErrorCode]
# 17                                                                                                                                                                                       [GrpcBackedSubscriptionQueryMessage->GrpcBackedQueryMessage, SubscriptionMessageSerializer->GrpcBackedResponseMessage]
# 18                                                                                                                                                                                             [EventUtils->EventUpcaster, EventUtils->InitialEventRepresentation, EventUtils->IntermediateEventRepresentation]
# 19  [AppendEventsStatementBuilder->EventSchema, FetchTrackedEventsStatementBuilder->EventSchema, JdbcEventStorageEngineStatements->EventSchema, DeleteSnapshotsStatementBuilder->EventSchema, ReadEventDataWithoutGapsStatementBuilder->EventSchema, CreateTokenAtStatementBuilder->EventSchema, AppendSnaps...
# 20                                                                                                                                                            [ConfigToken->TrackingToken, AbstractTokenEntry->TrackingToken, GenericTokenEntry->TrackingToken, TokenStore->TrackingToken, TokenStore->Segment]
# 21  [GenericJpaRepository->AnnotatedAggregate, ForwardMatchingInstances->EntityModel, ForwardingMode->EntityModel, GenericJpaRepository$Builder->AggregateModel, LockingRepository$Builder->AggregateModel, AbstractRepository->AggregateModel, AbstractRepository$Builder->AggregateModel, AggregateAnnotat...
# 22                                                                                                                                              [SimpleQueryBus$Builder->DuplicateQueryHandlerResolution, SimpleQueryBus$Builder->DuplicateQueryHandlerResolver, SimpleQueryBus->DuplicateQueryHandlerResolver]
# 23                  [SerializedMessage->AbstractMessage, SerializedObjectHolder->Message, SerializedMessage->Message, SerializedMetaData->MetaData, SerializedMessage->MetaData, AbstractXStreamSerializer->MetaData, AbstractXStreamSerializer$MetaDataConverter->MetaData, SerializedMessage->GenericMessage]
# 24  [ServerConnectorConfigurerModule->CommandPriorityCalculator, ErrorCode->AxonServerCommandDispatchException, ServerConnectorConfigurerModule->AxonServerCommandBus, ErrorCode->AxonServerRemoteCommandHandlingException, ServerConnectorConfigurerModule->CommandLoadFactorProvider, ServerConnectorConfi...
# 25                                                                                                                                                                                                                             [ResultHandler->HasHandlerAttributes, MessageHandlerInterceptor->MessageHandler]
# 26                                                                                                                       [AnnotationSagaMetaModelFactory$InspectedSagaModel->SagaMethodMessageHandlingMember, SagaModel->AssociationValue, AnnotationSagaMetaModelFactory$InspectedSagaModel->AssociationValue]
# 27                                      [CommandMessageFilter->AndCommandMessageFilter, DistributedCommandBus->DenyCommandNameFilter, CommandMessageFilter->NegateCommandMessageFilter, DistributedCommandBus->DenyAll, CommandMessageFilter->OrCommandMessageFilter, DistributedCommandBus->CommandNameFilter]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#              artifactName                      packageName  \
# 0   axon-messaging-4.11.1  org.axonframework.eventhandling
# 1   axon-messaging-4.11.1  org.axonframework.eventhandling
# 2   axon-messaging-4.11.1  org.axonframework.eventhandling
# 3   axon-messaging-4.11.1  org.axonframework.eventhandling
# 4   axon-messaging-4.11.1  org.axonframework.eventhandling
# 5   axon-messaging-4.11.1  org.axonframework.eventhandling
# 6   axon-messaging-4.11.1  org.axonframework.eventhandling
# 7   axon-messaging-4.11.1  org.axonframework.eventhandling
# 8   axon-messaging-4.11.1  org.axonframework.eventhandling
# 9   axon-messaging-4.11.1  org.axonframework.eventhandling
# 10  axon-messaging-4.11.1  org.axonframework.eventhandling
# 11  axon-messaging-4.11.1  org.axonframework.eventhandling
# 12  axon-messaging-4.11.1  org.axonframework.eventhandling
# 13  axon-messaging-4.11.1  org.axonframework.eventhandling
# 14  axon-messaging-4.11.1  org.axonframework.eventhandling
# 15  axon-messaging-4.11.1  org.axonframework.eventhandling
# 16  axon-messaging-4.11.1  org.axonframework.eventhandling
# 17  axon-messaging-4.11.1  org.axonframework.eventhandling
# 18  axon-messaging-4.11.1  org.axonframework.eventhandling
# 19  axon-messaging-4.11.1  org.axonframework.eventhandling
# 20  axon-messaging-4.11.1  org.axonframework.queryhandling
# 21  axon-messaging-4.11.1  org.axonframework.queryhandling
# 22  axon-messaging-4.11.1  org.axonframework.queryhandling
# 23  axon-messaging-4.11.1  org.axonframework.queryhandling
# 24  axon-messaging-4.11.1  org.axonframework.queryhandling
# 25  axon-messaging-4.11.1  org.axonframework.queryhandling
# 26  axon-messaging-4.11.1  org.axonframework.queryhandling
# 27  axon-messaging-4.11.1  org.axonframework.queryhandling
# 28  axon-messaging-4.11.1  org.axonframework.queryhandling
# 29  axon-messaging-4.11.1  org.axonframework.queryhandling
# 30  axon-messaging-4.11.1  org.axonframework.queryhandling
# 31  axon-messaging-4.11.1  org.axonframework.queryhandling
# 32  axon-messaging-4.11.1  org.axonframework.queryhandling
# 33  axon-messaging-4.11.1  org.axonframework.queryhandling
# 34  axon-messaging-4.11.1  org.axonframework.queryhandling
# 35  axon-messaging-4.11.1  org.axonframework.queryhandling
# 36  axon-messaging-4.11.1  org.axonframework.queryhandling
# 37  axon-messaging-4.11.1  org.axonframework.queryhandling
# 38  axon-messaging-4.11.1  org.axonframework.queryhandling
# 39  axon-messaging-4.11.1  org.axonframework.queryhandling
#
#     dependentArtifactName                       dependentPackageName  \
# 0   axon-messaging-4.11.1                  org.axonframework.tracing
# 1   axon-messaging-4.11.1                  org.axonframework.tracing
# 2   axon-messaging-4.11.1                  org.axonframework.tracing
# 3   axon-messaging-4.11.1                  org.axonframework.tracing
# 4   axon-messaging-4.11.1                  org.axonframework.tracing
# 5   axon-messaging-4.11.1                  org.axonframework.tracing
# 6   axon-messaging-4.11.1                  org.axonframework.tracing
# 7   axon-messaging-4.11.1                  org.axonframework.tracing
# 8   axon-messaging-4.11.1                  org.axonframework.tracing
# 9   axon-messaging-4.11.1                  org.axonframework.tracing
# 10  axon-messaging-4.11.1                  org.axonframework.tracing
# 11  axon-messaging-4.11.1                  org.axonframework.tracing
# 12  axon-messaging-4.11.1                  org.axonframework.tracing
# 13  axon-messaging-4.11.1                  org.axonframework.tracing
# 14  axon-messaging-4.11.1                  org.axonframework.tracing
# 15  axon-messaging-4.11.1                  org.axonframework.tracing
# 16  axon-messaging-4.11.1                  org.axonframework.tracing
# 17  axon-messaging-4.11.1                  org.axonframework.tracing
# 18  axon-messaging-4.11.1                  org.axonframework.tracing
# 19  axon-messaging-4.11.1                  org.axonframework.tracing
# 20  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 21  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 22  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 23  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 24  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 25  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 26  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 27  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 28  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 29  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 30  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 31  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 32  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 33  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 34  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 35  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 36  axon-messaging-4.11.1  org.axonframework.messaging.responsetypes
# 37  axon-messaging-4.11.1                  org.axonframework.tracing
# 38  axon-messaging-4.11.1                  org.axonframework.tracing
# 39  axon-messaging-4.11.1                  org.axonframework.tracing
#
#                                                     dependency  \
# 0                             DefaultEventBusSpanFactory->Span
# 1               SubscribingEventProcessor$Builder->SpanFactory
# 2                                       AbstractEventBus->Span
# 3        DefaultEventProcessorSpanFactory$Builder->SpanFactory
# 4                             EventMessage<-NestingSpanFactory
# 5                DefaultEventProcessorSpanFactory->SpanFactory
# 6                    AbstractEventBus$Builder->NoOpSpanFactory
# 7                                  AbstractEventBus->SpanScope
# 8                                    EventBusSpanFactory->Span
# 9                              EventProcessorSpanFactory->Span
# 10             AbstractEventProcessor$Builder->NoOpSpanFactory
# 11                         SimpleEventBus$Builder->SpanFactory
# 12                     DefaultEventBusSpanFactory->SpanFactory
# 13                      DefaultEventProcessorSpanFactory->Span
# 14                 AbstractEventProcessor$Builder->SpanFactory
# 15                       AbstractEventBus$Builder->SpanFactory
# 16             DefaultEventBusSpanFactory$Builder->SpanFactory
# 17  DefaultEventProcessorSpanFactory->NoOpSpanFactory$NoOpSpan
# 18                 TrackingEventProcessor$Builder->SpanFactory
# 19                                AbstractEventProcessor->Span
# 20                      SubscriptionQueryMessage->ResponseType
# 21                           GenericQueryMessage->ResponseType
# 22     SimpleQueryUpdateEmitter->MultipleInstancesResponseType
# 23                                  QueryGateway->ResponseType
# 24                                SimpleQueryBus->ResponseType
# 25                                 QueryGateway->ResponseTypes
# 26                                  QueryMessage->ResponseType
# 27                      SimpleQueryUpdateEmitter->ResponseType
# 28             QueryResponseMessage<-ConvertingResponseMessage
# 29              SimpleQueryUpdateEmitter->OptionalResponseType
# 30                             QuerySubscription->ResponseType
# 31               GenericSubscriptionQueryMessage->ResponseType
# 32             SimpleQueryUpdateEmitter->PublisherResponseType
# 33                         StreamingQueryMessage->ResponseType
# 34         GenericStreamingQueryMessage->PublisherResponseType
# 35                  GenericStreamingQueryMessage->ResponseType
# 36                           DefaultQueryGateway->ResponseType
# 37                              SimpleQueryUpdateEmitter->Span
# 38                                   SimpleQueryBus->SpanScope
# 39                            DefaultQueryBusSpanFactory->Span
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.900000             19               1
# 2                   0.900000             19               1
# 3                   0.900000             19               1
# 4                   0.900000             19               1
# 5                   0.900000             19               1
# 6                   0.900000             19               1
# 7                   0.900000             19               1
# 8                   0.900000             19               1
# 9                   0.900000             19               1
# 10                  0.900000             19               1
# 11                  0.900000             19               1
# 12                  0.900000             19               1
# 13                  0.900000             19               1
# 14                  0.900000             19               1
# 15                  0.900000             19               1
# 16                  0.900000             19               1
# 17                  0.900000             19               1
# 18                  0.900000             19               1
# 19                  0.900000             19               1
# 20                  0.882353             16               1
# 21                  0.882353             16               1
# 22                  0.882353             16               1
# 23                  0.882353             16               1
# 24                  0.882353             16               1
# 25                  0.882353             16               1
# 26                  0.882353             16               1
# 27                  0.882353             16               1
# 28                  0.882353             16               1
# 29                  0.882353             16               1
# 30                  0.882353             16               1
# 31                  0.882353             16               1
# 32                  0.882353             16               1
# 33                  0.882353             16               1
# 34                  0.882353             16               1
# 35                  0.882353             16               1
# 36                  0.882353             16               1
# 37                  0.875000             15               1
# 38                  0.875000             15               1
# 39                  0.875000             15               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                     artifactName  \
# 0          axon-messaging-4.11.1
# 1          axon-messaging-4.11.1
# 2          axon-messaging-4.11.1
# 3          axon-messaging-4.11.1
# 4          axon-messaging-4.11.1
# 5          axon-messaging-4.11.1
# 6          axon-messaging-4.11.1
# 7          axon-messaging-4.11.1
# 8          axon-messaging-4.11.1
# 9          axon-messaging-4.11.1
# 10     axon-eventsourcing-4.11.1
# 11     axon-eventsourcing-4.11.1
# 12         axon-messaging-4.11.1
# 13         axon-messaging-4.11.1
# 14         axon-messaging-4.11.1
# 15         axon-messaging-4.11.1
# 16         axon-messaging-4.11.1
# 17         axon-messaging-4.11.1
# 18         axon-messaging-4.11.1
# 19         axon-messaging-4.11.1
# 20  axon-server-connector-4.11.1
# 21  axon-server-connector-4.11.1
# 22  axon-server-connector-4.11.1
# 23  axon-server-connector-4.11.1
# 24  axon-server-connector-4.11.1
# 25  axon-server-connector-4.11.1
# 26  axon-server-connector-4.11.1
# 27  axon-server-connector-4.11.1
# 28  axon-server-connector-4.11.1
# 29  axon-server-connector-4.11.1
# 30  axon-server-connector-4.11.1
# 31         axon-messaging-4.11.1
# 32         axon-messaging-4.11.1
# 33         axon-messaging-4.11.1
# 34         axon-messaging-4.11.1
# 35         axon-messaging-4.11.1
# 36         axon-messaging-4.11.1
# 37  axon-server-connector-4.11.1
# 38  axon-server-connector-4.11.1
# 39  axon-server-connector-4.11.1
#
#                                           packageName  \
# 0                     org.axonframework.eventhandling
# 1                     org.axonframework.queryhandling
# 2                     org.axonframework.queryhandling
# 3                     org.axonframework.eventhandling
# 4                     org.axonframework.eventhandling
# 5                     org.axonframework.eventhandling
# 6                     org.axonframework.eventhandling
# 7                     org.axonframework.eventhandling
# 8                          org.axonframework.deadline
# 9                   org.axonframework.commandhandling
# 10                    org.axonframework.eventsourcing
# 11                    org.axonframework.eventsourcing
# 12        org.axonframework.commandhandling.callbacks
# 13        org.axonframework.commandhandling.callbacks
# 14                    org.axonframework.eventhandling
# 15                    org.axonframework.eventhandling
# 16                    org.axonframework.eventhandling
# 17             org.axonframework.messaging.unitofwork
# 18             org.axonframework.messaging.unitofwork
# 19             org.axonframework.messaging.unitofwork
# 20  org.axonframework.axonserver.connector.event.axon
# 21  org.axonframework.axonserver.connector.event.axon
# 22  org.axonframework.axonserver.connector.event.axon
# 23  org.axonframework.axonserver.connector.event.axon
# 24  org.axonframework.axonserver.connector.event.axon
# 25       org.axonframework.axonserver.connector.query
# 26       org.axonframework.axonserver.connector.query
# 27       org.axonframework.axonserver.connector.query
# 28       org.axonframework.axonserver.connector.query
# 29       org.axonframework.axonserver.connector.query
# 30       org.axonframework.axonserver.connector.query
# 31              org.axonframework.eventhandling.async
# 32              org.axonframework.eventhandling.async
# 33              org.axonframework.eventhandling.async
# 34             org.axonframework.eventhandling.replay
# 35             org.axonframework.eventhandling.replay
# 36             org.axonframework.eventhandling.replay
# 37        org.axonframework.axonserver.connector.util
# 38        org.axonframework.axonserver.connector.util
# 39             org.axonframework.axonserver.connector
#
#            dependentArtifactName  \
# 0          axon-messaging-4.11.1
# 1          axon-messaging-4.11.1
# 2          axon-messaging-4.11.1
# 3          axon-messaging-4.11.1
# 4          axon-messaging-4.11.1
# 5          axon-messaging-4.11.1
# 6          axon-messaging-4.11.1
# 7          axon-messaging-4.11.1
# 8          axon-messaging-4.11.1
# 9          axon-messaging-4.11.1
# 10     axon-eventsourcing-4.11.1
# 11     axon-eventsourcing-4.11.1
# 12         axon-messaging-4.11.1
# 13         axon-messaging-4.11.1
# 14         axon-messaging-4.11.1
# 15         axon-messaging-4.11.1
# 16         axon-messaging-4.11.1
# 17         axon-messaging-4.11.1
# 18         axon-messaging-4.11.1
# 19         axon-messaging-4.11.1
# 20  axon-server-connector-4.11.1
# 21  axon-server-connector-4.11.1
# 22  axon-server-connector-4.11.1
# 23  axon-server-connector-4.11.1
# 24  axon-server-connector-4.11.1
# 25  axon-server-connector-4.11.1
# 26  axon-server-connector-4.11.1
# 27  axon-server-connector-4.11.1
# 28  axon-server-connector-4.11.1
# 29  axon-server-connector-4.11.1
# 30  axon-server-connector-4.11.1
# 31         axon-messaging-4.11.1
# 32         axon-messaging-4.11.1
# 33         axon-messaging-4.11.1
# 34         axon-messaging-4.11.1
# 35         axon-messaging-4.11.1
# 36         axon-messaging-4.11.1
# 37  axon-server-connector-4.11.1
# 38  axon-server-connector-4.11.1
# 39  axon-server-connector-4.11.1
#
#                                  dependentPackageName  \
# 0                           org.axonframework.tracing
# 1           org.axonframework.messaging.responsetypes
# 2                           org.axonframework.tracing
# 3                         org.axonframework.messaging
# 4                         org.axonframework.messaging
# 5                         org.axonframework.messaging
# 6              org.axonframework.messaging.annotation
# 7              org.axonframework.messaging.annotation
# 8                           org.axonframework.tracing
# 9                           org.axonframework.tracing
# 10         org.axonframework.eventsourcing.eventstore
# 11         org.axonframework.eventsourcing.eventstore
# 12                  org.axonframework.commandhandling
# 13                  org.axonframework.commandhandling
# 14                    org.axonframework.serialization
# 15                    org.axonframework.serialization
# 16                    org.axonframework.serialization
# 17                        org.axonframework.messaging
# 18                        org.axonframework.messaging
# 19                        org.axonframework.messaging
# 20             org.axonframework.axonserver.connector
# 21             org.axonframework.axonserver.connector
# 22             org.axonframework.axonserver.connector
# 23             org.axonframework.axonserver.connector
# 24             org.axonframework.axonserver.connector
# 25             org.axonframework.axonserver.connector
# 26             org.axonframework.axonserver.connector
# 27             org.axonframework.axonserver.connector
# 28             org.axonframework.axonserver.connector
# 29             org.axonframework.axonserver.connector
# 30             org.axonframework.axonserver.connector
# 31                    org.axonframework.eventhandling
# 32                    org.axonframework.eventhandling
# 33                    org.axonframework.eventhandling
# 34                    org.axonframework.eventhandling
# 35                    org.axonframework.eventhandling
# 36                    org.axonframework.eventhandling
# 37             org.axonframework.axonserver.connector
# 38             org.axonframework.axonserver.connector
# 39  org.axonframework.axonserver.connector.event.util
#
#                                                                                   dependency  \
# 0                                                           EventMessage<-NestingSpanFactory
# 1                                            QueryResponseMessage<-ConvertingResponseMessage
# 2                                                                    QueryMessage<-SpanUtils
# 3                                                                      EventMessage<-Headers
# 4                                                     TrackingToken<-StreamableMessageSource
# 5                                                                DomainEventMessage<-Headers
# 6             DomainEventMessage<-SourceIdParameterResolverFactory$SourceIdParameterResolver
# 7   DomainEventMessage<-AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver
# 8                                                                 DeadlineMessage<-SpanUtils
# 9                                                                  CommandMessage<-SpanUtils
# 10                                                       EventStreamUtils<-DomainEventStream
# 11                                              EventStreamUtils<-AbstractEventStorageEngine
# 12                                                 LoggingCallback<-SimpleCommandBus$Builder
# 13                                                    NoOpCallback<-SimpleCommandBus$Builder
# 14                                     GapAwareTrackingToken<-GapAwareTrackingTokenConverter
# 15                                      GenericDomainEventMessage<-AbstractXStreamSerializer
# 16                                            GenericEventMessage<-AbstractXStreamSerializer
# 17                                                     UnitOfWork<-MessageHandlerInterceptor
# 18                                                       UnitOfWork<-DefaultInterceptorChain
# 19                                                         CurrentUnitOfWork<-GenericMessage
# 20                      AxonServerEventStoreFactory$Builder<-ServerConnectorConfigurerModule
# 21                                     AxonServerEventStore<-ServerConnectorConfigurerModule
# 22                          EventProcessorInfoConfiguration<-ServerConnectorConfigurerModule
# 23                             AxonServerEventStore$Builder<-ServerConnectorConfigurerModule
# 24                              AxonServerEventStoreFactory<-ServerConnectorConfigurerModule
# 25                               AxonServerQueryBus$Builder<-ServerConnectorConfigurerModule
# 26                                  QueryPriorityCalculator<-ServerConnectorConfigurerModule
# 27                             AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 28                                         AxonServerRemoteQueryHandlingException<-ErrorCode
# 29                                               AxonServerQueryDispatchException<-ErrorCode
# 30                                       AxonServerQueryBus<-ServerConnectorConfigurerModule
# 31                           SequentialPerAggregatePolicy<-SimpleEventHandlerInvoker$Builder
# 32                                       SequencingPolicy<-SimpleEventHandlerInvoker$Builder
# 33                                               SequencingPolicy<-SimpleEventHandlerInvoker
# 34                                        GenericResetContext<-AnnotationEventHandlerAdapter
# 35                                                                ResetContext<-ResetHandler
# 36                                               ResetContext<-AnnotationEventHandlerAdapter
# 37                           GrpcMessageSizeInterceptor<-AxonServerConnectionManager$Builder
# 38                                                            ExceptionSerializer<-ErrorCode
# 39                                                            ErrorCode<-GrpcExceptionParser
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.900000             19               1
# 1                   0.882353             16               1
# 2                   0.875000             15               1
# 3                   0.857143             39               3
# 4                   0.857143             39               3
# 5                   0.857143             39               3
# 6                   0.840000             23               2
# 7                   0.840000             23               2
# 8                   0.800000              9               1
# 9                   0.777778              8               1
# 10                  0.777778             16               2
# 11                  0.777778             16               2
# 12                  0.733333             13               2
# 13                  0.733333             13               2
# 14                  0.647059             14               3
# 15                  0.647059             14               3
# 16                  0.647059             14               3
# 17                  0.647059             14               3
# 18                  0.647059             14               3
# 19                  0.647059             14               3
# 20                  0.615385             21               5
# 21                  0.615385             21               5
# 22                  0.615385             21               5
# 23                  0.615385             21               5
# 24                  0.615385             21               5
# 25                  0.571429             22               6
# 26                  0.571429             22               6
# 27                  0.571429             22               6
# 28                  0.571429             22               6
# 29                  0.571429             22               6
# 30                  0.571429             22               6
# 31                  0.571429             11               3
# 32                  0.571429             11               3
# 33                  0.571429             11               3
# 34                  0.454545              8               3
# 35                  0.454545              8               3
# 36                  0.454545              8               3
# 37                  0.428571              5               2
# 38                  0.428571              5               2
# 39                  0.333333              2               1

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                    fullDependentTypeName  \
# 0                       org.axonframework.commandhandling.CommandMessage
# 1                           org.axonframework.eventhandling.EventMessage
# 2                           org.axonframework.eventhandling.EventMessage
# 3                     org.axonframework.eventhandling.DomainEventMessage
# 4                    org.axonframework.eventhandling.TrackedEventMessage
# 5          org.axonframework.commandhandling.GenericCommandResultMessage
# 6                     org.axonframework.eventhandling.DomainEventMessage
# 7                              org.axonframework.messaging.ResultMessage
# 8                            org.axonframework.eventhandling.ReplayToken
# 9                      org.axonframework.deadline.GenericDeadlineMessage
# 10                    org.axonframework.eventhandling.DomainEventMessage
# 11                   org.axonframework.eventhandling.TrackedEventMessage
# 12                   org.axonframework.eventhandling.GenericEventMessage
# 13                            org.axonframework.deadline.DeadlineMessage
# 14                    org.axonframework.eventhandling.DomainEventMessage
# 15          org.axonframework.deadline.DefaultDeadlineManagerSpanFactory
# 16             org.axonframework.common.transaction.NoTransactionManager
# 17              org.axonframework.queryhandling.SimpleQueryUpdateEmitter
# 18         org.axonframework.commandhandling.GenericCommandResultMessage
# 19   org.axonframework.messaging.annotation.WrappedMessageHandlingMember
# 20                           org.axonframework.eventhandling.ReplayToken
# 21         org.axonframework.modelling.command.inspection.AggregateModel
# 22              org.axonframework.queryhandling.SubscriptionQueryMessage
# 23                    org.axonframework.eventhandling.DomainEventMessage
# 24                        org.axonframework.queryhandling.SimpleQueryBus
# 25                    org.axonframework.eventhandling.DomainEventMessage
# 26                 org.axonframework.eventhandling.GapAwareTrackingToken
# 27                   org.axonframework.eventhandling.GenericEventMessage
# 28            org.axonframework.queryhandling.DefaultQueryBusSpanFactory
# 29       org.axonframework.commandhandling.gateway.DefaultCommandGateway
# 30                                org.axonframework.config.Configuration
# 31                                org.axonframework.config.Configuration
# 32                          org.axonframework.eventhandling.EventMessage
# 33                          org.axonframework.messaging.MessageDecorator
# 34                          org.axonframework.queryhandling.QueryMessage
# 35        org.axonframework.commandhandling.DefaultCommandBusSpanFactory
# 36                      org.axonframework.eventhandling.TrackedEventData
# 37                org.axonframework.eventhandling.tokenstore.ConfigToken
# 38            org.axonframework.eventhandling.DefaultEventBusSpanFactory
# 39  org.axonframework.queryhandling.DefaultQueryUpdateEmitterSpanFactory
#
#     declaredMethods  \
# 0                 9
# 1                 9
# 2                 9
# 3                10
# 4                10
# 5                14
# 6                10
# 7                 9
# 8                13
# 9                11
# 10               10
# 11               12
# 12               11
# 13               10
# 14               10
# 15                8
# 16                4
# 17               17
# 18               15
# 19               14
# 20               13
# 21               13
# 22               12
# 23               11
# 24               11
# 25               10
# 26               10
# 27               10
# 28               10
# 29                9
# 30                9
# 31                9
# 32                9
# 33                9
# 34                9
# 35                5
# 36                5
# 37                5
# 38                4
# 39                4
#
#                                                    calledMethodNames  \
# 0                                                   [getCommandName]
# 1                                                    [getIdentifier]
# 2                                      [getIdentifier, getTimestamp]
# 3                                                [getSequenceNumber]
# 4                                                    [trackingToken]
# 5                                           [asCommandResultMessage]
# 6               [getType, getAggregateIdentifier, getSequenceNumber]
# 7                                   [exceptionResult, isExceptional]
# 8                                                [createReplayToken]
# 9                                                [asDeadlineMessage]
# 10                                          [getAggregateIdentifier]
# 11                                                   [trackingToken]
# 12                                                  [asEventMessage]
# 13                                                 [getDeadlineName]
# 14                                                         [getType]
# 15                                                         [builder]
# 16                                                        [instance]
# 17                                                         [builder]
# 18                                          [asCommandResultMessage]
# 19                                                          [handle]
# 20                                                        [isReplay]
# 21                                                            [type]
# 22                                           [getUpdateResponseType]
# 23              [getType, getAggregateIdentifier, getSequenceNumber]
# 24                                                         [builder]
# 25                       [getAggregateIdentifier, getSequenceNumber]
# 26  [getGaps, newInstance, advanceTo, withGapsTruncatedAt, getIndex]
# 27                                                  [asEventMessage]
# 28                                                         [builder]
# 29                                                         [builder]
# 30                                                    [getComponent]
# 31                                   [snapshotFilter, upcasterChain]
# 32                                                    [getTimestamp]
# 33                                                      [describeTo]
# 34                                   [getResponseType, getQueryName]
# 35                                                         [builder]
# 36                                                   [trackingToken]
# 37                                                             [get]
# 38                                                         [builder]
# 39                                                         [builder]
#
#     calledMethods  callerTypes
# 0               1           20
# 1               1           10
# 2               2           10
# 3               1            9
# 4               1            8
# 5               1            6
# 6               3            6
# 7               2            6
# 8               1            5
# 9               1            5
# 10              1            5
# 11              1            4
# 12              1            4
# 13              1            4
# 14              1            4
# 15              1            4
# 16              1            4
# 17              1            3
# 18              1            3
# 19              1            3
# 20              1            3
# 21              1            3
# 22              1            3
# 23              3            3
# 24              1            3
# 25              2            3
# 26              5            3
# 27              1            3
# 28              1            3
# 29              1            3
# 30              1            3
# 31              2            3
# 32              1            3
# 33              1            3
# 34              2            3
# 35              1            3
# 36              1            3
# 37              1            3
# 38              1            3
# 39              1            3

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                      fullQualifiedDependentTypeName  \
# 0                             org.axonframework.common.BuilderUtils
# 1               org.axonframework.common.AxonConfigurationException
# 2                               org.axonframework.messaging.Message
# 3                              org.axonframework.messaging.MetaData
# 4                        org.axonframework.serialization.Serializer
# 5                      org.axonframework.eventhandling.EventMessage
# 6                 org.axonframework.messaging.unitofwork.UnitOfWork
# 7           org.axonframework.common.transaction.TransactionManager
# 8                                   org.axonframework.common.Assert
# 9                  org.axonframework.serialization.SerializedObject
# 10                   org.axonframework.serialization.SerializedType
# 11         org.axonframework.messaging.unitofwork.CurrentUnitOfWork
# 12                            org.axonframework.common.Registration
# 13                            org.axonframework.tracing.SpanFactory
# 14                            org.axonframework.lifecycle.Lifecycle
# 15          org.axonframework.lifecycle.Lifecycle$LifecycleRegistry
# 16            org.axonframework.messaging.MessageHandlerInterceptor
# 17                             org.axonframework.common.ObjectUtils
# 18                    org.axonframework.eventhandling.TrackingToken
# 19               org.axonframework.eventhandling.DomainEventMessage
# 20           org.axonframework.messaging.MessageDispatchInterceptor
# 21  org.axonframework.messaging.annotation.ParameterResolverFactory
# 22           org.axonframework.serialization.SimpleSerializedObject
# 23               org.axonframework.common.AxonNonTransientException
# 24              org.axonframework.eventhandling.GenericEventMessage
# 25                 org.axonframework.commandhandling.CommandMessage
# 26                        org.axonframework.tracing.NoOpSpanFactory
# 27                         org.axonframework.eventhandling.EventBus
# 28         org.axonframework.messaging.annotation.HandlerDefinition
# 29        org.axonframework.common.transaction.NoTransactionManager
# 30                        org.axonframework.messaging.ResultMessage
# 31                                   org.axonframework.tracing.Span
# 32         org.axonframework.messaging.unitofwork.DefaultUnitOfWork
# 33                         org.axonframework.common.ReflectionUtils
# 34                     org.axonframework.messaging.InterceptorChain
# 35              org.axonframework.eventhandling.TrackedEventMessage
# 36                           org.axonframework.common.AxonException
# 37                           org.axonframework.common.DateTimeUtils
# 38              org.axonframework.messaging.DefaultInterceptorChain
# 39        org.axonframework.eventhandling.GenericDomainEventMessage
#
#               dependentTypeName  \
# 0                  BuilderUtils
# 1    AxonConfigurationException
# 2                       Message
# 3                      MetaData
# 4                    Serializer
# 5                  EventMessage
# 6                    UnitOfWork
# 7            TransactionManager
# 8                        Assert
# 9              SerializedObject
# 10               SerializedType
# 11            CurrentUnitOfWork
# 12                 Registration
# 13                  SpanFactory
# 14                    Lifecycle
# 15  Lifecycle$LifecycleRegistry
# 16    MessageHandlerInterceptor
# 17                  ObjectUtils
# 18                TrackingToken
# 19           DomainEventMessage
# 20   MessageDispatchInterceptor
# 21     ParameterResolverFactory
# 22       SimpleSerializedObject
# 23    AxonNonTransientException
# 24          GenericEventMessage
# 25               CommandMessage
# 26              NoOpSpanFactory
# 27                     EventBus
# 28            HandlerDefinition
# 29         NoTransactionManager
# 30                ResultMessage
# 31                         Span
# 32            DefaultUnitOfWork
# 33              ReflectionUtils
# 34             InterceptorChain
# 35          TrackedEventMessage
# 36                AxonException
# 37                DateTimeUtils
# 38      DefaultInterceptorChain
# 39    GenericDomainEventMessage
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 1   [Type, File, Java, Class, ByteCode, Throwable, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedCom...
# 2   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 3   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4Ty...
# 4   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 5   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 6   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWe...
# 7   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1...
# 8   [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Ma...
# 9   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInduce...
# 10  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 11                          [Type, File, Java, Class, ByteCode, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation32, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity14, Mark4TypeKCoreDecomposition10]
# 12  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity11,...
# 13  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2,...
# 14                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10]
# 15                                                                                                                [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10]
# 16  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation26, Mark4TypeLouvainCommunity5, Mark4T...
# 17                                                                                                                   [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10]
# 18  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 19  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation56, Mark4T...
# 20  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation26, Mark4TypeLouvainCommunity14, Mark4TypeLeidenCommunity13, Mark4Typ...
# 21   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation40, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposition10]
# 22            [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation8, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.125]
# 23  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation64, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposi...
# 24  [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation26, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCore...
# 25  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeakl...
# 26                                                                                                                   [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10]
# 27    [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation14, Mark4TypeLouvainCommunity10, Mark4TypeLeidenCommunity9, Mark4TypeKCoreDecomposition10]
# 28   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation36, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposition10]
# 29                                                                            [Type, File, Java, ByteCode, Enum, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.14285714285714285]
# 30  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation93, Mark4TypeLouvainCommunit...
# 31  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity2...
# 32                                                                                              [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation94, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity14, Mark4TypeKCoreDecomposition10]
# 33                                                                                                                  [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation75, Mark4TypeLouvainCommunity12, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposition7]
# 34                                                                      [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation92, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity14, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.1038961038961039]
# 35  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation41, Mark4TypeLouvainCommunity9, Mark4T...
# 36  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation70, Mark4TypeLouvainCommunity18, Mark4TypeLeidenCommunity16, Mark4TypeKCoreDecompos...
# 37                                                                                                                    [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation35, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition8]
# 38                                                                                               [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation26, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition10]
# 39                                                       [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation56, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut0.2727272727272727]
#
#     numberOfUsingPackages
# 0                      50
# 1                      43
# 2                      42
# 3                      40
# 4                      37
# 5                      36
# 6                      33
# 7                      31
# 8                      29
# 9                      28
# 10                     28
# 11                     22
# 12                     22
# 13                     22
# 14                     20
# 15                     20
# 16                     20
# 17                     20
# 18                     20
# 19                     19
# 20                     19
# 21                     19
# 22                     19
# 23                     18
# 24                     18
# 25                     17
# 26                     17
# 27                     15
# 28                     15
# 29                     15
# 30                     15
# 31                     15
# 32                     14
# 33                     14
# 34                     13
# 35                     13
# 36                     12
# 37                     12
# 38                     12
# 39                     12

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                              artifactName  \
# 0       axon-tracing-opentelemetry-4.11.1
# 1            axon-server-connector-4.11.1
# 2   axon-spring-boot-autoconfigure-4.11.1
# 3                   axon-disruptor-4.11.1
# 4                        axon-test-4.11.1
# 5                   axon-disruptor-4.11.1
# 6               axon-eventsourcing-4.11.1
# 7                        axon-test-4.11.1
# 8                   axon-disruptor-4.11.1
# 9                   axon-modelling-4.11.1
# 10              axon-eventsourcing-4.11.1
# 11           axon-server-connector-4.11.1
# 12  axon-spring-boot-autoconfigure-4.11.1
# 13           axon-server-connector-4.11.1
# 14              axon-configuration-4.11.1
# 15                       axon-test-4.11.1
# 16              axon-configuration-4.11.1
# 17  axon-spring-boot-autoconfigure-4.11.1
# 18              axon-configuration-4.11.1
# 19  axon-spring-boot-autoconfigure-4.11.1
# 20                  axon-modelling-4.11.1
# 21  axon-spring-boot-autoconfigure-4.11.1
# 22                  axon-messaging-4.11.1
# 23                       axon-test-4.11.1
# 24              axon-eventsourcing-4.11.1
# 25           axon-server-connector-4.11.1
# 26  axon-spring-boot-autoconfigure-4.11.1
# 27  axon-spring-boot-autoconfigure-4.11.1
# 28              axon-configuration-4.11.1
# 29           axon-server-connector-4.11.1
#
#                     dependentArtifactName  dependentPackages  \
# 0                   axon-messaging-4.11.1                  3
# 1                   axon-modelling-4.11.1                  1
# 2                        axon-test-4.11.1                  1
# 3                   axon-messaging-4.11.1                  9
# 4                   axon-messaging-4.11.1                 10
# 5                   axon-modelling-4.11.1                  2
# 6                   axon-modelling-4.11.1                  2
# 7               axon-eventsourcing-4.11.1                  2
# 8               axon-eventsourcing-4.11.1                  2
# 9                   axon-messaging-4.11.1                 18
# 10                  axon-messaging-4.11.1                 20
# 11              axon-eventsourcing-4.11.1                  3
# 12           axon-server-connector-4.11.1                  4
# 13                  axon-messaging-4.11.1                 25
# 14              axon-eventsourcing-4.11.1                  4
# 15                  axon-modelling-4.11.1                  5
# 16                  axon-messaging-4.11.1                 34
# 17              axon-eventsourcing-4.11.1                  5
# 18                  axon-modelling-4.11.1                  6
# 19                  axon-modelling-4.11.1                  6
# 20                  axon-modelling-4.11.1                  6
# 21                  axon-messaging-4.11.1                 41
# 22                  axon-messaging-4.11.1                 41
# 23                       axon-test-4.11.1                  5
# 24              axon-eventsourcing-4.11.1                  7
# 25           axon-server-connector-4.11.1                  9
# 26  axon-spring-boot-autoconfigure-4.11.1                  8
# 27      axon-tracing-opentelemetry-4.11.1                  1
# 28                  axon-disruptor-4.11.1                  1
# 29              axon-configuration-4.11.1                  1
#
#     dependentArtifactPackages  packageUsagePercentage  \
# 0                          66                0.045455
# 1                          10                0.100000
# 2                           8                0.125000
# 3                          66                0.136364
# 4                          66                0.151515
# 5                          10                0.200000
# 6                          10                0.200000
# 7                           9                0.222222
# 8                           9                0.222222
# 9                          66                0.272727
# 10                         66                0.303030
# 11                          9                0.333333
# 12                         11                0.363636
# 13                         66                0.378788
# 14                          9                0.444444
# 15                         10                0.500000
# 16                         66                0.515152
# 17                          9                0.555556
# 18                         10                0.600000
# 19                         10                0.600000
# 20                         10                0.600000
# 21                         66                0.621212
# 22                         66                0.621212
# 23                          8                0.625000
# 24                          9                0.777778
# 25                         11                0.818182
# 26                          9                0.888889
# 27                          1                1.000000
# 28                          1                1.000000
# 29                          1                1.000000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                            [org.axonframework.common, org.axonframework.messaging, org.axonframework.tracing]
# 1                                                                                                                                                                                                                                                                         [org.axonframework.modelling.command]
# 2                                                                                                                                                                                                                                                                               [org.axonframework.test.server]
# 3   [org.axonframework.common.transaction, org.axonframework.messaging, org.axonframework.monitoring, org.axonframework.commandhandling, org.axonframework.common, org.axonframework.messaging.annotation, org.axonframework.commandhandling.callbacks, org.axonframework.messaging.unitofwork, org.axonfram...
# 4   [org.axonframework.common, org.axonframework.deadline, org.axonframework.messaging.unitofwork, org.axonframework.messaging, org.axonframework.eventhandling, org.axonframework.messaging.annotation, org.axonframework.commandhandling, org.axonframework.commandhandling.gateway, org.axonframework.eve...
# 5                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 6                                                                                                                                                                                                                         [org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 7                                                                                                                                                                                                                                 [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore]
# 8                                                                                                                                                                                                                                 [org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore]
# 9   [org.axonframework.common, org.axonframework.messaging.unitofwork, org.axonframework.messaging.annotation, org.axonframework.messaging, org.axonframework.eventhandling, org.axonframework.common.annotation, org.axonframework.common.property, org.axonframework.commandhandling, org.axonframework.se...
# 10  [org.axonframework.messaging.annotation, org.axonframework.messaging, org.axonframework.common, org.axonframework.commandhandling, org.axonframework.messaging.unitofwork, org.axonframework.eventhandling, org.axonframework.lifecycle, org.axonframework.tracing, org.axonframework.serialization, org...
# 11                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing]
# 12                                                                                                                    [org.axonframework.axonserver.connector, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.event.axon]
# 13  [org.axonframework.common.transaction, org.axonframework.commandhandling, org.axonframework.eventhandling.tokenstore.inmemory, org.axonframework.commandhandling.distributed, org.axonframework.lifecycle, org.axonframework.common, org.axonframework.messaging, org.axonframework.queryhandling, org.a...
# 14                                                                                                                                  [org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting]
# 15                                                                                   [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga, org.axonframework.modelling.command, org.axonframework.modelling.command.inspection]
# 16  [org.axonframework.common.transaction, org.axonframework.queryhandling.annotation, org.axonframework.eventhandling.scheduling, org.axonframework.common.jdbc, org.axonframework.messaging.correlation, org.axonframework.serialization, org.axonframework.eventhandling.deadletter, org.axonframework.me...
# 17                                                                         [org.axonframework.eventsourcing.eventstore.jpa, org.axonframework.eventsourcing, org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.eventstore.legacyjpa]
# 18                                  [org.axonframework.modelling.saga.repository.inmemory, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga.repository, org.axonframework.modelling.command, org.axonframework.modelling.saga, org.axonframework.modelling.command.inspection]
# 19                               [org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.command, org.axonframework.modelling.saga.repository.jdbc, org.axonframework.modelling.saga, org.axonframework.modelling.saga.repository.legacyjpa]
# 20                                            [org.axonframework.modelling.command, org.axonframework.modelling.saga.repository, org.axonframework.modelling.saga.repository.jpa, org.axonframework.modelling.saga, org.axonframework.modelling.command.inspection, org.axonframework.modelling.saga.metamodel]
# 21  [org.axonframework.common.jpa, org.axonframework.messaging.annotation, org.axonframework.serialization.upcasting.event, org.axonframework.tracing, org.axonframework.messaging.interceptors, org.axonframework.queryhandling, org.axonframework.deadline, org.axonframework.eventhandling.scheduling.dbs...
# 22  [org.axonframework.common.transaction, org.axonframework.lifecycle, org.axonframework.eventhandling, org.axonframework.eventhandling.scheduling, org.axonframework.messaging.unitofwork, org.axonframework.common, org.axonframework.messaging, org.axonframework.messaging.correlation, org.axonframewo...
# 23                                                                                                                                              [org.axonframework.test, org.axonframework.test.matchers, org.axonframework.test.utils, org.axonframework.test.deadline, org.axonframework.test.eventscheduler]
# 24  [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing, org.axonframework.eventsourcing.snapshotting, org.axonframework.eventsourcing.eventstore.jdbc, org.axonframework.eventsourcing.eventstore.jdbc.statements, org.axonframework.eventsourcing.eventstore.jpa, org.axonframewo...
# 25  [org.axonframework.axonserver.connector.event.axon, org.axonframework.axonserver.connector.util, org.axonframework.axonserver.connector.command, org.axonframework.axonserver.connector.event.util, org.axonframework.axonserver.connector.query, org.axonframework.axonserver.connector, org.axonframew...
# 26  [org.axonframework.springboot.util.jpa, org.axonframework.springboot.util, org.axonframework.springboot, org.axonframework.actuator.axonserver, org.axonframework.springboot.service.connection, org.axonframework.actuator, org.axonframework.springboot.autoconfig, org.axonframework.springboot.util....
# 27                                                                                                                                                                                                                                                                    [org.axonframework.tracing.opentelemetry]
# 28                                                                                                                                                                                                                                                                [org.axonframework.disruptor.commandhandling]
# 29                                                                                                                                                                                                                                                                                   [org.axonframework.config]
#
#                                                                                                                                                                                                                                                                                           dependentPackageNames
# 0                                                                                                                                                                                                                                                                                  [common, messaging, tracing]
# 1                                                                                                                                                                                                                                                                                                     [command]
# 2                                                                                                                                                                                                                                                                                                      [server]
# 3                                                                                                                                                                                                     [transaction, messaging, monitoring, commandhandling, common, annotation, callbacks, unitofwork, caching]
# 4                                                                                                                                                                                            [common, deadline, unitofwork, messaging, eventhandling, annotation, commandhandling, gateway, scheduling, stream]
# 5                                                                                                                                                                                                                                                                                         [command, inspection]
# 6                                                                                                                                                                                                                                                                                         [command, inspection]
# 7                                                                                                                                                                                                                                                                                   [eventsourcing, eventstore]
# 8                                                                                                                                                                                                                                                                                   [eventsourcing, eventstore]
# 9                                                                                                                               [common, unitofwork, annotation, messaging, eventhandling, property, commandhandling, xml, jdbc, serialization, interceptors, jpa, tracing, lock, deadline, legacyjpa, caching]
# 10                                                                                                         [annotation, messaging, common, commandhandling, unitofwork, eventhandling, lifecycle, tracing, serialization, event, jdbc, stream, monitoring, xml, io, transaction, jpa, legacyjpa, lock, caching]
# 11                                                                                                                                                                                                                                                                    [eventstore, snapshotting, eventsourcing]
# 12                                                                                                                                                                                                                                                                            [connector, query, command, axon]
# 13                                     [transaction, commandhandling, inmemory, distributed, lifecycle, common, messaging, queryhandling, eventhandling, tokenstore, xml, event, stream, unitofwork, java, scheduling, serialization, monitoring, async, jdbc, tracing, pooled, util, responsetypes, callbacks]
# 14                                                                                                                                                                                                                                                               [jpa, eventstore, eventsourcing, snapshotting]
# 15                                                                                                                                                                                                                                                            [repository, inmemory, saga, command, inspection]
# 16  [transaction, annotation, scheduling, jdbc, correlation, serialization, deadletter, lifecycle, lock, jpa, pooled, interceptors, async, caching, eventhandling, inmemory, messaging, gateway, util, unitofwork, commandhandling, tracing, monitoring, xml, common, queryhandling, deadline, tokenstore, e...
# 17                                                                                                                                                                                                                                                            [jpa, eventsourcing, eventstore, jdbc, legacyjpa]
# 18                                                                                                                                                                                                                                                       [inmemory, jpa, repository, command, saga, inspection]
# 19                                                                                                                                                                                                                                                            [repository, jpa, command, jdbc, saga, legacyjpa]
# 20                                                                                                                                                                                                                                                      [command, repository, jpa, saga, inspection, metamodel]
# 21  [jpa, annotation, event, tracing, interceptors, queryhandling, deadline, dbscheduler, distributed, jdbc, jobrunr, gateway, messaging, transaction, deadletter, serialization, scheduling, avro, eventhandling, timeout, lifecycle, commandhandling, xml, tokenstore, common, async, json, attributes, co...
# 22  [transaction, lifecycle, eventhandling, scheduling, unitofwork, common, messaging, correlation, annotation, serialization, io, commandhandling, queryhandling, util, deadline, lock, responsetypes, callbacks, deadletter, monitoring, tracing, replay, tokenstore, event, async, stream, xml, distribut...
# 23                                                                                                                                                                                                                                                            [test, matchers, utils, deadline, eventscheduler]
# 24                                                                                                                                                                                                                         [eventstore, eventsourcing, snapshotting, jdbc, statements, jpa, conflictresolution]
# 25                                                                                                                                                                                                                                  [axon, util, command, query, connector, heartbeat, processor, subscription]
# 26                                                                                                                                                                                                                             [jpa, util, springboot, axonserver, connection, actuator, autoconfig, legacyjpa]
# 27                                                                                                                                                                                                                                                                                              [opentelemetry]
# 28                                                                                                                                                                                                                                                                                            [commandhandling]
# 29                                                                                                                                                                                                                                                                                                     [config]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                              artifactName      dependentArtifactName  \
# 0                        axon-test-4.11.1      axon-messaging-4.11.1
# 1                   axon-modelling-4.11.1      axon-messaging-4.11.1
# 2            axon-server-connector-4.11.1      axon-messaging-4.11.1
# 3   axon-spring-boot-autoconfigure-4.11.1      axon-messaging-4.11.1
# 4               axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 5   axon-spring-boot-autoconfigure-4.11.1      axon-messaging-4.11.1
# 6               axon-eventsourcing-4.11.1      axon-modelling-4.11.1
# 7               axon-eventsourcing-4.11.1      axon-modelling-4.11.1
# 8            axon-server-connector-4.11.1      axon-modelling-4.11.1
# 9               axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 10                  axon-modelling-4.11.1      axon-messaging-4.11.1
# 11                  axon-modelling-4.11.1      axon-messaging-4.11.1
# 12                       axon-test-4.11.1      axon-messaging-4.11.1
# 13           axon-server-connector-4.11.1  axon-eventsourcing-4.11.1
# 14           axon-server-connector-4.11.1  axon-configuration-4.11.1
# 15  axon-spring-boot-autoconfigure-4.11.1  axon-configuration-4.11.1
# 16  axon-spring-boot-autoconfigure-4.11.1  axon-configuration-4.11.1
# 17              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 18                       axon-test-4.11.1      axon-messaging-4.11.1
# 19              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 20                       axon-test-4.11.1      axon-messaging-4.11.1
# 21  axon-spring-boot-autoconfigure-4.11.1      axon-messaging-4.11.1
# 22              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 23              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 24              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 25              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 26                       axon-test-4.11.1      axon-modelling-4.11.1
# 27              axon-eventsourcing-4.11.1      axon-messaging-4.11.1
# 28                       axon-test-4.11.1      axon-messaging-4.11.1
# 29           axon-server-connector-4.11.1  axon-eventsourcing-4.11.1
#
#                                                    packageName  \
# 0                              org.axonframework.test.matchers
# 1                   org.axonframework.modelling.saga.metamodel
# 2                       org.axonframework.axonserver.connector
# 3            org.axonframework.springboot.autoconfig.legacyjpa
# 4                 org.axonframework.eventsourcing.snapshotting
# 5                            org.axonframework.springboot.util
# 6              org.axonframework.eventsourcing.eventstore.jdbc
# 7           org.axonframework.eventsourcing.conflictresolution
# 8                       org.axonframework.axonserver.connector
# 9           org.axonframework.eventsourcing.conflictresolution
# 10                         org.axonframework.modelling.command
# 11               org.axonframework.modelling.command.legacyjpa
# 12                       org.axonframework.test.eventscheduler
# 13           org.axonframework.axonserver.connector.event.axon
# 14            org.axonframework.axonserver.connector.processor
# 15                                org.axonframework.springboot
# 16           org.axonframework.springboot.autoconfig.legacyjpa
# 17                  org.axonframework.eventsourcing.eventstore
# 18                             org.axonframework.test.matchers
# 19          org.axonframework.eventsourcing.conflictresolution
# 20                                      org.axonframework.test
# 21           org.axonframework.springboot.autoconfig.legacyjpa
# 22        org.axonframework.eventsourcing.eventstore.legacyjpa
# 23              org.axonframework.eventsourcing.eventstore.jpa
# 24             org.axonframework.eventsourcing.eventstore.jdbc
# 25  org.axonframework.eventsourcing.eventstore.jdbc.statements
# 26                                org.axonframework.test.utils
# 27          org.axonframework.eventsourcing.conflictresolution
# 28                             org.axonframework.test.matchers
# 29                      org.axonframework.axonserver.connector
#
#                           dependentPackage.fqn  dependentTypes  \
# 0              org.axonframework.eventhandling               1
# 1              org.axonframework.eventhandling               1
# 2              org.axonframework.eventhandling               1
# 3              org.axonframework.eventhandling               1
# 4              org.axonframework.eventhandling               1
# 5              org.axonframework.eventhandling               1
# 6          org.axonframework.modelling.command               1
# 7          org.axonframework.modelling.command               1
# 8          org.axonframework.modelling.command               1
# 9              org.axonframework.eventhandling               2
# 10             org.axonframework.eventhandling               2
# 11             org.axonframework.eventhandling               2
# 12             org.axonframework.eventhandling               2
# 13             org.axonframework.eventsourcing               1
# 14                    org.axonframework.config               1
# 15                    org.axonframework.config               1
# 16                    org.axonframework.config               1
# 17                 org.axonframework.messaging               1
# 18                 org.axonframework.messaging               1
# 19                 org.axonframework.messaging               1
# 20                 org.axonframework.messaging               1
# 21             org.axonframework.serialization               1
# 22             org.axonframework.serialization               1
# 23             org.axonframework.serialization               1
# 24             org.axonframework.serialization               1
# 25             org.axonframework.eventhandling               3
# 26            org.axonframework.modelling.saga               1
# 27           org.axonframework.commandhandling               1
# 28           org.axonframework.commandhandling               1
# 29  org.axonframework.eventsourcing.eventstore               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                     100             0.010000
# 1                     100             0.010000
# 2                     100             0.010000
# 3                     100             0.010000
# 4                     100             0.010000
# 5                     100             0.010000
# 6                      56             0.017857
# 7                      56             0.017857
# 8                      56             0.017857
# 9                     100             0.020000
# 10                    100             0.020000
# 11                    100             0.020000
# 12                    100             0.020000
# 13                     42             0.023810
# 14                     41             0.024390
# 15                     41             0.024390
# 16                     41             0.024390
# 17                     35             0.028571
# 18                     35             0.028571
# 19                     35             0.028571
# 20                     35             0.028571
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                    100             0.030000
# 26                     33             0.030303
# 27                     32             0.031250
# 28                     32             0.031250
# 29                     31             0.032258
#
#                                                                                                                                                dependentTypeNames
# 0                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 1                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 2                                                                                                           [org.axonframework.eventhandling.EventBusSpanFactory]
# 3                                                                                                                      [org.axonframework.eventhandling.EventBus]
# 4                                                                                                               [org.axonframework.eventhandling.DomainEventData]
# 5                                                                                                                  [org.axonframework.eventhandling.EventMessage]
# 6                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 7                                                                                      [org.axonframework.modelling.command.ConflictingAggregateVersionException]
# 8                                                                                                      [org.axonframework.modelling.command.ConcurrencyException]
# 9                                                              [org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 10                                                           [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 11                                                           [org.axonframework.eventhandling.EventBus, org.axonframework.eventhandling.DomainEventSequenceAware]
# 12                                                            [org.axonframework.eventhandling.GenericEventMessage, org.axonframework.eventhandling.EventMessage]
# 13                                                                                                             [org.axonframework.eventsourcing.EventStreamUtils]
# 14                                                                                                        [org.axonframework.config.EventProcessingConfiguration]
# 15                                                                                                                   [org.axonframework.config.TagsConfiguration]
# 16                                                                                                                       [org.axonframework.config.Configuration]
# 17                                                                                                          [org.axonframework.messaging.StreamableMessageSource]
# 18                                                                                                                          [org.axonframework.messaging.Message]
# 19                                                                                                                          [org.axonframework.messaging.Message]
# 20                                                                                                                          [org.axonframework.messaging.Message]
# 21                                                                                                                   [org.axonframework.serialization.Serializer]
# 22                                                                                                                   [org.axonframework.serialization.Serializer]
# 23                                                                                                                   [org.axonframework.serialization.Serializer]
# 24                                                                                                                   [org.axonframework.serialization.Serializer]
# 25  [org.axonframework.eventhandling.GenericDomainEventMessage, org.axonframework.eventhandling.DomainEventMessage, org.axonframework.eventhandling.EventMessage]
# 26                                                                                                      [org.axonframework.modelling.saga.SimpleResourceInjector]
# 27                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 28                                                                                                             [org.axonframework.commandhandling.CommandMessage]
# 29                                                                                               [org.axonframework.eventsourcing.eventstore.EventStoreException]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                    javax.annotation.Nonnull
# 1                                                        java.lang.Deprecated
# 2                                 org.springframework.context.annotation.Bean
# 3   org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 4                                               java.lang.FunctionalInterface
# 5                                                   javax.annotation.Nullable
# 6                                                    javax.annotation.Nonnull
# 7                                                 java.lang.annotation.Target
# 8                                              java.lang.annotation.Retention
# 9                                                        java.lang.Deprecated
# 10                                                    javax.persistence.Basic
# 11                                                  jakarta.persistence.Basic
# 12                              com.fasterxml.jackson.annotation.JsonProperty
# 13                   org.springframework.boot.autoconfigure.AutoConfiguration
# 14                                            java.lang.annotation.Documented
# 15                                           java.beans.ConstructorProperties
# 16                     org.springframework.beans.factory.annotation.Qualifier
# 17                                                       java.lang.Deprecated
# 18                  org.springframework.boot.autoconfigure.AutoConfigureAfter
# 19                               com.fasterxml.jackson.annotation.JsonCreator
# 20         org.springframework.boot.autoconfigure.condition.ConditionalOnBean
# 21     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 22        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 23                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 24                                                   javax.persistence.Column
# 25  org.springframework.boot.context.properties.EnableConfigurationProperties
# 26                                          org.axonframework.common.Priority
# 27                                                 jakarta.persistence.Column
# 28                                                       javax.persistence.Id
# 29     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       1668
# 1           Method                        133
# 2           Method                        122
# 3           Method                         78
# 4        Interface                         65
# 5        Parameter                         62
# 6           Method                         60
# 7       Annotation                         44
# 8       Annotation                         44
# 9            Class                         43
# 10           Field                         39
# 11           Field                         33
# 12       Parameter                         32
# 13           Class                         26
# 14      Annotation                         24
# 15     Constructor                         21
# 16       Parameter                         20
# 17     Constructor                         20
# 18           Class                         17
# 19     Constructor                         16
# 20          Method                         15
# 21          Method                         15
# 22           Class                         15
# 23           Class                         15
# 24           Field                         12
# 25           Class                         12
# 26           Class                         11
# 27           Field                         11
# 28           Field                         10
# 29           Class                         10
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.springboot.autoconfig.AxonAutoConfiguration.setBeanClassLoader(0), org.axonframework.springboot.autoconfig.PersistentStreamMessageSourceRegistrar.postProcessBeanDefinitionRegistry(0), org.axonframework.springboot.autoconfig.PersistentStreamMessageSourceRegistrar.postProcessBea...
# 1   [org.axonframework.springboot.TracingProperties.isNestedHandlers, org.axonframework.springboot.TracingProperties.setNestedHandlers, org.axonframework.springboot.TracingProperties.getNestedTimeLimit, org.axonframework.springboot.TracingProperties.setNestedTimeLimit, org.axonframework.eventsourcin...
# 2   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration.eventStorageEngine, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.entityManagerProvider, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.tokenStore, or...
# 3   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.entityManagerProvider, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.tokenStore, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.sagaStore, org.axonframework.spr...
# 4   [org.axonframework.eventsourcing.conflictresolution.ConflictExceptionSupplier, org.axonframework.eventsourcing.conflictresolution.ContextAwareConflictExceptionSupplier, org.axonframework.eventsourcing.eventstore.jdbc.statements.CreateTokenAtStatementBuilder, org.axonframework.eventsourcing.event...
# 5   [org.axonframework.eventsourcing.eventstore.EventStorageEngine.readEvents(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(0), org.axonframework.commandhandling.GenericCommandResultMessage.<init>(1), org.axonframework.commandhandling.MonitorAwareCallback.<init>(0), org.ax...
# 6   [org.axonframework.springboot.util.legacyjpa.ContainerManagedEntityManagerProvider.getEntityManager, org.axonframework.springboot.util.AbstractQualifiedBeanCondition.getConfigurationPhase, org.axonframework.springboot.util.jpa.ContainerManagedEntityManagerProvider.getEntityManager, org.axonframe...
# 7   [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.RegisterDefaultEntities, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonf...
# 8   [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.RegisterDefaultEntities, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonf...
# 9   [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.util.legacyjpa.ContainerManagedEntityManagerProvider, org.axonframework.eventsourcing.MultiStreamableM...
# 10  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 11  [org.axonframework.eventhandling.AbstractDomainEventEntry.type, org.axonframework.eventhandling.AbstractDomainEventEntry.aggregateIdentifier, org.axonframework.eventhandling.AbstractDomainEventEntry.sequenceNumber, org.axonframework.eventhandling.AbstractEventEntry.timeStamp, org.axonframework.e...
# 12  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(0), org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>(1), org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>(0), org.axonframewor...
# 13  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration,...
# 14  [org.axonframework.springboot.util.ConditionalOnQualifiedBean, org.axonframework.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.eventsourcing.EventSourcingHandler, org.axonframework.config.ProcessingGroup, org.axonframework.commandhandling.CommandHandler, org.axonframework....
# 15  [org.axonframework.commandhandling.distributed.commandfilter.AndCommandMessageFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.CommandNameFilter.<init>, org.axonframework.commandhandling.distributed.commandfilter.DenyCommandNameFilter.<init>, org.axonframework.commandha...
# 16  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration.eventStorageEngine(2), org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.deadLetterQueueProviderConfigurerModule(4), org.axonframework.springboot.autoconfig.AxonDbSchedulerAutoConfigu...
# 17  [org.axonframework.eventsourcing.MultiStreamableMessageSource.<init>, org.axonframework.eventsourcing.snapshotting.RevisionSnapshotFilter.<init>, org.axonframework.axonserver.connector.processor.EventProcessorControlService.<init>, org.axonframework.axonserver.connector.query.subscription.AxonSe...
# 18  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonDbSchedulerAutoConfigurat...
# 19  [org.axonframework.eventhandling.GapAwareTrackingToken.<init>, org.axonframework.eventhandling.GlobalSequenceTrackingToken.<init>, org.axonframework.eventhandling.MergedTrackingToken.<init>, org.axonframework.eventhandling.MultiSourceTrackingToken.<init>, org.axonframework.eventhandling.ReplayTo...
# 20  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration.persistenceExceptionResolver, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration.commandDispatchInterceptorConfigurer, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration.eventDispatch...
# 21  [org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration.eventScheduler, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration.metricsConfigurerModule, org.axonframework.springboot.autoconfig.AxonTracingAutoConfiguration.aggregateIdentifierSpanAttributesProvider, org.axonf...
# 22  [org.axonframework.springboot.autoconfig.AvroSerializerAutoConfiguration, org.axonframework.springboot.autoconfig.InterceptorAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframework.springboot.autoconfig.AxonServerAutoConfiguration, org.axonframework...
# 23  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxEventStoreAutoConfiguration, org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.AvroSerializerAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfigu...
# 24  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 25  [org.axonframework.springboot.autoconfig.legacyjpa.JpaJavaxAutoConfiguration, org.axonframework.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.springboot.autoconfig.MetricsAutoConfiguration, org.axonframework.sp...
# 26  [org.axonframework.config.ConfigurationParameterResolverFactory, org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.commandhandling.CurrentUnitOfWorkParameterResolverFactory, org.axonframework.eventhandling.SequenceNumberParameterResolverFactory, org.axonframework....
# 27  [org.axonframework.eventhandling.AbstractEventEntry.eventIdentifier, org.axonframework.eventhandling.AbstractEventEntry.payload, org.axonframework.eventhandling.AbstractEventEntry.metaData, org.axonframework.eventhandling.deadletter.jpa.DeadLetterEntry.causeMessage, org.axonframework.eventhandli...
# 28  [org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.aggregateIdentifier, org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.sequenceNumber, org.axonframework.eventsourcing.eventstore.AbstractSnapshotEventEntry.type, org.axonframework.eventhandling.AbstractSe...
# 29  [org.axonframework.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.springboot.autoconfig.XStreamAutoConfiguration$XStreamConfiguredCondition$EventsXStreamCondition, org.axonframework.springboot.autoconfig.XStreamAutoConfiguration$XStreamConfiguredCondition$GeneralDefaultCon...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2685                     1062                         1195
# 1                    92                       84                           38
# 2                  2559                      778                          477
# 3                  2631                      456                          550
#
#                                                                                                                                                                                                                                                                                                       examples
# 0  [/org/axonframework/springboot/autoconfig uses /org/axonframework/springboot/util, /org/axonframework/springboot/DistributedCommandBusProperties$JGroupsProperties$Gossip.class uses /org/axonframework/springboot/DistributedCommandBusProperties$JGroupsProperties.class, /org/axonframework/springboo...
# 1  [/org/axonframework/actuator/axonserver uses /org/axonframework/actuator, /org/axonframework/springboot/autoconfig uses /org/axonframework/springboot, /org/axonframework/springboot/util uses /org/axonframework/springboot, /org/axonframework/springboot/autoconfig/legacyjpa uses /org/axonframework...
# 2  [/org/axonframework/springboot/autoconfig uses /org/axonframework/actuator/axonserver, /org/axonframework/springboot/autoconfig/legacyjpa uses /org/axonframework/springboot, /org/axonframework/springboot/autoconfig uses /org/axonframework/springboot/service/connection, /org/axonframework/springb...
# 3  [/org/axonframework/disruptor/commandhandling/CommandHandlerInvoker$DisruptorRepository.class uses /org/axonframework/eventsourcing/AggregateCacheEntry.class, /org/axonframework/test/aggregate/AggregateTestFixture.class uses /org/axonframework/eventsourcing/EventSourcingRepository.class, /org/ax...
