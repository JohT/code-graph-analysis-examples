# %% [markdown]
# # Object Oriented Design Quality Metrics
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [jqassistant](https://jqassistant.org)
# - [notebook walks through examples for integrating various packages with Neo4j](https://nicolewhite.github.io/neo4j-jupyter/hello-world.html)
# - [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616)
# - [A Validation of Martin's Metric](https://www.researchgate.net/publication/31598248_A_Validation_of_Martin's_Metric)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %% [markdown]
# ## Incoming Dependencies
#
# Incoming dependencies are also denoted as "Fan-in", "Afferent Coupling" or "in-degree".
# These are the ones that use the listed package.
#
# If these packages get changed, the incoming dependencies might be affected by the change. The more incoming dependencies, the harder it gets to change the code without the need to adapt the dependent code (“rigid code”). Even worse, it might affect the behavior of the dependent code in an unwanted way (“fragile code”).
#
# Since Java Packages are organized hierarchically, incoming dependencies can be count for every package in isolation or by including all of its sub-packages. The latter one is done without top level packages like for example "org" or "org.company" by assuring that only packages are considered that have other packages or types in the same hierarchy level ("siblings").

# %% [markdown]
# #### Table 1a
# - Show the top 20 Java Packages with the most incoming dependencies
# - Set the "incomingDependencies" properties on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Incoming_Java_Package_Dependencies.cypher",
                                           "../cypher/Metrics/Set_Incoming_Java_Package_Dependencies.cypher", limit=20)
# Out:
#                 artifactName  \
# 0       axon-messaging-5.0.1
# 1       axon-messaging-5.0.1
# 2          axon-common-5.0.1
# 3       axon-messaging-5.0.1
# 4          axon-common-5.0.1
# 5       axon-messaging-5.0.1
# 6          axon-common-5.0.1
# 7          axon-common-5.0.1
# 8       axon-messaging-5.0.1
# 9       axon-messaging-5.0.1
# 10     axon-conversion-5.0.1
# 11      axon-messaging-5.0.1
# 12      axon-messaging-5.0.1
# 13  axon-eventsourcing-5.0.1
# 14      axon-messaging-5.0.1
# 15           axon-test-5.0.1
# 16      axon-modelling-5.0.1
# 17      axon-modelling-5.0.1
# 18      axon-modelling-5.0.1
# 19      axon-messaging-5.0.1
#
#                              fullQualifiedPackageName      packageName  \
# 0         org.axonframework.messaging.core.unitofwork       unitofwork
# 1                    org.axonframework.messaging.core             core
# 2              org.axonframework.common.configuration    configuration
# 3           org.axonframework.messaging.eventhandling    eventhandling
# 4                 org.axonframework.common.annotation       annotation
# 5         org.axonframework.messaging.commandhandling  commandhandling
# 6                      org.axonframework.common.infra            infra
# 7                            org.axonframework.common           common
# 8           org.axonframework.messaging.queryhandling    queryhandling
# 9         org.axonframework.messaging.core.annotation       annotation
# 10                       org.axonframework.conversion       conversion
# 11  org.axonframework.messaging.eventhandling.proc...            token
# 12         org.axonframework.messaging.eventstreaming   eventstreaming
# 13         org.axonframework.eventsourcing.eventstore       eventstore
# 14                org.axonframework.messaging.tracing          tracing
# 15                     org.axonframework.test.fixture          fixture
# 16                        org.axonframework.modelling        modelling
# 17                 org.axonframework.modelling.entity           entity
# 18           org.axonframework.modelling.entity.child            child
# 19  org.axonframework.messaging.eventhandling.proc...       segmenting
#
#     incomingDependencies  incomingDependenciesWeight  incomingDependentTypes  \
# 0                  11695                       41605                     245
# 1                  10993                       35618                     406
# 2                   3336                       17876                     145
# 3                   3209                       10719                     152
# 4                   1842                        2058                     130
# 5                   1442                        5110                      97
# 6                   1212                        1486                     111
# 7                    838                        2028                     278
# 8                    698                        2468                      76
# 9                    484                        1624                     117
# 10                   426                        1719                      55
# 11                   425                        2089                      58
# 12                   283                         801                      53
# 13                   223                         719                      65
# 14                   137                         481                      37
# 15                   132                         357                      26
# 16                   125                         282                      36
# 17                   115                         394                      25
# 18                    89                         230                      28
# 19                    86                         659                      31
#
#     incomingDependentInterfaces  incomingDependentPackages  \
# 0                            55                         60
# 1                            78                         69
# 2                            50                         32
# 3                            31                         37
# 4                            16                         52
# 5                            25                         26
# 6                            27                         41
# 7                            20                         77
# 8                            17                         16
# 9                            11                         24
# 10                           12                         19
# 11                            8                         16
# 12                           14                         10
# 13                            7                          9
# 14                            7                          7
# 15                            0                          1
# 16                            9                          9
# 17                            5                          5
# 18                            7                          3
# 19                            5                         10
#
#     incomingDependentArtifacts
# 0                            4
# 1                            7
# 2                            8
# 3                            6
# 4                            7
# 5                            6
# 6                            6
# 7                           10
# 8                            3
# 9                            4
# 10                           4
# 11                           3
# 12                           3
# 13                           3
# 14                           1
# 15                           0
# 16                           2
# 17                           1
# 18                           0
# 19                           1

# %% [markdown]
# #### Table 1b
# - Show the top 20 Java Packages including their sub-packages with the most incoming dependencies
# - Set the property "incomingDependenciesIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Incoming_Java_Package_Dependencies_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Set_Incoming_Java_Package_Dependencies_Including_Subpackages.cypher", limit=20)
# Out:
#                 artifactName  \
# 0       axon-messaging-5.0.1
# 1       axon-messaging-5.0.1
# 2          axon-common-5.0.1
# 3          axon-common-5.0.1
# 4       axon-messaging-5.0.1
# 5          axon-common-5.0.1
# 6          axon-common-5.0.1
# 7       axon-messaging-5.0.1
# 8       axon-messaging-5.0.1
# 9      axon-conversion-5.0.1
# 10      axon-messaging-5.0.1
# 11      axon-messaging-5.0.1
# 12      axon-messaging-5.0.1
# 13      axon-messaging-5.0.1
# 14      axon-messaging-5.0.1
# 15      axon-messaging-5.0.1
# 16  axon-eventsourcing-5.0.1
# 17      axon-messaging-5.0.1
# 18      axon-modelling-5.0.1
# 19      axon-modelling-5.0.1
#
#                              fullQualifiedPackageName      packageName  \
# 0                    org.axonframework.messaging.core             core
# 1         org.axonframework.messaging.core.unitofwork       unitofwork
# 2                            org.axonframework.common           common
# 3              org.axonframework.common.configuration    configuration
# 4           org.axonframework.messaging.eventhandling    eventhandling
# 5                 org.axonframework.common.annotation       annotation
# 6                      org.axonframework.common.infra            infra
# 7         org.axonframework.messaging.commandhandling  commandhandling
# 8         org.axonframework.messaging.core.annotation       annotation
# 9                        org.axonframework.conversion       conversion
# 10  org.axonframework.messaging.eventhandling.proc...            token
# 11          org.axonframework.messaging.queryhandling    queryhandling
# 12         org.axonframework.messaging.eventstreaming   eventstreaming
# 13  org.axonframework.messaging.eventhandling.proc...       processing
# 14  org.axonframework.messaging.eventhandling.proc...        streaming
# 15                org.axonframework.messaging.tracing          tracing
# 16         org.axonframework.eventsourcing.eventstore       eventstore
# 17  org.axonframework.messaging.eventhandling.proc...       segmenting
# 18                        org.axonframework.modelling        modelling
# 19             org.axonframework.modelling.repository       repository
#
#     incomingDependencies  incomingDependenciesWeight  incomingDependentTypes  \
# 0                  18122                       61768                     377
# 1                  11490                       40479                     230
# 2                   6759                       22336                     445
# 3                   3175                       17216                     105
# 4                   2081                        7412                      97
# 5                   1841                        2057                     129
# 6                   1198                        1412                     106
# 7                    883                        3295                      63
# 8                    396                        1318                      81
# 9                    374                        1538                      36
# 10                   350                        1386                      45
# 11                   279                         897                      34
# 12                   231                         656                      39
# 13                   217                         663                      30
# 14                   207                         633                      30
# 15                   108                         359                      22
# 16                    76                         206                      19
# 17                    74                         620                      23
# 18                    74                         226                      13
# 19                    66                         311                      14
#
#     incomingDependentInterfaces  incomingDependentPackages  \
# 0                           113                         68
# 1                            55                         58
# 2                            99                         87
# 3                            50                         31
# 4                            35                         25
# 5                            16                         51
# 6                            27                         40
# 7                            26                         20
# 8                            11                         23
# 9                            12                         15
# 10                            8                         11
# 11                           15                         12
# 12                           14                          9
# 13                           13                         10
# 14                           12                         11
# 15                            7                          5
# 16                            6                          6
# 17                            5                          9
# 18                           20                          4
# 19                            5                          6
#
#     incomingDependentArtifacts
# 0                            7
# 1                            5
# 2                            9
# 3                            8
# 4                            6
# 5                            7
# 6                            6
# 7                            6
# 8                            4
# 9                            3
# 10                           4
# 11                           5
# 12                           3
# 13                           5
# 14                           4
# 15                           1
# 16                           3
# 17                           1
# 18                           1
# 19                           1

# %% [markdown]
# ## Outgoing Dependencies
#
# Outgoing dependencies are also denoted as "Fan-out", "Efferent Coupling" or "out-degree".
# These are the ones that are used by the listed package.
#
# Code from other packages and libraries you’re depending on (outgoing) might change over time. The more outgoing changes, the more likely and frequently code changes are needed. This involves time and effort which can be reduced by automation of tests and version updates. Automated tests are crucial to reveal updates, that change the behavior of the code unexpectedly (“fragile code”). As soon as more effort is required, keeping up becomes difficult (“rigid code”). Not being able to use a newer version might not only restrict features, it can get problematic if there are security issues. This might force you to take “fast but ugly” solutions into account which further increases technical dept.
#
# Since Java Packages are organized hierarchically, outgoing dependencies can be count for every package in isolation or by including all of its sub-packages. The latter one is done without top level packages like for example "org" or "org.company" by assuring that only packages are considered that have other packages or types in the same hierarchy level ("siblings").

# %% [markdown]
# #### Table 2a
#
# - Show the top 20 Java Packages with the most outgoing dependencies
# - Set the "outgoingDependencies" properties on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Outgoing_Java_Package_Dependencies.cypher",
                                           "../cypher/Metrics/Set_Outgoing_Java_Package_Dependencies.cypher", limit=20)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.1
# 1                   axon-messaging-5.0.1
# 2               axon-eventsourcing-5.0.1
# 3               axon-eventsourcing-5.0.1
# 4            axon-server-connector-5.0.1
# 5                   axon-messaging-5.0.1
# 6                        axon-test-5.0.1
# 7                   axon-modelling-5.0.1
# 8                   axon-modelling-5.0.1
# 9                   axon-messaging-5.0.1
# 10              axon-eventsourcing-5.0.1
# 11  axon-spring-boot-autoconfigure-5.0.1
# 12                  axon-modelling-5.0.1
# 13                  axon-messaging-5.0.1
# 14                  axon-messaging-5.0.1
# 15                  axon-messaging-5.0.1
# 16                  axon-messaging-5.0.1
# 17                  axon-messaging-5.0.1
# 18                  axon-messaging-5.0.1
# 19                  axon-messaging-5.0.1
#
#                              fullQualifiedPackageName    packageName  \
# 0      org.axonframework.messaging.core.configuration  configuration
# 1   org.axonframework.messaging.eventhandling.proc...         pooled
# 2      org.axonframework.eventsourcing.eventstore.jpa            jpa
# 3       org.axonframework.eventsourcing.configuration  configuration
# 4        org.axonframework.axonserver.connector.event          event
# 5       org.axonframework.messaging.core.interception   interception
# 6                      org.axonframework.test.fixture        fixture
# 7       org.axonframework.modelling.entity.annotation     annotation
# 8                  org.axonframework.modelling.entity         entity
# 9   org.axonframework.messaging.eventhandling.proc...    subscribing
# 10         org.axonframework.eventsourcing.eventstore     eventstore
# 11  org.axonframework.extension.springboot.autoconfig     autoconfig
# 12          org.axonframework.modelling.configuration  configuration
# 13          org.axonframework.messaging.queryhandling  queryhandling
# 14  org.axonframework.messaging.eventhandling.anno...     annotation
# 15  org.axonframework.messaging.queryhandling.dist...    distributed
# 16  org.axonframework.messaging.monitoring.interce...   interception
# 17  org.axonframework.messaging.queryhandling.inte...   interception
# 18        org.axonframework.messaging.core.annotation     annotation
# 19          org.axonframework.messaging.eventhandling  eventhandling
#
#     outgoingDependencies  outgoingDependenciesWeight  outgoingDependentTypes  \
# 0                   2549                       15962                      75
# 1                   2346                        9920                      96
# 2                   1260                        4805                      59
# 3                   1237                        4801                      66
# 4                   1228                        3848                      72
# 5                   1084                        5770                      46
# 6                    954                        3383                      71
# 7                    858                        3265                      64
# 8                    800                        2887                      35
# 9                    737                        2672                      46
# 10                   705                        2705                      64
# 11                   678                        2925                      99
# 12                   585                        2279                      41
# 13                   547                        2129                      48
# 14                   528                        1611                      51
# 15                   513                        1412                      38
# 16                   500                        1550                      15
# 17                   491                        1561                      26
# 18                   464                        1548                      74
# 19                   438                        1108                      41
#
#     outgoingDependentInterfaces  outgoingDependentPackages  \
# 0                            40                         28
# 1                            47                         21
# 2                            27                         16
# 3                            41                         25
# 4                            29                         18
# 5                            25                         11
# 6                            38                         15
# 7                            30                         19
# 8                            21                          9
# 9                            29                         15
# 10                           29                         10
# 11                           36                         34
# 12                           29                         10
# 13                           23                          9
# 14                           23                         14
# 15                           23                         10
# 16                           15                          6
# 17                           16                          6
# 18                           16                         10
# 19                           20                          8
#
#     outgoingDependentArtifacts
# 0                            2
# 1                            1
# 2                            3
# 3                            3
# 4                            3
# 5                            1
# 6                            3
# 7                            3
# 8                            2
# 9                            1
# 10                           2
# 11                           6
# 12                           2
# 13                           2
# 14                           2
# 15                           1
# 16                           0
# 17                           1
# 18                           1
# 19                           2

# %% [markdown]
# #### Table 2b
#
# - Show the top 20 Java Packages including their sub-packages with the most outgoing dependencies
# - Set the property "outgoingDependenciesIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Outgoing_Java_Package_Dependencies_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Set_Outgoing_Java_Package_Dependencies_Including_Subpackages.cypher", limit=20)
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.1
# 1          axon-messaging-5.0.1
# 2          axon-modelling-5.0.1
# 3          axon-messaging-5.0.1
# 4      axon-eventsourcing-5.0.1
# 5          axon-messaging-5.0.1
# 6          axon-messaging-5.0.1
# 7          axon-messaging-5.0.1
# 8          axon-modelling-5.0.1
# 9   axon-server-connector-5.0.1
# 10         axon-messaging-5.0.1
# 11     axon-eventsourcing-5.0.1
# 12         axon-modelling-5.0.1
# 13         axon-messaging-5.0.1
# 14         axon-messaging-5.0.1
# 15              axon-test-5.0.1
# 16  axon-server-connector-5.0.1
# 17              axon-test-5.0.1
# 18         axon-messaging-5.0.1
# 19         axon-messaging-5.0.1
#
#                              fullQualifiedPackageName      packageName  \
# 0           org.axonframework.messaging.eventhandling    eventhandling
# 1                    org.axonframework.messaging.core             core
# 2                         org.axonframework.modelling        modelling
# 3   org.axonframework.messaging.eventhandling.proc...       processing
# 4                     org.axonframework.eventsourcing    eventsourcing
# 5         org.axonframework.messaging.commandhandling  commandhandling
# 6           org.axonframework.messaging.queryhandling    queryhandling
# 7   org.axonframework.messaging.eventhandling.proc...        streaming
# 8                  org.axonframework.modelling.entity           entity
# 9              org.axonframework.axonserver.connector        connector
# 10  org.axonframework.messaging.eventhandling.proc...           pooled
# 11         org.axonframework.eventsourcing.eventstore       eventstore
# 12      org.axonframework.modelling.entity.annotation       annotation
# 13        org.axonframework.messaging.core.unitofwork       unitofwork
# 14      org.axonframework.messaging.core.interception     interception
# 15                             org.axonframework.test             test
# 16       org.axonframework.axonserver.connector.event            event
# 17                     org.axonframework.test.fixture          fixture
# 18        org.axonframework.messaging.core.annotation       annotation
# 19  org.axonframework.messaging.eventhandling.conf...    configuration
#
#     outgoingDependencies  outgoingDependenciesWeight  outgoingDependentTypes  \
# 0                    656                        2132                     104
# 1                    398                        1425                      84
# 2                    381                        1124                      66
# 3                    345                        1285                      79
# 4                    317                        1060                      96
# 5                    313                        1019                      75
# 6                    310                        1111                      73
# 7                    275                        1026                      80
# 8                    270                         856                      47
# 9                    253                         870                     107
# 10                   231                         928                      73
# 11                   183                         597                      53
# 12                   179                         681                      49
# 13                   176                         697                      11
# 14                   166                         587                      43
# 15                   157                         469                      43
# 16                   142                         420                      59
# 17                   129                         462                      41
# 18                   124                         337                      36
# 19                   120                         382                      40
#
#     outgoingDependentInterfaces  outgoingDependentPackages  \
# 0                            47                         20
# 1                            72                         25
# 2                            23                         19
# 3                            13                         18
# 4                            14                         30
# 5                            29                         14
# 6                            19                         12
# 7                            11                         20
# 8                            11                         17
# 9                             2                         24
# 10                            2                         20
# 11                            7                         15
# 12                            5                         18
# 13                           55                          5
# 14                            0                         11
# 15                            9                         13
# 16                            0                         17
# 17                            8                         14
# 18                            8                          9
# 19                            7                         18
#
#     outgoingDependentArtifacts
# 0                            2
# 1                            2
# 2                            2
# 3                            2
# 4                            3
# 5                            2
# 6                            2
# 7                            2
# 8                            3
# 9                            3
# 10                           1
# 11                           3
# 12                           3
# 13                           1
# 14                           1
# 15                           2
# 16                           3
# 17                           3
# 18                           1
# 19                           1

# %% [markdown]
# ## Instability
#
# $$ Instability = \frac{Outgoing\:Dependencies}{Outgoing\:Dependencies + Incoming\:Dependencies} $$
#
# *Instability* is expressed as the ratio of the number of outgoing dependencies of a module (i.e., the number of packages that depend on it) to the total number of dependencies (i.e., the sum of incoming and outgoing dependencies).
#
# Small values near zero indicate low *Instability*. With no outgoing but some incoming dependencies the Instability is zero which is denoted as maximally stable. Such code units are more rigid and difficult to change without impacting other parts of the system. If they are changed less because of that, they are considered stable.
#
# Conversely, high values approaching one indicate high *Instability*. With some outgoing dependencies but no incoming ones the *Instability* is denoted as maximally unstable. Such code units are easier to change without affecting other modules, making them more flexible and less prone to cascading changes throughout the system. If they are changed more often because of that, they are considered unstable.
#
# Since Java Packages are organized hierarchically, *Instability* can be calculated for every package in isolation or by including all of its sub-packages.

# %% [markdown]
# #### Table 3a
#
# - Show the top 20 Java Packages with the lowest *Instability*
# - Set the property "instability" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Instability_for_Java.cypher",
                                           "../cypher/Metrics/Calculate_and_set_Instability_for_Java.cypher", limit=20)
# Out:
#              artifactName                           fullQualifiedPackageName  \
# 0       axon-common-5.0.1                org.axonframework.common.annotation
# 1    axon-messaging-5.0.1        org.axonframework.messaging.core.unitofwork
# 2       axon-common-5.0.1                     org.axonframework.common.infra
# 3    axon-messaging-5.0.1                   org.axonframework.messaging.core
# 4       axon-common-5.0.1                           org.axonframework.common
# 5    axon-messaging-5.0.1  org.axonframework.messaging.eventhandling.proc...
# 6   axon-conversion-5.0.1                       org.axonframework.conversion
# 7       axon-common-5.0.1             org.axonframework.common.configuration
# 8    axon-messaging-5.0.1          org.axonframework.messaging.eventhandling
# 9    axon-messaging-5.0.1        org.axonframework.messaging.commandhandling
# 10      axon-common-5.0.1                      org.axonframework.common.util
# 11   axon-messaging-5.0.1        org.axonframework.messaging.core.conversion
# 12   axon-messaging-5.0.1  org.axonframework.messaging.eventhandling.proc...
# 13   axon-messaging-5.0.1         org.axonframework.messaging.eventstreaming
# 14      axon-common-5.0.1                       org.axonframework.common.jpa
# 15   axon-messaging-5.0.1             org.axonframework.messaging.monitoring
# 16      axon-common-5.0.1                      org.axonframework.common.jdbc
# 17   axon-messaging-5.0.1                org.axonframework.messaging.tracing
# 18      axon-common-5.0.1                 org.axonframework.common.lifecycle
# 19      axon-update-5.0.1                       org.axonframework.update.api
#
#         packageName  instability  instabilityTypes  instabilityInterfaces  \
# 0        annotation     0.001626          0.022556               0.000000
# 1        unitofwork     0.010826          0.082397               0.153846
# 2             infra     0.021792          0.082645               0.100000
# 3              core     0.030086          0.164609               0.178947
# 4            common     0.035673          0.057627               0.000000
# 5             token     0.036281          0.121212               0.200000
# 6        conversion     0.046980          0.153846               0.250000
# 7     configuration     0.074875          0.263959               0.295775
# 8     eventhandling     0.120099          0.212435               0.392157
# 9   commandhandling     0.192157          0.276119               0.444444
# 10             util     0.200000          0.153846               0.000000
# 11       conversion     0.247059          0.192308               0.571429
# 12            store     0.263158          0.190476               1.000000
# 13   eventstreaming     0.270619          0.320513               0.461538
# 14              jpa     0.272727          0.272727               1.000000
# 15       monitoring     0.282051          0.195122               0.666667
# 16             jdbc     0.310345          0.380952               0.000000
# 17          tracing     0.331707          0.314815               0.533333
# 18        lifecycle     0.333333          0.444444               0.000000
# 19              api     0.379310          0.384615               0.000000
#
#     instabilityPackages  instabilityArtifacts  p.outgoingDependencies  \
# 0              0.037037              0.000000                       3
# 1              0.090909              0.200000                     128
# 2              0.068182              0.000000                      27
# 3              0.103896              0.222222                     341
# 4              0.012821              0.000000                      31
# 5              0.157895              0.250000                      16
# 6              0.136364              0.200000                      21
# 7              0.135135              0.000000                     270
# 8              0.177778              0.250000                     438
# 9              0.187500              0.250000                     343
# 10             0.250000              0.000000                       3
# 11             0.238095              0.333333                      21
# 12             0.400000              0.333333                      10
# 13             0.375000              0.250000                     105
# 14             0.375000              0.000000                       3
# 15             0.307692              0.333333                      22
# 16             0.428571              0.000000                       9
# 17             0.416667              0.500000                      68
# 18             0.333333              0.000000                       4
# 19             0.400000              1.000000                      11
#
#     p.incomingDependencies  p.outgoingDependentTypes  \
# 0                     1842                         3
# 1                    11695                        22
# 2                     1212                        10
# 3                    10993                        80
# 4                      838                        17
# 5                      425                         8
# 6                      426                        10
# 7                     3336                        52
# 8                     3209                        41
# 9                     1442                        37
# 10                      12                         2
# 11                      64                         5
# 12                      28                         4
# 13                     283                        25
# 14                       8                         3
# 15                      56                         8
# 16                      20                         8
# 17                     137                        17
# 18                       8                         4
# 19                      18                         5
#
#     p.incomingDependentTypes  p.outgoingDependentInterfaces  \
# 0                        130                              0
# 1                        245                             10
# 2                        111                              3
# 3                        406                             17
# 4                        278                              0
# 5                         58                              2
# 6                         55                              4
# 7                        145                             21
# 8                        152                             20
# 9                         97                             20
# 10                        11                              0
# 11                        21                              4
# 12                        17                              2
# 13                        53                             12
# 14                         8                              1
# 15                        33                              4
# 16                        13                              0
# 17                        37                              8
# 18                         5                              0
# 19                         8                              0
#
#     p.incomingDependentInterfaces  p.outgoingDependentPackages  \
# 0                              16                            2
# 1                              55                            6
# 2                              27                            3
# 3                              78                            8
# 4                              20                            1
# 5                               8                            3
# 6                              12                            3
# 7                              50                            5
# 8                              31                            8
# 9                              25                            6
# 10                              0                            2
# 11                              3                            5
# 12                              0                            4
# 13                             14                            6
# 14                              0                            3
# 15                              2                            4
# 16                              0                            3
# 17                              7                            5
# 18                              0                            2
# 19                              1                            2
#
#     p.incomingDependentPackages  p.outgoingDependentArtifacts  \
# 0                            52                             0
# 1                            60                             1
# 2                            41                             0
# 3                            69                             2
# 4                            77                             0
# 5                            16                             1
# 6                            19                             1
# 7                            32                             0
# 8                            37                             2
# 9                            26                             2
# 10                            6                             0
# 11                           16                             2
# 12                            6                             1
# 13                           10                             1
# 14                            5                             0
# 15                            9                             1
# 16                            4                             0
# 17                            7                             1
# 18                            4                             0
# 19                            3                             1
#
#     p.incomingDependentArtifacts
# 0                              7
# 1                              4
# 2                              6
# 3                              7
# 4                             10
# 5                              3
# 6                              4
# 7                              8
# 8                              6
# 9                              6
# 10                             2
# 11                             4
# 12                             2
# 13                             3
# 14                             3
# 15                             2
# 16                             3
# 17                             1
# 18                             1
# 19                             0

# %% [markdown]
# #### Table 3b
#
# - Show the top 20 Java Packages including their sub-packages with the lowest *Instability*
# - Set the property "instabilityIncludingSubpackages" on Package nodes.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Instability_for_Java_Including_Subpackages.cypher",
                                           "../cypher/Metrics/Calculate_and_set_Instability_for_Java_Including_Subpackages.cypher", limit=20)
# Out:
#                             artifactName  \
# 0                      axon-common-5.0.1
# 1                      axon-common-5.0.1
# 2                   axon-messaging-5.0.1
# 3                      axon-common-5.0.1
# 4                   axon-messaging-5.0.1
# 5                  axon-conversion-5.0.1
# 6                      axon-common-5.0.1
# 7                      axon-common-5.0.1
# 8                   axon-messaging-5.0.1
# 9                   axon-messaging-5.0.1
# 10                  axon-messaging-5.0.1
# 11                     axon-common-5.0.1
# 12                  axon-messaging-5.0.1
# 13                     axon-common-5.0.1
# 14                  axon-messaging-5.0.1
# 15                  axon-messaging-5.0.1
# 16                  axon-messaging-5.0.1
# 17                     axon-common-5.0.1
# 18  axon-spring-boot-autoconfigure-5.0.1
# 19                  axon-messaging-5.0.1
#
#                              fullQualifiedPackageName      packageName  \
# 0                 org.axonframework.common.annotation       annotation
# 1                      org.axonframework.common.infra            infra
# 2         org.axonframework.messaging.core.unitofwork       unitofwork
# 3              org.axonframework.common.configuration    configuration
# 4                    org.axonframework.messaging.core             core
# 5                        org.axonframework.conversion       conversion
# 6                       org.axonframework.common.util             util
# 7                       org.axonframework.common.jdbc             jdbc
# 8         org.axonframework.messaging.core.conversion       conversion
# 9   org.axonframework.messaging.eventhandling.proc...            token
# 10         org.axonframework.messaging.eventstreaming   eventstreaming
# 11                 org.axonframework.common.lifecycle        lifecycle
# 12                org.axonframework.messaging.tracing          tracing
# 13                       org.axonframework.common.jpa              jpa
# 14  org.axonframework.messaging.eventhandling.proc...    errorhandling
# 15        org.axonframework.messaging.core.annotation       annotation
# 16          org.axonframework.messaging.eventhandling    eventhandling
# 17                  org.axonframework.common.property         property
# 18        org.axonframework.extension.springboot.util             util
# 19        org.axonframework.messaging.commandhandling  commandhandling
#
#     instability  instabilityTypes  instabilityInterfaces  instabilityPackages  \
# 0      0.001085          0.015267               0.000000             0.019231
# 1      0.004156          0.027523               0.000000             0.047619
# 2      0.015087          0.045643               0.500000             0.079365
# 3      0.021270          0.070796               0.425287             0.114286
# 4      0.021490          0.182213               0.389189             0.268817
# 5      0.057935          0.142857               0.500000             0.166667
# 6      0.090909          0.100000               0.000000             0.166667
# 7      0.133333          0.181818               0.000000             0.400000
# 8      0.136986          0.166667               0.500000             0.210526
# 9      0.152542          0.328358               0.500000             0.450000
# 10     0.163043          0.204082               0.500000             0.357143
# 11     0.166667          0.250000               0.000000             0.250000
# 12     0.205882          0.290323               0.461538             0.444444
# 13     0.222222          0.222222               0.000000             0.333333
# 14     0.230769          0.333333               0.500000             0.500000
# 15     0.238462          0.307692               0.421053             0.281250
# 16     0.239678          0.517413               0.573171             0.444444
# 17     0.250000          0.400000               0.000000             0.250000
# 18     0.250000          0.333333               0.000000             0.500000
# 19     0.261706          0.543478               0.527273             0.411765
#
#     instabilityArtifacts  p.outgoingDependenciesIncludingSubpackages  \
# 0               0.000000                                           2
# 1               0.000000                                           5
# 2               0.166667                                         176
# 3               0.000000                                          69
# 4               0.222222                                         398
# 5               0.000000                                          23
# 6               0.000000                                           1
# 7               0.000000                                           2
# 8               0.333333                                          10
# 9               0.333333                                          63
# 10              0.250000                                          45
# 11              0.000000                                           1
# 12              0.500000                                          28
# 13              0.000000                                           2
# 14              0.000000                                           3
# 15              0.200000                                         124
# 16              0.250000                                         656
# 17              0.000000                                           2
# 18              0.000000                                           1
# 19              0.250000                                         313
#
#     p.incomingDependenciesIncludingSubpackages  \
# 0                                         1841
# 1                                         1198
# 2                                        11490
# 3                                         3175
# 4                                        18122
# 5                                          374
# 6                                           10
# 7                                           13
# 8                                           63
# 9                                          350
# 10                                         231
# 11                                           5
# 12                                         108
# 13                                           7
# 14                                          10
# 15                                         396
# 16                                        2081
# 17                                           6
# 18                                           3
# 19                                         883
#
#     p.outgoingDependentTypesIncludingSubpackages  \
# 0                                              2
# 1                                              3
# 2                                             11
# 3                                              8
# 4                                             84
# 5                                              6
# 6                                              1
# 7                                              2
# 8                                              4
# 9                                             22
# 10                                            10
# 11                                             1
# 12                                             9
# 13                                             2
# 14                                             3
# 15                                            36
# 16                                           104
# 17                                             2
# 18                                             1
# 19                                            75
#
#     p.incomingDependentTypesIncludingSubpackages  \
# 0                                            129
# 1                                            106
# 2                                            230
# 3                                            105
# 4                                            377
# 5                                             36
# 6                                              9
# 7                                              9
# 8                                             20
# 9                                             45
# 10                                            39
# 11                                             3
# 12                                            22
# 13                                             7
# 14                                             6
# 15                                            81
# 16                                            97
# 17                                             3
# 18                                             2
# 19                                            63
#
#     p.outgoingDependentInterfacesIncludingSubpackages  \
# 0                                                   0
# 1                                                   0
# 2                                                  55
# 3                                                  37
# 4                                                  72
# 5                                                  12
# 6                                                   0
# 7                                                   0
# 8                                                   3
# 9                                                   8
# 10                                                 14
# 11                                                  0
# 12                                                  6
# 13                                                  0
# 14                                                  1
# 15                                                  8
# 16                                                 47
# 17                                                  0
# 18                                                  0
# 19                                                 29
#
#     p.incomingDependentInterfacesIncludingSubpackages  \
# 0                                                  16
# 1                                                  27
# 2                                                  55
# 3                                                  50
# 4                                                 113
# 5                                                  12
# 6                                                   0
# 7                                                   0
# 8                                                   3
# 9                                                   8
# 10                                                 14
# 11                                                  0
# 12                                                  7
# 13                                                  0
# 14                                                  1
# 15                                                 11
# 16                                                 35
# 17                                                  0
# 18                                                  0
# 19                                                 26
#
#     p.outgoingDependentPackagesIncludingSubpackages  \
# 0                                                 1
# 1                                                 2
# 2                                                 5
# 3                                                 4
# 4                                                25
# 5                                                 3
# 6                                                 1
# 7                                                 2
# 8                                                 4
# 9                                                 9
# 10                                                5
# 11                                                1
# 12                                                4
# 13                                                2
# 14                                                3
# 15                                                9
# 16                                               20
# 17                                                1
# 18                                                1
# 19                                               14
#
#     p.incomingDependentPackagesIncludingSubpackages  \
# 0                                                51
# 1                                                40
# 2                                                58
# 3                                                31
# 4                                                68
# 5                                                15
# 6                                                 5
# 7                                                 3
# 8                                                15
# 9                                                11
# 10                                                9
# 11                                                3
# 12                                                5
# 13                                                4
# 14                                                3
# 15                                               23
# 16                                               25
# 17                                                3
# 18                                                1
# 19                                               20
#
#     p.outgoingDependentArtifactsIncludingSubpackages  \
# 0                                                  0
# 1                                                  0
# 2                                                  1
# 3                                                  0
# 4                                                  2
# 5                                                  0
# 6                                                  0
# 7                                                  0
# 8                                                  2
# 9                                                  2
# 10                                                 1
# 11                                                 0
# 12                                                 1
# 13                                                 0
# 14                                                 0
# 15                                                 1
# 16                                                 2
# 17                                                 0
# 18                                                 0
# 19                                                 2
#
#     p.incomingDependentArtifactsIncludingSubpackages
# 0                                                  7
# 1                                                  6
# 2                                                  5
# 3                                                  8
# 4                                                  7
# 5                                                  3
# 6                                                  1
# 7                                                  2
# 8                                                  4
# 9                                                  4
# 10                                                 3
# 11                                                 1
# 12                                                 1
# 13                                                 2
# 14                                                 0
# 15                                                 4
# 16                                                 6
# 17                                                 1
# 18                                                 0
# 19                                                 6

# %% [markdown]
# ## Abstractness
#
# $$ Abstractness = \frac{abstract\:classes\:in\:category}{total\:number\:of\:classes\:in\:category} $$
#
# Package *Abstractness* is expressed as the ratio of the number of abstract classes and interfaces to the total number of classes of a package.
#
# Zero *Abstractness* means that there are no abstract types or interfaces in the package. On the other hand, a value of one means that there are only abstract types.
#
# Since Java Packages are organized hierarchically, *Abstractness* can be calculated for every package in isolation or by including all of its sub-packages.

# %% [markdown]
# #### Table 4a
#
# - Show the top 30 packages with the lowest *Abstractness*
# - Set the property "abstractness" on Package nodes.

# %%
abstractness = query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Abstractness_for_Java.cypher",
                                                          "../cypher/Metrics/Calculate_and_set_Abstractness_for_Java.cypher")
abstractness.head(30)
# Out:
#                             artifactName  \
# 0   axon-spring-boot-autoconfigure-5.0.1
# 1   axon-spring-boot-autoconfigure-5.0.1
# 2            axon-server-connector-5.0.1
# 3          axon-metrics-micrometer-5.0.1
# 4                   axon-messaging-5.0.1
# 5                   axon-messaging-5.0.1
# 6            axon-server-connector-5.0.1
# 7                   axon-messaging-5.0.1
# 8                      axon-update-5.0.1
# 9       axon-tracing-opentelemetry-5.0.1
# 10                  axon-messaging-5.0.1
# 11                  axon-messaging-5.0.1
# 12                 axon-conversion-5.0.1
# 13                 axon-conversion-5.0.1
# 14                     axon-common-5.0.1
# 15                  axon-messaging-5.0.1
# 16                     axon-update-5.0.1
# 17                  axon-messaging-5.0.1
# 18                  axon-messaging-5.0.1
# 19                  axon-messaging-5.0.1
# 20                       axon-test-5.0.1
# 21  axon-spring-boot-autoconfigure-5.0.1
# 22                  axon-messaging-5.0.1
# 23                  axon-messaging-5.0.1
# 24                  axon-messaging-5.0.1
# 25                  axon-messaging-5.0.1
# 26  axon-spring-boot-autoconfigure-5.0.1
# 27                  axon-messaging-5.0.1
# 28                     axon-update-5.0.1
# 29         axon-metrics-micrometer-5.0.1
#
#                              fullQualifiedPackageName    packageName  \
# 0   org.axonframework.extension.springboot.autoconfig     autoconfig
# 1              org.axonframework.extension.springboot     springboot
# 2        org.axonframework.axonserver.connector.event          event
# 3      org.axonframework.extension.metrics.micrometer     micrometer
# 4   org.axonframework.messaging.queryhandling.inte...   interception
# 5            org.axonframework.messaging.core.timeout        timeout
# 6      org.axonframework.axonserver.connector.command        command
# 7      org.axonframework.messaging.tracing.attributes     attributes
# 8                        org.axonframework.update.api            api
# 9   org.axonframework.extension.tracing.opentelemetry  opentelemetry
# 10  org.axonframework.messaging.monitoring.interce...   interception
# 11  org.axonframework.messaging.commandhandling.in...   interception
# 12             org.axonframework.conversion.converter      converter
# 13                  org.axonframework.conversion.json           json
# 14                 org.axonframework.common.lifecycle      lifecycle
# 15  org.axonframework.messaging.eventhandling.proc...            jpa
# 16                 org.axonframework.update.detection      detection
# 17  org.axonframework.messaging.eventhandling.inte...   interception
# 18  org.axonframework.messaging.eventhandling.proc...       inmemory
# 19  org.axonframework.messaging.core.configuration...     reflection
# 20                      org.axonframework.test.server         server
# 21  org.axonframework.extension.springboot.actuato...     axonserver
# 22  org.axonframework.messaging.eventhandling.proc...     annotation
# 23        org.axonframework.messaging.core.reflection     reflection
# 24  org.axonframework.messaging.core.unitofwork.an...     annotation
# 25     org.axonframework.messaging.core.configuration  configuration
# 26    org.axonframework.extension.springboot.util.jpa            jpa
# 27  org.axonframework.messaging.commandhandling.retry          retry
# 28                    org.axonframework.update.common         common
# 29  org.axonframework.extension.metrics.micrometer...      reservoir
#
#     abstractness  numberAbstractTypes  numberTypes
# 0            0.0                    0           34
# 1            0.0                    0           21
# 2            0.0                    0           14
# 3            0.0                    0           12
# 4            0.0                    0            8
# 5            0.0                    0            8
# 6            0.0                    0            6
# 7            0.0                    0            6
# 8            0.0                    0            6
# 9            0.0                    0            5
# 10           0.0                    0            5
# 11           0.0                    0            5
# 12           0.0                    0            5
# 13           0.0                    0            5
# 14           0.0                    0            5
# 15           0.0                    0            4
# 16           0.0                    0            4
# 17           0.0                    0            3
# 18           0.0                    0            3
# 19           0.0                    0            3
# 20           0.0                    0            2
# 21           0.0                    0            2
# 22           0.0                    0            2
# 23           0.0                    0            2
# 24           0.0                    0            2
# 25           0.0                    0            2
# 26           0.0                    0            1
# 27           0.0                    0            1
# 28           0.0                    0            1
# 29           0.0                    0            1

# %% [markdown]
# #### Table 4b
#
# - Show the top 30 packages with the highest *Abstractness* and number of Java Types

# %%
abstractness.sort_values(by=['abstractness', 'numberTypes'], ascending=[False, False]).head(30)
# Out:
#                              artifactName  \
# 141  axon-spring-boot-autoconfigure-5.0.1
# 142                  axon-messaging-5.0.1
# 139                  axon-messaging-5.0.1
# 140                  axon-messaging-5.0.1
# 138                  axon-messaging-5.0.1
# 137              axon-eventsourcing-5.0.1
# 135  axon-spring-boot-autoconfigure-5.0.1
# 136                  axon-messaging-5.0.1
# 134                  axon-modelling-5.0.1
# 133                     axon-common-5.0.1
# 132                  axon-modelling-5.0.1
# 126                  axon-messaging-5.0.1
# 127                     axon-common-5.0.1
# 128                  axon-messaging-5.0.1
# 129                  axon-messaging-5.0.1
# 130                  axon-messaging-5.0.1
# 131                     axon-common-5.0.1
# 125                     axon-common-5.0.1
# 123                  axon-messaging-5.0.1
# 124                  axon-messaging-5.0.1
# 122                  axon-messaging-5.0.1
# 121                       axon-test-5.0.1
# 120                  axon-messaging-5.0.1
# 118                  axon-modelling-5.0.1
# 119              axon-eventsourcing-5.0.1
# 117                  axon-messaging-5.0.1
# 114                  axon-messaging-5.0.1
# 115                  axon-messaging-5.0.1
# 116                  axon-messaging-5.0.1
# 113                  axon-messaging-5.0.1
#
#                               fullQualifiedPackageName      packageName  \
# 141    org.axonframework.extension.springboot.actuator         actuator
# 142  org.axonframework.messaging.eventhandling.proc...        streaming
# 139  org.axonframework.messaging.commandhandling.co...    configuration
# 140  org.axonframework.messaging.queryhandling.conf...    configuration
# 138  org.axonframework.messaging.eventhandling.conf...    configuration
# 137         org.axonframework.eventsourcing.annotation       annotation
# 135        org.axonframework.extension.springboot.util             util
# 136  org.axonframework.messaging.queryhandling.anno...       annotation
# 134             org.axonframework.modelling.repository       repository
# 133                      org.axonframework.common.jdbc             jdbc
# 132          org.axonframework.modelling.configuration    configuration
# 126  org.axonframework.messaging.core.unitofwork.tr...      transaction
# 127                org.axonframework.common.annotation       annotation
# 128  org.axonframework.messaging.eventhandling.conv...       conversion
# 129  org.axonframework.messaging.queryhandling.gateway          gateway
# 130        org.axonframework.messaging.core.conversion       conversion
# 131                       org.axonframework.common.jpa              jpa
# 125             org.axonframework.common.configuration    configuration
# 123        org.axonframework.messaging.commandhandling  commandhandling
# 124          org.axonframework.messaging.eventhandling    eventhandling
# 122  org.axonframework.messaging.core.interception....       annotation
# 121                     org.axonframework.test.fixture          fixture
# 120         org.axonframework.messaging.eventstreaming   eventstreaming
# 118           org.axonframework.modelling.entity.child            child
# 119                    org.axonframework.eventsourcing    eventsourcing
# 117          org.axonframework.messaging.queryhandling    queryhandling
# 114  org.axonframework.messaging.commandhandling.di...      distributed
# 115  org.axonframework.messaging.eventhandling.repl...       annotation
# 116  org.axonframework.messaging.eventhandling.gateway          gateway
# 113                org.axonframework.messaging.tracing          tracing
#
#      abstractness  numberAbstractTypes  numberTypes
# 141      1.000000                    1            1
# 142      1.000000                    1            1
# 139      0.750000                    3            4
# 140      0.750000                    3            4
# 138      0.714286                   10           14
# 137      0.700000                    7           10
# 135      0.571429                    4            7
# 136      0.571429                    4            7
# 134      0.555556                    5            9
# 133      0.545455                    6           11
# 132      0.538462                    7           13
# 126      0.500000                    2            4
# 127      0.500000                    2            4
# 128      0.500000                    1            2
# 129      0.500000                    1            2
# 130      0.500000                    1            2
# 131      0.500000                    1            2
# 125      0.478261                   22           46
# 123      0.473684                    9           19
# 124      0.473684                    9           19
# 122      0.454545                    5           11
# 121      0.451613                   14           31
# 120      0.437500                    7           16
# 118      0.428571                    6           14
# 119      0.428571                    3            7
# 117      0.416667                   10           24
# 114      0.400000                    4           10
# 115      0.400000                    4           10
# 116      0.400000                    2            5
# 113      0.384615                    5           13

# %% [markdown]
# #### Table 4c
#
# - Show the top 30 packages including their sub-packages with the highest package depth and lowest *Abstractness*
# - Set the property "abstractnessIncludingSubpackages" on Package nodes.

# %%
abstractnessIncludingSubpackages = query_first_non_empty_cypher_to_data_frame("../cypher/Metrics/Get_Abstractness_for_Java_including_Subpackages.cypher",
                                                                              "../cypher/Metrics/Calculate_and_set_Abstractness_for_Java_including_Subpackages.cypher")
abstractnessIncludingSubpackages.head(30)
# Out:
#                             artifactName  \
# 0          axon-metrics-micrometer-5.0.1
# 1                   axon-messaging-5.0.1
# 2   axon-spring-boot-autoconfigure-5.0.1
# 3            axon-server-connector-5.0.1
# 4                   axon-messaging-5.0.1
# 5                   axon-messaging-5.0.1
# 6            axon-server-connector-5.0.1
# 7                   axon-messaging-5.0.1
# 8                      axon-update-5.0.1
# 9       axon-tracing-opentelemetry-5.0.1
# 10                  axon-messaging-5.0.1
# 11                  axon-messaging-5.0.1
# 12                 axon-conversion-5.0.1
# 13                 axon-conversion-5.0.1
# 14                     axon-common-5.0.1
# 15                  axon-messaging-5.0.1
# 16                     axon-update-5.0.1
# 17                  axon-messaging-5.0.1
# 18                  axon-messaging-5.0.1
# 19                  axon-messaging-5.0.1
# 20                       axon-test-5.0.1
# 21  axon-spring-boot-autoconfigure-5.0.1
# 22                  axon-messaging-5.0.1
# 23                  axon-messaging-5.0.1
# 24                  axon-messaging-5.0.1
# 25  axon-spring-boot-autoconfigure-5.0.1
# 26                  axon-messaging-5.0.1
# 27                     axon-update-5.0.1
# 28         axon-metrics-micrometer-5.0.1
# 29                     axon-common-5.0.1
#
#                              fullQualifiedPackageName    packageName  \
# 0      org.axonframework.extension.metrics.micrometer     micrometer
# 1      org.axonframework.messaging.core.configuration  configuration
# 2   org.axonframework.extension.springboot.autoconfig     autoconfig
# 3        org.axonframework.axonserver.connector.event          event
# 4   org.axonframework.messaging.queryhandling.inte...   interception
# 5            org.axonframework.messaging.core.timeout        timeout
# 6      org.axonframework.axonserver.connector.command        command
# 7      org.axonframework.messaging.tracing.attributes     attributes
# 8                        org.axonframework.update.api            api
# 9   org.axonframework.extension.tracing.opentelemetry  opentelemetry
# 10  org.axonframework.messaging.monitoring.interce...   interception
# 11  org.axonframework.messaging.commandhandling.in...   interception
# 12             org.axonframework.conversion.converter      converter
# 13                  org.axonframework.conversion.json           json
# 14                 org.axonframework.common.lifecycle      lifecycle
# 15  org.axonframework.messaging.eventhandling.proc...            jpa
# 16                 org.axonframework.update.detection      detection
# 17  org.axonframework.messaging.eventhandling.inte...   interception
# 18  org.axonframework.messaging.eventhandling.proc...       inmemory
# 19  org.axonframework.messaging.core.configuration...     reflection
# 20                      org.axonframework.test.server         server
# 21  org.axonframework.extension.springboot.actuato...     axonserver
# 22  org.axonframework.messaging.eventhandling.proc...     annotation
# 23        org.axonframework.messaging.core.reflection     reflection
# 24  org.axonframework.messaging.core.unitofwork.an...     annotation
# 25    org.axonframework.extension.springboot.util.jpa            jpa
# 26  org.axonframework.messaging.commandhandling.retry          retry
# 27                    org.axonframework.update.common         common
# 28  org.axonframework.extension.metrics.micrometer...      reservoir
# 29                        org.axonframework.common.io             io
#
#     abstractness  numberAbstractTypes  numberTypes  maxSubpackageDepth
# 0            0.0                    0           13                   1
# 1            0.0                    0            5                   1
# 2            0.0                    0           34                   0
# 3            0.0                    0           14                   0
# 4            0.0                    0            8                   0
# 5            0.0                    0            8                   0
# 6            0.0                    0            6                   0
# 7            0.0                    0            6                   0
# 8            0.0                    0            6                   0
# 9            0.0                    0            5                   0
# 10           0.0                    0            5                   0
# 11           0.0                    0            5                   0
# 12           0.0                    0            5                   0
# 13           0.0                    0            5                   0
# 14           0.0                    0            5                   0
# 15           0.0                    0            4                   0
# 16           0.0                    0            4                   0
# 17           0.0                    0            3                   0
# 18           0.0                    0            3                   0
# 19           0.0                    0            3                   0
# 20           0.0                    0            2                   0
# 21           0.0                    0            2                   0
# 22           0.0                    0            2                   0
# 23           0.0                    0            2                   0
# 24           0.0                    0            2                   0
# 25           0.0                    0            1                   0
# 26           0.0                    0            1                   0
# 27           0.0                    0            1                   0
# 28           0.0                    0            1                   0
# 29           0.0                    0            1                   0

# %% [markdown]
# #### Table 4d
#
# - Show the top 30 packages including their sub-packages with the highest package depth and highest *Abstractness*

# %%
abstractnessIncludingSubpackages.sort_values(by=['abstractness', 'maxSubpackageDepth', 'numberTypes'], ascending=[False, False, False]).head(30)
# Out:
#                              artifactName  \
# 112                  axon-messaging-5.0.1
# 113                  axon-messaging-5.0.1
# 111                  axon-messaging-5.0.1
# 110                  axon-messaging-5.0.1
# 109              axon-eventsourcing-5.0.1
# 108                  axon-modelling-5.0.1
# 107                     axon-common-5.0.1
# 106                  axon-modelling-5.0.1
# 99   axon-spring-boot-autoconfigure-5.0.1
# 100                  axon-messaging-5.0.1
# 101                     axon-common-5.0.1
# 102                  axon-messaging-5.0.1
# 103                  axon-messaging-5.0.1
# 104                  axon-messaging-5.0.1
# 105                     axon-common-5.0.1
# 98                      axon-common-5.0.1
# 97                   axon-messaging-5.0.1
# 96                        axon-test-5.0.1
# 95                   axon-messaging-5.0.1
# 94                   axon-modelling-5.0.1
# 91                   axon-messaging-5.0.1
# 92                   axon-messaging-5.0.1
# 93                   axon-messaging-5.0.1
# 90                   axon-messaging-5.0.1
# 89                   axon-modelling-5.0.1
# 87                   axon-messaging-5.0.1
# 88                   axon-messaging-5.0.1
# 86                   axon-messaging-5.0.1
# 84                   axon-messaging-5.0.1
# 85                   axon-messaging-5.0.1
#
#                               fullQualifiedPackageName      packageName  \
# 112  org.axonframework.messaging.commandhandling.co...    configuration
# 113  org.axonframework.messaging.queryhandling.conf...    configuration
# 111  org.axonframework.messaging.eventhandling.conf...    configuration
# 110  org.axonframework.messaging.queryhandling.anno...       annotation
# 109         org.axonframework.eventsourcing.annotation       annotation
# 108             org.axonframework.modelling.repository       repository
# 107                      org.axonframework.common.jdbc             jdbc
# 106          org.axonframework.modelling.configuration    configuration
# 99         org.axonframework.extension.springboot.util             util
# 100  org.axonframework.messaging.core.unitofwork.tr...      transaction
# 101                org.axonframework.common.annotation       annotation
# 102  org.axonframework.messaging.eventhandling.conv...       conversion
# 103  org.axonframework.messaging.queryhandling.gateway          gateway
# 104        org.axonframework.messaging.core.conversion       conversion
# 105                       org.axonframework.common.jpa              jpa
# 98              org.axonframework.common.configuration    configuration
# 97   org.axonframework.messaging.core.interception....       annotation
# 96                      org.axonframework.test.fixture          fixture
# 95          org.axonframework.messaging.eventstreaming   eventstreaming
# 94            org.axonframework.modelling.entity.child            child
# 91   org.axonframework.messaging.commandhandling.di...      distributed
# 92   org.axonframework.messaging.eventhandling.repl...       annotation
# 93   org.axonframework.messaging.eventhandling.gateway          gateway
# 90           org.axonframework.messaging.queryhandling    queryhandling
# 89                         org.axonframework.modelling        modelling
# 87         org.axonframework.messaging.commandhandling  commandhandling
# 88   org.axonframework.messaging.commandhandling.ga...          gateway
# 86   org.axonframework.messaging.eventhandling.anno...       annotation
# 84         org.axonframework.messaging.core.unitofwork       unitofwork
# 85   org.axonframework.messaging.queryhandling.dist...      distributed
#
#      abstractness  numberAbstractTypes  numberTypes  maxSubpackageDepth
# 112      0.750000                    3            4                   0
# 113      0.750000                    3            4                   0
# 111      0.714286                   10           14                   0
# 110      0.571429                    4            7                   0
# 109      0.562500                    9           16                   1
# 108      0.555556                    5            9                   0
# 107      0.545455                    6           11                   0
# 106      0.538462                    7           13                   0
# 99       0.500000                    4            8                   1
# 100      0.500000                    2            4                   0
# 101      0.500000                    2            4                   0
# 102      0.500000                    1            2                   0
# 103      0.500000                    1            2                   0
# 104      0.500000                    1            2                   0
# 105      0.500000                    1            2                   0
# 98       0.478261                   22           46                   0
# 97       0.454545                    5           11                   0
# 96       0.451613                   14           31                   0
# 95       0.437500                    7           16                   0
# 94       0.428571                    6           14                   0
# 91       0.400000                    4           10                   0
# 92       0.400000                    4           10                   0
# 93       0.400000                    2            5                   0
# 90       0.380952                   24           63                   1
# 89       0.376344                   35           93                   2
# 87       0.375000                   24           64                   1
# 88       0.375000                    3            8                   0
# 86       0.368421                    7           19                   0
# 84       0.363636                    8           22                   1
# 85       0.363636                    4           11                   0

# %% [markdown]
# ## Distance from the main sequence
#
# The *main sequence* is a imaginary line that represents a good compromise between *Abstractness* and *Instability*. A high distance to this line may indicate problems. For example is very *stable* (rigid) code with low abstractness hard to change.
#
# Read more details on that in [OO Design Quality Metrics](https://api.semanticscholar.org/CorpusID:18246616) and [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html).
#
# #### Table 5a
#
# - Show the top 30 packages with the highest distance from the "main sequence"

# %%
instabilityPerAbstractness = query_cypher_to_data_frame("../cypher/Metrics/Calculate_distance_between_abstractness_and_instability_for_Java.cypher")
instabilityPerAbstractness.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.1
# 1                  axon-conversion-5.0.1
# 2                   axon-messaging-5.0.1
# 3   axon-spring-boot-autoconfigure-5.0.1
# 4                   axon-messaging-5.0.1
# 5          axon-metrics-micrometer-5.0.1
# 6                      axon-common-5.0.1
# 7                      axon-common-5.0.1
# 8            axon-server-connector-5.0.1
# 9            axon-server-connector-5.0.1
# 10           axon-server-connector-5.0.1
# 11                       axon-test-5.0.1
# 12                       axon-test-5.0.1
# 13      axon-tracing-opentelemetry-5.0.1
# 14      axon-tracing-opentelemetry-5.0.1
# 15      axon-tracing-opentelemetry-5.0.1
# 16      axon-tracing-opentelemetry-5.0.1
# 17  axon-spring-boot-autoconfigure-5.0.1
# 18  axon-spring-boot-autoconfigure-5.0.1
# 19  axon-spring-boot-autoconfigure-5.0.1
# 20  axon-spring-boot-autoconfigure-5.0.1
# 21                  axon-modelling-5.0.1
# 22                  axon-modelling-5.0.1
# 23                  axon-messaging-5.0.1
# 24                  axon-messaging-5.0.1
# 25                  axon-messaging-5.0.1
# 26                 axon-conversion-5.0.1
# 27                 axon-conversion-5.0.1
# 28                     axon-update-5.0.1
# 29                     axon-update-5.0.1
#
#                                     fullQualifiedName           name  \
# 0      org.axonframework.messaging.tracing.attributes     attributes
# 1              org.axonframework.conversion.converter      converter
# 2         org.axonframework.messaging.core.reflection     reflection
# 3     org.axonframework.extension.springboot.actuator       actuator
# 4   org.axonframework.messaging.commandhandling.retry          retry
# 5   org.axonframework.extension.metrics.micrometer...      reservoir
# 6                         org.axonframework.common.io             io
# 7                     org.axonframework.common.digest         digest
# 8                                                 org            org
# 9                                   org.axonframework  axonframework
# 10                       org.axonframework.axonserver     axonserver
# 11                                                org            org
# 12                                  org.axonframework  axonframework
# 13                                                org            org
# 14                                  org.axonframework  axonframework
# 15                        org.axonframework.extension      extension
# 16                org.axonframework.extension.tracing        tracing
# 17                                                org            org
# 18                                  org.axonframework  axonframework
# 19                        org.axonframework.extension      extension
# 20     org.axonframework.extension.springboot.service        service
# 21                                                org            org
# 22                                  org.axonframework  axonframework
# 23                                                org            org
# 24                                  org.axonframework  axonframework
# 25                        org.axonframework.messaging      messaging
# 26                                                org            org
# 27                                  org.axonframework  axonframework
# 28                                                org            org
# 29                                  org.axonframework  axonframework
#
#     distance  abstractness  instability  elementsCount
# 0        NaN           0.0          NaN              6
# 1        NaN           0.0          NaN              5
# 2        NaN           0.0          NaN              2
# 3        NaN           1.0          NaN              1
# 4        NaN           0.0          NaN              1
# 5        NaN           0.0          NaN              1
# 6        NaN           0.0          NaN              1
# 7        NaN           0.0          NaN              1
# 8        NaN           0.0          NaN              0
# 9        NaN           0.0          NaN              0
# 10       NaN           0.0          NaN              0
# 11       NaN           0.0          NaN              0
# 12       NaN           0.0          NaN              0
# 13       NaN           0.0          NaN              0
# 14       NaN           0.0          NaN              0
# 15       NaN           0.0          NaN              0
# 16       NaN           0.0          NaN              0
# 17       NaN           0.0          NaN              0
# 18       NaN           0.0          NaN              0
# 19       NaN           0.0          NaN              0
# 20       NaN           0.0          NaN              0
# 21       NaN           0.0          NaN              0
# 22       NaN           0.0          NaN              0
# 23       NaN           0.0          NaN              0
# 24       NaN           0.0          NaN              0
# 25       NaN           0.0          NaN              0
# 26       NaN           0.0          NaN              0
# 27       NaN           0.0          NaN              0
# 28       NaN           0.0          NaN              0
# 29       NaN           0.0          NaN              0

# %% [markdown]
# #### Table 5b
#
# - Show the top 30 packages including their sub-packages with the highest distance from the "main sequence"

# %%
instabilityPerAbstractnessIncludingSubpackages = query_cypher_to_data_frame("../cypher/Metrics/Calculate_distance_between_abstractness_and_instability_for_Java_including_subpackages.cypher")
instabilityPerAbstractnessIncludingSubpackages.head(30)
# Out:
#                             artifactName  \
# 0                      axon-common-5.0.1
# 1                  axon-conversion-5.0.1
# 2                      axon-common-5.0.1
# 3                   axon-messaging-5.0.1
# 4                   axon-messaging-5.0.1
# 5                      axon-update-5.0.1
# 6                   axon-messaging-5.0.1
# 7                        axon-test-5.0.1
# 8                   axon-messaging-5.0.1
# 9                   axon-messaging-5.0.1
# 10                     axon-common-5.0.1
# 11                  axon-messaging-5.0.1
# 12                  axon-messaging-5.0.1
# 13                     axon-common-5.0.1
# 14                     axon-update-5.0.1
# 15  axon-spring-boot-autoconfigure-5.0.1
# 16                     axon-update-5.0.1
# 17                     axon-common-5.0.1
# 18              axon-eventsourcing-5.0.1
# 19                  axon-messaging-5.0.1
# 20                  axon-messaging-5.0.1
# 21                  axon-messaging-5.0.1
# 22                     axon-common-5.0.1
# 23                  axon-modelling-5.0.1
# 24  axon-spring-boot-autoconfigure-5.0.1
# 25                  axon-messaging-5.0.1
# 26                  axon-messaging-5.0.1
# 27                  axon-messaging-5.0.1
# 28                  axon-messaging-5.0.1
# 29                  axon-messaging-5.0.1
#
#                                     fullQualifiedName             name  \
# 0                  org.axonframework.common.lifecycle        lifecycle
# 1                        org.axonframework.conversion       conversion
# 2                      org.axonframework.common.infra            infra
# 3   org.axonframework.messaging.eventhandling.proc...            token
# 4                    org.axonframework.messaging.core             core
# 5                        org.axonframework.update.api              api
# 6   org.axonframework.messaging.queryhandling.conf...    configuration
# 7                       org.axonframework.test.server           server
# 8   org.axonframework.messaging.commandhandling.co...    configuration
# 9         org.axonframework.messaging.core.unitofwork       unitofwork
# 10                      org.axonframework.common.util             util
# 11                org.axonframework.messaging.tracing          tracing
# 12  org.axonframework.messaging.queryhandling.anno...       annotation
# 13             org.axonframework.common.configuration    configuration
# 14                 org.axonframework.update.detection        detection
# 15    org.axonframework.extension.springboot.util.jpa              jpa
# 16                    org.axonframework.update.common           common
# 17                org.axonframework.common.annotation       annotation
# 18         org.axonframework.eventsourcing.annotation       annotation
# 19          org.axonframework.messaging.eventhandling    eventhandling
# 20        org.axonframework.messaging.core.annotation       annotation
# 21  org.axonframework.messaging.eventhandling.proc...    errorhandling
# 22                  org.axonframework.common.property         property
# 23          org.axonframework.modelling.configuration    configuration
# 24  org.axonframework.extension.springboot.actuato...       axonserver
# 25  org.axonframework.messaging.queryhandling.gateway          gateway
# 26         org.axonframework.messaging.eventstreaming   eventstreaming
# 27  org.axonframework.messaging.eventhandling.conf...    configuration
# 28        org.axonframework.messaging.commandhandling  commandhandling
# 29        org.axonframework.messaging.core.conversion       conversion
#
#     distance  abstractness  instability  elementsCount
# 0   0.833333      0.000000     0.166667              5
# 1   0.775399      0.166667     0.057935             30
# 2   0.745844      0.250000     0.004156              8
# 3   0.718425      0.129032     0.152542             31
# 4   0.694106      0.284404     0.021490            218
# 5   0.684211      0.000000     0.315789              6
# 6   0.671053      0.750000     0.921053              4
# 7   0.666667      0.000000     0.333333              2
# 8   0.666667      0.750000     0.916667              4
# 9   0.621277      0.363636     0.015087             22
# 10  0.575758      0.333333     0.090909              6
# 11  0.530960      0.263158     0.205882             19
# 12  0.522648      0.571429     0.951220              7
# 13  0.500469      0.478261     0.021270             46
# 14  0.500000      0.000000     0.500000              4
# 15  0.500000      0.000000     0.500000              1
# 16  0.500000      0.000000     0.500000              1
# 17  0.498915      0.500000     0.001085              4
# 18  0.473214      0.562500     0.910714             16
# 19  0.444532      0.315789     0.239678            171
# 20  0.441538      0.320000     0.238462             50
# 21  0.435897      0.333333     0.230769              3
# 22  0.416667      0.333333     0.250000              9
# 23  0.415174      0.538462     0.876712             13
# 24  0.400000      0.000000     0.600000              2
# 25  0.400000      0.500000     0.900000              2
# 26  0.399457      0.437500     0.163043             16
# 27  0.377269      0.714286     0.662983             14
# 28  0.363294      0.375000     0.261706             64
# 29  0.363014      0.500000     0.136986              2

# %% [markdown]
# ### *Abstractness* vs. *Instability* Plot with "Main Sequence" line as reference
#
# - Plot *Abstractness* vs. *Instability* of all packages
# - Draw the "main sequence" as dashed green diagonal line
# - Scale the packages by the number of types they contain
# - Color the packages by their distance to the "main sequence" (blue=near, red=far)

# %%
# Function that returns the number of past (index smaller than given index) rows 
# with the same value in columnName1 and columnName2
# If there was a row with the same columnName1 and columnName2 values
# def countPastEntriesWithSameValues(dataFrame, index, columnName1, columnName2):
#     columnValue1 = dataFrame[columnName1][index]
#     columnValue2 = dataFrame[columnName2][index]
#     return len(dataFrame[
#         (dataFrame.index.isin(range(0, index + 1))) & 
#         (dataFrame[columnName1]==columnValue1) & 
#         (dataFrame[columnName2]==columnValue2)
#     ]) - 1

# %%
def annotate_plot(data_frame: pd.DataFrame, index: int):
    """
    Annotates the data points identified by the "index" in the plot of the "data_frame" 
    """
    x_position = data_frame.abstractness[index].item()
    y_position = data_frame.instability[index].item()
    artifact_name = data_frame.artifactName[index].item()
    package_name = data_frame.name[index].item()

    label_box=dict(boxstyle="round4,pad=0.5", fc="w", alpha=0.8)
    plot.annotate(artifact_name + '\n' + package_name
        ,xy=(x_position, y_position)
        ,xycoords='data'
        ,xytext=(20, 0)
        ,textcoords='offset points'
        ,size=6
        ,bbox=label_box
        ,arrowprops=dict(arrowstyle="-|>", mutation_scale=10, color="black")
    )

def index_of_sorted(data_frame: pd.DataFrame, highest: list[str] = []):
    """
    Sorts the "data_frame" by columns 'abstractness','instability','elementsCount', 'artifactName'
    and returns the index of the first row.
    Columns that are contained in the list of strings parameter "highest" will be sorted descending.
    """
    by = ['abstractness','instability','elementsCount','artifactName']
    ascending = [('abstractness' not in highest), ('instability' not in highest), False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

def index_of_highest_property(data_frame: pd.DataFrame, highest: str):
    """
    Sorts the "data_frame" by the property given in input parameter "highest" descending
    and returns the index of the first row.
    """
    by = [highest,'artifactName']
    ascending = [False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

# %%
from  matplotlib.colors import LinearSegmentedColormap

def plot_instability_per_abstractness_with_main_sequence(data_frame: pd.DataFrame, subtitle: str = ''):
    """
    Prints the so called "Main Sequence" as green dotted diagonal line as a reference.
    On top of that every Java Package is plotted as a data point:
     - The X-axis is the "Abstractness" where 0 = all classes to 1 = all interfaces and abstract classes
     - The Y-axis is the "Instability" where 0 = stable (many incoming dependencies) and 1 instable (no incoming dependencies)
     - The size reflects the number of contained Java Types
     - The color reflects the distance to the "Main Sequence"
    """
        
    colormap=LinearSegmentedColormap.from_list('rg',["green", "gold", "orangered", "red"], N=256) 
    marker_scales_bounded=data_frame.elementsCount.clip(lower=2, upper=300) * 0.7

    plot.scatter(
        data_frame.abstractness, # x axis shows abstractness
        data_frame.instability, # y axis shows instability
        s=marker_scales_bounded, # scale depends on number of contained types
        c=data_frame.distance, # color depends on distance to the main sequence
        cmap=colormap, #'bwr' # colormap that prints high values in red and lower values in blue
        alpha=0.5,
    )
    # green "main sequence" line
    plot.plot([0,1], [1,0], c='lightgreen', linestyle='dashed') 

    # Annotate largest package
    annotate_plot(data_frame, index_of_highest_property(data_frame, highest='elementsCount'))
    # Annotate largest package with the highest abstractness and instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['abstractness','instability']))
    # Annotate largest package with the lowest abstractness and highest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['instability']))
    # Annotate largest package with the lowest abstractness and lowest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=[]))
    # Annotate largest package with the highest abstractness and lowest instability
    annotate_plot(data_frame, index_of_sorted(data_frame, highest=['abstractness']))
    # Annotate largest packages with the highest abstractness and instability near 0.5% 
    annotation_index = index_of_sorted(highest=['abstractness', 'instability'], data_frame=data_frame.query('abstractness <= 0.4 & instability <= 0.4'))
    annotate_plot(data_frame, annotation_index)

    plot.title('Abstractness vs. Instability ("Main Sequence")\n' + subtitle)
    plot.xlabel('Abstractness')
    plot.ylabel('Instability')
    plot.show()

# %% [markdown]
# #### Figure 5a - Packages without their sub-packages

# %%
if not instabilityPerAbstractness.empty:
   plot_instability_per_abstractness_with_main_sequence(instabilityPerAbstractness, 'Packages without their sub-packages')

# %% [markdown]
# #### Figure 5b - Packages including their sub-packages

# %%
if not instabilityPerAbstractnessIncludingSubpackages.empty:
   plot_instability_per_abstractness_with_main_sequence(instabilityPerAbstractnessIncludingSubpackages, 'Packages including their sub-packages')
