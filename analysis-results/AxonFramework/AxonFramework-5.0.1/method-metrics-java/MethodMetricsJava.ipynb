# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())
    

def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-5.0.1.jar  axon-common-5.0.1.jar  \
# effectiveLineCount
# 1                                       1937                    350
# 2                                        502                    139
# 3                                        423                     88
# 4                                        189                     39
# 5                                        146                     36
# 6                                         86                     36
# 7                                         69                     14
# 8                                         66                     17
# 9                                         41                     11
# 10                                        26                      6
# 11                                        19                      7
# 12                                         7                      7
# 13                                        10                      5
# 14                                         6                      5
# 15                                         5                      1
# 16                                         7                      2
# 17                                         3                      3
# 18                                         1                      1
# 19                                         3                      0
# 20                                         2                      0
# 21                                         1                      0
# 22                                         3                      0
# 23                                         1                      0
# 24                                         0                      1
# 25                                         2                      0
# 26                                         1                      1
# 27                                         1                      0
# 28                                         0                      0
# 29                                         0                      0
# 30                                         1                      0
# 31                                         0                      0
# 36                                         1                      0
# 40                                         0                      0
# 41                                         0                      0
# 42                                         0                      0
# 45                                         0                      0
# 77                                         1                      0
#
# artifactName        axon-server-connector-5.0.1.jar  \
# effectiveLineCount
# 1                                               266
# 2                                               143
# 3                                                77
# 4                                                43
# 5                                                34
# 6                                                14
# 7                                                 9
# 8                                                15
# 9                                                11
# 10                                                7
# 11                                                2
# 12                                                3
# 13                                                2
# 14                                                2
# 15                                                1
# 16                                                1
# 17                                                2
# 18                                                1
# 19                                                0
# 20                                                1
# 21                                                2
# 22                                                0
# 23                                                0
# 24                                                0
# 25                                                0
# 26                                                0
# 27                                                0
# 28                                                1
# 29                                                0
# 30                                                1
# 31                                                0
# 36                                                0
# 40                                                0
# 41                                                0
# 42                                                1
# 45                                                0
# 77                                                0
#
# artifactName        axon-eventsourcing-5.0.1.jar  axon-test-5.0.1.jar  \
# effectiveLineCount
# 1                                            302                  203
# 2                                             74                   69
# 3                                             57                   32
# 4                                             54                   37
# 5                                             28                    4
# 6                                             19                   14
# 7                                             15                    8
# 8                                              4                    7
# 9                                             11                    7
# 10                                             6                    2
# 11                                             5                    3
# 12                                             4                    7
# 13                                             4                    3
# 14                                             2                    3
# 15                                             2                    1
# 16                                             1                    3
# 17                                             1                    0
# 18                                             0                    2
# 19                                             1                    0
# 20                                             1                    2
# 21                                             1                    1
# 22                                             0                    0
# 23                                             0                    1
# 24                                             0                    0
# 25                                             0                    0
# 26                                             0                    1
# 27                                             1                    0
# 28                                             0                    0
# 29                                             0                    0
# 30                                             1                    0
# 31                                             0                    1
# 36                                             0                    0
# 40                                             1                    0
# 41                                             0                    0
# 42                                             0                    0
# 45                                             0                    1
# 77                                             0                    0
#
# artifactName        axon-modelling-5.0.1.jar  \
# effectiveLineCount
# 1                                        175
# 2                                         56
# 3                                         30
# 4                                         36
# 5                                         23
# 6                                         18
# 7                                          9
# 8                                          9
# 9                                         13
# 10                                         3
# 11                                         2
# 12                                         4
# 13                                         5
# 14                                         1
# 15                                         1
# 16                                         1
# 17                                         2
# 18                                         2
# 19                                         0
# 20                                         0
# 21                                         1
# 22                                         0
# 23                                         0
# 24                                         0
# 25                                         0
# 26                                         0
# 27                                         0
# 28                                         0
# 29                                         0
# 30                                         0
# 31                                         0
# 36                                         0
# 40                                         0
# 41                                         0
# 42                                         0
# 45                                         0
# 77                                         0
#
# artifactName        axon-spring-boot-autoconfigure-5.0.1.jar  \
# effectiveLineCount
# 1                                                        173
# 2                                                         77
# 3                                                         16
# 4                                                          6
# 5                                                          9
# 6                                                          6
# 7                                                          5
# 8                                                          2
# 9                                                          2
# 10                                                         1
# 11                                                         0
# 12                                                         1
# 13                                                         1
# 14                                                         0
# 15                                                         0
# 16                                                         0
# 17                                                         1
# 18                                                         0
# 19                                                         0
# 20                                                         0
# 21                                                         0
# 22                                                         0
# 23                                                         1
# 24                                                         0
# 25                                                         0
# 26                                                         0
# 27                                                         0
# 28                                                         0
# 29                                                         1
# 30                                                         0
# 31                                                         0
# 36                                                         0
# 40                                                         0
# 41                                                         0
# 42                                                         0
# 45                                                         0
# 77                                                         0
#
# artifactName        axon-conversion-5.0.1.jar  axon-update-5.0.1.jar  \
# effectiveLineCount
# 1                                         101                     88
# 2                                          20                     10
# 3                                          12                      6
# 4                                           8                     10
# 5                                           9                      8
# 6                                           7                      8
# 7                                           5                      2
# 8                                           5                      2
# 9                                           4                      4
# 10                                          1                      2
# 11                                          2                      0
# 12                                          0                      1
# 13                                          1                      3
# 14                                          0                      2
# 15                                          1                      0
# 16                                          2                      1
# 17                                          1                      2
# 18                                          0                      1
# 19                                          1                      0
# 20                                          0                      0
# 21                                          0                      2
# 22                                          0                      0
# 23                                          0                      0
# 24                                          0                      1
# 25                                          0                      0
# 26                                          0                      0
# 27                                          0                      0
# 28                                          0                      0
# 29                                          1                      0
# 30                                          1                      0
# 31                                          0                      0
# 36                                          0                      0
# 40                                          0                      0
# 41                                          0                      1
# 42                                          0                      0
# 45                                          0                      0
# 77                                          0                      0
#
# artifactName        axon-metrics-micrometer-5.0.1.jar  \
# effectiveLineCount
# 1                                                  34
# 2                                                  17
# 3                                                  15
# 4                                                   6
# 5                                                   2
# 6                                                   4
# 7                                                   4
# 8                                                   5
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                                  3
# 14                                                  0
# 15                                                  1
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 36                                                  0
# 40                                                  0
# 41                                                  0
# 42                                                  0
# 45                                                  0
# 77                                                  0
#
# artifactName        axon-tracing-opentelemetry-5.0.1.jar
# effectiveLineCount
# 1                                                     11
# 2                                                      4
# 3                                                     10
# 4                                                      7
# 5                                                      2
# 6                                                      3
# 7                                                      2
# 8                                                      0
# 9                                                      1
# 10                                                     0
# 11                                                     0
# 12                                                     1
# 13                                                     0
# 14                                                     0
# 15                                                     0
# 16                                                     0
# 17                                                     0
# 18                                                     0
# 19                                                     0
# 20                                                     0
# 21                                                     0
# 22                                                     0
# 23                                                     0
# 24                                                     0
# 25                                                     0
# 26                                                     0
# 27                                                     0
# 28                                                     0
# 29                                                     0
# 30                                                     0
# 31                                                     0
# 36                                                     0
# 40                                                     0
# 41                                                     0
# 42                                                     0
# 45                                                     0
# 77                                                     0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-5.0.1.jar  axon-common-5.0.1.jar  \
# effectiveLineCount
# 1                                  54.410112              45.513654
# 2                                  14.101124              18.075423
# 3                                  11.882022              11.443433
# 4                                   5.308989               5.071521
# 5                                   4.101124               4.681404
# 6                                   2.415730               4.681404
# 7                                   1.938202               1.820546
# 8                                   1.853933               2.210663
# 9                                   1.151685               1.430429
# 10                                  0.730337               0.780234
# 11                                  0.533708               0.910273
# 12                                  0.196629               0.910273
# 13                                  0.280899               0.650195
# 14                                  0.168539               0.650195
# 15                                  0.140449               0.130039
# 16                                  0.196629               0.260078
# 17                                  0.084270               0.390117
# 18                                  0.028090               0.130039
# 19                                  0.084270               0.000000
# 20                                  0.056180               0.000000
# 21                                  0.028090               0.000000
# 22                                  0.084270               0.000000
# 23                                  0.028090               0.000000
# 24                                  0.000000               0.130039
# 25                                  0.056180               0.000000
# 26                                  0.028090               0.130039
# 27                                  0.028090               0.000000
# 28                                  0.000000               0.000000
# 29                                  0.000000               0.000000
# 30                                  0.028090               0.000000
# 31                                  0.000000               0.000000
# 36                                  0.028090               0.000000
# 40                                  0.000000               0.000000
# 41                                  0.000000               0.000000
# 42                                  0.000000               0.000000
# 45                                  0.000000               0.000000
# 77                                  0.028090               0.000000
#
# artifactName        axon-server-connector-5.0.1.jar  \
# effectiveLineCount
# 1                                         41.627543
# 2                                         22.378717
# 3                                         12.050078
# 4                                          6.729264
# 5                                          5.320814
# 6                                          2.190923
# 7                                          1.408451
# 8                                          2.347418
# 9                                          1.721440
# 10                                         1.095462
# 11                                         0.312989
# 12                                         0.469484
# 13                                         0.312989
# 14                                         0.312989
# 15                                         0.156495
# 16                                         0.156495
# 17                                         0.312989
# 18                                         0.156495
# 19                                         0.000000
# 20                                         0.156495
# 21                                         0.312989
# 22                                         0.000000
# 23                                         0.000000
# 24                                         0.000000
# 25                                         0.000000
# 26                                         0.000000
# 27                                         0.000000
# 28                                         0.156495
# 29                                         0.000000
# 30                                         0.156495
# 31                                         0.000000
# 36                                         0.000000
# 40                                         0.000000
# 41                                         0.000000
# 42                                         0.156495
# 45                                         0.000000
# 77                                         0.000000
#
# artifactName        axon-eventsourcing-5.0.1.jar  axon-test-5.0.1.jar  \
# effectiveLineCount
# 1                                      50.756303            49.271845
# 2                                      12.436975            16.747573
# 3                                       9.579832             7.766990
# 4                                       9.075630             8.980583
# 5                                       4.705882             0.970874
# 6                                       3.193277             3.398058
# 7                                       2.521008             1.941748
# 8                                       0.672269             1.699029
# 9                                       1.848739             1.699029
# 10                                      1.008403             0.485437
# 11                                      0.840336             0.728155
# 12                                      0.672269             1.699029
# 13                                      0.672269             0.728155
# 14                                      0.336134             0.728155
# 15                                      0.336134             0.242718
# 16                                      0.168067             0.728155
# 17                                      0.168067             0.000000
# 18                                      0.000000             0.485437
# 19                                      0.168067             0.000000
# 20                                      0.168067             0.485437
# 21                                      0.168067             0.242718
# 22                                      0.000000             0.000000
# 23                                      0.000000             0.242718
# 24                                      0.000000             0.000000
# 25                                      0.000000             0.000000
# 26                                      0.000000             0.242718
# 27                                      0.168067             0.000000
# 28                                      0.000000             0.000000
# 29                                      0.000000             0.000000
# 30                                      0.168067             0.000000
# 31                                      0.000000             0.242718
# 36                                      0.000000             0.000000
# 40                                      0.168067             0.000000
# 41                                      0.000000             0.000000
# 42                                      0.000000             0.000000
# 45                                      0.000000             0.242718
# 77                                      0.000000             0.000000
#
# artifactName        axon-modelling-5.0.1.jar  \
# effectiveLineCount
# 1                                  44.757033
# 2                                  14.322251
# 3                                   7.672634
# 4                                   9.207161
# 5                                   5.882353
# 6                                   4.603581
# 7                                   2.301790
# 8                                   2.301790
# 9                                   3.324808
# 10                                  0.767263
# 11                                  0.511509
# 12                                  1.023018
# 13                                  1.278772
# 14                                  0.255754
# 15                                  0.255754
# 16                                  0.255754
# 17                                  0.511509
# 18                                  0.511509
# 19                                  0.000000
# 20                                  0.000000
# 21                                  0.255754
# 22                                  0.000000
# 23                                  0.000000
# 24                                  0.000000
# 25                                  0.000000
# 26                                  0.000000
# 27                                  0.000000
# 28                                  0.000000
# 29                                  0.000000
# 30                                  0.000000
# 31                                  0.000000
# 36                                  0.000000
# 40                                  0.000000
# 41                                  0.000000
# 42                                  0.000000
# 45                                  0.000000
# 77                                  0.000000
#
# artifactName        axon-spring-boot-autoconfigure-5.0.1.jar  \
# effectiveLineCount
# 1                                                  57.284768
# 2                                                  25.496689
# 3                                                   5.298013
# 4                                                   1.986755
# 5                                                   2.980132
# 6                                                   1.986755
# 7                                                   1.655629
# 8                                                   0.662252
# 9                                                   0.662252
# 10                                                  0.331126
# 11                                                  0.000000
# 12                                                  0.331126
# 13                                                  0.331126
# 14                                                  0.000000
# 15                                                  0.000000
# 16                                                  0.000000
# 17                                                  0.331126
# 18                                                  0.000000
# 19                                                  0.000000
# 20                                                  0.000000
# 21                                                  0.000000
# 22                                                  0.000000
# 23                                                  0.331126
# 24                                                  0.000000
# 25                                                  0.000000
# 26                                                  0.000000
# 27                                                  0.000000
# 28                                                  0.000000
# 29                                                  0.331126
# 30                                                  0.000000
# 31                                                  0.000000
# 36                                                  0.000000
# 40                                                  0.000000
# 41                                                  0.000000
# 42                                                  0.000000
# 45                                                  0.000000
# 77                                                  0.000000
#
# artifactName        axon-conversion-5.0.1.jar  axon-update-5.0.1.jar  \
# effectiveLineCount
# 1                                   55.494505              57.142857
# 2                                   10.989011               6.493506
# 3                                    6.593407               3.896104
# 4                                    4.395604               6.493506
# 5                                    4.945055               5.194805
# 6                                    3.846154               5.194805
# 7                                    2.747253               1.298701
# 8                                    2.747253               1.298701
# 9                                    2.197802               2.597403
# 10                                   0.549451               1.298701
# 11                                   1.098901               0.000000
# 12                                   0.000000               0.649351
# 13                                   0.549451               1.948052
# 14                                   0.000000               1.298701
# 15                                   0.549451               0.000000
# 16                                   1.098901               0.649351
# 17                                   0.549451               1.298701
# 18                                   0.000000               0.649351
# 19                                   0.549451               0.000000
# 20                                   0.000000               0.000000
# 21                                   0.000000               1.298701
# 22                                   0.000000               0.000000
# 23                                   0.000000               0.000000
# 24                                   0.000000               0.649351
# 25                                   0.000000               0.000000
# 26                                   0.000000               0.000000
# 27                                   0.000000               0.000000
# 28                                   0.000000               0.000000
# 29                                   0.549451               0.000000
# 30                                   0.549451               0.000000
# 31                                   0.000000               0.000000
# 36                                   0.000000               0.000000
# 40                                   0.000000               0.000000
# 41                                   0.000000               0.649351
# 42                                   0.000000               0.000000
# 45                                   0.000000               0.000000
# 77                                   0.000000               0.000000
#
# artifactName        axon-metrics-micrometer-5.0.1.jar  \
# effectiveLineCount
# 1                                           36.956522
# 2                                           18.478261
# 3                                           16.304348
# 4                                            6.521739
# 5                                            2.173913
# 6                                            4.347826
# 7                                            4.347826
# 8                                            5.434783
# 9                                            1.086957
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           3.260870
# 14                                           0.000000
# 15                                           1.086957
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 36                                           0.000000
# 40                                           0.000000
# 41                                           0.000000
# 42                                           0.000000
# 45                                           0.000000
# 77                                           0.000000
#
# artifactName        axon-tracing-opentelemetry-5.0.1.jar
# effectiveLineCount
# 1                                              26.829268
# 2                                               9.756098
# 3                                              24.390244
# 4                                              17.073171
# 5                                               4.878049
# 6                                               7.317073
# 7                                               4.878049
# 8                                               0.000000
# 9                                               2.439024
# 10                                              0.000000
# 11                                              0.000000
# 12                                              2.439024
# 13                                              0.000000
# 14                                              0.000000
# 15                                              0.000000
# 16                                              0.000000
# 17                                              0.000000
# 18                                              0.000000
# 19                                              0.000000
# 20                                              0.000000
# 21                                              0.000000
# 22                                              0.000000
# 23                                              0.000000
# 24                                              0.000000
# 25                                              0.000000
# 26                                              0.000000
# 27                                              0.000000
# 28                                              0.000000
# 29                                              0.000000
# 30                                              0.000000
# 31                                              0.000000
# 36                                              0.000000
# 40                                              0.000000
# 41                                              0.000000
# 42                                              0.000000
# 45                                              0.000000
# 77                                              0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
if effective_method_line_count_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,20)
    axes = effective_method_line_count_distribution_normalized.head(20).plot(
        kind='line',
        logx=True,
        grid=True,
        xlim=[2, 20],
        ylim=[0, 20],
        xticks=method_line_count_x_ticks,
        title='Effective Method Line Count Distribution', 
        xlabel='effective line count',
        ylabel='percent of methods',
        cmap=main_color_map,
        figsize=(10, 6),
        lw=2,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.1
# 1                   axon-messaging-5.0.1
# 2                        axon-test-5.0.1
# 3                   axon-messaging-5.0.1
# 4            axon-server-connector-5.0.1
# 5                      axon-common-5.0.1
# 6                      axon-common-5.0.1
# 7               axon-eventsourcing-5.0.1
# 8            axon-server-connector-5.0.1
# 9               axon-eventsourcing-5.0.1
# 10                  axon-messaging-5.0.1
# 11                  axon-messaging-5.0.1
# 12                  axon-messaging-5.0.1
# 13           axon-server-connector-5.0.1
# 14                  axon-modelling-5.0.1
# 15                       axon-test-5.0.1
# 16  axon-spring-boot-autoconfigure-5.0.1
# 17                  axon-messaging-5.0.1
# 18                 axon-conversion-5.0.1
# 19         axon-metrics-micrometer-5.0.1
# 20                  axon-modelling-5.0.1
# 21                  axon-messaging-5.0.1
# 22  axon-spring-boot-autoconfigure-5.0.1
# 23                  axon-messaging-5.0.1
# 24                     axon-common-5.0.1
# 25                     axon-common-5.0.1
# 26                  axon-messaging-5.0.1
# 27                  axon-messaging-5.0.1
# 28                  axon-messaging-5.0.1
# 29                  axon-messaging-5.0.1
#
#                                       fullPackageName  linesInPackage  \
# 0   org.axonframework.messaging.eventhandling.proc...            1325
# 1                    org.axonframework.messaging.core            1119
# 2                      org.axonframework.test.fixture             719
# 3         org.axonframework.messaging.core.annotation             702
# 4              org.axonframework.axonserver.connector             698
# 5              org.axonframework.common.configuration             668
# 6                            org.axonframework.common             608
# 7          org.axonframework.eventsourcing.eventstore             591
# 8        org.axonframework.axonserver.connector.event             535
# 9      org.axonframework.eventsourcing.eventstore.jpa             455
# 10  org.axonframework.messaging.eventhandling.proc...             455
# 11          org.axonframework.messaging.queryhandling             381
# 12        org.axonframework.messaging.core.unitofwork             352
# 13       org.axonframework.axonserver.connector.query             325
# 14      org.axonframework.modelling.entity.annotation             321
# 15                    org.axonframework.test.matchers             318
# 16  org.axonframework.extension.springboot.autoconfig             307
# 17  org.axonframework.messaging.eventhandling.proc...             297
# 18                  org.axonframework.conversion.avro             292
# 19     org.axonframework.extension.metrics.micrometer             281
# 20                 org.axonframework.modelling.entity             268
# 21     org.axonframework.messaging.core.configuration             259
# 22             org.axonframework.extension.springboot             254
# 23  org.axonframework.messaging.eventhandling.proc...             253
# 24                   org.axonframework.common.caching             234
# 25                     org.axonframework.common.infra             233
# 26        org.axonframework.messaging.commandhandling             228
# 27  org.axonframework.messaging.eventhandling.proc...             224
# 28           org.axonframework.messaging.core.timeout             217
# 29          org.axonframework.messaging.eventhandling             207
#
#     methodCount  maxLinesMethod  \
# 0           393              77
# 1           531              16
# 2           202              45
# 3           235              23
# 4           278              42
# 5           262              26
# 6           182              24
# 7           232              19
# 8           161              21
# 9           138              20
# 10          130              25
# 11          172              14
# 12          172              21
# 13           90              21
# 14           75              18
# 15          101              21
# 16          131              29
# 17          115              12
# 18           81              30
# 19           87              15
# 20           76              18
# 21          120              19
# 22          140               9
# 23           96              19
# 24           85              13
# 25           56              14
# 26          101              18
# 27           50              22
# 28           56              16
# 29           84              11
#
#                                    maxLinesMethodName
# 0                                                 run
# 1                                             process
# 2                                 appendEventOverview
# 3                                              <init>
# 4                                               build
# 5                             invokeLifecycleHandlers
# 6   getExactDirectSuperTypesOfParameterizedTypeOrC...
# 7                                  createTagsForValue
# 8                               lambda$appendEvents$0
# 9                                     withGapsCleaned
# 10                                        updateToken
# 11                                             handle
# 12                                       runNextPhase
# 13                                convertQueryMessage
# 14                       createOptionalChildForMember
# 15                                     matchingFields
# 16                                     buildConverter
# 17                                         advancedTo
# 18                                            convert
# 19                             registerEventProcessor
# 20                                             <init>
# 21                                 registerComponents
# 22                                             <init>
# 23                                              split
# 24                          lambda$computeIfPresent$4
# 25                                   describeProperty
# 26                                             handle
# 27                                         storeToken
# 28                                             <init>
# 29                                             handle

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index                          artifactName  \
# 0       0                  axon-messaging-5.0.1
# 1       2                       axon-test-5.0.1
# 2       4           axon-server-connector-5.0.1
# 3      42                     axon-update-5.0.1
# 4      30              axon-eventsourcing-5.0.1
# 5      18                 axon-conversion-5.0.1
# 6      61              axon-eventsourcing-5.0.1
# 7      16  axon-spring-boot-autoconfigure-5.0.1
# 8      65                 axon-conversion-5.0.1
# 9       5                     axon-common-5.0.1
# 10     10                  axon-messaging-5.0.1
# 11      6                     axon-common-5.0.1
# 12     82  axon-spring-boot-autoconfigure-5.0.1
# 13      3                  axon-messaging-5.0.1
# 14     27                  axon-messaging-5.0.1
# 15      8           axon-server-connector-5.0.1
# 16     12                  axon-messaging-5.0.1
# 17     47                     axon-update-5.0.1
# 18     13           axon-server-connector-5.0.1
# 19     15                       axon-test-5.0.1
# 20     54                  axon-modelling-5.0.1
# 21     39                     axon-update-5.0.1
# 22     34           axon-server-connector-5.0.1
# 23      9              axon-eventsourcing-5.0.1
# 24     33                       axon-test-5.0.1
# 25     21                  axon-messaging-5.0.1
# 26     23                  axon-messaging-5.0.1
# 27      7              axon-eventsourcing-5.0.1
# 28     14                  axon-modelling-5.0.1
# 29     20                  axon-modelling-5.0.1
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.proc...
# 1                      org.axonframework.test.fixture
# 2              org.axonframework.axonserver.connector
# 3                  org.axonframework.update.detection
# 4   org.axonframework.eventsourcing.annotation.ref...
# 5                   org.axonframework.conversion.avro
# 6          org.axonframework.eventsourcing.annotation
# 7   org.axonframework.extension.springboot.autoconfig
# 8                   org.axonframework.conversion.json
# 9              org.axonframework.common.configuration
# 10  org.axonframework.messaging.eventhandling.proc...
# 11                           org.axonframework.common
# 12        org.axonframework.extension.springboot.util
# 13        org.axonframework.messaging.core.annotation
# 14  org.axonframework.messaging.eventhandling.proc...
# 15       org.axonframework.axonserver.connector.event
# 16        org.axonframework.messaging.core.unitofwork
# 17                       org.axonframework.update.api
# 18       org.axonframework.axonserver.connector.query
# 19                    org.axonframework.test.matchers
# 20             org.axonframework.modelling.annotation
# 21                           org.axonframework.update
# 22     org.axonframework.axonserver.connector.command
# 23     org.axonframework.eventsourcing.eventstore.jpa
# 24                      org.axonframework.test.server
# 25     org.axonframework.messaging.core.configuration
# 26  org.axonframework.messaging.eventhandling.proc...
# 27         org.axonframework.eventsourcing.eventstore
# 28      org.axonframework.modelling.entity.annotation
# 29                 org.axonframework.modelling.entity
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                                            Reporter
# 2                 AxonServerConnectionManager$Builder
# 3                             TestEnvironmentDetector
# 4            AnnotationBasedEventSourcedEntityFactory
# 5                                       AvroConverter
# 6   AnnotationBasedEventCriteriaResolver$WrappedEv...
# 7                          ConverterAutoConfiguration
# 8                                    JacksonConverter
# 9        DefaultAxonApplication$AxonConfigurationImpl
# 10                                     JdbcTokenStore
# 11                                TypeReflectionUtils
# 12                     AbstractQualifiedBeanCondition
# 13                MethodInvokingMessageHandlingMember
# 14                                      JpaTokenStore
# 15         AggregateBasedAxonServerEventStorageEngine
# 16             UnitOfWork$UnitOfWorkProcessingContext
# 17                                UpdateCheckResponse
# 18                                     QueryConverter
# 19                                  DeepEqualsMatcher
# 20             AnnotationBasedEntityEvolvingComponent
# 21                            UpdateCheckerHttpClient
# 22                                   CommandConverter
# 23                    GapAwareTrackingTokenOperations
# 24                           AxonServerContainerUtils
# 25                     MessagingConfigurationDefaults
# 26                                      TrackerStatus
# 27                         AnnotationBasedTagResolver
# 28                           AnnotatedEntityMetamodel
# 29                            ConcreteEntityMetamodel
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run              77
# 1                                 appendEventOverview              45
# 2                                               build              42
# 3                                         isTestClass              41
# 4                          addEntityCreatorExecutable              40
# 5                                             convert              30
# 6                                              <init>              30
# 7                                      buildConverter              29
# 8                                             convert              29
# 9                             invokeLifecycleHandlers              26
# 10                                        updateToken              25
# 11  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 12                                    getMatchOutcome              23
# 13                                             <init>              23
# 14                                         storeToken              22
# 15                              lambda$appendEvents$0              21
# 16                                       runNextPhase              21
# 17                                        fromRequest              21
# 18                                convertQueryMessage              21
# 19                                     matchingFields              21
# 20                                             evolve              21
# 21                                        sendRequest              21
# 22                               convertResultMessage              20
# 23                                    withGapsCleaned              20
# 24                                      createContext              20
# 25                                 registerComponents              19
# 26                                              split              19
# 27                                 createTagsForValue              19
# 28                       createOptionalChildForMember              18
# 29                                             <init>              18
#
#     linesInPackage
# 0             1325
# 1              719
# 2              698
# 3              163
# 4              197
# 5              292
# 6               97
# 7              307
# 8               86
# 9              668
# 10             455
# 11             608
# 12              46
# 13             702
# 14             224
# 15             535
# 16             352
# 17             143
# 18             325
# 19             318
# 20             120
# 21             169
# 22             186
# 23             455
# 24             195
# 25             259
# 26             253
# 27             591
# 28             321
# 29             268

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-5.0.1.jar  axon-common-5.0.1.jar  \
# cyclomaticComplexity
# 1                                         2938                    538
# 2                                          316                     89
# 3                                          147                     74
# 4                                           86                     31
# 5                                           29                     10
# 6                                           27                      7
# 7                                            9                      6
# 8                                            3                      8
# 9                                            1                      3
# 10                                           0                      1
# 11                                           1                      1
# 12                                           0                      1
# 13                                           1                      0
# 17                                           0                      0
# 21                                           0                      0
# 23                                           1                      0
# 41                                           0                      0
# 58                                           1                      0
#
# artifactName          axon-server-connector-5.0.1.jar  \
# cyclomaticComplexity
# 1                                                 536
# 2                                                  57
# 3                                                  25
# 4                                                   7
# 5                                                   5
# 6                                                   5
# 7                                                   1
# 8                                                   0
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  0
# 17                                                  0
# 21                                                  0
# 23                                                  0
# 41                                                  0
# 58                                                  0
#
# artifactName          axon-eventsourcing-5.0.1.jar  axon-test-5.0.1.jar  \
# cyclomaticComplexity
# 1                                              455                  312
# 2                                               63                   40
# 3                                               36                   32
# 4                                               17                    7
# 5                                                8                    9
# 6                                                6                    5
# 7                                                4                    2
# 8                                                4                    2
# 9                                                0                    1
# 10                                               0                    0
# 11                                               1                    1
# 12                                               0                    1
# 13                                               1                    0
# 17                                               0                    0
# 21                                               0                    0
# 23                                               0                    0
# 41                                               0                    0
# 58                                               0                    0
#
# artifactName          axon-modelling-5.0.1.jar  \
# cyclomaticComplexity
# 1                                          311
# 2                                           27
# 3                                           23
# 4                                           16
# 5                                            7
# 6                                            5
# 7                                            1
# 8                                            1
# 9                                            0
# 10                                           0
# 11                                           0
# 12                                           0
# 13                                           0
# 17                                           0
# 21                                           0
# 23                                           0
# 41                                           0
# 58                                           0
#
# artifactName          axon-spring-boot-autoconfigure-5.0.1.jar  \
# cyclomaticComplexity
# 1                                                          277
# 2                                                           12
# 3                                                            7
# 4                                                            2
# 5                                                            1
# 6                                                            0
# 7                                                            1
# 8                                                            0
# 9                                                            2
# 10                                                           0
# 11                                                           0
# 12                                                           0
# 13                                                           0
# 17                                                           0
# 21                                                           0
# 23                                                           0
# 41                                                           0
# 58                                                           0
#
# artifactName          axon-conversion-5.0.1.jar  axon-update-5.0.1.jar  \
# cyclomaticComplexity
# 1                                           137                    119
# 2                                            14                     16
# 3                                             8                      5
# 4                                            11                      1
# 5                                             2                      3
# 6                                             3                      4
# 7                                             2                      2
# 8                                             1                      0
# 9                                             1                      1
# 10                                            1                      0
# 11                                            0                      1
# 12                                            0                      0
# 13                                            0                      0
# 17                                            1                      1
# 21                                            1                      0
# 23                                            0                      0
# 41                                            0                      1
# 58                                            0                      0
#
# artifactName          axon-metrics-micrometer-5.0.1.jar  \
# cyclomaticComplexity
# 1                                                    86
# 2                                                     3
# 3                                                     1
# 4                                                     0
# 5                                                     0
# 6                                                     2
# 7                                                     0
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 12                                                    0
# 13                                                    0
# 17                                                    0
# 21                                                    0
# 23                                                    0
# 41                                                    0
# 58                                                    0
#
# artifactName          axon-tracing-opentelemetry-5.0.1.jar
# cyclomaticComplexity
# 1                                                       30
# 2                                                        8
# 3                                                        2
# 4                                                        1
# 5                                                        0
# 6                                                        0
# 7                                                        0
# 8                                                        0
# 9                                                        0
# 10                                                       0
# 11                                                       0
# 12                                                       0
# 13                                                       0
# 17                                                       0
# 21                                                       0
# 23                                                       0
# 41                                                       0
# 58                                                       0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-5.0.1.jar  axon-common-5.0.1.jar  \
# cyclomaticComplexity
# 1                                    82.528090              69.960988
# 2                                     8.876404              11.573472
# 3                                     4.129213               9.622887
# 4                                     2.415730               4.031209
# 5                                     0.814607               1.300390
# 6                                     0.758427               0.910273
# 7                                     0.252809               0.780234
# 8                                     0.084270               1.040312
# 9                                     0.028090               0.390117
# 10                                    0.000000               0.130039
# 11                                    0.028090               0.130039
# 12                                    0.000000               0.130039
# 13                                    0.028090               0.000000
# 17                                    0.000000               0.000000
# 21                                    0.000000               0.000000
# 23                                    0.028090               0.000000
# 41                                    0.000000               0.000000
# 58                                    0.028090               0.000000
#
# artifactName          axon-server-connector-5.0.1.jar  \
# cyclomaticComplexity
# 1                                           83.881064
# 2                                            8.920188
# 3                                            3.912363
# 4                                            1.095462
# 5                                            0.782473
# 6                                            0.782473
# 7                                            0.156495
# 8                                            0.000000
# 9                                            0.312989
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.156495
# 13                                           0.000000
# 17                                           0.000000
# 21                                           0.000000
# 23                                           0.000000
# 41                                           0.000000
# 58                                           0.000000
#
# artifactName          axon-eventsourcing-5.0.1.jar  axon-test-5.0.1.jar  \
# cyclomaticComplexity
# 1                                        76.470588            75.728155
# 2                                        10.588235             9.708738
# 3                                         6.050420             7.766990
# 4                                         2.857143             1.699029
# 5                                         1.344538             2.184466
# 6                                         1.008403             1.213592
# 7                                         0.672269             0.485437
# 8                                         0.672269             0.485437
# 9                                         0.000000             0.242718
# 10                                        0.000000             0.000000
# 11                                        0.168067             0.242718
# 12                                        0.000000             0.242718
# 13                                        0.168067             0.000000
# 17                                        0.000000             0.000000
# 21                                        0.000000             0.000000
# 23                                        0.000000             0.000000
# 41                                        0.000000             0.000000
# 58                                        0.000000             0.000000
#
# artifactName          axon-modelling-5.0.1.jar  \
# cyclomaticComplexity
# 1                                    79.539642
# 2                                     6.905371
# 3                                     5.882353
# 4                                     4.092072
# 5                                     1.790281
# 6                                     1.278772
# 7                                     0.255754
# 8                                     0.255754
# 9                                     0.000000
# 10                                    0.000000
# 11                                    0.000000
# 12                                    0.000000
# 13                                    0.000000
# 17                                    0.000000
# 21                                    0.000000
# 23                                    0.000000
# 41                                    0.000000
# 58                                    0.000000
#
# artifactName          axon-spring-boot-autoconfigure-5.0.1.jar  \
# cyclomaticComplexity
# 1                                                    91.721854
# 2                                                     3.973510
# 3                                                     2.317881
# 4                                                     0.662252
# 5                                                     0.331126
# 6                                                     0.000000
# 7                                                     0.331126
# 8                                                     0.000000
# 9                                                     0.662252
# 10                                                    0.000000
# 11                                                    0.000000
# 12                                                    0.000000
# 13                                                    0.000000
# 17                                                    0.000000
# 21                                                    0.000000
# 23                                                    0.000000
# 41                                                    0.000000
# 58                                                    0.000000
#
# artifactName          axon-conversion-5.0.1.jar  axon-update-5.0.1.jar  \
# cyclomaticComplexity
# 1                                     75.274725              77.272727
# 2                                      7.692308              10.389610
# 3                                      4.395604               3.246753
# 4                                      6.043956               0.649351
# 5                                      1.098901               1.948052
# 6                                      1.648352               2.597403
# 7                                      1.098901               1.298701
# 8                                      0.549451               0.000000
# 9                                      0.549451               0.649351
# 10                                     0.549451               0.000000
# 11                                     0.000000               0.649351
# 12                                     0.000000               0.000000
# 13                                     0.000000               0.000000
# 17                                     0.549451               0.649351
# 21                                     0.549451               0.000000
# 23                                     0.000000               0.000000
# 41                                     0.000000               0.649351
# 58                                     0.000000               0.000000
#
# artifactName          axon-metrics-micrometer-5.0.1.jar  \
# cyclomaticComplexity
# 1                                             93.478261
# 2                                              3.260870
# 3                                              1.086957
# 4                                              0.000000
# 5                                              0.000000
# 6                                              2.173913
# 7                                              0.000000
# 8                                              0.000000
# 9                                              0.000000
# 10                                             0.000000
# 11                                             0.000000
# 12                                             0.000000
# 13                                             0.000000
# 17                                             0.000000
# 21                                             0.000000
# 23                                             0.000000
# 41                                             0.000000
# 58                                             0.000000
#
# artifactName          axon-tracing-opentelemetry-5.0.1.jar
# cyclomaticComplexity
# 1                                                73.170732
# 2                                                19.512195
# 3                                                 4.878049
# 4                                                 2.439024
# 5                                                 0.000000
# 6                                                 0.000000
# 7                                                 0.000000
# 8                                                 0.000000
# 9                                                 0.000000
# 10                                                0.000000
# 11                                                0.000000
# 12                                                0.000000
# 13                                                0.000000
# 17                                                0.000000
# 21                                                0.000000
# 23                                                0.000000
# 41                                                0.000000
# 58                                                0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
if cyclomatic_method_complexity_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,11)
    cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
    axes = cyclomatic_method_complexity_distribution_normalized.plot(
        kind='line', 
        logx=True,
        logy=True,
        grid=True,
        xlim=[1,11],
        ylim=[1,100],
        xticks=method_line_count_x_ticks,
        yticks=cyclomatic_complexity_y_ticks,
        title='Cyclomatic complexity distribution of methods', 
        xlabel='cyclomatic complexity',
        ylabel='percentage of methods',
        cmap=main_color_map,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.set_yticklabels(cyclomatic_complexity_y_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                             artifactName  \
# 1                   axon-messaging-5.0.1
# 0                   axon-messaging-5.0.1
# 6                      axon-common-5.0.1
# 7               axon-eventsourcing-5.0.1
# 3                   axon-messaging-5.0.1
# 5                      axon-common-5.0.1
# 4            axon-server-connector-5.0.1
# 2                        axon-test-5.0.1
# 12                  axon-messaging-5.0.1
# 17                  axon-messaging-5.0.1
# 11                  axon-messaging-5.0.1
# 8            axon-server-connector-5.0.1
# 9               axon-eventsourcing-5.0.1
# 10                  axon-messaging-5.0.1
# 16  axon-spring-boot-autoconfigure-5.0.1
# 15                       axon-test-5.0.1
# 18                 axon-conversion-5.0.1
# 23                  axon-messaging-5.0.1
# 24                     axon-common-5.0.1
# 40                  axon-messaging-5.0.1
# 22  axon-spring-boot-autoconfigure-5.0.1
# 21                  axon-messaging-5.0.1
# 14                  axon-modelling-5.0.1
# 13           axon-server-connector-5.0.1
# 26                  axon-messaging-5.0.1
# 20                  axon-modelling-5.0.1
# 43                  axon-messaging-5.0.1
# 29                  axon-messaging-5.0.1
# 19         axon-metrics-micrometer-5.0.1
# 27                  axon-messaging-5.0.1
#
#                                       fullPackageName  complexityInPackage  \
# 1                    org.axonframework.messaging.core                  731
# 0   org.axonframework.messaging.eventhandling.proc...                  539
# 6                            org.axonframework.common                  383
# 7          org.axonframework.eventsourcing.eventstore                  371
# 3         org.axonframework.messaging.core.annotation                  371
# 5              org.axonframework.common.configuration                  358
# 4              org.axonframework.axonserver.connector                  357
# 2                      org.axonframework.test.fixture                  318
# 12        org.axonframework.messaging.core.unitofwork                  228
# 17  org.axonframework.messaging.eventhandling.proc...                  217
# 11          org.axonframework.messaging.queryhandling                  216
# 8        org.axonframework.axonserver.connector.event                  215
# 9      org.axonframework.eventsourcing.eventstore.jpa                  212
# 10  org.axonframework.messaging.eventhandling.proc...                  196
# 16  org.axonframework.extension.springboot.autoconfig                  175
# 15                    org.axonframework.test.matchers                  173
# 18                  org.axonframework.conversion.avro                  159
# 23  org.axonframework.messaging.eventhandling.proc...                  149
# 24                   org.axonframework.common.caching                  147
# 40  org.axonframework.messaging.eventhandling.anno...                  143
# 22             org.axonframework.extension.springboot                  143
# 21     org.axonframework.messaging.core.configuration                  132
# 14      org.axonframework.modelling.entity.annotation                  130
# 13       org.axonframework.axonserver.connector.query                  127
# 26        org.axonframework.messaging.commandhandling                  120
# 20                 org.axonframework.modelling.entity                  119
# 43         org.axonframework.messaging.eventstreaming                  119
# 29          org.axonframework.messaging.eventhandling                  104
# 19     org.axonframework.extension.metrics.micrometer                   99
# 27  org.axonframework.messaging.eventhandling.proc...                   98
#
#     methodCount  maxComplexity               maxComplexityMethod
# 1           531              9                           process
# 0           393             23                               run
# 6           182              9               fieldNameFromMember
# 7           232              8                              from
# 3           235             13                   resolveToStream
# 5           262              8                      hasComponent
# 4           278             12                             build
# 2           202             11               appendEventOverview
# 12          172              6                      runNextPhase
# 17          115              7                            equals
# 11          172              4                subscribeToUpdates
# 8           161              4                      appendEvents
# 9           138              8                   withGapsCleaned
# 10          130              8                       updateToken
# 16          131              9       registerHandlerInterceptors
# 15          101              8                       matchesList
# 18           81             21                           convert
# 23           96              8                       isDifferent
# 24           85              8                           onEvent
# 40           59             58                    parseParameter
# 22          140              2                       threadCount
# 21          120              4      lambda$registerDecorators$10
# 14           75              6         getExpectedRepresentation
# 13           90              6                     sendResponses
# 26          101              4                            handle
# 20           76              7                    handleInstance
# 43           92              4                                or
# 29           84              4                       andMetadata
# 19           87              6  registerComponentWithDefaultTags
# 27           50              6                            equals

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index                          artifactName  \
# 0      40                  axon-messaging-5.0.1
# 1      42                     axon-update-5.0.1
# 2       0                  axon-messaging-5.0.1
# 3      18                 axon-conversion-5.0.1
# 4      65                 axon-conversion-5.0.1
# 5      47                     axon-update-5.0.1
# 6      30              axon-eventsourcing-5.0.1
# 7       3                  axon-messaging-5.0.1
# 8      33                       axon-test-5.0.1
# 9       4           axon-server-connector-5.0.1
# 10     51                     axon-common-5.0.1
# 11      2                       axon-test-5.0.1
# 12     61              axon-eventsourcing-5.0.1
# 13     53                     axon-common-5.0.1
# 14     16  axon-spring-boot-autoconfigure-5.0.1
# 15      1                  axon-messaging-5.0.1
# 16      6                     axon-common-5.0.1
# 17     24                     axon-common-5.0.1
# 18      7              axon-eventsourcing-5.0.1
# 19     15                       axon-test-5.0.1
# 20     10                  axon-messaging-5.0.1
# 21      9              axon-eventsourcing-5.0.1
# 22     23                  axon-messaging-5.0.1
# 23      5                     axon-common-5.0.1
# 24     68                     axon-common-5.0.1
# 25     36                  axon-modelling-5.0.1
# 26     64                     axon-update-5.0.1
# 27     72                     axon-common-5.0.1
# 28     52                  axon-messaging-5.0.1
# 29     20                  axon-modelling-5.0.1
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.anno...
# 1                  org.axonframework.update.detection
# 2   org.axonframework.messaging.eventhandling.proc...
# 3                   org.axonframework.conversion.avro
# 4                   org.axonframework.conversion.json
# 5                        org.axonframework.update.api
# 6   org.axonframework.eventsourcing.annotation.ref...
# 7         org.axonframework.messaging.core.annotation
# 8                       org.axonframework.test.server
# 9              org.axonframework.axonserver.connector
# 10                      org.axonframework.common.jdbc
# 11                     org.axonframework.test.fixture
# 12         org.axonframework.eventsourcing.annotation
# 13                      org.axonframework.common.lock
# 14  org.axonframework.extension.springboot.autoconfig
# 15                   org.axonframework.messaging.core
# 16                           org.axonframework.common
# 17                   org.axonframework.common.caching
# 18         org.axonframework.eventsourcing.eventstore
# 19                    org.axonframework.test.matchers
# 20  org.axonframework.messaging.eventhandling.proc...
# 21     org.axonframework.eventsourcing.eventstore.jpa
# 22  org.axonframework.messaging.eventhandling.proc...
# 23             org.axonframework.common.configuration
# 24                org.axonframework.common.annotation
# 25           org.axonframework.modelling.entity.child
# 26             org.axonframework.update.configuration
# 27                      org.axonframework.common.util
# 28  org.axonframework.messaging.commandhandling.an...
# 29                 org.axonframework.modelling.entity
#
#                                     maxComplexityType  \
# 0   MethodSequencingPolicyEventHandlerDefinition$S...
# 1                             TestEnvironmentDetector
# 2                        Coordinator$CoordinationTask
# 3                                       AvroConverter
# 4                                    JacksonConverter
# 5                                 UpdateCheckResponse
# 6            AnnotationBasedEventSourcedEntityFactory
# 7                          MessageStreamResolverUtils
# 8                                 AxonServerContainer
# 9                 AxonServerConnectionManager$Builder
# 10                           ConnectionWrapperFactory
# 11                                           Reporter
# 12  AnnotationBasedEventCriteriaResolver$WrappedEv...
# 13              PessimisticLockFactory$DisposableLock
# 14                       InterceptorAutoConfiguration
# 15                         MessageStreamUtils$Reducer
# 16                                    ReflectionUtils
# 17           EhCacheAdapter$CacheEventListenerAdapter
# 18                    AggregateBasedConsistencyMarker
# 19                                    SequenceMatcher
# 20                                     JdbcTokenStore
# 21                    GapAwareTrackingTokenOperations
# 22                                 EventTrackerStatus
# 23                           DefaultComponentRegistry
# 24                                    AnnotationUtils
# 25                    FieldChildEntityFieldDefinition
# 26                  PropertyFileUsagePropertyProvider
# 27                                   PriorityRunnable
# 28  MethodCommandHandlerDefinition$MethodCommandHa...
# 29                            ConcreteEntityMetamodel
#
#               maxComplexityMethod  maxComplexity
# 0                  parseParameter             58
# 1                     isTestClass             41
# 2                             run             23
# 3                         convert             21
# 4                         convert             17
# 5                     fromRequest             17
# 6      addEntityCreatorExecutable             13
# 7                 resolveToStream             13
# 8                          equals             12
# 9                           build             12
# 10                  lambda$wrap$0             12
# 11            appendEventOverview             11
# 12                         <init>             11
# 13                           lock             10
# 14    registerHandlerInterceptors              9
# 15                        process              9
# 16            fieldNameFromMember              9
# 17                        onEvent              8
# 18                           from              8
# 19                    matchesList              8
# 20                    updateToken              8
# 21                withGapsCleaned              8
# 22                    isDifferent              8
# 23                   hasComponent              8
# 24              collectAttributes              8
# 25  evolveParentBasedOnChildInput              8
# 26                           load              7
# 27                         equals              7
# 28                         <init>              7
# 29                 handleInstance              7
