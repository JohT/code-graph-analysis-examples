# %% [markdown]
# # Internal Dependencies
# <br>
#
# ### References
# - [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html)
# - [Calculate metrics](https://101.jqassistant.org/calculate-metrics/index.html)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(cypher_file_name : str):
    with open(cypher_file_name) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename : str, limit: int = -1):
    """
    Execute the Cypher query of the given file and returns the result.
    filename : str : The name of the file containing the Cypher query
    limit : int : The optional limit of rows to optimize the query. Default = -1 = no limit
    """
    cypher_query = get_cypher_query_from_file(filename)
    if limit > 0:
        cypher_query = "{query}\nLIMIT {row_limit}".format(query = cypher_query, row_limit = limit)
    records, summary, keys = driver.execute_query(cypher_query)
    return pd.DataFrame([r.values() for r in records], columns=keys)


def query_first_non_empty_cypher_to_data_frame(*filenames : str, limit: int = -1):
    """
    Executes the Cypher queries of the given files and returns the first result that is not empty.
    If all given file names result in empty results, the last (empty) result will be returned.
    By additionally specifying "limit=" the "LIMIT" keyword will appended to query so that only the first results get returned.
    """    
    result=pd.DataFrame()
    for filename in filenames:
        result=query_cypher_to_data_frame(filename, limit)
        if not result.empty:
            return result
    return result

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Pandas DataFrame Display Configuration
pd.set_option('display.max_colwidth', 300)

# %% [markdown]
# ## Artifacts
#
# List the artifacts this notebook is based on. Different sorting variations help finding artifacts by their features and support larger code bases where the list of all artifacts gets too long.
#
# Only the top 30 entries are shown. The whole table can be found in the following CSV report:
# `List_all_Java_artifacts`

# %%
artifacts = query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_all_Java_artifacts.cypher")

# %% [markdown]
# ### Table 1a - Top 30 artifacts with the highest package count

# %%
# Sort by number of packages descending
artifacts.sort_values(by=['packages','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.2.jar        57    570
# 1                      axon-common-5.0.2.jar        15    156
# 2               axon-eventsourcing-5.0.2.jar         8    104
# 3                   axon-modelling-5.0.2.jar         7     93
# 4   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 5            axon-server-connector-5.0.2.jar         5     72
# 6                        axon-test-5.0.2.jar         5     73
# 7                      axon-update-5.0.2.jar         5     23
# 8                  axon-conversion-5.0.2.jar         4     30
# 9          axon-metrics-micrometer-5.0.2.jar         2     13
# 10      axon-tracing-opentelemetry-5.0.2.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      0                     7
# 5                      1                     4
# 6                      1                     3
# 7                      1                     1
# 8                      4                     1
# 9                      0                     2
# 10                     0                     2

# %% [markdown]
# ### Table 1b - Top 30 artifacts with the highest type count

# %%
# Sort by number of types descending
artifacts.sort_values(by=['types','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                   axon-messaging-5.0.2.jar        57    570
# 1                      axon-common-5.0.2.jar        15    156
# 2               axon-eventsourcing-5.0.2.jar         8    104
# 3                   axon-modelling-5.0.2.jar         7     93
# 4                        axon-test-5.0.2.jar         5     73
# 5            axon-server-connector-5.0.2.jar         5     72
# 6   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 7                  axon-conversion-5.0.2.jar         4     30
# 8                      axon-update-5.0.2.jar         5     23
# 9          axon-metrics-micrometer-5.0.2.jar         2     13
# 10      axon-tracing-opentelemetry-5.0.2.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                      7                     2
# 1                     10                     0
# 2                      3                     4
# 3                      2                     3
# 4                      1                     3
# 5                      1                     4
# 6                      0                     7
# 7                      4                     1
# 8                      1                     1
# 9                      0                     2
# 10                     0                     2

# %% [markdown]
# ### Table 1c - Top 30 artifacts with the highest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the most by other artifacts (highest count of incoming dependencies, highest in-degree).

# %%
# Sort by number of incoming dependencies descending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.2.jar        15    156
# 1                   axon-messaging-5.0.2.jar        57    570
# 2                  axon-conversion-5.0.2.jar         4     30
# 3               axon-eventsourcing-5.0.2.jar         8    104
# 4                   axon-modelling-5.0.2.jar         7     93
# 5            axon-server-connector-5.0.2.jar         5     72
# 6                        axon-test-5.0.2.jar         5     73
# 7                      axon-update-5.0.2.jar         5     23
# 8          axon-metrics-micrometer-5.0.2.jar         2     13
# 9   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 10      axon-tracing-opentelemetry-5.0.2.jar         1      5
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      7                     2
# 2                      4                     1
# 3                      3                     4
# 4                      2                     3
# 5                      1                     4
# 6                      1                     3
# 7                      1                     1
# 8                      0                     2
# 9                      0                     7
# 10                     0                     2

# %% [markdown]
# ### Table 1d - Top 30 artifacts with the highest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the highest number of other artifacts (highest count of outgoing dependencies, highest out-degree).

# %%
# Sort by number of outgoing dependencies descending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[False, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 1               axon-eventsourcing-5.0.2.jar         8    104
# 2            axon-server-connector-5.0.2.jar         5     72
# 3                   axon-modelling-5.0.2.jar         7     93
# 4                        axon-test-5.0.2.jar         5     73
# 5                   axon-messaging-5.0.2.jar        57    570
# 6          axon-metrics-micrometer-5.0.2.jar         2     13
# 7       axon-tracing-opentelemetry-5.0.2.jar         1      5
# 8                  axon-conversion-5.0.2.jar         4     30
# 9                      axon-update-5.0.2.jar         5     23
# 10                     axon-common-5.0.2.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     7
# 1                      3                     4
# 2                      1                     4
# 3                      2                     3
# 4                      1                     3
# 5                      7                     2
# 6                      0                     2
# 7                      0                     2
# 8                      4                     1
# 9                      1                     1
# 10                    10                     0

# %% [markdown]
# ### Table 1e - Top 30 artifacts with the lowest package count

# %%
# Sort by number of packages ascending
artifacts.sort_values(by=['packages','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.2.jar         1      5
# 1          axon-metrics-micrometer-5.0.2.jar         2     13
# 2                  axon-conversion-5.0.2.jar         4     30
# 3            axon-server-connector-5.0.2.jar         5     72
# 4                        axon-test-5.0.2.jar         5     73
# 5                      axon-update-5.0.2.jar         5     23
# 6                   axon-modelling-5.0.2.jar         7     93
# 7   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 8               axon-eventsourcing-5.0.2.jar         8    104
# 9                      axon-common-5.0.2.jar        15    156
# 10                  axon-messaging-5.0.2.jar        57    570
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     2
# 2                      4                     1
# 3                      1                     4
# 4                      1                     3
# 5                      1                     1
# 6                      2                     3
# 7                      0                     7
# 8                      3                     4
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1f - Top 30 artifacts with the lowest type count

# %%
# Sort by number of types ascending
artifacts.sort_values(by=['types','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0       axon-tracing-opentelemetry-5.0.2.jar         1      5
# 1          axon-metrics-micrometer-5.0.2.jar         2     13
# 2                      axon-update-5.0.2.jar         5     23
# 3                  axon-conversion-5.0.2.jar         4     30
# 4            axon-server-connector-5.0.2.jar         5     72
# 5   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 6                        axon-test-5.0.2.jar         5     73
# 7                   axon-modelling-5.0.2.jar         7     93
# 8               axon-eventsourcing-5.0.2.jar         8    104
# 9                      axon-common-5.0.2.jar        15    156
# 10                  axon-messaging-5.0.2.jar        57    570
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     2
# 2                      1                     1
# 3                      4                     1
# 4                      1                     4
# 5                      0                     7
# 6                      1                     3
# 7                      2                     3
# 8                      3                     4
# 9                     10                     0
# 10                     7                     2

# %% [markdown]
# ### Table 1g - Top 30 artifacts with the lowest number of incoming dependencies
#
# The following table lists the top 30 artifacts that are used the least by other artifacts (lowest count of incoming dependencies, lowest in-degree).

# %%
# Sort by number of incoming dependencies ascending
artifacts.sort_values(by=['incomingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0          axon-metrics-micrometer-5.0.2.jar         2     13
# 1   axon-spring-boot-autoconfigure-5.0.2.jar         7     72
# 2       axon-tracing-opentelemetry-5.0.2.jar         1      5
# 3            axon-server-connector-5.0.2.jar         5     72
# 4                        axon-test-5.0.2.jar         5     73
# 5                      axon-update-5.0.2.jar         5     23
# 6                   axon-modelling-5.0.2.jar         7     93
# 7               axon-eventsourcing-5.0.2.jar         8    104
# 8                  axon-conversion-5.0.2.jar         4     30
# 9                   axon-messaging-5.0.2.jar        57    570
# 10                     axon-common-5.0.2.jar        15    156
#
#     incomingDependencies  outgoingDependencies
# 0                      0                     2
# 1                      0                     7
# 2                      0                     2
# 3                      1                     4
# 4                      1                     3
# 5                      1                     1
# 6                      2                     3
# 7                      3                     4
# 8                      4                     1
# 9                      7                     2
# 10                    10                     0

# %% [markdown]
# ### Table 1h - Top 30 artifacts with the lowest number of outgoing dependencies
#
# The following table lists the top 30 artifacts that are depending on the lowest number of other artifacts (lowest count of outgoing dependencies, lowest out-degree).

# %%
# Sort by number of outgoing dependencies ascending
artifacts.sort_values(by=['outgoingDependencies','artifactName'], ascending=[True, True]).reset_index(drop=True).head(30)
# Out:
#                                 artifactName  packages  types  \
# 0                      axon-common-5.0.2.jar        15    156
# 1                  axon-conversion-5.0.2.jar         4     30
# 2                      axon-update-5.0.2.jar         5     23
# 3                   axon-messaging-5.0.2.jar        57    570
# 4          axon-metrics-micrometer-5.0.2.jar         2     13
# 5       axon-tracing-opentelemetry-5.0.2.jar         1      5
# 6                   axon-modelling-5.0.2.jar         7     93
# 7                        axon-test-5.0.2.jar         5     73
# 8               axon-eventsourcing-5.0.2.jar         8    104
# 9            axon-server-connector-5.0.2.jar         5     72
# 10  axon-spring-boot-autoconfigure-5.0.2.jar         7     72
#
#     incomingDependencies  outgoingDependencies
# 0                     10                     0
# 1                      4                     1
# 2                      1                     1
# 3                      7                     2
# 4                      0                     2
# 5                      0                     2
# 6                      2                     3
# 7                      1                     3
# 8                      3                     4
# 9                      1                     4
# 10                     0                     7

# %% [markdown]
# ## Cyclic Dependencies
#
# Cyclic dependencies occur when one package uses a class of another package and vice versa.
# These dependencies can lead to problems when one of these packages needs to be changed.

# %% [markdown]
# ## Table 2a - Cyclic Dependencies Overview
#
# Show the top 40 cyclic dependencies sorted by the most promising to resolve first. This is done by calculating the number of forward dependencies (first cycle participant to second cycle participant) in relation to backward dependencies (second cycle participant back to first cycle participant). The higher this rate (approaching 1), the easier it should be to resolve the cycle by focussing on the few backward dependencies.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies`
#
# **Columns:**
# - *artifactName* identifies the artifact of the first participant of the cycle
# - *packageName* identifies the package of the first participant of the cycle
# - *dependentArtifactName* identifies the artifact of the second participant of the cycle
# - *dependentPackageName* identifies the package of the second participant of the cycle
# - *forwardToBackwardBalance* is between 0 and 1. High for many forward and few backward dependencies.
# - *numberForward* contains the number of dependencies from the first participant of the cycle to the second one
# - *numberBackward* contains the number of dependencies from the second participant of the cycle back to the first one
# - *someForwardDependencies* lists some forward dependencies in the text format "type1 -> type2"
# - *backwardDependencies* lists the backward dependencies in the format "type1 <- type2" that are recommended to get resolved

# %%
cyclic_dependencies = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies.cypher")
cyclic_dependencies.head(40)
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.2
# 1          axon-messaging-5.0.2
# 2          axon-messaging-5.0.2
# 3          axon-messaging-5.0.2
# 4          axon-messaging-5.0.2
# 5          axon-modelling-5.0.2
# 6          axon-messaging-5.0.2
# 7          axon-messaging-5.0.2
# 8          axon-messaging-5.0.2
# 9             axon-common-5.0.2
# 10         axon-messaging-5.0.2
# 11  axon-server-connector-5.0.2
# 12  axon-server-connector-5.0.2
# 13         axon-messaging-5.0.2
# 14         axon-messaging-5.0.2
# 15  axon-server-connector-5.0.2
# 16         axon-modelling-5.0.2
# 17         axon-modelling-5.0.2
# 18         axon-messaging-5.0.2
# 19  axon-server-connector-5.0.2
# 20     axon-eventsourcing-5.0.2
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8        org.axonframework.messaging.eventhandling.processing.subscribing
# 9                                  org.axonframework.common.configuration
# 10               org.axonframework.messaging.core.interception.annotation
# 11                           org.axonframework.axonserver.connector.event
# 12                                 org.axonframework.axonserver.connector
# 13                         org.axonframework.messaging.core.configuration
# 14                   org.axonframework.messaging.eventhandling.sequencing
# 15                           org.axonframework.axonserver.connector.query
# 16                          org.axonframework.modelling.entity.annotation
# 17                               org.axonframework.modelling.entity.child
# 18                            org.axonframework.messaging.core.unitofwork
# 19                            org.axonframework.axonserver.connector.util
# 20                  org.axonframework.eventsourcing.annotation.reflection
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.2
# 1          axon-messaging-5.0.2
# 2          axon-messaging-5.0.2
# 3          axon-messaging-5.0.2
# 4          axon-messaging-5.0.2
# 5          axon-modelling-5.0.2
# 6          axon-messaging-5.0.2
# 7          axon-messaging-5.0.2
# 8          axon-messaging-5.0.2
# 9             axon-common-5.0.2
# 10         axon-messaging-5.0.2
# 11  axon-server-connector-5.0.2
# 12  axon-server-connector-5.0.2
# 13         axon-messaging-5.0.2
# 14         axon-messaging-5.0.2
# 15  axon-server-connector-5.0.2
# 16         axon-modelling-5.0.2
# 17         axon-modelling-5.0.2
# 18         axon-messaging-5.0.2
# 19  axon-server-connector-5.0.2
# 20     axon-eventsourcing-5.0.2
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9                            org.axonframework.common.infra
# 10              org.axonframework.messaging.core.annotation
# 11                   org.axonframework.axonserver.connector
# 12           org.axonframework.axonserver.connector.command
# 13  org.axonframework.messaging.eventhandling.configuration
# 14                org.axonframework.messaging.eventhandling
# 15                   org.axonframework.axonserver.connector
# 16                   org.axonframework.modelling.annotation
# 17                       org.axonframework.modelling.entity
# 18                         org.axonframework.messaging.core
# 19                   org.axonframework.axonserver.connector
# 20               org.axonframework.eventsourcing.annotation
#
#     forwardToBackwardBalance  numberForward  numberBackward  \
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.928571             27               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.529412             13               4
# 10                  0.500000             15               5
# 11                  0.428571              5               2
# 12                  0.333333              4               2
# 13                  0.333333              2               1
# 14                  0.333333              8               4
# 15                  0.200000              6               4
# 16                  0.200000              3               2
# 17                  0.142857              8               6
# 18                  0.111111             10               8
# 19                  0.000000              2               2
# 20                  0.000000              1               1
#
#                                                                                                                                                                                                                                                                                         someForwardDependencies  \
# 0   [MessageHandler->Message, AnnotatedMessageHandlingMemberDefinition->MessageStream, AnnotatedMessageHandlingMemberDefinition->Message, MethodInvokingMessageHandlingMember->MessageStream$Entry, MethodInvokingMessageHandlingMember->DelayedMessageStream, MethodInvokingMessageHandlingMember->MessageS...
# 1   [GenericEventMessage->MessageDecorator, GenericEventMessage->GenericMessage, GenericEventMessage->Message, GenericEventMessage->Metadata, GenericEventMessage->MessageType, EventHandlerRegistry->QualifiedName, EventBus->SubscribableEventSource, InterceptingEventSink$InterceptingPublisher->Message...
# 2   [TimestampParameterResolverFactory->ParameterResolver, TimestampParameterResolverFactory->AbstractAnnotatedParameterResolverFactory, AnnotatedEventHandlingComponent->AnnotatedHandlerInspector, AnnotatedEventHandlingComponent->HandlerDefinition, AnnotatedEventHandlingComponent->ParameterResolverF...
# 3   [CommandHandlingMember->MessageHandlingMember, AnnotatedCommandHandlingComponent->HandlerDefinition, AnnotatedCommandHandlingComponent->AnnotatedHandlerInspector, AnnotatedCommandHandlingComponent->MessageHandlingMember, AnnotatedCommandHandlingComponent->ParameterResolverFactory, CommandHandler...
# 4   [QueryResponse->Message, Query->Message, MethodQueryHandlerDefinition->HandlerEnhancerDefinition, MethodQueryHandlerDefinition->MessageHandlingMember, MethodQueryHandlerDefinition$MethodQueryHandlingMember->UnsupportedHandlerException, MethodQueryHandlerDefinition$MethodQueryHandlingMember->Wrap...
# 5   [InjectEntity->EntityIdResolver, InjectEntityParameterResolverFactory->PropertyBasedEntityIdResolver, InjectEntityParameterResolverFactory->EntityIdResolver, InjectEntityParameterResolver->EntityIdResolver, InjectEntityParameterResolver->StateManager, InjectEntityParameterResolver->EntityIdResol...
# 6                                                                       [TransactionalExecutorProvider->ProcessingContext, TransactionManager->ProcessingContext, TransactionManager->ProcessingLifecycle, TransactionManager->ProcessingLifecycle$Phase, TransactionManager->ProcessingLifecycle$ErrorHandler]
# 7   [PooledStreamingEventProcessorModule->EventHandlingComponentsConfigurer$RequiredComponentPhase, PooledStreamingEventProcessorModule->EventProcessorConfiguration, PooledStreamingEventProcessorModule->EventProcessorModule, PooledStreamingEventProcessorModule->EventProcessorCustomization, PooledStr...
# 8   [SubscribingEventProcessorsConfigurer->EventHandlingComponentsConfigurer$CompletePhase, SubscribingEventProcessorsConfigurer->EventProcessorModule$CustomizationPhase, SubscribingEventProcessorsConfigurer->EventProcessorModule$EventHandlingPhase, SubscribingEventProcessorsConfigurer->EventProcess...
# 9   [DecoratedComponent->ComponentDescriptor, AbstractComponent->ComponentDescriptor, InstantiatedComponentDefinition->ComponentDescriptor, Components->ComponentDescriptor, Components->DescribableComponent, ComponentRegistry->DescribableComponent, ComponentFactory->DescribableComponent, DefaultCompo...
# 10  [MessageHandlerInterceptorDefinition$InterceptedMessageHandlingMember->MessageHandlingMember, MessageHandlerInterceptorDefinition$InterceptedMessageHandlingMember->WrappedMessageHandlingMember, MessageHandlerInterceptorMemberChain->MessageHandlingMember, NoMoreInterceptors->MessageHandlingMember...
# 11  [AggregateBasedAxonServerEventStorageEngine->MetadataConverter, EventProcessorControlService->AxonServerConnectionManager, EventProcessorControlService->AxonServerConfiguration$Eventhandling$ProcessorSettings, EventProcessorControlService->AxonServerConfiguration$Eventhandling, AxonServerEventSt...
# 12                                                                        [ErrorCode->AxonServerCommandDispatchException, ErrorCode->AxonServerNonTransientRemoteCommandHandlingException, ErrorCode->AxonServerRemoteCommandHandlingException, AxonServerConfigurationEnhancer->AxonServerCommandBusConnector]
# 13                                                                                                                                                                                                         [MessagingConfigurer->EventProcessingConfigurer, MessagingConfigurer->EventBusConfigurationDefaults]
# 14  [SequencingPolicy->EventMessage, MetadataSequencingPolicy->EventMessage, SequentialPerAggregatePolicy->EventMessage, ExtractionSequencingPolicy->EventMessage, FullConcurrencyPolicy->EventMessage, FallbackSequencingPolicy->EventMessage, SequentialPolicy->EventMessage, HierarchicalSequencingPolicy...
# 15                                  [AxonServerQueryBusConnector$AxonServerUpdateCallback->ErrorCode, QueryConverter->MetadataConverter, QueryConverter->ErrorCode, FlowControlledResponseSender->ErrorCode, AxonServerQueryBusConnector->AxonServerConfiguration, AxonServerQueryDispatchException->ErrorCode]
# 16                                                                                                    [AnnotatedEntityIdResolverDefinition->AnnotationBasedEntityIdResolver, AnnotatedEntityIdResolverDefinition->EntityIdResolverDefinition, AnnotatedEntityMetamodel->AnnotationBasedEntityEvolvingComponent]
# 17  [SingleEntityChildMetamodel->EntityMetamodel, AbstractEntityChildMetamodel$Builder->EntityMetamodel, EntityChildMetamodel->EntityMetamodel, AbstractEntityChildMetamodel->ChildEntityNotFoundException, AbstractEntityChildMetamodel->EntityMetamodel, SingleEntityChildMetamodel$Builder->EntityMetamod...
# 18  [SimpleUnitOfWorkFactory->ApplicationContext, UnitOfWork->ApplicationContext, UnitOfWork$UnitOfWorkProcessingContext->Context$ResourceKey, UnitOfWork$UnitOfWorkProcessingContext->ApplicationContext, ProcessingContext->Context, ProcessingContext->ApplicationContext, ProcessingContext->Context$Res...
# 19                                                                                                                                                                                                                                              [GrpcExceptionParser->ErrorCode, ExceptionConverter->ErrorCode]
# 20                                                                                                                                                                                                                    [AnnotationBasedEventSourcedEntityFactoryDefinition->EventSourcedEntityFactoryDefinition]
#
#                                                                                                                                                                                                                                                                                            backwardDependencies
# 0                                                                                                                                                                                                                                                                  [SimpleHandlerAttributes->HandlerAttributes]
# 1                                                                                                                                                                                                                                                                       [SubscribableEventSource->EventMessage]
# 2                                                                                                                                                                                                                                                                           [HandlerTypeResolver->EventHandler]
# 3                                                                                                                                                                                                                                                                         [HandlerTypeResolver->CommandHandler]
# 4                                                                                                                                                                                                                                                                           [HandlerTypeResolver->QueryHandler]
# 5                                                                                                                                                                                                                                        [PropertyBasedEntityIdResolver->TargetEntityIdMemberMismatchException]
# 6                                                                                                                                                                                                                                                          [TransactionalUnitOfWorkFactory->TransactionManager]
# 7                                                                                                            [EventProcessingConfigurer->PooledStreamingEventProcessorsConfigurer, EventProcessorModule->PooledStreamingEventProcessorConfiguration, EventProcessorModule->PooledStreamingEventProcessorModule]
# 8                                                                                                                        [EventProcessingConfigurer->SubscribingEventProcessorsConfigurer, EventProcessorModule->SubscribingEventProcessorModule, EventProcessorModule->SubscribingEventProcessorConfiguration]
# 9                                                                                                            [JacksonComponentDescriptor->Component, JacksonComponentDescriptor->Component$Identifier, FilesystemStyleComponentDescriptor->Component, FilesystemStyleComponentDescriptor->Component$Identifier]
# 10  [ChainedMessageHandlerInterceptorMember->MessageHandlerInterceptorMemberChain, ChainedMessageHandlerInterceptorMember->NoMoreInterceptors, AnnotatedHandlerInspector->MessageInterceptingMember, AnnotatedHandlerInspector->MessageHandlerInterceptorMemberChain, AnnotatedHandlerInspector->NoMoreInter...
# 11                                                                                                                                                                        [AxonServerConfigurationEnhancer->AxonServerEventStorageEngineFactory, AxonServerConfigurationEnhancer->EventProcessorControlService]
# 12                                                                                                                                                                                                                [CommandConverter->MetadataConverter, AxonServerCommandBusConnector->AxonServerConfiguration]
# 13                                                                                                                                                                                                                                                             [EventProcessingConfigurer->MessagingConfigurer]
# 14                                                                                     [SimpleEventHandlingComponent->SequentialPerAggregatePolicy, SimpleEventHandlingComponent->SequentialPolicy, SimpleEventHandlingComponent->HierarchicalSequencingPolicy, SimpleEventHandlingComponent->SequencingPolicy]
# 15                                                                                [ErrorCode->AxonServerQueryDispatchException, ErrorCode->AxonServerRemoteQueryHandlingException, ErrorCode->AxonServerNonTransientRemoteQueryHandlingException, AxonServerConfigurationEnhancer->AxonServerQueryBusConnector]
# 16                                                                                                                                                                                  [AnnotationBasedEntityIdResolverDefinition->AnnotatedEntityMetamodel, EntityIdResolverDefinition->AnnotatedEntityMetamodel]
# 17  [PolymorphicEntityMetamodel$Builder->EntityChildMetamodel, ConcreteEntityMetamodel$Builder->EntityChildMetamodel, PolymorphicEntityMetamodelBuilder->EntityChildMetamodel, ConcreteEntityMetamodel->EntityChildMetamodel, ConcreteEntityMetamodel->ChildAmbiguityException, EntityMetamodelBuilder->Enti...
# 18  [MessageHandlerInterceptor->ProcessingContext, DefaultMessageDispatchInterceptorChain->ProcessingContext, DefaultMessageDispatchInterceptorChain$InterceptingDispatcher->ProcessingContext, Message->ProcessingContext, MessageDispatchInterceptor->ProcessingContext, MessageDispatchInterceptorChain->...
# 19                                                                                                                                                                                                             [AxonServerConnectionManager$Builder->GrpcMessageSizeInterceptor, ErrorCode->ExceptionConverter]
# 20                                                                                                                                                                                                                                     [EventSourcedEntity->AnnotationBasedEventSourcedEntityFactoryDefinition]

# %% [markdown]
# ### Table 2b - Cyclic Dependencies Break Down
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown`
#
# **Columns in addition to Table 2a:**
# - *dependency* shows the cycle dependency in the text format "type1 -> type2" (forward) or "type2<-type1" (backward)

# %%
cyclic_dependencies_breakdown = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown.cypher",limit=40)
cyclic_dependencies_breakdown
# Out:
#             artifactName                                  packageName  \
# 0   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 1   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 2   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 3   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 4   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 5   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 6   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 7   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 8   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 9   axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 10  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 11  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 12  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 13  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 14  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 15  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 16  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 17  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 18  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 19  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 20  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 21  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 22  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 23  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 24  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 25  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 26  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 27  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 28  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 29  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 30  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 31  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 32  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 33  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 34  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 35  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 36  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 37  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 38  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
# 39  axon-messaging-5.0.2  org.axonframework.messaging.core.annotation
#
#    dependentArtifactName              dependentPackageName  \
# 0   axon-messaging-5.0.2  org.axonframework.messaging.core
# 1   axon-messaging-5.0.2  org.axonframework.messaging.core
# 2   axon-messaging-5.0.2  org.axonframework.messaging.core
# 3   axon-messaging-5.0.2  org.axonframework.messaging.core
# 4   axon-messaging-5.0.2  org.axonframework.messaging.core
# 5   axon-messaging-5.0.2  org.axonframework.messaging.core
# 6   axon-messaging-5.0.2  org.axonframework.messaging.core
# 7   axon-messaging-5.0.2  org.axonframework.messaging.core
# 8   axon-messaging-5.0.2  org.axonframework.messaging.core
# 9   axon-messaging-5.0.2  org.axonframework.messaging.core
# 10  axon-messaging-5.0.2  org.axonframework.messaging.core
# 11  axon-messaging-5.0.2  org.axonframework.messaging.core
# 12  axon-messaging-5.0.2  org.axonframework.messaging.core
# 13  axon-messaging-5.0.2  org.axonframework.messaging.core
# 14  axon-messaging-5.0.2  org.axonframework.messaging.core
# 15  axon-messaging-5.0.2  org.axonframework.messaging.core
# 16  axon-messaging-5.0.2  org.axonframework.messaging.core
# 17  axon-messaging-5.0.2  org.axonframework.messaging.core
# 18  axon-messaging-5.0.2  org.axonframework.messaging.core
# 19  axon-messaging-5.0.2  org.axonframework.messaging.core
# 20  axon-messaging-5.0.2  org.axonframework.messaging.core
# 21  axon-messaging-5.0.2  org.axonframework.messaging.core
# 22  axon-messaging-5.0.2  org.axonframework.messaging.core
# 23  axon-messaging-5.0.2  org.axonframework.messaging.core
# 24  axon-messaging-5.0.2  org.axonframework.messaging.core
# 25  axon-messaging-5.0.2  org.axonframework.messaging.core
# 26  axon-messaging-5.0.2  org.axonframework.messaging.core
# 27  axon-messaging-5.0.2  org.axonframework.messaging.core
# 28  axon-messaging-5.0.2  org.axonframework.messaging.core
# 29  axon-messaging-5.0.2  org.axonframework.messaging.core
# 30  axon-messaging-5.0.2  org.axonframework.messaging.core
# 31  axon-messaging-5.0.2  org.axonframework.messaging.core
# 32  axon-messaging-5.0.2  org.axonframework.messaging.core
# 33  axon-messaging-5.0.2  org.axonframework.messaging.core
# 34  axon-messaging-5.0.2  org.axonframework.messaging.core
# 35  axon-messaging-5.0.2  org.axonframework.messaging.core
# 36  axon-messaging-5.0.2  org.axonframework.messaging.core
# 37  axon-messaging-5.0.2  org.axonframework.messaging.core
# 38  axon-messaging-5.0.2  org.axonframework.messaging.core
# 39  axon-messaging-5.0.2  org.axonframework.messaging.core
#
#                                                                                    dependency  \
# 0                                             MessageStreamResolverUtils->MessageTypeResolver
# 1                                       ChainedMessageHandlerInterceptorMember->MessageStream
# 2                         DefaultParameterResolverFactory$MetadataParameterResolver->Metadata
# 3                                             MessageStreamResolverUtils->MessageStream$Empty
# 4                                                                            Message->Message
# 5                                             ChainedMessageHandlerInterceptorMember->Message
# 6   AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->Context$ResourceKey
# 7                           DefaultParameterResolverFactory$MessageParameterResolver->Message
# 8                                                       MessageStreamResolverUtils->FluxUtils
# 9                                            MessageStreamResolverUtils->MessageStream$Single
# 10                                                      WrappedMessageHandlingMember->Message
# 11                                                  MessageStreamResolverUtils->MessageStream
# 12                                                WrappedMessageHandlingMember->MessageStream
# 13                                                             MessageHandlingMember->Message
# 14                                    InterceptorChainParameterResolverFactory->MessageStream
# 15      AggregateTypeParameterResolverFactory$AggregateTypeParameterResolver->LegacyResources
# 16                                                          PayloadParameterResolver->Message
# 17                                                  DefaultParameterResolverFactory->Metadata
# 18            SourceIdParameterResolverFactory$SourceIdParameterResolver->Context$ResourceKey
# 19                         DefaultParameterResolverFactory$MetadataParameterResolver->Message
# 20                                                 HandlerAttributes<-SimpleHandlerAttributes
# 21                                                      MessageStreamResolverUtils->MonoUtils
# 22                                          AnnotatedMessageHandlingMemberDefinition->Message
# 23                   InterceptorChainParameterResolverFactory->MessageHandlerInterceptorChain
# 24                                  MethodInvokingMessageHandlingMember->DelayedMessageStream
# 25                                                 MessageStreamResolverUtils->GenericMessage
# 26                              InterceptorChainParameterResolverFactory->Context$ResourceKey
# 27                                   MethodInvokingMessageHandlingMember->MessageStream$Entry
# 28                                          InterceptorChainParameterResolverFactory->Message
# 29                                                       MessageHandlingMember->MessageStream
# 30                                               MethodInvokingMessageHandlingMember->Message
# 31                SourceIdParameterResolverFactory$SourceIdParameterResolver->LegacyResources
# 32                                   MethodInvokingMessageHandlingMember->MessageStream$Empty
# 33                                    AnnotatedMessageHandlingMemberDefinition->MessageStream
# 34                                  MethodInvokingMessageHandlingMember->MessageStream$Single
# 35                                                   DefaultParameterResolverFactory->Message
# 36                                         MethodInvokingMessageHandlingMember->MessageStream
# 37                                                      MultiHandlerDefinition->MessageStream
# 38                                                                    MessageHandler->Message
# 39               DefaultParameterResolverFactory$AnnotatedMetadataParameterResolver->Metadata
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.959184             48               1
# 2                   0.959184             48               1
# 3                   0.959184             48               1
# 4                   0.959184             48               1
# 5                   0.959184             48               1
# 6                   0.959184             48               1
# 7                   0.959184             48               1
# 8                   0.959184             48               1
# 9                   0.959184             48               1
# 10                  0.959184             48               1
# 11                  0.959184             48               1
# 12                  0.959184             48               1
# 13                  0.959184             48               1
# 14                  0.959184             48               1
# 15                  0.959184             48               1
# 16                  0.959184             48               1
# 17                  0.959184             48               1
# 18                  0.959184             48               1
# 19                  0.959184             48               1
# 20                  0.959184             48               1
# 21                  0.959184             48               1
# 22                  0.959184             48               1
# 23                  0.959184             48               1
# 24                  0.959184             48               1
# 25                  0.959184             48               1
# 26                  0.959184             48               1
# 27                  0.959184             48               1
# 28                  0.959184             48               1
# 29                  0.959184             48               1
# 30                  0.959184             48               1
# 31                  0.959184             48               1
# 32                  0.959184             48               1
# 33                  0.959184             48               1
# 34                  0.959184             48               1
# 35                  0.959184             48               1
# 36                  0.959184             48               1
# 37                  0.959184             48               1
# 38                  0.959184             48               1
# 39                  0.959184             48               1

# %% [markdown]
# ### Table 2c - Cyclic Dependencies Break Down - Backward Dependencies Only
#
# Lists packages with cyclic dependencies with every dependency in a separate row sorted by the most promising  dependency first. This table only contains the backward dependencies from the second participant of the cycle back to the first one that are the most promising to resolve.
#
# Only the top 40 entries are shown. The whole table can be found in the following CSV report:
# `Cyclic_Dependencies_Breakdown_BackwardOnly`

# %%
cyclic_dependencies_breakdown_backward = query_cypher_to_data_frame("../cypher/Cyclic_Dependencies/Cyclic_Dependencies_Breakdown_Backward_Only.cypher",limit=40)
cyclic_dependencies_breakdown_backward
# Out:
#                    artifactName  \
# 0          axon-messaging-5.0.2
# 1          axon-messaging-5.0.2
# 2          axon-messaging-5.0.2
# 3          axon-messaging-5.0.2
# 4          axon-messaging-5.0.2
# 5          axon-modelling-5.0.2
# 6          axon-messaging-5.0.2
# 7          axon-messaging-5.0.2
# 8          axon-messaging-5.0.2
# 9          axon-messaging-5.0.2
# 10         axon-messaging-5.0.2
# 11         axon-messaging-5.0.2
# 12         axon-messaging-5.0.2
# 13            axon-common-5.0.2
# 14            axon-common-5.0.2
# 15            axon-common-5.0.2
# 16            axon-common-5.0.2
# 17         axon-messaging-5.0.2
# 18         axon-messaging-5.0.2
# 19         axon-messaging-5.0.2
# 20         axon-messaging-5.0.2
# 21         axon-messaging-5.0.2
# 22  axon-server-connector-5.0.2
# 23  axon-server-connector-5.0.2
# 24  axon-server-connector-5.0.2
# 25  axon-server-connector-5.0.2
# 26         axon-messaging-5.0.2
# 27         axon-messaging-5.0.2
# 28         axon-messaging-5.0.2
# 29         axon-messaging-5.0.2
# 30         axon-messaging-5.0.2
# 31  axon-server-connector-5.0.2
# 32  axon-server-connector-5.0.2
# 33  axon-server-connector-5.0.2
# 34  axon-server-connector-5.0.2
# 35         axon-modelling-5.0.2
# 36         axon-modelling-5.0.2
# 37         axon-modelling-5.0.2
# 38         axon-modelling-5.0.2
# 39         axon-modelling-5.0.2
#
#                                                               packageName  \
# 0                             org.axonframework.messaging.core.annotation
# 1                               org.axonframework.messaging.eventhandling
# 2                    org.axonframework.messaging.eventhandling.annotation
# 3                  org.axonframework.messaging.commandhandling.annotation
# 4                    org.axonframework.messaging.queryhandling.annotation
# 5                                  org.axonframework.modelling.annotation
# 6                 org.axonframework.messaging.core.unitofwork.transaction
# 7   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 8   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 9   org.axonframework.messaging.eventhandling.processing.streaming.pooled
# 10       org.axonframework.messaging.eventhandling.processing.subscribing
# 11       org.axonframework.messaging.eventhandling.processing.subscribing
# 12       org.axonframework.messaging.eventhandling.processing.subscribing
# 13                                 org.axonframework.common.configuration
# 14                                 org.axonframework.common.configuration
# 15                                 org.axonframework.common.configuration
# 16                                 org.axonframework.common.configuration
# 17               org.axonframework.messaging.core.interception.annotation
# 18               org.axonframework.messaging.core.interception.annotation
# 19               org.axonframework.messaging.core.interception.annotation
# 20               org.axonframework.messaging.core.interception.annotation
# 21               org.axonframework.messaging.core.interception.annotation
# 22                           org.axonframework.axonserver.connector.event
# 23                           org.axonframework.axonserver.connector.event
# 24                                 org.axonframework.axonserver.connector
# 25                                 org.axonframework.axonserver.connector
# 26                         org.axonframework.messaging.core.configuration
# 27                   org.axonframework.messaging.eventhandling.sequencing
# 28                   org.axonframework.messaging.eventhandling.sequencing
# 29                   org.axonframework.messaging.eventhandling.sequencing
# 30                   org.axonframework.messaging.eventhandling.sequencing
# 31                           org.axonframework.axonserver.connector.query
# 32                           org.axonframework.axonserver.connector.query
# 33                           org.axonframework.axonserver.connector.query
# 34                           org.axonframework.axonserver.connector.query
# 35                          org.axonframework.modelling.entity.annotation
# 36                          org.axonframework.modelling.entity.annotation
# 37                               org.axonframework.modelling.entity.child
# 38                               org.axonframework.modelling.entity.child
# 39                               org.axonframework.modelling.entity.child
#
#           dependentArtifactName  \
# 0          axon-messaging-5.0.2
# 1          axon-messaging-5.0.2
# 2          axon-messaging-5.0.2
# 3          axon-messaging-5.0.2
# 4          axon-messaging-5.0.2
# 5          axon-modelling-5.0.2
# 6          axon-messaging-5.0.2
# 7          axon-messaging-5.0.2
# 8          axon-messaging-5.0.2
# 9          axon-messaging-5.0.2
# 10         axon-messaging-5.0.2
# 11         axon-messaging-5.0.2
# 12         axon-messaging-5.0.2
# 13            axon-common-5.0.2
# 14            axon-common-5.0.2
# 15            axon-common-5.0.2
# 16            axon-common-5.0.2
# 17         axon-messaging-5.0.2
# 18         axon-messaging-5.0.2
# 19         axon-messaging-5.0.2
# 20         axon-messaging-5.0.2
# 21         axon-messaging-5.0.2
# 22  axon-server-connector-5.0.2
# 23  axon-server-connector-5.0.2
# 24  axon-server-connector-5.0.2
# 25  axon-server-connector-5.0.2
# 26         axon-messaging-5.0.2
# 27         axon-messaging-5.0.2
# 28         axon-messaging-5.0.2
# 29         axon-messaging-5.0.2
# 30         axon-messaging-5.0.2
# 31  axon-server-connector-5.0.2
# 32  axon-server-connector-5.0.2
# 33  axon-server-connector-5.0.2
# 34  axon-server-connector-5.0.2
# 35         axon-modelling-5.0.2
# 36         axon-modelling-5.0.2
# 37         axon-modelling-5.0.2
# 38         axon-modelling-5.0.2
# 39         axon-modelling-5.0.2
#
#                                        dependentPackageName  \
# 0                          org.axonframework.messaging.core
# 1                          org.axonframework.messaging.core
# 2               org.axonframework.messaging.core.annotation
# 3               org.axonframework.messaging.core.annotation
# 4               org.axonframework.messaging.core.annotation
# 5                               org.axonframework.modelling
# 6               org.axonframework.messaging.core.unitofwork
# 7   org.axonframework.messaging.eventhandling.configuration
# 8   org.axonframework.messaging.eventhandling.configuration
# 9   org.axonframework.messaging.eventhandling.configuration
# 10  org.axonframework.messaging.eventhandling.configuration
# 11  org.axonframework.messaging.eventhandling.configuration
# 12  org.axonframework.messaging.eventhandling.configuration
# 13                           org.axonframework.common.infra
# 14                           org.axonframework.common.infra
# 15                           org.axonframework.common.infra
# 16                           org.axonframework.common.infra
# 17              org.axonframework.messaging.core.annotation
# 18              org.axonframework.messaging.core.annotation
# 19              org.axonframework.messaging.core.annotation
# 20              org.axonframework.messaging.core.annotation
# 21              org.axonframework.messaging.core.annotation
# 22                   org.axonframework.axonserver.connector
# 23                   org.axonframework.axonserver.connector
# 24           org.axonframework.axonserver.connector.command
# 25           org.axonframework.axonserver.connector.command
# 26  org.axonframework.messaging.eventhandling.configuration
# 27                org.axonframework.messaging.eventhandling
# 28                org.axonframework.messaging.eventhandling
# 29                org.axonframework.messaging.eventhandling
# 30                org.axonframework.messaging.eventhandling
# 31                   org.axonframework.axonserver.connector
# 32                   org.axonframework.axonserver.connector
# 33                   org.axonframework.axonserver.connector
# 34                   org.axonframework.axonserver.connector
# 35                   org.axonframework.modelling.annotation
# 36                   org.axonframework.modelling.annotation
# 37                       org.axonframework.modelling.entity
# 38                       org.axonframework.modelling.entity
# 39                       org.axonframework.modelling.entity
#
#                                                                       dependency  \
# 0                                     HandlerAttributes<-SimpleHandlerAttributes
# 1                                          EventMessage<-SubscribableEventSource
# 2                                              EventHandler<-HandlerTypeResolver
# 3                                            CommandHandler<-HandlerTypeResolver
# 4                                              QueryHandler<-HandlerTypeResolver
# 5           TargetEntityIdMemberMismatchException<-PropertyBasedEntityIdResolver
# 6                             TransactionManager<-TransactionalUnitOfWorkFactory
# 7               PooledStreamingEventProcessorConfiguration<-EventProcessorModule
# 8                      PooledStreamingEventProcessorModule<-EventProcessorModule
# 9            PooledStreamingEventProcessorsConfigurer<-EventProcessingConfigurer
# 10               SubscribingEventProcessorsConfigurer<-EventProcessingConfigurer
# 11                         SubscribingEventProcessorModule<-EventProcessorModule
# 12                  SubscribingEventProcessorConfiguration<-EventProcessorModule
# 13                      Component$Identifier<-FilesystemStyleComponentDescriptor
# 14                                 Component<-FilesystemStyleComponentDescriptor
# 15                              Component$Identifier<-JacksonComponentDescriptor
# 16                                         Component<-JacksonComponentDescriptor
# 17               MessageHandlerInterceptorMemberChain<-AnnotatedHandlerInspector
# 18                          MessageInterceptingMember<-AnnotatedHandlerInspector
# 19                    NoMoreInterceptors<-ChainedMessageHandlerInterceptorMember
# 20  MessageHandlerInterceptorMemberChain<-ChainedMessageHandlerInterceptorMember
# 21                                 NoMoreInterceptors<-AnnotatedHandlerInspector
# 22          AxonServerEventStorageEngineFactory<-AxonServerConfigurationEnhancer
# 23                 EventProcessorControlService<-AxonServerConfigurationEnhancer
# 24                                           MetadataConverter<-CommandConverter
# 25                        AxonServerConfiguration<-AxonServerCommandBusConnector
# 26                                MessagingConfigurer<-EventProcessingConfigurer
# 27                    HierarchicalSequencingPolicy<-SimpleEventHandlingComponent
# 28                                SequencingPolicy<-SimpleEventHandlingComponent
# 29                    SequentialPerAggregatePolicy<-SimpleEventHandlingComponent
# 30                                SequentialPolicy<-SimpleEventHandlingComponent
# 31                 AxonServerNonTransientRemoteQueryHandlingException<-ErrorCode
# 32                             AxonServerRemoteQueryHandlingException<-ErrorCode
# 33                                   AxonServerQueryDispatchException<-ErrorCode
# 34                  AxonServerQueryBusConnector<-AxonServerConfigurationEnhancer
# 35           AnnotatedEntityMetamodel<-AnnotationBasedEntityIdResolverDefinition
# 36                          AnnotatedEntityMetamodel<-EntityIdResolverDefinition
# 37                      EntityChildMetamodel<-PolymorphicEntityMetamodel$Builder
# 38                         EntityChildMetamodel<-ConcreteEntityMetamodel$Builder
# 39                       EntityChildMetamodel<-PolymorphicEntityMetamodelBuilder
#
#     forwardToBackwardBalance  numberForward  numberBackward
# 0                   0.959184             48               1
# 1                   0.942857             34               1
# 2                   0.928571             27               1
# 3                   0.875000             15               1
# 4                   0.857143             13               1
# 5                   0.846154             12               1
# 6                   0.666667              5               1
# 7                   0.666667             15               3
# 8                   0.666667             15               3
# 9                   0.666667             15               3
# 10                  0.666667             15               3
# 11                  0.666667             15               3
# 12                  0.666667             15               3
# 13                  0.529412             13               4
# 14                  0.529412             13               4
# 15                  0.529412             13               4
# 16                  0.529412             13               4
# 17                  0.500000             15               5
# 18                  0.500000             15               5
# 19                  0.500000             15               5
# 20                  0.500000             15               5
# 21                  0.500000             15               5
# 22                  0.428571              5               2
# 23                  0.428571              5               2
# 24                  0.333333              4               2
# 25                  0.333333              4               2
# 26                  0.333333              2               1
# 27                  0.333333              8               4
# 28                  0.333333              8               4
# 29                  0.333333              8               4
# 30                  0.333333              8               4
# 31                  0.200000              6               4
# 32                  0.200000              6               4
# 33                  0.200000              6               4
# 34                  0.200000              6               4
# 35                  0.200000              3               2
# 36                  0.200000              3               2
# 37                  0.142857              8               6
# 38                  0.142857              8               6
# 39                  0.142857              8               6

# %% [markdown]
# ## Interface Segregation Candidates
#
# Well known from [Design Principles and Design Patterns by Robert C. Martin](http://staff.cs.utu.fi/~jounsmed/doos_06/material/DesignPrinciplesAndPatterns.pdf), the *Interface Segregation Principle* suggests that software components should have narrow, focused interfaces rather than large, general-purpose ones. The goal is to minimize the dependencies between components and increase modularity, flexibility, and maintainability.
#
# Smaller, focused and purpose-driven interfaces
#
# - make it easier to modify individual components without affecting the rest of the system.
# - make it clearer which client is affected by which change.
# - don’t force their clients to depend on methods they don’t need.
# - reduce the scope of changes since a change to one component doesn’t affect others.
# - lead to a more loosely coupled architecture that is easier to understand and maintain.
#
# Reference: [Analyze java package metrics in a graph database](https://joht.github.io/johtizen/data/2023/04/21/java-package-metrics-analysis.html#interface-segregation)
#
# ### How to apply the results
#
# If just one method of a type is used, especially in many places, then the result of this method can be used to call e.g. a method or constuct an object instead of using the whole object and then just calling that single method.
#
# If there are a couple of methods that are used for a distinct purpose, those could be factored out into a separate interface. The original type can extended/implement the new interface so that there are no breaking changes. Then all the callers, that use only this group of methods, can be changed to the new interface.

# %% [markdown]
# ### Table 4 - Top 40 most used combinations of methods
#
# The following table shows the top 40 most used combinations of methods of larger types that might benefit from applying the *Interface Segregation Principle*. The whole table can be found in the CSV report `Candidates_for_Interface_Segregation`.

# %%
interface_segregation_candidates=query_cypher_to_data_frame("../cypher/Internal_Dependencies/Candidates_for_Interface_Segregation.cypher", limit=40)
interface_segregation_candidates
# Out:
#                                                                                     fullDependentTypeName  \
# 0                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                                  org.axonframework.messaging.commandhandling.CommandBus
# 2                             org.axonframework.common.configuration.ComponentDefinition$ComponentCreator
# 3                                                    org.axonframework.messaging.core.MessageStream$Entry
# 4                                           org.axonframework.messaging.core.unitofwork.ProcessingContext
# 5                                                  org.axonframework.messaging.eventhandling.EventMessage
# 6                                                    org.axonframework.messaging.core.MessageStream$Empty
# 7                                                   org.axonframework.messaging.core.DelayedMessageStream
# 8                                                  org.axonframework.messaging.eventhandling.EventMessage
# 9                                org.axonframework.messaging.core.annotation.WrappedMessageHandlingMember
# 10                                               org.axonframework.common.configuration.AbstractComponent
# 11                                                 org.axonframework.messaging.core.unitofwork.UnitOfWork
# 12                                                     org.axonframework.test.fixture.AxonTestThenMessage
# 13                                             org.axonframework.messaging.commandhandling.CommandMessage
# 14                                                 org.axonframework.messaging.eventhandling.EventMessage
# 15                                                 org.axonframework.messaging.eventhandling.EventMessage
# 16                               org.axonframework.messaging.eventhandling.annotation.EventHandlingMember
# 17                                              org.axonframework.messaging.eventstreaming.EventCriterion
# 18                                             org.axonframework.messaging.eventstreaming.OrEventCriteria
# 19                                             org.axonframework.modelling.entity.ConcreteEntityMetamodel
# 20                                          org.axonframework.modelling.entity.PolymorphicEntityMetamodel
# 21                                 org.axonframework.modelling.entity.annotation.AnnotatedEntityMetamodel
# 22                                                  org.axonframework.eventsourcing.eventstore.EventStore
# 23                      org.axonframework.messaging.eventhandling.processing.streaming.token.WrappedToken
# 24                                                   org.axonframework.messaging.core.MessageStream$Entry
# 25                     org.axonframework.messaging.core.unitofwork.UnitOfWork$UnitOfWorkProcessingContext
# 26                                                    org.axonframework.messaging.core.EmptyMessageStream
# 27  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 28  org.axonframework.eventsourcing.eventstore.inmemory.InMemoryEventStorageEngine$MapBackedMessageStream
# 29                                                  org.axonframework.messaging.core.DelayedMessageStream
# 30                                                  org.axonframework.messaging.core.MessageStream$Single
# 31                                                  org.axonframework.messaging.core.MessageStream$Single
# 32                                                  org.axonframework.messaging.core.MessageStream$Single
# 33                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 34                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 35                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 36                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 37                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 38                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
# 39                                          org.axonframework.messaging.core.unitofwork.ProcessingContext
#
#     declaredMethods  \
# 0                32
# 1                 6
# 2                17
# 3                 7
# 4                32
# 5                19
# 6                44
# 7                42
# 8                19
# 9                13
# 10               24
# 11               24
# 12               22
# 13               19
# 14               19
# 15               19
# 16               13
# 17               12
# 18               12
# 19               11
# 20               11
# 21               11
# 22                9
# 23                9
# 24                7
# 25               45
# 26               44
# 27               43
# 28               42
# 29               42
# 30               42
# 31               42
# 32               42
# 33               37
# 34               36
# 35               35
# 36               34
# 37               33
# 38               33
# 39               33
#
#                                                                               calledMethodNames  \
# 0                                                                     [computeResourceIfAbsent]
# 1                                                                                    [dispatch]
# 2                                                                             [createComponent]
# 3                                                                                     [message]
# 4                                                                                [withResource]
# 5                                                                       [timestamp, identifier]
# 6                                                                                        [cast]
# 7                                                                                      [create]
# 8                                                                                   [timestamp]
# 9                                                                                  [handleSync]
# 10                                                                                 [describeTo]
# 11                                                                                    [execute]
# 12                                                              [exception, exceptionSatisfies]
# 13                                                                                [andMetadata]
# 14                                                                                 [identifier]
# 15                                                                                [andMetadata]
# 16                                                                                  [eventName]
# 17                                                                                       [tags]
# 18                                                                                         [or]
# 19                                                                             [forEntityClass]
# 20                                                                               [forSuperType]
# 21                                                                                 [entityType]
# 22                                                                                [transaction]
# 23                                                                           [unwrapLowerBound]
# 24                                                                                        [map]
# 25            [isCompleted, whenComplete, isStarted, isCommitted, onError, on, commit, isError]
# 26                                                                                   [instance]
# 27                                                              [hasNextAvailable, isCompleted]
# 28                                                                                   [callback]
# 29                                                                               [createSingle]
# 30                                                                        [asCompletableFuture]
# 31                                                                                      [first]
# 32                                                                                       [cast]
# 33  [updateResource, putResourceIfAbsent, removeResource, putResource, computeResourceIfAbsent]
# 34                                                    [updateResource, computeResourceIfAbsent]
# 35                                                                    [computeResourceIfAbsent]
# 36                                                                    [computeResourceIfAbsent]
# 37                                                    [removeResource, computeResourceIfAbsent]
# 38                                                                                [putResource]
# 39                                                                    [computeResourceIfAbsent]
#
#     calledMethods  callerTypes
# 0               1            7
# 1               1            6
# 2               1            5
# 3               1            5
# 4               1            4
# 5               2            4
# 6               1            3
# 7               1            3
# 8               1            3
# 9               1            3
# 10              1            2
# 11              1            2
# 12              3            2
# 13              1            2
# 14              1            2
# 15              1            2
# 16              1            2
# 17              1            2
# 18              1            2
# 19              1            2
# 20              1            2
# 21              1            2
# 22              1            2
# 23              1            2
# 24              1            2
# 25              8            1
# 26              1            1
# 27              2            1
# 28              1            1
# 29              1            1
# 30              1            1
# 31              1            1
# 32              1            1
# 33              6            1
# 34              2            1
# 35              1            1
# 36              1            1
# 37              2            1
# 38              1            1
# 39              1            1

# %% [markdown]
# ## Package Usage

# %% [markdown]
# ### Table 5 - Types that are used by multiple packages
#
# This table shows the top 40 packages that are used by the highest number of different packages. The whole table can be found in the CSV report `List_types_that_are_used_by_many_different_packages`.

# %%
types_used_by_many_packages=query_cypher_to_data_frame("../cypher/Internal_Dependencies/List_types_that_are_used_by_many_different_packages.cypher", limit=40)
types_used_by_many_packages
# Out:
#                                                               fullQualifiedDependentTypeName  \
# 0                              org.axonframework.messaging.core.unitofwork.ProcessingContext
# 1                                               org.axonframework.common.annotation.Internal
# 2                                                   org.axonframework.messaging.core.Message
# 3                                         org.axonframework.common.infra.ComponentDescriptor
# 4                                     org.axonframework.messaging.eventhandling.EventMessage
# 5                                             org.axonframework.messaging.core.MessageStream
# 6                                               org.axonframework.messaging.core.MessageType
# 7                                             org.axonframework.messaging.core.QualifiedName
# 8                                       org.axonframework.common.configuration.Configuration
# 9                                                       org.axonframework.common.FutureUtils
# 10                                      org.axonframework.messaging.core.Context$ResourceKey
# 11                                       org.axonframework.common.infra.DescribableComponent
# 12                                      org.axonframework.messaging.core.MessageStream$Empty
# 13                                                           org.axonframework.common.Assert
# 14                                                     org.axonframework.common.BuilderUtils
# 15                                  org.axonframework.common.configuration.ComponentRegistry
# 16                                org.axonframework.messaging.commandhandling.CommandMessage
# 17                                      org.axonframework.messaging.core.MessageStream$Entry
# 18                      org.axonframework.messaging.core.annotation.ParameterResolverFactory
# 19                                     org.axonframework.messaging.core.MessageStream$Single
# 20                                      org.axonframework.messaging.core.MessageTypeResolver
# 21                              org.axonframework.common.configuration.ConfigurationEnhancer
# 22                              org.axonframework.messaging.core.conversion.MessageConverter
# 23                                                 org.axonframework.messaging.core.Metadata
# 24                                                      org.axonframework.common.ObjectUtils
# 25        org.axonframework.messaging.eventhandling.processing.streaming.token.TrackingToken
# 26                                       org.axonframework.common.AxonConfigurationException
# 27                                                    org.axonframework.conversion.Converter
# 28                                    org.axonframework.messaging.commandhandling.CommandBus
# 29                                    org.axonframework.messaging.queryhandling.QueryMessage
# 30                          org.axonframework.messaging.commandhandling.CommandResultMessage
# 31                                org.axonframework.common.configuration.ComponentDefinition
# 32  org.axonframework.common.configuration.ComponentDefinition$IncompleteComponentDefinition
# 33                                                  org.axonframework.messaging.core.Context
# 34                                                  org.axonframework.common.ReflectionUtils
# 35                                        org.axonframework.common.AxonNonTransientException
# 36                                   org.axonframework.common.configuration.ComponentBuilder
# 37                       org.axonframework.messaging.eventhandling.conversion.EventConverter
# 38                                org.axonframework.messaging.core.MessageHandlerInterceptor
# 39                             org.axonframework.messaging.core.annotation.ParameterResolver
#
#                                     dependentTypeName  \
# 0                                   ProcessingContext
# 1                                            Internal
# 2                                             Message
# 3                                 ComponentDescriptor
# 4                                        EventMessage
# 5                                       MessageStream
# 6                                         MessageType
# 7                                       QualifiedName
# 8                                       Configuration
# 9                                         FutureUtils
# 10                                Context$ResourceKey
# 11                               DescribableComponent
# 12                                MessageStream$Empty
# 13                                             Assert
# 14                                       BuilderUtils
# 15                                  ComponentRegistry
# 16                                     CommandMessage
# 17                                MessageStream$Entry
# 18                           ParameterResolverFactory
# 19                               MessageStream$Single
# 20                                MessageTypeResolver
# 21                              ConfigurationEnhancer
# 22                                   MessageConverter
# 23                                           Metadata
# 24                                        ObjectUtils
# 25                                      TrackingToken
# 26                         AxonConfigurationException
# 27                                          Converter
# 28                                         CommandBus
# 29                                       QueryMessage
# 30                               CommandResultMessage
# 31                                ComponentDefinition
# 32  ComponentDefinition$IncompleteComponentDefinition
# 33                                            Context
# 34                                    ReflectionUtils
# 35                          AxonNonTransientException
# 36                                   ComponentBuilder
# 37                                     EventConverter
# 38                          MessageHandlerInterceptor
# 39                                  ParameterResolver
#
#                                                                                                                                                                                                                                                                                             dependentTypeLabels  \
# 0   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 1   [Type, File, Java, ByteCode, Annotation, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent...
# 2   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mar...
# 3   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 4   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponen...
# 5   [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWea...
# 6   [Type, File, Java, ByteCode, Record, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, M...
# 7   [Type, File, Java, ByteCode, Record, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4T...
# 8   [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation3, Mark4TypeLouvainCommunity3,...
# 9   [Type, File, Java, Class, ByteCode, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation32, Mark4TypeLouvainCommunity8, Mark...
# 10  [Type, File, Java, Class, ByteCode, GenericDeclaration, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyCon...
# 11  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0...
# 12  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation45, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity7, Mark4TypeK...
# 13  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecompositi...
# 14                                                    [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation39, Mark4TypeLouvainCommunity1, Mark4TypeLeidenCommunity1, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut67, Mark4TypeHDBSCAN88, Mark4TopAnomalyHub]
# 15                                    [Type, File, Java, ByteCode, Interface, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut42, Mark4TypeHDBSCAN159]
# 16  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation42, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity8,...
# 17  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation45, Mark4TypeLouvainCommunity7, Mark4T...
# 18                                                                   [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation54, Mark4TypeLouvainCommunity11, Mark4TypeLeidenCommunity12, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut2, Mark4TypeHDBSCAN97]
# 19  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation45, Mar...
# 20  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition10, ...
# 21                                                                     [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation6, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut87, Mark4TypeHDBSCAN-1]
# 22                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut55, Mark4TypeHDBSCAN137]
# 23  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut96, Ma...
# 24                                                                         [Type, File, Java, Class, ByteCode, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut74, Mark4TypeHDBSCAN-1]
# 25  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityArticleRank, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation47, Mark4TypeLouvainCommunity8, Mark4TypeLeidenCommunity9,...
# 26                                                             [Type, File, Java, Class, ByteCode, Throwable, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation10, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut82, Mark4TypeHDBSCAN-1]
# 27  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity2, Mark4TypeLeidenCommunity2, Mark4TypeKCoreDecompo...
# 28                                                                   [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation42, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut30, Mark4TypeHDBSCAN88]
# 29  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation58, Mark4TypeLouvainCommunity7, Mark4TypeLeidenCommunity7, Mark4TypeKCoreDecomposition10,...
# 30  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity8, Mark4TypeKCoreDecomposition10, ...
# 31  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation4, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut96, Mark4TypeLocalClusteringCoefficient0.2028985507246377, Mark4Ty...
# 32                                               [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation4, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut80, Mark4TypeHDBSCAN159]
# 33  [Type, File, Java, ByteCode, Interface, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TopCentralityBetweenness, Mark4TopCentralityHarmonic, Mark4TopCentralityCloseness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation45, Mark4TypeLouvainCommunity7, Mark4TypeLeidenC...
# 34                [Type, File, Java, Class, ByteCode, Mark4TopCentralityBetweenness, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity4, Mark4TypeLeidenCommunity4, Mark4TypeKCoreDecomposition8, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN-1, Mark4TopAnomalyBottleneck]
# 35  [Type, File, Java, Class, ByteCode, Mark4TopCentralityPageRank, Mark4TopCentralityArticleRank, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation11, Mark4TypeLouvainCommunity6, Mark4TypeLeidenCommunity6, Mark4TypeKCoreDecomposition4, Mark4TypeMaximumKCut52, Mark4TypeLocalClusteringCoe...
# 36                                               [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation5, Mark4TypeLouvainCommunity3, Mark4TypeLeidenCommunity3, Mark4TypeKCoreDecomposition10, Mark4TypeMaximumKCut27, Mark4TypeHDBSCAN160]
# 37                                                                    [Type, File, Java, ByteCode, Interface, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity9, Mark4TypeLeidenCommunity10, Mark4TypeKCoreDecomposition9, Mark4TypeMaximumKCut38, Mark4TypeHDBSCAN32]
# 38  [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TopCentralityBetweenness, Mark4TopCentralityHyperlinkInducedTopicSearchAuthority, Mark4TopCentralityHyperlinkInducedTopicSearchHub, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation92, Mark4TypeLouvainCommunity3, Mark4T...
# 39                                                 [Type, File, Java, ByteCode, Interface, GenericDeclaration, Mark4TypeWeaklyConnectedComponent0, Mark4TypeLabelPropagation1, Mark4TypeLouvainCommunity5, Mark4TypeLeidenCommunity5, Mark4TypeKCoreDecomposition7, Mark4TypeMaximumKCut0, Mark4TypeHDBSCAN115]
#
#     numberOfUsingPackages
# 0                      58
# 1                      51
# 2                      46
# 3                      44
# 4                      35
# 5                      35
# 6                      30
# 7                      30
# 8                      28
# 9                      28
# 10                     24
# 11                     24
# 12                     24
# 13                     21
# 14                     21
# 15                     21
# 16                     20
# 17                     19
# 18                     19
# 19                     18
# 20                     18
# 21                     17
# 22                     16
# 23                     16
# 24                     16
# 25                     15
# 26                     14
# 27                     14
# 28                     13
# 29                     13
# 30                     12
# 31                     12
# 32                     12
# 33                     12
# 34                     12
# 35                     11
# 36                     11
# 37                     11
# 38                     11
# 39                     11

# %% [markdown]
# ### Table 6 - Packages that are used by multiple artifacts
#
# This table shows the top 30 artifacts that only use a few (compared to all existing) packages of another artifact.
# The whole table can be found in the CSV report `ArtifactPackageUsage`.

# %%
used_packages_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_packages_compared_to_all_existing_are_used_by_dependent_artifacts.cypher",limit=30)
used_packages_of_dependent_artifact
# Out:
#                             artifactName          dependentArtifactName  \
# 0       axon-tracing-opentelemetry-5.0.2           axon-messaging-5.0.2
# 1       axon-tracing-opentelemetry-5.0.2              axon-common-5.0.2
# 2          axon-metrics-micrometer-5.0.2           axon-messaging-5.0.2
# 3            axon-server-connector-5.0.2       axon-eventsourcing-5.0.2
# 4                        axon-test-5.0.2       axon-eventsourcing-5.0.2
# 5          axon-metrics-micrometer-5.0.2              axon-common-5.0.2
# 6            axon-server-connector-5.0.2           axon-modelling-5.0.2
# 7                        axon-test-5.0.2           axon-messaging-5.0.2
# 8   axon-spring-boot-autoconfigure-5.0.2    axon-server-connector-5.0.2
# 9                      axon-update-5.0.2              axon-common-5.0.2
# 10  axon-spring-boot-autoconfigure-5.0.2                axon-test-5.0.2
# 11                 axon-conversion-5.0.2              axon-common-5.0.2
# 12                  axon-modelling-5.0.2           axon-messaging-5.0.2
# 13  axon-spring-boot-autoconfigure-5.0.2       axon-eventsourcing-5.0.2
# 14                 axon-conversion-5.0.2          axon-conversion-5.0.2
# 15              axon-eventsourcing-5.0.2          axon-conversion-5.0.2
# 16                  axon-modelling-5.0.2          axon-conversion-5.0.2
# 17  axon-spring-boot-autoconfigure-5.0.2           axon-messaging-5.0.2
# 18                       axon-test-5.0.2              axon-common-5.0.2
# 19              axon-eventsourcing-5.0.2           axon-messaging-5.0.2
# 20           axon-server-connector-5.0.2           axon-messaging-5.0.2
# 21  axon-spring-boot-autoconfigure-5.0.2              axon-common-5.0.2
# 22                  axon-modelling-5.0.2              axon-common-5.0.2
# 23           axon-server-connector-5.0.2              axon-common-5.0.2
# 24                  axon-messaging-5.0.2          axon-conversion-5.0.2
# 25         axon-metrics-micrometer-5.0.2  axon-metrics-micrometer-5.0.2
# 26                     axon-common-5.0.2              axon-common-5.0.2
# 27              axon-eventsourcing-5.0.2              axon-common-5.0.2
# 28                  axon-messaging-5.0.2              axon-common-5.0.2
# 29  axon-spring-boot-autoconfigure-5.0.2              axon-update-5.0.2
#
#     dependentPackages  dependentArtifactPackages  packageUsagePercentage  \
# 0                   2                         57                0.035088
# 1                   1                         15                0.066667
# 2                   6                         57                0.105263
# 3                   1                          8                0.125000
# 4                   1                          8                0.125000
# 5                   2                         15                0.133333
# 6                   1                          7                0.142857
# 7                   9                         57                0.157895
# 8                   1                          5                0.200000
# 9                   3                         15                0.200000
# 10                  1                          5                0.200000
# 11                  3                         15                0.200000
# 12                 13                         57                0.228070
# 13                  2                          8                0.250000
# 14                  1                          4                0.250000
# 15                  1                          4                0.250000
# 16                  1                          4                0.250000
# 17                 15                         57                0.263158
# 18                  4                         15                0.266667
# 19                 16                         57                0.280702
# 20                 16                         57                0.280702
# 21                  5                         15                0.333333
# 22                  5                         15                0.333333
# 23                  6                         15                0.400000
# 24                  2                          4                0.500000
# 25                  1                          2                0.500000
# 26                  8                         15                0.533333
# 27                  9                         15                0.600000
# 28                  9                         15                0.600000
# 29                  3                          5                0.600000
#
#                                                                                                                                                                                                                                                                              dependentFullQualifiedPackageNames  \
# 0                                                                                                                                                                                                                                       [org.axonframework.messaging.core, org.axonframework.messaging.tracing]
# 1                                                                                                                                                                                                                                                                                    [org.axonframework.common]
# 2                                           [org.axonframework.messaging.commandhandling, org.axonframework.messaging.core, org.axonframework.messaging.monitoring, org.axonframework.messaging.eventhandling.processing, org.axonframework.messaging.eventhandling, org.axonframework.messaging.queryhandling]
# 3                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 4                                                                                                                                                                                                                                                                  [org.axonframework.eventsourcing.eventstore]
# 5                                                                                                                                                                                                                                            [org.axonframework.common, org.axonframework.common.configuration]
# 6                                                                                                                                                                                                                                                                                 [org.axonframework.modelling]
# 7   [org.axonframework.messaging.core.annotation, org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.monitoring, org.axonframework.messaging.commandhandling, org.axonframework.messaging.core, org.axonframework.messaging.eventstreaming, org.axonframework.messaging.eventhandling,...
# 8                                                                                                                                                                                                                                                                      [org.axonframework.axonserver.connector]
# 9                                                                                                                                                                                                       [org.axonframework.common.annotation, org.axonframework.common.configuration, org.axonframework.common]
# 10                                                                                                                                                                                                                                                                              [org.axonframework.test.server]
# 11                                                                                                                                                                                                              [org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common]
# 12  [org.axonframework.messaging.core, org.axonframework.messaging.eventhandling.conversion, org.axonframework.messaging.core.annotation, org.axonframework.messaging.commandhandling, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core.conversion, org.axonframework.messaging.c...
# 13                                                                                                                                                                                                                 [org.axonframework.eventsourcing.eventstore, org.axonframework.eventsourcing.eventstore.jpa]
# 14                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 15                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 16                                                                                                                                                                                                                                                                               [org.axonframework.conversion]
# 17  [org.axonframework.messaging.core.correlation, org.axonframework.messaging.core.interception, org.axonframework.messaging.commandhandling, org.axonframework.messaging.eventhandling.processing.streaming.token.store, org.axonframework.messaging.queryhandling, org.axonframework.messaging.eventhandl...
# 18                                                                                                                                                                      [org.axonframework.common, org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common.configuration]
# 19  [org.axonframework.messaging.eventhandling.conversion, org.axonframework.messaging.core.configuration, org.axonframework.messaging.eventhandling.configuration, org.axonframework.messaging.commandhandling, org.axonframework.messaging.eventhandling, org.axonframework.messaging.core.interception, o...
# 20  [org.axonframework.messaging.queryhandling, org.axonframework.messaging.queryhandling.distributed, org.axonframework.messaging.core.unitofwork, org.axonframework.messaging.core, org.axonframework.messaging.core.conversion, org.axonframework.messaging.commandhandling, org.axonframework.messaging....
# 21                                                                                                                                         [org.axonframework.common.jpa, org.axonframework.common.configuration, org.axonframework.common, org.axonframework.common.jdbc, org.axonframework.common.annotation]
# 22                                                                                                                                   [org.axonframework.common.property, org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.annotation, org.axonframework.common.infra]
# 23                                                                                                   [org.axonframework.common.util, org.axonframework.common, org.axonframework.common.infra, org.axonframework.common.annotation, org.axonframework.common.lifecycle, org.axonframework.common.configuration]
# 24                                                                                                                                                                                                                                            [org.axonframework.conversion, org.axonframework.conversion.json]
# 25                                                                                                                                                                                                                                                   [org.axonframework.extension.metrics.micrometer.reservoir]
# 26                                     [org.axonframework.common, org.axonframework.common.io, org.axonframework.common.configuration, org.axonframework.common.function, org.axonframework.common.annotation, org.axonframework.common.tx, org.axonframework.common.lifecycle, org.axonframework.common.infra]
# 27            [org.axonframework.common, org.axonframework.common.configuration, org.axonframework.common.annotation, org.axonframework.common.infra, org.axonframework.common.jpa, org.axonframework.common.tx, org.axonframework.common.io, org.axonframework.common.function, org.axonframework.common.jdbc]
# 28          [org.axonframework.common, org.axonframework.common.infra, org.axonframework.common.configuration, org.axonframework.common.annotation, org.axonframework.common.util, org.axonframework.common.property, org.axonframework.common.tx, org.axonframework.common.jdbc, org.axonframework.common.jpa]
# 29                                                                                                                                                                                                       [org.axonframework.update.configuration, org.axonframework.update.detection, org.axonframework.update]
#
#                                                                                                                                                        dependentPackageNames
# 0                                                                                                                                                            [core, tracing]
# 1                                                                                                                                                                   [common]
# 2                                                                                              [commandhandling, core, monitoring, processing, eventhandling, queryhandling]
# 3                                                                                                                                                               [eventstore]
# 4                                                                                                                                                               [eventstore]
# 5                                                                                                                                                    [common, configuration]
# 6                                                                                                                                                                [modelling]
# 7                                                              [annotation, unitofwork, monitoring, commandhandling, core, eventstreaming, eventhandling, conversion, token]
# 8                                                                                                                                                                [connector]
# 9                                                                                                                                        [annotation, configuration, common]
# 10                                                                                                                                                                  [server]
# 11                                                                                                                                               [infra, annotation, common]
# 12                                                                     [core, conversion, annotation, commandhandling, eventhandling, unitofwork, configuration, reflection]
# 13                                                                                                                                                         [eventstore, jpa]
# 14                                                                                                                                                              [conversion]
# 15                                                                                                                                                              [conversion]
# 16                                                                                                                                                              [conversion]
# 17                   [correlation, interception, commandhandling, store, queryhandling, conversion, jpa, transaction, distributed, timeout, eventhandling, annotation, core]
# 18                                                                                                                                [common, infra, annotation, configuration]
# 19                               [conversion, configuration, commandhandling, eventhandling, interception, core, annotation, eventstreaming, unitofwork, token, transaction]
# 20  [queryhandling, distributed, unitofwork, core, conversion, commandhandling, subscribing, store, streaming, segmenting, eventhandling, eventstreaming, token, processing]
# 21                                                                                                                            [jpa, configuration, common, jdbc, annotation]
# 22                                                                                                                      [property, common, configuration, annotation, infra]
# 23                                                                                                               [util, common, infra, annotation, lifecycle, configuration]
# 24                                                                                                                                                        [conversion, json]
# 25                                                                                                                                                               [reservoir]
# 26                                                                                                   [common, io, configuration, function, annotation, tx, lifecycle, infra]
# 27                                                                                                   [common, configuration, annotation, infra, jpa, tx, io, function, jdbc]
# 28                                                                                                 [common, infra, configuration, annotation, util, property, tx, jdbc, jpa]
# 29                                                                                                                                        [configuration, detection, update]

# %% [markdown]
# ### Table 7 - Types that are used by multiple artifacts
#
# This table shows the top 30 types that only use a few (compared to all existing) types of another artifact. The whole table can be found in the CSV report `ClassesPerPackageUsageAcrossArtifacts`.

# %%
used_types_of_dependent_artifact=query_cypher_to_data_frame("../cypher/Internal_Dependencies/How_many_classes_compared_to_all_existing_in_the_same_package_are_used_by_dependent_packages_across_different_artifacts.cypher", limit=30)
used_types_of_dependent_artifact
# Out:
#                             artifactName dependentArtifactName  \
# 0                        axon-test-5.0.2  axon-messaging-5.0.2
# 1               axon-eventsourcing-5.0.2  axon-messaging-5.0.2
# 2                   axon-modelling-5.0.2  axon-messaging-5.0.2
# 3               axon-eventsourcing-5.0.2  axon-messaging-5.0.2
# 4               axon-eventsourcing-5.0.2  axon-messaging-5.0.2
# 5   axon-spring-boot-autoconfigure-5.0.2  axon-messaging-5.0.2
# 6               axon-eventsourcing-5.0.2     axon-common-5.0.2
# 7                   axon-modelling-5.0.2     axon-common-5.0.2
# 8                   axon-messaging-5.0.2     axon-common-5.0.2
# 9                   axon-messaging-5.0.2     axon-common-5.0.2
# 10              axon-eventsourcing-5.0.2     axon-common-5.0.2
# 11      axon-tracing-opentelemetry-5.0.2  axon-messaging-5.0.2
# 12         axon-metrics-micrometer-5.0.2  axon-messaging-5.0.2
# 13                  axon-messaging-5.0.2     axon-common-5.0.2
# 14                  axon-messaging-5.0.2     axon-common-5.0.2
# 15         axon-metrics-micrometer-5.0.2     axon-common-5.0.2
# 16                  axon-messaging-5.0.2     axon-common-5.0.2
# 17                  axon-messaging-5.0.2     axon-common-5.0.2
# 18                  axon-messaging-5.0.2     axon-common-5.0.2
# 19                  axon-messaging-5.0.2     axon-common-5.0.2
# 20                  axon-messaging-5.0.2     axon-common-5.0.2
# 21                  axon-messaging-5.0.2     axon-common-5.0.2
# 22                  axon-messaging-5.0.2     axon-common-5.0.2
# 23  axon-spring-boot-autoconfigure-5.0.2     axon-common-5.0.2
# 24                  axon-modelling-5.0.2     axon-common-5.0.2
# 25                  axon-messaging-5.0.2     axon-common-5.0.2
# 26                  axon-messaging-5.0.2     axon-common-5.0.2
# 27      axon-tracing-opentelemetry-5.0.2     axon-common-5.0.2
# 28                  axon-messaging-5.0.2     axon-common-5.0.2
# 29                  axon-messaging-5.0.2     axon-common-5.0.2
#
#                                                                    packageName  \
# 0                                              org.axonframework.test.matchers
# 1                                org.axonframework.eventsourcing.configuration
# 2                                       org.axonframework.modelling.repository
# 3                              org.axonframework.eventsourcing.eventstore.jdbc
# 4                                org.axonframework.eventsourcing.configuration
# 5                            org.axonframework.extension.springboot.autoconfig
# 6                                   org.axonframework.eventsourcing.annotation
# 7                                org.axonframework.modelling.entity.annotation
# 8                                             org.axonframework.messaging.core
# 9                                  org.axonframework.messaging.core.unitofwork
# 10                       org.axonframework.eventsourcing.annotation.reflection
# 11                           org.axonframework.extension.tracing.opentelemetry
# 12                              org.axonframework.extension.metrics.micrometer
# 13  org.axonframework.messaging.eventhandling.processing.streaming.token.store
# 14   org.axonframework.messaging.eventhandling.processing.streaming.segmenting
# 15                              org.axonframework.extension.metrics.micrometer
# 16                         org.axonframework.messaging.commandhandling.tracing
# 17                           org.axonframework.messaging.commandhandling.retry
# 18                                      org.axonframework.messaging.monitoring
# 19                        org.axonframework.messaging.eventhandling.sequencing
# 20                     org.axonframework.messaging.queryhandling.configuration
# 21                      org.axonframework.messaging.core.unitofwork.annotation
# 22                   org.axonframework.messaging.core.configuration.reflection
# 23                           org.axonframework.extension.springboot.autoconfig
# 24                                      org.axonframework.modelling.repository
# 25                           org.axonframework.messaging.eventhandling.tracing
# 26                                    org.axonframework.messaging.core.timeout
# 27                           org.axonframework.extension.tracing.opentelemetry
# 28                        org.axonframework.messaging.monitoring.configuration
# 29                        org.axonframework.messaging.eventhandling.processing
#
#                            dependentPackage.fqn  dependentTypes  \
# 0              org.axonframework.messaging.core               1
# 1              org.axonframework.messaging.core               1
# 2              org.axonframework.messaging.core               1
# 3              org.axonframework.messaging.core               1
# 4   org.axonframework.messaging.core.annotation               1
# 5   org.axonframework.messaging.core.annotation               1
# 6        org.axonframework.common.configuration               1
# 7        org.axonframework.common.configuration               1
# 8        org.axonframework.common.configuration               1
# 9        org.axonframework.common.configuration               1
# 10       org.axonframework.common.configuration               1
# 11             org.axonframework.messaging.core               2
# 12             org.axonframework.messaging.core               2
# 13                     org.axonframework.common               1
# 14                     org.axonframework.common               1
# 15                     org.axonframework.common               1
# 16                     org.axonframework.common               1
# 17                     org.axonframework.common               1
# 18                     org.axonframework.common               1
# 19                     org.axonframework.common               1
# 20                     org.axonframework.common               1
# 21                     org.axonframework.common               1
# 22                     org.axonframework.common               1
# 23                     org.axonframework.common               1
# 24                     org.axonframework.common               1
# 25                     org.axonframework.common               1
# 26                     org.axonframework.common               1
# 27                     org.axonframework.common               1
# 28                     org.axonframework.common               1
# 29                     org.axonframework.common               1
#
#     dependentPackageTypes  typeUsagePercentage  \
# 0                      80             0.012500
# 1                      80             0.012500
# 2                      80             0.012500
# 3                      80             0.012500
# 4                      50             0.020000
# 5                      50             0.020000
# 6                      46             0.021739
# 7                      46             0.021739
# 8                      46             0.021739
# 9                      46             0.021739
# 10                     46             0.021739
# 11                     80             0.025000
# 12                     80             0.025000
# 13                     34             0.029412
# 14                     34             0.029412
# 15                     34             0.029412
# 16                     34             0.029412
# 17                     34             0.029412
# 18                     34             0.029412
# 19                     34             0.029412
# 20                     34             0.029412
# 21                     34             0.029412
# 22                     34             0.029412
# 23                     34             0.029412
# 24                     34             0.029412
# 25                     34             0.029412
# 26                     34             0.029412
# 27                     34             0.029412
# 28                     34             0.029412
# 29                     34             0.029412
#
#                                                                        dependentTypeNames
# 0                                              [org.axonframework.messaging.core.Message]
# 1                                  [org.axonframework.messaging.core.MessageTypeResolver]
# 2                                  [org.axonframework.messaging.core.Context$ResourceKey]
# 3                                  [org.axonframework.messaging.core.Context$ResourceKey]
# 4                  [org.axonframework.messaging.core.annotation.ParameterResolverFactory]
# 5                 [org.axonframework.messaging.core.annotation.HandlerEnhancerDefinition]
# 6                                  [org.axonframework.common.configuration.Configuration]
# 7                                  [org.axonframework.common.configuration.Configuration]
# 8                                  [org.axonframework.common.configuration.Configuration]
# 9                     [org.axonframework.common.configuration.ComponentNotFoundException]
# 10                                 [org.axonframework.common.configuration.Configuration]
# 11  [org.axonframework.messaging.core.Metadata, org.axonframework.messaging.core.Message]
# 12  [org.axonframework.messaging.core.Metadata, org.axonframework.messaging.core.Message]
# 13                                      [org.axonframework.common.AxonTransientException]
# 14                                                      [org.axonframework.common.Assert]
# 15                                                [org.axonframework.common.BuilderUtils]
# 16                                                [org.axonframework.common.BuilderUtils]
# 17                                                 [org.axonframework.common.FutureUtils]
# 18                                                      [org.axonframework.common.Assert]
# 19                                                [org.axonframework.common.BuilderUtils]
# 20                                                 [org.axonframework.common.FutureUtils]
# 21                                                    [org.axonframework.common.Priority]
# 22                                                    [org.axonframework.common.Priority]
# 23                                  [org.axonframework.common.AxonConfigurationException]
# 24                                                 [org.axonframework.common.FutureUtils]
# 25                                                [org.axonframework.common.BuilderUtils]
# 26                                           [org.axonframework.common.AxonThreadFactory]
# 27                                                [org.axonframework.common.BuilderUtils]
# 28                                               [org.axonframework.common.TypeReference]
# 29                                               [org.axonframework.common.AxonException]

# %% [markdown]
# ### Table 8 - Duplicate package names across artifacts
#
# This table shows the top 30 duplicate package names across artifacts. They are ordered by the number of duplicates descending.
#
# This might lead to confusion, makes importing more error prone and might even lead to duplicate classes where only one of them will be loaded by the class loader. If a package is named the same way in two or more artifacts this even allows another artifact to access package protected classes, methods or members which might not be intended.
#
# The whole table can be found in the CSV report `DuplicatePackageNamesAcrossArtifacts`.

# %%
duplicate_package_names_across_artifacts=query_cypher_to_data_frame("../cypher/Artifact_Dependencies/Artifacts_with_duplicate_packages.cypher", limit=30)
duplicate_package_names_across_artifacts
# Out:
# Empty DataFrame
# Columns: [packageName, duplicates, artifactNames]
# Index: []

# %% [markdown]
# ### Table 9 - Annotated elements
#
# This table shows 30 most used Java Annotations including some examples where they are used.

# %%
annotated_elements=query_cypher_to_data_frame("../cypher/Java/Annotated_code_elements.cypher", limit=30)
annotated_elements
# Out:
#                                                                annotationName  \
# 0                                                  jakarta.annotation.Nonnull
# 1                                                  jakarta.annotation.Nonnull
# 2                                                 jakarta.annotation.Nullable
# 3                                                 jakarta.annotation.Nullable
# 4                                org.axonframework.common.annotation.Internal
# 5                                                  jakarta.annotation.Nonnull
# 6                                               java.lang.FunctionalInterface
# 7                                                 java.lang.annotation.Target
# 8                                              java.lang.annotation.Retention
# 9                                 org.springframework.context.annotation.Bean
# 10  org.springframework.boot.autoconfigure.condition.ConditionalOnMissingBean
# 11                   org.springframework.boot.autoconfigure.AutoConfiguration
# 12                               org.axonframework.common.annotation.Internal
# 13                               org.axonframework.common.annotation.Internal
# 14                                            java.lang.annotation.Documented
# 15                              com.fasterxml.jackson.annotation.JsonProperty
# 16                                          org.axonframework.common.Priority
# 17                               org.axonframework.common.annotation.Internal
# 18        org.springframework.boot.context.properties.ConfigurationProperties
# 19  org.springframework.boot.context.properties.EnableConfigurationProperties
# 20    org.springframework.boot.context.properties.NestedConfigurationProperty
# 21     org.springframework.boot.autoconfigure.condition.ConditionalOnProperty
# 22                                                  jakarta.persistence.Basic
# 23        org.springframework.boot.autoconfigure.condition.ConditionalOnClass
# 24                                                      java.lang.SafeVarargs
# 25                                                       java.lang.Deprecated
# 26                         org.springframework.context.annotation.Conditional
# 27              org.springframework.boot.context.properties.bind.DefaultValue
# 28                 org.springframework.boot.autoconfigure.AutoConfigureBefore
# 29                               com.fasterxml.jackson.annotation.JsonCreator
#
#    languageElement  numberOfAnnotatedElements  \
# 0        Parameter                       3440
# 1           Method                        837
# 2        Parameter                        358
# 3           Method                         99
# 4            Class                         79
# 5            Field                         72
# 6        Interface                         55
# 7       Annotation                         42
# 8       Annotation                         42
# 9           Method                         38
# 10          Method                         20
# 11           Class                         19
# 12     Constructor                         19
# 13       Interface                         16
# 14      Annotation                         15
# 15       Parameter                         12
# 16           Class                         12
# 17          Method                         11
# 18           Class                         10
# 19           Class                          9
# 20           Field                          8
# 21           Class                          8
# 22           Field                          8
# 23           Class                          7
# 24     Constructor                          7
# 25          Method                          7
# 26          Method                          6
# 27       Parameter                          6
# 28           Class                          6
# 29     Constructor                          6
#
#                                                                                                                                                                                                                                                                                                        examples
# 0   [org.axonframework.update.UpdateChecker.<init>(0), org.axonframework.update.UpdateChecker.<init>(1), org.axonframework.update.UpdateChecker.<init>(2), org.axonframework.update.common.DelayedTask.<init>(0), org.axonframework.update.common.DelayedTask.of(0), org.axonframework.update.UpdateCheckerC...
# 1   [org.axonframework.update.UpdateChecker.buildRequest, org.axonframework.update.api.UpdateCheckResponse.upgrades, org.axonframework.update.api.UpdateCheckResponse.vulnerabilities, org.axonframework.update.api.UpdateCheckRequest.libraries, org.axonframework.update.api.Artifact.version, org.axonfra...
# 2   [org.axonframework.update.api.UpdateCheckResponse.fromRequest(0), org.axonframework.common.StringUtils.capitalize(0), org.axonframework.common.ReflectionUtils.explicitlyUnequal(0), org.axonframework.common.ReflectionUtils.explicitlyUnequal(1), org.axonframework.common.lifecycle.LifecycleHandlerI...
# 3   [org.axonframework.common.ReflectionUtils.declaringClass, org.axonframework.common.FutureUtils.joinAndUnwrap, org.axonframework.common.configuration.AbstractComponent.name, org.axonframework.common.configuration.ComponentDefinition.name, org.axonframework.common.configuration.Components.put, org...
# 4   [org.axonframework.update.UpdateChecker, org.axonframework.update.UpdateCheckerHttpClient, org.axonframework.update.detection.MachineId, org.axonframework.update.common.DelayedTask, org.axonframework.update.detection.KotlinVersion, org.axonframework.update.detection.AxonVersionDetector, org.axon...
# 5   [org.axonframework.update.api.DetectedVulnerability.groupId, org.axonframework.update.api.DetectedVulnerability.artifactId, org.axonframework.update.api.DetectedVulnerability.severity, org.axonframework.update.api.DetectedVulnerability.fixVersion, org.axonframework.update.api.DetectedVulnerabili...
# 6   [org.axonframework.update.configuration.EnvironmentVariableUsagePropertyProvider$EnvironmentVariableSupplier, org.axonframework.common.jdbc.JdbcUtils$SqlResultConverter, org.axonframework.common.jdbc.ConnectionProvider, org.axonframework.common.jdbc.JdbcUtils$SqlFunction, org.axonframework.commo...
# 7   [org.axonframework.common.annotation.Internal, org.axonframework.common.Priority, org.axonframework.modelling.annotation.TargetEntityId, org.axonframework.modelling.annotation.InjectEntity, org.axonframework.modelling.entity.annotation.EntityMember, org.axonframework.extension.springboot.util.Co...
# 8   [org.axonframework.common.annotation.Internal, org.axonframework.common.Priority, org.axonframework.modelling.annotation.TargetEntityId, org.axonframework.modelling.annotation.InjectEntity, org.axonframework.modelling.entity.annotation.EntityMember, org.axonframework.extension.springboot.util.Co...
# 9   [org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration.axonTransactionManager, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration.messageTimeoutHandlerEnhancerDefinition, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoCon...
# 10  [org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration.axonTransactionManager, org.axonframework.extension.springboot.autoconfig.JpaAutoConfiguration.entityManagerProvider, org.axonframework.extension.springboot.autoconfig.JpaAutoConfiguration.tokenStore, org.axonfra...
# 11  [org.axonframework.extension.springboot.autoconfig.JdbcTransactionAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.CorrelationDataProviderAutoConfiguration, org.axonframework.extension.springboot....
# 12  [org.axonframework.eventsourcing.eventstore.InterceptingEventStore.<init>, org.axonframework.conversion.avro.AvroConverter.<init>, org.axonframework.conversion.json.JacksonConverter.<init>, org.axonframework.messaging.eventhandling.processing.streaming.pooled.PooledStreamingEventProcessorConfigu...
# 13  [org.axonframework.update.configuration.UsagePropertyProvider, org.axonframework.common.jdbc.ConnectionProvider, org.axonframework.common.tx.TransactionalExecutor, org.axonframework.common.jpa.EntityManagerProvider, org.axonframework.modelling.entity.annotation.AnnotatedEntityMetamodelFactory, o...
# 14  [org.axonframework.common.annotation.Internal, org.axonframework.modelling.entity.annotation.EntityMember, org.axonframework.extension.springboot.util.ConditionalOnQualifiedBean, org.axonframework.extension.springboot.util.ConditionalOnMissingQualifiedBean, org.axonframework.eventsourcing.annota...
# 15  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(0), org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>(1), org.axonframework.messaging.eventhandling.processing.streaming.token.ReplayToken.<init>(0),...
# 16  [org.axonframework.test.FixtureResourceParameterResolverFactory, org.axonframework.messaging.eventhandling.annotation.SequenceNumberParameterResolverFactory, org.axonframework.messaging.eventhandling.annotation.TimestampParameterResolverFactory, org.axonframework.messaging.core.annotation.Hierar...
# 17  [org.axonframework.extension.springboot.EventProcessorProperties.getProcessors, org.axonframework.messaging.eventhandling.conversion.DelegatingEventConverter.delegate, org.axonframework.messaging.eventhandling.processing.streaming.token.store.jdbc.JdbcTokenStore.converter, org.axonframework.mess...
# 18  [org.axonframework.axonserver.connector.AxonServerConfiguration, org.axonframework.extension.springboot.DistributedCommandBusProperties, org.axonframework.extension.springboot.TokenStoreProperties, org.axonframework.extension.springboot.TagsConfigurationProperties, org.axonframework.extension.sp...
# 19  [org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.UpdateCheckerAutoConfiguration, org.axonframework.extension.springboot.autoconfig.ConverterAutoConfiguration, org.axonframework.extension.springboot.autoconfig.JpaAu...
# 20  [org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.events, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.commands, org.axonframework.extension.springboot.TimeoutProperties$MessageHandlerTimeoutProperties.queries, o...
# 21  [org.axonframework.extension.springboot.autoconfig.AxonTimeoutAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration$AvroConfiguredCondition$MessagesAvroCondition, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration$Av...
# 22  [org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.type, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.version, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.timestamp, org.axonframework.eventsourcing.eventstore.jpa.AggregateEventEntry.p...
# 23  [org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration, org.axonframework.extension.springboot.autoconfig.JpaAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AxonServerAutoConfiguration, org.axonframework.extension.springboot.autoconfig.ObjectMapp...
# 24  [org.axonframework.test.matchers.SequenceMatcher.<init>, org.axonframework.test.matchers.ListMatcher.<init>, org.axonframework.test.matchers.ExactSequenceMatcher.<init>, org.axonframework.test.matchers.ListWithAllOfMatcher.<init>, org.axonframework.test.matchers.ListWithAnyOfMatcher.<init>, org....
# 25  [org.axonframework.test.fixture.AxonTestThenCommand.resultMessagePayloadSatisfies, org.axonframework.test.fixture.AxonTestPhase$Then$Command.resultMessagePayloadSatisfies, org.axonframework.messaging.core.GenericResultMessage.asResultMessage, org.axonframework.messaging.core.annotation.MessageHa...
# 26  [org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration.defaultAxonSchemaStore, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration.collectAvroSchemasFromClassPath, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoCon...
# 27  [org.axonframework.extension.springboot.JpaEventStorageEngineConfigurationProperties.<init>(0), org.axonframework.extension.springboot.JpaEventStorageEngineConfigurationProperties.<init>(1), org.axonframework.extension.springboot.JpaEventStorageEngineConfigurationProperties.<init>(2), org.axonfr...
# 28  [org.axonframework.extension.springboot.autoconfig.CorrelationDataProviderAutoConfiguration, org.axonframework.extension.springboot.autoconfig.AvroSchemaStoreAutoConfiguration, org.axonframework.extension.springboot.autoconfig.ConverterAutoConfiguration, org.axonframework.extension.springboot.au...
# 29  [org.axonframework.messaging.eventhandling.processing.streaming.token.GapAwareTrackingToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.ReplayToken.<init>, org.axonframework.messaging.eventhandling.processing.streaming.token.GlobalSequenceTrackingToken.<init>, or...

# %% [markdown]
# ### Table 10 - Distance distribution between dependent files
#
# This table shows the file directory distance distribution between dependent files. Intuitively, the distance is given by the fewest number of change directory commands needed to navigate between a file and a dependency it uses. Those are aggregate to see how many dependent files are in the same directory, how many are just one change directory command apart, and so on.

# %%
query_first_non_empty_cypher_to_data_frame("../cypher/Internal_Dependencies/Get_file_distance_as_shortest_contains_path_for_dependencies.cypher",
                                           "../cypher/Internal_Dependencies/Set_file_distance_as_shortest_contains_path_for_dependencies.cypher", limit=20)
# Out:
#    dependency.fileDistanceAsFewestChangeDirectoryCommands  \
# 0                                                       0
# 1                                                       1
# 2                                                       2
# 3                                                       4
#
#    numberOfDependencies  numberOfDependencyUsers  numberOfDependencyProviders  \
# 0                  2090                      863                          904
# 1                    96                       82                           41
# 2                  2059                      609                          411
# 3                  2073                      666                          317
#
#                                                                                                                                                                                                                                                                                                       examples
# 0  [/axon-spring-boot-autoconfigure-5.0.2.jar uses /axon-update-5.0.2.jar, /org/axonframework/update/detection uses /org/axonframework/update/api, /org/axonframework/update/UpdateCheckerConfigurationEnhancer.class uses /org/axonframework/update/UpdateChecker.class, /org/axonframework/update/UpdateC...
# 1                                  [/org/axonframework/update uses /org/axonframework/update/detection, /org/axonframework/update uses /org/axonframework/update/common, /org/axonframework/update uses /org/axonframework/update/api, /org/axonframework/update uses /org/axonframework/update/configuration]
# 2  [/org/axonframework/update/UpdateChecker.class uses /org/axonframework/update/detection/MachineId.class, /org/axonframework/update/UpdateChecker.class uses /org/axonframework/update/common/DelayedTask.class, /org/axonframework/update/UpdateChecker.class uses /org/axonframework/update/detection/K...
# 3  [/org/axonframework/extension/springboot/autoconfig uses /org/axonframework/update, /org/axonframework/extension/springboot/autoconfig uses /org/axonframework/update/detection, /org/axonframework/extension/springboot/autoconfig uses /org/axonframework/update/configuration, /org/axonframework/ext...
