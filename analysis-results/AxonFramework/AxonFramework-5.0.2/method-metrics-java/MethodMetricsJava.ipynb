# %% [markdown]
# # Method Metrics
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())
    

def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## Effective Method Line Count

# %% [markdown]
# ### Table 1a - Effective method line count distribution
#
# This table shows the distribution of the effective method line count per artifact.
# For each artifact the number of methods with effective line count = 1,2,3,... is shown to get an overview of how line counts are distributed over methods.
#
# Only the 15 artifacts with the highest method count and their effective method line count distribution (limited by 40)is shown here. The whole table can be found in the CSV report `Effective_Method_Line_Count_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
effective_method_line_count_distribution_max_artifacts=20

effective_method_line_count_distribution=query_cypher_to_data_frame("../cypher/Overview/Effective_Method_Line_Count_Distribution.cypher")
effective_method_line_count_distribution=effective_method_line_count_distribution.pivot(index='effectiveLineCount', columns='artifactName', values='methods')

# Fill missing values with zero
effective_method_line_count_distribution.fillna(0, inplace=True)

# Convert to integer
effective_method_line_count_distribution=effective_method_line_count_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
effective_method_line_count_distribution = effective_method_line_count_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:effective_method_line_count_distribution_max_artifacts]]

effective_method_line_count_distribution.head(40)
# Out:
# artifactName        axon-messaging-5.0.2.jar  axon-common-5.0.2.jar  \
# effectiveLineCount
# 1                                       1935                    351
# 2                                        495                    141
# 3                                        415                     93
# 4                                        189                     39
# 5                                        153                     36
# 6                                         92                     36
# 7                                         67                     14
# 8                                         71                     17
# 9                                         36                     11
# 10                                        29                      6
# 11                                        20                      7
# 12                                        10                      7
# 13                                         8                      5
# 14                                         4                      5
# 15                                         6                      1
# 16                                         7                      2
# 17                                         4                      3
# 18                                         1                      1
# 19                                         3                      0
# 20                                         2                      0
# 21                                         1                      0
# 22                                         3                      0
# 23                                         1                      0
# 24                                         0                      1
# 25                                         2                      0
# 26                                         0                      1
# 27                                         1                      0
# 28                                         0                      0
# 29                                         0                      0
# 30                                         0                      0
# 31                                         2                      0
# 36                                         1                      0
# 40                                         0                      0
# 41                                         0                      0
# 42                                         0                      0
# 45                                         0                      0
# 111                                        1                      0
#
# artifactName        axon-server-connector-5.0.2.jar  \
# effectiveLineCount
# 1                                               266
# 2                                               143
# 3                                                77
# 4                                                44
# 5                                                33
# 6                                                15
# 7                                                 9
# 8                                                15
# 9                                                11
# 10                                                7
# 11                                                2
# 12                                                3
# 13                                                2
# 14                                                2
# 15                                                1
# 16                                                1
# 17                                                2
# 18                                                1
# 19                                                0
# 20                                                1
# 21                                                2
# 22                                                0
# 23                                                0
# 24                                                0
# 25                                                0
# 26                                                0
# 27                                                0
# 28                                                1
# 29                                                0
# 30                                                1
# 31                                                0
# 36                                                0
# 40                                                0
# 41                                                0
# 42                                                1
# 45                                                0
# 111                                               0
#
# artifactName        axon-eventsourcing-5.0.2.jar  axon-test-5.0.2.jar  \
# effectiveLineCount
# 1                                            305                  204
# 2                                             75                   69
# 3                                             61                   33
# 4                                             53                   37
# 5                                             31                    4
# 6                                             17                   14
# 7                                             15                    8
# 8                                              5                    7
# 9                                             10                    7
# 10                                             7                    2
# 11                                             5                    4
# 12                                             4                    7
# 13                                             4                    2
# 14                                             3                    2
# 15                                             2                    3
# 16                                             1                    3
# 17                                             1                    0
# 18                                             0                    2
# 19                                             1                    0
# 20                                             1                    2
# 21                                             1                    1
# 22                                             0                    0
# 23                                             0                    1
# 24                                             0                    0
# 25                                             0                    0
# 26                                             0                    1
# 27                                             1                    0
# 28                                             0                    0
# 29                                             0                    0
# 30                                             1                    0
# 31                                             0                    1
# 36                                             0                    0
# 40                                             1                    0
# 41                                             0                    0
# 42                                             0                    0
# 45                                             0                    1
# 111                                            0                    0
#
# artifactName        axon-modelling-5.0.2.jar  \
# effectiveLineCount
# 1                                        175
# 2                                         56
# 3                                         30
# 4                                         36
# 5                                         23
# 6                                         18
# 7                                          9
# 8                                          9
# 9                                         13
# 10                                         3
# 11                                         2
# 12                                         4
# 13                                         5
# 14                                         1
# 15                                         1
# 16                                         1
# 17                                         2
# 18                                         2
# 19                                         0
# 20                                         0
# 21                                         1
# 22                                         0
# 23                                         0
# 24                                         0
# 25                                         0
# 26                                         0
# 27                                         0
# 28                                         0
# 29                                         0
# 30                                         0
# 31                                         0
# 36                                         0
# 40                                         0
# 41                                         0
# 42                                         0
# 45                                         0
# 111                                        0
#
# artifactName        axon-spring-boot-autoconfigure-5.0.2.jar  \
# effectiveLineCount
# 1                                                        181
# 2                                                         79
# 3                                                         16
# 4                                                          6
# 5                                                          9
# 6                                                          7
# 7                                                          5
# 8                                                          2
# 9                                                          1
# 10                                                         1
# 11                                                         0
# 12                                                         1
# 13                                                         1
# 14                                                         0
# 15                                                         0
# 16                                                         0
# 17                                                         1
# 18                                                         0
# 19                                                         0
# 20                                                         0
# 21                                                         0
# 22                                                         0
# 23                                                         1
# 24                                                         0
# 25                                                         0
# 26                                                         0
# 27                                                         0
# 28                                                         0
# 29                                                         1
# 30                                                         0
# 31                                                         0
# 36                                                         0
# 40                                                         0
# 41                                                         0
# 42                                                         0
# 45                                                         0
# 111                                                        0
#
# artifactName        axon-conversion-5.0.2.jar  axon-update-5.0.2.jar  \
# effectiveLineCount
# 1                                         101                     88
# 2                                          20                     10
# 3                                          12                      6
# 4                                           8                     10
# 5                                           9                      8
# 6                                           7                      8
# 7                                           5                      2
# 8                                           5                      2
# 9                                           4                      4
# 10                                          1                      2
# 11                                          2                      0
# 12                                          0                      1
# 13                                          1                      3
# 14                                          0                      2
# 15                                          1                      0
# 16                                          2                      1
# 17                                          1                      2
# 18                                          0                      1
# 19                                          1                      0
# 20                                          0                      0
# 21                                          0                      2
# 22                                          0                      0
# 23                                          0                      0
# 24                                          0                      1
# 25                                          0                      0
# 26                                          0                      0
# 27                                          0                      0
# 28                                          0                      0
# 29                                          1                      0
# 30                                          1                      0
# 31                                          0                      0
# 36                                          0                      0
# 40                                          0                      0
# 41                                          0                      1
# 42                                          0                      0
# 45                                          0                      0
# 111                                         0                      0
#
# artifactName        axon-metrics-micrometer-5.0.2.jar  \
# effectiveLineCount
# 1                                                  34
# 2                                                  17
# 3                                                  15
# 4                                                   6
# 5                                                   2
# 6                                                   4
# 7                                                   4
# 8                                                   5
# 9                                                   1
# 10                                                  0
# 11                                                  0
# 12                                                  0
# 13                                                  3
# 14                                                  0
# 15                                                  1
# 16                                                  0
# 17                                                  0
# 18                                                  0
# 19                                                  0
# 20                                                  0
# 21                                                  0
# 22                                                  0
# 23                                                  0
# 24                                                  0
# 25                                                  0
# 26                                                  0
# 27                                                  0
# 28                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 36                                                  0
# 40                                                  0
# 41                                                  0
# 42                                                  0
# 45                                                  0
# 111                                                 0
#
# artifactName        axon-tracing-opentelemetry-5.0.2.jar
# effectiveLineCount
# 1                                                     11
# 2                                                      4
# 3                                                     10
# 4                                                      7
# 5                                                      2
# 6                                                      3
# 7                                                      2
# 8                                                      0
# 9                                                      1
# 10                                                     0
# 11                                                     0
# 12                                                     1
# 13                                                     0
# 14                                                     0
# 15                                                     0
# 16                                                     0
# 17                                                     0
# 18                                                     0
# 19                                                     0
# 20                                                     0
# 21                                                     0
# 22                                                     0
# 23                                                     0
# 24                                                     0
# 25                                                     0
# 26                                                     0
# 27                                                     0
# 28                                                     0
# 29                                                     0
# 30                                                     0
# 31                                                     0
# 36                                                     0
# 40                                                     0
# 41                                                     0
# 42                                                     0
# 45                                                     0
# 111                                                    0

# %% [markdown]
# ### Table 1b - Effective method line count distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
effective_method_line_count_distribution_normalized = effective_method_line_count_distribution.div(effective_method_line_count_distribution.sum(axis=0), axis=1).multiply(100)
effective_method_line_count_distribution_normalized.head(40)
# Out:
# artifactName        axon-messaging-5.0.2.jar  axon-common-5.0.2.jar  \
# effectiveLineCount
# 1                                  54.369205              45.173745
# 2                                  13.908401              18.146718
# 3                                  11.660579              11.969112
# 4                                   5.310480               5.019305
# 5                                   4.298960               4.633205
# 6                                   2.584996               4.633205
# 7                                   1.882551               1.801802
# 8                                   1.994942               2.187902
# 9                                   1.011520               1.415701
# 10                                  0.814836               0.772201
# 11                                  0.561956               0.900901
# 12                                  0.280978               0.900901
# 13                                  0.224782               0.643501
# 14                                  0.112391               0.643501
# 15                                  0.168587               0.128700
# 16                                  0.196684               0.257400
# 17                                  0.112391               0.386100
# 18                                  0.028098               0.128700
# 19                                  0.084293               0.000000
# 20                                  0.056196               0.000000
# 21                                  0.028098               0.000000
# 22                                  0.084293               0.000000
# 23                                  0.028098               0.000000
# 24                                  0.000000               0.128700
# 25                                  0.056196               0.000000
# 26                                  0.000000               0.128700
# 27                                  0.028098               0.000000
# 28                                  0.000000               0.000000
# 29                                  0.000000               0.000000
# 30                                  0.000000               0.000000
# 31                                  0.056196               0.000000
# 36                                  0.028098               0.000000
# 40                                  0.000000               0.000000
# 41                                  0.000000               0.000000
# 42                                  0.000000               0.000000
# 45                                  0.000000               0.000000
# 111                                 0.028098               0.000000
#
# artifactName        axon-server-connector-5.0.2.jar  \
# effectiveLineCount
# 1                                          41.56250
# 2                                          22.34375
# 3                                          12.03125
# 4                                           6.87500
# 5                                           5.15625
# 6                                           2.34375
# 7                                           1.40625
# 8                                           2.34375
# 9                                           1.71875
# 10                                          1.09375
# 11                                          0.31250
# 12                                          0.46875
# 13                                          0.31250
# 14                                          0.31250
# 15                                          0.15625
# 16                                          0.15625
# 17                                          0.31250
# 18                                          0.15625
# 19                                          0.00000
# 20                                          0.15625
# 21                                          0.31250
# 22                                          0.00000
# 23                                          0.00000
# 24                                          0.00000
# 25                                          0.00000
# 26                                          0.00000
# 27                                          0.00000
# 28                                          0.15625
# 29                                          0.00000
# 30                                          0.15625
# 31                                          0.00000
# 36                                          0.00000
# 40                                          0.00000
# 41                                          0.00000
# 42                                          0.15625
# 45                                          0.00000
# 111                                         0.00000
#
# artifactName        axon-eventsourcing-5.0.2.jar  axon-test-5.0.2.jar  \
# effectiveLineCount
# 1                                      50.413223            49.156627
# 2                                      12.396694            16.626506
# 3                                      10.082645             7.951807
# 4                                       8.760331             8.915663
# 5                                       5.123967             0.963855
# 6                                       2.809917             3.373494
# 7                                       2.479339             1.927711
# 8                                       0.826446             1.686747
# 9                                       1.652893             1.686747
# 10                                      1.157025             0.481928
# 11                                      0.826446             0.963855
# 12                                      0.661157             1.686747
# 13                                      0.661157             0.481928
# 14                                      0.495868             0.481928
# 15                                      0.330579             0.722892
# 16                                      0.165289             0.722892
# 17                                      0.165289             0.000000
# 18                                      0.000000             0.481928
# 19                                      0.165289             0.000000
# 20                                      0.165289             0.481928
# 21                                      0.165289             0.240964
# 22                                      0.000000             0.000000
# 23                                      0.000000             0.240964
# 24                                      0.000000             0.000000
# 25                                      0.000000             0.000000
# 26                                      0.000000             0.240964
# 27                                      0.165289             0.000000
# 28                                      0.000000             0.000000
# 29                                      0.000000             0.000000
# 30                                      0.165289             0.000000
# 31                                      0.000000             0.240964
# 36                                      0.000000             0.000000
# 40                                      0.165289             0.000000
# 41                                      0.000000             0.000000
# 42                                      0.000000             0.000000
# 45                                      0.000000             0.240964
# 111                                     0.000000             0.000000
#
# artifactName        axon-modelling-5.0.2.jar  \
# effectiveLineCount
# 1                                  44.757033
# 2                                  14.322251
# 3                                   7.672634
# 4                                   9.207161
# 5                                   5.882353
# 6                                   4.603581
# 7                                   2.301790
# 8                                   2.301790
# 9                                   3.324808
# 10                                  0.767263
# 11                                  0.511509
# 12                                  1.023018
# 13                                  1.278772
# 14                                  0.255754
# 15                                  0.255754
# 16                                  0.255754
# 17                                  0.511509
# 18                                  0.511509
# 19                                  0.000000
# 20                                  0.000000
# 21                                  0.255754
# 22                                  0.000000
# 23                                  0.000000
# 24                                  0.000000
# 25                                  0.000000
# 26                                  0.000000
# 27                                  0.000000
# 28                                  0.000000
# 29                                  0.000000
# 30                                  0.000000
# 31                                  0.000000
# 36                                  0.000000
# 40                                  0.000000
# 41                                  0.000000
# 42                                  0.000000
# 45                                  0.000000
# 111                                 0.000000
#
# artifactName        axon-spring-boot-autoconfigure-5.0.2.jar  \
# effectiveLineCount
# 1                                                  58.012821
# 2                                                  25.320513
# 3                                                   5.128205
# 4                                                   1.923077
# 5                                                   2.884615
# 6                                                   2.243590
# 7                                                   1.602564
# 8                                                   0.641026
# 9                                                   0.320513
# 10                                                  0.320513
# 11                                                  0.000000
# 12                                                  0.320513
# 13                                                  0.320513
# 14                                                  0.000000
# 15                                                  0.000000
# 16                                                  0.000000
# 17                                                  0.320513
# 18                                                  0.000000
# 19                                                  0.000000
# 20                                                  0.000000
# 21                                                  0.000000
# 22                                                  0.000000
# 23                                                  0.320513
# 24                                                  0.000000
# 25                                                  0.000000
# 26                                                  0.000000
# 27                                                  0.000000
# 28                                                  0.000000
# 29                                                  0.320513
# 30                                                  0.000000
# 31                                                  0.000000
# 36                                                  0.000000
# 40                                                  0.000000
# 41                                                  0.000000
# 42                                                  0.000000
# 45                                                  0.000000
# 111                                                 0.000000
#
# artifactName        axon-conversion-5.0.2.jar  axon-update-5.0.2.jar  \
# effectiveLineCount
# 1                                   55.494505              57.142857
# 2                                   10.989011               6.493506
# 3                                    6.593407               3.896104
# 4                                    4.395604               6.493506
# 5                                    4.945055               5.194805
# 6                                    3.846154               5.194805
# 7                                    2.747253               1.298701
# 8                                    2.747253               1.298701
# 9                                    2.197802               2.597403
# 10                                   0.549451               1.298701
# 11                                   1.098901               0.000000
# 12                                   0.000000               0.649351
# 13                                   0.549451               1.948052
# 14                                   0.000000               1.298701
# 15                                   0.549451               0.000000
# 16                                   1.098901               0.649351
# 17                                   0.549451               1.298701
# 18                                   0.000000               0.649351
# 19                                   0.549451               0.000000
# 20                                   0.000000               0.000000
# 21                                   0.000000               1.298701
# 22                                   0.000000               0.000000
# 23                                   0.000000               0.000000
# 24                                   0.000000               0.649351
# 25                                   0.000000               0.000000
# 26                                   0.000000               0.000000
# 27                                   0.000000               0.000000
# 28                                   0.000000               0.000000
# 29                                   0.549451               0.000000
# 30                                   0.549451               0.000000
# 31                                   0.000000               0.000000
# 36                                   0.000000               0.000000
# 40                                   0.000000               0.000000
# 41                                   0.000000               0.649351
# 42                                   0.000000               0.000000
# 45                                   0.000000               0.000000
# 111                                  0.000000               0.000000
#
# artifactName        axon-metrics-micrometer-5.0.2.jar  \
# effectiveLineCount
# 1                                           36.956522
# 2                                           18.478261
# 3                                           16.304348
# 4                                            6.521739
# 5                                            2.173913
# 6                                            4.347826
# 7                                            4.347826
# 8                                            5.434783
# 9                                            1.086957
# 10                                           0.000000
# 11                                           0.000000
# 12                                           0.000000
# 13                                           3.260870
# 14                                           0.000000
# 15                                           1.086957
# 16                                           0.000000
# 17                                           0.000000
# 18                                           0.000000
# 19                                           0.000000
# 20                                           0.000000
# 21                                           0.000000
# 22                                           0.000000
# 23                                           0.000000
# 24                                           0.000000
# 25                                           0.000000
# 26                                           0.000000
# 27                                           0.000000
# 28                                           0.000000
# 29                                           0.000000
# 30                                           0.000000
# 31                                           0.000000
# 36                                           0.000000
# 40                                           0.000000
# 41                                           0.000000
# 42                                           0.000000
# 45                                           0.000000
# 111                                          0.000000
#
# artifactName        axon-tracing-opentelemetry-5.0.2.jar
# effectiveLineCount
# 1                                              26.829268
# 2                                               9.756098
# 3                                              24.390244
# 4                                              17.073171
# 5                                               4.878049
# 6                                               7.317073
# 7                                               4.878049
# 8                                               0.000000
# 9                                               2.439024
# 10                                              0.000000
# 11                                              0.000000
# 12                                              2.439024
# 13                                              0.000000
# 14                                              0.000000
# 15                                              0.000000
# 16                                              0.000000
# 17                                              0.000000
# 18                                              0.000000
# 19                                              0.000000
# 20                                              0.000000
# 21                                              0.000000
# 22                                              0.000000
# 23                                              0.000000
# 24                                              0.000000
# 25                                              0.000000
# 26                                              0.000000
# 27                                              0.000000
# 28                                              0.000000
# 29                                              0.000000
# 30                                              0.000000
# 31                                              0.000000
# 36                                              0.000000
# 40                                              0.000000
# 41                                              0.000000
# 42                                              0.000000
# 45                                              0.000000
# 111                                             0.000000

# %% [markdown]
# ### Table 1b Chart 1 - Effective method line count distribution (normalized)

# %%
if effective_method_line_count_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,20)
    axes = effective_method_line_count_distribution_normalized.head(20).plot(
        kind='line',
        logx=True,
        grid=True,
        xlim=[2, 20],
        ylim=[0, 20],
        xticks=method_line_count_x_ticks,
        title='Effective Method Line Count Distribution', 
        xlabel='effective line count',
        ylabel='percent of methods',
        cmap=main_color_map,
        figsize=(10, 6),
        lw=2,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 1c - Top 30 packages with highest effective line counts
#
# The following table shows the top 30 packages with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Query artifacts and packages and find the method with the highest effective lines of code and cyclomatic complexity
# The result of this query will be also used further below. 
method_statistics_per_package = query_cypher_to_data_frame("../cypher/Overview/Effective_lines_of_method_code_per_package.cypher")

# %%
# Select and order the columns for this particular table 
effective_line_count_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'linesInPackage', 'methodCount', 'maxLinesMethod','maxLinesMethodName']]

# Print out the top 30 (head) rows
effective_line_count_per_package.head(30)
# Out:
#                             artifactName  \
# 0                   axon-messaging-5.0.2
# 1                   axon-messaging-5.0.2
# 2                        axon-test-5.0.2
# 3                   axon-messaging-5.0.2
# 4            axon-server-connector-5.0.2
# 5                      axon-common-5.0.2
# 6                      axon-common-5.0.2
# 7               axon-eventsourcing-5.0.2
# 8            axon-server-connector-5.0.2
# 9               axon-eventsourcing-5.0.2
# 10                  axon-messaging-5.0.2
# 11                  axon-messaging-5.0.2
# 12                  axon-messaging-5.0.2
# 13           axon-server-connector-5.0.2
# 14                  axon-modelling-5.0.2
# 15                  axon-messaging-5.0.2
# 16                       axon-test-5.0.2
# 17  axon-spring-boot-autoconfigure-5.0.2
# 18                 axon-conversion-5.0.2
# 19         axon-metrics-micrometer-5.0.2
# 20                  axon-modelling-5.0.2
# 21  axon-spring-boot-autoconfigure-5.0.2
# 22                  axon-messaging-5.0.2
# 23                  axon-messaging-5.0.2
# 24                     axon-common-5.0.2
# 25                     axon-common-5.0.2
# 26                  axon-messaging-5.0.2
# 27                  axon-messaging-5.0.2
# 28                  axon-messaging-5.0.2
# 29                  axon-messaging-5.0.2
#
#                                       fullPackageName  linesInPackage  \
# 0   org.axonframework.messaging.eventhandling.proc...            1417
# 1                    org.axonframework.messaging.core            1119
# 2                      org.axonframework.test.fixture             733
# 3         org.axonframework.messaging.core.annotation             702
# 4              org.axonframework.axonserver.connector             698
# 5              org.axonframework.common.configuration             668
# 6                            org.axonframework.common             608
# 7          org.axonframework.eventsourcing.eventstore             599
# 8        org.axonframework.axonserver.connector.event             540
# 9      org.axonframework.eventsourcing.eventstore.jpa             457
# 10  org.axonframework.messaging.eventhandling.proc...             455
# 11          org.axonframework.messaging.queryhandling             381
# 12        org.axonframework.messaging.core.unitofwork             339
# 13       org.axonframework.axonserver.connector.query             325
# 14      org.axonframework.modelling.entity.annotation             321
# 15  org.axonframework.messaging.eventhandling.proc...             320
# 16                    org.axonframework.test.matchers             318
# 17  org.axonframework.extension.springboot.autoconfig             304
# 18                  org.axonframework.conversion.avro             292
# 19     org.axonframework.extension.metrics.micrometer             281
# 20                 org.axonframework.modelling.entity             268
# 21             org.axonframework.extension.springboot             266
# 22     org.axonframework.messaging.core.configuration             253
# 23  org.axonframework.messaging.eventhandling.proc...             253
# 24                   org.axonframework.common.caching             234
# 25                     org.axonframework.common.infra             233
# 26  org.axonframework.messaging.eventhandling.proc...             231
# 27           org.axonframework.messaging.core.timeout             217
# 28        org.axonframework.messaging.commandhandling             216
# 29          org.axonframework.messaging.eventhandling             211
#
#     methodCount  maxLinesMethod  \
# 0           397             111
# 1           531              16
# 2           204              45
# 3           235              23
# 4           278              42
# 5           262              26
# 6           182              24
# 7           233              19
# 8           162              21
# 9           141              20
# 10          130              25
# 11          172              14
# 12          168              21
# 13           90              21
# 14           75              18
# 15          121              11
# 16          101              21
# 17          134              29
# 18           81              30
# 19           87              15
# 20           76              18
# 21          147               9
# 22          119              19
# 23           94              19
# 24           85              13
# 25           56              14
# 26           50              22
# 27           56              16
# 28          100              18
# 29           86              11
#
#                                    maxLinesMethodName
# 0                                                 run
# 1                                             process
# 2                                 appendEventOverview
# 3                                              <init>
# 4                                               build
# 5                             invokeLifecycleHandlers
# 6   getExactDirectSuperTypesOfParameterizedTypeOrC...
# 7                                  createTagsForValue
# 8                               lambda$appendEvents$0
# 9                                     withGapsCleaned
# 10                                        updateToken
# 11                                             handle
# 12                                       runNextPhase
# 13                                convertQueryMessage
# 14                       createOptionalChildForMember
# 15                                          advanceTo
# 16                                     matchingFields
# 17                                     buildConverter
# 18                                            convert
# 19                             registerEventProcessor
# 20                                             <init>
# 21                                             <init>
# 22                                 registerComponents
# 23                                              split
# 24                          lambda$computeIfPresent$4
# 25                                   describeProperty
# 26                                         storeToken
# 27                                             <init>
# 28                                             handle
# 29                                             handle

# %% [markdown]
# ### Table 1d - Top 30 methods with the highest effective line count
#
# The following table shows the top 30 methods with the highest effective lines of code. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
effective_line_count_method_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxLinesMethodType', 'maxLinesMethodName', 'maxLinesMethod', 'linesInPackage']]

# Sort by the maximum of effective lines of code per package descending
effective_line_count_method_per_package=effective_line_count_method_per_package.sort_values(by='maxLinesMethod', ascending=False)

# Reset the index to the new sort order
effective_line_count_method_per_package=effective_line_count_method_per_package.reset_index()

# Print out the top 30 (head) rows
effective_line_count_method_per_package.head(30)
# Out:
#     index                          artifactName  \
# 0       0                  axon-messaging-5.0.2
# 1       2                       axon-test-5.0.2
# 2       4           axon-server-connector-5.0.2
# 3      42                     axon-update-5.0.2
# 4      32              axon-eventsourcing-5.0.2
# 5      18                 axon-conversion-5.0.2
# 6      61              axon-eventsourcing-5.0.2
# 7      65                 axon-conversion-5.0.2
# 8      17  axon-spring-boot-autoconfigure-5.0.2
# 9       5                     axon-common-5.0.2
# 10     10                  axon-messaging-5.0.2
# 11      6                     axon-common-5.0.2
# 12     84  axon-spring-boot-autoconfigure-5.0.2
# 13      3                  axon-messaging-5.0.2
# 14     26                  axon-messaging-5.0.2
# 15     40                     axon-update-5.0.2
# 16     46                     axon-update-5.0.2
# 17     54                  axon-modelling-5.0.2
# 18      8           axon-server-connector-5.0.2
# 19     16                       axon-test-5.0.2
# 20     12                  axon-messaging-5.0.2
# 21     13           axon-server-connector-5.0.2
# 22     34           axon-server-connector-5.0.2
# 23     31                       axon-test-5.0.2
# 24      9              axon-eventsourcing-5.0.2
# 25     22                  axon-messaging-5.0.2
# 26     23                  axon-messaging-5.0.2
# 27      7              axon-eventsourcing-5.0.2
# 28     14                  axon-modelling-5.0.2
# 29     20                  axon-modelling-5.0.2
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.proc...
# 1                      org.axonframework.test.fixture
# 2              org.axonframework.axonserver.connector
# 3                  org.axonframework.update.detection
# 4   org.axonframework.eventsourcing.annotation.ref...
# 5                   org.axonframework.conversion.avro
# 6          org.axonframework.eventsourcing.annotation
# 7                   org.axonframework.conversion.json
# 8   org.axonframework.extension.springboot.autoconfig
# 9              org.axonframework.common.configuration
# 10  org.axonframework.messaging.eventhandling.proc...
# 11                           org.axonframework.common
# 12        org.axonframework.extension.springboot.util
# 13        org.axonframework.messaging.core.annotation
# 14  org.axonframework.messaging.eventhandling.proc...
# 15                           org.axonframework.update
# 16                       org.axonframework.update.api
# 17             org.axonframework.modelling.annotation
# 18       org.axonframework.axonserver.connector.event
# 19                    org.axonframework.test.matchers
# 20        org.axonframework.messaging.core.unitofwork
# 21       org.axonframework.axonserver.connector.query
# 22     org.axonframework.axonserver.connector.command
# 23                      org.axonframework.test.server
# 24     org.axonframework.eventsourcing.eventstore.jpa
# 25     org.axonframework.messaging.core.configuration
# 26  org.axonframework.messaging.eventhandling.proc...
# 27         org.axonframework.eventsourcing.eventstore
# 28      org.axonframework.modelling.entity.annotation
# 29                 org.axonframework.modelling.entity
#
#                                    maxLinesMethodType  \
# 0                        Coordinator$CoordinationTask
# 1                                            Reporter
# 2                 AxonServerConnectionManager$Builder
# 3                             TestEnvironmentDetector
# 4            AnnotationBasedEventSourcedEntityFactory
# 5                                       AvroConverter
# 6   AnnotationBasedEventCriteriaResolver$WrappedEv...
# 7                                    JacksonConverter
# 8                          ConverterAutoConfiguration
# 9        DefaultAxonApplication$AxonConfigurationImpl
# 10                                     JdbcTokenStore
# 11                                TypeReflectionUtils
# 12                     AbstractQualifiedBeanCondition
# 13                MethodInvokingMessageHandlingMember
# 14                                      JpaTokenStore
# 15                            UpdateCheckerHttpClient
# 16                                UpdateCheckResponse
# 17             AnnotationBasedEntityEvolvingComponent
# 18         AggregateBasedAxonServerEventStorageEngine
# 19                                  DeepEqualsMatcher
# 20             UnitOfWork$UnitOfWorkProcessingContext
# 21                                     QueryConverter
# 22                                   CommandConverter
# 23                           AxonServerContainerUtils
# 24                    GapAwareTrackingTokenOperations
# 25                     MessagingConfigurationDefaults
# 26                                      TrackerStatus
# 27                         AnnotationBasedTagResolver
# 28                           AnnotatedEntityMetamodel
# 29                            ConcreteEntityMetamodel
#
#                                    maxLinesMethodName  maxLinesMethod  \
# 0                                                 run             111
# 1                                 appendEventOverview              45
# 2                                               build              42
# 3                                         isTestClass              41
# 4                          addEntityCreatorExecutable              40
# 5                                             convert              30
# 6                                              <init>              30
# 7                                             convert              29
# 8                                      buildConverter              29
# 9                             invokeLifecycleHandlers              26
# 10                                        updateToken              25
# 11  getExactDirectSuperTypesOfParameterizedTypeOrC...              24
# 12                                    getMatchOutcome              23
# 13                                             <init>              23
# 14                                         storeToken              22
# 15                                        sendRequest              21
# 16                                        fromRequest              21
# 17                                             evolve              21
# 18                              lambda$appendEvents$0              21
# 19                                     matchingFields              21
# 20                                       runNextPhase              21
# 21                                convertQueryMessage              21
# 22                               convertResultMessage              20
# 23                                      createContext              20
# 24                                    withGapsCleaned              20
# 25                                 registerComponents              19
# 26                                              split              19
# 27                                 createTagsForValue              19
# 28                       createOptionalChildForMember              18
# 29                                             <init>              18
#
#     linesInPackage
# 0             1417
# 1              733
# 2              698
# 3              163
# 4              197
# 5              292
# 6               97
# 7               86
# 8              304
# 9              668
# 10             455
# 11             608
# 12              46
# 13             702
# 14             231
# 15             169
# 16             143
# 17             120
# 18             540
# 19             318
# 20             339
# 21             325
# 22             186
# 23             199
# 24             457
# 25             253
# 26             253
# 27             599
# 28             321
# 29             268

# %% [markdown]
# ## Cyclomatic Complexity

# %% [markdown]
# ### Table 2a - Cyclomatic method complexity distribution
#
# This table shows the distribution of the cyclomatic complexity of methods per artifact.
# For each artifact the number of methods with the cyclomatic complexity = 1,2,3,... is shown to get an overview of how cyclomatic complexity is distributed over methods.
#
# Only the 15 artifacts with the highest method count sum and their cyclomatic method complexity distribution (limited by 40) is shown here. The whole table can be found in the CSV report `Cyclomatic_Method_Complexity_Distribution`.
#
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
cyclomatic_method_complexity_distribution_max_artifacts=15

cyclomatic_method_complexity_distribution=query_cypher_to_data_frame("../cypher/Overview/Cyclomatic_Method_Complexity_Distribution.cypher")
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.pivot(index='cyclomaticComplexity', columns='artifactName', values='methods')

# Fill missing values with zero
cyclomatic_method_complexity_distribution.fillna(0, inplace=True)

# Convert to integer
cyclomatic_method_complexity_distribution=cyclomatic_method_complexity_distribution.astype(int)

# Sort by column sum and then take only the first 10 columns
effective_method_line_count_sum_per_artifact = effective_method_line_count_distribution.sum()
cyclomatic_method_complexity_distribution = cyclomatic_method_complexity_distribution[effective_method_line_count_sum_per_artifact.sort_values(ascending=False).index[:cyclomatic_method_complexity_distribution_max_artifacts]]

cyclomatic_method_complexity_distribution.head(40)
# Out:
# artifactName          axon-messaging-5.0.2.jar  axon-common-5.0.2.jar  \
# cyclomaticComplexity
# 1                                         2926                    544
# 2                                          320                     91
# 3                                          153                     74
# 4                                           83                     31
# 5                                           29                     10
# 6                                           32                      7
# 7                                            8                      6
# 8                                            3                      8
# 9                                            1                      3
# 10                                           0                      1
# 11                                           1                      1
# 12                                           0                      1
# 13                                           1                      0
# 17                                           0                      0
# 21                                           0                      0
# 25                                           1                      0
# 41                                           0                      0
# 58                                           1                      0
#
# artifactName          axon-server-connector-5.0.2.jar  \
# cyclomaticComplexity
# 1                                                 536
# 2                                                  57
# 3                                                  26
# 4                                                   7
# 5                                                   5
# 6                                                   5
# 7                                                   1
# 8                                                   0
# 9                                                   2
# 10                                                  0
# 11                                                  0
# 12                                                  1
# 13                                                  0
# 17                                                  0
# 21                                                  0
# 25                                                  0
# 41                                                  0
# 58                                                  0
#
# artifactName          axon-eventsourcing-5.0.2.jar  axon-test-5.0.2.jar  \
# cyclomaticComplexity
# 1                                              463                  314
# 2                                               59                   40
# 3                                               38                   33
# 4                                               20                    7
# 5                                                8                    9
# 6                                                6                    5
# 7                                                5                    2
# 8                                                4                    2
# 9                                                0                    1
# 10                                               0                    0
# 11                                               1                    1
# 12                                               0                    0
# 13                                               1                    1
# 17                                               0                    0
# 21                                               0                    0
# 25                                               0                    0
# 41                                               0                    0
# 58                                               0                    0
#
# artifactName          axon-modelling-5.0.2.jar  \
# cyclomaticComplexity
# 1                                          311
# 2                                           27
# 3                                           23
# 4                                           16
# 5                                            7
# 6                                            5
# 7                                            1
# 8                                            1
# 9                                            0
# 10                                           0
# 11                                           0
# 12                                           0
# 13                                           0
# 17                                           0
# 21                                           0
# 25                                           0
# 41                                           0
# 58                                           0
#
# artifactName          axon-spring-boot-autoconfigure-5.0.2.jar  \
# cyclomaticComplexity
# 1                                                          288
# 2                                                           11
# 3                                                            7
# 4                                                            2
# 5                                                            1
# 6                                                            0
# 7                                                            1
# 8                                                            0
# 9                                                            2
# 10                                                           0
# 11                                                           0
# 12                                                           0
# 13                                                           0
# 17                                                           0
# 21                                                           0
# 25                                                           0
# 41                                                           0
# 58                                                           0
#
# artifactName          axon-conversion-5.0.2.jar  axon-update-5.0.2.jar  \
# cyclomaticComplexity
# 1                                           137                    119
# 2                                            14                     16
# 3                                             8                      5
# 4                                            11                      1
# 5                                             2                      3
# 6                                             3                      4
# 7                                             2                      2
# 8                                             1                      0
# 9                                             1                      1
# 10                                            1                      0
# 11                                            0                      1
# 12                                            0                      0
# 13                                            0                      0
# 17                                            1                      1
# 21                                            1                      0
# 25                                            0                      0
# 41                                            0                      1
# 58                                            0                      0
#
# artifactName          axon-metrics-micrometer-5.0.2.jar  \
# cyclomaticComplexity
# 1                                                    86
# 2                                                     3
# 3                                                     1
# 4                                                     0
# 5                                                     0
# 6                                                     2
# 7                                                     0
# 8                                                     0
# 9                                                     0
# 10                                                    0
# 11                                                    0
# 12                                                    0
# 13                                                    0
# 17                                                    0
# 21                                                    0
# 25                                                    0
# 41                                                    0
# 58                                                    0
#
# artifactName          axon-tracing-opentelemetry-5.0.2.jar
# cyclomaticComplexity
# 1                                                       30
# 2                                                        8
# 3                                                        2
# 4                                                        1
# 5                                                        0
# 6                                                        0
# 7                                                        0
# 8                                                        0
# 9                                                        0
# 10                                                       0
# 11                                                       0
# 12                                                       0
# 13                                                       0
# 17                                                       0
# 21                                                       0
# 25                                                       0
# 41                                                       0
# 58                                                       0

# %% [markdown]
# ### Table 2b - Cyclomatic method complexity distribution (normalized)
#
# The table shown here only includes the first 40 rows which typically represents the most significant entries.
# Have a look below to find out which packages and methods have the highest effective lines of code.

# %%
# Divide every value by the sum of all values in the same column to get vertical normalized values.
cyclomatic_method_complexity_distribution_normalized = cyclomatic_method_complexity_distribution.div(cyclomatic_method_complexity_distribution.sum(axis=0), axis=1).multiply(100)
cyclomatic_method_complexity_distribution_normalized.head(40)
# Out:
# artifactName          axon-messaging-5.0.2.jar  axon-common-5.0.2.jar  \
# cyclomaticComplexity
# 1                                    82.214105              70.012870
# 2                                     8.991290              11.711712
# 3                                     4.298960               9.523810
# 4                                     2.332116               3.989704
# 5                                     0.814836               1.287001
# 6                                     0.899129               0.900901
# 7                                     0.224782               0.772201
# 8                                     0.084293               1.029601
# 9                                     0.028098               0.386100
# 10                                    0.000000               0.128700
# 11                                    0.028098               0.128700
# 12                                    0.000000               0.128700
# 13                                    0.028098               0.000000
# 17                                    0.000000               0.000000
# 21                                    0.000000               0.000000
# 25                                    0.028098               0.000000
# 41                                    0.000000               0.000000
# 58                                    0.028098               0.000000
#
# artifactName          axon-server-connector-5.0.2.jar  \
# cyclomaticComplexity
# 1                                            83.75000
# 2                                             8.90625
# 3                                             4.06250
# 4                                             1.09375
# 5                                             0.78125
# 6                                             0.78125
# 7                                             0.15625
# 8                                             0.00000
# 9                                             0.31250
# 10                                            0.00000
# 11                                            0.00000
# 12                                            0.15625
# 13                                            0.00000
# 17                                            0.00000
# 21                                            0.00000
# 25                                            0.00000
# 41                                            0.00000
# 58                                            0.00000
#
# artifactName          axon-eventsourcing-5.0.2.jar  axon-test-5.0.2.jar  \
# cyclomaticComplexity
# 1                                        76.528926            75.662651
# 2                                         9.752066             9.638554
# 3                                         6.280992             7.951807
# 4                                         3.305785             1.686747
# 5                                         1.322314             2.168675
# 6                                         0.991736             1.204819
# 7                                         0.826446             0.481928
# 8                                         0.661157             0.481928
# 9                                         0.000000             0.240964
# 10                                        0.000000             0.000000
# 11                                        0.165289             0.240964
# 12                                        0.000000             0.000000
# 13                                        0.165289             0.240964
# 17                                        0.000000             0.000000
# 21                                        0.000000             0.000000
# 25                                        0.000000             0.000000
# 41                                        0.000000             0.000000
# 58                                        0.000000             0.000000
#
# artifactName          axon-modelling-5.0.2.jar  \
# cyclomaticComplexity
# 1                                    79.539642
# 2                                     6.905371
# 3                                     5.882353
# 4                                     4.092072
# 5                                     1.790281
# 6                                     1.278772
# 7                                     0.255754
# 8                                     0.255754
# 9                                     0.000000
# 10                                    0.000000
# 11                                    0.000000
# 12                                    0.000000
# 13                                    0.000000
# 17                                    0.000000
# 21                                    0.000000
# 25                                    0.000000
# 41                                    0.000000
# 58                                    0.000000
#
# artifactName          axon-spring-boot-autoconfigure-5.0.2.jar  \
# cyclomaticComplexity
# 1                                                    92.307692
# 2                                                     3.525641
# 3                                                     2.243590
# 4                                                     0.641026
# 5                                                     0.320513
# 6                                                     0.000000
# 7                                                     0.320513
# 8                                                     0.000000
# 9                                                     0.641026
# 10                                                    0.000000
# 11                                                    0.000000
# 12                                                    0.000000
# 13                                                    0.000000
# 17                                                    0.000000
# 21                                                    0.000000
# 25                                                    0.000000
# 41                                                    0.000000
# 58                                                    0.000000
#
# artifactName          axon-conversion-5.0.2.jar  axon-update-5.0.2.jar  \
# cyclomaticComplexity
# 1                                     75.274725              77.272727
# 2                                      7.692308              10.389610
# 3                                      4.395604               3.246753
# 4                                      6.043956               0.649351
# 5                                      1.098901               1.948052
# 6                                      1.648352               2.597403
# 7                                      1.098901               1.298701
# 8                                      0.549451               0.000000
# 9                                      0.549451               0.649351
# 10                                     0.549451               0.000000
# 11                                     0.000000               0.649351
# 12                                     0.000000               0.000000
# 13                                     0.000000               0.000000
# 17                                     0.549451               0.649351
# 21                                     0.549451               0.000000
# 25                                     0.000000               0.000000
# 41                                     0.000000               0.649351
# 58                                     0.000000               0.000000
#
# artifactName          axon-metrics-micrometer-5.0.2.jar  \
# cyclomaticComplexity
# 1                                             93.478261
# 2                                              3.260870
# 3                                              1.086957
# 4                                              0.000000
# 5                                              0.000000
# 6                                              2.173913
# 7                                              0.000000
# 8                                              0.000000
# 9                                              0.000000
# 10                                             0.000000
# 11                                             0.000000
# 12                                             0.000000
# 13                                             0.000000
# 17                                             0.000000
# 21                                             0.000000
# 25                                             0.000000
# 41                                             0.000000
# 58                                             0.000000
#
# artifactName          axon-tracing-opentelemetry-5.0.2.jar
# cyclomaticComplexity
# 1                                                73.170732
# 2                                                19.512195
# 3                                                 4.878049
# 4                                                 2.439024
# 5                                                 0.000000
# 6                                                 0.000000
# 7                                                 0.000000
# 8                                                 0.000000
# 9                                                 0.000000
# 10                                                0.000000
# 11                                                0.000000
# 12                                                0.000000
# 13                                                0.000000
# 17                                                0.000000
# 21                                                0.000000
# 25                                                0.000000
# 41                                                0.000000
# 58                                                0.000000

# %% [markdown]
# ### Table 2b Chart 1 - Cyclomatic method complexity distribution (normalized)

# %%
if cyclomatic_method_complexity_distribution_normalized.empty:
    print("No data to plot")
else:
    plot.figure();
    method_line_count_x_ticks=range(1,11)
    cyclomatic_complexity_y_ticks=[1, 2, 3, 4, 5, 7, 10, 20, 30, 40, 50, 100]
    axes = cyclomatic_method_complexity_distribution_normalized.plot(
        kind='line', 
        logx=True,
        logy=True,
        grid=True,
        xlim=[1,11],
        ylim=[1,100],
        xticks=method_line_count_x_ticks,
        yticks=cyclomatic_complexity_y_ticks,
        title='Cyclomatic complexity distribution of methods', 
        xlabel='cyclomatic complexity',
        ylabel='percentage of methods',
        cmap=main_color_map,
    )
    axes.set_xticklabels(method_line_count_x_ticks)
    axes.set_yticklabels(cyclomatic_complexity_y_ticks)
    axes.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plot.show()

# %% [markdown]
# ### Table 2c - Top 30 packages with highest cyclomatic complexity
#
# The following table shows the top 30 packages with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_package=method_statistics_per_package[['artifactName', 'fullPackageName', 'complexityInPackage', 'methodCount', 'maxComplexity','maxComplexityMethod']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_package=cyclomatic_complexity_per_package.sort_values(by='complexityInPackage', ascending=False)

# Print out the top 30 (head) rows
cyclomatic_complexity_per_package.head(30)
# Out:
#                             artifactName  \
# 1                   axon-messaging-5.0.2
# 0                   axon-messaging-5.0.2
# 6                      axon-common-5.0.2
# 7               axon-eventsourcing-5.0.2
# 3                   axon-messaging-5.0.2
# 5                      axon-common-5.0.2
# 4            axon-server-connector-5.0.2
# 2                        axon-test-5.0.2
# 15                  axon-messaging-5.0.2
# 12                  axon-messaging-5.0.2
# 8            axon-server-connector-5.0.2
# 9               axon-eventsourcing-5.0.2
# 11                  axon-messaging-5.0.2
# 10                  axon-messaging-5.0.2
# 17  axon-spring-boot-autoconfigure-5.0.2
# 16                       axon-test-5.0.2
# 18                 axon-conversion-5.0.2
# 21  axon-spring-boot-autoconfigure-5.0.2
# 24                     axon-common-5.0.2
# 23                  axon-messaging-5.0.2
# 37                  axon-messaging-5.0.2
# 22                  axon-messaging-5.0.2
# 14                  axon-modelling-5.0.2
# 13           axon-server-connector-5.0.2
# 20                  axon-modelling-5.0.2
# 43                  axon-messaging-5.0.2
# 28                  axon-messaging-5.0.2
# 29                  axon-messaging-5.0.2
# 26                  axon-messaging-5.0.2
# 19         axon-metrics-micrometer-5.0.2
#
#                                       fullPackageName  complexityInPackage  \
# 1                    org.axonframework.messaging.core                  731
# 0   org.axonframework.messaging.eventhandling.proc...                  546
# 6                            org.axonframework.common                  383
# 7          org.axonframework.eventsourcing.eventstore                  375
# 3         org.axonframework.messaging.core.annotation                  371
# 5              org.axonframework.common.configuration                  358
# 4              org.axonframework.axonserver.connector                  357
# 2                      org.axonframework.test.fixture                  322
# 15  org.axonframework.messaging.eventhandling.proc...                  249
# 12        org.axonframework.messaging.core.unitofwork                  224
# 8        org.axonframework.axonserver.connector.event                  218
# 9      org.axonframework.eventsourcing.eventstore.jpa                  217
# 11          org.axonframework.messaging.queryhandling                  216
# 10  org.axonframework.messaging.eventhandling.proc...                  196
# 17  org.axonframework.extension.springboot.autoconfig                  177
# 16                    org.axonframework.test.matchers                  173
# 18                  org.axonframework.conversion.avro                  159
# 21             org.axonframework.extension.springboot                  150
# 24                   org.axonframework.common.caching                  147
# 23  org.axonframework.messaging.eventhandling.proc...                  147
# 37  org.axonframework.messaging.eventhandling.anno...                  143
# 22     org.axonframework.messaging.core.configuration                  131
# 14      org.axonframework.modelling.entity.annotation                  130
# 13       org.axonframework.axonserver.connector.query                  127
# 20                 org.axonframework.modelling.entity                  119
# 43         org.axonframework.messaging.eventstreaming                  119
# 28        org.axonframework.messaging.commandhandling                  117
# 29          org.axonframework.messaging.eventhandling                  106
# 26  org.axonframework.messaging.eventhandling.proc...                   99
# 19     org.axonframework.extension.metrics.micrometer                   99
#
#     methodCount  maxComplexity               maxComplexityMethod
# 1           531              9                           process
# 0           397             25                               run
# 6           182              9               fieldNameFromMember
# 7           233              8                              from
# 3           235             13                   resolveToStream
# 5           262              8                      hasComponent
# 4           278             12                             build
# 2           204             11               appendEventOverview
# 15          121              7                            equals
# 12          168              6                            commit
# 8           162              4                      splitSegment
# 9           141              8             loadKeyViolationCodes
# 11          172              4                subscribeToUpdates
# 10          130              8                       updateToken
# 17          134              9       registerHandlerInterceptors
# 16          101              8                       matchesList
# 18           81             21                           convert
# 21          147              2                       threadCount
# 24           85              8                           onEvent
# 23           94              8                       isDifferent
# 37           60             58                    parseParameter
# 22          119              4       lambda$registerDecorators$9
# 14           75              6       createCommandTargetResolver
# 13           90              6               responseSendingLoop
# 20           76              7                    handleInstance
# 43           92              4                                or
# 28          100              4                         subscribe
# 29           86              4                       andMetadata
# 26           50              6                            equals
# 19           87              6  registerComponentWithDefaultTags

# %% [markdown]
# ### Table 2d - Top 30 methods with highest cyclomatic complexity
#
# The following table shows the top 30 packages containing the methods with the highest cyclomatic complexity. The whole table can be found in the CSV report `Effective_lines_of_method_code_per_package`.

# %%
# Select and order the columns for this particular table 
cyclomatic_complexity_per_method=method_statistics_per_package[['artifactName', 'fullPackageName', 'maxComplexityType', 'maxComplexityMethod', 'maxComplexity']]

# Sort by the method with the highest cyclomatic complexity per package descending
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.sort_values(by='maxComplexity', ascending=False)

# Reset the index to the new sort order
cyclomatic_complexity_per_method=cyclomatic_complexity_per_method.reset_index()

# Print out the top 30 (head) rows
cyclomatic_complexity_per_method.head(30)
# Out:
#     index                          artifactName  \
# 0      37                  axon-messaging-5.0.2
# 1      42                     axon-update-5.0.2
# 2       0                  axon-messaging-5.0.2
# 3      18                 axon-conversion-5.0.2
# 4      65                 axon-conversion-5.0.2
# 5      46                     axon-update-5.0.2
# 6      32              axon-eventsourcing-5.0.2
# 7       3                  axon-messaging-5.0.2
# 8      31                       axon-test-5.0.2
# 9      49                     axon-common-5.0.2
# 10      4           axon-server-connector-5.0.2
# 11      2                       axon-test-5.0.2
# 12     61              axon-eventsourcing-5.0.2
# 13     53                     axon-common-5.0.2
# 14      1                  axon-messaging-5.0.2
# 15      6                     axon-common-5.0.2
# 16     17  axon-spring-boot-autoconfigure-5.0.2
# 17     68                     axon-common-5.0.2
# 18     24                     axon-common-5.0.2
# 19      5                     axon-common-5.0.2
# 20     23                  axon-messaging-5.0.2
# 21      9              axon-eventsourcing-5.0.2
# 22     10                  axon-messaging-5.0.2
# 23     16                       axon-test-5.0.2
# 24      7              axon-eventsourcing-5.0.2
# 25     36                  axon-modelling-5.0.2
# 26     93              axon-eventsourcing-5.0.2
# 27     72                     axon-common-5.0.2
# 28     15                  axon-messaging-5.0.2
# 29     38                 axon-conversion-5.0.2
#
#                                       fullPackageName  \
# 0   org.axonframework.messaging.eventhandling.anno...
# 1                  org.axonframework.update.detection
# 2   org.axonframework.messaging.eventhandling.proc...
# 3                   org.axonframework.conversion.avro
# 4                   org.axonframework.conversion.json
# 5                        org.axonframework.update.api
# 6   org.axonframework.eventsourcing.annotation.ref...
# 7         org.axonframework.messaging.core.annotation
# 8                       org.axonframework.test.server
# 9                       org.axonframework.common.jdbc
# 10             org.axonframework.axonserver.connector
# 11                     org.axonframework.test.fixture
# 12         org.axonframework.eventsourcing.annotation
# 13                      org.axonframework.common.lock
# 14                   org.axonframework.messaging.core
# 15                           org.axonframework.common
# 16  org.axonframework.extension.springboot.autoconfig
# 17                org.axonframework.common.annotation
# 18                   org.axonframework.common.caching
# 19             org.axonframework.common.configuration
# 20  org.axonframework.messaging.eventhandling.proc...
# 21     org.axonframework.eventsourcing.eventstore.jpa
# 22  org.axonframework.messaging.eventhandling.proc...
# 23                    org.axonframework.test.matchers
# 24         org.axonframework.eventsourcing.eventstore
# 25           org.axonframework.modelling.entity.child
# 26    org.axonframework.eventsourcing.eventstore.jdbc
# 27                      org.axonframework.common.util
# 28  org.axonframework.messaging.eventhandling.proc...
# 29                       org.axonframework.conversion
#
#                                     maxComplexityType  \
# 0   MethodSequencingPolicyEventHandlerDefinition$S...
# 1                             TestEnvironmentDetector
# 2                        Coordinator$CoordinationTask
# 3                                       AvroConverter
# 4                                    JacksonConverter
# 5                                 UpdateCheckResponse
# 6            AnnotationBasedEventSourcedEntityFactory
# 7                          MessageStreamResolverUtils
# 8                                 AxonServerContainer
# 9                            ConnectionWrapperFactory
# 10                AxonServerConnectionManager$Builder
# 11                                           Reporter
# 12  AnnotationBasedEventCriteriaResolver$WrappedEv...
# 13              PessimisticLockFactory$DisposableLock
# 14                         MessageStreamUtils$Reducer
# 15                                    ReflectionUtils
# 16                       InterceptorAutoConfiguration
# 17                                    AnnotationUtils
# 18           EhCacheAdapter$CacheEventListenerAdapter
# 19                           DefaultComponentRegistry
# 20                                 EventTrackerStatus
# 21                              SQLErrorCodesResolver
# 22                                     JdbcTokenStore
# 23                                    SequenceMatcher
# 24                    AggregateBasedConsistencyMarker
# 25                    FieldChildEntityFieldDefinition
# 26                JdbcTransactionalExecutorProvider$1
# 27                                   PriorityRunnable
# 28                                        ReplayToken
# 29                   ChainedConverter$RouteCalculator
#
#               maxComplexityMethod  maxComplexity
# 0                  parseParameter             58
# 1                     isTestClass             41
# 2                             run             25
# 3                         convert             21
# 4                         convert             17
# 5                     fromRequest             17
# 6      addEntityCreatorExecutable             13
# 7                 resolveToStream             13
# 8                          equals             13
# 9                   lambda$wrap$0             12
# 10                          build             12
# 11            appendEventOverview             11
# 12                         <init>             11
# 13                           lock             10
# 14                        process              9
# 15            fieldNameFromMember              9
# 16    registerHandlerInterceptors              9
# 17              collectAttributes              8
# 18                        onEvent              8
# 19                   hasComponent              8
# 20                    isDifferent              8
# 21          loadKeyViolationCodes              8
# 22                    updateToken              8
# 23                    matchesList              8
# 24                           from              8
# 25  evolveParentBasedOnChildInput              8
# 26                      applyInTx              7
# 27                         equals              7
# 28                         equals              7
# 29                 calculateRoute              7
