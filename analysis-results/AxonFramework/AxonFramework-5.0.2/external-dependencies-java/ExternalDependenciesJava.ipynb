# %% [markdown]
# # External Dependencies for Java
# <br>
#
# ### References
# - [jqassistant](https://jqassistant.org)
# - [Neo4j Python Driver](https://neo4j.com/docs/api/python-driver/current)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plot
from neo4j import GraphDatabase

# %%
# Please set the environment variable "NEO4J_INITIAL_PASSWORD" in your shell 
# before starting jupyter notebook to provide the password for the user "neo4j". 
# It is not recommended to hardcode the password into jupyter notebook for security reasons.

driver = GraphDatabase.driver(uri="bolt://localhost:7687", auth=("neo4j", os.environ.get("NEO4J_INITIAL_PASSWORD")))
driver.verify_connectivity()

# %%
def get_cypher_query_from_file(filename):
    with open(filename) as file:
        return ' '.join(file.readlines())


def query_cypher_to_data_frame(filename):
    records, summary, keys = driver.execute_query(get_cypher_query_from_file(filename))
    return pd.DataFrame([r.values() for r in records], columns=keys)

# %%
def group_to_others_below_threshold(data_frame : pd.DataFrame, value_column : str, name_column: str, threshold: float) -> pd.DataFrame:    
    """
    Adds a new percentage column for the value column and 
    groups all values below the given threshold to "others" in the name column.

    Parameters:
    - data_frame (pd.DataFrame): Input pandas DataFrame
    - value_column (str): Name of the column that contains the numeric value
    - name_column (str): Name of the column that contains the group name that will be replaced by "others" for small values
    - threshold (float): Threshold in % that is used to group values below it into the "others" group

    Returns:
    int:Returning value

    """
    result_data_frame = data_frame[[name_column, value_column]].copy();

    percent_column_name = value_column + 'Percent';

    # Add column with the name given in "percent_column_name" with the percentage of the value column.
    result_data_frame[percent_column_name] = result_data_frame[value_column] / result_data_frame[value_column].sum() * 100.0;

    # Convert name column to string values if it wasn't of that type before
    result_data_frame[name_column] = result_data_frame[name_column].astype(str)

    # Change the group name to "others" if it is called less than the specified threshold
    result_data_frame.loc[result_data_frame[percent_column_name] < threshold, name_column] = 'others';

    # Group by name column (foremost the new "others" entries) and sum their percentage
    #result_data_frame = result_data_frame.groupby(name_column)[percent_column_name].sum();
    result_data_frame = result_data_frame.groupby(name_column).sum();
    # Sort by values descending
    #return result_data_frame.sort_values(ascending=False).to_frame();
    return result_data_frame.sort_values(by=percent_column_name, ascending=False);

# %%
def filter_values_below_threshold(data_frame : pd.DataFrame, value_column : str, upper_limit: float = 100.0) -> pd.DataFrame:    
    """
    Adds a new percentage column for the value column and 
    groups all values below the given threshold to "others" in the name column.

    Parameters:
    - data_frame (pd.DataFrame): Input pandas DataFrame
    - value_column (str): Name of the column that contains the numeric value
    - upper_limit (float): Defaults to 100%. Filters out all entries exceeding this limit. Intended to drill down "others" in a second chart/table.

    Returns:
    int:Returning value

    """
    result_data_frame = data_frame.copy();

    percent_column_name = value_column + 'Percent';

    # Add column with the name given in "percent_column_name" with the percentage of the value column.
    result_data_frame[percent_column_name] = result_data_frame[value_column] / result_data_frame[value_column].sum() * 100.0;

    # Limit entries to meet the an optional upper limit (in percentage)
    result_data_frame = result_data_frame.query("`" + percent_column_name + "` <= " + str(upper_limit))

    result_data_frame = result_data_frame.reset_index(drop=True)
    return result_data_frame.sort_values(by=percent_column_name, ascending=False);

# %%
def explode_index_value(input_data_frame: pd.DataFrame, index_value_to_emphasize: str = 'others', base_value: float = 0.02, emphasize_value: float = 0.2):
    """
    "Explode" offsets slices in a pie chart plot by a given value.
    The specified index value will be emphasized with a larger value to make it stand out in the pie chart plot.

    Parameters:
    - input_data_frame (pd.DataFrame): Input pandas DataFrame with the data that will be plot. (Required)
    - index_value_to_emphasize (str): Value of the index that will be emphasized. (Default= 'others')
    - base_value (float): Base value for all pies in the chart. (Default=0.02)
    - emphasize_value (float): Value for the emphasized pie in the chart. (Default=0.2)

    Returns:
    Array with the same size as the number of rows/pies to plot containing the "explode" value for each of them

    """
    # Each entry in the list corresponds to an x value
    # The comparison with the index_value_to_emphasize produces an array of booleans where nth entry with the emphasized value is "true"
    # Multiplying it leads to 1 for True and 0 for False therefore "exploding" the emphasized entry whilst 
    return (input_data_frame.index == index_value_to_emphasize) * emphasize_value + base_value

# %%
def plot_pie_chart(input_data_frame: pd.DataFrame, title: str):
    if input_data_frame.empty:
        print("No data to plot for title '" + title + "'.")
        return
    
    name_of_the_first_column_containing_the_values=input_data_frame.columns[0]
    total_sum = input_data_frame[name_of_the_first_column_containing_the_values].sum()
    
    def custom_auto_percentage_format(percentage):
        return '{:1.2f}% ({:.0f})'.format(percentage, total_sum * percentage / 100.0)
        
    plot.figure();

    axis = input_data_frame.plot(
        kind='pie',
        y=name_of_the_first_column_containing_the_values + 'Percent',
        ylabel='',
        legend=True,
        labeldistance=None,
        autopct=custom_auto_percentage_format,
        textprops={'fontsize': 6},
        pctdistance=1.15,
        cmap=main_color_map,
        figsize=(9,9),
        explode=explode_index_value(input_data_frame, index_value_to_emphasize='others')
    )
    plot.title(title, pad=15)
    axis.legend(bbox_to_anchor=(1.08, 1), loc='upper left')
    plot.show()

# %%
#The following cell uses the build-in %html "magic" to override the CSS style for tables to a much smaller size.
#This is especially needed for PDF export of tables with multiple columns.

# %%
# %%html
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>
# Out:
# <style>
# /* CSS style for smaller dataframe tables. */
# .dataframe th {
#     font-size: 8px;
# }
# .dataframe td {
#     font-size: 8px;
# }
# </style>

# %%
# Main Colormap
main_color_map = 'nipy_spectral'

# %% [markdown]
# ## External Package Usage
#
# ### External Package
#
# An external type has no `byteCodeVersion` since it only occurs as a dependency but wasn't analyzed itself (missing bytecode). Core Java types like `java.lang.Integer` and primitives like `int` are considered "build-in" and therefore aren't interpreted as "external" even though their byte code is also missing. A package is categorized as "external" if the types it contains are classified as external.
#
# ### External annotation dependency
#
# The aforementioned classification encompasses external annotation dependencies as well. These dependencies introduce significantly less coupling and are not indispensable for compiling code. Without the external annotation the code would most probably behave differently. Hence, they are included in the first more overall and general tables and then left out in the later more specific ones.

# %% [markdown]
# ### Table 1 - Top 20 most used external packages overall
#
# This table shows the external packages that are used by the most different internal types overall.
# Additionally, it shows which types of the external package are actually used. External annotations are also listed.
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_overall`
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalCallerPackages* refers to the distinct packages that make use of the external package
# - *numberOfExternalCallerTypes* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every dependency to the types in the external package
# - *numberOfExternalTypeCallsWeighted* includes every invocation or reference (sum of weights) to the types in the external package
# - *allPackages* contains the total count of all analyzed packages in general
# - *allTypes* contains the total count of all analyzed types in general
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
external_package_usage=query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_overall.cypher")

# Select columns and only show the first 20 entries (head)
external_package_usage.head(20)
# Out:
#                           externalPackageName  numberOfExternalCallerPackages  \
# 0                          jakarta.annotation                             102
# 1                                   org.slf4j                              38
# 2              io.axoniq.axonserver.connector                               5
# 3                   io.axoniq.axonserver.grpc                               5
# 4                         jakarta.persistence                               5
# 5                      reactor.core.publisher                               5
# 6            com.fasterxml.jackson.annotation                               3
# 7              com.fasterxml.jackson.databind                               3
# 8                                     io.grpc                               3
# 9                                org.hamcrest                               3
# 10                        org.reactivestreams                               3
# 11    org.springframework.boot.actuate.health                               3
# 12        com.fasterxml.jackson.databind.node                               2
# 13          io.axoniq.axonserver.grpc.control                               2
# 14                               io.grpc.stub                               2
# 15              io.micrometer.core.instrument                               2
# 16                            org.apache.avro                               2
# 17                    org.apache.avro.message                               2
# 18  org.axonframework.extension.spring.config                               2
# 19     org.springframework.boot.autoconfigure                               2
#
#     numberOfExternalCallerTypes  numberOfExternalTypeCalls  \
# 0                           684                        870
# 1                            74                        133
# 2                            16                         23
# 3                            18                         40
# 4                            18                         42
# 5                             8                         14
# 6                             6                         18
# 7                             9                         14
# 8                             7                         23
# 9                            22                         44
# 10                            6                          8
# 11                            4                          7
# 12                            3                          5
# 13                            6                         13
# 14                            3                          4
# 15                           12                         38
# 16                            5                         17
# 17                            9                         12
# 18                            5                         13
# 19                           20                         30
#
#     numberOfExternalTypeCallsWeighted  allPackages  allTypes  \
# 0                                4811          116      1211
# 1                                 471          116      1211
# 2                                 124          116      1211
# 3                                 271          116      1211
# 4                                 161          116      1211
# 5                                  49          116      1211
# 6                                  34          116      1211
# 7                                  67          116      1211
# 8                                  51          116      1211
# 9                                 196          116      1211
# 10                                 27          116      1211
# 11                                 24          116      1211
# 12                                 28          116      1211
# 13                                 86          116      1211
# 14                                 11          116      1211
# 15                                140          116      1211
# 16                                 56          116      1211
# 17                                 38          116      1211
# 18                                 42          116      1211
# 19                                 31          116      1211
#
#                                  tenExternalTypeNames
# 0                                 [Nonnull, Nullable]
# 1                             [Logger, LoggerFactory]
# 2   [AxonServerConnection, AxonServerConnectionFac...
# 3   [ErrorMessage, MetaDataValue$DataCase, Instruc...
# 4   [EntityManagerFactory, PersistenceContext, Ent...
# 5                    [MonoSink, Mono, Flux, FluxSink]
# 6   [JsonTypeInfo, JsonProperty, JsonTypeInfo$Id, ...
# 7   [ObjectMapper, JsonNode, JavaType, Serializati...
# 8   [ManagedChannelBuilder, ClientInterceptor, Sta...
# 9   [CoreMatchers, StringDescription, Description,...
# 10              [Publisher, Subscription, Subscriber]
# 11  [Status, AbstractHealthIndicator, Health$Build...
# 12              [JsonNodeType, ObjectNode, ArrayNode]
# 13  [TopologyChange, UpdateType, QuerySubscription...
# 14  [StreamObserver, ClientCallStreamObserver, Cli...
# 15  [Tags, Clock, Gauge$Builder, Tag, MeterRegistr...
# 16  [Schema, SchemaCompatibility$SchemaCompatibili...
# 17  [SchemaStore, SchemaStore$Cache, BadHeaderExce...
# 18  [EventProcessorSettings$SubscribingEventProces...
# 19  [AutoConfiguration, AutoConfigureBefore, AutoC...

# %% [markdown]
# #### Table 1 Chart 1a - Most called external packages in % by types (more than 0.7% overall)
#
# External packages that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_package_by_type_usage_significant = group_to_others_below_threshold(
    data_frame=external_package_usage,
    value_column='numberOfExternalCallerTypes',
    name_column='externalPackageName',
    threshold= 0.7
)
plot_pie_chart(
    input_data_frame=external_package_by_type_usage_significant,
    title='Top external package usage [%] by type (more than 0.7% overall)'
)

# %% [markdown]
# #### Table 1 Chart 1b - Most called external packages in % by types (less than 0.7% overall "others" drill-down)
#
# Shows the lowest (less than 0.7% overall) most called external package. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_package_by_type_usage_drill_down_others=filter_values_below_threshold(external_package_usage, 'numberOfExternalCallerTypes', 0.7)

external_package_by_type_usage_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_package_by_type_usage_drill_down_others,
    value_column='numberOfExternalCallerTypes',
    name_column='externalPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_package_by_type_usage_significant_drill_down_others,
    title='Top external package usage [%] by type (less than 0.7% overall "others" drill-down)'
)

# %% [markdown]
# #### Table 1 Chart 2a - Most called external packages in % by packages (more than 0.7% overall)
#
# External packages that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_package_by_package_usage_significant = group_to_others_below_threshold(
    data_frame=external_package_usage,
    value_column='numberOfExternalCallerPackages',
    name_column='externalPackageName',
    threshold= 0.7
)
plot_pie_chart(
    input_data_frame=external_package_by_package_usage_significant,
    title='Top external package usage [%] by package (more than 0.7% overall)'
)

# %% [markdown]
# #### Table 1 Chart 2b - Most called external packages in % by packages (less than 0.7% overall "others" drill-down)
#
# Shows the lowest (less than 0.7% overall) most called external package. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_package_usage_by_package_drill_down_others=filter_values_below_threshold(external_package_usage, 'numberOfExternalCallerPackages', 0.7)

external_package_by_package_usage_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_package_usage_by_package_drill_down_others,
    value_column='numberOfExternalCallerPackages',
    name_column='externalPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_package_by_package_usage_significant_drill_down_others,
    title='Top external package usage [%] by package (less than 0.7% overall "others" drill-down)'
)

# %% [markdown]
# ### Table 2 - Top 20 most used external packages grouped by their first 2 layers
#
# This table shows external packages grouped by their first 2 layers that are used by the most different internal types overall including external annotations. For example, "javax.xml.stream" and "javax.xml.parsers" are grouped together to "javax.xml".
#
# Additionally, it shows which types of the external packages are actually used.
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_second_level_package_usage_overall`
#
# **Columns:**
# - *externalSecondLevelPackageName* identifies the first 2 levels of the external package as described above
# - *numberOfExternalCallerPackages* refers to the distinct packages that make use of the external package
# - *numberOfExternalCallerTypes* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every dependency to the types in the external package
# - *numberOfExternalTypeCallsWeighted* includes every invocation or reference (sum of weights) to the types in the external package
# - *allPackages* contains the total count of all analyzed packages in general
# - *allTypes* contains the total count of all analyzed types in general
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
external_grouped_package_usage=query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_overall.cypher")
external_grouped_package_usage.head(20)
# Out:
#    externalSecondLevelPackageName  numberOfExternalCallerPackages  \
# 0              jakarta.annotation                             102
# 1                       org.slf4j                              38
# 2             org.springframework                               7
# 3                   com.fasterxml                               6
# 4                       io.axoniq                               6
# 5                    reactor.core                               6
# 6                      com.google                               5
# 7             jakarta.persistence                               5
# 8                         io.grpc                               3
# 9               org.axonframework                               3
# 10                   org.hamcrest                               3
# 11            org.reactivestreams                               3
# 12                  io.micrometer                               2
# 13                     org.apache                               2
# 14               io.opentelemetry                               1
# 15             jakarta.validation                               1
# 16                    javax.cache                               1
# 17                 org.awaitility                               1
# 18                    org.ehcache                               1
# 19             org.testcontainers                               1
#
#     numberOfExternalCallerTypes  numberOfExternalTypeCalls  \
# 0                           684                        870
# 1                            74                        133
# 2                            56                        183
# 3                            16                         40
# 4                            45                        153
# 5                             9                         16
# 6                             9                         12
# 7                            18                         42
# 8                            10                         29
# 9                            10                         20
# 10                           22                         44
# 11                            6                          8
# 12                           12                         39
# 13                           12                         42
# 14                            5                         21
# 15                            2                          5
# 16                            2                         12
# 17                            1                          2
# 18                            3                         10
# 19                            1                          6
#
#     numberOfExternalTypeCallsWeighted  allPackages  allTypes  \
# 0                                4811          116      1211
# 1                                 471          116      1211
# 2                                 306          116      1211
# 3                                 138          116      1211
# 4                                 849          116      1211
# 5                                  51          116      1211
# 6                                  36          116      1211
# 7                                 161          116      1211
# 8                                  65          116      1211
# 9                                  57          116      1211
# 10                                196          116      1211
# 11                                 27          116      1211
# 12                                142          116      1211
# 13                                145          116      1211
# 14                                 70          116      1211
# 15                                 16          116      1211
# 16                                 48          116      1211
# 17                                  3          116      1211
# 18                                 45          116      1211
# 19                                 19          116      1211
#
#                                  tenExternalTypeNames
# 0                                 [Nonnull, Nullable]
# 1                             [Logger, LoggerFactory]
# 2   [NestedConfigurationProperty, ConfigurationPro...
# 3   [CBORMapper, ObjectMapper, JsonTypeInfo, JsonP...
# 4   [ControlChannel, AxonServerConnection, ErrorMe...
# 5   [MonoSink, Mono, Flux, FluxSink, Schedulers, S...
# 6   [JsonParser, JsonElement, JsonArray, JsonObjec...
# 7   [EntityManagerFactory, PersistenceContext, Ent...
# 8   [StreamObserver, ManagedChannelBuilder, GrpcSs...
# 9   [EventProcessorSettings$SubscribingEventProces...
# 10  [CoreMatchers, StringDescription, Description,...
# 11              [Publisher, Subscription, Subscriber]
# 12  [Tags, Clock, Gauge$Builder, Tag, MeterRegistr...
# 13  [SchemaStore, SchemaStore$Cache, Schema, Gener...
# 14  [Span, StatusCode, SpanBuilder, Scope, SpanCon...
# 15  [ConstraintViolation, Validator, ValidatorFact...
# 16  [CacheEntryEventFilter, CacheEntryListenerExce...
# 17                     [Awaitility, ConditionFactory]
# 18  [CacheEvent, CacheEventListener, EventType, Ca...
# 19  [DockerImageName, ContainerLaunchException, Mo...

# %% [markdown]
# #### Table 2 Chart 1a - Most called second level external packages in % by type
#
# External package groups that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_by_type_usage_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage,
    value_column='numberOfExternalCallerTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.7
);
plot_pie_chart(
    input_data_frame=external_grouped_package_by_type_usage_significant,
    title='Top external package (grouped by first 2 layers) usage [%] by type (more than 0.7% overall)'
)

# %% [markdown]
# #### Table 2 Chart 1b - Most called second level external packages in % by type (less than 0.7% overall "others" drill-down)
#
# Shows the lowest (less than 0.7% overall) most called external package. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_grouped_package_by_type_usage_drill_down_others=filter_values_below_threshold(external_grouped_package_usage, 'numberOfExternalCallerTypes', 0.7)

external_grouped_package_by_type_usage_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_grouped_package_by_type_usage_drill_down_others,
    value_column='numberOfExternalCallerTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_grouped_package_by_type_usage_significant_drill_down_others,
    title='Top external package (grouped by first 2 layers) usage [%] by type (less than 0.7% overall "others" drill-down)'
)

# %% [markdown]
# #### Table 2 Chart 2a - Most called second level external packages in % by package (more than 0.7% overall)
#
# External package groups that are used less than 0.7% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_by_package_usage_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage,
    value_column='numberOfExternalCallerPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.7
);
plot_pie_chart(
    input_data_frame=external_grouped_package_by_package_usage_significant,
    title='Top external package (grouped by first 2 layers) usage [%] by package (more than 0.7% overall)'
)

# %% [markdown]
# #### Table 2 Chart 2b - Most called second level external packages in % by package (less than 0.7% overall "others" drill-down)
#
# Shows the lowest (less than 0.7% overall) most called external package. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_grouped_package_by_package_usage_drill_down_others=filter_values_below_threshold(external_grouped_package_usage, 'numberOfExternalCallerPackages', 0.7)

external_grouped_package_by_package_usage_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_grouped_package_by_type_usage_drill_down_others,
    value_column='numberOfExternalCallerPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_grouped_package_by_package_usage_significant_drill_down_others,
    title='Top external package (grouped by first 2 layers) usage [%] by package (less than 0.7% overall "others" drill-down)'
)

# %% [markdown]
# ### Table 3 - Top 20 most widely spread external packages
#
# The following tables shows external packages that are used by many different artifacts with the highest number of artifacts first. External annotations are filtered out to only get those external packages that significantly add to coupling.
#
# Statistics like minimum, maximum, average, median and standard deviation are provided for the number of packages and number of types in every artifact that uses the listed external package.
#
# The intuition behind that is to find external package dependencies that are used in a widely spread manner. This should uncover libraries and frameworks and make it easier to distinguish them from external dependencies that are used for specific tasks. It can also be used to find external dependencies that are used sparsely regarding artifacts but are used in many different packages there. This could then be improved by applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture).
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_spread`
#
# **Columns:**
# - *externalPackageName* identifies the external package as defined above. All other columns contain aggregated data for this external package.
# - *numberOfArtifacts* contains the number of artifacts that use the external package
# - *sumNumberOfPackages* contains the sum of all packages that use the external package
# - *min/max/med/avg/stdNumberOfPackages* provide statistics based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfTypes* provide statistics based on the number of types of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of types of each artifact that uses the external package
# - *someArtifactNames* contain some of the artifacts that contain the external package for reference

# %%
# Query the graph database to provide the 
# most widely spread external dependencies for the tables/charts below.
external_package_usage_spread=query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_spread.cypher")
external_package_usage_spread.head(10)
# Out:
#                       externalPackageName  numberOfArtifacts  \
# 0                               org.slf4j                 11
# 1                     jakarta.persistence                  4
# 2          com.fasterxml.jackson.databind                  3
# 3     com.fasterxml.jackson.databind.node                  2
# 4          io.axoniq.axonserver.connector                  2
# 5  io.axoniq.axonserver.connector.control                  2
# 6                         org.apache.avro                  2
# 7                 org.apache.avro.message                  2
# 8                 IdTypeParameterResolver                  1
# 9                    ScannedEntityCreator                  1
#
#    sumNumberOfPackages  minNumberOfPackages  maxNumberOfPackages  \
# 0                   38                    1                   14
# 1                    5                    1                    2
# 2                    3                    1                    1
# 3                    2                    1                    1
# 4                    5                    1                    4
# 5                    3                    1                    2
# 6                    2                    1                    1
# 7                    2                    1                    1
# 8                    1                    1                    1
# 9                    1                    1                    1
#
#    medNumberOfPackages  avgNumberOfPackages  stdNumberOfPackages  \
# 0                  3.0             3.454545             3.670521
# 1                  1.0             1.250000             0.500000
# 2                  1.0             1.000000             0.000000
# 3                  1.0             1.000000             0.000000
# 4                  2.5             2.500000             2.121320
# 5                  1.5             1.500000             0.707107
# 6                  1.0             1.000000             0.000000
# 7                  1.0             1.000000             0.000000
# 8                  1.0             1.000000             0.000000
# 9                  1.0             1.000000             0.000000
#
#    minNumberOfPackagesPercentage  maxNumberOfPackagesPercentage  ...  \
# 0                      20.000000                     100.000000  ...
# 1                       1.754386                      28.571429  ...
# 2                       6.666667                      25.000000  ...
# 3                       6.666667                      25.000000  ...
# 4                      14.285714                      80.000000  ...
# 5                      14.285714                      40.000000  ...
# 6                      14.285714                      25.000000  ...
# 7                      14.285714                      25.000000  ...
# 8                      12.500000                      12.500000  ...
# 9                      12.500000                      12.500000  ...
#
#    maxNumberOfTypes  medNumberOfTypes  avgNumberOfTypes  stdNumberOfTypes  \
# 0                30               3.0          6.727273          8.486353
# 1                 6               4.5          4.250000          1.707825
# 2                 5               3.0          3.000000          2.000000
# 3                 2               1.5          1.500000          0.707107
# 4                15               8.0          8.000000          9.899495
# 5                 4               2.5          2.500000          2.121320
# 6                 4               2.5          2.500000          2.121320
# 7                 6               4.5          4.500000          2.121320
# 8                 1               1.0          1.000000          0.000000
# 9                 1               1.0          1.000000          0.000000
#
#    minNumberOfTypesPercentage  maxNumberOfTypesPercentage  \
# 0                    1.369863                   30.434783
# 1                    0.350877                    6.944444
# 2                    0.641026                   16.666667
# 3                    0.641026                    6.666667
# 4                    1.388889                   20.833333
# 5                    1.388889                    5.555556
# 6                    1.388889                   13.333333
# 7                    4.166667                   20.000000
# 8                    0.961538                    0.961538
# 9                    0.961538                    0.961538
#
#    medNumberOfTypesPercentage  avgNumberOfTypesPercentage  \
# 0                    5.769231                    9.847982
# 1                    4.166667                    3.907164
# 2                    4.166667                    7.158120
# 3                    3.653846                    3.653846
# 4                   11.111111                   11.111111
# 5                    3.472222                    3.472222
# 6                    7.361111                    7.361111
# 7                   12.083333                   12.083333
# 8                    0.961538                    0.961538
# 9                    0.961538                    0.961538
#
#    stdNumberOfTypesPercentage  \
# 0                    8.964915
# 1                    3.007954
# 2                    8.421216
# 3                    4.260772
# 4                   13.749299
# 5                    2.946278
# 6                    8.445998
# 7                   11.195857
# 8                    0.000000
# 9                    0.000000
#
#                                    someArtifactNames
# 0  [axon-test-5.0.2, axon-update-5.0.2, axon-spri...
# 1  [axon-spring-boot-autoconfigure-5.0.2, axon-me...
# 2  [axon-spring-boot-autoconfigure-5.0.2, axon-co...
# 3         [axon-conversion-5.0.2, axon-common-5.0.2]
# 4  [axon-spring-boot-autoconfigure-5.0.2, axon-se...
# 5  [axon-spring-boot-autoconfigure-5.0.2, axon-se...
# 6  [axon-spring-boot-autoconfigure-5.0.2, axon-co...
# 7  [axon-spring-boot-autoconfigure-5.0.2, axon-co...
# 8                         [axon-eventsourcing-5.0.2]
# 9                         [axon-eventsourcing-5.0.2]
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Table 3a - Top 20 most widely spread external packages - number of internal packages
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the number of internal packages.

# %%
external_package_usage_spread_packages=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfPackages', 'maxNumberOfPackages', 'medNumberOfPackages', 'avgNumberOfPackages', 'stdNumberOfPackages']]
external_package_usage_spread_packages.head(20)
# Out:
#                                externalPackageName  numberOfArtifacts  \
# 0                                        org.slf4j                 11
# 1                              jakarta.persistence                  4
# 2                   com.fasterxml.jackson.databind                  3
# 3              com.fasterxml.jackson.databind.node                  2
# 4                   io.axoniq.axonserver.connector                  2
# 5           io.axoniq.axonserver.connector.control                  2
# 6                                  org.apache.avro                  2
# 7                          org.apache.avro.message                  2
# 8                          IdTypeParameterResolver                  1
# 9                             ScannedEntityCreator                  1
# 10               WrappedEventCriteriaBuilderMethod                  1
# 11                com.fasterxml.jackson.annotation                  1
# 12                      com.fasterxml.jackson.core                  1
# 13  com.fasterxml.jackson.dataformat.cbor.databind                  1
# 14                                 com.google.gson                  1
# 15                             com.google.protobuf                  1
# 16            io.axoniq.axonserver.connector.admin                  1
# 17          io.axoniq.axonserver.connector.command                  1
# 18            io.axoniq.axonserver.connector.event                  1
# 19             io.axoniq.axonserver.connector.impl                  1
#
#     minNumberOfPackages  maxNumberOfPackages  medNumberOfPackages  \
# 0                     1                   14                  3.0
# 1                     1                    2                  1.0
# 2                     1                    1                  1.0
# 3                     1                    1                  1.0
# 4                     1                    4                  2.5
# 5                     1                    2                  1.5
# 6                     1                    1                  1.0
# 7                     1                    1                  1.0
# 8                     1                    1                  1.0
# 9                     1                    1                  1.0
# 10                    1                    1                  1.0
# 11                    1                    1                  1.0
# 12                    1                    1                  1.0
# 13                    1                    1                  1.0
# 14                    1                    1                  1.0
# 15                    4                    4                  4.0
# 16                    1                    1                  1.0
# 17                    1                    1                  1.0
# 18                    1                    1                  1.0
# 19                    1                    1                  1.0
#
#     avgNumberOfPackages  stdNumberOfPackages
# 0              3.454545             3.670521
# 1              1.250000             0.500000
# 2              1.000000             0.000000
# 3              1.000000             0.000000
# 4              2.500000             2.121320
# 5              1.500000             0.707107
# 6              1.000000             0.000000
# 7              1.000000             0.000000
# 8              1.000000             0.000000
# 9              1.000000             0.000000
# 10             1.000000             0.000000
# 11             1.000000             0.000000
# 12             1.000000             0.000000
# 13             1.000000             0.000000
# 14             1.000000             0.000000
# 15             4.000000             0.000000
# 16             1.000000             0.000000
# 17             1.000000             0.000000
# 18             1.000000             0.000000
# 19             1.000000             0.000000

# %% [markdown]
# ### Table 3b - Top 20 most widely spread external packages - percentage of internal packages
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the percentage of internal packages.

# %%
external_package_usage_spread_packages_percentage=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfPackagesPercentage', 'maxNumberOfPackagesPercentage', 'medNumberOfPackagesPercentage', 'avgNumberOfPackagesPercentage', 'stdNumberOfPackagesPercentage']]
external_package_usage_spread_packages_percentage.head(20)
# Out:
#                                externalPackageName  numberOfArtifacts  \
# 0                                        org.slf4j                 11
# 1                              jakarta.persistence                  4
# 2                   com.fasterxml.jackson.databind                  3
# 3              com.fasterxml.jackson.databind.node                  2
# 4                   io.axoniq.axonserver.connector                  2
# 5           io.axoniq.axonserver.connector.control                  2
# 6                                  org.apache.avro                  2
# 7                          org.apache.avro.message                  2
# 8                          IdTypeParameterResolver                  1
# 9                             ScannedEntityCreator                  1
# 10               WrappedEventCriteriaBuilderMethod                  1
# 11                com.fasterxml.jackson.annotation                  1
# 12                      com.fasterxml.jackson.core                  1
# 13  com.fasterxml.jackson.dataformat.cbor.databind                  1
# 14                                 com.google.gson                  1
# 15                             com.google.protobuf                  1
# 16            io.axoniq.axonserver.connector.admin                  1
# 17          io.axoniq.axonserver.connector.command                  1
# 18            io.axoniq.axonserver.connector.event                  1
# 19             io.axoniq.axonserver.connector.impl                  1
#
#     minNumberOfPackagesPercentage  maxNumberOfPackagesPercentage  \
# 0                       20.000000                     100.000000
# 1                        1.754386                      28.571429
# 2                        6.666667                      25.000000
# 3                        6.666667                      25.000000
# 4                       14.285714                      80.000000
# 5                       14.285714                      40.000000
# 6                       14.285714                      25.000000
# 7                       14.285714                      25.000000
# 8                       12.500000                      12.500000
# 9                       12.500000                      12.500000
# 10                      12.500000                      12.500000
# 11                       1.754386                       1.754386
# 12                      25.000000                      25.000000
# 13                      14.285714                      14.285714
# 14                      20.000000                      20.000000
# 15                      80.000000                      80.000000
# 16                      20.000000                      20.000000
# 17                      20.000000                      20.000000
# 18                      20.000000                      20.000000
# 19                      20.000000                      20.000000
#
#     medNumberOfPackagesPercentage  avgNumberOfPackagesPercentage  \
# 0                       42.857143                      48.423331
# 1                        9.583333                      12.373120
# 2                       14.285714                      15.317460
# 3                       15.833333                      15.833333
# 4                       47.142857                      47.142857
# 5                       27.142857                      27.142857
# 6                       19.642857                      19.642857
# 7                       19.642857                      19.642857
# 8                       12.500000                      12.500000
# 9                       12.500000                      12.500000
# 10                      12.500000                      12.500000
# 11                       1.754386                       1.754386
# 12                      25.000000                      25.000000
# 13                      14.285714                      14.285714
# 14                      20.000000                      20.000000
# 15                      80.000000                      80.000000
# 16                      20.000000                      20.000000
# 17                      20.000000                      20.000000
# 18                      20.000000                      20.000000
# 19                      20.000000                      20.000000
#
#     stdNumberOfPackagesPercentage
# 0                       27.063677
# 1                       11.657936
# 2                        9.210111
# 3                       12.963624
# 4                       46.467017
# 5                       18.182746
# 6                        7.576144
# 7                        7.576144
# 8                        0.000000
# 9                        0.000000
# 10                       0.000000
# 11                       0.000000
# 12                       0.000000
# 13                       0.000000
# 14                       0.000000
# 15                       0.000000
# 16                       0.000000
# 17                       0.000000
# 18                       0.000000
# 19                       0.000000

# %% [markdown]
# ### Table 3c - Top 20 most widely spread external packages - number of internal types
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the number of internal types.

# %%
external_package_usage_spread_types=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfTypes', 'maxNumberOfTypes', 'medNumberOfTypes', 'avgNumberOfTypes', 'stdNumberOfTypes']]
external_package_usage_spread_types.head(20)
# Out:
#                                externalPackageName  numberOfArtifacts  \
# 0                                        org.slf4j                 11
# 1                              jakarta.persistence                  4
# 2                   com.fasterxml.jackson.databind                  3
# 3              com.fasterxml.jackson.databind.node                  2
# 4                   io.axoniq.axonserver.connector                  2
# 5           io.axoniq.axonserver.connector.control                  2
# 6                                  org.apache.avro                  2
# 7                          org.apache.avro.message                  2
# 8                          IdTypeParameterResolver                  1
# 9                             ScannedEntityCreator                  1
# 10               WrappedEventCriteriaBuilderMethod                  1
# 11                com.fasterxml.jackson.annotation                  1
# 12                      com.fasterxml.jackson.core                  1
# 13  com.fasterxml.jackson.dataformat.cbor.databind                  1
# 14                                 com.google.gson                  1
# 15                             com.google.protobuf                  1
# 16            io.axoniq.axonserver.connector.admin                  1
# 17          io.axoniq.axonserver.connector.command                  1
# 18            io.axoniq.axonserver.connector.event                  1
# 19             io.axoniq.axonserver.connector.impl                  1
#
#     minNumberOfTypes  maxNumberOfTypes  medNumberOfTypes  avgNumberOfTypes  \
# 0                  1                30               3.0          6.727273
# 1                  2                 6               4.5          4.250000
# 2                  1                 5               3.0          3.000000
# 3                  1                 2               1.5          1.500000
# 4                  1                15               8.0          8.000000
# 5                  1                 4               2.5          2.500000
# 6                  1                 4               2.5          2.500000
# 7                  3                 6               4.5          4.500000
# 8                  1                 1               1.0          1.000000
# 9                  1                 1               1.0          1.000000
# 10                 1                 1               1.0          1.000000
# 11                 2                 2               2.0          2.000000
# 12                 1                 1               1.0          1.000000
# 13                 2                 2               2.0          2.000000
# 14                 1                 1               1.0          1.000000
# 15                 8                 8               8.0          8.000000
# 16                 1                 1               1.0          1.000000
# 17                 1                 1               1.0          1.000000
# 18                 5                 5               5.0          5.000000
# 19                 1                 1               1.0          1.000000
#
#     stdNumberOfTypes
# 0           8.486353
# 1           1.707825
# 2           2.000000
# 3           0.707107
# 4           9.899495
# 5           2.121320
# 6           2.121320
# 7           2.121320
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000

# %% [markdown]
# ### Table 3d - Top 20 most widely spread external packages - percentage of internal types
#
# This table shows the top 20 most widely spread external packages focussing on the spread across the percentage of internal types.

# %%
external_package_usage_spread_types_percentage=external_package_usage_spread[['externalPackageName', 'numberOfArtifacts', 'minNumberOfTypesPercentage', 'maxNumberOfTypesPercentage', 'medNumberOfTypesPercentage', 'avgNumberOfTypesPercentage', 'stdNumberOfTypesPercentage']]
external_package_usage_spread_types_percentage.head(20)
# Out:
#                                externalPackageName  numberOfArtifacts  \
# 0                                        org.slf4j                 11
# 1                              jakarta.persistence                  4
# 2                   com.fasterxml.jackson.databind                  3
# 3              com.fasterxml.jackson.databind.node                  2
# 4                   io.axoniq.axonserver.connector                  2
# 5           io.axoniq.axonserver.connector.control                  2
# 6                                  org.apache.avro                  2
# 7                          org.apache.avro.message                  2
# 8                          IdTypeParameterResolver                  1
# 9                             ScannedEntityCreator                  1
# 10               WrappedEventCriteriaBuilderMethod                  1
# 11                com.fasterxml.jackson.annotation                  1
# 12                      com.fasterxml.jackson.core                  1
# 13  com.fasterxml.jackson.dataformat.cbor.databind                  1
# 14                                 com.google.gson                  1
# 15                             com.google.protobuf                  1
# 16            io.axoniq.axonserver.connector.admin                  1
# 17          io.axoniq.axonserver.connector.command                  1
# 18            io.axoniq.axonserver.connector.event                  1
# 19             io.axoniq.axonserver.connector.impl                  1
#
#     minNumberOfTypesPercentage  maxNumberOfTypesPercentage  \
# 0                     1.369863                   30.434783
# 1                     0.350877                    6.944444
# 2                     0.641026                   16.666667
# 3                     0.641026                    6.666667
# 4                     1.388889                   20.833333
# 5                     1.388889                    5.555556
# 6                     1.388889                   13.333333
# 7                     4.166667                   20.000000
# 8                     0.961538                    0.961538
# 9                     0.961538                    0.961538
# 10                    0.961538                    0.961538
# 11                    0.350877                    0.350877
# 12                    3.333333                    3.333333
# 13                    2.777778                    2.777778
# 14                    1.369863                    1.369863
# 15                   11.111111                   11.111111
# 16                    1.388889                    1.388889
# 17                    1.388889                    1.388889
# 18                    6.944444                    6.944444
# 19                    1.388889                    1.388889
#
#     medNumberOfTypesPercentage  avgNumberOfTypesPercentage  \
# 0                     5.769231                    9.847982
# 1                     4.166667                    3.907164
# 2                     4.166667                    7.158120
# 3                     3.653846                    3.653846
# 4                    11.111111                   11.111111
# 5                     3.472222                    3.472222
# 6                     7.361111                    7.361111
# 7                    12.083333                   12.083333
# 8                     0.961538                    0.961538
# 9                     0.961538                    0.961538
# 10                    0.961538                    0.961538
# 11                    0.350877                    0.350877
# 12                    3.333333                    3.333333
# 13                    2.777778                    2.777778
# 14                    1.369863                    1.369863
# 15                   11.111111                   11.111111
# 16                    1.388889                    1.388889
# 17                    1.388889                    1.388889
# 18                    6.944444                    6.944444
# 19                    1.388889                    1.388889
#
#     stdNumberOfTypesPercentage
# 0                     8.964915
# 1                     3.007954
# 2                     8.421216
# 3                     4.260772
# 4                    13.749299
# 5                     2.946278
# 6                     8.445998
# 7                    11.195857
# 8                     0.000000
# 9                     0.000000
# 10                    0.000000
# 11                    0.000000
# 12                    0.000000
# 13                    0.000000
# 14                    0.000000
# 15                    0.000000
# 16                    0.000000
# 17                    0.000000
# 18                    0.000000
# 19                    0.000000

# %% [markdown]
# #### Table 3 Chart 1a - Most widely spread external packages in % by types (more than 0.5% overall)
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_package_type_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_package_usage_spread,
    value_column='sumNumberOfTypes',
    name_column='externalPackageName',
    threshold= 0.5
);
plot_pie_chart(
    input_data_frame=external_package_type_usage_spread_significant,
    title='Top external package usage spread [%] by type (more than 0.5% overall)'
)

# %% [markdown]
# #### Table 3 Chart 1b - Most widely spread external packages in % by types (less than 0.5% overall "others" drill-down)
#
# Shows the lowest (less than 0.5% overall) most spread external packages. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_package_type_usage_spread_drill_down_others=filter_values_below_threshold(external_package_usage_spread, 'sumNumberOfTypes', 0.5)

external_package_type_usage_spread_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_package_type_usage_spread_drill_down_others,
    value_column='sumNumberOfTypes',
    name_column='externalPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_package_type_usage_spread_significant_drill_down_others,
    title='Top external package usage spread [%] by type (less than 0.5% overall "others" drill-down)'
)

# %% [markdown]
# #### Table 3 Chart 2a - Most widely spread external packages in % by packages (more than 0.5% overall)
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_package_usage_package_spread_significant = group_to_others_below_threshold(
    data_frame=external_package_usage_spread,
    value_column='sumNumberOfPackages',
    name_column='externalPackageName',
    threshold= 0.5
);
plot_pie_chart(
    input_data_frame=external_package_usage_package_spread_significant,
    title='Top external package usage spread [%] by package (more than 0.5% overall)'
)

# %% [markdown]
# #### Table 3 Chart 2b - Most widely spread external packages in % by packages (less than 0.5% overall "others" drill-down)
#
# Shows the lowest (less than 0.5% overall) most spread external packages. Therefore, this plot breaks down the "others" slice of the pie chart above. Values under 0.3% from that will be grouped into "others" to get a cleaner plot.

# %%
external_package_usage_package_spread_drill_down_others=filter_values_below_threshold(external_package_usage_spread, 'sumNumberOfPackages', 0.5)

external_grouped_package_type_usage_spread_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_package_usage_package_spread_drill_down_others,
    value_column='sumNumberOfPackages',
    name_column='externalPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_grouped_package_type_usage_spread_significant_drill_down_others,
    title='Top external package usage spread [%] by type (less than 0.7% overall "others" drill-down)'
)
# Out:
# No data to plot for title 'Top external package usage spread [%] by type (less than 0.7% overall "others" drill-down)'.

# %% [markdown]
# ### Table 4 - Top 20 most widely spread external packages grouped by their first 2 layers
#
# This table shows external packages grouped by their first 2 layers that are used by many different artifacts with the highest number of artifacts first. External annotations are filtered out to only get those external packages that significantly add to coupling.
#
# Statistics like minimum, maximum, average, median and standard deviation are provided for the number of packages and number of types in every artifact that uses the listed external package.
#
# The intuition behind that is to find external package dependencies that are used in a widely spread manner. This should uncover libraries and frameworks and make it easier to distinguish them from external dependencies that are used for specific tasks. It can also be used to find external dependencies that are used sparsely regarding artifacts but are used in many different packages there. This could then be improved by applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture).
#
# Only the top 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_spread`
#
# **Columns:**
# - *externalPackageName* identifies the external package as defined above. All other columns contain aggregated data for this external package.
# - *numberOfArtifacts* contains the number of artifacts that use the external package
# - *sumNumberOfPackages* contains the sum of all packages that use the external package
# - *min/max/med/avg/stdNumberOfPackages* provide statistics based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of packages of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfTypes* provide statistics based on the number of types of each artifact that uses the external package
# - *min/max/med/avg/stdNumberOfPackagesPercentage* provide statistics in percent (%) based on the number of types of each artifact that uses the external package
# - *someArtifactNames* contain some of the artifacts that contain the external package for reference

# %%
external_grouped_package_usage_spread=query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_spread.cypher")
external_grouped_package_usage_spread.head(20)
# Out:
#        externalSecondLevelPackageName  numberOfArtifacts  sumNumberOfPackages  \
# 0                           org.slf4j                 11                   38
# 1                       com.fasterxml                  4                    4
# 2                 jakarta.persistence                  4                    5
# 3                          com.google                  2                    5
# 4                           io.axoniq                  2                    6
# 5                          org.apache                  2                    2
# 6                        reactor.core                  2                    6
# 7             IdTypeParameterResolver                  1                    1
# 8                ScannedEntityCreator                  1                    1
# 9   WrappedEventCriteriaBuilderMethod                  1                    1
# 10                            io.grpc                  1                    3
# 11                      io.micrometer                  1                    2
# 12                   io.opentelemetry                  1                    1
# 13                 jakarta.validation                  1                    1
# 14                        javax.cache                  1                    1
# 15                     org.awaitility                  1                    1
# 16                  org.axonframework                  1                    3
# 17                        org.ehcache                  1                    1
# 18                       org.hamcrest                  1                    3
# 19                          org.junit                  1                    1
#
#     minNumberOfPackages  maxNumberOfPackages  medNumberOfPackages  \
# 0                     1                   14                  3.0
# 1                     1                    1                  1.0
# 2                     1                    2                  1.0
# 3                     1                    4                  2.5
# 4                     1                    5                  3.0
# 5                     1                    1                  1.0
# 6                     1                    5                  3.0
# 7                     1                    1                  1.0
# 8                     1                    1                  1.0
# 9                     1                    1                  1.0
# 10                    3                    3                  3.0
# 11                    2                    2                  2.0
# 12                    1                    1                  1.0
# 13                    1                    1                  1.0
# 14                    1                    1                  1.0
# 15                    1                    1                  1.0
# 16                    3                    3                  3.0
# 17                    1                    1                  1.0
# 18                    3                    3                  3.0
# 19                    1                    1                  1.0
#
#     avgNumberOfPackages  stdNumberOfPackages  minNumberOfPackagesPercentage  \
# 0              3.454545             3.670521                      20.000000
# 1              1.000000             0.000000                       1.754386
# 2              1.250000             0.500000                       1.754386
# 3              2.500000             2.121320                      20.000000
# 4              3.000000             2.828427                      14.285714
# 5              1.000000             0.000000                      14.285714
# 6              3.000000             2.828427                       8.771930
# 7              1.000000             0.000000                      12.500000
# 8              1.000000             0.000000                      12.500000
# 9              1.000000             0.000000                      12.500000
# 10             3.000000             0.000000                      60.000000
# 11             2.000000             0.000000                     100.000000
# 12             1.000000             0.000000                     100.000000
# 13             1.000000             0.000000                       1.754386
# 14             1.000000             0.000000                       6.666667
# 15             1.000000             0.000000                      20.000000
# 16             3.000000             0.000000                      42.857143
# 17             1.000000             0.000000                       6.666667
# 18             3.000000             0.000000                      60.000000
# 19             1.000000             0.000000                      20.000000
#
#     maxNumberOfPackagesPercentage  ...  maxNumberOfTypes  medNumberOfTypes  \
# 0                      100.000000  ...                30               3.0
# 1                       25.000000  ...                 5               3.0
# 2                       28.571429  ...                 6               4.5
# 3                       80.000000  ...                 8               4.5
# 4                      100.000000  ...                44              22.5
# 5                       25.000000  ...                 9               6.0
# 6                       20.000000  ...                 8               4.5
# 7                       12.500000  ...                 1               1.0
# 8                       12.500000  ...                 1               1.0
# 9                       12.500000  ...                 1               1.0
# 10                      60.000000  ...                10              10.0
# 11                     100.000000  ...                12              12.0
# 12                     100.000000  ...                 5               5.0
# 13                       1.754386  ...                 2               2.0
# 14                       6.666667  ...                 2               2.0
# 15                      20.000000  ...                 1               1.0
# 16                      42.857143  ...                10              10.0
# 17                       6.666667  ...                 3               3.0
# 18                      60.000000  ...                22              22.0
# 19                      20.000000  ...                 1               1.0
#
#     avgNumberOfTypes  stdNumberOfTypes  minNumberOfTypesPercentage  \
# 0           6.727273          8.486353                    1.369863
# 1           3.000000          1.825742                    0.350877
# 2           4.250000          1.707825                    0.350877
# 3           4.500000          4.949747                    1.369863
# 4          22.500000         30.405592                    1.388889
# 5           6.000000          4.242641                    4.166667
# 6           4.500000          4.949747                    1.388889
# 7           1.000000          0.000000                    0.961538
# 8           1.000000          0.000000                    0.961538
# 9           1.000000          0.000000                    0.961538
# 10         10.000000          0.000000                   13.888889
# 11         12.000000          0.000000                   92.307692
# 12          5.000000          0.000000                  100.000000
# 13          2.000000          0.000000                    0.350877
# 14          2.000000          0.000000                    1.282051
# 15          1.000000          0.000000                    1.369863
# 16         10.000000          0.000000                   13.888889
# 17          3.000000          0.000000                    1.923077
# 18         22.000000          0.000000                   30.136986
# 19          1.000000          0.000000                    1.369863
#
#     maxNumberOfTypesPercentage  medNumberOfTypesPercentage  \
# 0                    30.434783                    5.769231
# 1                    16.666667                    3.098291
# 2                     6.944444                    4.166667
# 3                    11.111111                    6.240487
# 4                    61.111111                   31.250000
# 5                    30.000000                   17.083333
# 6                     1.403509                    1.396199
# 7                     0.961538                    0.961538
# 8                     0.961538                    0.961538
# 9                     0.961538                    0.961538
# 10                   13.888889                   13.888889
# 11                   92.307692                   92.307692
# 12                  100.000000                  100.000000
# 13                    0.350877                    0.350877
# 14                    1.282051                    1.282051
# 15                    1.369863                    1.369863
# 16                   13.888889                   13.888889
# 17                    1.923077                    1.923077
# 18                   30.136986                   30.136986
# 19                    1.369863                    1.369863
#
#     avgNumberOfTypesPercentage  stdNumberOfTypesPercentage  \
# 0                     9.847982                    8.964915
# 1                     5.803531                    7.625661
# 2                     3.907164                    3.007954
# 3                     6.240487                    6.888103
# 4                    31.250000                   42.229988
# 5                    17.083333                   18.266925
# 6                     1.396199                    0.010338
# 7                     0.961538                    0.000000
# 8                     0.961538                    0.000000
# 9                     0.961538                    0.000000
# 10                   13.888889                    0.000000
# 11                   92.307692                    0.000000
# 12                  100.000000                    0.000000
# 13                    0.350877                    0.000000
# 14                    1.282051                    0.000000
# 15                    1.369863                    0.000000
# 16                   13.888889                    0.000000
# 17                    1.923077                    0.000000
# 18                   30.136986                    0.000000
# 19                    1.369863                    0.000000
#
#                                     someArtifactNames
# 0   [axon-test-5.0.2, axon-update-5.0.2, axon-spri...
# 1   [axon-spring-boot-autoconfigure-5.0.2, axon-me...
# 2   [axon-spring-boot-autoconfigure-5.0.2, axon-me...
# 3      [axon-test-5.0.2, axon-server-connector-5.0.2]
# 4   [axon-spring-boot-autoconfigure-5.0.2, axon-se...
# 5   [axon-spring-boot-autoconfigure-5.0.2, axon-co...
# 6   [axon-messaging-5.0.2, axon-server-connector-5...
# 7                          [axon-eventsourcing-5.0.2]
# 8                          [axon-eventsourcing-5.0.2]
# 9                          [axon-eventsourcing-5.0.2]
# 10                      [axon-server-connector-5.0.2]
# 11                    [axon-metrics-micrometer-5.0.2]
# 12                 [axon-tracing-opentelemetry-5.0.2]
# 13                             [axon-messaging-5.0.2]
# 14                                [axon-common-5.0.2]
# 15                                  [axon-test-5.0.2]
# 16             [axon-spring-boot-autoconfigure-5.0.2]
# 17                                [axon-common-5.0.2]
# 18                                  [axon-test-5.0.2]
# 19                                  [axon-test-5.0.2]
#
# [20 rows x 25 columns]

# %% [markdown]
# #### Table 4 Chart 1a - Most widely spread second level external packages in % by type (more than 0.5% overall)
#
# External package groups that are used less than 0.5% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_type_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage_spread,
    value_column='sumNumberOfTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.5
);
plot_pie_chart(
    input_data_frame=external_grouped_package_type_usage_spread_significant,
    title='Top external package (grouped by first 2 layers) usage spread [%] by type'
)

# %% [markdown]
# #### Table 4 Chart 1b - Most widely spread second level external packages in % by type  (less than 0.5% overall "others" drill-down)
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_grouped_package_type_usage_spread_drill_down_others=filter_values_below_threshold(external_grouped_package_usage_spread, 'sumNumberOfTypes', 0.5)

external_package_usage_package_spread_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_grouped_package_type_usage_spread_drill_down_others,
    value_column='sumNumberOfTypes',
    name_column='externalSecondLevelPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_package_usage_package_spread_significant_drill_down_others,
    title='Top external package usage spread [%] by type (less than 0.7% overall "others" drill-down)'
)

# %% [markdown]
# #### Table 4 Chart 2a - Most widely spread second level external packages in % by package (more than 0.5% overall)
#
# External package groups that are used less than 0.5% are grouped into the name "others" to get a cleaner chart
# with the most significant external packages and how ofter they are called in percent.

# %%
external_grouped_package_package_usage_spread_significant = group_to_others_below_threshold(
    data_frame=external_grouped_package_usage_spread,
    value_column='sumNumberOfPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.5
);
plot_pie_chart(
    input_data_frame=external_grouped_package_package_usage_spread_significant,
    title='Top external package (grouped by first 2 layers) usage spread [%] by package (more than 0.5% overall)'
)

# %% [markdown]
# #### Table 4 Chart 2b - Most widely spread second level external packages in % by package (less than 0.5% overall "others" drill-down)
#
# External packages that are used less than 0.5% are grouped into the name "others" to get a cleaner chart with the most significant external packages.

# %%
external_grouped_package_package_usage_spread_drill_down_others=filter_values_below_threshold(external_grouped_package_usage_spread, 'sumNumberOfPackages', 0.5)

external_grouped_package_package_usage_spread_significant_drill_down_others = group_to_others_below_threshold(
    data_frame=external_grouped_package_package_usage_spread_drill_down_others,
    value_column='sumNumberOfPackages',
    name_column='externalSecondLevelPackageName',
    threshold= 0.3
)
plot_pie_chart(
    input_data_frame=external_grouped_package_package_usage_spread_significant_drill_down_others,
    title='Top external package (less than 0.7% overall "others" drill-down)'
)
# Out:
# No data to plot for title 'Top external package (less than 0.7% overall "others" drill-down)'.

# %% [markdown]
# ### Table 5 - Top 20 least used external packages overall
#
# This table identifies external packages that aren't used very often. This could help to find libraries that aren't actually needed or maybe easily replaceable. Some of them might be used sparsely on purpose for example as an adapter to an external library that is actually important. Thus, decisions need to be made on a case-by-case basis.
#
# Only the last 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_overall`
#
# **Columns:**
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package

# %%
# Sort by number of external type calls
external_package_least_used=external_package_usage.sort_values(by='numberOfExternalTypeCalls', ascending=True)

# Reset index
external_package_least_used = external_package_least_used.reset_index(drop=True)

# Select columns and only show the first 10 entries (head)
external_package_least_used[['externalPackageName','numberOfExternalTypeCalls']].head(20)
# Out:
#                                   externalPackageName  \
# 0                          org.testcontainers.utility
# 1                              reactor.core.scheduler
# 2        org.springframework.boot.docker.compose.core
# 3   org.springframework.boot.docker.compose.servic...
# 4         org.testcontainers.containers.wait.strategy
# 5                       org.testcontainers.containers
# 6   org.axonframework.extension.spring.conversion....
# 7                           javax.cache.configuration
# 8                                        io.grpc.stub
# 9                                     com.google.gson
# 10                  org.springframework.beans.factory
# 11                           org.apache.avro.specific
# 12  org.springframework.boot.testcontainers.servic...
# 13                                 jakarta.validation
# 14                    io.axoniq.axonserver.grpc.event
# 15                com.fasterxml.jackson.databind.node
# 16   org.springframework.boot.context.properties.bind
# 17                        org.springframework.context
# 18               io.axoniq.axonserver.connector.query
# 19                            org.apache.avro.generic
#
#     numberOfExternalTypeCalls
# 0                           2
# 1                           2
# 2                           2
# 3                           2
# 4                           2
# 5                           2
# 6                           3
# 7                           3
# 8                           4
# 9                           4
# 10                          4
# 11                          4
# 12                          4
# 13                          5
# 14                          5
# 15                          5
# 16                          5
# 17                          5
# 18                          6
# 19                          7

# %% [markdown]
# ### Table 6 - External usage per artifact sorted by highest external type rate descending
#
# The following table shows the most used external packages separately for each artifact including external annotations. The results are sorted by the artifacts with the highest external type usage rate descending.
#
# The intention of this table is to find artifacts that use a lot of external dependencies in relation to their size and get all the external packages and their usage.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_sorted`
#
# **Columns:**
# - *artifactName* is used to group the the external package usage per artifact for a more detailed analysis.
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInArtifact* represents the total count of all analyzed types for the artifact
# - *numberOfExternalTypesInArtifact* is the number of all external types that are used by the artifact
# - *numberOfExternalPackagesInArtifact* is the number of all external packages that are used by the artifact
# - *externalTypeRate* is the numberOfExternalTypesInArtifact / numberOfTypesInArtifact * 100
# - *externalTypeNames* contains a list of actually utilized types of the external package

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_sorted.cypher").head(40)
# Out:
#                             artifactName  \
# 0       axon-tracing-opentelemetry-5.0.2
# 1       axon-tracing-opentelemetry-5.0.2
# 2       axon-tracing-opentelemetry-5.0.2
# 3       axon-tracing-opentelemetry-5.0.2
# 4       axon-tracing-opentelemetry-5.0.2
# 5       axon-tracing-opentelemetry-5.0.2
# 6            axon-server-connector-5.0.2
# 7            axon-server-connector-5.0.2
# 8            axon-server-connector-5.0.2
# 9            axon-server-connector-5.0.2
# 10           axon-server-connector-5.0.2
# 11           axon-server-connector-5.0.2
# 12           axon-server-connector-5.0.2
# 13           axon-server-connector-5.0.2
# 14           axon-server-connector-5.0.2
# 15           axon-server-connector-5.0.2
# 16           axon-server-connector-5.0.2
# 17           axon-server-connector-5.0.2
# 18           axon-server-connector-5.0.2
# 19           axon-server-connector-5.0.2
# 20           axon-server-connector-5.0.2
# 21           axon-server-connector-5.0.2
# 22           axon-server-connector-5.0.2
# 23           axon-server-connector-5.0.2
# 24           axon-server-connector-5.0.2
# 25           axon-server-connector-5.0.2
# 26           axon-server-connector-5.0.2
# 27           axon-server-connector-5.0.2
# 28           axon-server-connector-5.0.2
# 29  axon-spring-boot-autoconfigure-5.0.2
# 30  axon-spring-boot-autoconfigure-5.0.2
# 31  axon-spring-boot-autoconfigure-5.0.2
# 32  axon-spring-boot-autoconfigure-5.0.2
# 33  axon-spring-boot-autoconfigure-5.0.2
# 34  axon-spring-boot-autoconfigure-5.0.2
# 35  axon-spring-boot-autoconfigure-5.0.2
# 36  axon-spring-boot-autoconfigure-5.0.2
# 37  axon-spring-boot-autoconfigure-5.0.2
# 38  axon-spring-boot-autoconfigure-5.0.2
# 39  axon-spring-boot-autoconfigure-5.0.2
#
#                                  externalPackageName  \
# 0                         io.opentelemetry.api.trace
# 1               io.opentelemetry.context.propagation
# 2                                 jakarta.annotation
# 3                           io.opentelemetry.context
# 4                                          org.slf4j
# 5                               io.opentelemetry.api
# 6                          io.axoniq.axonserver.grpc
# 7                                 jakarta.annotation
# 8                io.axoniq.axonserver.grpc.event.dcb
# 9                                            io.grpc
# 10                    io.axoniq.axonserver.connector
# 11                                         org.slf4j
# 12                   io.axoniq.axonserver.grpc.query
# 13                 io.axoniq.axonserver.grpc.control
# 14                               com.google.protobuf
# 15              io.axoniq.axonserver.connector.event
# 16                 io.axoniq.axonserver.grpc.command
# 17              io.axoniq.axonserver.connector.query
# 18                   io.axoniq.axonserver.grpc.event
# 19            io.axoniq.axonserver.connector.control
# 20                                      io.grpc.stub
# 21                            reactor.core.scheduler
# 22              io.axoniq.axonserver.connector.admin
# 23            io.axoniq.axonserver.connector.command
# 24               io.axoniq.axonserver.connector.impl
# 25                io.grpc.netty.shaded.io.grpc.netty
# 26         io.grpc.netty.shaded.io.netty.handler.ssl
# 27                                  javax.annotation
# 28       org.springframework.boot.context.properties
# 29  org.springframework.boot.autoconfigure.condition
# 30            org.springframework.context.annotation
# 31            org.springframework.boot.autoconfigure
# 32       org.springframework.boot.context.properties
# 33                                jakarta.annotation
# 34         org.axonframework.extension.spring.config
# 35           org.springframework.boot.actuate.health
# 36                               jakarta.persistence
# 37  org.springframework.boot.context.properties.bind
# 38                       org.springframework.context
# 39                           org.apache.avro.message
#
#     numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0                            9                         46
# 1                            9                         15
# 2                            3                          8
# 3                            2                          7
# 4                            2                          7
# 5                            1                          2
# 6                           40                        271
# 7                           31                        181
# 8                           28                        104
# 9                           23                         51
# 10                          22                        123
# 11                          19                         70
# 12                          14                         98
# 13                          13                         86
# 14                           8                         29
# 15                           8                         38
# 16                           8                         63
# 17                           6                         19
# 18                           5                         31
# 19                           4                          5
# 20                           4                         11
# 21                           2                          2
# 22                           1                          3
# 23                           1                          3
# 24                           1                          3
# 25                           1                          1
# 26                           1                          2
# 27                           1                          1
# 28                           1                          2
# 29                          45                         75
# 30                          36                         65
# 31                          30                         31
# 32                          20                         26
# 33                          15                         30
# 34                          13                         42
# 35                           7                         24
# 36                           6                         12
# 37                           5                         11
# 38                           5                          9
# 39                           4                         10
#
#     numberOfTypesInArtifact  numberOfExternalTypesInArtifact  \
# 0                         5                               16
# 1                         5                               16
# 2                         5                               16
# 3                         5                               16
# 4                         5                               16
# 5                         5                               16
# 6                        72                              113
# 7                        72                              113
# 8                        72                              113
# 9                        72                              113
# 10                       72                              113
# 11                       72                              113
# 12                       72                              113
# 13                       72                              113
# 14                       72                              113
# 15                       72                              113
# 16                       72                              113
# 17                       72                              113
# 18                       72                              113
# 19                       72                              113
# 20                       72                              113
# 21                       72                              113
# 22                       72                              113
# 23                       72                              113
# 24                       72                              113
# 25                       72                              113
# 26                       72                              113
# 27                       72                              113
# 28                       72                              113
# 29                       72                               95
# 30                       72                               95
# 31                       72                               95
# 32                       72                               95
# 33                       72                               95
# 34                       72                               95
# 35                       72                               95
# 36                       72                               95
# 37                       72                               95
# 38                       72                               95
# 39                       72                               95
#
#     numberOfExternalPackagesInArtifact  externalTypeRate  \
# 0                                    6        320.000000
# 1                                    6        320.000000
# 2                                    6        320.000000
# 3                                    6        320.000000
# 4                                    6        320.000000
# 5                                    6        320.000000
# 6                                   23        156.944444
# 7                                   23        156.944444
# 8                                   23        156.944444
# 9                                   23        156.944444
# 10                                  23        156.944444
# 11                                  23        156.944444
# 12                                  23        156.944444
# 13                                  23        156.944444
# 14                                  23        156.944444
# 15                                  23        156.944444
# 16                                  23        156.944444
# 17                                  23        156.944444
# 18                                  23        156.944444
# 19                                  23        156.944444
# 20                                  23        156.944444
# 21                                  23        156.944444
# 22                                  23        156.944444
# 23                                  23        156.944444
# 24                                  23        156.944444
# 25                                  23        156.944444
# 26                                  23        156.944444
# 27                                  23        156.944444
# 28                                  23        156.944444
# 29                                  37        131.944444
# 30                                  37        131.944444
# 31                                  37        131.944444
# 32                                  37        131.944444
# 33                                  37        131.944444
# 34                                  37        131.944444
# 35                                  37        131.944444
# 36                                  37        131.944444
# 37                                  37        131.944444
# 38                                  37        131.944444
# 39                                  37        131.944444
#
#                                     externalTypeNames
# 0   [Span, StatusCode, SpanBuilder, SpanContext, S...
# 1   [TextMapGetter, TextMapSetter, TextMapPropagat...
# 2                                           [Nonnull]
# 3                                    [Scope, Context]
# 4                             [LoggerFactory, Logger]
# 5                               [GlobalOpenTelemetry]
# 6   [ErrorMessage, InstructionAck$Builder, Instruc...
# 7                                 [Nonnull, Nullable]
# 8   [AppendEventsResponse, StreamEventsRequest, Ta...
# 9   [ClientCall$Listener, Metadata, ForwardingClie...
# 10  [ResultStream, AxonServerConnection, Registrat...
# 11                            [Logger, LoggerFactory]
# 12  [QueryResponse, QueryResponse$Builder, QueryUp...
# 13  [UpdateType, TopologyChange, NodeInfo$Builder,...
# 14                          [ByteString, MessageLite]
# 15  [DcbEventChannel$AppendEventsTransaction, Aggr...
# 16  [CommandResponse, Command, CommandResponse$Bui...
# 17  [QueryHandler$UpdateHandler, QueryChannel, Que...
# 18  [Event, Event$Builder, EventWithToken, Confirm...
# 19      [ControlChannel, ProcessorInstructionHandler]
# 20  [StreamObserver, ClientCallStreamObserver, Cli...
# 21                            [Schedulers, Scheduler]
# 22                                     [AdminChannel]
# 23                                   [CommandChannel]
# 24                                    [ServerAddress]
# 25                                  [GrpcSslContexts]
# 26                                [SslContextBuilder]
# 27                                          [Nonnull]
# 28                          [ConfigurationProperties]
# 29  [ConditionalOnProperty, ConditionalOnClass, Co...
# 30  [Bean, Import, Primary, Conditional, Configura...
# 31  [AutoConfiguration, AutoConfigureBefore, AutoC...
# 32  [EnableConfigurationProperties, ConfigurationP...
# 33                                [Nonnull, Nullable]
# 34  [EventProcessorSettings$MapWrapper, ProcessorD...
# 35  [Status, SimpleStatusAggregator, AbstractHealt...
# 36  [EntityManagerFactory, PersistenceContext, Ent...
# 37  [DefaultValue, ConstructorBinding, BindResult,...
# 38      [ApplicationContext, ApplicationContextAware]
# 39                   [SchemaStore, SchemaStore$Cache]

# %% [markdown]
# ### Table 7 - Artifacts and their external packages
#
# The following table shows the artifacts with the highest external dependency usage broken down by each external package including external annotations. The results are sorted by the artifacts with the highest external package usage rate descending.
#
# The intention of this table is to find artifacts that use a lot of external dependencies and show in detail which external packages are used by them and how many internal packages.
#
# Only the last 30 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_and_external_package`
#
# **Columns:**
# - *artifactName* is the name of the artifact with external dependencies (first grouping column)
# - *artifactPackages* is the number of packages in the artifact
# - *artifactTypes* is the number of types in the artifact
# - *artifactExternalPackages* is the number of external packages used by the artifact
# - *artifactExternalCallingPackages* is the number of packages that use external packages in the artifact
# - *artifactExternalCallingPackagesRate* is artifactExternalCallingPackages / artifactPackages * 100%
# - *externalPackageName* the name of the external package (second grouping column)
# - *numberOfPackages* is the number of internal packages of the artifact that use the external packages
# - *numberOfTypes* is the number of internal types of the artifact that use the external packages
# - *packagesCallingExternalRate* is numberOfPackages / artifactPackages * 100%
# - *typesCallingExternalRate* is numberOfTypes / artifactTypes * 100%
# - *nameOfPackages* names of the internal packages that use the external package in the artifact
# - *someTypeNames* some (10) names of the internal types that use the external package in the artifact

# %%
external_packages_per_artifact = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_and_external_package.cypher")
external_packages_per_artifact.head(30)
# Out:
#                      artifactName  artifactPackages  artifactTypes  \
# 0           axon-conversion-5.0.2                 4             30
# 1           axon-conversion-5.0.2                 4             30
# 2           axon-conversion-5.0.2                 4             30
# 3           axon-conversion-5.0.2                 4             30
# 4           axon-conversion-5.0.2                 4             30
# 5           axon-conversion-5.0.2                 4             30
# 6           axon-conversion-5.0.2                 4             30
# 7           axon-conversion-5.0.2                 4             30
# 8           axon-conversion-5.0.2                 4             30
# 9           axon-conversion-5.0.2                 4             30
# 10          axon-conversion-5.0.2                 4             30
# 11       axon-eventsourcing-5.0.2                 8            104
# 12       axon-eventsourcing-5.0.2                 8            104
# 13       axon-eventsourcing-5.0.2                 8            104
# 14       axon-eventsourcing-5.0.2                 8            104
# 15       axon-eventsourcing-5.0.2                 8            104
# 16       axon-eventsourcing-5.0.2                 8            104
# 17  axon-metrics-micrometer-5.0.2                 2             13
# 18  axon-metrics-micrometer-5.0.2                 2             13
# 19  axon-metrics-micrometer-5.0.2                 2             13
# 20  axon-metrics-micrometer-5.0.2                 2             13
# 21           axon-modelling-5.0.2                 7             93
# 22           axon-modelling-5.0.2                 7             93
# 23    axon-server-connector-5.0.2                 5             72
# 24    axon-server-connector-5.0.2                 5             72
# 25    axon-server-connector-5.0.2                 5             72
# 26    axon-server-connector-5.0.2                 5             72
# 27    axon-server-connector-5.0.2                 5             72
# 28    axon-server-connector-5.0.2                 5             72
# 29    axon-server-connector-5.0.2                 5             72
#
#     artifactExternalPackages  artifactExternalCallingPackages  \
# 0                         11                                4
# 1                         11                                4
# 2                         11                                4
# 3                         11                                4
# 4                         11                                4
# 5                         11                                4
# 6                         11                                4
# 7                         11                                4
# 8                         11                                4
# 9                         11                                4
# 10                        11                                4
# 11                         6                                8
# 12                         6                                8
# 13                         6                                8
# 14                         6                                8
# 15                         6                                8
# 16                         6                                8
# 17                         4                                2
# 18                         4                                2
# 19                         4                                2
# 20                         4                                2
# 21                         2                                7
# 22                         2                                7
# 23                        23                                5
# 24                        23                                5
# 25                        23                                5
# 26                        23                                5
# 27                        23                                5
# 28                        23                                5
# 29                        23                                5
#
#     artifactExternalCallingPackagesRate  \
# 0                                 100.0
# 1                                 100.0
# 2                                 100.0
# 3                                 100.0
# 4                                 100.0
# 5                                 100.0
# 6                                 100.0
# 7                                 100.0
# 8                                 100.0
# 9                                 100.0
# 10                                100.0
# 11                                100.0
# 12                                100.0
# 13                                100.0
# 14                                100.0
# 15                                100.0
# 16                                100.0
# 17                                100.0
# 18                                100.0
# 19                                100.0
# 20                                100.0
# 21                                100.0
# 22                                100.0
# 23                                100.0
# 24                                100.0
# 25                                100.0
# 26                                100.0
# 27                                100.0
# 28                                100.0
# 29                                100.0
#
#                        externalPackageName  numberOfPackages  numberOfTypes  \
# 0                       jakarta.annotation                 4             25
# 1                                org.slf4j                 3              3
# 2               com.fasterxml.jackson.core                 1              1
# 3           com.fasterxml.jackson.databind                 1              5
# 4      com.fasterxml.jackson.databind.node                 1              2
# 5                          org.apache.avro                 1              4
# 6                  org.apache.avro.generic                 1              6
# 7                       org.apache.avro.io                 1              1
# 8                  org.apache.avro.message                 1              6
# 9                 org.apache.avro.specific                 1              2
# 10          org.apache.commons.lang3.tuple                 1              1
# 11                      jakarta.annotation                 8             64
# 12                               org.slf4j                 2              6
# 13                 IdTypeParameterResolver                 1              1
# 14                    ScannedEntityCreator                 1              1
# 15       WrappedEventCriteriaBuilderMethod                 1              1
# 16                     jakarta.persistence                 1              6
# 17           io.micrometer.core.instrument                 2             12
# 18    io.micrometer.core.instrument.simple                 1              1
# 19                      jakarta.annotation                 1              5
# 20                               org.slf4j                 1              1
# 21                      jakarta.annotation                 7             77
# 22                               org.slf4j                 3              3
# 23               io.axoniq.axonserver.grpc                 5             18
# 24                      jakarta.annotation                 5             25
# 25                     com.google.protobuf                 4              8
# 26          io.axoniq.axonserver.connector                 4             15
# 27                               org.slf4j                 4             12
# 28                                 io.grpc                 3              7
# 29  io.axoniq.axonserver.connector.control                 2              4
#
#     packagesCallingExternalRate  typesCallingExternalRate  \
# 0                    100.000000                 83.333333
# 1                     75.000000                 10.000000
# 2                     25.000000                  3.333333
# 3                     25.000000                 16.666667
# 4                     25.000000                  6.666667
# 5                     25.000000                 13.333333
# 6                     25.000000                 20.000000
# 7                     25.000000                  3.333333
# 8                     25.000000                 20.000000
# 9                     25.000000                  6.666667
# 10                    25.000000                  3.333333
# 11                   100.000000                 61.538462
# 12                    25.000000                  5.769231
# 13                    12.500000                  0.961538
# 14                    12.500000                  0.961538
# 15                    12.500000                  0.961538
# 16                    12.500000                  5.769231
# 17                   100.000000                 92.307692
# 18                    50.000000                  7.692308
# 19                    50.000000                 38.461538
# 20                    50.000000                  7.692308
# 21                   100.000000                 82.795699
# 22                    42.857143                  3.225806
# 23                   100.000000                 25.000000
# 24                   100.000000                 34.722222
# 25                    80.000000                 11.111111
# 26                    80.000000                 20.833333
# 27                    80.000000                 16.666667
# 28                    60.000000                  9.722222
# 29                    40.000000                  5.555556
#
#                                        nameOfPackages  \
# 0   [org.axonframework.conversion, org.axonframewo...
# 1   [org.axonframework.conversion, org.axonframewo...
# 2                 [org.axonframework.conversion.json]
# 3                 [org.axonframework.conversion.json]
# 4                 [org.axonframework.conversion.json]
# 5                 [org.axonframework.conversion.avro]
# 6                 [org.axonframework.conversion.avro]
# 7                 [org.axonframework.conversion.avro]
# 8                 [org.axonframework.conversion.avro]
# 9                 [org.axonframework.conversion.avro]
# 10                [org.axonframework.conversion.avro]
# 11  [org.axonframework.eventsourcing, org.axonfram...
# 12  [org.axonframework.eventsourcing.eventstore.in...
# 13  [org.axonframework.eventsourcing.annotation.re...
# 14  [org.axonframework.eventsourcing.annotation.re...
# 15       [org.axonframework.eventsourcing.annotation]
# 16   [org.axonframework.eventsourcing.eventstore.jpa]
# 17  [org.axonframework.extension.metrics.micromete...
# 18   [org.axonframework.extension.metrics.micrometer]
# 19   [org.axonframework.extension.metrics.micrometer]
# 20   [org.axonframework.extension.metrics.micrometer]
# 21  [org.axonframework.modelling, org.axonframewor...
# 22  [org.axonframework.modelling, org.axonframewor...
# 23  [org.axonframework.axonserver.connector, org.a...
# 24  [org.axonframework.axonserver.connector, org.a...
# 25  [org.axonframework.axonserver.connector.util, ...
# 26  [org.axonframework.axonserver.connector, org.a...
# 27  [org.axonframework.axonserver.connector.util, ...
# 28  [org.axonframework.axonserver.connector, org.a...
# 29  [org.axonframework.axonserver.connector, org.a...
#
#                                         someTypeNames
# 0   [org.axonframework.conversion.ConversionExcept...
# 1   [org.axonframework.conversion.ChainingContentT...
# 2   [org.axonframework.conversion.json.JsonNodeToB...
# 3   [org.axonframework.conversion.json.JsonNodeToO...
# 4   [org.axonframework.conversion.json.JsonNodeToO...
# 5   [org.axonframework.conversion.avro.AvroUtil, o...
# 6   [org.axonframework.conversion.avro.ByteArrayTo...
# 7   [org.axonframework.conversion.avro.ByteArrayTo...
# 8   [org.axonframework.conversion.avro.ByteArrayTo...
# 9   [org.axonframework.conversion.avro.AvroUtil, o...
# 10  [org.axonframework.conversion.avro.DefaultSche...
# 11  [org.axonframework.eventsourcing.EventSourcedE...
# 12  [org.axonframework.eventsourcing.eventstore.in...
# 13  [org.axonframework.eventsourcing.annotation.re...
# 14  [org.axonframework.eventsourcing.annotation.re...
# 15  [org.axonframework.eventsourcing.annotation.An...
# 16  [org.axonframework.eventsourcing.eventstore.jp...
# 17  [org.axonframework.extension.metrics.micromete...
# 18  [org.axonframework.extension.metrics.micromete...
# 19  [org.axonframework.extension.metrics.micromete...
# 20  [org.axonframework.extension.metrics.micromete...
# 21  [org.axonframework.modelling.SimpleStateManage...
# 22  [org.axonframework.modelling.SimpleEntityEvolv...
# 23  [org.axonframework.axonserver.connector.AxonSe...
# 24  [org.axonframework.axonserver.connector.Metada...
# 25  [org.axonframework.axonserver.connector.util.E...
# 26  [org.axonframework.axonserver.connector.AxonSe...
# 27  [org.axonframework.axonserver.connector.util.G...
# 28  [org.axonframework.axonserver.connector.Manage...
# 29  [org.axonframework.axonserver.connector.AxonSe...

# %% [markdown]
# ### Table 7a - Artifacts and their external packages (first 2 levels)
#
# The following table groups the external packages by their first two levels. For example `javax.xml.namespace` and `javax.xml.stream` will be grouped together to `javax.xml`.

# %%
external_second_level_packages_per_artifact = query_cypher_to_data_frame("../cypher/External_Dependencies/External_second_level_package_usage_per_artifact_and_external_package.cypher")
external_second_level_packages_per_artifact.head(30)
# Out:
#                             artifactName  artifactPackages  artifactTypes  \
# 0                  axon-conversion-5.0.2                 4             30
# 1                  axon-conversion-5.0.2                 4             30
# 2                  axon-conversion-5.0.2                 4             30
# 3                  axon-conversion-5.0.2                 4             30
# 4               axon-eventsourcing-5.0.2                 8            104
# 5               axon-eventsourcing-5.0.2                 8            104
# 6               axon-eventsourcing-5.0.2                 8            104
# 7               axon-eventsourcing-5.0.2                 8            104
# 8               axon-eventsourcing-5.0.2                 8            104
# 9               axon-eventsourcing-5.0.2                 8            104
# 10         axon-metrics-micrometer-5.0.2                 2             13
# 11         axon-metrics-micrometer-5.0.2                 2             13
# 12         axon-metrics-micrometer-5.0.2                 2             13
# 13                  axon-modelling-5.0.2                 7             93
# 14                  axon-modelling-5.0.2                 7             93
# 15           axon-server-connector-5.0.2                 5             72
# 16           axon-server-connector-5.0.2                 5             72
# 17           axon-server-connector-5.0.2                 5             72
# 18           axon-server-connector-5.0.2                 5             72
# 19           axon-server-connector-5.0.2                 5             72
# 20           axon-server-connector-5.0.2                 5             72
# 21           axon-server-connector-5.0.2                 5             72
# 22           axon-server-connector-5.0.2                 5             72
# 23  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 24  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 25  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 26  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 27  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 28  axon-spring-boot-autoconfigure-5.0.2                 7             72
# 29  axon-spring-boot-autoconfigure-5.0.2                 7             72
#
#     artifactExternalPackagesFirst2Levels  artifactExternalCallingPackages  \
# 0                                      4                                4
# 1                                      4                                4
# 2                                      4                                4
# 3                                      4                                4
# 4                                      6                                8
# 5                                      6                                8
# 6                                      6                                8
# 7                                      6                                8
# 8                                      6                                8
# 9                                      6                                8
# 10                                     3                                2
# 11                                     3                                2
# 12                                     3                                2
# 13                                     2                                7
# 14                                     2                                7
# 15                                     8                                5
# 16                                     8                                5
# 17                                     8                                5
# 18                                     8                                5
# 19                                     8                                5
# 20                                     8                                5
# 21                                     8                                5
# 22                                     8                                5
# 23                                     8                                7
# 24                                     8                                7
# 25                                     8                                7
# 26                                     8                                7
# 27                                     8                                7
# 28                                     8                                7
# 29                                     8                                7
#
#     artifactExternalCallingPackagesRate    externalPackageNameFirst2Levels  \
# 0                                 100.0                 jakarta.annotation
# 1                                 100.0                          org.slf4j
# 2                                 100.0                      com.fasterxml
# 3                                 100.0                         org.apache
# 4                                 100.0                 jakarta.annotation
# 5                                 100.0                          org.slf4j
# 6                                 100.0            IdTypeParameterResolver
# 7                                 100.0               ScannedEntityCreator
# 8                                 100.0  WrappedEventCriteriaBuilderMethod
# 9                                 100.0                jakarta.persistence
# 10                                100.0                      io.micrometer
# 11                                100.0                 jakarta.annotation
# 12                                100.0                          org.slf4j
# 13                                100.0                 jakarta.annotation
# 14                                100.0                          org.slf4j
# 15                                100.0                          io.axoniq
# 16                                100.0                 jakarta.annotation
# 17                                100.0                         com.google
# 18                                100.0                          org.slf4j
# 19                                100.0                            io.grpc
# 20                                100.0                   javax.annotation
# 21                                100.0                org.springframework
# 22                                100.0                       reactor.core
# 23                                100.0                org.springframework
# 24                                100.0                 jakarta.annotation
# 25                                100.0                  org.axonframework
# 26                                100.0                jakarta.persistence
# 27                                100.0                          org.slf4j
# 28                                100.0                      com.fasterxml
# 29                                100.0                          io.axoniq
#
#     numberOfPackages  numberOfTypes  packagesCallingExternalRate  \
# 0                  4             25                   100.000000
# 1                  3              3                    75.000000
# 2                  1              5                    25.000000
# 3                  1              9                    25.000000
# 4                  8             64                   100.000000
# 5                  2              6                    25.000000
# 6                  1              1                    12.500000
# 7                  1              1                    12.500000
# 8                  1              1                    12.500000
# 9                  1              6                    12.500000
# 10                 2             12                   100.000000
# 11                 1              5                    50.000000
# 12                 1              1                    50.000000
# 13                 7             77                   100.000000
# 14                 3              3                    42.857143
# 15                 5             44                   100.000000
# 16                 5             25                   100.000000
# 17                 4              8                    80.000000
# 18                 4             12                    80.000000
# 19                 3             10                    60.000000
# 20                 1              1                    20.000000
# 21                 1              1                    20.000000
# 22                 1              1                    20.000000
# 23                 6             55                    85.714286
# 24                 4             15                    57.142857
# 25                 3             10                    42.857143
# 26                 2              5                    28.571429
# 27                 2              2                    28.571429
# 28                 1              4                    14.285714
# 29                 1              1                    14.285714
#
#     typesCallingExternalRate  \
# 0                  83.333333
# 1                  10.000000
# 2                  16.666667
# 3                  30.000000
# 4                  61.538462
# 5                   5.769231
# 6                   0.961538
# 7                   0.961538
# 8                   0.961538
# 9                   5.769231
# 10                 92.307692
# 11                 38.461538
# 12                  7.692308
# 13                 82.795699
# 14                  3.225806
# 15                 61.111111
# 16                 34.722222
# 17                 11.111111
# 18                 16.666667
# 19                 13.888889
# 20                  1.388889
# 21                  1.388889
# 22                  1.388889
# 23                 76.388889
# 24                 20.833333
# 25                 13.888889
# 26                  6.944444
# 27                  2.777778
# 28                  5.555556
# 29                  1.388889
#
#                                        nameOfPackages  \
# 0   [org.axonframework.conversion, org.axonframewo...
# 1   [org.axonframework.conversion, org.axonframewo...
# 2                 [org.axonframework.conversion.json]
# 3                 [org.axonframework.conversion.avro]
# 4   [org.axonframework.eventsourcing, org.axonfram...
# 5   [org.axonframework.eventsourcing.eventstore.in...
# 6   [org.axonframework.eventsourcing.annotation.re...
# 7   [org.axonframework.eventsourcing.annotation.re...
# 8        [org.axonframework.eventsourcing.annotation]
# 9    [org.axonframework.eventsourcing.eventstore.jpa]
# 10  [org.axonframework.extension.metrics.micromete...
# 11   [org.axonframework.extension.metrics.micrometer]
# 12   [org.axonframework.extension.metrics.micrometer]
# 13  [org.axonframework.modelling, org.axonframewor...
# 14  [org.axonframework.modelling, org.axonframewor...
# 15  [org.axonframework.axonserver.connector, org.a...
# 16  [org.axonframework.axonserver.connector, org.a...
# 17  [org.axonframework.axonserver.connector.util, ...
# 18  [org.axonframework.axonserver.connector.util, ...
# 19  [org.axonframework.axonserver.connector, org.a...
# 20           [org.axonframework.axonserver.connector]
# 21           [org.axonframework.axonserver.connector]
# 22      [org.axonframework.axonserver.connector.util]
# 23  [org.axonframework.extension.springboot, org.a...
# 24  [org.axonframework.extension.springboot, org.a...
# 25  [org.axonframework.extension.springboot, org.a...
# 26  [org.axonframework.extension.springboot.autoco...
# 27  [org.axonframework.extension.springboot.servic...
# 28  [org.axonframework.extension.springboot.autoco...
# 29  [org.axonframework.extension.springboot.autoco...
#
#                                         someTypeNames
# 0   [org.axonframework.conversion.ConversionExcept...
# 1   [org.axonframework.conversion.ChainingContentT...
# 2   [org.axonframework.conversion.json.JsonNodeToO...
# 3   [org.axonframework.conversion.avro.ByteArrayTo...
# 4   [org.axonframework.eventsourcing.EventSourcedE...
# 5   [org.axonframework.eventsourcing.eventstore.in...
# 6   [org.axonframework.eventsourcing.annotation.re...
# 7   [org.axonframework.eventsourcing.annotation.re...
# 8   [org.axonframework.eventsourcing.annotation.An...
# 9   [org.axonframework.eventsourcing.eventstore.jp...
# 10  [org.axonframework.extension.metrics.micromete...
# 11  [org.axonframework.extension.metrics.micromete...
# 12  [org.axonframework.extension.metrics.micromete...
# 13  [org.axonframework.modelling.SimpleStateManage...
# 14  [org.axonframework.modelling.SimpleEntityEvolv...
# 15  [org.axonframework.axonserver.connector.AxonSe...
# 16  [org.axonframework.axonserver.connector.Metada...
# 17  [org.axonframework.axonserver.connector.util.E...
# 18  [org.axonframework.axonserver.connector.util.G...
# 19  [org.axonframework.axonserver.connector.Defaul...
# 20  [org.axonframework.axonserver.connector.AxonSe...
# 21  [org.axonframework.axonserver.connector.AxonSe...
# 22  [org.axonframework.axonserver.connector.util.P...
# 23  [org.axonframework.extension.springboot.Timeou...
# 24  [org.axonframework.extension.springboot.EventP...
# 25  [org.axonframework.extension.springboot.EventP...
# 26  [org.axonframework.extension.springboot.autoco...
# 27  [org.axonframework.extension.springboot.servic...
# 28  [org.axonframework.extension.springboot.autoco...
# 29  [org.axonframework.extension.springboot.autoco...

# %% [markdown]
# #### Table 7b - Top 15 external dependency using artifacts as columns with their external packages
#
# The following table uses pivot to show the artifacts in columns, the external dependencies in rows and the number of internal packages as values.

# %%
# Calculate the percentage for each value based on the global sum of all values
def percentage_global(data_frame : pd.DataFrame):
    total = data_frame.sum().sum()
    return data_frame / total * 100

# %%
external_packages_per_artifact_pivot = external_packages_per_artifact.copy()

# Every row represents the number of external package
external_packages_per_artifact_pivot=external_packages_per_artifact_pivot.pivot(index='externalPackageName', columns='artifactName', values='numberOfPackages')

# Sort by column sum and then take only the first 10 columns
sum_of_external_packages_per_artifact = external_packages_per_artifact_pivot.sum()
external_packages_per_artifact_pivot = external_packages_per_artifact_pivot[sum_of_external_packages_per_artifact.sort_values(ascending=False).index[:15]]

# Fill missing values with zeroes
external_packages_per_artifact_pivot.fillna(0, inplace=True)

external_packages_per_artifact_pivot.astype('int')
# Out:
# artifactName                                 axon-messaging-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                         0
# ScannedEntityCreator                                            0
# WrappedEventCriteriaBuilderMethod                               0
# com.fasterxml.jackson.annotation                                3
# com.fasterxml.jackson.core                                      0
# ...                                                           ...
# org.testcontainers.containers.wait.strategy                     0
# org.testcontainers.utility                                      0
# reactor.core.publisher                                          5
# reactor.core.scheduler                                          0
# reactor.util.concurrent                                         1
#
# artifactName                                 axon-spring-boot-autoconfigure-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                                         0
# ScannedEntityCreator                                                            0
# WrappedEventCriteriaBuilderMethod                                               0
# com.fasterxml.jackson.annotation                                                0
# com.fasterxml.jackson.core                                                      0
# ...                                                                           ...
# org.testcontainers.containers.wait.strategy                                     0
# org.testcontainers.utility                                                      0
# reactor.core.publisher                                                          0
# reactor.core.scheduler                                                          0
# reactor.util.concurrent                                                         0
#
# artifactName                                 axon-server-connector-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                                0
# ScannedEntityCreator                                                   0
# WrappedEventCriteriaBuilderMethod                                      0
# com.fasterxml.jackson.annotation                                       0
# com.fasterxml.jackson.core                                             0
# ...                                                                  ...
# org.testcontainers.containers.wait.strategy                            0
# org.testcontainers.utility                                             0
# reactor.core.publisher                                                 0
# reactor.core.scheduler                                                 1
# reactor.util.concurrent                                                0
#
# artifactName                                 axon-common-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                      0
# ScannedEntityCreator                                         0
# WrappedEventCriteriaBuilderMethod                            0
# com.fasterxml.jackson.annotation                             0
# com.fasterxml.jackson.core                                   0
# ...                                                        ...
# org.testcontainers.containers.wait.strategy                  0
# org.testcontainers.utility                                   0
# reactor.core.publisher                                       0
# reactor.core.scheduler                                       0
# reactor.util.concurrent                                      0
#
# artifactName                                 axon-conversion-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                          0
# ScannedEntityCreator                                             0
# WrappedEventCriteriaBuilderMethod                                0
# com.fasterxml.jackson.annotation                                 0
# com.fasterxml.jackson.core                                       1
# ...                                                            ...
# org.testcontainers.containers.wait.strategy                      0
# org.testcontainers.utility                                       0
# reactor.core.publisher                                           0
# reactor.core.scheduler                                           0
# reactor.util.concurrent                                          0
#
# artifactName                                 axon-test-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                    0
# ScannedEntityCreator                                       0
# WrappedEventCriteriaBuilderMethod                          0
# com.fasterxml.jackson.annotation                           0
# com.fasterxml.jackson.core                                 0
# ...                                                      ...
# org.testcontainers.containers.wait.strategy                1
# org.testcontainers.utility                                 1
# reactor.core.publisher                                     0
# reactor.core.scheduler                                     0
# reactor.util.concurrent                                    0
#
# artifactName                                 axon-eventsourcing-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                             1
# ScannedEntityCreator                                                1
# WrappedEventCriteriaBuilderMethod                                   1
# com.fasterxml.jackson.annotation                                    0
# com.fasterxml.jackson.core                                          0
# ...                                                               ...
# org.testcontainers.containers.wait.strategy                         0
# org.testcontainers.utility                                          0
# reactor.core.publisher                                              0
# reactor.core.scheduler                                              0
# reactor.util.concurrent                                             0
#
# artifactName                                 axon-modelling-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                         0
# ScannedEntityCreator                                            0
# WrappedEventCriteriaBuilderMethod                               0
# com.fasterxml.jackson.annotation                                0
# com.fasterxml.jackson.core                                      0
# ...                                                           ...
# org.testcontainers.containers.wait.strategy                     0
# org.testcontainers.utility                                      0
# reactor.core.publisher                                          0
# reactor.core.scheduler                                          0
# reactor.util.concurrent                                         0
#
# artifactName                                 axon-update-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                      0
# ScannedEntityCreator                                         0
# WrappedEventCriteriaBuilderMethod                            0
# com.fasterxml.jackson.annotation                             0
# com.fasterxml.jackson.core                                   0
# ...                                                        ...
# org.testcontainers.containers.wait.strategy                  0
# org.testcontainers.utility                                   0
# reactor.core.publisher                                       0
# reactor.core.scheduler                                       0
# reactor.util.concurrent                                      0
#
# artifactName                                 axon-tracing-opentelemetry-5.0.2  \
# externalPackageName
# IdTypeParameterResolver                                                     0
# ScannedEntityCreator                                                        0
# WrappedEventCriteriaBuilderMethod                                           0
# com.fasterxml.jackson.annotation                                            0
# com.fasterxml.jackson.core                                                  0
# ...                                                                       ...
# org.testcontainers.containers.wait.strategy                                 0
# org.testcontainers.utility                                                  0
# reactor.core.publisher                                                      0
# reactor.core.scheduler                                                      0
# reactor.util.concurrent                                                     0
#
# artifactName                                 axon-metrics-micrometer-5.0.2
# externalPackageName
# IdTypeParameterResolver                                                  0
# ScannedEntityCreator                                                     0
# WrappedEventCriteriaBuilderMethod                                        0
# com.fasterxml.jackson.annotation                                         0
# com.fasterxml.jackson.core                                               0
# ...                                                                    ...
# org.testcontainers.containers.wait.strategy                              0
# org.testcontainers.utility                                               0
# reactor.core.publisher                                                   0
# reactor.core.scheduler                                                   0
# reactor.util.concurrent                                                  0
#
# [90 rows x 11 columns]

# %% [markdown]
# #### Table 7c - Top 15 external dependency using artifacts as columns with their external packages (first 2 levels)
#
# The following table uses pivot to show the artifacts in columns, the external package name grouped by its first two levels in rows and the number of internal packages as values. For example `javax.xml.namespace` and `javax.xml.stream` will be grouped together to `javax.xml`.

# %%
external_second_level_packages_per_artifact_pivot = external_second_level_packages_per_artifact.copy()

# Every row represents the number of external package
external_second_level_packages_per_artifact_pivot=external_second_level_packages_per_artifact_pivot.pivot(index='externalPackageNameFirst2Levels', columns='artifactName', values='numberOfPackages')

# Sort by column sum and then take only the first 10 columns
sum_of_external_second_level_packages_per_artifact = external_second_level_packages_per_artifact_pivot.sum()
external_second_level_packages_per_artifact_pivot = external_second_level_packages_per_artifact_pivot[sum_of_external_second_level_packages_per_artifact.sort_values(ascending=False).index[:15]]

# Fill missing values with zeroes
external_second_level_packages_per_artifact_pivot.fillna(0, inplace=True)

external_second_level_packages_per_artifact_pivot.astype('int')
# Out:
# artifactName                       axon-messaging-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                               0
# ScannedEntityCreator                                  0
# WrappedEventCriteriaBuilderMethod                     0
# com.fasterxml                                         3
# com.google                                            0
# io.axoniq                                             0
# io.grpc                                               0
# io.micrometer                                         0
# io.opentelemetry                                      0
# jakarta.annotation                                   56
# jakarta.persistence                                   1
# jakarta.validation                                    1
# javax.annotation                                      1
# javax.cache                                           0
# org.apache                                            0
# org.awaitility                                        0
# org.axonframework                                     0
# org.ehcache                                           0
# org.hamcrest                                          0
# org.jetbrains                                         0
# org.junit                                             0
# org.reactivestreams                                   3
# org.slf4j                                            14
# org.springframework                                   0
# org.testcontainers                                    0
# reactor.core                                          5
# reactor.util                                          1
#
# artifactName                       axon-server-connector-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                      0
# ScannedEntityCreator                                         0
# WrappedEventCriteriaBuilderMethod                            0
# com.fasterxml                                                0
# com.google                                                   4
# io.axoniq                                                    5
# io.grpc                                                      3
# io.micrometer                                                0
# io.opentelemetry                                             0
# jakarta.annotation                                           5
# jakarta.persistence                                          0
# jakarta.validation                                           0
# javax.annotation                                             1
# javax.cache                                                  0
# org.apache                                                   0
# org.awaitility                                               0
# org.axonframework                                            0
# org.ehcache                                                  0
# org.hamcrest                                                 0
# org.jetbrains                                                0
# org.junit                                                    0
# org.reactivestreams                                          0
# org.slf4j                                                    4
# org.springframework                                          1
# org.testcontainers                                           0
# reactor.core                                                 1
# reactor.util                                                 0
#
# artifactName                       axon-spring-boot-autoconfigure-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                               0
# ScannedEntityCreator                                                  0
# WrappedEventCriteriaBuilderMethod                                     0
# com.fasterxml                                                         1
# com.google                                                            0
# io.axoniq                                                             1
# io.grpc                                                               0
# io.micrometer                                                         0
# io.opentelemetry                                                      0
# jakarta.annotation                                                    4
# jakarta.persistence                                                   2
# jakarta.validation                                                    0
# javax.annotation                                                      0
# javax.cache                                                           0
# org.apache                                                            1
# org.awaitility                                                        0
# org.axonframework                                                     3
# org.ehcache                                                           0
# org.hamcrest                                                          0
# org.jetbrains                                                         0
# org.junit                                                             0
# org.reactivestreams                                                   0
# org.slf4j                                                             2
# org.springframework                                                   6
# org.testcontainers                                                    0
# reactor.core                                                          0
# reactor.util                                                          0
#
# artifactName                       axon-common-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                            0
# ScannedEntityCreator                               0
# WrappedEventCriteriaBuilderMethod                  0
# com.fasterxml                                      1
# com.google                                         0
# io.axoniq                                          0
# io.grpc                                            0
# io.micrometer                                      0
# io.opentelemetry                                   0
# jakarta.annotation                                 9
# jakarta.persistence                                1
# jakarta.validation                                 0
# javax.annotation                                   0
# javax.cache                                        1
# org.apache                                         0
# org.awaitility                                     0
# org.axonframework                                  0
# org.ehcache                                        1
# org.hamcrest                                       0
# org.jetbrains                                      0
# org.junit                                          0
# org.reactivestreams                                0
# org.slf4j                                          4
# org.springframework                                0
# org.testcontainers                                 0
# reactor.core                                       0
# reactor.util                                       0
#
# artifactName                       axon-eventsourcing-5.0.2  axon-test-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                   1                0
# ScannedEntityCreator                                      1                0
# WrappedEventCriteriaBuilderMethod                         1                0
# com.fasterxml                                             0                0
# com.google                                                0                1
# io.axoniq                                                 0                0
# io.grpc                                                   0                0
# io.micrometer                                             0                0
# io.opentelemetry                                          0                0
# jakarta.annotation                                        8                3
# jakarta.persistence                                       1                0
# jakarta.validation                                        0                0
# javax.annotation                                          0                0
# javax.cache                                               0                0
# org.apache                                                0                0
# org.awaitility                                            0                1
# org.axonframework                                         0                0
# org.ehcache                                               0                0
# org.hamcrest                                              0                3
# org.jetbrains                                             0                2
# org.junit                                                 0                1
# org.reactivestreams                                       0                0
# org.slf4j                                                 2                1
# org.springframework                                       0                0
# org.testcontainers                                        0                1
# reactor.core                                              0                0
# reactor.util                                              0                0
#
# artifactName                       axon-modelling-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                               0
# ScannedEntityCreator                                  0
# WrappedEventCriteriaBuilderMethod                     0
# com.fasterxml                                         0
# com.google                                            0
# io.axoniq                                             0
# io.grpc                                               0
# io.micrometer                                         0
# io.opentelemetry                                      0
# jakarta.annotation                                    7
# jakarta.persistence                                   0
# jakarta.validation                                    0
# javax.annotation                                      0
# javax.cache                                           0
# org.apache                                            0
# org.awaitility                                        0
# org.axonframework                                     0
# org.ehcache                                           0
# org.hamcrest                                          0
# org.jetbrains                                         0
# org.junit                                             0
# org.reactivestreams                                   0
# org.slf4j                                             3
# org.springframework                                   0
# org.testcontainers                                    0
# reactor.core                                          0
# reactor.util                                          0
#
# artifactName                       axon-conversion-5.0.2  axon-update-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                0                  0
# ScannedEntityCreator                                   0                  0
# WrappedEventCriteriaBuilderMethod                      0                  0
# com.fasterxml                                          1                  0
# com.google                                             0                  0
# io.axoniq                                              0                  0
# io.grpc                                                0                  0
# io.micrometer                                          0                  0
# io.opentelemetry                                       0                  0
# jakarta.annotation                                     4                  4
# jakarta.persistence                                    0                  0
# jakarta.validation                                     0                  0
# javax.annotation                                       0                  0
# javax.cache                                            0                  0
# org.apache                                             1                  0
# org.awaitility                                         0                  0
# org.axonframework                                      0                  0
# org.ehcache                                            0                  0
# org.hamcrest                                           0                  0
# org.jetbrains                                          0                  0
# org.junit                                              0                  0
# org.reactivestreams                                    0                  0
# org.slf4j                                              3                  3
# org.springframework                                    0                  0
# org.testcontainers                                     0                  0
# reactor.core                                           0                  0
# reactor.util                                           0                  0
#
# artifactName                       axon-metrics-micrometer-5.0.2  \
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                        0
# ScannedEntityCreator                                           0
# WrappedEventCriteriaBuilderMethod                              0
# com.fasterxml                                                  0
# com.google                                                     0
# io.axoniq                                                      0
# io.grpc                                                        0
# io.micrometer                                                  2
# io.opentelemetry                                               0
# jakarta.annotation                                             1
# jakarta.persistence                                            0
# jakarta.validation                                             0
# javax.annotation                                               0
# javax.cache                                                    0
# org.apache                                                     0
# org.awaitility                                                 0
# org.axonframework                                              0
# org.ehcache                                                    0
# org.hamcrest                                                   0
# org.jetbrains                                                  0
# org.junit                                                      0
# org.reactivestreams                                            0
# org.slf4j                                                      1
# org.springframework                                            0
# org.testcontainers                                             0
# reactor.core                                                   0
# reactor.util                                                   0
#
# artifactName                       axon-tracing-opentelemetry-5.0.2
# externalPackageNameFirst2Levels
# IdTypeParameterResolver                                           0
# ScannedEntityCreator                                              0
# WrappedEventCriteriaBuilderMethod                                 0
# com.fasterxml                                                     0
# com.google                                                        0
# io.axoniq                                                         0
# io.grpc                                                           0
# io.micrometer                                                     0
# io.opentelemetry                                                  1
# jakarta.annotation                                                1
# jakarta.persistence                                               0
# jakarta.validation                                                0
# javax.annotation                                                  0
# javax.cache                                                       0
# org.apache                                                        0
# org.awaitility                                                    0
# org.axonframework                                                 0
# org.ehcache                                                       0
# org.hamcrest                                                      0
# org.jetbrains                                                     0
# org.junit                                                         0
# org.reactivestreams                                               0
# org.slf4j                                                         1
# org.springframework                                               0
# org.testcontainers                                                0
# reactor.core                                                      0
# reactor.util                                                      0

# %% [markdown]
# #### Table 7 Chart 1 - Top 15 external dependency using artifacts and their external packages stacked
#
# The following chart shows the top 15 external package using artifacts and breaks down which external packages they use in how many different internal packages with stacked bars.
#
# Note that every external dependency is counted separately so that if on internal package uses two external packages it will be displayed for both and so stacked twice.

# %%
if external_packages_per_artifact_pivot.empty:
    print("No data to plot")
else:
    plot.figure();
    axes = external_packages_per_artifact_pivot.transpose().plot(
        kind='bar', 
        grid=True,
        title='External package usage per artifact', 
        xlabel='artifact',
        ylabel='number of packages',
        stacked=True,
        legend=True,
        cmap=main_color_map
    ).legend(bbox_to_anchor=(1.0, 1.0))
    plot.show()

# %% [markdown]
# #### Table 7 Chart 2 - Top 15 external dependency using artifacts and their external packages (first 2 levels) stacked
#
# The following chart shows the top 15 external package using artifacts and breaks down which external packages (first 2 levels) are used in how many different internal packages with stacked bars.
#
# Note that every external dependency is counted separately so that if on internal package uses two external packages it will be displayed for both and so stacked twice.

# %%
if external_second_level_packages_per_artifact_pivot.empty:
    print("No data to plot")
else:
    plot.figure();
    axes = external_second_level_packages_per_artifact_pivot.transpose().plot(
        kind='bar', 
        grid=True,
        title='External package (first 2 levels) usage per artifact', 
        xlabel='artifact',
        ylabel='number of packages',
        stacked=True,
        legend=True,
        cmap=main_color_map
    ).legend(bbox_to_anchor=(1.0, 1.0))
    plot.show()

# %% [markdown]
# ### Table 8 - External usage per artifact
#
# The following table shows the most used external packages separately for each artifact including external annotations. The results are grouped per artifact and sorted by the artifacts with the highest external type usage rate descending. Additionally, for each artifact the top 5 used external packages are listed in the top5ExternalPackages column.
#
# The intention of this table is to find artifacts that use a lot of external dependencies in relation to their size and get an overview per artifact with the top 5 used external packages, the number of external types and packages used etc. .
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_sorted_top`
#
# **Columns:**
# - *artifactName* is used to group the the external package usage per artifact for a more detailed analysis.
# - *numberOfTypesInArtifact* represents the total count of all analyzed types for the artifact
# - *numberOfExternalTypesInArtifact* is the number of all external types that are used by the artifact
# - *numberOfExternalPackagesInArtifact* is the number of all external packages that are used by the artifact
# - *externalTypeRate* is the numberOfExternalTypesInArtifact / numberOfTypesInArtifact * 100
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfExternalPackages* is the number of distinct external packages used by the artifact
# - *top5ExternalPackages* contains a list of the top 5 most used external packages of the artifact
# - *someExternalTypes* contains a list of lists and is also mean't to provide some examples of external types used

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_sorted_top.cypher").head(40)
# Out:
#                             artifactName  numberOfTypesInArtifact  \
# 0       axon-tracing-opentelemetry-5.0.2                        5
# 1            axon-server-connector-5.0.2                       72
# 2   axon-spring-boot-autoconfigure-5.0.2                       72
# 3                  axon-conversion-5.0.2                       30
# 4          axon-metrics-micrometer-5.0.2                       13
# 5                        axon-test-5.0.2                       73
# 6               axon-eventsourcing-5.0.2                      104
# 7                      axon-common-5.0.2                      156
# 8                      axon-update-5.0.2                       23
# 9                   axon-messaging-5.0.2                      570
# 10                  axon-modelling-5.0.2                       93
#
#     numberOfExternalTypesInArtifact  numberOfExternalPackagesInArtifact  \
# 0                                16                                   6
# 1                               113                                  23
# 2                                95                                  37
# 3                                32                                  11
# 4                                13                                   4
# 5                                24                                  11
# 6                                22                                   6
# 7                                29                                  11
# 8                                 4                                   2
# 9                                33                                   9
# 10                                4                                   2
#
#     externalTypeRate  numberOfExternalTypeCaller  numberOfExternalTypeCalls  \
# 0         320.000000                          26                         85
# 1         156.944444                         242                       1197
# 2         131.944444                         239                        442
# 3         106.666667                          99                        421
# 4         100.000000                          46                        152
# 5          32.876712                          94                        461
# 6          21.153846                         109                        407
# 7          18.589744                         116                        540
# 8          17.391304                          28                        129
# 9           5.789474                         607                       3254
# 10          4.301075                          92                        586
#
#     numberOfExternalPackages  \
# 0                          6
# 1                         23
# 2                         37
# 3                         11
# 4                          4
# 5                         11
# 6                          6
# 7                         11
# 8                          2
# 9                          9
# 10                         2
#
#                                  top5ExternalPackages  \
# 0   [io.opentelemetry.context.propagation, io.open...
# 1   [io.axoniq.axonserver.grpc, jakarta.annotation...
# 2   [org.springframework.boot.autoconfigure.condit...
# 3   [jakarta.annotation, org.apache.avro, org.apac...
# 4   [io.micrometer.core.instrument, jakarta.annota...
# 5   [org.hamcrest, jakarta.annotation, com.google....
# 6   [jakarta.annotation, jakarta.persistence, org....
# 7   [jakarta.annotation, org.slf4j, javax.cache.ev...
# 8                     [jakarta.annotation, org.slf4j]
# 9   [jakarta.annotation, org.slf4j, com.fasterxml....
# 10                    [jakarta.annotation, org.slf4j]
#
#                                     someExternalTypes
# 0   [TextMapGetter, TextMapSetter, TextMapPropagat...
# 1   [ErrorMessage, InstructionAck$Builder, Instruc...
# 2   [ConditionalOnProperty, ConditionalOnClass, Co...
# 3   [Nonnull, Nullable, AvroRuntimeException, Sche...
# 4   [Clock, Timer, Tags, Tag, MeterRegistry, Count...
# 5   [Description, TypeSafeMatcher, Matcher, CoreMa...
# 6   [Nonnull, Nullable, EntityManager, EntityManag...
# 7   [Nonnull, Nullable, LoggerFactory, Logger, Cac...
# 8          [Nonnull, Nullable, LoggerFactory, Logger]
# 9   [Nonnull, Nullable, LoggerFactory, Logger, Jso...
# 10         [Nonnull, Nullable, LoggerFactory, Logger]

# %% [markdown]
# ### Table 9 - External usage per artifact and package
#
# This table lists internal packages and the artifacts they belong to that use many different external types of a specific external package without taking external annotations into account.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_and_package`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls the external package
# - *externalPackageName* identifies the external package as described above
# - *numberOfExternalTypeCaller* refers to the distinct types that make use of the external package
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_package = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_and_package.cypher")
external_package_usage_per_package.head(40)
# Out:
#                             artifactName  \
# 0          axon-metrics-micrometer-5.0.2
# 1                        axon-test-5.0.2
# 2            axon-server-connector-5.0.2
# 3            axon-server-connector-5.0.2
# 4                  axon-conversion-5.0.2
# 5                   axon-messaging-5.0.2
# 6            axon-server-connector-5.0.2
# 7               axon-eventsourcing-5.0.2
# 8            axon-server-connector-5.0.2
# 9            axon-server-connector-5.0.2
# 10           axon-server-connector-5.0.2
# 11           axon-server-connector-5.0.2
# 12  axon-spring-boot-autoconfigure-5.0.2
# 13      axon-tracing-opentelemetry-5.0.2
# 14      axon-tracing-opentelemetry-5.0.2
# 15                     axon-common-5.0.2
# 16                     axon-common-5.0.2
# 17                 axon-conversion-5.0.2
# 18                 axon-conversion-5.0.2
# 19                  axon-messaging-5.0.2
# 20           axon-server-connector-5.0.2
# 21           axon-server-connector-5.0.2
# 22           axon-server-connector-5.0.2
# 23           axon-server-connector-5.0.2
# 24                     axon-update-5.0.2
# 25                 axon-conversion-5.0.2
# 26              axon-eventsourcing-5.0.2
# 27                  axon-messaging-5.0.2
# 28           axon-server-connector-5.0.2
# 29                       axon-test-5.0.2
# 30           axon-server-connector-5.0.2
# 31                     axon-common-5.0.2
# 32                     axon-common-5.0.2
# 33                     axon-common-5.0.2
# 34                  axon-messaging-5.0.2
# 35                  axon-messaging-5.0.2
# 36                  axon-messaging-5.0.2
# 37           axon-server-connector-5.0.2
# 38           axon-server-connector-5.0.2
# 39           axon-server-connector-5.0.2
#
#                                       fullPackageName  \
# 0      org.axonframework.extension.metrics.micrometer
# 1                     org.axonframework.test.matchers
# 2        org.axonframework.axonserver.connector.event
# 3         org.axonframework.axonserver.connector.util
# 4                   org.axonframework.conversion.avro
# 5   org.axonframework.messaging.eventhandling.proc...
# 6        org.axonframework.axonserver.connector.query
# 7      org.axonframework.eventsourcing.eventstore.jpa
# 8              org.axonframework.axonserver.connector
# 9        org.axonframework.axonserver.connector.event
# 10       org.axonframework.axonserver.connector.query
# 11       org.axonframework.axonserver.connector.query
# 12  org.axonframework.extension.springboot.autoconfig
# 13  org.axonframework.extension.tracing.opentelemetry
# 14  org.axonframework.extension.tracing.opentelemetry
# 15                   org.axonframework.common.caching
# 16                   org.axonframework.common.caching
# 17                  org.axonframework.conversion.avro
# 18                  org.axonframework.conversion.json
# 19        org.axonframework.messaging.core.annotation
# 20             org.axonframework.axonserver.connector
# 21     org.axonframework.axonserver.connector.command
# 22       org.axonframework.axonserver.connector.event
# 23        org.axonframework.axonserver.connector.util
# 24                           org.axonframework.update
# 25                  org.axonframework.conversion.avro
# 26     org.axonframework.eventsourcing.eventstore.jpa
# 27                   org.axonframework.messaging.core
# 28     org.axonframework.axonserver.connector.command
# 29                     org.axonframework.test.fixture
# 30       org.axonframework.axonserver.connector.query
# 31                           org.axonframework.common
# 32             org.axonframework.common.configuration
# 33                       org.axonframework.common.jpa
# 34                   org.axonframework.messaging.core
# 35      org.axonframework.messaging.core.interception
# 36  org.axonframework.messaging.eventhandling.proc...
# 37             org.axonframework.axonserver.connector
# 38       org.axonframework.axonserver.connector.event
# 39       org.axonframework.axonserver.connector.event
#
#                           externalPackageName  numberOfExternalTypeCaller  \
# 0               io.micrometer.core.instrument                          37
# 1                                org.hamcrest                          36
# 2         io.axoniq.axonserver.grpc.event.dcb                          28
# 3                                     io.grpc                          17
# 4                             org.apache.avro                          16
# 5                                   org.slf4j                          15
# 6             io.axoniq.axonserver.grpc.query                          14
# 7                         jakarta.persistence                          12
# 8                   io.axoniq.axonserver.grpc                          12
# 9                                   org.slf4j                          10
# 10             io.axoniq.axonserver.connector                          10
# 11                  io.axoniq.axonserver.grpc                           9
# 12  org.axonframework.extension.spring.config                           9
# 13                 io.opentelemetry.api.trace                           9
# 14       io.opentelemetry.context.propagation                           9
# 15                          org.ehcache.event                           8
# 16                          javax.cache.event                           8
# 17                    org.apache.avro.message                           8
# 18             com.fasterxml.jackson.databind                           8
# 19                                  org.slf4j                           8
# 20          io.axoniq.axonserver.grpc.control                           8
# 21          io.axoniq.axonserver.grpc.command                           8
# 22       io.axoniq.axonserver.connector.event                           8
# 23                  io.axoniq.axonserver.grpc                           8
# 24                                  org.slf4j                           8
# 25                    org.apache.avro.generic                           7
# 26                                  org.slf4j                           7
# 27                     reactor.core.publisher                           7
# 28                  io.axoniq.axonserver.grpc                           7
# 29                               org.hamcrest                           7
# 30       io.axoniq.axonserver.connector.query                           6
# 31                                  org.slf4j                           5
# 32                                  org.slf4j                           5
# 33                        jakarta.persistence                           5
# 34                        org.reactivestreams                           5
# 35                         jakarta.validation                           5
# 36                        jakarta.persistence                           5
# 37             io.axoniq.axonserver.connector                           5
# 38          io.axoniq.axonserver.grpc.control                           5
# 39             io.axoniq.axonserver.connector                           5
#
#     numberOfExternalTypeCalls  numberOfTypesInPackage  \
# 0                         136                      12
# 1                         142                      23
# 2                         104                      14
# 3                          35                      13
# 4                          54                      10
# 5                          87                      24
# 6                          98                      11
# 7                          56                      15
# 8                          94                      28
# 9                          44                      14
# 10                         37                      11
# 11                         50                      11
# 12                         33                      35
# 13                         46                       5
# 14                         15                       5
# 15                         30                      13
# 16                         26                      13
# 17                         28                      10
# 18                         42                       5
# 19                         17                      50
# 20                         46                      28
# 21                         63                       6
# 22                         38                      14
# 23                         81                      13
# 24                         27                       5
# 25                         30                      10
# 26                         16                      15
# 27                         30                      80
# 28                         31                       6
# 29                         47                      31
# 30                         19                      11
# 31                         14                      34
# 32                         27                      46
# 33                         11                       4
# 34                         10                      80
# 35                         16                      19
# 36                         60                       4
# 37                         38                      28
# 38                         40                      14
# 39                         37                      14
#
#                                     externalTypeNames    packageName
# 0   [Tags, Clock, Gauge$Builder, Tag, MeterRegistr...     micrometer
# 1   [Description, Matcher, BaseMatcher, TypeSafeMa...       matchers
# 2   [GetTailResponse, GetSequenceAtResponse, Tagge...          event
# 3   [Status, Status$Code, Metadata, Metadata$Ascii...           util
# 4   [SchemaCompatibility$SchemaCompatibilityType, ...           avro
# 5                             [LoggerFactory, Logger]         pooled
# 6   [QueryResponse, QueryUpdate, QueryUpdate$Build...          query
# 7   [EntityExistsException, EntityManager, EntityM...            jpa
# 8   [ErrorMessage, MetaDataValue$DataCase, Instruc...      connector
# 9                             [LoggerFactory, Logger]          event
# 10  [ResultStream, ReplyChannel, FlowControl, Regi...          query
# 11  [MetaDataValue, SerializedObject$Builder, Meta...          query
# 12  [EventProcessorSettings$MapWrapper, ProcessorD...     autoconfig
# 13  [Span, StatusCode, SpanBuilder, SpanContext, T...  opentelemetry
# 14  [TextMapGetter, TextMapSetter, TextMapPropagat...  opentelemetry
# 15  [CacheEvent, CacheEventListener, EventType, Ev...        caching
# 16  [CacheEntryEventFilter, CacheEntryListenerExce...        caching
# 17  [SchemaStore, BadHeaderException, BinaryMessag...           avro
# 18                 [JsonNode, ObjectMapper, JavaType]           json
# 19                            [Logger, LoggerFactory]     annotation
# 20  [TopologyChange, UpdateType, QuerySubscription...      connector
# 21  [CommandResponse, Command, CommandResponse$Bui...        command
# 22  [DcbEventChannel$AppendEventsTransaction, DcbE...          event
# 23  [ErrorMessage, ErrorMessage$Builder, Serialize...           util
# 24                            [LoggerFactory, Logger]         update
# 25   [GenericRecord, GenericDatumReader, GenericData]           avro
# 26                            [Logger, LoggerFactory]            jpa
# 27                             [Flux, Mono, FluxSink]           core
# 28  [ErrorMessage, SerializedObject, SerializedObj...        command
# 29  [CoreMatchers, StringDescription, Description,...        fixture
# 30  [QueryHandler, QueryHandler$UpdateHandler, Que...          query
# 31                            [Logger, LoggerFactory]         common
# 32                            [LoggerFactory, Logger]  configuration
# 33              [EntityManager, EntityManagerFactory]            jpa
# 34              [Subscription, Publisher, Subscriber]           core
# 35  [ConstraintViolation, Validator, ValidatorFact...   interception
# 36   [LockModeType, Query, TypedQuery, EntityManager]            jpa
# 37  [AxonServerConnectionFactory, AxonServerConnec...      connector
# 38  [EventProcessorInfo, EventProcessorInfo$Builde...          event
# 39               [AxonServerConnection, ResultStream]          event

# %% [markdown]
# ### Table 10 - Top 20 external package usage per type
#
# This table shows internal types that utilize the most different external types and packages. These have the highest probability of change depending on external libraries. A case-by-case approach is also advisable here because there could for example also be code units that encapsulate an external library and have this high count of external dependencies on purpose.
#
# Only the last 20 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_type`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *fullPackageName* is the package within the artifact that contains the type that calls external types
# - *typeName* identifies the internal type within the package and artifact that calls external types
# - *numberOfExternalTypeCaller* and *numberOfExternalTypes* refers to the distinct external types that are used by the internal type
# - *numberOfExternalTypeCalls* includes every invocation or reference to the types in the external package
# - *numberOfTypesInPackage* represents the total count of all types in that package
# - *numberOfExternalPackages* shows how many different external packages are used by the internal type
# - *externalPackageNames* contains the list of names of the different external packages that are used by the internal type
# - *externalTypeNames* contains a list of actually utilized types of the external package
# - *packageName* contains the name of the package (last part of *fullPackageName*)

# %%
external_package_usage_per_type = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_type.cypher")
external_package_usage_per_type.head(20)
# Out:
#                             artifactName  \
# 0   axon-spring-boot-autoconfigure-5.0.2
# 1   axon-spring-boot-autoconfigure-5.0.2
# 2   axon-spring-boot-autoconfigure-5.0.2
# 3   axon-spring-boot-autoconfigure-5.0.2
# 4   axon-spring-boot-autoconfigure-5.0.2
# 5   axon-spring-boot-autoconfigure-5.0.2
# 6   axon-spring-boot-autoconfigure-5.0.2
# 7            axon-server-connector-5.0.2
# 8            axon-server-connector-5.0.2
# 9            axon-server-connector-5.0.2
# 10  axon-spring-boot-autoconfigure-5.0.2
# 11  axon-spring-boot-autoconfigure-5.0.2
# 12  axon-spring-boot-autoconfigure-5.0.2
# 13                 axon-conversion-5.0.2
# 14                 axon-conversion-5.0.2
# 15           axon-server-connector-5.0.2
# 16           axon-server-connector-5.0.2
# 17  axon-spring-boot-autoconfigure-5.0.2
# 18  axon-spring-boot-autoconfigure-5.0.2
# 19  axon-spring-boot-autoconfigure-5.0.2
#
#                                       fullPackageName  \
# 0   org.axonframework.extension.springboot.autoconfig
# 1   org.axonframework.extension.springboot.autoconfig
# 2   org.axonframework.extension.springboot.autoconfig
# 3         org.axonframework.extension.springboot.util
# 4   org.axonframework.extension.springboot.autoconfig
# 5   org.axonframework.extension.springboot.autoconfig
# 6   org.axonframework.extension.springboot.autoconfig
# 7              org.axonframework.axonserver.connector
# 8        org.axonframework.axonserver.connector.event
# 9        org.axonframework.axonserver.connector.event
# 10  org.axonframework.extension.springboot.autoconfig
# 11  org.axonframework.extension.springboot.autoconfig
# 12        org.axonframework.extension.springboot.util
# 13                  org.axonframework.conversion.avro
# 14                  org.axonframework.conversion.avro
# 15     org.axonframework.axonserver.connector.command
# 16       org.axonframework.axonserver.connector.event
# 17  org.axonframework.extension.springboot.autoconfig
# 18  org.axonframework.extension.springboot.autoconfig
# 19  org.axonframework.extension.springboot.autoconfig
#
#                                       typeName  numberOfExternalTypeCaller  \
# 0                   ConverterAutoConfiguration                          16
# 1                  AxonServerAutoConfiguration                          14
# 2             AvroSchemaStoreAutoConfiguration                          14
# 3               AbstractQualifiedBeanCondition                          12
# 4             EventProcessingAutoConfiguration                          10
# 5               JpaEventStoreAutoConfiguration                           8
# 6              JpaTransactionAutoConfiguration                           8
# 7          AxonServerConnectionManager$Builder                           9
# 8   AggregateBasedAxonServerEventStorageEngine                          13
# 9                 EventProcessorControlService                           7
# 10                        JpaAutoConfiguration                           8
# 11            JdbcTransactionAutoConfiguration                           7
# 12                      DefaultEntityRegistrar                           6
# 13         SpecificRecordBaseConverterStrategy                           8
# 14                                    AvroUtil                          16
# 15               AxonServerCommandBusConnector                           9
# 16                AxonServerEventStorageEngine                          12
# 17                AxonTimeoutAutoConfiguration                           5
# 18                 CBORMapperAutoConfiguration                           8
# 19               ObjectMapperAutoConfiguration                           9
#
#     numberOfExternalTypeCalls  numberOfExternalPackages  \
# 0                          45                        11
# 1                          22                        10
# 2                          28                         8
# 3                          24                         8
# 4                          17                         7
# 5                           9                         7
# 6                          11                         7
# 7                          45                         6
# 8                          64                         6
# 9                          31                         6
# 10                         13                         6
# 11                         10                         6
# 12                          7                         6
# 13                         38                         5
# 14                         71                         5
# 15                         40                         5
# 16                         48                         5
# 17                          6                         5
# 18                         13                         5
# 19                         12                         5
#
#     numberOfExternalTypes                               externalPackageNames  \
# 0                      16  [jakarta.annotation, org.springframework.boot....
# 1                      14  [jakarta.annotation, org.springframework.boot....
# 2                      14  [org.springframework.boot.autoconfigure, org.s...
# 3                      12  [org.slf4j, jakarta.annotation, org.springfram...
# 4                      10  [jakarta.annotation, org.springframework.boot....
# 5                       8  [org.springframework.boot.autoconfigure, org.s...
# 6                       8  [org.springframework.boot.autoconfigure, org.s...
# 7                       9  [io.axoniq.axonserver.connector, io.axoniq.axo...
# 8                      13  [io.axoniq.axonserver.grpc, jakarta.annotation...
# 9                       7  [jakarta.annotation, org.slf4j, io.axoniq.axon...
# 10                      8  [org.springframework.boot.autoconfigure, org.s...
# 11                      7  [org.springframework.boot.autoconfigure, org.s...
# 12                      6  [jakarta.annotation, org.springframework.boot....
# 13                      8  [jakarta.annotation, org.apache.avro.generic, ...
# 14                     16  [jakarta.annotation, org.apache.avro, org.apac...
# 15                      9  [jakarta.annotation, org.slf4j, io.axoniq.axon...
# 16                     12  [jakarta.annotation, org.slf4j, io.axoniq.axon...
# 17                      5  [jakarta.annotation, org.springframework.boot....
# 18                      8  [org.springframework.boot.autoconfigure, org.s...
# 19                      9  [org.springframework.boot.autoconfigure, org.s...
#
#                                     externalTypeNames packageName  \
# 0   [jakarta.annotation.Nonnull, org.springframewo...  autoconfig
# 1   [jakarta.annotation.Nonnull, org.springframewo...  autoconfig
# 2   [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 3   [org.slf4j.Logger, org.slf4j.LoggerFactory, ja...        util
# 4   [jakarta.annotation.Nonnull, org.springframewo...  autoconfig
# 5   [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 6   [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 7   [io.axoniq.axonserver.connector.AxonServerConn...   connector
# 8   [io.axoniq.axonserver.grpc.MetaDataValue$Build...       event
# 9   [jakarta.annotation.Nonnull, org.slf4j.Logger,...       event
# 10  [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 11  [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 12  [jakarta.annotation.Nonnull, org.springframewo...        util
# 13  [jakarta.annotation.Nonnull, org.apache.avro.g...        avro
# 14  [jakarta.annotation.Nonnull, org.apache.avro.S...        avro
# 15  [jakarta.annotation.Nonnull, org.slf4j.Logger,...     command
# 16  [jakarta.annotation.Nonnull, org.slf4j.Logger,...       event
# 17  [jakarta.annotation.Nonnull, org.springframewo...  autoconfig
# 18  [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
# 19  [org.springframework.boot.autoconfigure.AutoCo...  autoconfig
#
#                                          fullTypeName
# 0   org.axonframework.extension.springboot.autocon...
# 1   org.axonframework.extension.springboot.autocon...
# 2   org.axonframework.extension.springboot.autocon...
# 3   org.axonframework.extension.springboot.util.Ab...
# 4   org.axonframework.extension.springboot.autocon...
# 5   org.axonframework.extension.springboot.autocon...
# 6   org.axonframework.extension.springboot.autocon...
# 7   org.axonframework.axonserver.connector.AxonSer...
# 8   org.axonframework.axonserver.connector.event.A...
# 9   org.axonframework.axonserver.connector.event.E...
# 10  org.axonframework.extension.springboot.autocon...
# 11  org.axonframework.extension.springboot.autocon...
# 12  org.axonframework.extension.springboot.util.De...
# 13  org.axonframework.conversion.avro.SpecificReco...
# 14         org.axonframework.conversion.avro.AvroUtil
# 15  org.axonframework.axonserver.connector.command...
# 16  org.axonframework.axonserver.connector.event.A...
# 17  org.axonframework.extension.springboot.autocon...
# 18  org.axonframework.extension.springboot.autocon...
# 19  org.axonframework.extension.springboot.autocon...

# %% [markdown]
# ### Table 11 - External package usage distribution per type
#
# This table shows how many types use one external package, how many use two, etc. .
# This gives an overview of the distribution of external package calls and the overall coupling to external libraries. The higher the count of distinct external packages the lower should be the count of types that use them. Dependencies to external annotations are left out here.
#
# More details about which types have the highest external package dependency usage can be in the tables 4 and 5 above.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_distribution`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *artifactTypes* the total count of types in the artifact
# - *numberOfExternalPackages* the number of distinct external packages used
# - *numberOfTypes* in the artifact where the *numberOfExternalPackages* applies
# - *numberOfTypesPercentage* in the artifact where the *numberOfExternalPackages* applies in %

# %%
external_package_usage_per_artifact_distribution = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_distribution.cypher")
external_package_usage_per_artifact_distribution_truncated=external_package_usage_per_artifact_distribution[['artifactName', 'artifactPackages', 'artifactTypes', 'numberOfExternalPackages', 'numberOfPackages', 'numberOfTypes', 'typesCallingExternalRate', 'packagesCallingExternalRate']].head(40)
external_package_usage_per_artifact_distribution_truncated
# Out:
#                             artifactName  artifactPackages  artifactTypes  \
# 0                   axon-messaging-5.0.2                57            570
# 1                      axon-common-5.0.2                15            156
# 2   axon-spring-boot-autoconfigure-5.0.2                 7             72
# 3            axon-server-connector-5.0.2                 5             72
# 4               axon-eventsourcing-5.0.2                 8            104
# 5                        axon-test-5.0.2                 5             73
# 6                  axon-conversion-5.0.2                 4             30
# 7                   axon-modelling-5.0.2                 7             93
# 8                      axon-update-5.0.2                 5             23
# 9          axon-metrics-micrometer-5.0.2                 2             13
# 10      axon-tracing-opentelemetry-5.0.2                 1              5
#
#     numberOfExternalPackages  numberOfPackages  numberOfTypes  \
# 0                          7                18             45
# 1                         10                 7             18
# 2                         33                 7             34
# 3                         20                 5             51
# 4                          5                 4             11
# 5                          9                 4             24
# 6                         10                 3             15
# 7                          1                 3              3
# 8                          1                 3              7
# 9                          3                 2             12
# 10                         5                 1              5
#
#     typesCallingExternalRate  packagesCallingExternalRate
# 0                   7.894737                    31.578947
# 1                  11.538462                    46.666667
# 2                  47.222222                   100.000000
# 3                  70.833333                   100.000000
# 4                  10.576923                    50.000000
# 5                  32.876712                    80.000000
# 6                  50.000000                    75.000000
# 7                   3.225806                    42.857143
# 8                  30.434783                    60.000000
# 9                  92.307692                   100.000000
# 10                100.000000                   100.000000

# %% [markdown]
# ### Table 12 - External package usage per artifact grouped by number of internal packages
#
# The following table shows the external package usage for every artifact grouped by the number of distinct internal dependent packages. The intention is to find external package usage spread across multiple internal packages in artifacts.
#
# Artifacts that encapsulate external dependency calls in one internal package overall (or each) are easier to change if those external dependencies change and are most likely applying a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture). Artifacts that use external dependencies in multiple internal packages need more effort to adapt to changes of those external dependencies. On one hand this could be intended e.g. when using standardized libraries. On the other hand this might indicate higher than necessary coupling.
#
# The whole table can be found in the following CSV report:
# `External_package_usage_per_internal_package_count`

# %%
external_package_usage_per_package_distribution = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_internal_package_count.cypher")

# Only show external dependencies that are at least used in 2 internal packages. 
# Filter out all rows with "numberOfPackages" <= 2.
external_package_usage_per_package_distribution=external_package_usage_per_package_distribution.query("`numberOfPackages` >= 2")
# Organize artifacts in columns with the number of packages that call external packages as values using pivot
# Every row represents the number of external packages
external_package_usage_per_package_distribution=external_package_usage_per_package_distribution.pivot(index='numberOfPackages', columns='artifactName', values='maxPackagesCallingExternalRate')

# Fill missing values with zero
external_package_usage_per_package_distribution.fillna(0, inplace=True)

external_package_usage_per_package_distribution
# Out:
# artifactName      axon-common-5.0.2  axon-conversion-5.0.2  \
# numberOfPackages
# 2                          0.000000                    0.0
# 3                          0.000000                   75.0
# 4                         26.666667                  100.0
# 5                          0.000000                    0.0
# 7                          0.000000                    0.0
# 8                          0.000000                    0.0
# 9                         60.000000                    0.0
# 14                         0.000000                    0.0
# 56                         0.000000                    0.0
#
# artifactName      axon-eventsourcing-5.0.2  axon-messaging-5.0.2  \
# numberOfPackages
# 2                                     25.0              0.000000
# 3                                      0.0              5.263158
# 4                                      0.0              0.000000
# 5                                      0.0              8.771930
# 7                                      0.0              0.000000
# 8                                    100.0              0.000000
# 9                                      0.0              0.000000
# 14                                     0.0             24.561404
# 56                                     0.0             98.245614
#
# artifactName      axon-metrics-micrometer-5.0.2  axon-modelling-5.0.2  \
# numberOfPackages
# 2                                         100.0              0.000000
# 3                                           0.0             42.857143
# 4                                           0.0              0.000000
# 5                                           0.0              0.000000
# 7                                           0.0            100.000000
# 8                                           0.0              0.000000
# 9                                           0.0              0.000000
# 14                                          0.0              0.000000
# 56                                          0.0              0.000000
#
# artifactName      axon-server-connector-5.0.2  \
# numberOfPackages
# 2                                        40.0
# 3                                        60.0
# 4                                        80.0
# 5                                       100.0
# 7                                         0.0
# 8                                         0.0
# 9                                         0.0
# 14                                        0.0
# 56                                        0.0
#
# artifactName      axon-spring-boot-autoconfigure-5.0.2  axon-test-5.0.2  \
# numberOfPackages
# 2                                            28.571429             40.0
# 3                                            42.857143             60.0
# 4                                            57.142857              0.0
# 5                                             0.000000              0.0
# 7                                             0.000000              0.0
# 8                                             0.000000              0.0
# 9                                             0.000000              0.0
# 14                                            0.000000              0.0
# 56                                            0.000000              0.0
#
# artifactName      axon-update-5.0.2
# numberOfPackages
# 2                               0.0
# 3                              60.0
# 4                              80.0
# 5                               0.0
# 7                               0.0
# 8                               0.0
# 9                               0.0
# 14                              0.0
# 56                              0.0

# %% [markdown]
# ### Table 13 - External package usage aggregated
#
# This table lists all artifacts and their external package dependencies usage aggregated over internal packages.
#
# The intention behind this is to find artifacts that use an external dependency across multiple internal packages. This might be intended for frameworks and standardized libraries and helps to quantify how widely those are used. For some external dependencies it might be beneficial to only access it from one package and provide an abstraction for internal usage following a [Hexagonal architecture](https://alistair.cockburn.us/hexagonal-architecture). Thus, this table may also help in finding application for the Hexagonal architecture or similar approaches (Domain Driven Design Anti Corruption Layer). After all it is easier to update or replace such external dependencies when they are used in specific areas and not all over the code.
#
# Only the last 40 entries are shown. The whole table can be found in the following CSV report:
# `External_package_usage_per_artifact_package_aggregated`
#
# **Columns:**
# - *artifactName* that contains the type that calls the external package
# - *artifactPackages* is the total count of packages in the artifact
# - *artifactTypes* is the total count of types in the artifact
# - *numberOfExternalPackages* the number of distinct external packages used
# - *[min,max,med,avg,std]NumberOfPackages* provide statistics based on each external package and its package usage within the artifact
# - *[min,max,med,avg,std]NumberOfPackagesPercentage* provide statistics in % based on each external package and its package usage within the artifact in respect to the overall count of packages in the artifact
# - *[min,max,med,avg,std]NumberOfTypes* provide statistics based on each external package and its type usage within the artifact
# - *[min,max,med,avg,std]NumberOfTypePercentage* provide statistics in % based on each external package and its type usage within the artifact in respect to the overall count of packages in the artifact
# - *numberOfTypes* in the artifact where the *numberOfExternalPackages* applies
# - *numberOfTypesPercentage* in the artifact where the *numberOfExternalPackages* applies in %

# %% [markdown]
# #### Table 13a - External package usage aggregated - count of internal packages

# %%
external_package_usage_aggregated = query_cypher_to_data_frame("../cypher/External_Dependencies/External_package_usage_per_artifact_package_aggregated.cypher")

external_package_usage_aggregated_packages = external_package_usage_aggregated[['artifactName', 'artifactPackages', 'numberOfExternalPackages', 'minNumberOfPackages', 'medNumberOfPackages', 'avgNumberOfPackages', 'maxNumberOfPackages', 'stdNumberOfPackages']]
external_package_usage_aggregated_packages.head(30)
# Out:
#                             artifactName  artifactPackages  \
# 0                   axon-messaging-5.0.2                57
# 1            axon-server-connector-5.0.2                 5
# 2                      axon-common-5.0.2                15
# 3                  axon-conversion-5.0.2                 4
# 4                   axon-modelling-5.0.2                 7
# 5   axon-spring-boot-autoconfigure-5.0.2                 7
# 6                        axon-test-5.0.2                 5
# 7                      axon-update-5.0.2                 5
# 8               axon-eventsourcing-5.0.2                 8
# 9          axon-metrics-micrometer-5.0.2                 2
# 10      axon-tracing-opentelemetry-5.0.2                 1
#
#     numberOfExternalPackages  minNumberOfPackages  medNumberOfPackages  \
# 0                          7                    1                  1.0
# 1                         20                    1                  1.0
# 2                         10                    1                  1.0
# 3                         10                    1                  1.0
# 4                          1                    3                  3.0
# 5                         33                    1                  1.0
# 6                          9                    1                  1.0
# 7                          1                    3                  3.0
# 8                          5                    1                  1.0
# 9                          3                    1                  1.0
# 10                         5                    1                  1.0
#
#     avgNumberOfPackages  maxNumberOfPackages  stdNumberOfPackages
# 0              3.714286                   14             4.785892
# 1              1.900000                    5             1.333772
# 2              1.300000                    4             0.948683
# 3              1.200000                    3             0.632456
# 4              3.000000                    3             0.000000
# 5              1.303030                    3             0.529437
# 6              1.222222                    3             0.666667
# 7              3.000000                    3             0.000000
# 8              1.200000                    2             0.447214
# 9              1.333333                    2             0.577350
# 10             1.000000                    1             0.000000

# %% [markdown]
# #### Table 13b - External package usage aggregated - percentage of internal packages

# %%
external_package_usage_aggregated_packages_percentage = external_package_usage_aggregated[['artifactName', 'artifactPackages', 'numberOfExternalPackages', 'minNumberOfPackagesPercentage', 'medNumberOfPackagesPercentage', 'avgNumberOfPackagesPercentage', 'maxNumberOfPackagesPercentage', 'stdNumberOfPackagesPercentage']]
external_package_usage_aggregated_packages_percentage.head(30)
# Out:
#                             artifactName  artifactPackages  \
# 0                   axon-messaging-5.0.2                57
# 1            axon-server-connector-5.0.2                 5
# 2                      axon-common-5.0.2                15
# 3                  axon-conversion-5.0.2                 4
# 4                   axon-modelling-5.0.2                 7
# 5   axon-spring-boot-autoconfigure-5.0.2                 7
# 6                        axon-test-5.0.2                 5
# 7                      axon-update-5.0.2                 5
# 8               axon-eventsourcing-5.0.2                 8
# 9          axon-metrics-micrometer-5.0.2                 2
# 10      axon-tracing-opentelemetry-5.0.2                 1
#
#     numberOfExternalPackages  minNumberOfPackagesPercentage  \
# 0                          7                       1.754386
# 1                         20                      20.000000
# 2                         10                       6.666667
# 3                         10                      25.000000
# 4                          1                      42.857143
# 5                         33                      14.285714
# 6                          9                      20.000000
# 7                          1                      60.000000
# 8                          5                      12.500000
# 9                          3                      50.000000
# 10                         5                     100.000000
#
#     medNumberOfPackagesPercentage  avgNumberOfPackagesPercentage  \
# 0                        1.754386                       6.516291
# 1                       20.000000                      38.000000
# 2                        6.666667                       8.666667
# 3                       25.000000                      30.000000
# 4                       42.857143                      42.857143
# 5                       14.285714                      18.614719
# 6                       20.000000                      24.444444
# 7                       60.000000                      60.000000
# 8                       12.500000                      15.000000
# 9                       50.000000                      66.666667
# 10                     100.000000                     100.000000
#
#     maxNumberOfPackagesPercentage  stdNumberOfPackagesPercentage
# 0                       24.561404                       8.396302
# 1                      100.000000                      26.675437
# 2                       26.666667                       6.324555
# 3                       75.000000                      15.811388
# 4                       42.857143                       0.000000
# 5                       42.857143                       7.563379
# 6                       60.000000                      13.333333
# 7                       60.000000                       0.000000
# 8                       25.000000                       5.590170
# 9                      100.000000                      28.867513
# 10                     100.000000                       0.000000

# %% [markdown]
# #### Table 13c - External package usage aggregated - count of internal types

# %%
external_package_usage_aggregated_types = external_package_usage_aggregated[['artifactName', 'artifactTypes', 'numberOfExternalPackages', 'minNumberOfTypes', 'medNumberOfTypes', 'avgNumberOfTypes', 'maxNumberOfTypes', 'stdNumberOfTypes']]
external_package_usage_aggregated_types.head(30)
# Out:
#                             artifactName  artifactTypes  \
# 0                   axon-messaging-5.0.2            570
# 1            axon-server-connector-5.0.2             72
# 2                      axon-common-5.0.2            156
# 3                  axon-conversion-5.0.2             30
# 4                   axon-modelling-5.0.2             93
# 5   axon-spring-boot-autoconfigure-5.0.2             72
# 6                        axon-test-5.0.2             73
# 7                      axon-update-5.0.2             23
# 8               axon-eventsourcing-5.0.2            104
# 9          axon-metrics-micrometer-5.0.2             13
# 10      axon-tracing-opentelemetry-5.0.2              5
#
#     numberOfExternalPackages  minNumberOfTypes  medNumberOfTypes  \
# 0                          7                 2               2.0
# 1                         20                 1               3.5
# 2                         10                 1               1.0
# 3                         10                 1               2.5
# 4                          1                 3               3.0
# 5                         33                 1               2.0
# 6                          9                 1               1.0
# 7                          1                 7               7.0
# 8                          5                 1               1.0
# 9                          3                 1               1.0
# 10                         5                 1               2.0
#
#     avgNumberOfTypes  maxNumberOfTypes  stdNumberOfTypes
# 0           7.428571                30         10.244627
# 1           5.200000                18          4.840618
# 2           2.300000                 8          2.263233
# 3           3.100000                 6          2.024846
# 4           3.000000                 3          0.000000
# 5           2.272727                 7          1.586520
# 6           3.333333                22          7.000000
# 7           7.000000                 7          0.000000
# 8           3.000000                 6          2.738613
# 9           4.666667                12          6.350853
# 10          2.200000                 4          1.303840

# %% [markdown]
# #### Table 13d - External package usage aggregated - percentage of internal types

# %%
external_package_usage_aggregated_types_percentage = external_package_usage_aggregated[['artifactName', 'artifactTypes', 'numberOfExternalPackages', 'minNumberOfTypesPercentage', 'medNumberOfTypesPercentage', 'avgNumberOfTypesPercentage', 'maxNumberOfTypesPercentage', 'stdNumberOfTypesPercentage']]
external_package_usage_aggregated_types_percentage.head(30)
# Out:
#                             artifactName  artifactTypes  \
# 0                   axon-messaging-5.0.2            570
# 1            axon-server-connector-5.0.2             72
# 2                      axon-common-5.0.2            156
# 3                  axon-conversion-5.0.2             30
# 4                   axon-modelling-5.0.2             93
# 5   axon-spring-boot-autoconfigure-5.0.2             72
# 6                        axon-test-5.0.2             73
# 7                      axon-update-5.0.2             23
# 8               axon-eventsourcing-5.0.2            104
# 9          axon-metrics-micrometer-5.0.2             13
# 10      axon-tracing-opentelemetry-5.0.2              5
#
#     numberOfExternalPackages  minNumberOfTypesPercentage  \
# 0                          7                    0.350877
# 1                         20                    1.388889
# 2                         10                    0.641026
# 3                         10                    3.333333
# 4                          1                    3.225806
# 5                         33                    1.388889
# 6                          9                    1.369863
# 7                          1                   30.434783
# 8                          5                    0.961538
# 9                          3                    7.692308
# 10                         5                   20.000000
#
#     medNumberOfTypesPercentage  avgNumberOfTypesPercentage  \
# 0                     0.350877                    1.303258
# 1                     4.861111                    7.222222
# 2                     0.641026                    1.474359
# 3                     8.333333                   10.333333
# 4                     3.225806                    3.225806
# 5                     2.777778                    3.156566
# 6                     1.369863                    4.566210
# 7                    30.434783                   30.434783
# 8                     0.961538                    2.884615
# 9                     7.692308                   35.897436
# 10                   40.000000                   44.000000
#
#     maxNumberOfTypesPercentage  stdNumberOfTypesPercentage
# 0                     5.263158                    1.797303
# 1                    25.000000                    6.723080
# 2                     5.128205                    1.450790
# 3                    20.000000                    6.749486
# 4                     3.225806                    0.000000
# 5                     9.722222                    2.203500
# 6                    30.136986                    9.589041
# 7                    30.434783                    0.000000
# 8                     5.769231                    2.633282
# 9                    92.307692                   48.852715
# 10                   80.000000                   26.076810

# %% [markdown]
# #### Table 13 Chart 1 - External package usage - max percentage of internal types
#
# This chart shows per artifact the maximum percentage of internal packages (compared to all packages in that artifact) that use one specific external package.
#
# **Example:** One artifact might use 10 external packages where 7 of them are used in one internal package, 2 of them are used in two packages and one external dependency is used in 5 packages. So for this artifact there will be a point at x = 10 (external packages used by the artifact) and 5 (max internal packages). Instead of the count the percentage of internal packages compared to all packages in that artifact is used to get a normalized plot.

# %%
def annotate_plot(data_frame: pd.DataFrame, index: int):
    """
    Annotates the data points identified by the "index" in the plot of the "data_frame" 
    """
    x_position = data_frame.numberOfExternalPackages[index].item()
    y_position = data_frame.maxNumberOfPackagesPercentage[index].item()
    artifact_name = data_frame.artifactName[index].item()

    label_box=dict(boxstyle="round4,pad=0.5", fc="w", alpha=0.8)
    plot.annotate(artifact_name
        ,xy=(x_position, y_position)
        ,xycoords='data'
        ,xytext=(-30, -15)
        ,textcoords='offset points'
        ,size=6
        ,bbox=label_box
        ,arrowprops=dict(arrowstyle="-|>", mutation_scale=10, color="black")
    )

def index_of_sorted(data_frame: pd.DataFrame, highest: list[str] = []):
    """
    Sorts the "data_frame" by columns 'numberOfExternalPackages','maxNumberOfPackagesPercentage','artifactPackages', 'artifactName'
    and returns the index of the first row.
    Columns that are contained in the list of strings parameter "highest" will be sorted descending (highest first).
    """
    by = ['numberOfExternalPackages','maxNumberOfPackagesPercentage','artifactPackages', 'artifactName']
    ascending = [('numberOfExternalPackages' not in highest), ('maxNumberOfPackagesPercentage' not in highest), False, True]
    return data_frame.sort_values(by=by, ascending=ascending).head(1).index

# %%
if external_package_usage_aggregated.empty:
    print("No data to plot")
else:
    plot.figure();
    axes = external_package_usage_aggregated.plot(
        kind='scatter',
        title='External package usage - max internal packages %', 
        x='numberOfExternalPackages',
        y='maxNumberOfPackagesPercentage',
        s='artifactPackages',
        c='stdNumberOfPackagesPercentage',
        xlabel='external package count',
        ylabel='max percentage of internal packages',
        cmap=main_color_map,
    )

    # Annotate the largest artifact with the highest number of external packages and max number of packages in percentage
    annotation_index = index_of_sorted(highest=['numberOfExternalPackages','maxNumberOfPackagesPercentage'], data_frame=external_package_usage_aggregated)
    annotate_plot(external_package_usage_aggregated, annotation_index)


    # Annotate the largest artifact with the lowest number of external packages and the highest max number of packages in percentage
    annotation_index = index_of_sorted(highest=['maxNumberOfPackagesPercentage'], data_frame=external_package_usage_aggregated)
    annotate_plot(external_package_usage_aggregated, annotation_index)

    # Annotate the largest artifact with the lowest number of external packages and max number of packages in percentage
    annotation_index = index_of_sorted(highest=[], data_frame=external_package_usage_aggregated)
    annotate_plot(external_package_usage_aggregated, annotation_index)

    plot.show()

# %% [markdown]
# #### Table 13 Chart 2 - External package usage - median percentage of internal types
#
# This chart shows per artifact the median (0.5 percentile) of internal packages (compared to all packages in that artifact) that use one specific external package.
#
# **Example:** One artifact might use 9 external packages where 3 of them are used in 1 internal package, 3 of them are used in 2 package and the last 3 ones are used in 3 packages. So for this artifact there will be a point at x = 10 (external packages used by the artifact) and 2 (median internal packages). Instead of the count the percentage of internal packages compared to all packages in that artifact is used to get a normalized plot.

# %%
if external_package_usage_aggregated.empty:
    print("No data to plot")
else:
    plot.figure();
    axes = external_package_usage_aggregated.plot(
        kind='scatter',
        title='External package usage - median internal packages %', 
        x='numberOfExternalPackages',
        y='medNumberOfPackagesPercentage',
        s='artifactPackages',
        c='stdNumberOfPackagesPercentage',
        xlabel='external package count',
        ylabel='median percentage of internal packages',
        cmap=main_color_map,
    )
    plot.show()

# %% [markdown]
# ## Maven POMs
#
#
# ### Table 14 - Maven POMs and their declared dependencies
#
# If Maven is used as for package and dependency management and a ".pom" file is included in the artifact, the following table shows the external dependencies that are declared there.

# %%
query_cypher_to_data_frame("../cypher/External_Dependencies/Maven_POMs_and_their_declared_dependencies.cypher")
# Out:
#                  pom.artifactId                                  pom.name  \
# 0                   axon-common                   Axon Framework - Common
# 1                   axon-common                   Axon Framework - Common
# 2                   axon-common                   Axon Framework - Common
# 3                   axon-common                   Axon Framework - Common
# 4                   axon-common                   Axon Framework - Common
# ..                          ...                                       ...
# 190  axon-tracing-opentelemetry  Axon Extension - Tracing - OpenTelemetry
# 191  axon-tracing-opentelemetry  Axon Extension - Tracing - OpenTelemetry
# 192                 axon-update                   Axon Framework - Update
# 193                 axon-update                   Axon Framework - Update
# 194                 axon-update                   Axon Framework - Update
#
#         scope  dependency.optional     dependentArtifact.group  \
# 0     default                 True          jakarta.annotation
# 1     default                False  com.fasterxml.jackson.core
# 2     default                 True           io.projectreactor
# 3     default                 True           org.hibernate.orm
# 4    provided                False    com.google.code.findbugs
# ..        ...                  ...                         ...
# 190   default                False            io.opentelemetry
# 191   default                False          jakarta.annotation
# 192      test                False           org.axonframework
# 193   default                False           org.axonframework
# 194   default                False          jakarta.annotation
#
#      dependentArtifact.name
# 0    jakarta.annotation-api
# 1              jackson-core
# 2              reactor-core
# 3            hibernate-core
# 4                    jsr305
# ..                      ...
# 190       opentelemetry-api
# 191  jakarta.annotation-api
# 192             axon-common
# 193             axon-common
# 194  jakarta.annotation-api
#
# [195 rows x 6 columns]

# %%
driver.close()
